# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2263.4231227306523), ('GrLivArea', 1597.878695916866), ('ExterQual', 1033.7141434034572), ('GarageCars', 961.7515977732157), ('TotalBsmtSF', 921.5483673197025), ('GarageArea', 879.2628959844347), ('1stFlrSF', 825.8071914147931), ('KitchenQual', 775.54913818027), ('BsmtQual', 769.6257514754724), ('FullBath', 609.3048514739886), ('TotRmsAbvGrd', 566.5746087879229), ('YearBuilt', 552.8077251674924), ('YearRemodAdd', 447.73491780914446), ('MasVnrArea', 391.58223661070673), ('Fireplaces', 349.01230123565665), ('GarageFinish', 340.9518188654906), ('BsmtFinSF1', 252.16480822030374), ('HeatingQC', 249.13699635252283), ('LotFrontage', 224.27959829130236), ('NeighborhoodDummy_NridgHt', 219.62584184005507), ('MSSubClassDummy_60', 211.37735346948546), ('NeighborhoodDummy_NoRidge', 184.34339917144032), ('OpenPorchSF', 172.6577534788365), ('WoodDeckSF', 159.08572266499644), ('BsmtExposure', 143.28608356179032), ('2ndFlrSF', 138.11683977009682), ('MSZoningDummy_RM', 131.9005017995235), ('LotArea', 110.21140126850368), ('HalfBath', 105.20275690824245), ('LotShapeDummy_Reg', 90.65817674238498), ('BsmtFullBath', 84.04370540797287), ('MSZoningDummy_RL', 76.32281607592955), ('MSSubClassDummy_30', 69.97751050951251), ('NeighborhoodDummy_NAmes', 69.3199047480088), ('GarageYrBlt', 66.22492787952226), ('NeighborhoodDummy_OldTown', 62.142690616570974), ('BsmtUnfSF', 58.67558431847866), ('GarageCond', 51.86541679914146), ('GarageQual', 49.22271616036187), ('NeighborhoodDummy_StoneBr', 45.649900947823866), ('NeighborhoodDummy_Edwards', 42.47703379679817), ('MSSubClassDummy_50', 41.11513847535489), ('Fence', 35.762454711791385), ('NeighborhoodDummy_Somerst', 35.523206711986134), ('BedroomAbvGr', 34.32374340059292), ('NeighborhoodDummy_Sawyer', 28.246529566552724), ('OverallCond', 27.35945124444817), ('NeighborhoodDummy_IDOTRR', 25.362355396117024), ('NeighborhoodDummy_Timber', 24.429223244966252), ('NeighborhoodDummy_BrkSide', 23.981181790200303), ('KitchenAbvGr', 22.38418844176416), ('MSSubClassDummy_160', 21.297418778523692), ('EnclosedPorch', 18.958619974462056), ('AlleyDummy_No_Alley_Access', 17.36436078037845), ('LotConfigDummy_CulDSac', 17.225409026949695), ('MSSubClassDummy_90', 17.153107259310303), ('MSZoningDummy_FV', 16.8925746963765), ('ExterCond', 16.649468199619108), ('NeighborhoodDummy_BrDale', 16.481466073017273), ('Condition1Dummy_Norm', 15.53652986901979), ('NeighborhoodDummy_MeadowV', 12.130509403849786), ('Condition1Dummy_Feedr', 11.438529251641379), ('BsmtFinType1', 10.047074965878029), ('LandContourDummy_HLS', 10.03134051532315), ('NeighborhoodDummy_CollgCr', 9.434167183105503), ('BsmtFinType2', 7.744010596977385), ('BsmtCond', 7.565573677587241), ('FireplaceQu', 7.182874925721101), ('MSSubClassDummy_45', 6.9883960523162925), ('MSSubClassDummy_190', 6.220524155433208), ('MSZoningDummy_RH', 6.124643353673461), ('NeighborhoodDummy_SWISU', 6.09025068088084), ('NeighborhoodDummy_Crawfor', 5.99015788962686), ('LotConfigDummy_Inside', 5.986050558869858), ('NeighborhoodDummy_Veenker', 5.729033119293524), ('LotShapeDummy_IR2', 5.561193204894594), ('NeighborhoodDummy_Mitchel', 5.345642047210723), ('LowQualFinSF', 4.840861404121432), ('NeighborhoodDummy_ClearCr', 4.816499392152724), ('MSSubClassDummy_85', 4.183612108091699), ('LandContourDummy_Low', 4.135440657708055), ('ScreenPorch', 3.841043213282496), ('MoSold', 3.705991872804996), ('MSSubClassDummy_180', 3.530392691774311), ('NeighborhoodDummy_NPkVill', 2.4867910007693617), ('Condition1Dummy_PosA', 2.426156775067478), ('3SsnPorch', 2.1933872748101546), ('Condition1Dummy_RRAe', 2.1216838390247053), ('LandSlope', 1.9853837577481799), ('NeighborhoodDummy_Gilbert', 1.9657647470567818), ('MSSubClassDummy_80', 1.9233416880345418), ('MSSubClassDummy_120', 1.8866479061949433), ('BsmtHalfBath', 1.5776935692335088), ('Condition1Dummy_PosN', 1.5562450968687), ('MSSubClassDummy_70', 0.9811339003531755), ('LandContourDummy_Lvl', 0.9169894100733035), ('BsmtFinSF2', 0.7441865236732818),  ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.34558411, 0.21234326]),
#  'std_fit_time': array([0.10976918, 0.01526989]),
#  'mean_score_time': array([0.01023264, 0.01004229]),
#  'std_score_time': array([0.00058955, 0.0006853 ]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86152849, 0.88953702]),
#  'split1_test_score': array([0.89579923, 0.88472081]),
#  'split2_test_score': array([0.87003942, 0.82136031]),
#  'split3_test_score': array([0.86620304, 0.87709994]),
#  'split4_test_score': array([0.90281083, 0.8890844 ]),
#  'mean_test_score': array([0.8792762, 0.8723605]),
#  'std_test_score': array([0.01672182, 0.02588815]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8792762025030934

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5592582530718107),
#  ('GrLivArea', 0.1272180609288096),
#  ('TotalBsmtSF', 0.05034794241189032),
#  ('BsmtFinSF1', 0.04551939495739145),
#  ('1stFlrSF', 0.028263380612757166),
#  ('GarageArea', 0.026624180009315015),
#  ('MasVnrArea', 0.017617269997777667),
#  ('GarageCars', 0.013311330865471477),
#  ('LotArea', 0.011071656055764292),
#  ('2ndFlrSF', 0.010186531855017732),
#  ('YearBuilt', 0.00860526994387223),
#  ('YearRemodAdd', 0.007688848144730981),
#  ('BsmtUnfSF', 0.006312047730120532),
#  ('TotRmsAbvGrd', 0.005652255969342625),
#  ('BsmtQual', 0.00559318959224942),
#  ('LotFrontage', 0.0048507455784443775),
#  ('GarageYrBlt', 0.004392473836530069),
#  ('OpenPorchSF', 0.004238700010110196),
#  ('WoodDeckSF', 0.003924550688356698),
#  ('OverallCond', 0.0037578197277796936),
#  ('FullBath', 0.003267013501605216),
#  ('MoSold', 0.002909751036609496),
#  ('KitchenQual', 0.00273564147602946),
#  ('BsmtExposure', 0.002257939639973993),
#  ('GarageFinish', 0.002083860170267877),
#  ('FunctionalDummy_Typ', 0.002003394495129551),
#  ('BsmtFinType1', 0.001961342722949789),
#  ('Fireplaces', 0.0019097235470927098),
#  ('ExterQual', 0.0017762272679950914),
#  ('BedroomAbvGr', 0.0015846951032843866),
#  ('MSZoningDummy_RL', 0.0015280483100455857),
#  ('KitchenAbvGr', 0.0014523756208695007),
#  ('YrSold', 0.0013448667875978725),
#  ('FireplaceQu', 0.0012668241387079036),
#  ('LotShapeDummy_IR3', 0.0011551619110767902),
#  ('GarageTypeDummy_CarPort', 0.0010657945860166166),
#  ('HalfBath', 0.0010558927155966014),
#  ('BsmtFullBath', 0.0009168856873001007),
#  ('NeighborhoodDummy_CollgCr', 0.0009032217185427071),
#  ('HeatingQC', 0.0006811108942729064),
#  ('BsmtFinSF2', 0.000591242383124876),
#  ('Exterior2ndDummy_Stucco', 0.0005715467241237574),
#  ('MSSubClassDummy_50', 0.0005548316155165174),
#  ('Exterior2ndDummy_CmentBd', 0.0005362181601105977),
#  ('EnclosedPorch', 0.000520983865112205),
#  ('Exterior1stDummy_CemntBd', 0.0005204181897625328),
#  ('RoofStyleDummy_Hip', 4.7528383223844897e-07),
#  ('Condition2Dummy_Feedr', 4.3694224977397667e-07),
#  ('MSSubClassDummy_30', 3.4256471946526475e-07),
#  ('SaleTypeDummy_WD', 3.306290295663756e-07),
#  ('BldgTypeDummy_TwnhsE', 3.198899296598487e-07),
#  ('Exterior2ndDummy_Plywood', 3.052895233717972e-07),
#  ('MiscFeatureDummy_Shed', 2.802489856958404e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 2.7733528309498777e-07),
#  ('SaleTypeDummy_Con', 2.171769705161693e-07),
#  ('MSSubClassDummy_160', 1.8624923730730832e-07),
#  ('Exterior2ndDummy_BrkFace', 1.8247391897758022e-07),
#  ('SaleTypeDummy_ConLD', 1.1198710623850409e-07),
#  ('LandContourDummy_Lvl', 2.239958640429928e-08),
#  ('RoofMatlDummy_WdShngl', 2.1113982005976195e-08),
#  ('Exterior1stDummy_BrkFace', 1.9104086993844285e-08),
#  ('RoofMatlDummy_Metal', 6.62949404813506e-09),
#  ('Condition2Dummy_RRAn', 4.604343733437752e-09),
#  ('Condition2Dummy_RRAe', 3.330460344294998e-09),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('FunctionalDummy_Mod', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.026511  , 0.0048543 , 0.00460563, 0.00468717, 0.00463815,
#         0.00513535, 0.00476642, 0.00484161]),
#  'std_fit_time': array([0.04351826, 0.00012144, 0.00038582, 0.00033851, 0.00023595,
#         0.00039079, 0.00012284, 0.00011733]),
#  'mean_score_time': array([0.00247588, 0.00263362, 0.00256033, 0.00267181, 0.00258274,
#         0.00268331, 0.00259309, 0.00264101]),
#  'std_score_time': array([1.91662772e-04, 5.38009684e-05, 1.22824811e-04, 4.09937435e-05,
#         1.22315600e-04, 1.51508927e-04, 9.21736711e-05, 1.93265577e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.88775545, 0.88905048, 0.89383825, 0.90061321, 0.90296447,
#         0.90474107, 0.90239903, 0.88117572]),
#  'split1_test_score': array([0.88777264, 0.88994674, 0.89395738, 0.89611537, 0.89635158,
#         0.89638074, 0.87801634, 0.85087114]),
#  'split2_test_score': array([0.86265406, 0.87905343, 0.88622432, 0.88838704, 0.88778163,
#         0.88693484, 0.85063076, 0.81499993]),
#  'split3_test_score': array([0.86752007, 0.86872616, 0.87145495, 0.87427985, 0.87479574,
#         0.87499048, 0.85851775, 0.83337196]),
#  'split4_test_score': array([0.88174898, 0.88668136, 0.88831423, 0.8923491 , 0.89389938,
#         0.89506991, 0.88836898, 0.865643  ]),
#  'mean_test_score': array([0.87749024, 0.88269163, 0.88675782, 0.89034892, 0.89115856,
#         0.89162341, 0.87558657, 0.84921235]),
#  ('Condition1Dummy_Feedr', 2485.52726441929),
#  ('Exterior1stDummy_BrkComm', 2460.6624034388246),
#  ('NeighborhoodDummy_NPkVill', -2360.805900084427),
#  ('GarageArea', 2353.6190334934413),
#  ('BldgTypeDummy_Twnhs', -2344.682369504582),
#  ('NeighborhoodDummy_Mitchel', -2217.303321609829),
#  ('LotFrontage', 2202.161073744663),
#  ('FullBath', 2198.9718985541635),
#  ('UtilitiesDummy_NoSeWa', 2194.798081714075),
#  ('SaleConditionDummy_Family', 2182.5926271411213),
#  ('MSSubClassDummy_90', -2150.311084239332),
#  ('NeighborhoodDummy_Crawfor', -2086.2228940584573),
#  ('BsmtExposure', -2051.6968205100616),
#  ('Fireplaces', 2027.774066578119),
#  ('FoundationDummy_CBlock', 2022.2630771379793),
#  ('MasVnrTypeDummy_No_MasVnr', 2006.9385995158104),
#  ('BldgTypeDummy_Duplex', -1985.6818300793034),
#  ('MasVnrTypeDummy_None', 1852.7215706004363),
#  ('Exterior1stDummy_VinylSd', -1820.1786416328093),
#  ('SaleConditionDummy_Normal', 1724.259494158645),
#  ('NeighborhoodDummy_ClearCr', -1716.811620886925),
#  ('BsmtUnfSF', -1691.111041408612),
#  ('OpenPorchSF', 1685.4588931474468),
#  ('WoodDeckSF', 1677.6049633719833),
#  ('MSZoningDummy_RM', 1654.7721051804306),
#  ('NeighborhoodDummy_NridgHt', -1642.5299405842648),
#  ('Exterior2ndDummy_Wd Sdng', -1641.3155872599245),
#  ('MSSubClassDummy_120', -1618.5019036831727),
#  ('YearRemodAdd', 1594.8309779972403),
#  ('MSSubClassDummy_190', 1477.6362217993046),
#  ('HouseStyleDummy_2.5Unf', -1453.7104351265325),
#  ('ScreenPorch', 1452.9314039305737),
#  ('NeighborhoodDummy_Edwards', -1447.6138376476702),
#  ('NeighborhoodDummy_Blueste', 1375.6814664432698),
#  ('HouseStyleDummy_1Story', -1360.7388809783913),
#  ('SaleTypeDummy_CWD', 1288.7633316654976),
#  ('Exterior2ndDummy_CBlock', 1277.6340409591292),
#  ('LandContourDummy_Lvl', -1271.8282990452851),
#  ('LandContourDummy_HLS', -1261.9245523352706),
#  ('Exterior1stDummy_CBlock', -1242.6952211659234),
#  ('NeighborhoodDummy_MeadowV', -1219.65798491141),
#  ('FireplaceQu', -1203.0625284588418),
#  ('Condition1Dummy_PosN', -1189.2440418536514),
#  ('Exterior2ndDummy_VinylSd', 1179.716502719395),
#  ('FoundationDummy_PConc', 1178.5392862389272),
#  ('SalePrice', -1177.2219559905739),
#  ('MSSubClassDummy_75', -1172.818641480847),
#  ('PoolArea', 1138.7136263280845),
#  ('LotShapeDummy_Reg', 1131.874804972129),
#  ('HouseStyleDummy_SFoyer', 1090.1527064949048),
#  ('Exterior1stDummy_Stone', 1077.537684870345),
#  ('FoundationDummy_Stone', -1073.3085073945572),
#  ('FunctionalDummy_Min2', -1066.5511270641036),
#  ('MSSubClassDummy_80', -1039.3718824189036),
#  ('RoofStyleDummy_Mansard', 1009.8392415803138),
#  ('Exterior1stDummy_Wd Sdng', 1003.4567529683918),
#  ('RoofStyleDummy_Shed', -993.5597935763179),
#  ('HouseStyleDummy_2.5Fin', -982.3165676020692),
#  ('LotConfigDummy_CulDSac', -957.0412987796853),
#  ('GarageFinish', -948.3705727098381),
#  ('BsmtFullBath', 946.8310747402202),
#  ('NeighborhoodDummy_NAmes', 943.1210928837777),
#  ('MiscFeatureDummy_TenC', 939.283766214114),
#  ('HouseStyleDummy_1.5Unf', 935.2467518784649),
#  ('MSSubClassDummy_50', 915.2687907155627),
#  ('GarageTypeDummy_CarPort', 915.014505127573),
#  ('MiscFeatureDummy_Shed', -909.6689463174553),
#  ('HeatingQC', -903.0770807462613),
#  ('MasVnrTypeDummy_Stone', 893.5294256698609),
#  ('BsmtFinSF2', 892.8389413208021),
#  ('Exterior1stDummy_MetalSd', -888.1531023193576),
#  ('SaleTypeDummy_WD', 882.233917387125),
#  ('Exterior2ndDummy_Other', -881.3379928568675),
#  ('NeighborhoodDummy_BrDale', 865.140876672321),
#  ('RoofMatlDummy_Tar&Grv', -855.5934537908549),
#  ('CentralAirDummy_Y', -844.6362641334318),
#  ('GarageYrBlt', -836.4270194903887),
#  ('RoofMatlDummy_Roll', -833.4372657398275),
#  ('GarageTypeDummy_Detchd', 749.554712354126),
#  ('MoSold', -749.1058195104946),
#  ('LandSlope', -736.1599926043777),
#  ('SaleConditionDummy_AdjLand', 725.5764118189361),
#  ('LotShapeDummy_IR3', 720.3449081342225),
#  ('MSZoningDummy_RH', 716.3086977477573),
#  ('Exterior1stDummy_HdBoard', -713.1484763412046),
#  ('FunctionalDummy_Typ', -707.6933677793422),
#  ('Exterior1stDummy_ImStucc', 698.0749811980606),
#  ('MSSubClassDummy_180', -697.4890987937082),
#  ('Condition2Dummy_RRNn', -697.4890987936968),
#  ('LotConfigDummy_FR2', -688.2522288732005),
#  ('NeighborhoodDummy_StoneBr', -679.9754148335144),
#  ('NeighborhoodDummy_OldTown', -672.0996106552785),
#  ('NeighborhoodDummy_Timber', 648.7815121002316),
#  ('Exterior1stDummy_Plywood', -643.8966215409376),
#  ('NeighborhoodDummy_Sawyer', -641.9638860634885),
#  ('HouseStyleDummy_SLvl', -630.5533118124982),
#  ('RoofMatlDummy_Metal', -610.0258518382675),
#  ('SaleTypeDummy_Con', 606.1608256449283),
#  ('Exterior2ndDummy_CmentBd', -587.1690788254202),
#  ('BsmtFinType1', 586.5048765097462),
#  ('AlleyDummy_No_Alley_Access', -584.8348837874265),
#  ('HeatingDummy_GasW', -583.5817045124018),
#  ('Exterior2ndDummy_Brk Cmn', -531.5172456935912),
#  ('Condition1Dummy_RRAe', 517.6412866990872),
#  ('Condition1Dummy_RRNn', -494.59651972464826),
#  ('HalfBath', 482.4171402881824),
#  ('HeatingDummy_GasA', -481.4248080764832),
#  ('Exterior2ndDummy_Wd Shng', -469.38416556556854),
#  ('3SsnPorch', 466.9561919395445),
#  ('MSZoningDummy_RL', -466.34617523870514),
#  ('Exterior2ndDummy_AsphShn', 466.07336224268636),
#  ('Exterior2ndDummy_Plywood', 463.3489269373132),
#  ('GarageQual', 453.7514358925533),
#  ('RoofMatlDummy_Membran', 453.185055399888),
#  ('RoofStyleDummy_Gambrel', 451.294879625336),
#  ('Condition1Dummy_RRAn', -437.06752742425044),
#  ('MasVnrTypeDummy_BrkFace', 416.32425621409305),
#  ('RoofStyleDummy_Gable', 414.4000840095772),
#  ('GarageTypeDummy_Basment', 410.9472054067403),
#  ('BsmtFinType2', -407.78565222301404),
#  ('MSSubClassDummy_85', -387.96472055331117),
#  ('BldgTypeDummy_2fmCon', -387.9647205533107),
#  ('Exterior2ndDummy_Stone', -386.42880574826177),
#  ('GarageTypeDummy_No_Garage', -381.40666641888066),
#  ('MSSubClassDummy_45', -373.15927416548413),
#  ('Exterior1stDummy_AsphShn', -369.550808776879),
#  ('PoolQC', 363.24369626611394),
#  ('YrSold', -354.5534198141797),
#  ('MSSubClassDummy_60', 345.1632580584318),
#  ('MiscFeatureDummy_Othr', 344.72162801391613),
#  ('Exterior1stDummy_BrkFace', -339.0547380670497),
#  ('Exterior2ndDummy_BrkFace', -339.0547380670448),
#  ('BsmtCond', 337.7731532114756),
#  ('LotShapeDummy_IR2', -332.9895310945571),
#  ('HeatingDummy_Wall', 327.1112679826313),
#  ('Fence', 317.7969896752271),
#  ('AlleyDummy_Pave', 312.8294591993387),
#  ('PavedDriveDummy_P', 302.1607843375324),
#  ('BsmtHalfBath', 300.12056928397254),
#  ('Exterior1stDummy_WdShing', 298.42200849083457),
#  ('FunctionalDummy_Min1', 296.2928083729688),
#  ('RoofStyleDummy_Hip', -289.9932336495588),
#  ('GarageTypeDummy_Attchd', 280.9576086285599),
#  ('SaleTypeDummy_New', 277.4093494912397),
#  ('RoofMatlDummy_WdShngl', -267.49495816400355),
#  ('Condition2Dummy_RRAn', 259.1449103092282),
#  ('HouseStyleDummy_2Story', 249.5203195785678),
#  ('NeighborhoodDummy_Veenker', -244.50243182472852),
#  ('FoundationDummy_Slab', -238.05332020562534),
#  ('ExterCond', 230.11788846269),
#  ('Condition2Dummy_Feedr', 229.59672076626742),
#  ('EnclosedPorch', 226.0149341784407),
#  ('FoundationDummy_Wood', -217.17311135896995),
#  ('GarageCond', 209.2987934052841),
#  ('MSSubClassDummy_40', 193.54168150389395),
#  ('BldgTypeDummy_TwnhsE', 193.54168150388955),
#  ('Exterior1stDummy_CemntBd', -191.9243823885543),
#  ('SaleTypeDummy_ConLD', -187.8546244173606),
#  ('LowQualFinSF', -176.29268003174363),
#  ('LotConfigDummy_Inside', 174.2486184574306),
#  ('NeighborhoodDummy_Gilbert', 171.83367211026265),
#  ('MSSubClassDummy_160', 169.38685852216545),
#  ('MSSubClassDummy_70', 169.07042813054238),
#  ('Condition2Dummy_RRAe', 167.59443623949207),
#  ('ElectricalDummy_FuseF', 167.458028318605),
#  ('GarageTypeDummy_BuiltIn', -162.50386934578333),
#  ('Exterior2ndDummy_MetalSd', -160.44623925884466),
#  ('Exterior2ndDummy_HdBoard', 155.33245231168942),
#  ('MSSubClassDummy_30', 143.1397739066331),
#  ('Condition1Dummy_RRNe', 141.51487478287817),
#  ('MiscVal', 134.76653570295602),
#  ('SaleTypeDummy_Oth', -128.43539633863725),
#  ('ElectricalDummy_SBrkr', -127.18349195471885),
#  ('ElectricalDummy_FuseP', -117.1441066159139),
#  ('ElectricalDummy_Mix', -113.43764218901903),
#  ('LotConfigDummy_FR3', -95.99892716999481),
#  ('PavedDriveDummy_Y', -82.3377878218237),
#  ('LandContourDummy_Low', -79.68076529972036),
#  ('NeighborhoodDummy_SWISU', -76.81717442038473),
#  ('NeighborhoodDummy_IDOTRR', -67.44940568881044),
#  ('Exterior2ndDummy_Stucco', -60.395614601754076),
#  ('HeatingDummy_OthW', 34.3538810118735),
#  ('Exterior1stDummy_Stucco', 34.30268039446934),
#  ('FunctionalDummy_Maj2', 33.7129513559661),
#  ('SaleTypeDummy_ConLI', -33.167174140723375),
#  ('MSZoningDummy_FV', 31.953339870552654),
#  ('Exterior2ndDummy_ImStucc', 20.361324785561855),
#  ('NeighborhoodDummy_BrkSide', 13.936044959060405),
#  ('SaleConditionDummy_Alloca', -9.932701335500262),
#  ('NeighborhoodDummy_SawyerW', -8.254922916474015),
#  ('MiscFeatureDummy_No_Misc_Feature', -7.836640187452477),
#  ('StreetDummy_Pave', 5.392698233135895),
#  ('Condition1Dummy_PosA', -4.9205241712400705),
#  ('Condition1Dummy_Norm', -3.798689729614224),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('FunctionalDummy_Mod', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182907995861.4361, tolerance: 573299911.3926402
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180683111383.0298, tolerance: 536605936.56712306
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179954494172.39883, tolerance: 549249402.1356102
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175352226211.6172, tolerance: 556855297.4112337
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190172027582.66504, tolerance: 569990647.1062179
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102073184654.84265, tolerance: 573299911.3926402
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143380326009.52512, tolerance: 536605936.56712306
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147871405085.51483, tolerance: 549249402.1356102
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123482869729.45828, tolerance: 556855297.4112337
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153838289485.20856, tolerance: 569990647.1062179
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3382857066.1540527, tolerance: 549249402.1356102
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11253119, 0.11383781, 0.11205482, 0.0959096 , 0.06754079,
#         0.05404077, 0.00891647, 0.00810723]),
#  'std_fit_time': array([0.00726952, 0.00376189, 0.00326559, 0.00906316, 0.00783501,
#         0.0052058 , 0.00103737, 0.00082436]),
#  'mean_score_time': array([0.00247235, 0.00252781, 0.00244441, 0.00250769, 0.00274615,
#         0.00253525, 0.00263195, 0.0026072 ]),
#  'std_score_time': array([0.00027204, 0.00025834, 0.00043529, 0.00032909, 0.0001078 ,
#         0.00034243, 0.00011329, 0.0001343 ]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.88708082, 0.88792492, 0.8907139 , 0.89614779, 0.89841975,
#         0.89971642, 0.9047146 , 0.8932992 ]),
#  'split1_test_score': array([0.88604636, 0.88922335, 0.89282355, 0.89553433, 0.89640457,
#         0.89671528, 0.89406693, 0.88819056]),
#  'split2_test_score': array([0.8714966 , 0.8725998 , 0.88256561, 0.88999347, 0.89209301,
#         0.89301965, 0.88341236, 0.86592321]),
#  'split3_test_score': array([0.86769162, 0.86801932, 0.87036677, 0.8737938 , 0.87437684,
#         0.87488946, 0.8780398 , 0.86628883]),
#  'split4_test_score': array([0.88348749, 0.88500201, 0.88613447, 0.88942548, 0.89067989,
#         0.89225578, 0.90301461, 0.8917296 ]),
#  'mean_test_score': array([0.87916058, 0.88055388, 0.88452086, 0.88897897, 0.89039481,
#         0.89131932, 0.89264966, 0.88108628]),
#  'std_test_score': array([0.00798924, 0.00859838, 0.00792532, 0.00807691, 0.00848596,
#         0.00864102, 0.01052406, 0.01234333]),
#  'rank_test_score': array([8, 7, 5, 4, 3, 2, 1, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8926496599728739

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 25618.92449309562),
#  ('OverallQual', 11790.383905785344),
#  ('BsmtFinSF1', 9607.102642807617),
#  ('ExterQual', -6127.17740003328),
#  ('TotalBsmtSF', 6065.235677822302),
#  ('MasVnrArea', 4556.865524123461),
#  ('KitchenQual', -4446.8354159938135),
#  ('YearBuilt', 4338.984486695053),
#  ('NeighborhoodDummy_NoRidge', 4152.574540791681),
#  ('BsmtQual', -4108.905944125753),
#  ('SaleTypeDummy_ConLw', 3939.5786229062173),
#  ('OverallCond', 3914.1570712756366),
#  ('NeighborhoodDummy_NWAmes', 3637.0277720697795),
#  ('LotArea', 3379.5543727108548),
#  ('NeighborhoodDummy_Somerst', 2910.7241790260236),
#  ('RoofMatlDummy_WdShake', 2824.1081394472),
#  ('KitchenAbvGr', -2809.3708064907296),
#  ('FunctionalDummy_Sev', 2804.266577922083),
#  ('GarageCars', 2631.771223786853),
#  ('GarageArea', 2493.2481639612665),
#  ('NeighborhoodDummy_CollgCr', 2237.936614628198),
#  ('Exterior1stDummy_BrkComm', 1984.2341613074339),
#  ('YearRemodAdd', 1915.334022038696),
#  ('Condition1Dummy_Feedr', 1771.4534138862052),
#  ('Fireplaces', 1631.0827535182766),
#  ('Exterior2ndDummy_Wd Shng', -1481.2441041279226),
#  ('MSSubClassDummy_90', -1437.959820525503),
#  ('MSSubClassDummy_120', -1335.1716259442248),
#  ('BedroomAbvGr', -1251.8996079781891),
#  ('BldgTypeDummy_Twnhs', -1227.8481729619646),
#  ('LotFrontage', 1201.0035346890534),
#  ('UtilitiesDummy_NoSeWa', 1044.791601547396),
#  ('NeighborhoodDummy_NPkVill', -945.6863777974509),
#  ('BsmtExposure', -894.8131907396034),
#  ('1stFlrSF', 860.5774091475819),
#  ('BldgTypeDummy_Duplex', -802.527178123306),
#  ('NeighborhoodDummy_NridgHt', -767.3179249920164),
#  ('BsmtFinSF2', 741.9239045015557),
#  ('WoodDeckSF', 721.2342064308183),
#  ('SaleTypeDummy_CWD', 685.2656701002556),
#  ('GarageFinish', -654.4462919109825),
#  ('MSZoningDummy_RL', -645.8637121181919),
#  ('HouseStyleDummy_SLvl', -623.2713539424735),
#  ('NeighborhoodDummy_SawyerW', 617.1598551389777),
#  ('HouseStyleDummy_1Story', -595.3398626468154),
#  ('FireplaceQu', -575.2283385370591),
#  ('FunctionalDummy_Min2', -558.1878897946968),
#  ('OpenPorchSF', 517.6112056797895),
#  ('LotShapeDummy_Reg', 422.63983669508184),
#  ('FoundationDummy_PConc', 393.91212531345684),
#  ('HeatingQC', -333.3911272439871),
#  ('FoundationDummy_Stone', -316.06308587931863),
#  ('MSZoningDummy_RM', 294.23237488496994),
#  ('NeighborhoodDummy_BrDale', 258.30859977705774),
#  ('Exterior2ndDummy_Wd Sdng', -254.43487142714125),
#  ('FoundationDummy_CBlock', 225.36386152206143),
#  ('MasVnrTypeDummy_None', 187.60179161559967),
#  ('LowQualFinSF', -172.09681301647362),
#  ('MSSubClassDummy_70', -155.91274259148076),
#  ('Exterior1stDummy_MetalSd', -107.25321884937033),
#  ('NeighborhoodDummy_OldTown', -60.45812127622919),
#  ('Exterior1stDummy_VinylSd', -36.18537692130895),
#  ('NeighborhoodDummy_Timber', 34.990954947933965),
#  ('Condition1Dummy_PosN', -33.40243670103868),
#  ('LandSlope', -0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinType2', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtFullBath', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', 0.0),
#  ('ScreenPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', -0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', -0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', -0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_2fmCon', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', -0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', -0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_CmentBd', -0.0),
#  ('Exterior2ndDummy_HdBoard', -0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Other', -0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', -0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', -0.0),
#  ('MiscFeatureDummy_TenC', 0.0),
#  ('SaleTypeDummy_Con', 0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', 0.0),
#  ('SaleConditionDummy_Normal', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.best_score_

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.best_score_

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)

# %%
mostCorrelatedFeat.head(50)

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
stats.summary(gridLasso.best_estimator_, X_Scaled, y)
