# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2470.1940004888065), ('GrLivArea', 1647.085474040165), ('GarageCars', 1071.2299220983361), ('GarageArea', 974.3643407757393), ('ExterQual', 945.0812839210167), ('TotalBsmtSF', 898.7736760501101), ('1stFlrSF', 792.5864530982536), ('BsmtQual', 755.6684608068251), ('KitchenQual', 704.677194415202), ('FullBath', 691.5476140647256), ('YearBuilt', 663.0581992588108), ('TotRmsAbvGrd', 596.5973068076853), ('YearRemodAdd', 517.8053220652417), ('Fireplaces', 324.3302923463539), ('GarageFinish', 309.4007982627965), ('HeatingQC', 288.4251262970486), ('MasVnrArea', 281.17140735069484), ('MSSubClassDummy_60', 230.74586652632914), ('LotFrontage', 227.41617769867432), ('BsmtFinSF1', 202.90220641717727), ('WoodDeckSF', 174.5056349153009), ('OpenPorchSF', 173.47131287250568), ('LotArea', 172.36757290006616), ('2ndFlrSF', 133.5415010918121), ('BsmtExposure', 122.19761315422262), ('HalfBath', 108.00821572328647), ('GarageYrBlt', 106.97729781327543), ('MSSubClassDummy_30', 95.455192180523), ('GarageCond', 80.69999586548866), ('BsmtUnfSF', 78.20839919361174), ('BsmtFullBath', 77.19718344642014), ('GarageQual', 71.41492122833611), ('BedroomAbvGr', 56.34209127611203), ('Fence', 39.53966986360142), ('ExterCond', 29.85953914236952), ('OverallCond', 23.693400374510773), ('EnclosedPorch', 22.819851494987187), ('KitchenAbvGr', 16.77347283820426), ('BsmtFinType2', 12.86368762097188), ('MSSubClassDummy_45', 10.447736636999611), ('BsmtFinType1', 7.769475783609941), ('MoSold', 6.45447452637353), ('LowQualFinSF', 5.440705690718708), ('BsmtCond', 5.352551446430266), ('BsmtHalfBath', 4.088621441052606), ('FireplaceQu', 4.047088232649567), ('ScreenPorch', 3.3210209611794466), ('MSSubClassDummy_40', 2.024020972998576), ('BsmtFinSF2', 1.6034127077385898), ('3SsnPorch', 0.45436299353168264), ('MiscVal', 0.3986414946078358), ('YrSold', 0.2593579031637225), ('LandSlope', 0.2408385029341686), ('PoolArea', 0.00023544653984330788), ('PoolQC', 0.00015937188756642195), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 218.33875254281588), ('MSZoningDummy_RM', 158.81698263275896), ('NeighborhoodDummy_NoRidge', 158.64101571230933), ('MSZoningDummy_RL', 94.01956560250154), ('LotShapeDummy_Reg', 89.15125478512101), ('NeighborhoodDummy_OldTown', 61.348073528894474), ('NeighborhoodDummy_NAmes', 61.110436046651245), ('NeighborhoodDummy_Edwards', 51.03104971766378), ('NeighborhoodDummy_StoneBr', 44.02856406667333), ('MSSubClassDummy_50', 43.002222391513335), ('NeighborhoodDummy_Somerst', 38.132633765533356), ('NeighborhoodDummy_IDOTRR', 35.23638162102942), ('NeighborhoodDummy_Timber', 33.7536666030448), ('NeighborhoodDummy_BrkSide', 31.67903903007818), ('NeighborhoodDummy_Sawyer', 26.877622619744628), ('NeighborhoodDummy_MeadowV', 23.519224235671047), ('Condition1Dummy_Norm', 22.187372782509975), ('MSSubClassDummy_160', 21.986353521101183), ('AlleyDummy_No_Alley_Access', 19.804238645270342), ('NeighborhoodDummy_BrDale', 18.841722517853288), ('NeighborhoodDummy_CollgCr', 16.379111641851544), ('MSZoningDummy_FV', 16.374028598991128), ('Condition1Dummy_Feedr', 15.274523308008956), ('MSSubClassDummy_90', 15.213209012787583), ('LotConfigDummy_CulDSac', 13.201591591369093), ('LandContourDummy_HLS', 12.445717949170481), ('MSSubClassDummy_180', 12.381241306512601), ('MSSubClassDummy_190', 10.045948495081497), ('NeighborhoodDummy_Veenker', 8.14715758285117), ('MSZoningDummy_RH', 5.970699895573786), ('LotConfigDummy_Inside', 5.905002563156013), ('NeighborhoodDummy_SWISU', 5.758087365536481), ('MSSubClassDummy_120', 5.362623781182552), ('NeighborhoodDummy_Crawfor', 5.274604007083587), ('NeighborhoodDummy_Mitchel', 4.909559206559511), ('MSSubClassDummy_85', 4.286678591722336), ('LotShapeDummy_IR2', 4.214423351808042), ('NeighborhoodDummy_Gilbert', 4.0620058025444274), ('NeighborhoodDummy_ClearCr', 2.980357528785358), ('LandContourDummy_Low', 2.832430749567152), ('Condition1Dummy_PosA', 2.5222255501898885), ('NeighborhoodDummy_SawyerW', 2.3547989591885714), ('Neigh ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.37017331, 0.23351636]),
#  'std_fit_time': array([0.03354903, 0.0334067 ]),
#  'mean_score_time': array([0.01090436, 0.01029706]),
#  'std_score_time': array([0.0016607 , 0.00052745]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86235186, 0.88485924]),
#  'split1_test_score': array([0.90685316, 0.88551197]),
#  'split2_test_score': array([0.85198586, 0.85075401]),
#  'split3_test_score': array([0.87928212, 0.89636489]),
#  'split4_test_score': array([0.88096235, 0.86968547]),
#  'mean_test_score': array([0.87628707, 0.87743512]),
#  'std_test_score': array([0.0187075 , 0.01581536]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8774351151618742

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.08664791360711815),
#  ('GrLivArea', 0.0775458987741668),
#  ('TotalBsmtSF', 0.05552605450032778),
#  ('GarageArea', 0.05500255442812238),
#  ('GarageCars', 0.05407804309050657),
#  ('FullBath', 0.04731988957446826),
#  ('YearBuilt', 0.04622473312690092),
#  ('ExterQual', 0.0381023225221648),
#  ('KitchenQual', 0.0374779157253861),
#  ('1stFlrSF', 0.0366943617101107),
#  ('GarageYrBlt', 0.029918489447044994),
#  ('BsmtFinSF1', 0.02744173842901632),
#  ('YearRemodAdd', 0.023772406056351954),
#  ('TotRmsAbvGrd', 0.0216711289755009),
#  ('2ndFlrSF', 0.020246209127355138),
#  ('LotArea', 0.019689027093262958),
#  ('LotFrontage', 0.017634946258644205),
#  ('BsmtQual', 0.01706744267903997),
#  ('FoundationDummy_CBlock', 0.01657465861699594),
#  ('MasVnrArea', 0.015980772988234263),
#  ('OpenPorchSF', 0.015499792350445192),
#  ('Fireplaces', 0.013137663309924939),
#  ('GarageFinish', 0.011242636927396457),
#  ('MSSubClassDummy_50', 0.010360274944792872),
#  ('WoodDeckSF', 0.010067479240855319),
#  ('FunctionalDummy_Typ', 0.009673275011824965),
#  ('BsmtUnfSF', 0.008246240958996925),
#  ('FireplaceQu', 0.008050808686129292),
#  ('MasVnrTypeDummy_Stone', 0.005923883197995488),
#  ('Exterior1stDummy_Stucco', 0.005739798975922473),
#  ('MasVnrTypeDummy_No_MasVnr', 0.005539729785374244),
#  ('SaleTypeDummy_ConLw', 0.005254738127487451),
#  ('BsmtExposure', 0.00514793980622266),
#  ('OverallCond', 0.00500016091137873),
#  ('BedroomAbvGr', 0.004875151053344691),
#  ('BsmtFullBath', 0.004826684808720966),
#  ('NeighborhoodDummy_NoRidge', 0.004431112351406362),
#  ('MoSold', 0.004424931201702098),
#  ('NeighborhoodDummy_NWAmes', 0.004418193215585807),
#  ('GarageTypeDummy_CarPort', 0.004271145585351103),
#  ('SalePrice', 0.004188347243646851),
#  ('SaleTypeDummy_ConLI', 1.3282591307346351e-05),
#  ('FunctionalDummy_Mod', 1.2531720267383475e-05),
#  ('PoolQC', 1.1144594692942813e-05),
#  ('MSSubClassDummy_30', 1.0590639667558836e-05),
#  ('Condition1Dummy_RRNn', 9.578781045816871e-06),
#  ('SaleTypeDummy_ConLD', 9.529675167982488e-06),
#  ('LotConfigDummy_FR2', 8.503713104726427e-06),
#  ('SaleTypeDummy_Con', 7.63025169450684e-06),
#  ('FoundationDummy_Slab', 7.07248749314979e-06),
#  ('HeatingDummy_OthW', 6.3790844550078e-06),
#  ('Condition1Dummy_RRAn', 3.410326221453916e-06),
#  ('SaleTypeDummy_New', 3.2283816534426684e-06),
#  ('LotConfigDummy_Inside', 3.060802381015339e-06),
#  ('MSZoningDummy_RM', 2.918869151506802e-06),
#  ('Condition2Dummy_RRAn', 2.64630400860446e-06),
#  ('SaleTypeDummy_WD', 2.1509838529867338e-06),
#  ('RoofMatlDummy_Metal', 1.688958868907796e-06),
#  ('Exterior1stDummy_BrkFace', 1.1296933409030173e-06),
#  ('Exterior2ndDummy_BrkFace', 7.876443270784116e-07),
#  ('Exterior1stDummy_HdBoard', 4.5925804843935415e-07),
#  ('Condition2Dummy_RRAe', 2.6498014769866495e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 2.256663388958197e-07),
#  ('Exterior1stDummy_WdShing', 1.2051301366319811e-07),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02542906, 0.0048912 , 0.0049407 , 0.00484219, 0.00446734,
#         0.00480528, 0.00511513, 0.00520573]),
#  'std_fit_time': array([4.11772184e-02, 1.51958613e-04, 3.15568944e-05, 2.56844280e-04,
#         4.70952211e-04, 1.77990825e-04, 1.59644668e-04, 3.04311617e-04]),
#  'mean_score_time': array([0.00271559, 0.0025476 , 0.00268483, 0.00249124, 0.00231252,
#         0.00249095, 0.00270963, 0.00280027]),
#  'std_score_time': array([2.23169011e-04, 2.05995341e-04, 2.66568605e-05, 2.87462458e-04,
#         3.05452877e-04, 1.82100384e-04, 2.29467200e-05, 9.78609265e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89891317, 0.9008968 , 0.90560255, 0.90869605, 0.9094446 ,
#         0.90992641, 0.89582762, 0.87147439]),
#  'split1_test_score': array([0.91108073, 0.91236595, 0.9140433 , 0.91501354, 0.91487709,
#         0.91456113, 0.88648463, 0.85347622]),
#  ('YearRemodAdd', 2294.785121752997),
#  ('SaleConditionDummy_Family', 2246.0030730538033),
#  ('WoodDeckSF', 2234.219248817706),
#  ('NeighborhoodDummy_Mitchel', -2211.1685715639987),
#  ('MSSubClassDummy_90', -2191.40415560333),
#  ('BldgTypeDummy_Duplex', -2180.7287030996517),
#  ('NeighborhoodDummy_Crawfor', -2104.235673604734),
#  ('BedroomAbvGr', -2036.79513755662),
#  ('MiscFeatureDummy_TenC', 2019.7456706558746),
#  ('BldgTypeDummy_Twnhs', -1990.383044245073),
#  ('Fireplaces', 1983.3264411275231),
#  ('Exterior1stDummy_VinylSd', -1971.8649348367242),
#  ('BsmtExposure', -1908.6702047304382),
#  ('BsmtFullBath', 1893.1277407028108),
#  ('OpenPorchSF', 1863.7009076186873),
#  ('MSSubClassDummy_120', -1850.5648123784854),
#  ('Exterior2ndDummy_CBlock', 1793.5532889862693),
#  ('FoundationDummy_CBlock', 1781.9936830366562),
#  ('NeighborhoodDummy_NPkVill', -1767.1237668107226),
#  ('SaleTypeDummy_ConLw', 1764.41565278043),
#  ('NeighborhoodDummy_Edwards', -1731.864933846547),
#  ('FunctionalDummy_Mod', -1729.015722153543),
#  ('NeighborhoodDummy_ClearCr', -1680.9712115574732),
#  ('NeighborhoodDummy_MeadowV', -1625.3774242095947),
#  ('FullBath', 1622.681465808358),
#  ('MSSubClassDummy_190', 1587.8521023609007),
#  ('Exterior2ndDummy_Wd Sdng', -1502.1427661794514),
#  ('NeighborhoodDummy_NridgHt', -1478.1999866551262),
#  ('Exterior2ndDummy_Other', -1434.6105331289543),
#  ('LotConfigDummy_CulDSac', -1423.0793998653162),
#  ('MSSubClassDummy_75', -1355.2712425585512),
#  ('LotShapeDummy_Reg', 1351.654218760294),
#  ('NeighborhoodDummy_Blueste', 1349.1677738657331),
#  ('Exterior2ndDummy_CmentBd', -1312.9774873558606),
#  ('FoundationDummy_PConc', 1294.8143113071314),
#  ('Exterior2ndDummy_VinylSd', 1266.499108060882),
#  ('Condition1Dummy_PosN', -1265.2280302738122),
#  ('MasVnrTypeDummy_None', 1255.6659230814844),
#  ('GarageTypeDummy_Basment', 1221.8534552971641),
#  ('Exterior1stDummy_CBlock', -1209.7170867832492),
#  ('BldgTypeDummy_2fmCon', -1200.649407707848),
#  ('MSSubClassDummy_85', -1200.6494077078448),
#  ('SaleTypeDummy_CWD', 1125.5388318947962),
#  ('MSZoningDummy_RH', 1123.4512655401327),
#  ('FunctionalDummy_Min2', -1111.0220122387109),
#  ('ScreenPorch', 1097.1020949451786),
#  ('LotFrontage', 1096.960551847366),
#  ('Exterior1stDummy_Wd Sdng', 1044.9081860234128),
#  ('FireplaceQu', -1041.5978408804049),
#  ('GarageTypeDummy_CarPort', 1028.2188970166983),
#  ('MSSubClassDummy_80', -1010.5982475500829),
#  ('ExterCond', 1009.4752660244122),
#  ('PoolArea', 1008.3025386375878),
#  ('PavedDriveDummy_P', 1008.2732793275062),
#  ('NeighborhoodDummy_BrDale', 991.2547658799671),
#  ('Exterior1stDummy_Stone', 978.7154489722944),
#  ('MasVnrTypeDummy_No_MasVnr', 977.7645704951168),
#  ('UtilitiesDummy_NoSeWa', 976.2815076040623),
#  ('HouseStyleDummy_1Story', -975.1091245561738),
#  ('HouseStyleDummy_SFoyer', 974.4445533458364),
#  ('NeighborhoodDummy_Timber', 961.0943216102016),
#  ('HeatingQC', -947.9802281839004),
#  ('MSSubClassDummy_50', 942.9185121848556),
#  ('FoundationDummy_Stone', -924.4696228035025),
#  ('NeighborhoodDummy_NAmes', 867.0944954614212),
#  ('MSSubClassDummy_180', -837.6424119639707),
#  ('Condition2Dummy_RRNn', -837.6424119639674),
#  ('SalePrice', -816.2103666096207),
#  ('MasVnrTypeDummy_Stone', 814.6630374656114),
#  ('GarageFinish', -809.7538087752388),
#  ('HouseStyleDummy_2.5Fin', -751.1808447083532),
#  ('GarageYrBlt', -746.794624434615),
#  ('LotConfigDummy_FR2', -736.6208404336957),
#  ('ElectricalDummy_SBrkr', -733.6665950042881),
#  ('MSZoningDummy_RM', 732.9807766317372),
#  ('GarageTypeDummy_Detchd', 719.0892274576179),
#  ('SaleTypeDummy_WD', 714.1982829972713),
#  ('NeighborhoodDummy_IDOTRR', -711.4982436111885),
#  ('HouseStyleDummy_SLvl', -707.0676456676912),
#  ('HalfBath', 687.5643695976978),
#  ('BsmtFinSF2', 678.3505533064637),
#  ('NeighborhoodDummy_SawyerW', 673.4625767322892),
#  ('NeighborhoodDummy_OldTown', -669.7308308305679),
#  ('MSSubClassDummy_70', 659.6250633014071),
#  ('Exterior1stDummy_HdBoard', -655.8911455918577),
#  ('FunctionalDummy_Min1', 638.7192319572023),
#  ('AlleyDummy_No_Alley_Access', -619.5560361118104),
#  ('SaleTypeDummy_Con', 613.3898759300586),
#  ('BsmtUnfSF', -582.0012351504215),
#  ('HouseStyleDummy_1.5Unf', -579.6324579769748),
#  ('BldgTypeDummy_TwnhsE', 563.3012604825036),
#  ('SaleConditionDummy_AdjLand', 551.1450118522495),
#  ('KitchenAbvGr', -550.6391106461842),
#  ('Exterior2ndDummy_Wd Shng', 547.3222729933972),
#  ('MSSubClassDummy_60', 540.9598272975882),
#  ('RoofMatlDummy_Tar&Grv', -527.8954479768464),
#  ('Exterior1stDummy_ImStucc', 520.0841317755604),
#  ('Condition1Dummy_PosA', 517.0856769248268),
#  ('LotConfigDummy_FR3', -447.9364499447755),
#  ('LotShapeDummy_IR3', 446.0472653994277),
#  ('HouseStyleDummy_2.5Unf', -442.12025724207547),
#  ('FunctionalDummy_Maj2', -441.43153881374354),
#  ('HeatingDummy_GasW', -441.0665439570428),
#  ('RoofStyleDummy_Gambrel', 435.70093570417464),
#  ('Condition1Dummy_RRNe', 421.436311632622),
#  ('Exterior1stDummy_MetalSd', -410.2828663576198),
#  ('RoofMatlDummy_WdShake', 406.54718898902775),
#  ('PoolQC', 395.3442576103236),
#  ('BsmtCond', 391.51767232196016),
#  ('YrSold', -375.67598963626943),
#  ('Exterior2ndDummy_HdBoard', 375.24125153803834),
#  ('EnclosedPorch', 373.18560448404844),
#  ('MSZoningDummy_FV', 369.1603347392792),
#  ('MSSubClassDummy_160', -366.00758873538706),
#  ('MiscFeatureDummy_Othr', 350.2625774688547),
#  ('Exterior1stDummy_CemntBd', -343.22104269905765),
#  ('LandContourDummy_HLS', -341.91578170316177),
#  ('Exterior2ndDummy_Brk Cmn', -340.389796143164),
#  ('MasVnrTypeDummy_BrkFace', 332.56926379199126),
#  ('NeighborhoodDummy_Sawyer', -332.38801042205876),
#  ('BsmtHalfBath', -325.9448087578928),
#  ('GarageQual', 321.6283431797708),
#  ('SaleTypeDummy_ConLD', 321.251554124061),
#  ('GarageTypeDummy_No_Garage', -318.6629841571036),
#  ('NeighborhoodDummy_StoneBr', -313.74287424218875),
#  ('NeighborhoodDummy_Gilbert', -311.7732050233784),
#  ('Condition1Dummy_RRAn', -308.309648147268),
#  ('NeighborhoodDummy_BrkSide', 306.12572915479575),
#  ('Condition1Dummy_RRAe', 296.8828816236162),
#  ('NeighborhoodDummy_Veenker', 295.6221754768793),
#  ('MSSubClassDummy_40', -291.6981530810355),
#  ('Exterior2ndDummy_Plywood', 291.33461605336447),
#  ('BsmtFinType2', -285.1502260480741),
#  ('LotConfigDummy_Inside', 277.52384826215234),
#  ('Exterior1stDummy_AsphShn', -274.9738898619589),
#  ('ElectricalDummy_FuseP', 272.0655258129307),
#  ('Exterior2ndDummy_Stucco', 266.33314472931045),
#  ('Exterior2ndDummy_AsphShn', 263.5851131491512),
#  ('GarageTypeDummy_Attchd', 256.4900976337704),
#  ('LotShapeDummy_IR2', -256.237295071362),
#  ('Fence', 253.80870795465304),
#  ('SaleTypeDummy_New', 246.16852063353758),
#  ('CentralAirDummy_Y', -244.6938702083168),
#  ('MiscVal', 242.18248421141345),
#  ('Exterior2ndDummy_BrkFace', -236.14813943959436),
#  ('Exterior1stDummy_BrkFace', -236.14813943959072),
#  ('RoofMatlDummy_Roll', 225.03390738123593),
#  ('NeighborhoodDummy_SWISU', -222.65629611061877),
#  ('Condition1Dummy_RRNn', -211.1661784014473),
#  ('MoSold', -210.71785896674606),
#  ('ElectricalDummy_FuseF', -210.24479858708497),
#  ('Exterior1stDummy_Plywood', -209.17032695307077),
#  ('LandSlope', -200.80342162724153),
#  ('RoofStyleDummy_Hip', -190.70469303774408),
#  ('AlleyDummy_Pave', 190.3050908878878),
#  ('HeatingDummy_Wall', 183.2722251212932),
#  ('ElectricalDummy_Mix', 182.91081531319787),
#  ('MSZoningDummy_RL', -181.7882477156868),
#  ('PavedDriveDummy_Y', -178.95497458574735),
#  ('BsmtFinType1', -171.25149975713612),
#  ('3SsnPorch', 163.02678522129153),
#  ('LowQualFinSF', -151.18943609801477),
#  ('RoofMatlDummy_Metal', -149.14923442811983),
#  ('GarageCond', -137.04612815336148),
#  ('SaleTypeDummy_ConLI', -136.1381186773276),
#  ('Condition2Dummy_Feedr', 136.05661034775298),
#  ('SaleTypeDummy_Oth', -129.05389590053252),
#  ('Exterior2ndDummy_ImStucc', 121.76285740852971),
#  ('GarageTypeDummy_BuiltIn', -118.27398853768898),
#  ('Exterior2ndDummy_Stone', -117.23890707661396),
#  ('MiscFeatureDummy_No_Misc_Feature', 116.35243318449287),
#  ('HeatingDummy_GasA', -110.57358376711973),
#  ('MSSubClassDummy_30', 108.5052160026312),
#  ('Condition2Dummy_RRAn', 98.19136260802995),
#  ('Condition2Dummy_RRAe', -95.82180821488583),
#  ('SaleConditionDummy_Alloca', 84.95583008659149),
#  ('RoofStyleDummy_Gable', -72.80859562776192),
#  ('MSSubClassDummy_45', -61.172600821763716),
#  ('HouseStyleDummy_2Story', 60.81994740085843),
#  ('Exterior1stDummy_WdShing', -58.60460422822957),
#  ('RoofStyleDummy_Shed', -57.6664707831041),
#  ('Exterior2ndDummy_MetalSd', -47.971217743350664),
#  ('LandContourDummy_Low', 41.53700310464652),
#  ('FunctionalDummy_Typ', 40.83690991927437),
#  ('StreetDummy_Pave', 25.013321069364633),
#  ('HeatingDummy_OthW', -21.043255230071754),
#  ('FoundationDummy_Slab', 20.1798392910686),
#  ('Exterior1stDummy_Stucco', -19.523782941542258),
#  ('FoundationDummy_Wood', -17.758990917101258),
#  ('Condition1Dummy_Norm', -14.652797596064339),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143251314928.56628, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139953112452.63937, tolerance: 449599498.0921968
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140495470105.25504, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148556348168.35153, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136702398066.58286, tolerance: 484085473.0635178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105680995318.51846, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104747092336.60522, tolerance: 449599498.0921968
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113355084976.57903, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110981032653.03271, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109246082308.703, tolerance: 484085473.0635178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14928211366.164795, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2640259783.2953796, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8369712263.008362, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.10998549, 0.11608806, 0.1202734 , 0.09635758, 0.06212082,
#         0.05025043, 0.01112781, 0.00966983]),
#  'std_fit_time': array([0.00709274, 0.00503258, 0.00582026, 0.01477193, 0.0059723 ,
#         0.00254271, 0.0040564 , 0.00121644]),
#  'mean_score_time': array([0.00255036, 0.00267653, 0.0024703 , 0.00296459, 0.00286283,
#         0.00285587, 0.00266061, 0.00307202]),
#  'std_score_time': array([2.16817284e-04, 3.65337383e-04, 2.34106669e-04, 5.31630292e-04,
#         3.30436233e-04, 6.34135337e-05, 7.42548301e-05, 1.09934287e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89850143, 0.89871979, 0.90122226, 0.908424  , 0.90954112,
#         0.91046481, 0.91028271, 0.8961001 ]),
#  'split1_test_score': array([0.9114448 , 0.91167692, 0.91338956, 0.91689161, 0.91792207,
#         0.91869089, 0.91601153, 0.90536381]),
#  'split2_test_score': array([0.86876585, 0.87100727, 0.88443725, 0.89316859, 0.89547082,
#         0.89609895, 0.88658945, 0.86829842]),
#  'split3_test_score': array([0.89470941, 0.89495906, 0.89576528, 0.89775062, 0.8993975 ,
#         0.90068628, 0.90903073, 0.89524144]),
#  'split4_test_score': array([0.87633481, 0.87637557, 0.87691504, 0.87810903, 0.88010034,
#         0.88185842, 0.89555056, 0.88967491]),
#  'mean_test_score': array([0.88995126, 0.89054772, 0.89434588, 0.89886877, 0.90048637,
#         0.90155987, 0.903493  , 0.89093574]),
#  'std_test_score': array([0.01543987, 0.01493563, 0.01275912, 0.01327278, 0.01286797,
#         0.01258175, 0.01079159, 0.01238884]),
#  'rank_test_score': array([8, 7, 5, 4, 3, 2, 1, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9034929950216182

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 22214.20223831416),
#  ('OverallQual', 12543.02585475907),
#  ('BsmtFinSF1', 7414.749716852954),
#  ('TotalBsmtSF', 6302.724704132379),
#  ('YearBuilt', 5980.013485431679),
#  ('LotArea', 4458.847214836),
#  ('KitchenQual', -4449.077566843907),
#  ('NeighborhoodDummy_NoRidge', 4403.031369752155),
#  ('ExterQual', -3971.0547636656665),
#  ('OverallCond', 3909.5749435474618),
#  ('BsmtQual', -3566.0700955193297),
#  ('GarageArea', 3462.0066832986454),
#  ('NeighborhoodDummy_NWAmes', 3458.860722100038),
#  ('SaleConditionDummy_Normal', 3456.956843080419),
#  ('NeighborhoodDummy_Somerst', 2975.4715651506945),
#  ('FunctionalDummy_Sev', 2550.920470985333),
#  ('NeighborhoodDummy_CollgCr', 2451.4450652668593),
#  ('Exterior1stDummy_BrkComm', 2442.493531719492),
#  ('YearRemodAdd', 2110.4139196227434),
#  ('GarageCars', 2050.249328723477),
#  ('Fireplaces', 1798.3934910791609),
#  ('WoodDeckSF', 1480.4351617011612),
#  ('MasVnrArea', 1442.109851607557),
#  ('MSSubClassDummy_120', -1400.0554899193162),
#  ('BsmtFullBath', 1359.5186142501705),
#  ('Condition1Dummy_Feedr', 1356.9634356662377),
#  ('KitchenAbvGr', -1125.636729771495),
#  ('FunctionalDummy_Mod', -1078.797222776651),
#  ('BldgTypeDummy_Twnhs', -1036.6875364398682),
#  ('MSSubClassDummy_90', -1031.8223546153158),
#  ('MiscFeatureDummy_TenC', 1017.1255844901256),
#  ('NeighborhoodDummy_SawyerW', 1011.868732643417),
#  ('OpenPorchSF', 961.6838675843766),
#  ('BldgTypeDummy_Duplex', -922.6188472936914),
#  ('MSSubClassDummy_85', -916.9274827331305),
#  ('BsmtExposure', -906.9780169508819),
#  ('LotShapeDummy_Reg', 738.1130957749845),
#  ('MSZoningDummy_RL', -716.2962443936641),
#  ('GarageFinish', -619.7612972693402),
#  ('HeatingQC', -595.9292305899068),
#  ('NeighborhoodDummy_BrDale', 580.5042220448402),
#  ('FunctionalDummy_Min2', -503.7736557793511),
#  ('SaleTypeDummy_CWD', 493.3274463969178),
#  ('NeighborhoodDummy_NPkVill', -473.80915099171506),
#  ('NeighborhoodDummy_Timber', 454.34368690149654),
#  ('Exterior2ndDummy_Other', -437.7280409278761),
#  ('RoofStyleDummy_Gambrel', 420.22959368898984),
#  ('1stFlrSF', 373.0059707189082),
#  ('FireplaceQu', -352.79793770540226),
#  ('Exterior2ndDummy_CmentBd', -293.68835705131585),
#  ('NeighborhoodDummy_MeadowV', -227.20049922946728),
#  ('Condition1Dummy_PosN', -205.70410795271255),
#  ('NeighborhoodDummy_NridgHt', -202.62667632539757),
#  ('LowQualFinSF', -179.07507790818593),
#  ('ExterCond', 156.90250922794547),
#  ('FoundationDummy_Stone', -136.83991814681536),
#  ('Condition2Dummy_RRNn', -126.940656724953),
#  ('MSSubClassDummy_180', -105.30360807365437),
#  ('LotConfigDummy_CulDSac', -99.95723414428149),
#  ('ScreenPorch', 97.99611707788196),
#  ('MasVnrTypeDummy_None', 90.0592743529153),
#  ('FoundationDummy_CBlock', 89.7903272979347),
#  ('FoundationDummy_PConc', 82.74080527474808),
#  ('BldgTypeDummy_2fmCon', -79.56450219201439),
#  ('Exterior1stDummy_VinylSd', -58.790929747708184),
#  ('UtilitiesDummy_NoSeWa', 54.89091095556658),
#  ('LotFrontage', 41.08083439193531),
#  ('Exterior1stDummy_AsphShn', -25.12613024131489),
#  ('LandSlope', -0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinType2', -0.0),
#  ('BsmtFinSF2', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('BedroomAbvGr', -0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', -0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', -0.0),
#  ('MSSubClassDummy_30', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_160', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', 0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', 0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_OldTown', -0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Veenker', 0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', 0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_1Story', -0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('HouseStyleDummy_SLvl', -0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', -0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Sdng', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', -0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_Con', 0.0),
#  ('SaleTypeDummy_ConLD', 0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-33-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8797355548355629

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8998752592363453

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152584216744.66605, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158117522806.24445, tolerance: 449599498.0921968
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151523640233.14148, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157318228359.63223, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144356842964.12152, tolerance: 484085473.0635178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65234404882.50128, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121838235687.7627, tolerance: 449599498.0921968
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107658730244.19833, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51698309082.77539, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36184327316.35138, tolerance: 484085473.0635178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2123350597.1000977, tolerance: 485970292.4337178
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2122259332.9085693, tolerance: 449599498.0921968
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12457248177.035522, tolerance: 487944514.55273813
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1173062720.7341309, tolerance: 499729365.51416177
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.9006106804864465

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.999310
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999162
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998875
# PoolArea                  PoolQC                       0.997939
# GarageYrBlt               GarageTypeDummy_No_Garage    0.997014
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.993217
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.991836
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.991247
# GarageCars                GarageArea                   0.990081
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.984179
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.983048
# GrLivArea                 TotRmsAbvGrd                 0.970587
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.969055
# TotalBsmtSF               1stFlrSF                     0.961851
# ExterQual                 KitchenQual                  0.961061
# OverallQual               ExterQual                    0.955201
# 2ndFlrSF                  HouseStyleDummy_2Story       0.952789
# BsmtQual                  FoundationDummy_PConc        0.951637
# ExterQual                 BsmtQual                     0.951061
# MasVnrArea                MasVnrTypeDummy_None         0.942398
# YearRemodAdd              FoundationDummy_PConc        0.942398
#                           BsmtQual                     0.941680
# KitchenAbvGr              MSSubClassDummy_90           0.941447
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.939787
# OverallQual               BsmtQual                     0.938916
#                           GarageCars                   0.934938
#                           KitchenQual                  0.930586
#                           FullBath                     0.927987
# YearRemodAdd              ExterQual                    0.927074
# ExterQual                 FoundationDummy_PConc        0.926912
# YearBuilt                 BsmtQual                     0.926200
# HalfBath                  HouseStyleDummy_2Story       0.925581
# RoofStyleDummy_Mansard    Exterior2ndDummy_AsphShn     0.924926
# FoundationDummy_CBlock    FoundationDummy_PConc        0.924721
# YearBuilt                 YearRemodAdd                 0.920403
# BsmtQual                  KitchenQual                  0.916637
# OverallQual               YearRemodAdd                 0.916535
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.915019
# OverallQual               GarageArea                   0.912105
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.912101
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.910600
# OverallQual               FoundationDummy_PConc        0.907971
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.906670
# BsmtFinSF1                BsmtFullBath                 0.905723
# HalfBath                  MSSubClassDummy_60           0.904381
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.904036
# FullBath                  GarageCars                   0.899398
# LotFrontage               LotArea                      0.897641
# BsmtQual                  FullBath                     0.896971
# dtype: float64

# %% [markdown]
# ### Variance Inflation Factor

# %%
np.ones()

# %%
vifs = list(zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]))
