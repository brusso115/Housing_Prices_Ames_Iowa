# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2466.385074562077), ('GrLivArea', 1578.3110482118059), ('ExterQual', 1025.825302617967), ('GarageCars', 1013.4425371717706), ('GarageArea', 931.7142551091563), ('TotalBsmtSF', 910.0035477012882), ('1stFlrSF', 837.1482248461749), ('Baths', 797.3460540446968), ('KitchenQual', 793.6873336916688), ('BsmtQual', 769.2673441842815), ('FullBath', 717.8878625608479), ('TotRmsAbvGrd', 611.2707233765741), ('YearBuilt', 611.1422038731743), ('YearRemodAdd', 515.5186180907768), ('hasFireplace', 373.85449694671104), ('Fireplaces', 334.54049665697977), ('GarageFinish', 329.773540705767), ('MasVnrArea', 317.44740369705596), ('HeatingQC', 286.372793287399), ('NeighborhoodDummy_NridgHt', 257.77062590403), ('LotFrontage', 221.49609325097052), ('MSSubClassDummy_60', 210.2066779631524), ('BsmtFinSF1', 196.15706114922742), ('OpenPorchSF', 170.5001362528922), ('WoodDeckSF', 144.5938642769042), ('NeighborhoodDummy_NoRidge', 141.48274186093087), ('MSZoningDummy_RM', 136.2529337902045), ('BsmtExposure', 134.55910337531182), ('2ndFlrSF', 125.44416057432815), ('LotArea', 106.9291590391225), ('HalfBath', 97.99242922361015), ('MSSubClassDummy_30', 83.99901660715284), ('LotShapeDummy_Reg', 82.86089492356216), ('MSZoningDummy_RL', 78.35946827283405), ('BsmtUnfSF', 74.76971485753364), ('BsmtFullBath', 72.4126484778477), ('GarageYrBlt', 71.29880800753513), ('NeighborhoodDummy_NAmes', 67.64084040812894), ('BsmtBaths', 65.90200146837613), ('GarageCond', 62.456285901934095), ('hasFence', 58.0785279494675), ('NeighborhoodDummy_OldTown', 57.22842439665464), ('GarageQual', 51.751501396630715), ('NeighborhoodDummy_StoneBr', 50.98111694626402), ('hasGarage', 50.2668459621225), ('NeighborhoodDummy_Edwards', 48.4063492814184), ('BedroomAbvGr', 44.68426370468788), ('Fence', 39.69623272953201), ('NeighborhoodDummy_Somerst', 38.232808644618196), ('MSSubClassDummy_50', 34.33325142516668), ('NumFloors', 34.20337155500091), ('NeighborhoodDummy_IDOTRR', 31.524304407278255), ('NeighborhoodDummy_Sawyer', 29.540524720952217), ('NeighborhoodDummy_BrkSide', 29.34983929291433), ('NeighborhoodDummy_Timber', 28.403857941625773), ('EnclosedPorch', 26.58682236312137), ('OverallCond', 25.746271759484543), ('hasBsmt', 24.317638332801575), ('MSSubClassDummy_160', 21.808981480915463), ('ExterCond', 19.29725424707692), ('AlleyDummy_No_Alley_Access', 19.007710299772427), ('hasAlley_Access', 19.007710299771922), ('MSZoningDummy_FV', 18.08658509177183), ('NeighborhoodDummy_BrDale', 17.552514790864233), ('LotConfigDummy_CulDSac', 16.351245093471945), ('KitchenAbvGr', 15.671738264782093), ('NeighborhoodDummy_MeadowV', 12.917741710607144), ('MSSubClassDummy_90', 11.699407505152745), ('NeighborhoodDummy_CollgCr', 11.507089725686027), ('LandContourDummy_HLS', 11.102240622876833), ('MSSubClassDummy_45', 10.890350780289666), ('MSSubClassDummy_190', 10.212169539812333), ('MSZoningDummy_RH', 8.04218854568134), ('MoSold', 7.945344543530599), ('NeighborhoodDummy_ClearCr', 7.136437882292245), ('NeighborhoodDummy_SWISU', 7.038640686395385), ('FireplaceQu', 6.920336299338671), ('LowQualFinSF', 6.914208531084315), ('LotShapeDummy_IR2', 6.745393361577058), ('BsmtFinType1', 6.3458499312063195), ('hasMasVnr', 5.874860085352), ('hasMisc_Feature', 5.823729067699358), ('ScreenPorch', 5.788152094381769), ('BsmtCond', 5.261941872612141), ('BsmtFinType2', 5.2284950319073245), ('NeighborhoodDummy_Mitchel', 5.026433172206656), ('LotConfigDummy_Inside', 4.8766042264433285), ('MSSubClassDummy_85', 4.79769086753556), ('LandContourDummy_Low', 3.9203068228883367), ('BsmtHalfBath', 3.8673410234937355), ('NeighborhoodDummy_Crawfor', 3.790717867728242), ('MSSubClassDummy_180', 3.7344440548932827), ('NeighborhoodDummy_Gilbert', 3.020593282218919), ('LandSlope', 3.0097513544153593), ('3SsnPorch', 2.6183420052090693), ('NeighborhoodDummy_NPkVill', 2.5799576925744527), ('MSSubClassDummy_120', 2.377175693924348), ('MSSubClassDummy_80', 1.8346531975251734), ('NeighborhoodDummy_SawyerW', 1.5082010961277805), ('hasBeenR ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.42044492, 0.22381835]),
#  'std_fit_time': array([0.07799922, 0.01270582]),
#  'mean_score_time': array([0.01081071, 0.01160874]),
#  'std_score_time': array([0.00109719, 0.00199912]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86346072, 0.88161074]),
#  'split1_test_score': array([0.90362381, 0.87027487]),
#  'split2_test_score': array([0.86072467, 0.85496424]),
#  'split3_test_score': array([0.8753623 , 0.89464922]),
#  'split4_test_score': array([0.88751625, 0.8802411 ]),
#  'mean_test_score': array([0.87813755, 0.87634803]),
#  'std_test_score': array([0.01589861, 0.01320557]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8781375499731687

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5706373493961542),
#  ('GrLivArea', 0.12633648909929768),
#  ('TotalBsmtSF', 0.03876015232165203),
#  ('1stFlrSF', 0.037228907047260486),
#  ('BsmtFinSF1', 0.03134697939529348),
#  ('GarageArea', 0.029407132703732144),
#  ('GarageCars', 0.018031932482002515),
#  ('YearBuilt', 0.010194523143643192),
#  ('LotArea', 0.010142195493002888),
#  ('BsmtBaths', 0.010053024408698716),
#  ('YearRemodAdd', 0.009282601375018082),
#  ('BsmtQual', 0.006154208898928445),
#  ('BsmtUnfSF', 0.00564855174775788),
#  ('LotFrontage', 0.005547913136817912),
#  ('MasVnrArea', 0.004855466488409471),
#  ('GarageYrBlt', 0.004850845412276075),
#  ('OpenPorchSF', 0.004719274311430578),
#  ('2ndFlrSF', 0.004686411126601852),
#  ('OverallCond', 0.004531245238642362),
#  ('WoodDeckSF', 0.004158844477078728),
#  ('FullBath', 0.0032245302974969734),
#  ('ExterQual', 0.002990681594172586),
#  ('KitchenQual', 0.0027382213191747685),
#  ('MoSold', 0.0026581394402996283),
#  ('FunctionalDummy_Typ', 0.002216931878862784),
#  ('BsmtExposure', 0.0021027793552934834),
#  ('GarageFinish', 0.002081075809292558),
#  ('hasMasVnr', 0.001957249116464617),
#  ('BedroomAbvGr', 0.0019179540802783128),
#  ('TotRmsAbvGrd', 0.0018015648656601456),
#  ('LotShapeDummy_IR3', 0.0017771581859960675),
#  ('GarageTypeDummy_CarPort', 0.0017022385778603423),
#  ('YrSold', 0.0016353602206084369),
#  ('FireplaceQu', 0.0015608937735563776),
#  ('BsmtFinType1', 0.0014653937499557361),
#  ('Fireplaces', 0.0013261090188058072),
#  ('MSZoningDummy_RL', 0.0012681945721411602),
#  ('HalfBath', 0.001029627897513236),
#  ('HeatingDummy_Wall', 0.001026578828068883),
#  ('hasAlley_Access', 0.0010096012718008303),
#  ('NeighborhoodDummy_CollgCr', 0.0009536931792335901),
#  ('KitchenAbvGr', 0.0008813222595627936),
#  ('EnclosedPorch', 0.0008102647287321141),
#  ('HeatingQC', 0.0007342397894479881),
#  ('MasVnrTypeDummy_None', 0.0007248203532209022),
#  ('SaleTypeDummy_ConLD', 1.963068361223356e-06),
#  ('HouseStyleDummy_2.5Fin', 1.8691959946929175e-06),
#  ('hasFireplace', 1.8386972696388602e-06),
#  ('RoofMatlDummy_WdShake', 1.7872329186839914e-06),
#  ('Condition1Dummy_RRAn', 1.647808904924214e-06),
#  ('MSSubClassDummy_40', 1.3408919796795792e-06),
#  ('Exterior2ndDummy_Plywood', 1.2292087474980847e-06),
#  ('Condition2Dummy_RRAn', 7.575297702032937e-07),
#  ('SaleTypeDummy_CWD', 6.910129072515572e-07),
#  ('HeatingDummy_GasW', 6.811760528800077e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 6.579850038532514e-07),
#  ('LandContourDummy_Lvl', 5.737415998448851e-07),
#  ('ElectricalDummy_FuseF', 4.861929434136494e-07),
#  ('Exterior1stDummy_Plywood', 4.7416930781682123e-07),
#  ('HeatingDummy_Grav', 3.6631285354075227e-07),
#  ('FoundationDummy_Slab', 3.5280683361360347e-07),
#  ('LotConfigDummy_Inside', 2.7808853594773114e-07),
#  ('Condition1Dummy_RRNe', 1.9829907080383256e-07),
#  ('RoofMatlDummy_WdShngl', 1.9358797756272223e-07),
#  ('Condition1Dummy_RRNn', 1.54849242455916e-07),
#  ('Exterior1stDummy_HdBoard', 8.611888358567362e-08),
#  ('RoofMatlDummy_Metal', 4.122190047648136e-08),
#  ('RoofMatlDummy_Tar&Grv', 4.000375622884414e-08),
#  ('MSSubClassDummy_30', 3.7174066068969274e-08),
#  ('Exterior2ndDummy_BrkFace', 1.3023260942993939e-08),
#  ('RoofStyleDummy_Hip', 6.149806731684471e-09),
#  ('MSZoningDummy_RM', 2.5146943171017985e-09),
#  ('Exterior1stDummy_BrkFace', 2.2378513984641904e-09),
#  ('Condition2Dummy_Norm', 4.986013806233274e-10),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02633815, 0.00505524, 0.00561061, 0.00520978, 0.00503116,
#         0.00497184, 0.00506177, 0.00482926]),
#  'std_fit_time': array([0.04259329, 0.00027917, 0.00039496, 0.00023582, 0.00014376,
#         0.00024193, 0.0003118 , 0.00041192]),
#  'mean_score_time': array([0.0025692 , 0.00269952, 0.00300136, 0.00277324, 0.00278721,
#         0.00268245, 0.00261459, 0.00262322]),
#  'std_score_time': array([2.03530388e-04, 1.30247230e-04, 2.18861794e-04, 8.45030788e-05,
#         1.11603184e-04, 6.61895665e-05, 2.51137850e-04, 2.49760485e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.90471316, 0.90536457, 0.90694186, 0.9097199 , 0.91072783,
#         0.91143431, 0.89878778, 0.87587511]),
#  'split1_test_score': array([0.89940905, 0.90246738, 0.90737262, 0.90714719, 0.90615363,
#         0.90519057, 0.87291781, 0.83982158]),
#  'split2_test_score': array([0.86817215, 0.88093399, 0.88944448, 0.89536493, 0.89601746,
#         0.89610491, 0.87608531, 0.85180351]),
#  'split3_test_score': array([0.88414645, 0.88547562, 0.88978406, 0.89692153, 0.89921819,
#         0.90078649, 0.89588545, 0.87814707]),
#  'split4_test_score': array([0.88983051, 0.89009444, 0.89011629, 0.8912623 , 0.89163972,
#         0.89180595, 0.87456375, 0.85121884]),
#  'mean_test_score': array([0.88925427, 0.8928672 , 0.89673186, 0.90008317, 0.90075137,
#         0.90106445, 0.88364802, 0.85937322]),
#  'std_test_score': array([0.01275127, 0.00951917, 0.00851603, 0.00711101, 0.00687745,
#         0.00685497, 0.01125898, 0.01503882]),
#  'rank_test_score': array([6, 5, 4, 3, 2, 1, 7, 8], dtype=int32)}

# %%
gridRidge.best_params_
# Out:
# {'alpha': 100}

# %%
gridRidge.best_score_
# Out:
# 0.9010644453209741

# %%
gridRidge.best_estimator_.coef_
# Out:
# array([ 1.92533704e+03,  3.64723776e+03,  2.96526943e+02,  9.27848828e+03,
#         4.94341516e+03,  4.30695904e+03,  1.56616892e+03,  2.43199293e+03,
#        -4.17404052e+03,  9.98960446e+02, -3.25785198e+03,  5.55569462e+02,
#        -1.79506669e+03,  5.28197522e+01,  7.21371703e+03, -5.61179127e+02,
#         7.74402649e+02, -5.92096750e+02,  7.33159169e+03, -8.73836523e+02,
#         7.29639421e+03,  6.48557364e+03, -3.28561463e+02,  1.14261333e+04,
#         9.26233745e+02, -5.65365805e+02,  1.06415087e+03,  8.34188680e+02,
#        -2.43153346e+03, -1.61312037e+03, -4.29037146e+03,  3.28503944e+03,
#         1.82975986e+03, -1.09014677e+03, -5.21019624e+02, -5.92049043e+02,
#         3.07379124e+03,  2.92078412e+03,  2.67730848e+02, -2.74106691e+01,
#         2.03494506e+03,  1.50308531e+03,  6.78923909e+01,  5.09124417e+02,
#         1.69716054e+03,  5.04414686e+02,  5.95740954e+02,  1.12375991e+03,
#         2.40325513e+02, -2.61810022e+02, -3.62197467e+02, -4.41545133e+02,
#        -1.24047942e+03,  1.94829916e+01, -1.28713686e+02,  7.48138361e+02,
#         8.26920242e+02, -1.56539933e+01, -1.41061239e+02,  8.04027049e+02,
#         1.24627453e+03,  6.63943999e+02, -6.63208522e+01, -9.70458462e+02,
#         1.68317771e+02, -3.90176766e+02, -2.12191140e+01,  8.16740825e+02,
#         4.21917197e+02,  1.22732852e+02, -1.21272281e+03, -7.93625493e+02,
#        -1.02476152e+03, -2.45836672e+03, -1.82621012e+03,  1.68902610e+02,
#        -6.23931620e+02,  1.73465018e+03,  2.54901052e+02,  7.89770062e+02,
#         1.60141688e+01,  1.04370046e+03, -1.94829916e+01, -4.86805258e+02,
#         1.63705991e+02, -9.99633490e+01,  4.10106903e+02,  1.37734429e+03,
#        -1.01609135e+03,  2.76137020e+02, -9.08298183e+02,  1.52764048e+03,
#  ('NeighborhoodDummy_MeadowV', -1268.1855267639087),
#  ('Exterior2ndDummy_VinylSd', 1258.8564324837494),
#  ('GarageTypeDummy_Basment', 1248.955044461613),
#  ('BsmtBaths', 1246.274525970388),
#  ('hasGarage', -1240.479417354713),
#  ('Condition2Dummy_Norm', 1229.5037847701876),
#  ('Condition1Dummy_PosN', -1222.5057723889422),
#  ('MSSubClassDummy_75', -1212.7228105953293),
#  ('Exterior2ndDummy_Other', -1177.6752631173788),
#  ('Exterior1stDummy_CBlock', -1168.426629601725),
#  ('HouseStyleDummy_1Story', -1141.3452187121832),
#  ('Fence', 1123.7599075704288),
#  ('HouseStyleDummy_SFoyer', 1122.5534972222788),
#  ('MasVnrTypeDummy_No_MasVnr', 1111.2898625017651),
#  ('FireplaceQu', -1090.1467730626284),
#  ('FullBath', 1064.150871418839),
#  ('FoundationDummy_Stone', -1044.4069317000817),
#  ('RoofMatlDummy_WdShake', 1043.7135959680193),
#  ('MSZoningDummy_RM', 1043.700461197917),
#  ('MSSubClassDummy_85', -1024.7615211395678),
#  ('BldgTypeDummy_2fmCon', -1024.7615211395573),
#  ('LandContourDummy_HLS', -1016.0913464526907),
#  ('Exterior1stDummy_Stone', 1013.3644896724002),
#  ('FunctionalDummy_Min2', -1012.9255417547557),
#  ('ExterCond', 998.9604463111878),
#  ('NumFloors', -970.4584623168731),
#  ('NeighborhoodDummy_NAmes', 958.7032444712037),
#  ('BsmtFullBath', 926.2337451847554),
#  ('MasVnrTypeDummy_Stone', 918.2090498632541),
#  ('LandContourDummy_Lvl', -908.2981830581182),
#  ('HeatingQC', -873.8365225272572),
#  ('GarageTypeDummy_CarPort', 854.6387361488637),
#  ('LotConfigDummy_FR2', -839.2800064443844),
#  ('HalfBath', 834.1886801576708),
#  ('hasPool', 826.9202418029998),
#  ('MSSubClassDummy_50', 816.7408253329237),
#  ('hasMasVnr', 804.0270488695573),
#  ('MSSubClassDummy_80', -793.6254933722043),
#  ('PavedDriveDummy_P', 790.0022799502117),
#  ('MSZoningDummy_RH', 789.7700617455554),
#  ('BsmtFinSF2', 774.4026492112721),
#  ('Exterior1stDummy_ImStucc', 771.0424874170548),
#  ('LotConfigDummy_CulDSac', -760.8799188333604),
#  ('hasFireplace', 748.1383608366789),
#  ('HouseStyleDummy_2.5Fin', -712.3768891399834),
#  ('HouseStyleDummy_SLvl', -698.928205638025),
#  ('SaleTypeDummy_WD', 684.8059767926081),
#  ('FoundationDummy_PConc', 668.2698790501776),
#  ('FunctionalDummy_Min1', 667.2100936633102),
#  ('Baths', 663.9439985016695),
#  ('Condition1Dummy_RRNn', -642.743188948511),
#  ('NeighborhoodDummy_BrDale', 638.7423624110706),
#  ('MSSubClassDummy_180', -623.9316195191715),
#  ('SaleTypeDummy_Con', 612.9336269070878),
#  ('Condition1Dummy_PosA', 611.5911734411145),
#  ('Exterior1stDummy_Wd Sdng', 606.3490275784153),
#  ('Exterior1stDummy_WdShing', 602.7121824258295),
#  ('PoolQC', 595.740954094928),
#  ('BsmtUnfSF', -592.0967497105605),
#  ('GarageFinish', -592.0490425945519),
#  ('ElectricalDummy_SBrkr', -591.1302856663177),
#  ('Exterior1stDummy_HdBoard', -588.0694823554769),
#  ('RoofMatlDummy_Tar&Grv', -581.6109596457812),
#  ('NeighborhoodDummy_OldTown', -580.7613105572115),
#  ('RoofStyleDummy_Hip', -571.6833388935177),
#  ('Condition2Dummy_RRNn', -568.4901681990331),
#  ('BsmtHalfBath', -565.3658053648888),
#  ('BsmtFinType2', -561.1791274001101),
#  ('BsmtCond', 555.5694618140319),
#  ('RoofStyleDummy_Gambrel', 549.5166975477131),
#  ('Exterior1stDummy_MetalSd', -543.0391085149028),
#  ('NeighborhoodDummy_IDOTRR', -524.6763298368503),
#  ('GarageYrBlt', -521.0196242264072),
#  ('HeatingDummy_Grav', -513.5007199388629),
#  ('3SsnPorch', 509.1244166863629),
#  ('Exterior2ndDummy_Stucco', 504.69520192618535),
#  ('PoolArea', 504.41468623907764),
#  ('SaleTypeDummy_CWD', 491.275648208389),
#  ('AlleyDummy_No_Alley_Access', -486.80525837286814),
#  ('SalePrice', -441.5451325907546),
#  ('GarageTypeDummy_Detchd', 441.5451325907361),
#  ('RoofMatlDummy_WdShngl', -441.52145575108426),
#  ('SaleConditionDummy_AdjLand', 433.6966262988167),
#  ('HouseStyleDummy_2.5Unf', -425.63010976030387),
#  ('Exterior2ndDummy_Brk Cmn', -424.66848264583854),
#  ('Exterior2ndDummy_Wd Shng', 424.40835112377704),
#  ('MSSubClassDummy_60', 421.917197122111),
#  ('HeatingDummy_Wall', 412.5811446223339),
#  ('LotShapeDummy_IR3', 410.1069032610685),
#  ('NeighborhoodDummy_SawyerW', 408.42104669543176),
#  ('NeighborhoodDummy_Gilbert', -401.4517226732926),
#  ('Condition1Dummy_RRAn', -390.41327597160785),
#  ('BldgTypeDummy_TwnhsE', 390.236892957198),
#  ('MSSubClassDummy_40', -390.17676628730055),
#  ('Exterior2ndDummy_Plywood', 388.09758715697456),
#  ('SaleTypeDummy_New', 385.72495899176477),
#  ('NeighborhoodDummy_Timber', 362.7715735023574),
#  ('YrSold', -362.19746678659476),
#  ('CentralAirDummy_Y', -354.1478951272826),
#  ('LotConfigDummy_Inside', 338.62290572323235),
#  ('Exterior2ndDummy_HdBoard', 335.06030779014486),
#  ('LowQualFinSF', -328.5614629210971),
#  ('Condition1Dummy_RRNe', 311.74044205167206),
#  ('Condition1Dummy_RRAe', 305.0824066934048),
#  ('LandSlope', 296.52694296033843),
#  ('Condition1Dummy_Norm', -290.9841359325626),
#  ('LandContourDummy_Low', 276.13701965855716),
#  ('Exterior2ndDummy_BrkFace', -268.3576968197133),
#  ('Exterior1stDummy_BrkFace', -268.3576968197129),
#  ('GarageQual', 267.7308481042557),
#  ('MoSold', -261.8100224789923),
#  ('MSZoningDummy_FV', 254.90105195948962),
#  ('Exterior2ndDummy_AsphShn', 251.7886065700199),
#  ('NeighborhoodDummy_Sawyer', -243.20630489561637),
#  ('NeighborhoodDummy_Veenker', -240.86695706146588),
#  ('MiscVal', 240.32551286731464),
#  ('Exterior1stDummy_Plywood', -234.66728158379192),
#  ('ElectricalDummy_Mix', 234.2128892128777),
#  ('RoofStyleDummy_Shed', -226.21602944992708),
#  ('Exterior2ndDummy_MetalSd', -218.09534833636317),
#  ('Exterior2ndDummy_ImStucc', 211.63546582606457),
#  ('NeighborhoodDummy_BrkSide', 178.5594494480381),
#  ('MSSubClassDummy_160', 168.90261032462573),
#  ('MSSubClassDummy_30', 168.31777055889657),
#  ('FunctionalDummy_Maj2', -166.712062141617),
#  ('AlleyDummy_Pave', 163.70599081340598),
#  ('ElectricalDummy_FuseF', 154.29330839700486),
#  ('RoofStyleDummy_Gable', 153.08025555586798),
#  ('HouseStyleDummy_1.5Unf', -142.05694893460796),
#  ('hasMisc_Feature', -141.06123899340452),
#  ('MasVnrTypeDummy_BrkFace', 141.06123899337112),
#  ('GarageTypeDummy_Attchd', 140.33307439899772),
#  ('Exterior1stDummy_CemntBd', -133.3936641855293),
#  ('NeighborhoodDummy_SWISU', -129.56442116885833),
#  ('hasAlley_Access', -128.7136859702557),
#  ('Exterior1stDummy_AsphShn', -128.22180243521018),
#  ('GarageTypeDummy_BuiltIn', -126.41274268534646),
#  ('MSSubClassDummy_70', 122.7328524431207),
#  ('FoundationDummy_Wood', 120.01996420698045),
#  ('RoofMatlDummy_Metal', -119.5893078607526),
#  ('MiscFeatureDummy_No_Misc_Feature', 109.70113999072846),
#  ('Exterior1stDummy_Stucco', 105.15709515132126),
#  ('Exterior2ndDummy_Stone', 104.8781536986201),
#  ('LotShapeDummy_IR2', -99.9633490432256),
#  ('NeighborhoodDummy_StoneBr', -94.80277002078137),
#  ('Condition2Dummy_Feedr', -94.61292598719372),
#  ('Condition2Dummy_RRAe', -92.53784679857006),
#  ('MiscFeatureDummy_Othr', 90.54261146565712),
#  ('HeatingDummy_GasA', -72.28761905430723),
#  ('RoofMatlDummy_Roll', 71.5336974471721),
#  ('GarageTypeDummy_No_Garage', -69.13284360541414),
#  ('EnclosedPorch', 67.89239091984113),
#  ('SaleTypeDummy_Oth', 66.6544624204895),
#  ('hasBeenRemodeled', -66.32085223412187),
#  ('LotConfigDummy_FR3', -65.02459509524066),
#  ('SaleConditionDummy_Alloca', 65.02202513932455),
#  ('SaleTypeDummy_ConLD', -63.898578737605895),
#  ('BsmtFinType1', 52.819752158731),
#  ('FunctionalDummy_Typ', -34.476248326844356),
#  ('Condition2Dummy_RRAn', 27.61140437377603),
#  ('GarageCond', -27.410669099598305),
#  ('MSSubClassDummy_45', -21.219114026784606),
#  ('hasBsmt', 19.48299156413391),
#  ('StreetDummy_Pave', -19.482991564106786),
#  ('MSZoningDummy_RL', 16.014168833472816),
#  ('PavedDriveDummy_Y', 15.653993333029671),
#  ('hasFence', -15.653993333015485),
#  ('HeatingDummy_GasW', 13.873479485117112),
#  ('SaleTypeDummy_ConLI', -9.460653367055672),
#  ('FoundationDummy_Slab', 3.9583969211636467),
#  ('HouseStyleDummy_2Story', 1.4523735163192315),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146715683971.00873, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146246383954.68863, tolerance: 468456883.5106045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153646349310.42828, tolerance: 520416840.482401
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161924977432.8003, tolerance: 536158623.30847865
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152577941156.30234, tolerance: 515997508.11935616
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87099515406.08867, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122092138167.87817, tolerance: 468456883.5106045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131106192267.28539, tolerance: 520416840.482401
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122896441776.14435, tolerance: 536158623.30847865
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127331025446.29955, tolerance: 515997508.11935616
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6146206787.804047, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.13049331, 0.12295508, 0.12652578, 0.09906836, 0.06852818,
#         0.06029439, 0.01470633, 0.01032529]),
#  'std_fit_time': array([0.00686424, 0.00398046, 0.01123161, 0.01139663, 0.00381355,
#         0.00641412, 0.00624457, 0.00278569]),
#  'mean_score_time': array([0.0028625 , 0.00263896, 0.00244989, 0.00252767, 0.0027247 ,
#         0.00302458, 0.00297241, 0.00263   ]),
#  'std_score_time': array([6.95279519e-04, 2.81111160e-04, 1.68578870e-04, 2.37419582e-04,
#         2.41081313e-04, 4.88118987e-04, 2.45717033e-04, 9.90824703e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.90406941, 0.90458307, 0.90566385, 0.9075326 , 0.90853944,
#         0.90923183, 0.90753094, 0.89237256]),
#  'split1_test_score': array([0.90001859, 0.90108543, 0.90628088, 0.91161345, 0.91206683,
#         0.91210974, 0.91095239, 0.90194673]),
#  'split2_test_score': array([0.87519042, 0.87655282, 0.88431157, 0.89374439, 0.89643531,
#         0.8974511 , 0.89181657, 0.87261471]),
#  'split3_test_score': array([0.88415588, 0.88450661, 0.88680107, 0.89119488, 0.89353522,
#         0.89552459, 0.90124046, 0.8889045 ]),
#  'split4_test_score': array([0.88989242, 0.88992309, 0.88992112, 0.89043789, 0.89149731,
#         0.89272481, 0.89923968, 0.889963  ]),
#  'mean_test_score': array([0.89066534, 0.8913302 , 0.8945957 , 0.89890464, 0.90041482,
#         0.90140841, 0.90215601, 0.8891603 ]),
#  'std_test_score': array([0.01048424, 0.0103703 , 0.00945959, 0.00887367, 0.0083002 ,
#         0.00776413, 0.00667103, 0.00946866]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 2, 1, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9021560071990002

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 23932.054942990075),
#  ('OverallQual', 12693.556246803346),
#  ('BsmtFinSF1', 8086.0191968566),
#  ('TotalBsmtSF', 7626.3975329259665),
#  ('ExterQual', -5293.261168346383),
#  ('YearBuilt', 5216.341092470427),
#  ('NeighborhoodDummy_NoRidge', 4906.461440818671),
#  ('KitchenQual', -4738.114216282669),
#  ('OverallCond', 4212.4614649302775),
#  ('SaleConditionDummy_Normal', 3974.1270206574404),
#  ('NeighborhoodDummy_Somerst', 3334.013217887907),
#  ('GarageArea', 3225.0536869682755),
#  ('BsmtQual', -3196.2017212658434),
#  ('LotArea', 3178.145588754519),
#  ('NeighborhoodDummy_NWAmes', 3157.495853625492),
#  ('FunctionalDummy_Sev', 2540.919289237997),
#  ('YearRemodAdd', 2269.3636075577097),
#  ('NeighborhoodDummy_CollgCr', 2255.090011124059),
#  ('GarageCars', 2032.8738556350404),
#  ('Exterior1stDummy_BrkComm', 1831.926993745964),
#  ('KitchenAbvGr', -1737.058518255972),
#  ('MSSubClassDummy_90', -1674.810714146161),
#  ('Fireplaces', 1616.4887007376508),
#  ('MSSubClassDummy_120', -1346.5081826277694),
#  ('Condition1Dummy_Feedr', 1280.0464980770732),
#  ('WoodDeckSF', 1211.0171130786762),
#  ('BldgTypeDummy_Twnhs', -1196.7858503316745),
#  ('MasVnrArea', 1181.6957360803071),
#  ('BldgTypeDummy_Duplex', -1158.4358766947523),
#  ('FunctionalDummy_Mod', -1079.3970861183434),
#  ('LotFrontage', 1007.7409692020879),
#  ('MiscFeatureDummy_TenC', 1005.9200305129278),
#  ('NeighborhoodDummy_SawyerW', 924.7594402621422),
#  ('BsmtExposure', -885.7623119279339),
#  ('BsmtFullBath', 879.8470368547529),
#  ('MSSubClassDummy_85', -876.7178271974142),
#  ('LotShapeDummy_Reg', 792.1970801931955),
#  ('NeighborhoodDummy_NridgHt', -725.3891570345253),
#  ('hasGarage', -689.524579936256),
#  ('HouseStyleDummy_1Story', -537.1791457150307),
#  ('ScreenPorch', 536.5824197888365),
#  ('FunctionalDummy_Min2', -532.1357365128907),
#  ('HouseStyleDummy_SLvl', -518.776674983067),
#  ('OpenPorchSF', 472.1774627658513),
#  ('MasVnrTypeDummy_None', 446.08237665989935),
#  ('Exterior2ndDummy_CmentBd', -431.5750858777041),
#  ('BedroomAbvGr', -425.6042570733898),
#  ('UtilitiesDummy_NoSeWa', 422.6819567398268),
#  ('NeighborhoodDummy_NPkVill', -389.8243235148091),
#  ('FireplaceQu', -369.9875958247693),
#  ('LowQualFinSF', -366.92575126849397),
#  ('GarageFinish', -351.1655859211938),
#  ('Exterior2ndDummy_Wd Sdng', -300.3867586389573),
#  ('HeatingQC', -284.72929571598513),
#  ('BsmtFinSF2', 283.41241264410843),
#  ('GarageTypeDummy_Basment', 224.5744048459411),
#  ('MSSubClassDummy_70', -223.66135897734222),
#  ('FoundationDummy_Stone', -198.59325598105926),
#  ('Exterior2ndDummy_Other', -182.8057815734594),
#  ('MSZoningDummy_RL', -174.44527673591855),
#  ('Exterior1stDummy_Stone', 157.7436590202736),
#  ('Exterior2ndDummy_Stucco', 140.54477011342746),
#  ('NeighborhoodDummy_Crawfor', -98.79459766540326),
#  ('Condition1Dummy_PosN', -84.85262737130179),
#  ('BldgTypeDummy_2fmCon', -78.8122127801525),
#  ('RoofMatlDummy_WdShake', 71.98112213070138),
#  ('NeighborhoodDummy_BrDale', 69.0712445730294),
#  ('Exterior1stDummy_VinylSd', -62.65926499122415),
#  ('RoofStyleDummy_Gambrel', 38.54142724583757),
#  ('BsmtFinType2', -0.6692783446272672),
#  ('LandSlope', 0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', -0.0),
#  ('hasBsmt', -0.0),
#  ('hasAlley_Access', 0.0),
#  ('hasFireplace', 0.0),
#  ('hasPool', -0.0),
#  ('hasFence', 0.0),
#  ('hasMisc_Feature', -0.0),
#  ('hasMasVnr', 0.0),
#  ('BsmtBaths', 0.0),
#  ('Baths', 0.0),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -0.0),
#  ('MSSubClassDummy_30', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_75', 0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', -0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', 0.0),
#  ('LotConfigDummy_Inside', 0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_OldTown', -0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Timber', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', 0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', -0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_CBlock', 0.0),
#  ('FoundationDummy_PConc', 0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', -0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_CWD', 0.0),
#  ('SaleTypeDummy_Con', -0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8797129863634081

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.9000257433096237

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153351710146.13132, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164159528368.20526, tolerance: 468456883.5106045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169039810122.73178, tolerance: 520416840.482401
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169532109618.48672, tolerance: 536158623.30847865
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157981819802.2306, tolerance: 515997508.11935616
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63652751606.274994, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131735545433.82332, tolerance: 468456883.5106045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129795217961.90659, tolerance: 520416840.482401
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91328325909.38145, tolerance: 536158623.30847865
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39541291738.27246, tolerance: 515997508.11935616
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2587226455.9851074, tolerance: 510463582.81833
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7398262156.58667, tolerance: 536158623.30847865
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.9002511815019718

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# hasGarage                 GarageTypeDummy_No_Garage     1.000000
# hasMasVnr                 MasVnrTypeDummy_No_MasVnr     1.000000
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock       1.000000
# hasAlley_Access           AlleyDummy_No_Alley_Access    1.000000
# PoolArea                  hasPool                       0.999917
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd      0.999179
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd      0.999018
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd      0.998726
# PoolArea                  PoolQC                        0.998335
# PoolQC                    hasPool                       0.997510
# GarageYrBlt               GarageTypeDummy_No_Garage     0.996011
#                           hasGarage                     0.996011
# MSSubClassDummy_80        HouseStyleDummy_SLvl          0.992260
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf        0.992210
# Fence                     hasFence                      0.991375
# BsmtFullBath              BsmtBaths                     0.990434
# GarageCars                GarageArea                    0.989379
# RoofStyleDummy_Gable      RoofStyleDummy_Hip            0.989061
# Fireplaces                hasFireplace                  0.986032
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng      0.985410
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard      0.983307
# FullBath                  Baths                         0.974406
# GrLivArea                 TotRmsAbvGrd                  0.974203
# MSZoningDummy_FV          NeighborhoodDummy_Somerst     0.970391
# TotalBsmtSF               1stFlrSF                      0.966435
# ExterQual                 KitchenQual                   0.965939
# 2ndFlrSF                  NumFloors                     0.965843
# OverallQual               ExterQual                     0.958166
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco       0.957540
# ExterQual                 BsmtQual                      0.954597
# BsmtQual                  FoundationDummy_PConc         0.953828
# 2ndFlrSF                  HouseStyleDummy_2Story        0.949138
# OverallQual               BsmtQual                      0.948261
# MSSubClassDummy_85        HouseStyleDummy_SFoyer        0.948091
# MasVnrArea                MasVnrTypeDummy_None          0.944392
# YearRemodAdd              BsmtQual                      0.943645
# NumFloors                 HouseStyleDummy_1Story        0.940555
# YearRemodAdd              FoundationDummy_PConc         0.939899
# HalfBath                  HouseStyleDummy_2Story        0.939575
# OverallQual               KitchenQual                   0.938989
#                           GarageCars                    0.936718
# KitchenAbvGr              MSSubClassDummy_90            0.933803
# FoundationDummy_CBlock    FoundationDummy_PConc         0.927085
# GrLivArea                 Baths                         0.927053
# OverallQual               FullBath                      0.925839
# BsmtQual                  KitchenQual                   0.925482
# YearRemodAdd              ExterQual                     0.922730
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood      0.922369
# ExterQual                 FoundationDummy_PConc         0.921986
# YearBuilt                 BsmtQual                      0.920811
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.894598396421326),
#  ('LotArea', 2.058897884940748),
#  ('OverallQual', 4.814655552934898),
#  ('OverallCond', 2.1614536171199945),
#  ('YearBuilt', 16.54070819200726),
#  ('YearRemodAdd', 3.6738179137256735),
#  ('MasVnrArea', 2.759972418528664),
#  ('ExterQual', 3.04041529338128),
#  ('BsmtQual', 3.1310143116951337),
#  ('BsmtExposure', 1.8244102404574913),
#  ('BsmtFinType1', 2.246252261834252),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', inf),
#  ('BsmtHalfBath', inf),
#  ('FullBath', inf),
#  ('HalfBath', inf),
#  ('BedroomAbvGr', 3.0500799436648682),
#  ('KitchenAbvGr', 4.726583088082887),
#  ('KitchenQual', 2.3396781621694074),
#  ('TotRmsAbvGrd', 5.491166240447242),
#  ('Fireplaces', 7.3550815784046035),
#  ('FireplaceQu', 1.4524312030981963),
#  ('GarageYrBlt', 1153.1221105904967),
#  ('GarageFinish', 2.1526857054900113),
#  ('GarageCars', 6.446480658526092),
#  ('GarageArea', 6.384178229664475),
#  ('WoodDeckSF', 1.3822568832531588),
#  ('OpenPorchSF', 1.4865707875886183),
#  ('EnclosedPorch', 1.5145678972934309),
#  ('3SsnPorch', 1.1205527198221186),
#  ('ScreenPorch', 1.1924771517258526),
#  ('PoolArea', inf),
#  ('PoolQC', inf),
#  ('Fence', 9.801232464505084),
#  ('MiscVal', 1.255943135367444),
#  ('MoSold', 1.1639533075315287),
#  ('YrSold', 1.2087710178328397),
#  ('hasGarage', inf),
#  ('hasBsmt', 5.9906888516838555),
#  ('hasAlley_Access', inf),
#  ('hasFireplace', 7.36378325176553),
#  ('hasPool', inf),
#  ('hasFence', 9.786767595160942),
#  ('hasMisc_Feature', 1.387706475877017),
#  ('hasMasVnr', inf),
#  ('BsmtBaths', inf),
#  ('Baths', inf),
#  ('hasBeenRemodeled', 1.9244218482006523),
#  ('NumFloors', 44.6343705687709),
#  ('MSSubClassDummy_30', 2.625187686975519),
#  ('MSSubClassDummy_40', 1.252486014041948),
#  ('MSSubClassDummy_45', 7.060553343664805),
#  ('MSSubClassDummy_50', 20.86114929762841),
#  ('MSSubClassDummy_60', 31.427098634327397),
#  ('MSSubClassDummy_70', 7.4276121998253135),
#  ('MSSubClassDummy_75', 19.674079848994804),
#  ('MSSubClassDummy_80', 14.485858579736727),
#  ('MSSubClassDummy_85', 6.034894030968152),
#  ('MSSubClassDummy_90', 4.837941241462697),
#  ('MSSubClassDummy_120', 2.781078838836007),
#  ('MSSubClassDummy_160', 10.75310967100684),
#  ('MSSubClassDummy_180', 2.263412781187774),
#  ('MSSubClassDummy_190', 2.0071820486930694),
#  ('MSZoningDummy_FV', 23.977117398114054),
#  ('MSZoningDummy_RH', 5.516716370991626),
#  ('MSZoningDummy_RL', 69.92291367718089),
#  ('MSZoningDummy_RM', 47.86627477751957),
#  ('AlleyDummy_No_Alley_Access', inf),
#  ('AlleyDummy_Pave', 2.6653492180733465),
#  ('LotShapeDummy_IR2', 1.3334894077297528),
#  ('LotShapeDummy_IR3', 1.1563381318815158),
#  ('LotShapeDummy_Reg', 1.5572722107960464),
#  ('LotConfigDummy_CulDSac', 1.8244920746722577),
#  ('LotConfigDummy_FR2', 1.3882528089151676),
#  ('LotConfigDummy_FR3', 1.1034662995038824),
#  ('LotConfigDummy_Inside', 1.7915366418866445),
#  ('NeighborhoodDummy_Blueste', 1.4561455499945075),
#  ('NeighborhoodDummy_BrDale', 3.83402626346663),
#  ('NeighborhoodDummy_BrkSide', 8.69920571548219),
#  ('NeighborhoodDummy_ClearCr', 3.322334987769073),
#  ('NeighborhoodDummy_CollgCr', 13.810766732878795),
#  ('NeighborhoodDummy_Crawfor', 6.502336598464081),
#  ('NeighborhoodDummy_Edwards', 9.886529483147328),
#  ('NeighborhoodDummy_Gilbert', 8.484945810536235),
#  ('NeighborhoodDummy_IDOTRR', 6.39424555154579),
#  ('NeighborhoodDummy_MeadowV', 3.5115574507438936),
#  ('NeighborhoodDummy_Mitchel', 6.017863974522514),
#  ('NeighborhoodDummy_NAmes', 22.10217008134127),
#  ('NeighborhoodDummy_NPkVill', 2.19107858600012),
#  ('NeighborhoodDummy_NWAmes', 8.267085339796242),
#  ('NeighborhoodDummy_NoRidge', 5.199380684599561),
#  ('NeighborhoodDummy_NridgHt', 7.004481899569906),
#  ('NeighborhoodDummy_OldTown', 14.731267881218018),
#  ('NeighborhoodDummy_SWISU', 4.172747879083216),
#  ('NeighborhoodDummy_Sawyer', 8.792082697230095),
#  ('NeighborhoodDummy_SawyerW', 6.205013069404863),
#  ('NeighborhoodDummy_Somerst', 11.679050811560188),
#  ('NeighborhoodDummy_StoneBr', 2.918129878218901),
#  ('NeighborhoodDummy_Timber', 4.298071533841491),
#  ('NeighborhoodDummy_Veenker', 1.9597835950652054),
#  ('HouseStyleDummy_1.5Unf', 9.304777850888653),
#  ('HouseStyleDummy_1Story', 81.40047693565987),
#  ('HouseStyleDummy_2.5Fin', 8.694421671101326),
#  ('HouseStyleDummy_2.5Unf', 13.47589556478496),
#  ('HouseStyleDummy_2Story', 47.26665061247161),
#  ('HouseStyleDummy_SFoyer', 12.090766614662593),
#  ('HouseStyleDummy_SLvl', 23.36234069975355),
#  ('RoofStyleDummy_Gable', 64.2127829708601),
#  ('RoofStyleDummy_Gambrel', 3.605086261233697),
#  ('RoofStyleDummy_Hip', 62.38943051119815),
#  ('RoofStyleDummy_Mansard', 1.3786783658972737),
#  ('RoofStyleDummy_Shed', nan),
#  ('Exterior1stDummy_AsphShn', 1.3018678096324692),
#  ('Exterior1stDummy_BrkComm', 1.1290492877769358),
#  ('Exterior1stDummy_BrkFace', 3.93223457336491),
#  ('Exterior1stDummy_CBlock', 1.2097349790926146),
#  ('Exterior1stDummy_CemntBd', 5.1737595249001185),
#  ('Exterior1stDummy_HdBoard', 15.551357074069655),
#  ('Exterior1stDummy_ImStucc', 1.194192566005438),
#  ('Exterior1stDummy_MetalSd', 14.102048639053809),
#  ('Exterior1stDummy_Plywood', 8.242190647539987),
#  ('Exterior1stDummy_Stone', 1.4067126848703462),
#  ('Exterior1stDummy_Stucco', 2.411603837264157),
#  ('Exterior1stDummy_VinylSd', 26.294721677883285),
#  ('Exterior1stDummy_Wd Sdng', 12.807214652212723),
#  ('Exterior1stDummy_WdShing', 2.415863149209579),
#  ('MasVnrTypeDummy_BrkFace', 25.44437975053154),
#  ('MasVnrTypeDummy_No_MasVnr', inf),
#  ('MasVnrTypeDummy_None', 28.946348844505177),
#  ('MasVnrTypeDummy_Stone', 10.450775847882115),
#  ('FoundationDummy_CBlock', 7.220773353174145),
#  ('FoundationDummy_PConc', 8.624586651407766),
#  ('FoundationDummy_Slab', 2.3197075047434317),
#  ('FoundationDummy_Stone', 1.2816386160712598),
#  ('FoundationDummy_Wood', 1.280248048893708),
#  ('GarageTypeDummy_Attchd', 77.67799952959906),
#  ('GarageTypeDummy_Basment', 6.009579240745757),
#  ('GarageTypeDummy_BuiltIn', 19.34676761509837),
#  ('GarageTypeDummy_CarPort', 2.794441797078259),
#  ('GarageTypeDummy_Detchd', 64.4415539119963),
#  ('GarageTypeDummy_No_Garage', inf),
#  ('SaleConditionDummy_AdjLand', 1.0748368140543283),
#  ('SaleConditionDummy_Alloca', 1.2992199512953235),
#  ('SaleConditionDummy_Family', 1.3534551360809597),
#  ('SaleConditionDummy_Normal', 2.7869142256792334),
#  ('SaleConditionDummy_Partial', 2.955220292998813),
#  ('constant', 0.0)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.894190553576911),
#  ('LotArea', 2.0580408162342163),
#  ('OverallCond', 2.1099885901827773),
#  ('YearBuilt', 16.238533518760274),
#  ('YearRemodAdd', 3.6737531374798746),
#  ('MasVnrArea', 2.7599419289305778),
#  ('ExterQual', 2.9513324030354147),
#  ('BsmtQual', 3.1194923930614755),
#  ('BsmtExposure', 1.8197648200720196),
#  ('BsmtFinType1', 2.2404596462054673),
#  ('BsmtFinSF1', 12.961682046389642),
#  ('BsmtFinSF2', 2.5769796868454677),
#  ('BsmtUnfSF', 13.312192918783763),
#  ('1stFlrSF', 11.260223264616293),
#  ('2ndFlrSF', 20.69791915475406),
#  ('LowQualFinSF', 2.816887608540117),
#  ('BsmtFullBath', inf),
#  ('BsmtHalfBath', inf),
#  ('FullBath', inf),
#  ('HalfBath', inf),
#  ('BedroomAbvGr', 3.0450328100111466),
#  ('KitchenAbvGr', 4.705030450792641),
#  ('KitchenQual', 2.3213117465828543),
#  ('TotRmsAbvGrd', 5.487745629727395),
#  ('Fireplaces', 7.331909188255999),
#  ('FireplaceQu', 1.4453294396756151),
#  ('GarageYrBlt', 1152.8209979982655),
#  ('GarageFinish', 2.1438842335813493),
#  ('GarageCars', 6.440944529415138),
#  ('GarageArea', 6.380075305740116),
#  ('WoodDeckSF', 1.3803623766737971),
#  ('OpenPorchSF', 1.4858036703092403),
#  ('EnclosedPorch', 1.51226226008791),
#  ('3SsnPorch', 1.120461988373887),
#  ('ScreenPorch', 1.1923555417805956),
#  ('PoolArea', inf),
#  ('PoolQC', inf),
#  ('Fence', 9.755635808261356),
#  ('MiscVal', 1.2523372310619565),
#  ('MoSold', 1.162300128666727),
#  ('YrSold', 1.2082251814055),
#  ('hasGarage', inf),
#  ('hasBsmt', 5.986621178063395),
#  ('hasAlley_Access', inf),
#  ('hasFireplace', 7.3637178463221025),
#  ('hasPool', inf),
#  ('hasFence', 9.758949019256121),
#  ('hasMisc_Feature', 1.3876683575495146),
#  ('hasMasVnr', inf),
#  ('BsmtBaths', inf),
#  ('Baths', inf),
#  ('hasBeenRemodeled', 1.919506406746601),
#  ('NumFloors', 44.407451299081316),
#  ('MSSubClassDummy_30', 2.6248292583343233),
#  ('MSSubClassDummy_40', 1.2522303999774786),
#  ('MSSubClassDummy_45', 7.060093649444311),
#  ('MSSubClassDummy_50', 20.831209299945783),
#  ('MSSubClassDummy_60', 31.42339120737593),
#  ('MSSubClassDummy_70', 7.391233416342813),
#  ('MSSubClassDummy_75', 19.641166014379284),
#  ('MSSubClassDummy_80', 14.480173991576478),
#  ('MSSubClassDummy_85', 6.009833823398535),
#  ('MSSubClassDummy_90', 4.837245150593684),
#  ('MSSubClassDummy_120', 2.78085193786424),
#  ('MSSubClassDummy_160', 10.752357844876274),
#  ('MSSubClassDummy_180', 2.2596212148745187),
#  ('MSSubClassDummy_190', 2.006805189665595),
#  ('MSZoningDummy_FV', 23.92316481528516),
#  ('MSZoningDummy_RH', 5.503999651254583),
#  ('MSZoningDummy_RL', 69.7828146297037),
#  ('MSZoningDummy_RM', 47.77359482018606),
#  ('AlleyDummy_No_Alley_Access', inf),
#  ('AlleyDummy_Pave', 2.6538026982245015),
#  ('LotShapeDummy_IR2', 1.3329118514057674),
#  ('LotShapeDummy_IR3', 1.1562299006022578),
#  ('LotShapeDummy_Reg', 1.555598689776871),
#  ('LotConfigDummy_CulDSac', 1.8243636382488149),
#  ('LotConfigDummy_FR2', 1.3879824340360403),
#  ('LotConfigDummy_FR3', 1.1034432666306697),
#  ('LotConfigDummy_Inside', 1.79013343778857),
#  ('NeighborhoodDummy_Blueste', 1.4561440868558844),
#  ('NeighborhoodDummy_BrDale', 3.83138157297202),
#  ('NeighborhoodDummy_BrkSide', 8.689358359285354),
#  ('NeighborhoodDummy_ClearCr', 3.319233075867506),
#  ('NeighborhoodDummy_CollgCr', 13.810117438154435),
#  ('NeighborhoodDummy_Crawfor', 6.5007151173323985),
#  ('NeighborhoodDummy_Edwards', 9.851404826533198),
#  ('NeighborhoodDummy_Gilbert', 8.483972895689217),
#  ('NeighborhoodDummy_IDOTRR', 6.391203145179534),
#  ('NeighborhoodDummy_MeadowV', 3.492534834058309),
#  ('NeighborhoodDummy_Mitchel', 6.012927828474409),
#  ('NeighborhoodDummy_NAmes', 22.09079977604339),
#  ('NeighborhoodDummy_NPkVill', 2.1903656191659935),
#  ('NeighborhoodDummy_NWAmes', 8.26708472602633),
#  ('NeighborhoodDummy_NoRidge', 5.193497874568305),
#  ('NeighborhoodDummy_NridgHt', 6.985394968264133),
#  ('NeighborhoodDummy_OldTown', 14.72764876637094),
#  ('NeighborhoodDummy_SWISU', 4.1632877451015995),
#  ('NeighborhoodDummy_Sawyer', 8.778295703513635),
#  ('NeighborhoodDummy_SawyerW', 6.2049675114884995),
#  ('NeighborhoodDummy_Somerst', 11.667905604338413),
#  ('NeighborhoodDummy_StoneBr', 2.88799693751283),
#  ('NeighborhoodDummy_Timber', 4.294193852372135),
#  ('NeighborhoodDummy_Veenker', 1.955780240311478),
#  ('HouseStyleDummy_1.5Unf', 9.299088971867858),
#  ('HouseStyleDummy_1Story', 81.27076937719494),
#  ('HouseStyleDummy_2.5Fin', 8.652835036730616),
#  ('HouseStyleDummy_2.5Unf', 13.474964203550023),
#  ('HouseStyleDummy_2Story', 47.16616443047739),
#  ('HouseStyleDummy_SFoyer', 12.084419383431467),
#  ('HouseStyleDummy_SLvl', 23.361983633835475),
#  ('RoofStyleDummy_Gable', 63.794452389257),
#  ('RoofStyleDummy_Gambrel', 3.5793697999707588),
#  ('RoofStyleDummy_Hip', 62.08168834164034),
#  ('RoofStyleDummy_Mansard', 1.3759825620568122),
#  ('RoofStyleDummy_Shed', nan),
#  ('Exterior1stDummy_AsphShn', 1.2960994200319425),
#  ('Exterior1stDummy_BrkComm', 1.1273940345651203),
#  ('Exterior1stDummy_BrkFace', 3.9122879984691545),
#  ('Exterior1stDummy_CBlock', 1.2052445261473506),
#  ('Exterior1stDummy_CemntBd', 5.154364200114707),
#  ('Exterior1stDummy_HdBoard', 15.479706995458988),
#  ('Exterior1stDummy_ImStucc', 1.1926343545582034),
#  ('Exterior1stDummy_MetalSd', 14.075297517373702),
#  ('Exterior1stDummy_Plywood', 8.206369662780515),
#  ('Exterior1stDummy_Stone', 1.4065348291073854),
#  ('Exterior1stDummy_Stucco', 2.3927542007087452),
#  ('Exterior1stDummy_VinylSd', 26.1960414376973),
#  ('Exterior1stDummy_Wd Sdng', 12.712851415258402),
#  ('Exterior1stDummy_WdShing', 2.3967726976753276),
#  ('MasVnrTypeDummy_BrkFace', 25.374796520900933),
#  ('MasVnrTypeDummy_No_MasVnr', inf),
#  ('MasVnrTypeDummy_None', 28.923647624386973),
#  ('MasVnrTypeDummy_Stone', 10.406747007504563),
#  ('FoundationDummy_CBlock', 7.137356915829342),
#  ('FoundationDummy_PConc', 8.597870332950183),
#  ('FoundationDummy_Slab', 2.3189524741190515),
#  ('FoundationDummy_Stone', 1.2784436348235362),
#  ('FoundationDummy_Wood', 1.280247980952362),
#  ('GarageTypeDummy_Attchd', 77.58245556363468),
#  ('GarageTypeDummy_Basment', 6.00122907931207),
#  ('GarageTypeDummy_BuiltIn', 19.33820782112515),
#  ('GarageTypeDummy_CarPort', 2.793474699284681),
#  ('GarageTypeDummy_Detchd', 64.40143254158629),
#  ('GarageTypeDummy_No_Garage', inf),
#  ('SaleConditionDummy_AdjLand', 1.0746427785063675),
#  ('SaleConditionDummy_Alloca', 1.2990459392808837),
#  ('SaleConditionDummy_Family', 1.3530804469588458),
#  ('SaleConditionDummy_Normal', 2.7868288619513817),
#  ('SaleConditionDummy_Partial', 2.9481156024997937)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
stats.summary(gridLasso.best_estimator_, X_Scaled, y)
