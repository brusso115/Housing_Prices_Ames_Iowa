# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %% [markdown]
# ## Train w/ dummies

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
# X = train.loc[:, train.columns != 'SalePrice']
# y = train['SalePrice']

# %% [markdown]
# ## Drop columns with all zeros

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k, X, y):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50, X=train.loc[:, train.columns != 'SalePrice'], y=train['SalePrice'])
# Out:
# [('OverallQual', 2503.566159751241), ('GrLivArea', 1396.306906888013), ('ExterQual', 1099.9981460336526), ('GarageCars', 1007.4649914099118), ('TotalBsmtSF', 945.3313700591382), ('GarageArea', 934.1741878376324), ('KitchenQual', 907.41215245565), ('1stFlrSF', 836.9319398840304), ('BsmtQual', 835.2188169306571), ('YearBuilt', 622.3106982521762), ('FullBath', 590.063083874904), ('FoundationDummy_PConc', 509.6109583163052), ('TotRmsAbvGrd', 508.63593772372275), ('YearRemodAdd', 482.3777753888501), ('Fireplaces', 337.065842880272), ('GarageFinish', 330.98055556785135), ('NeighborhoodDummy_NridgHt', 319.6145483159399), ('MasVnrArea', 299.96568198347967), ('HeatingQC', 264.92611258435863), ('BsmtFinSF1', 253.96092841285542), ('GarageTypeDummy_Detchd', 239.13994166798307), ('FoundationDummy_CBlock', 233.02074822008763), ('MasVnrTypeDummy_None', 220.73735775879726), ('LotFrontage', 207.99053185054444), ('GarageTypeDummy_Attchd', 201.7682992339341), ('MSSubClassDummy_60', 185.49530917955605), ('Exterior2ndDummy_VinylSd', 180.68385995694788), ('Exterior1stDummy_VinylSd', 179.98479958580472), ('SaleTypeDummy_New', 175.45016613643253), ('MasVnrTypeDummy_Stone', 174.51610054062192), ('SaleConditionDummy_Partial', 171.54966627176117), ('OpenPorchSF', 171.15837401548424), ('BsmtExposure', 168.57709791496697), ('WoodDeckSF', 142.48764889170556), ('MSZoningDummy_RM', 135.07918877293116), ('NeighborhoodDummy_NoRidge', 128.33333840557054), ('LotArea', 100.55509203775696), ('BsmtFullBath', 95.38276558842003), ('HalfBath', 89.96019172462205), ('2ndFlrSF', 86.63604791339989), ('SaleTypeDummy_WD', 81.13392780943622), ('GarageYrBlt', 80.17176114303368), ('MSZoningDummy_RL', 75.3182090972277), ('LotShapeDummy_Reg', 73.91094072679206), ('HouseStyleDummy_2Story', 70.99222042780882), ('NeighborhoodDummy_OldTown', 70.2637090032018), ('MSSubClassDummy_30', 69.3898233428585), ('ElectricalDummy_SBrkr', 68.44514002694864), ('NeighborhoodDummy_NAmes', 67.98501080887985), ('GarageCond', 61.83432407191812), ('GarageTypeDummy_No_Garage', 60.217170772575415), ('BsmtUnfSF', 60.025477648183916), ('GarageQual', 59.99058030788644), ('CentralAirDummy_Y', 56.17417977600278), ('RoofStyleDummy_Hip', 55.792463091187635), ('MasVnrTypeDummy_BrkFace', 54.32938125591267), ('RoofStyleDummy_Gable', 53.455588311525865), ('PavedDriveDummy_Y', 53.31261726319119), ('MSSubClassDummy_50', 47.823089394535074), ('Exterior1stDummy_Wd Sdng', 46.071805901256134), ('GarageTypeDummy_BuiltIn', 45.731944844358225), ('NeighborhoodDummy_Edwards', 43.56712214193698), ('Fence', 42.099270019236016), ('Exterior2ndDummy_Wd Sdng', 41.24678534653109), ('OverallCond', 37.210801992333614), ('Exterior1stDummy_MetalSd', 36.38677666077166), ('NeighborhoodDummy_Somerst', 35.60233494923655), ('Exterior2ndDummy_MetalSd', 34.83793479404605), ('NeighborhoodDummy_Timber', 32.97137141998004), ('NeighborhoodDummy_StoneBr', 32.80224019077354), ('Exterior2ndDummy_CmentBd', 31.074329054919897), ('SaleConditionDummy_Normal', 28.724107509985444), ('NeighborhoodDummy_Sawyer', 27.7234100257982), ('Exterior1stDummy_CemntBd', 26.16891962751302), ('NeighborhoodDummy_BrkSide', 25.12724639405683), ('Exterior1stDummy_HdBoard', 24.1735661972239), ('NeighborhoodDummy_IDOTRR', 22.862162361432016), ('NumFloors', 22.8090038601442), ('MSSubClassDummy_160', 22.468431281703012), ('KitchenAbvGr', 22.18074943863651), ('BedroomAbvGr', 21.697617656772763), ('ExterCond', 21.448640657666846), ('FunctionalDummy_Typ', 20.67831772011433), ('Condition1Dummy_Norm', 19.54524434088495), ('EnclosedPorch', 19.477755500545022), ('MSSubClassDummy_90', 17.770737756071), ('BldgTypeDummy_Duplex', 17.770737756071), ('NeighborhoodDummy_BrDale', 17.25223067283076), ('Condition1Dummy_Feedr', 17.051545908710683), ('FoundationDummy_Slab', 16.366767730858236), ('MSZoningDummy_FV', 16.365924143160868), ('AlleyDummy_No_Alley_Access', 16.28624426150275), ('Exterior2ndDummy_HdBoard', 15.461448538297901), ('NeighborhoodDummy_MeadowV', 13.967829396638678), ('Electrica ...
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.03941507, 0.00552092, 0.00508437, 0.00482235, 0.00475864,
#         0.00471101, 0.00468507, 0.00482497]),
#  'std_fit_time': array([0.04876929, 0.00036659, 0.00039198, 0.00020051, 0.0001398 ,
#         0.00010558, 0.00034494, 0.00012299]),
#  'mean_score_time': array([0.00266294, 0.00300694, 0.00283446, 0.00254984, 0.00262995,
#         0.00237598, 0.00260577, 0.00257635]),
#  'std_score_time': array([2.95667393e-04, 1.99748218e-04, 1.02366799e-04, 1.08561527e-04,
#         7.88418771e-05, 3.48287083e-04, 1.44407407e-04, 7.53864316e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89180095, 0.8940651 , 0.89816948, 0.90303169, 0.90444826,
#         0.90541151, 0.89638464, 0.87463227]),
#  'split1_test_score': array([0.91022841, 0.91180547, 0.91402695, 0.91477626, 0.91438315,
#         0.91377563, 0.87971518, 0.84268622]),
#  'split2_test_score': array([0.86712302, 0.87230922, 0.88255894, 0.88974192, 0.89065686,
#         0.89099996, 0.87501377, 0.85149517]),
#  'split3_test_score': array([0.88074147, 0.88108149, 0.88245247, 0.88663881, 0.88810784,
#         0.88907535, 0.87968149, 0.85702733]),
#  'split4_test_score': array([0.89354149, 0.89368358, 0.89362293, 0.89577191, 0.89676529,
#         0.89745118, 0.88473241, 0.86132223]),
#  'mean_test_score': array([0.88868707, 0.89058897, 0.89416616, 0.89799211, 0.89887228,
#         0.89934273, 0.8831055 , 0.85743264]),
#  'std_test_score': array([0.01432084, 0.01338911, 0.01168512, 0.01008957, 0.00958629,
#         0.00920584, 0.00731679, 0.01061914]),
#  'rank_test_score': array([6, 5, 4, 3, 2, 1, 7, 8], dtype=int32)}

# %%
gridRidge.best_params_
# Out:
# {'alpha': 100}

# %%
gridRidge.best_score_
# Out:
# 0.8993427255751107

# %%
gridRidge.best_estimator_.coef_
# Out:
# array([ 1.48189197e+03,  4.88086630e+03, -1.70467743e+02,  9.29357031e+03,
#         4.42388170e+03,  4.79428733e+03,  1.49143451e+03,  2.83135092e+03,
#        -4.41092552e+03,  7.41833813e+02, -3.47765505e+03,  4.86064265e+02,
#        -1.98991962e+03,  5.99471013e+02,  7.97093215e+03, -1.07838390e+03,
#         3.88855458e+02, -1.11351898e+03,  7.27948464e+03, -8.13650924e+02,
#         7.11765891e+03,  6.20235466e+03, -2.80169898e+02,  1.13067855e+04,
#         1.22242304e+03, -3.97254453e+02,  1.73570669e+03,  1.39412453e+03,
#        -2.88161375e+03, -2.90690416e+03, -4.83015227e+03,  3.82634267e+03,
#         2.04692039e+03, -7.88781625e+02, -6.98344275e+02, -1.06827413e+03,
#         3.48845979e+03,  2.45468408e+03,  3.12507713e+02, -8.56696215e+01,
#         1.69744768e+03,  1.73722533e+03,  5.23568441e+02,  2.89498839e+02,
#         1.48180914e+03,  1.01760146e+03,  3.70984855e+02,  4.08508020e+02,
#         1.75165797e+02, -4.63484765e+02, -1.21781429e+02,  7.65257926e+02,
#         4.78064145e+01,  8.87095514e+02,  6.28130775e+02, -6.54591127e+01,
#         9.28156959e+02, -3.24968235e+02,  5.17065976e+01,  3.97387635e+02,
#         2.13144493e+03,  1.25141413e+03,  4.04592178e+02,  9.74490001e+02,
#        -2.36704305e+02,  2.09208414e+03,  2.98562969e+02,  1.89490252e+02,
#         6.58338867e+02,  1.03704317e+03, -1.13251724e+02,  2.09504650e+03,
#         2.97541937e+03])

# %%
getFeatureImportance(50, train.columns, gridRidge.best_estimator_.coef_,'descending')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 11306.785512164646),
#  ('OverallQual', 9293.570312153466),
#  ('BsmtFinSF1', 7970.932150400841),
#  ('TotalBsmtSF', 7279.484642892427),
#  ('1stFlrSF', 7117.658911118166),
#  ('2ndFlrSF', 6202.354656491235),
#  ('NeighborhoodDummy_NoRidge', 5563.213920334567),
#  ('LotArea', 4880.866303796294),
#  ('KitchenQual', -4830.152271164508),
#  ('YearBuilt', 4794.287331284027),
#  ('OverallCond', 4423.881704861817),
#  ('ExterQual', -4410.925515771605),
#  ('TotRmsAbvGrd', 3826.342673468963),
#  ('NeighborhoodDummy_Somerst', 3555.2167483928615),
#  ('GarageCars', 3488.4597859259716),
#  ('NeighborhoodDummy_NWAmes', 3483.483927064991),
#  ('BsmtQual', -3477.655048216855),
#  ('FunctionalDummy_Sev', 3011.5573411518203),
#  ('SaleConditionDummy_Normal', 2975.419372741441),
#  ('KitchenAbvGr', -2906.904161850229),
#  ('BedroomAbvGr', -2881.613753100368),
#  ('MasVnrArea', 2831.350920531061),
#  ('MSSubClassDummy_90', -2653.401097420889),
#  ('Exterior1stDummy_BrkComm', 2643.549760108432),
#  ('GarageArea', 2454.6840796483075),
#  ('NeighborhoodDummy_Mitchel', -2297.9702593692678),
#  ('Condition1Dummy_Feedr', 2221.2849172086158),
#  ('NeighborhoodDummy_CollgCr', 2198.1945554151757),
#  ('BldgTypeDummy_Twnhs', -2190.395911089678),
#  ('MiscFeatureDummy_Shed', 2131.4449323518525),
#  ('NeighborhoodDummy_Crawfor', -2130.233301043137),
#  ('SaleConditionDummy_Family', 2095.0464989515276),
#  ('SaleTypeDummy_ConLw', 2092.0841409233512),
#  ('BldgTypeDummy_Duplex', -2064.3996686284463),
#  ('Fireplaces', 2046.9203853457766),
#  ('BsmtExposure', -1989.9196206726006),
#  ('NeighborhoodDummy_NridgHt', -1932.691050941335),
#  ('Exterior2ndDummy_CBlock', 1876.2277498758606),
#  ('MSSubClassDummy_120', -1787.1747545832682),
#  ('MasVnrTypeDummy_None', 1776.1671933734044),
#  ('NeighborhoodDummy_NPkVill', -1744.6591309537064),
#  ('OpenPorchSF', 1737.2253313174715),
#  ('FullBath', 1735.7066899320591),
#  ('WoodDeckSF', 1697.4476763826176),
#  ('FunctionalDummy_Mod', -1673.861932644844),
#  ('NeighborhoodDummy_Blueste', 1598.7675793956844),
#  ('NeighborhoodDummy_Edwards', -1584.700005115021),
#  ('NeighborhoodDummy_ClearCr', -1524.0303041822706),
#  ('FoundationDummy_CBlock', 1523.4816276410534),
#  ('YearRemodAdd', 1491.4345119467741),
#  ('LotFrontage', 1481.8919672924424),
#  ('ScreenPorch', 1481.8091363357837),
#  ('Exterior1stDummy_VinylSd', -1475.1817638647665),
#  ('MSSubClassDummy_190', 1473.0846140443434),
#  ('HalfBath', 1394.124534621234),
#  ('Exterior2ndDummy_Wd Sdng', -1299.6743224429051),
#  ('FoundationDummy_PConc', 1289.3285511048293),
#  ('LotShapeDummy_Reg', 1264.2344619206326),
#  ('MasVnrTypeDummy_No_MasVnr', 1256.9894857075503),
#  ('SaleTypeDummy_CWD', 1251.4141288466274),
#  ('BsmtFullBath', 1222.4230412271968),
#  ('NeighborhoodDummy_MeadowV', -1214.7194111819297),
#  ('MSSubClassDummy_50', 1208.6123084532571),
#  ('Exterior1stDummy_Wd Sdng', 1201.6069765593863),
#  ('Condition1Dummy_PosN', -1164.2063379834726),
#  ('BsmtUnfSF', -1113.518984913523),
#  ('Exterior2ndDummy_CmentBd', -1097.7020074300735),
#  ('NeighborhoodDummy_BrDale', 1088.9498412269545),
#  ('FunctionalDummy_Min2', -1088.1640413477062),
#  ('BsmtFinType2', -1078.3838954598586),
#  ('GarageFinish', -1068.274125846891),
#  ('SaleConditionDummy_AdjLand', 1037.0431734587564),
#  ('LandContourDummy_Lvl', 1033.3287860700666),
#  ('Exterior2ndDummy_Other', -1032.4521781275296),
#  ('PoolArea', 1017.6014633135279),
#  ('LotConfigDummy_CulDSac', -1015.3224062248021),
#  ('NeighborhoodDummy_NAmes', 1011.9671762729051),
#  ('FoundationDummy_Stone', -1004.9528752667202),
#  ('NeighborhoodDummy_Timber', 994.8256780266568),
#  ('MSSubClassDummy_75', -982.7759406778553),
#  ('SaleTypeDummy_ConLD', 974.4900005527076),
#  ('hasBeenRemodeled', -958.2040485559352),
#  ('NumFloors', -956.0280746960353),
#  ('MSZoningDummy_RH', 946.8303678345122),
#  ('HouseStyleDummy_1Story', -945.3401584918247),
#  ('PavedDriveDummy_P', 928.1569587709834),
#  ('Exterior2ndDummy_VinylSd', 917.1919438857019),
#  ('LotConfigDummy_FR2', -913.4720106057049),
#  ('Exterior1stDummy_CBlock', -911.9900404198828),
#  ('GarageTypeDummy_CarPort', 887.0955144769392),
#  ('Exterior1stDummy_ImStucc', 876.3284938164287),
#  ('HouseStyleDummy_SFoyer', 853.1775862479589),
#  ('GarageTypeDummy_Basment', 830.1431357258595),
#  ('NeighborhoodDummy_OldTown', -818.4605886868452),
#  ('HeatingQC', -813.6509238941535),
#  ('FireplaceQu', -788.781625059308),
#  ('Condition2Dummy_Norm', -787.699297941034),
#  ('SalePrice', 765.2579257101387),
#  ('RoofMatlDummy_WdShake', 760.7664935707692),
#  ('MSZoningDummy_RM', 752.1266362780807),
#  ('ExterCond', 741.8338130209685),
#  ('GarageYrBlt', -698.3442751951272),
#  ('Condition1Dummy_PosA', 698.2722413825786),
#  ('RoofMatlDummy_Tar&Grv', -690.6960392684637),
#  ('MSSubClassDummy_80', -680.4056597656421),
#  ('SaleTypeDummy_WD', 658.3388669141175),
#  ('ElectricalDummy_SBrkr', -644.548022182307),
#  ('HouseStyleDummy_SLvl', -636.5380051634211),
#  ('Exterior1stDummy_MetalSd', -633.7354098701824),
#  ('GarageTypeDummy_Detchd', 628.1307753591495),
#  ('Exterior1stDummy_HdBoard', -626.8658332724127),
#  ('CentralAirDummy_Y', -600.7206855501572),
#  ('BsmtFinType1', 599.4710125747552),
#  ('MSSubClassDummy_60', 597.0725062223967),
#  ('MasVnrTypeDummy_Stone', 586.4362567876522),
#  ('Exterior1stDummy_Stone', 573.5300733775725),
#  ('HouseStyleDummy_2.5Unf', -569.8474198165671),
#  ('MSZoningDummy_RL', -544.3117088657302),
#  ('NeighborhoodDummy_BrkSide', 531.0745275102244),
#  ('MSSubClassDummy_70', 526.3017634924126),
#  ('EnclosedPorch', 523.5684407424118),
#  ('NeighborhoodDummy_Sawyer', -520.7154881059405),
#  ('Exterior2ndDummy_Stucco', 511.35736395771124),
#  ('HeatingDummy_GasW', -501.1490509464406),
#  ('FunctionalDummy_Min1', 500.60998876796054),
#  ('FoundationDummy_Slab', -499.13174733350814),
#  ('BsmtCond', 486.06426491127155),
#  ('MoSold', -463.4847647770076),
#  ('Exterior2ndDummy_Brk Cmn', -447.1288172611397),
#  ('NeighborhoodDummy_StoneBr', -443.4365434148197),
#  ('Condition2Dummy_RRNn', -439.8322867741243),
#  ('LotShapeDummy_IR2', -436.0882837337504),
#  ('LotShapeDummy_IR3', 422.46545319844756),
#  ('HouseStyleDummy_2.5Fin', -420.5373024157854),
#  ('Fence', 408.50801992121154),
#  ('SaleTypeDummy_Con', 404.59217777467273),
#  ('RoofStyleDummy_Gambrel', 400.7811458586392),
#  ('NeighborhoodDummy_IDOTRR', -397.7108678098946),
#  ('MiscFeatureDummy_Othr', 397.3876354607767),
#  ('BsmtHalfBath', -397.25445265678144),
#  ('BsmtFinSF2', 388.85545753255315),
#  ('HeatingDummy_GasA', -378.92584015111186),
#  ('LandContourDummy_HLS', -372.2666469401153),
#  ('LotConfigDummy_FR3', -371.2604916046599),
#  ('LotConfigDummy_Inside', 371.02791927314246),
#  ('PoolQC', 370.98485475680775),
#  ('RoofStyleDummy_Gable', 360.60457730569254),
#  ('StreetDummy_Pave', -360.5300610640183),
#  ('BldgTypeDummy_2fmCon', -356.380288834596),
#  ('MSSubClassDummy_85', -356.3802888345896),
#  ('Exterior1stDummy_Plywood', -355.83054434557897),
#  ('Condition1Dummy_RRAn', -335.88151723480286),
#  ('PavedDriveDummy_Y', -324.9682353422713),
#  ('GarageQual', 312.5077130877799),
#  ('Exterior2ndDummy_Plywood', 306.4113728625738),
#  ('Exterior1stDummy_WdShing', 299.7189501154421),
#  ('SaleTypeDummy_New', 298.56296885225134),
#  ('ElectricalDummy_FuseP', -296.0679568907127),
#  ('Exterior1stDummy_BrkFace', -291.357046844114),
#  ('Exterior2ndDummy_BrkFace', -291.3570468441138),
#  ('3SsnPorch', 289.4988386738631),
#  ('Condition1Dummy_RRAe', 285.97893184772846),
#  ('LowQualFinSF', -280.1698978094334),
#  ('FunctionalDummy_Typ', -277.65159396119026),
#  ('Exterior2ndDummy_AsphShn', 276.09791088240195),
#  ('RoofMatlDummy_WdShngl', -263.3657275756395),
#  ('Exterior2ndDummy_HdBoard', 261.55563560940055),
#  ('Condition2Dummy_RRAn', 260.58308732573363),
#  ('AlleyDummy_Pave', 259.7687765336396),
#  ('Condition1Dummy_RRNe', 258.42359057612464),
#  ('FunctionalDummy_Maj2', -255.74090834834797),
#  ('RoofMatlDummy_CompShg', -252.28083468011792),
#  ('NeighborhoodDummy_SawyerW', 251.08069515757674),
#  ('FoundationDummy_Wood', 239.31286163242225),
#  ('SaleTypeDummy_ConLI', -236.70430527319922),
#  ('MasVnrTypeDummy_BrkFace', 229.57948693519458),
#  ('Exterior1stDummy_AsphShn', -222.18033633560532),
#  ('BldgTypeDummy_TwnhsE', 206.08977106416603),
#  ('RoofMatlDummy_Roll', 201.68114391915597),
#  ('Exterior1stDummy_CemntBd', -201.6559874800462),
#  ('Condition1Dummy_RRNn', -193.9463615537808),
#  ('SaleTypeDummy_Oth', 189.49025199185076),
#  ('HouseStyleDummy_1.5Unf', -186.71333431922045),
#  ('LandContourDummy_Low', 183.56727076427927),
#  ('AlleyDummy_No_Alley_Access', -177.97763881830573),
#  ('HeatingDummy_Wall', -176.15955403463389),
#  ('MiscVal', 175.16579706633505),
#  ('MSSubClassDummy_160', 174.72948395050167),
#  ('LandSlope', -170.46774348790404),
#  ('GarageTypeDummy_Attchd', 159.8068986686537),
#  ('HouseStyleDummy_2Story', -149.12225928725096),
#  ('Exterior2ndDummy_Stone', 131.87441330631387),
#  ('ElectricalDummy_FuseF', 124.47912059097978),
#  ('YrSold', -121.7814288661937),
#  ('SaleConditionDummy_Alloca', -113.25172425537058),
#  ('Exterior2ndDummy_MetalSd', -107.33720097969034),
#  ('Condition2Dummy_Feedr', 107.02187431489888),
#  ('Exterior2ndDummy_Wd Shng', 95.89812284126927),
#  ('NeighborhoodDummy_Veenker', -94.04124067311369),
#  ('RoofStyleDummy_Mansard', -90.78086472666645),
#  ('GarageCond', -85.6696214951296),
#  ('Exterior1stDummy_Stucco', -79.0480359493966),
#  ('MSSubClassDummy_180', -73.23220817074241),
#  ('GarageTypeDummy_No_Garage', -65.45911269857424),
#  ('MSSubClassDummy_30', 56.55394059378538),
#  ('MiscFeatureDummy_No_Misc_Feature', 51.706597600618196),
#  ('NeighborhoodDummy_Gilbert', -50.895806333452796),
#  ('GarageTypeDummy_BuiltIn', 47.80641454735354),
#  ('HeatingDummy_Grav', -36.3799061034474),
#  ('Condition2Dummy_PosN', -36.37620493539034),
#  ('MSSubClassDummy_45', 26.919973424572603),
#  ('MSZoningDummy_FV', 20.997340999871717),
#  ('RoofStyleDummy_Hip', -20.696919290578755),
#  ('MSSubClassDummy_40', 20.39038953553099),
#  ('Condition1Dummy_Norm', 8.910386256529799),
#  ('NeighborhoodDummy_SWISU', 7.899176684936452),
#  ('Exterior2ndDummy_ImStucc', -1.0524361111270735)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159589472779.28473, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156769962769.67047, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162181397792.76932, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157518895144.02463, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161086769713.59756, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92897809603.9739, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129979235621.10622, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123339118982.41034, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110224948251.84155, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125534429133.26016, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5327772378.962463, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.12347088, 0.11895084, 0.12622108, 0.085987  , 0.06406417,
#         0.04961147, 0.01315675, 0.00945458]),
#  'std_fit_time': array([0.00413733, 0.00333786, 0.00722092, 0.00730128, 0.00375005,
#         0.00264999, 0.00496392, 0.00140773]),
#  'mean_score_time': array([0.00267911, 0.0023757 , 0.00233192, 0.00284705, 0.00309186,
#         0.00294952, 0.00285926, 0.00279469]),
#  'std_score_time': array([2.24575014e-04, 9.78493318e-05, 2.57362421e-04, 4.58255211e-04,
#         3.04086215e-04, 8.38451943e-05, 1.36349799e-04, 2.03854516e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89207396, 0.89267806, 0.89545354, 0.89892798, 0.90047107,
#         0.90176074, 0.90664802, 0.89490171]),
#  'split1_test_score': array([0.90990435, 0.9110438 , 0.9131831 , 0.91505103, 0.91594606,
#         0.91661301, 0.91236808, 0.89977778]),
#  'split2_test_score': array([0.8682172 , 0.86941371, 0.87521258, 0.88784688, 0.89239401,
#         0.89538723, 0.88669325, 0.87214211]),
#  'split3_test_score': array([0.88084919, 0.8809504 , 0.88140127, 0.88414123, 0.88595982,
#         0.88725938, 0.8906111 , 0.87686727]),
#  'split4_test_score': array([0.8936972 , 0.89373017, 0.89369748, 0.89455674, 0.89610313,
#         0.89780688, 0.90639592, 0.89826196]),
#  'mean_test_score': array([0.88894838, 0.88956323, 0.8917896 , 0.89610477, 0.89817482,
#         0.89976545, 0.90054328, 0.88839017]),
#  'std_test_score': array([0.01390577, 0.0139188 , 0.01309551, 0.01077633, 0.01007974,
#         0.00966673, 0.01001817, 0.01154389]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 2, 1, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9005432757509931

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [
#  ('LandSlope', 0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinSF2', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', 0.0),
#  ('SalePrice', 0.0),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -0.0),
#  ('MSSubClassDummy_30', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', 0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', 0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_PosN', -0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', -0.0),
#  ('Condition2Dummy_PosN', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_2fmCon', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', -0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_CmentBd', -0.0),
#  ('Exterior2ndDummy_HdBoard', -0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Sdng', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_CBlock', 0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('SaleTypeDummy_Con', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Family', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-26-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType','MSSubClass']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8956097224273535

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178139926615.62665, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184127476634.30902, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185798487952.75696, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188017096046.5701, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187953770239.41666, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66023237450.1196, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136892083913.04944, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137943586597.90576, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138918781923.70514, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111298808606.48709, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2276681445.9937134, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8951788792880283

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X_Scaled.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999203
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998807
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998355
# PoolArea                  PoolQC                       0.998140
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996496
# GarageCars                GarageArea                   0.990057
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.985321
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.984601
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.983732
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.971213
# ExterQual                 KitchenQual                  0.970624
# 2ndFlrSF                  NumFloors                    0.966384
# GrLivArea                 TotRmsAbvGrd                 0.965300
# TotalBsmtSF               1stFlrSF                     0.962926
# 2ndFlrSF                  HouseStyleDummy_2Story       0.961402
# OverallQual               ExterQual                    0.960195
# ExterQual                 BsmtQual                     0.955945
# NumFloors                 HouseStyleDummy_1Story       0.951910
# BsmtQual                  FoundationDummy_PConc        0.951569
# OverallQual               BsmtQual                     0.951254
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.949141
# OverallQual               KitchenQual                  0.949072
# MasVnrArea                MasVnrTypeDummy_None         0.944779
# YearRemodAdd              FoundationDummy_PConc        0.941272
#                           BsmtQual                     0.938971
# OverallQual               GarageCars                   0.938230
# FoundationDummy_CBlock    FoundationDummy_PConc        0.931655
# HalfBath                  HouseStyleDummy_2Story       0.930275
# YearBuilt                 BsmtQual                     0.927973
# BsmtQual                  KitchenQual                  0.927819
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.924384
# OverallQual               GarageArea                   0.919828
# ExterQual                 FoundationDummy_PConc        0.919029
# YearRemodAdd              ExterQual                    0.918366
# BsmtFinSF1                BsmtFullBath                 0.917320
# OverallQual               FullBath                     0.915608
# NumFloors                 HouseStyleDummy_2Story       0.914810
# OverallQual               YearRemodAdd                 0.911389
# 2ndFlrSF                  HouseStyleDummy_1Story       0.909999
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.907726
# YearBuilt                 YearRemodAdd                 0.907500
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.906980
# OverallQual               FoundationDummy_PConc        0.906935
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.906791
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.905938
# BsmtQual                  GarageCars                   0.903797
# YearRemodAdd              KitchenQual                  0.901390
# YearBuilt                 FoundationDummy_PConc        0.900495
# OverallQual               YearBuilt                    0.896856
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.5899690938754105),
#  ('LotArea', 1.6858461305263441),
#  ('OverallQual', 4.6016591700121),
#  ('OverallCond', 2.0976627841092585),
#  ('YearBuilt', 12.472650015993821),
#  ('YearRemodAdd', 3.541889332711096),
#  ('MasVnrArea', 2.6569996113576173),
#  ('ExterQual', 3.2812958154062692),
#  ('BsmtQual', 3.0919510004379096),
#  ('BsmtExposure', 1.7849487318630421),
#  ('BsmtFinType1', 2.1863694847598696),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.427698607735494),
#  ('BsmtHalfBath', 1.2359634349661195),
#  ('FullBath', 3.7400855585486554),
#  ('HalfBath', 2.8539308122769578),
#  ('BedroomAbvGr', 2.9011424934170775),
#  ('KitchenAbvGr', 1.8540417338102886),
#  ('KitchenQual', 2.436342215214369),
#  ('TotRmsAbvGrd', 5.1986203335170735),
#  ('Fireplaces', 1.854277635866552),
#  ('FireplaceQu', 1.416899420146764),
#  ('GarageYrBlt', 1466.8134468490032),
#  ('GarageFinish', 2.1409087495252925),
#  ('GarageCars', 6.764719200778878),
#  ('GarageArea', 6.500739731354169),
#  ('WoodDeckSF', 1.3589274201191388),
#  ('OpenPorchSF', 1.4272625896631836),
#  ('EnclosedPorch', 1.461231670027362),
#  ('3SsnPorch', 1.115313247615099),
#  ('ScreenPorch', 1.1820398967710906),
#  ('PoolArea', 16.07515760456125),
#  ('PoolQC', 16.01826868523735),
#  ('Fence', 1.3250238587850938),
#  ('MiscVal', 1.0658078468850989),
#  ('MoSold', 1.1530582808644663),
#  ('YrSold', 1.1815850563651578),
#  ('hasBeenRemodeled', 1.8971443319925994),
#  ('NumFloors', 22.31394262095415),
#  ('MSZoningDummy_FV', 27.90240280540118),
#  ('MSZoningDummy_RH', 5.408780177961572),
#  ('MSZoningDummy_RL', 82.91630246871782),
#  ('MSZoningDummy_RM', 58.54939920401884),
#  ('AlleyDummy_No_Alley_Access', 2.5965812926656957),
#  ('AlleyDummy_Pave', 2.6313745354330997),
#  ('LotShapeDummy_IR2', 1.1713191311785638),
#  ('LotShapeDummy_IR3', 1.2454962296398366),
#  ('LotShapeDummy_Reg', 1.529550302030243),
#  ('LotConfigDummy_CulDSac', 1.6936607307117086),
#  ('LotConfigDummy_FR2', 1.3492868069015458),
#  ('LotConfigDummy_FR3', 1.098602795771447),
#  ('LotConfigDummy_Inside', 1.6723701625404002),
#  ('NeighborhoodDummy_Blueste', 1.3133064477892695),
#  ('NeighborhoodDummy_BrDale', 3.1168613895607593),
#  ('NeighborhoodDummy_BrkSide', 6.702801744300412),
#  ('FoundationDummy_PConc', 8.408904579389793),
#  ('FoundationDummy_Slab', 2.666243857567744),
#  ('FoundationDummy_Stone', 1.247901970519317),
#  ('FoundationDummy_Wood', 1.2699946667025879),
#  ('GarageTypeDummy_Attchd', 91.51112402165143),
#  ('GarageTypeDummy_Basment', 5.466374343932593),
#  ('GarageTypeDummy_BuiltIn', 21.6150051354829),
#  ('GarageTypeDummy_CarPort', 2.6750180870636333),
#  ('GarageTypeDummy_Detchd', 75.06372710447822),
#  ('GarageTypeDummy_No_Garage', 1424.3660460281508),
#  ('SaleConditionDummy_AdjLand', 1.0746441514995726),
#  ('SaleConditionDummy_Alloca', 1.3566666795247921),
#  ('SaleConditionDummy_Family', 1.352731100937552),
#  ('SaleConditionDummy_Normal', 2.80322121782968),
#  ('SaleConditionDummy_Partial', 2.8866156061761306),
#  ('constant', 115741.55954369136)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual','GarageArea','PoolArea','PoolQC'], axis=1)

# %%
X_Scaled = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.5899690938754105),
#  ('LotArea', 1.6858461305263441),
#  ('OverallQual', 4.6016591700121),
#  ('OverallCond', 2.0976627841092585),
#  ('YearBuilt', 12.472650015993821),
#  ('YearRemodAdd', 3.541889332711096),
#  ('MasVnrArea', 2.6569996113576173),
#  ('ExterQual', 3.2812958154062692),
#  ('BsmtQual', 3.0919510004379096),
#  ('BsmtExposure', 1.7849487318630421),
#  ('BsmtFinType1', 2.1863694847598696),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.427698607735494),
#  ('BsmtHalfBath', 1.2359634349661195),
#  ('FullBath', 3.7400855585486554),
#  ('HalfBath', 2.8539308122769578),
#  ('BedroomAbvGr', 2.9011424934170775),
#  ('KitchenAbvGr', 1.8540417338102886),
#  ('KitchenQual', 2.436342215214369),
#  ('TotRmsAbvGrd', 5.1986203335170735),
#  ('Fireplaces', 1.854277635866552),
#  ('FireplaceQu', 1.416899420146764),
#  ('GarageYrBlt', 1466.8134468490032),
#  ('GarageFinish', 2.1409087495252925),
#  ('GarageCars', 6.764719200778878),
#  ('GarageArea', 6.500739731354169),
#  ('WoodDeckSF', 1.3589274201191388),
#  ('OpenPorchSF', 1.4272625896631836),
#  ('EnclosedPorch', 1.461231670027362),
#  ('3SsnPorch', 1.115313247615099),
#  ('ScreenPorch', 1.1820398967710906),
#  ('PoolArea', 16.07515760456125),
#  ('PoolQC', 16.01826868523735),
#  ('Fence', 1.3250238587850938),
#  ('MiscVal', 1.0658078468850989),
#  ('MoSold', 1.1530582808644663),
#  ('YrSold', 1.1815850563651578),
#  ('hasBeenRemodeled', 1.8971443319925994),
#  ('NumFloors', 22.31394262095415),
#  ('MSZoningDummy_FV', 27.90240280540118),
#  ('MSZoningDummy_RH', 5.408780177961572),
#  ('MSZoningDummy_RL', 82.91630246871782),
#  ('MSZoningDummy_RM', 58.54939920401884),
#  ('AlleyDummy_No_Alley_Access', 2.5965812926656957),
#  ('AlleyDummy_Pave', 2.6313745354330997),
#  ('LotShapeDummy_IR2', 1.1713191311785638),
#  ('LotShapeDummy_IR3', 1.2454962296398366),
#  ('LotShapeDummy_Reg', 1.529550302030243),
#  ('LotConfigDummy_CulDSac', 1.6936607307117086),
#  ('LotConfigDummy_FR2', 1.3492868069015458),
#  ('LotConfigDummy_FR3', 1.098602795771447),
#  ('LotConfigDummy_Inside', 1.6723701625404002),
#  ('NeighborhoodDummy_Blueste', 1.3133064477892695),
#  ('NeighborhoodDummy_BrDale', 3.1168613895607593),
#  ('NeighborhoodDummy_BrkSide', 6.702801744300412),
#  ('NeighborhoodDummy_ClearCr', 2.30071571881878),
#  ('NeighborhoodDummy_CollgCr', 11.171417873133725),
#  ('NeighborhoodDummy_Crawfor', 5.469138450887968),
#  ('NeighborhoodDummy_Edwards', 8.336642692926409),
#  ('NeighborhoodDummy_Gilbert', 6.561758394682443),
#  ('NeighborhoodDummy_IDOTRR', 4.677968615151572),
#  ('NeighborhoodDummy_MeadowV', 3.135890456454532),
#  ('NeighborhoodDummy_Mitchel', 5.053210148681753),
#  ('NeighborhoodDummy_NAmes', 18.569524517424636),
#  ('NeighborhoodDummy_NPkVill', 2.02101998542464),
#  ('NeighborhoodDummy_NWAmes', 6.829189865824943),
#  ('NeighborhoodDummy_NoRidge', 4.407106907794436),
#  ('NeighborhoodDummy_NridgHt', 6.9079189235990786),
#  ('NeighborhoodDummy_OldTown', 12.49552057866668),
#  ('NeighborhoodDummy_SWISU', 3.3808379518464253),
#  ('NeighborhoodDummy_Sawyer', 7.073699529054146),
#  ('NeighborhoodDummy_SawyerW', 5.385435588436467),
#  ('NeighborhoodDummy_Somerst', 10.506665090668026),
#  ('NeighborhoodDummy_StoneBr', 2.6270722665207695),
#  ('NeighborhoodDummy_Timber', 3.773362957672512),
#  ('NeighborhoodDummy_Veenker', 1.9942625620614567),
#  ('HouseStyleDummy_1.5Unf', 1.7466331815491387),
#  ('HouseStyleDummy_1Story', 22.277586871264006),
#  ('HouseStyleDummy_2.5Fin', 1.7310928189210055),
#  ('HouseStyleDummy_2.5Unf', 1.2167603713869222),
#  ('HouseStyleDummy_2Story', 6.180368158814281),
#  ('HouseStyleDummy_SFoyer', 2.69335371573081),
#  ('HouseStyleDummy_SLvl', 3.483309511617248),
#  ('RoofStyleDummy_Gable', 53.93247916827116),
#  ('RoofStyleDummy_Gambrel', 3.128063928221388),
#  ('RoofStyleDummy_Hip', 51.684657589291035),
#  ('RoofStyleDummy_Mansard', 2.402619089297801),
#  ('Exterior1stDummy_AsphShn', 1.2389614430646516),
#  ('Exterior1stDummy_BrkComm', 1.1269134523166655),
#  ('Exterior1stDummy_BrkFace', 4.630952660595176),
#  ('Exterior1stDummy_CBlock', 1.200444314972949),
#  ('Exterior1stDummy_CemntBd', 5.393197968344239),
#  ('Exterior1stDummy_HdBoard', 15.418251799277488),
#  ('Exterior1stDummy_ImStucc', 1.180896360846706),
#  ('Exterior1stDummy_MetalSd', 13.970343215505942),
#  ('Exterior1stDummy_Plywood', 8.432109611789192),
#  ('Exterior1stDummy_Stone', 1.3755626983583593),
#  ('Exterior1stDummy_Stucco', 2.308296647014553),
#  ('Exterior1stDummy_VinylSd', 26.191521725436782),
#  ('Exterior1stDummy_Wd Sdng', 12.469425210928831),
#  ('Exterior1stDummy_WdShing', 2.7276826414945448),
#  ('MasVnrTypeDummy_BrkFace', 25.777408058148783),
#  ('MasVnrTypeDummy_No_MasVnr', 1.6165099950084127),
#  ('MasVnrTypeDummy_None', 29.33924808080957),
#  ('MasVnrTypeDummy_Stone', 10.627806164795281),
#  ('FoundationDummy_CBlock', 6.96513053639141),
#  ('FoundationDummy_PConc', 8.408904579389793),
#  ('FoundationDummy_Slab', 2.666243857567744),
#  ('FoundationDummy_Stone', 1.247901970519317),
#  ('FoundationDummy_Wood', 1.2699946667025879),
#  ('GarageTypeDummy_Attchd', 91.51112402165143),
#  ('GarageTypeDummy_Basment', 5.466374343932593),
#  ('GarageTypeDummy_BuiltIn', 21.6150051354829),
#  ('GarageTypeDummy_CarPort', 2.6750180870636333),
#  ('GarageTypeDummy_Detchd', 75.06372710447822),
#  ('GarageTypeDummy_No_Garage', 1424.3660460281508),
#  ('SaleConditionDummy_AdjLand', 1.0746441514995726),
#  ('SaleConditionDummy_Alloca', 1.3566666795247921),
#  ('SaleConditionDummy_Family', 1.352731100937552),
#  ('SaleConditionDummy_Normal', 2.80322121782968),
#  ('SaleConditionDummy_Partial', 2.8866156061761306),
#  ('constant', 115741.55954369136)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X_Scaled.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# GarageYrBlt                 GarageTypeDummy_No_Garage     0.996557
# RoofStyleDummy_Gable        RoofStyleDummy_Hip            0.985332
# MSZoningDummy_FV            NeighborhoodDummy_Somerst     0.973223
# 2ndFlrSF                    NumFloors                     0.967457
# ExterQual                   KitchenQual                   0.966191
# 2ndFlrSF                    HouseStyleDummy_2Story        0.961524
# NumFloors                   HouseStyleDummy_1Story        0.953757
# ExterQual                   BsmtQual                      0.951109
# BsmtQual                    FoundationDummy_PConc         0.947113
# MasVnrArea                  MasVnrTypeDummy_None          0.940653
# YearRemodAdd                FoundationDummy_PConc         0.933668
#                             BsmtQual                      0.931509
# HalfBath                    HouseStyleDummy_2Story        0.927942
# FoundationDummy_CBlock      FoundationDummy_PConc         0.927717
# YearBuilt                   BsmtQual                      0.922194
# Exterior1stDummy_VinylSd    FoundationDummy_PConc         0.921959
# BsmtQual                    KitchenQual                   0.917778
# BsmtFinSF1                  BsmtFullBath                  0.916362
# NumFloors                   HouseStyleDummy_2Story        0.914577
# 2ndFlrSF                    HouseStyleDummy_1Story        0.914155
# YearRemodAdd                ExterQual                     0.912820
# ExterQual                   FoundationDummy_PConc         0.911664
# GarageTypeDummy_Attchd      GarageTypeDummy_Detchd        0.900943
# BsmtQual                    GarageCars                    0.897962
# YearBuilt                   YearRemodAdd                  0.896415
# YearRemodAdd                KitchenQual                   0.893909
# YearBuilt                   FoundationDummy_PConc         0.892837
# ExterQual                   GarageCars                    0.889220
# YearRemodAdd                Exterior1stDummy_VinylSd      0.889121
# MasVnrTypeDummy_BrkFace     MasVnrTypeDummy_None          0.888327
# YearBuilt                   GarageCars                    0.887167
# BsmtQual                    FullBath                      0.882763
# YearBuilt                   ExterQual                     0.882705
# 2ndFlrSF                    HalfBath                      0.881933
# MSZoningDummy_RL            MSZoningDummy_RM              0.878976
# KitchenQual                 FoundationDummy_PConc         0.876943
# FullBath                    FoundationDummy_PConc         0.871753
#                             GarageCars                    0.870975
# BsmtQual                    Exterior1stDummy_VinylSd      0.870606
# SaleConditionDummy_Normal   SaleConditionDummy_Partial    0.867965
# BsmtQual                    GarageFinish                  0.866974
# KitchenQual                 GarageCars                    0.861761
# AlleyDummy_No_Alley_Access  AlleyDummy_Pave               0.856440
# YearBuilt                   GarageFinish                  0.856238
#                             Exterior1stDummy_VinylSd      0.853536
# MasVnrArea                  MasVnrTypeDummy_BrkFace       0.848093
# YearBuilt                   FullBath                      0.847382
# ExterQual                   FullBath                      0.844384
# GarageCars                  FoundationDummy_PConc         0.844004
# YearRemodAdd                FullBath                      0.843861
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94297449252.1677, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 194259913661.36127, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201145990330.24347, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209634331674.47574, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193808301498.46814, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7996231583.25647, tolerance: 533245741.1815748
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116042558645.68112, tolerance: 475483646.72209007
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131110511167.54141, tolerance: 534785756.6046795
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162312498746.9823, tolerance: 529585769.393642
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85459735932.67468, tolerance: 525812604.512143
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 3124.7263071022835),
#  ('LotArea', 4912.054843122572),
#  ('OverallCond', 6934.48843963933),
#  ('YearBuilt', 10263.883331590067),
#  ('YearRemodAdd', 0.0),
#  ('MasVnrArea', 2631.3916034387325),
#  ('ExterQual', -5481.301358309019),
#  ('BsmtQual', -3520.962659194225),
#  ('BsmtExposure', -2078.549608268544),
#  ('BsmtFinType1', 1176.5753575033618),
#  ('BsmtFinSF1', 21087.549751532213),
#  ('BsmtFinSF2', 5124.482683381492),
#  ('BsmtUnfSF', 11365.253078650408),
#  ('1stFlrSF', 16964.41961620676),
#  ('2ndFlrSF', 23732.464984257138),
#  ('LowQualFinSF', 766.234625747991),
#  ('BsmtFullBath', 393.34132403678524),
#  ('BsmtHalfBath', -589.6150226220308),
#  ('FullBath', -0.0),
#  ('HalfBath', 273.9421909713313),
#  ('BedroomAbvGr', -3260.913410044345),
#  ('KitchenAbvGr', -4733.319412327302),
#  ('KitchenQual', -6164.623366902659),
#  ('TotRmsAbvGrd', 4760.679910388638),
#  ('Fireplaces', 2223.2557184508405),
#  ('FireplaceQu', -1457.1256612118755),
#  ('GarageYrBlt', -810.6133537318857),
#  ('GarageFinish', -1617.1420835083964),
#  ('GarageCars', 6099.181180440214),
#  ('WoodDeckSF', 1548.2827536787192),
#  ('OpenPorchSF', 1552.3753206955805),
#  ('EnclosedPorch', 836.4141548176789),
#  ('3SsnPorch', 155.15352705363273),
#  ('ScreenPorch', 1439.4391199206925),
#  ('Fence', 0.0),
#  ('MiscVal', 514.8276328802888),
#  ('MoSold', 0.0),
#  ('YrSold', 18.895316037267317),
#  ('hasBeenRemodeled', 352.0175254321397),
#  ('NumFloors', -2227.6534925700767),
#  ('MSZoningDummy_FV', 1802.2551395304517),
#  ('MSZoningDummy_RH', 53.58630833157139),
#  ('MSZoningDummy_RL', 861.8627272889481),
#  ('MSZoningDummy_RM', -1544.1933016824037),
#  ('AlleyDummy_No_Alley_Access', -358.7123351464013),
#  ('AlleyDummy_Pave', -882.8341276508239),
#  ('LotShapeDummy_IR2', 157.86009937934443),
#  ('LotShapeDummy_IR3', -779.6996756306352),
#  ('LotShapeDummy_Reg', 365.97323769605197),
#  ('LotConfigDummy_CulDSac', 1389.6295020242449),
#  ('LotConfigDummy_FR2', -865.3993255013554),
#  ('LotConfigDummy_FR3', -940.4393552946999),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrDale', 1161.174341861246),
#  ('NeighborhoodDummy_BrkSide', 2310.259355529244),
#  ('NeighborhoodDummy_ClearCr', 496.64783991456187),
#  ('NeighborhoodDummy_CollgCr', 601.5884425324738),
#  ('NeighborhoodDummy_Crawfor', 3569.348077111037),
#  ('NeighborhoodDummy_Edwards', -1683.2116486207894),
#  ('NeighborhoodDummy_Gilbert', -2.7913274080208614),
#  ('NeighborhoodDummy_IDOTRR', 1176.476916094966),
#  ('NeighborhoodDummy_MeadowV', -919.1828633722677),
#  ('NeighborhoodDummy_Mitchel', -627.5924454718868),
#  ('NeighborhoodDummy_NAmes', -949.3082691105749),
#  ('NeighborhoodDummy_NPkVill', 756.456253101673),
#  ('NeighborhoodDummy_NWAmes', -659.8667877349849),
#  ('NeighborhoodDummy_NoRidge', 4344.685922769289),
#  ('NeighborhoodDummy_NridgHt', 6557.140201713558),
#  ('NeighborhoodDummy_OldTown', 0.0),
#  ('NeighborhoodDummy_SWISU', -11.472164867732392),
#  ('NeighborhoodDummy_Sawyer', 0.0),
#  ('NeighborhoodDummy_SawyerW', -160.57657974893328),
#  ('NeighborhoodDummy_Somerst', 1995.8508918879945),
#  ('NeighborhoodDummy_StoneBr', 3862.2561692660015),
#  ('NeighborhoodDummy_Timber', 570.3985466626631),
#  ('NeighborhoodDummy_Veenker', 1179.7625095479518),
#  ('HouseStyleDummy_1.5Unf', 843.4152065119513),
#  ('HouseStyleDummy_1Story', -0.0),
#  ('HouseStyleDummy_2.5Fin', -950.9194791710042),
#  ('HouseStyleDummy_2.5Unf', 183.5348015145203),
#  ('HouseStyleDummy_2Story', -357.50727777589873),
#  ('HouseStyleDummy_SFoyer', -85.27481110713627),
#  ('HouseStyleDummy_SLvl', 922.0079199205526),
#  ('RoofStyleDummy_Gable', -0.0),
#  ('RoofStyleDummy_Gambrel', 561.7604001885718),
#  ('RoofStyleDummy_Hip', 974.8262121232598),
#  ('RoofStyleDummy_Mansard', -289.7865106746652),
#  ('Exterior1stDummy_AsphShn', 353.53060363682596),
#  ('Exterior1stDummy_BrkComm', -724.1476935745854),
#  ('Exterior1stDummy_BrkFace', 2164.654234998127),
#  ('Exterior1stDummy_CBlock', -1007.2363537962274),
#  ('Exterior1stDummy_CemntBd', 299.6439389290401),
#  ('Exterior1stDummy_HdBoard', -1073.7136103519586),
#  ('Exterior1stDummy_ImStucc', -389.84736596059076),
#  ('Exterior1stDummy_MetalSd', 117.6130309281309),
#  ('Exterior1stDummy_Plywood', -1819.5062208684512),
#  ('Exterior1stDummy_Stone', -558.5248297759042),
#  ('Exterior1stDummy_Stucco', 987.5901684770206),
#  ('Exterior1stDummy_VinylSd', 0.0),
#  ('Exterior1stDummy_Wd Sdng', -300.0121524559002),
#  ('Exterior1stDummy_WdShing', 415.4823816020934),
#  ('MasVnrTypeDummy_BrkFace', 212.31186234174785),
#  ('MasVnrTypeDummy_No_MasVnr', 405.177802945178),
#  ('MasVnrTypeDummy_None', 1949.9129353378719),
#  ('MasVnrTypeDummy_Stone', 1687.9637431346198),
#  ('FoundationDummy_CBlock', -0.0),
#  ('FoundationDummy_PConc', 1296.3485063851176),
#  ('FoundationDummy_Slab', 1800.8134966402934),
#  ('FoundationDummy_Stone', -224.07409207136013),
#  ('FoundationDummy_Wood', -1061.6228439720312),
#  ('GarageTypeDummy_Attchd', -207.60197232655386),
#  ('GarageTypeDummy_Basment', 160.37390754594227),
#  ('GarageTypeDummy_BuiltIn', 276.8776683653486),
#  ('GarageTypeDummy_CarPort', -1005.599511814403),
#  ('GarageTypeDummy_Detchd', 0.0),
