# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2415.5025140356533), ('GrLivArea', 1539.864755765523), ('GarageCars', 1044.6449237272918), ('ExterQual', 1024.2928265601133), ('GarageArea', 975.8366693493304), ('TotalBsmtSF', 908.9320227177525), ('1stFlrSF', 833.0989335661669), ('KitchenQual', 823.6652674315948), ('BsmtQual', 763.5043687020593), ('FullBath', 674.237210105872), ('YearBuilt', 641.1971670798466), ('TotRmsAbvGrd', 571.1025400502213), ('YearRemodAdd', 516.2252643801128), ('Fireplaces', 351.8534090780861), ('GarageFinish', 323.95742366427135), ('HeatingQC', 293.3192673469972), ('MasVnrArea', 288.8711847286976), ('NeighborhoodDummy_NridgHt', 242.4017313970033), ('BsmtFinSF1', 226.07043878126666), ('MSSubClassDummy_60', 204.84214926514895), ('LotFrontage', 191.41011871315087), ('OpenPorchSF', 169.3630660681323), ('MSZoningDummy_RM', 153.85886709193295), ('WoodDeckSF', 149.2734636986968), ('LotArea', 147.95582222162435), ('NeighborhoodDummy_NoRidge', 144.3439552857044), ('BsmtExposure', 137.54897532634558), ('2ndFlrSF', 108.95123028034119), ('HalfBath', 96.19240032718054), ('LotShapeDummy_Reg', 88.63216609009532), ('MSSubClassDummy_30', 87.63655835783979), ('BsmtFullBath', 87.44102163604379), ('MSZoningDummy_RL', 86.45133733704292), ('GarageYrBlt', 85.31955450122206), ('GarageCond', 75.12804040420093), ('GarageQual', 66.5677351061228), ('BsmtUnfSF', 66.30096096235404), ('NeighborhoodDummy_OldTown', 64.43898686400999), ('NeighborhoodDummy_NAmes', 60.348102142341716), ('NeighborhoodDummy_Edwards', 46.80135283757849), ('NeighborhoodDummy_StoneBr', 46.00465715131498), ('NeighborhoodDummy_Somerst', 43.7948910219364), ('Fence', 42.92232928360393), ('MSSubClassDummy_50', 41.3977264072572), ('BedroomAbvGr', 34.64507796312642), ('NeighborhoodDummy_IDOTRR', 32.04608189448962), ('OverallCond', 29.44064285403503), ('NeighborhoodDummy_Timber', 29.426215497253047), ('NeighborhoodDummy_Sawyer', 28.91019321037672), ('NeighborhoodDummy_BrkSide', 28.325361041721756), ('ExterCond', 24.025080074148548), ('EnclosedPorch', 22.083485635246348), ('MSSubClassDummy_160', 21.54795869644923), ('LotConfigDummy_CulDSac', 21.46259891676117), ('MSZoningDummy_FV', 18.440925854366032), ('Condition1Dummy_Norm', 18.340220564941724), ('KitchenAbvGr', 17.975253805510377), ('NeighborhoodDummy_BrDale', 17.11709726792103), ('Condition1Dummy_Feedr', 17.056892319911935), ('AlleyDummy_No_Alley_Access', 15.740677870663246), ('NeighborhoodDummy_MeadowV', 15.639638776112527), ('MSSubClassDummy_90', 15.01578026075299), ('LandContourDummy_HLS', 14.898554718778406), ('NeighborhoodDummy_CollgCr', 13.22391728232226), ('BsmtFinType1', 11.4205953360633), ('MSSubClassDummy_45', 10.756087665113565), ('LotShapeDummy_IR2', 10.221442473995891), ('MSSubClassDummy_190', 9.752941045186928), ('BsmtCond', 9.161229530091559), ('FireplaceQu', 8.284747491063216), ('MSZoningDummy_RH', 8.196566952495395), ('LowQualFinSF', 7.372000365873076), ('NeighborhoodDummy_SWISU', 7.354229152563738), ('NeighborhoodDummy_Crawfor', 5.755971625305224), ('BsmtFinType2', 5.718385537877155), ('LotConfigDummy_Inside', 5.6975955688664), ('NeighborhoodDummy_Mitchel', 5.518205784355076), ('BsmtHalfBath', 5.473220579645169), ('ScreenPorch', 5.116539088200384), ('MSSubClassDummy_180', 5.086705307565591), ('MSSubClassDummy_120', 4.7667755626401815), ('NeighborhoodDummy_ClearCr', 4.46676792236), ('NeighborhoodDummy_Veenker', 4.272632102677647), ('MSSubClassDummy_85', 4.052512365993944), ('MoSold', 3.7589903103360824), ('Condition1Dummy_PosA', 3.676169724603336), ('NeighborhoodDummy_Gilbert', 2.9595121036927496), ('3SsnPorch', 2.5081033147329856), ('NeighborhoodDummy_NPkVill', 2.44821542739212), ('Condition1Dummy_PosN', 2.3606931064234455), ('MSSubClassDummy_70', 1.9704878628018971), ('MSSubClassDummy_80', 1.594844812660489), ('LandSlope', 1.5114118534592034), ('MSSubClassDummy_75', 1.2678941905627246), ('NeighborhoodDummy_NWAmes', 1.0246172406083582), ('LandContourDummy_Low', 0.9556594168205961), ('MiscVal', 0.8832649984639912), ('LotConfigDum ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.28433347, 0.21703839]),
#  'std_fit_time': array([0.03854879, 0.00283824]),
#  'mean_score_time': array([0.00982471, 0.01095099]),
#  'std_score_time': array([0.00027205, 0.00070976]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.8719031 , 0.89570126]),
#  'split1_test_score': array([0.89306777, 0.87403852]),
#  'split2_test_score': array([0.86383378, 0.85925987]),
#  'split3_test_score': array([0.88646485, 0.89758825]),
#  'split4_test_score': array([0.88929649, 0.87435534]),
#  'mean_test_score': array([0.8809132 , 0.88018865]),
#  'std_test_score': array([0.01115099, 0.01451381]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8809132007133307

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5484434427059653),
#  ('GrLivArea', 0.10791267639392499),
#  ('BsmtFinSF1', 0.05218329913646627),
#  ('TotalBsmtSF', 0.04771094551880748),
#  ('GarageArea', 0.035794904087438746),
#  ('GarageCars', 0.03412414819778435),
#  ('1stFlrSF', 0.03088284189850882),
#  ('LotArea', 0.009095101617533635),
#  ('FullBath', 0.009083473561628143),
#  ('YearRemodAdd', 0.008667299468575956),
#  ('YearBuilt', 0.008300972157515369),
#  ('BsmtQual', 0.007431616076793882),
#  ('LotFrontage', 0.005876096850350092),
#  ('BsmtUnfSF', 0.005640817864136734),
#  ('OpenPorchSF', 0.0051099423548944724),
#  ('MasVnrArea', 0.004927367951679691),
#  ('GarageYrBlt', 0.004902914206238934),
#  ('2ndFlrSF', 0.004303806555791111),
#  ('OverallCond', 0.004019335933622758),
#  ('KitchenQual', 0.0037701475179440554),
#  ('WoodDeckSF', 0.0035571172000977104),
#  ('FunctionalDummy_Typ', 0.003396435781954835),
#  ('MoSold', 0.0029321211229060918),
#  ('BsmtFinType1', 0.0027197949860474236),
#  ('ExterQual', 0.0024420823588632277),
#  ('GarageFinish', 0.0020940402513566665),
#  ('Fireplaces', 0.0019907798965602846),
#  ('TotRmsAbvGrd', 0.0019382288328098577),
#  ('BedroomAbvGr', 0.0019034247575077825),
#  ('BsmtExposure', 0.0017850106085453726),
#  ('LotShapeDummy_IR3', 0.0017549723741799902),
#  ('GarageTypeDummy_CarPort', 0.0016188949530738946),
#  ('FireplaceQu', 0.001387029664894214),
#  ('YrSold', 0.0013441478101141238),
#  ('BsmtFullBath', 0.001256784578885049),
#  ('HeatingDummy_Wall', 0.0011460675926405859),
#  ('HalfBath', 0.001068676472382712),
#  ('Exterior2ndDummy_Stucco', 0.0010137751323867873),
#  ('MSZoningDummy_RL', 0.0009533840381668404),
#  ('EnclosedPorch', 0.0009147058776917986),
#  ('HeatingQC', 0.0007232995881678027),
#  ('SaleConditionDummy_Family', 0.0007023085257110823),
#  ('MasVnrTypeDummy_None', 0.0006563913398863661),
#  ('NeighborhoodDummy_CollgCr', 0.0006493678249306248),
#  ('MSSubClassDummy_50', 0.0006207339146337384),
#  ('KitchenAbvGr', 0.0005745477625009963),
#  ('SaleTypeDummy_ConLw', 0.0005726060244055217),
#  ('GarageQual', 0.0005564851134694445),
#  ('MSZoningDummy_RH', 0.000546967512227462),
#  ('MSSubClassDummy_30', 7.057123903339724e-07),
#  ('NeighborhoodDummy_Blueste', 5.081235018028809e-07),
#  ('MSSubClassDummy_160', 4.3039915250778025e-07),
#  ('Condition1Dummy_RRNn', 1.7790534944731206e-07),
#  ('RoofStyleDummy_Hip', 1.7705192803287496e-07),
#  ('FoundationDummy_Slab', 1.1183946648422396e-07),
#  ('Exterior2ndDummy_BrkFace', 1.0230244742245437e-07),
#  ('SaleTypeDummy_WD', 7.325642039213235e-08),
#  ('MiscFeatureDummy_No_Misc_Feature', 4.137476276733072e-08),
#  ('Exterior1stDummy_BrkFace', 9.276450474833327e-09),
#  ('Exterior1stDummy_HdBoard', 6.852194965851916e-09),
#  ('Condition1Dummy_RRAn', 1.0143491288757862e-09),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02723489, 0.00515099, 0.00498819, 0.00501742, 0.00519195,
#         0.00530124, 0.00495105, 0.00507479]),
#  'std_fit_time': array([4.33957480e-02, 1.15835553e-04, 1.23658043e-04, 6.52780491e-05,
#         1.56322290e-04, 1.61733928e-04, 2.91141790e-05, 1.83635828e-04]),
#  'mean_score_time': array([0.0029264 , 0.00278001, 0.00264425, 0.00268259, 0.00277953,
#         0.00284801, 0.00261807, 0.00269289]),
#  'std_score_time': array([1.16287024e-04, 5.88376092e-05, 7.81706715e-05, 8.96814710e-05,
#         1.31775172e-04, 1.34204512e-04, 5.26567282e-05, 1.11334727e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.90609175, 0.90806561, 0.9101088 , 0.91261419, 0.9134645 ,
#         0.91405194, 0.90192961, 0.87936615]),
#  'split1_test_score': array([0.91342459, 0.91465649, 0.91595079, 0.91531644, 0.91450385,
#         0.91364891, 0.88082917, 0.84630493]),
#  'split2_test_score': array([0.85921548, 0.87034836, 0.8789089 , 0.8870894 , 0.88885264,
#         0.88981509, 0.87139967, 0.84329403]),
#  'split3_test_score': array([0.89279886, 0.89363784, 0.89684454, 0.90110285, 0.90226228,
#         0.90301858, 0.89813772, 0.88087405]),
#  'split4_test_score': array([0.89280832, 0.89344361, 0.89457794, 0.8968285 , 0.89747379,
#         0.89782961, 0.88015923, 0.85344364]),
#  'mean_test_score': array([0.8928678 , 0.89603038, 0.89927819, 0.90259027, 0.90331141,
#         0.90367282, 0.88649108, 0.86065656]),
#  'std_test_score': array([0.01860076, 0.01525622, 0.01294759, 0.01037422, 0.00972204,
#         0.00931511, 0.01160941, 0.01623729]),
#  ('NeighborhoodDummy_Mitchel', -2386.576955079167),
#  ('SaleConditionDummy_Family', 2369.967981817323),
#  ('BldgTypeDummy_Twnhs', -2204.1911270554647),
#  ('BldgTypeDummy_Duplex', -2203.1329991453276),
#  ('Condition1Dummy_Feedr', 2188.2133434858924),
#  ('MSSubClassDummy_90', -2167.9622668401794),
#  ('KitchenAbvGr', -2079.4090724529387),
#  ('SaleTypeDummy_ConLw', 2079.0009198549296),
#  ('MiscFeatureDummy_TenC', 2052.2264693298143),
#  ('NeighborhoodDummy_Crawfor', -2027.3366160146682),
#  ('Fireplaces', 1993.5343998154551),
#  ('MSSubClassDummy_120', -1900.4479868786837),
#  ('YearRemodAdd', 1843.5830105249113),
#  ('NeighborhoodDummy_NPkVill', -1829.2432610662513),
#  ('FoundationDummy_CBlock', 1823.519900879777),
#  ('NeighborhoodDummy_ClearCr', -1801.2978458246605),
#  ('Exterior1stDummy_VinylSd', -1792.5629446261435),
#  ('WoodDeckSF', 1739.187252007378),
#  ('FullBath', 1699.0882529353328),
#  ('NeighborhoodDummy_Edwards', -1660.6895831499453),
#  ('BsmtExposure', -1643.5115293466374),
#  ('NeighborhoodDummy_Blueste', 1621.044246605259),
#  ('OpenPorchSF', 1596.4097163118067),
#  ('NeighborhoodDummy_MeadowV', -1558.0741495131128),
#  ('MasVnrTypeDummy_None', 1535.2963244771563),
#  ('UtilitiesDummy_NoSeWa', 1520.0406103581136),
#  ('NeighborhoodDummy_NridgHt', -1497.8939207001529),
#  ('Exterior2ndDummy_CBlock', 1483.569374290751),
#  ('Condition1Dummy_PosN', -1410.5349052573367),
#  ('NeighborhoodDummy_BrDale', 1396.8448936302673),
#  ('BsmtFullBath', 1388.0793285174188),
#  ('MSSubClassDummy_190', 1366.0798243513352),
#  ('LotShapeDummy_Reg', 1343.906807903565),
#  ('Exterior2ndDummy_Other', -1304.2649812383384),
#  ('FoundationDummy_PConc', 1302.0671543944195),
#  ('Exterior2ndDummy_Wd Sdng', -1286.058024972535),
#  ('Exterior1stDummy_CBlock', -1261.33903256262),
#  ('ScreenPorch', 1258.9881002184977),
#  ('Exterior2ndDummy_CmentBd', -1236.7038195266819),
#  ('LandContourDummy_HLS', -1225.2415375233595),
#  ('FireplaceQu', -1211.7599373088244),
#  ('SaleTypeDummy_CWD', 1188.8254370605048),
#  ('SalePrice', -1185.8086170021909),
#  ('MSSubClassDummy_75', -1146.067164436497),
#  ('MSZoningDummy_RH', 1116.8416871143615),
#  ('PoolArea', 1104.4366332778786),
#  ('LotFrontage', 1088.9947645393675),
#  ('PavedDriveDummy_P', 1063.1433177752879),
#  ('LandContourDummy_Lvl', -1044.833977112996),
#  ('Exterior1stDummy_Wd Sdng', 1042.0277786093995),
#  ('LotConfigDummy_CulDSac', -1033.8817344049264),
#  ('HeatingQC', -1023.5407665283401),
#  ('MasVnrTypeDummy_No_MasVnr', 1018.0772692578654),
#  ('FunctionalDummy_Min1', 1006.6464626318536),
#  ('Exterior2ndDummy_VinylSd', 1004.7441980465641),
#  ('FoundationDummy_Stone', -972.3056135669697),
#  ('GarageTypeDummy_Basment', 969.8318523082405),
#  ('MasVnrTypeDummy_Stone', 928.8422391832377),
#  ('NeighborhoodDummy_NAmes', 920.8100960167521),
#  ('BsmtFinSF2', 918.2450452500576),
#  ('BsmtUnfSF', -912.8686581258376),
#  ('NeighborhoodDummy_OldTown', -874.2835764061861),
#  ('ExterCond', 870.5959884103235),
#  ('BsmtCond', 857.919801949864),
#  ('FunctionalDummy_Min2', -827.8538320009176),
#  ('Exterior1stDummy_Stone', 826.4250316915508),
#  ('HouseStyleDummy_SFoyer', 825.7624825419742),
#  ('NeighborhoodDummy_Timber', 824.3127355945167),
#  ('Condition1Dummy_PosA', 822.9839146222308),
#  ('MSSubClassDummy_50', 810.7790473430362),
#  ('BsmtFinType2', -797.6072842614029),
#  ('GarageTypeDummy_CarPort', 794.9780826088098),
#  ('MSZoningDummy_RM', 768.460197224733),
#  ('NeighborhoodDummy_SawyerW', 763.6291905943872),
#  ('GarageFinish', -758.7376539280962),
#  ('Condition1Dummy_RRNn', -736.3959550522819),
#  ('LotConfigDummy_FR2', -734.4890345726948),
#  ('HeatingDummy_Grav', -724.3967867602562),
#  ('MSSubClassDummy_80', -723.5472336327688),
#  ('NeighborhoodDummy_Sawyer', -723.0330824736988),
#  ('HouseStyleDummy_SLvl', -721.2933593559114),
#  ('Exterior1stDummy_ImStucc', 716.7074818750015),
#  ('MSSubClassDummy_180', -701.0335668043506),
#  ('Condition2Dummy_RRNn', -701.0335668043339),
#  ('HalfBath', 676.6207904993543),
#  ('Exterior1stDummy_HdBoard', -675.2683346032732),
#  ('HouseStyleDummy_2.5Unf', -652.2963563807951),
#  ('GarageYrBlt', -630.4572130800069),
#  ('SaleTypeDummy_WD', 606.7230709989802),
#  ('HouseStyleDummy_1Story', -599.8398046044649),
#  ('EnclosedPorch', 599.1413490220355),
#  ('Exterior2ndDummy_Stucco', 585.2939001453475),
#  ('GarageTypeDummy_Detchd', 582.6809842770219),
#  ('Exterior1stDummy_Plywood', -580.2755206035223),
#  ('HeatingDummy_GasW', -573.8939589093704),
#  ('MSZoningDummy_FV', 563.9754744526633),
#  ('MSSubClassDummy_45', -557.4027292210405),
#  ('Exterior1stDummy_MetalSd', -537.6728775066882),
#  ('RoofStyleDummy_Gambrel', 536.4859590113485),
#  ('3SsnPorch', 511.0058193993547),
#  ('BsmtHalfBath', -504.1027027682682),
#  ('MoSold', -500.7968531232735),
#  ('Exterior2ndDummy_Brk Cmn', -498.5894008530653),
#  ('NeighborhoodDummy_BrkSide', 495.73229910127253),
#  ('Condition1Dummy_RRAe', 489.82665818968394),
#  ('PoolQC', 486.6081511400823),
#  ('BldgTypeDummy_2fmCon', -475.7071764869548),
#  ('MSSubClassDummy_85', -475.7071764869528),
#  ('SaleConditionDummy_AdjLand', 466.4150432252412),
#  ('LotShapeDummy_IR3', 461.5829642123838),
#  ('RoofMatlDummy_Tar&Grv', -447.50051402539236),
#  ('ElectricalDummy_SBrkr', -419.96990627694225),
#  ('GarageTypeDummy_Attchd', 405.89123080202626),
#  ('YrSold', -401.53404752837),
#  ('SaleTypeDummy_Con', 390.48305288396296),
#  ('NeighborhoodDummy_StoneBr', -369.5131573441529),
#  ('MSSubClassDummy_70', -367.6438083735655),
#  ('ElectricalDummy_FuseP', 363.6856654668136),
#  ('HouseStyleDummy_1.5Unf', -362.63573802517584),
#  ('Condition1Dummy_RRAn', -358.7194822890108),
#  ('SaleTypeDummy_New', 354.25485807501497),
#  ('MasVnrTypeDummy_BrkFace', 350.12694064377195),
#  ('GarageQual', 342.12641098902566),
#  ('RoofStyleDummy_Gable', 337.17934770554825),
#  ('Exterior1stDummy_WdShing', 328.88507715360913),
#  ('Exterior2ndDummy_Stone', 324.7728401440538),
#  ('LotShapeDummy_IR2', -322.75939910832545),
#  ('MiscFeatureDummy_Othr', 309.195352369254),
#  ('AlleyDummy_Pave', 307.87263274821083),
#  ('LotConfigDummy_Inside', 304.0517323811542),
#  ('LandSlope', -300.444427531653),
#  ('Exterior2ndDummy_Plywood', 297.80852705076705),
#  ('Exterior2ndDummy_HdBoard', 297.3247309556171),
#  ('RoofMatlDummy_Roll', 296.8927180514086),
#  ('BldgTypeDummy_TwnhsE', 295.0024362722521),
#  ('Condition1Dummy_RRNe', 289.96375579507674),
#  ('Exterior2ndDummy_BrkFace', -281.03413190922817),
#  ('Exterior1stDummy_BrkFace', -281.0341319092227),
#  ('MSZoningDummy_RL', -274.4479001103071),
#  ('SaleTypeDummy_ConLI', -269.0210413925476),
#  ('SaleTypeDummy_ConLD', -264.0506402420467),
#  ('Exterior2ndDummy_AsphShn', 262.37414629564006),
#  ('RoofMatlDummy_WdShngl', -248.9774190029279),
#  ('RoofStyleDummy_Hip', -246.15723660915737),
#  ('RoofMatlDummy_WdShake', 239.20081462375805),
#  ('LotConfigDummy_FR3', -235.92789902847437),
#  ('RoofMatlDummy_Metal', -228.98711722138384),
#  ('MSSubClassDummy_40', -228.81190680189172),
#  ('Fence', 222.25893083579763),
#  ('NeighborhoodDummy_SWISU', -220.04727858293515),
#  ('PavedDriveDummy_Y', -215.2026162075926),
#  ('Exterior1stDummy_CemntBd', -211.6825012556219),
#  ('FunctionalDummy_Typ', -205.6224550070754),
#  ('NeighborhoodDummy_Gilbert', -194.09510191298182),
#  ('Condition2Dummy_RRAe', -186.6118631245289),
#  ('FunctionalDummy_Maj2', 184.367942683682),
#  ('NeighborhoodDummy_IDOTRR', -178.28103973682295),
#  ('FoundationDummy_Wood', 166.72379756722427),
#  ('Exterior1stDummy_AsphShn', -163.47129412400332),
#  ('ElectricalDummy_FuseF', 162.27257403045618),
#  ('Exterior2ndDummy_MetalSd', -151.29045173284294),
#  ('MiscVal', 148.40017582528097),
#  ('ElectricalDummy_Mix', -145.2151755773798),
#  ('HeatingDummy_Wall', -145.18255123206097),
#  ('MSSubClassDummy_60', -139.9986823611252),
#  ('StreetDummy_Pave', 123.753042016277),
#  ('CentralAirDummy_Y', -112.89240185235478),
#  ('Exterior2ndDummy_Wd Shng', 111.13949813417099),
#  ('SaleConditionDummy_Alloca', 107.30592420248769),
#  ('MiscFeatureDummy_No_Misc_Feature', 104.05861196136375),
#  ('GarageTypeDummy_BuiltIn', -85.68041372399173),
#  ('MSSubClassDummy_160', -84.57031525293077),
#  ('BsmtFinType1', -81.36586872151662),
#  ('Condition2Dummy_RRAn', -78.99074140006712),
#  ('LowQualFinSF', -78.56782767264502),
#  ('HouseStyleDummy_2Story', -73.29789700471542),
#  ('SaleTypeDummy_Oth', -70.76482943710954),
#  ('NeighborhoodDummy_Veenker', 69.99267480550638),
#  ('Condition1Dummy_Norm', 66.13741503921823),
#  ('Exterior1stDummy_Stucco', 55.98196767161544),
#  ('HeatingDummy_GasA', -47.98611368649627),
#  ('RoofStyleDummy_Shed', 33.58865570396239),
#  ('Exterior2ndDummy_ImStucc', 24.372496283798377),
#  ('GarageCond', 18.163794791437688),
#  ('AlleyDummy_No_Alley_Access', 14.38220376456006),
#  ('GarageTypeDummy_No_Garage', -14.349349072816244),
#  ('MSSubClassDummy_30', 14.252067602821661),
#  ('LandContourDummy_Low', -8.218743286699283),
#  ('HouseStyleDummy_2.5Fin', 7.001590919062784),
#  ('FoundationDummy_Slab', -3.440554377441151),
#  ('Condition2Dummy_Feedr', -1.4992014332998074),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154075723359.84192, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147267467155.00735, tolerance: 473149439.8449268
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143528934999.997, tolerance: 512921076.67597485
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159165181456.7803, tolerance: 531742386.47439015
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150967622254.87857, tolerance: 512265587.4714985
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109173638086.62254, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104557705073.23987, tolerance: 473149439.8449268
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116387495918.65459, tolerance: 512921076.67597485
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105835505542.16818, tolerance: 531742386.47439015
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125008634099.09142, tolerance: 512265587.4714985
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7574700400.872314, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11831932, 0.12463236, 0.12296729, 0.08765287, 0.06416245,
#         0.05066738, 0.01268315, 0.01000624]),
#  'std_fit_time': array([0.00770802, 0.00346546, 0.00209596, 0.00406135, 0.0008821 ,
#         0.00129106, 0.00338447, 0.00251037]),
#  'mean_score_time': array([0.00261912, 0.00285478, 0.0025136 , 0.00300694, 0.00307903,
#         0.00298376, 0.00293703, 0.00273032]),
#  'std_score_time': array([2.43713268e-04, 3.00991286e-04, 1.60795924e-04, 9.11632339e-05,
#         1.56096021e-04, 1.09335901e-04, 1.74065772e-04, 7.33344545e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.90724065, 0.90762152, 0.90954373, 0.91178282, 0.91281809,
#         0.91380072, 0.90840417, 0.89236523]),
#  'split1_test_score': array([0.91342999, 0.91408728, 0.91585278, 0.91804409, 0.9184035 ,
#         0.91858849, 0.91310948, 0.90265626]),
#  'split2_test_score': array([0.8652825 , 0.86687396, 0.87384188, 0.88356843, 0.88738752,
#         0.88910886, 0.88841448, 0.87389578]),
#  'split3_test_score': array([0.89254813, 0.89285474, 0.89465529, 0.89908754, 0.90050777,
#         0.90165124, 0.90622419, 0.89491279]),
#  'split4_test_score': array([0.89342751, 0.89328316, 0.89408055, 0.89475805, 0.89614692,
#         0.89738539, 0.90280318, 0.8930414 ]),
#  'mean_test_score': array([0.89438575, 0.89494413, 0.89759484, 0.90144819, 0.90305276,
#         0.90410694, 0.9037911 , 0.89137429]),
#  'std_test_score': array([0.01660859, 0.01626183, 0.0145693 , 0.01226576, 0.01123009,
#         0.01076881, 0.0083839 , 0.00947696]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9041069369524031

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 25945.39700408272),
#  ('OverallQual', 9678.118149063555),
#  ('YearBuilt', 9197.606190231998),
#  ('BsmtFinSF1', 8937.565308224648),
#  ('TotalBsmtSF', 5874.139453005044),
#  ('OverallCond', 5806.161311932057),
#  ('LotArea', 5317.877984399514),
#  ('SaleConditionDummy_Normal', 5299.709866299725),
#  ('NeighborhoodDummy_NoRidge', 5175.106004197213),
#  ('FunctionalDummy_Sev', 4925.578241365277),
#  ('KitchenQual', -4435.5607719562395),
#  ('NeighborhoodDummy_Somerst', 4295.390148763808),
#  ('ExterQual', -3541.225545936369),
#  ('GarageCars', 3453.534224046861),
#  ('BsmtQual', -3449.2028786733026),
#  ('NeighborhoodDummy_NWAmes', 3400.4529367776818),
#  ('BedroomAbvGr', -3380.8326203648608),
#  ('NeighborhoodDummy_CollgCr', 2878.424435311818),
#  ('Exterior1stDummy_BrkComm', 2686.74920908963),
#  ('SaleConditionDummy_Family', 2661.1605622836205),
#  ('MSSubClassDummy_90', -2485.9060639491768),
#  ('BldgTypeDummy_Duplex', -2485.0525174780196),
#  ('KitchenAbvGr', -2471.9746069472553),
#  ('BldgTypeDummy_Twnhs', -2399.268826290721),
#  ('MSSubClassDummy_120', -2142.1630550707937),
#  ('GarageArea', 2073.9053630298267),
#  ('TotRmsAbvGrd', 2062.2911621426824),
#  ('MiscFeatureDummy_TenC', 2043.2846592961732),
#  ('MasVnrArea', 1977.9437576273813),
#  ('Condition1Dummy_Feedr', 1955.2954587182537),
#  ('NeighborhoodDummy_Blueste', 1922.8037957867248),
#  ('Exterior2ndDummy_CmentBd', -1850.6285566946788),
#  ('Exterior2ndDummy_Other', -1816.3830870772538),
#  ('FunctionalDummy_Min1', 1795.5384696474134),
#  ('NeighborhoodDummy_NPkVill', -1757.012107102756),
#  ('NeighborhoodDummy_Mitchel', -1725.2984340148596),
#  ('NeighborhoodDummy_BrDale', 1694.305044545211),
#  ('NeighborhoodDummy_ClearCr', -1640.6155827903867),
#  ('NeighborhoodDummy_Crawfor', -1570.8161027323042),
#  ('Condition1Dummy_PosN', -1542.8711615650582),
#  ('NeighborhoodDummy_MeadowV', -1493.1237657748236),
#  ('WoodDeckSF', 1471.1107324948098),
#  ('Exterior2ndDummy_Wd Sdng', -1419.9755605136422),
#  ('BsmtExposure', -1398.6255277257117),
#  ('OpenPorchSF', 1392.167943067265),
#  ('NeighborhoodDummy_NridgHt', -1388.877503374855),
#  ('BsmtFinSF2', 1386.972301221492),
#  ('MSSubClassDummy_190', 1379.2606197115554),
#  ('MasVnrTypeDummy_None', 1360.7641773961484),
#  ('LotShapeDummy_Reg', 1325.4662898357858),
#  ('HouseStyleDummy_1.5Unf', 1312.9947034430804),
#  ('FoundationDummy_Stone', -1285.315088530813),
#  ('ScreenPorch', 1259.8317544149018),
#  ('LandContourDummy_HLS', -1248.8967383708925),
#  ('Fireplaces', 1232.6756084378255),
#  ('UtilitiesDummy_NoSeWa', 1231.0564057960598),
#  ('Exterior1stDummy_VinylSd', -1218.304641448211),
#  ('NeighborhoodDummy_NAmes', 1208.81706807449),
#  ('NeighborhoodDummy_Edwards', -1196.283107898838),
#  ('Exterior1stDummy_CBlock', -1187.3067548661663),
#  ('FoundationDummy_CBlock', 1181.8602168413377),
#  ('FoundationDummy_PConc', 1177.0385603865166),
#  ('SaleTypeDummy_CWD', 1168.859385894794),
#  ('Exterior1stDummy_Wd Sdng', 1113.0274881204766),
#  ('Exterior2ndDummy_CBlock', 1108.5667925093182),
#  ('FireplaceQu', -1074.1044784499877),
#  ('MSZoningDummy_RH', 1041.4660903698166),
#  ('YearRemodAdd', 1032.8417999864182),
#  ('HouseStyleDummy_SLvl', -1015.4361975073255),
#  ('Exterior1stDummy_Stone', 994.8916430340812),
#  ('MasVnrTypeDummy_No_MasVnr', 963.1404734664983),
#  ('HouseStyleDummy_1Story', -957.2014667521867),
#  ('HeatingDummy_Grav', -928.2678047189361),
#  ('GarageYrBlt', -882.3775283731289),
#  ('LotConfigDummy_CulDSac', -869.7043178682413),
#  ('BsmtCond', 858.2402046169431),
#  ('MSSubClassDummy_180', -852.7885728230799),
#  ('BsmtFullBath', 846.580802187222),
#  ('NeighborhoodDummy_SawyerW', 832.7018206144846),
#  ('BsmtFinType2', -797.3640385271071),
#  ('ExterCond', 787.9142920841002),
#  ('RoofMatlDummy_Tar&Grv', -785.1888014200491),
#  ('PavedDriveDummy_P', 766.2434744843923),
#  ('MSZoningDummy_RM', 764.4623216357103),
#  ('EnclosedPorch', 752.7265398589058),
#  ('LandContourDummy_Lvl', -747.2555382680192),
#  ('NeighborhoodDummy_Sawyer', -715.7744686244476),
#  ('MasVnrTypeDummy_Stone', 714.2483474318686),
#  ('NeighborhoodDummy_Timber', 708.3414958540249),
#  ('Exterior2ndDummy_Brk Cmn', -681.393029378056),
#  ('LotConfigDummy_FR2', -661.4423182038513),
#  ('FunctionalDummy_Maj2', 657.0021883460145),
#  ('FunctionalDummy_Typ', -638.1630714690685),
#  ('Exterior1stDummy_Plywood', -637.0613032419458),
#  ('NeighborhoodDummy_OldTown', -632.8325859925421),
#  ('PoolArea', 628.8680138366065),
#  ('Exterior1stDummy_HdBoard', -615.6661939184188),
#  ('Condition1Dummy_PosA', 613.3425222749928),
#  ('SaleTypeDummy_WD', 610.2770085344362),
#  ('MSZoningDummy_FV', 604.9548069971943),
#  ('HeatingQC', -603.7613515360097),
#  ('Condition1Dummy_RRNn', -602.634004225557),
#  ('GarageTypeDummy_CarPort', 595.6229517833065),
#  ('LowQualFinSF', -576.8178181207619),
#  ('HouseStyleDummy_2.5Unf', -523.8713739138974),
#  ('LotFrontage', 492.9556603126757),
#  ('GarageFinish', -488.4229787781599),
#  ('LotShapeDummy_IR3', 477.6096606329131),
#  ('BsmtHalfBath', -464.25386204322535),
#  ('MoSold', -426.3809062725673),
#  ('FunctionalDummy_Min2', -423.9325320322454),
#  ('BldgTypeDummy_TwnhsE', 402.40543684469776),
#  ('Exterior1stDummy_BrkFace', -399.1657897925777),
#  ('HouseStyleDummy_SFoyer', 353.16460762027475),
#  ('3SsnPorch', 343.35816698351834),
#  ('Condition1Dummy_RRAe', 326.9970934776229),
#  ('FoundationDummy_Wood', 321.1346673176216),
#  ('ElectricalDummy_FuseP', 314.2991136409668),
#  ('SaleConditionDummy_AdjLand', 314.017429149134),
#  ('SalePrice', -304.4956616454166),
#  ('MSSubClassDummy_85', -304.2098161877114),
#  ('SaleTypeDummy_New', 296.7107092576467),
#  ('Exterior1stDummy_ImStucc', 291.1944221502074),
#  ('MiscFeatureDummy_Othr', 273.97759810214876),
#  ('GarageTypeDummy_Attchd', 270.1673988249794),
#  ('YrSold', -269.5844613766722),
#  ('MSSubClassDummy_80', -267.2306933556628),
#  ('NeighborhoodDummy_BrkSide', 260.0336944422482),
#  ('LandSlope', -253.80676285438776),
#  ('PavedDriveDummy_Y', -253.2871261889623),
#  ('Condition1Dummy_RRAn', -251.60129361675322),
#  ('HeatingDummy_GasW', -247.74861985971168),
#  ('Condition1Dummy_RRNe', 246.60482292105303),
#  ('Exterior1stDummy_MetalSd', -245.07471502936158),
#  ('NeighborhoodDummy_StoneBr', -234.14378696928244),
#  ('SaleConditionDummy_Alloca', 226.78423216238653),
#  ('SaleTypeDummy_ConLI', -219.51944989902032),
#  ('HeatingDummy_Wall', -209.50130688942392),
#  ('AlleyDummy_Pave', 204.98318492837532),
#  ('BldgTypeDummy_2fmCon', -198.8733657261929),
#  ('LotShapeDummy_IR2', -182.03027086952542),
#  ('Exterior2ndDummy_MetalSd', -181.34895825452077),
#  ('SaleTypeDummy_Con', 179.21654827534496),
#  ('SaleTypeDummy_ConLD', -173.67100970549066),
#  ('RoofMatlDummy_Metal', -170.63824646554315),
#  ('LotConfigDummy_Inside', 170.51576729498439),
#  ('MasVnrTypeDummy_BrkFace', 151.7773051169527),
#  ('GarageTypeDummy_Basment', 148.1618980379713),
#  ('Exterior2ndDummy_VinylSd', 146.17824881572753),
#  ('MSSubClassDummy_45', -136.39808007386574),
#  ('RoofStyleDummy_Gable', 122.96555700630732),
#  ('Condition2Dummy_RRNn', -107.56762526071235),
#  ('Condition2Dummy_RRAe', -104.13524823330738),
#  ('HalfBath', -99.35860023694238),
#  ('RoofMatlDummy_WdShngl', -96.86887638494126),
#  ('LotConfigDummy_FR3', -93.04851844777734),
#  ('NeighborhoodDummy_SWISU', 89.44776182709033),
#  ('NeighborhoodDummy_IDOTRR', 87.94759921369794),
#  ('Exterior2ndDummy_Plywood', 82.44787421881566),
#  ('MSSubClassDummy_70', -73.47562421024523),
#  ('RoofMatlDummy_Roll', 68.16554306270116),
#  ('Exterior2ndDummy_Stone', 52.85377597355196),
#  ('RoofStyleDummy_Hip', -46.34280137076565),
#  ('ElectricalDummy_FuseF', 40.94759018469864),
#  ('MiscVal', 30.22769948172706),
#  ('GarageQual', 22.610266751999877),
#  ('Exterior2ndDummy_BrkFace', -8.456670296828726),
#  ('RoofMatlDummy_WdShake', 6.48934568089383),
#  ('BsmtFinType1', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('FullBath', 0.0),
#  ('GarageCond', 0.0),
#  ('PoolQC', 0.0),
#  ('Fence', 0.0),
#  ('MSSubClassDummy_30', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSZoningDummy_RL', -0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('LandContourDummy_Low', 0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_Veenker', 0.0),
#  ('Condition1Dummy_Norm', 0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', -0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', -0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('CentralAirDummy_Y', 0.0),
#  ('ElectricalDummy_Mix', -0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-30-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8830915786671504

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.9023111173585201

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170305608132.67383, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166021943651.60822, tolerance: 473149439.8449268
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164137794227.05524, tolerance: 512921076.67597485
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159177168987.31433, tolerance: 531742386.47439015
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131957614021.99126, tolerance: 512265587.4714985
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107779788599.92673, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123404642958.83728, tolerance: 473149439.8449268
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127624432780.78221, tolerance: 512921076.67597485
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29459187692.576782, tolerance: 531742386.47439015
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15413670584.93982, tolerance: 512265587.4714985
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10063527589.260376, tolerance: 515822518.53212416
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 945146395.0615234, tolerance: 531742386.47439015
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.9026391352177805

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999152
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998844
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998752
# PoolArea                  PoolQC                       0.997940
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996570
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996232
# GarageCars                GarageArea                   0.989672
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988297
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.985410
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984269
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.983860
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.969774
# GrLivArea                 TotRmsAbvGrd                 0.968670
# ExterQual                 KitchenQual                  0.966069
# TotalBsmtSF               1stFlrSF                     0.965884
# OverallQual               ExterQual                    0.958499
# ExterQual                 BsmtQual                     0.957137
# BsmtQual                  FoundationDummy_PConc        0.954282
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.953722
# KitchenAbvGr              MSSubClassDummy_90           0.951222
# YearRemodAdd              BsmtQual                     0.945462
# OverallQual               BsmtQual                     0.945109
# 2ndFlrSF                  HouseStyleDummy_2Story       0.944729
# MasVnrArea                MasVnrTypeDummy_None         0.943421
# OverallQual               KitchenQual                  0.941847
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.941397
# YearRemodAdd              FoundationDummy_PConc        0.940110
# OverallQual               GarageCars                   0.937818
# FoundationDummy_CBlock    FoundationDummy_PConc        0.930003
# HalfBath                  HouseStyleDummy_2Story       0.927327
# YearRemodAdd              ExterQual                    0.926959
# ExterQual                 FoundationDummy_PConc        0.926958
# OverallQual               FullBath                     0.925598
# YearBuilt                 BsmtQual                     0.924703
# BsmtQual                  KitchenQual                  0.923652
# YearBuilt                 YearRemodAdd                 0.921379
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.918448
# OverallQual               YearRemodAdd                 0.916897
#                           GarageArea                   0.915210
# BsmtFinSF1                BsmtFullBath                 0.913362
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.909569
# OverallQual               FoundationDummy_PConc        0.908277
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.906078
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.904714
# HalfBath                  MSSubClassDummy_60           0.903122
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.902775
# YearRemodAdd              KitchenQual                  0.898732
# BsmtQual                  GarageCars                   0.897492
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.895876
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.938871604348209),
#  ('LotArea', 2.1085003469221912),
#  ('OverallQual', 4.72237299195794),
#  ('OverallCond', 2.11784249573792),
#  ('YearBuilt', 16.201869599232),
#  ('YearRemodAdd', 3.18529791930577),
#  ('MasVnrArea', 2.683858126784115),
#  ('ExterQual', 3.201512648106204),
#  ('BsmtQual', 3.0593910253692522),
#  ('BsmtExposure', 1.7592821544805803),
#  ('BsmtFinType1', 2.2166813674489885),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.460397421503155),
#  ('BsmtHalfBath', 1.2603504359404305),
#  ('FullBath', 3.932526295215381),
#  ('HalfBath', 2.9610243294044247),
#  ('BedroomAbvGr', 3.1751270986460174),
#  ('KitchenAbvGr', 5.069332188478803),
#  ('KitchenQual', 2.322956209561351),
#  ('TotRmsAbvGrd', 5.51508632952444),
#  ('Fireplaces', 1.9015697926467963),
#  ('FireplaceQu', 1.4090254823891601),
#  ('GarageYrBlt', 1374.1269992836048),
#  ('GarageFinish', 2.1537012220166525),
#  ('GarageCars', 6.793829252146898),
#  ('GarageArea', 6.630562782258719),
#  ('WoodDeckSF', 1.3771608215078714),
#  ('OpenPorchSF', 1.4322746727866729),
#  ('EnclosedPorch', 1.4943042751551305),
#  ('3SsnPorch', 1.1103029244302984),
#  ('ScreenPorch', 1.2115545003249553),
#  ('PoolArea', 16.07922633448991),
#  ('PoolQC', 16.02459880739292),
#  ('Fence', 1.352896950473144),
#  ('MiscVal', 1.0608900773354073),
#  ('MoSold', 1.1523461732053968),
#  ('YrSold', 1.194845188355783),
#  ('MSSubClassDummy_30', 2.590205440534331),
#  ('MSSubClassDummy_40', 1.136435979350602),
#  ('MSSubClassDummy_45', 15.213800458499339),
#  ('MSSubClassDummy_50', 20.177172097942897),
#  ('MSSubClassDummy_60', 34.44601690750196),
#  ('MSSubClassDummy_70', 8.87476651119791),
#  ('MSSubClassDummy_75', inf),
#  ('MSSubClassDummy_80', 13.628888781052376),
#  ('MSSubClassDummy_85', 5.005641508470926),
#  ('MSSubClassDummy_90', 5.554212605869155),
#  ('MSSubClassDummy_120', 2.7410794079807803),
#  ('MSSubClassDummy_160', 11.930077728077286),
#  ('MSSubClassDummy_180', 2.4285258329220984),
#  ('MSSubClassDummy_190', 1.886392409940959),
#  ('MSZoningDummy_FV', 26.868129133855003),
#  ('MSZoningDummy_RH', 5.049483913948362),
#  ('MSZoningDummy_RL', 77.37197610078368),
#  ('MSZoningDummy_RM', 54.099266641833864),
#  ('AlleyDummy_No_Alley_Access', 2.564105903007423),
#  ('AlleyDummy_Pave', 2.8455756272258546),
#  ('LotShapeDummy_IR2', 1.2682591562579484),
#  ('LotShapeDummy_IR3', 1.1112032362916224),
#  ('LotShapeDummy_Reg', 1.55163954420415),
#  ('LotConfigDummy_CulDSac', 1.8208215846476536),
#  ('LotConfigDummy_FR2', 1.370503076256532),
#  ('LotConfigDummy_FR3', 1.1016876718190636),
#  ('LotConfigDummy_Inside', 1.7408403248969524),
#  ('MasVnrTypeDummy_None', 32.370724440587566),
#  ('MasVnrTypeDummy_Stone', 11.42643212794547),
#  ('FoundationDummy_CBlock', 7.316863810394027),
#  ('FoundationDummy_PConc', 8.577265748089077),
#  ('FoundationDummy_Slab', 1.9485149542139104),
#  ('FoundationDummy_Stone', 1.1588339445829672),
#  ('FoundationDummy_Wood', 1.2652784008123725),
#  ('GarageTypeDummy_Attchd', 94.79739083641509),
#  ('GarageTypeDummy_Basment', 6.407470993401164),
#  ('GarageTypeDummy_BuiltIn', 23.123250520709227),
#  ('GarageTypeDummy_CarPort', 2.524982872022371),
#  ('GarageTypeDummy_Detchd', 78.92213745757991),
#  ('GarageTypeDummy_No_Garage', 1333.4075214731804),
#  ('SaleConditionDummy_AdjLand', 1.0742436132334752),
#  ('SaleConditionDummy_Alloca', 1.3655188924017942),
#  ('SaleConditionDummy_Family', 1.3093869688680366),
#  ('SaleConditionDummy_Normal', 2.681924989148123),
#  ('SaleConditionDummy_Partial', 2.8302735128801255),
#  ('MSSubClassDummy_150', nan),
#  ('constant', 129679.72186677999)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF', 'OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 32.79307752574932),
#  ('LotArea', 9.0480198686135),
#  ('OverallCond', 40.89145811196475),
#  ('YearBuilt', 53617.57140527553),
#  ('YearRemodAdd', 28172.005933862943),
#  ('MasVnrArea', 3.614531515410827),
#  ('ExterQual', 53.438651915127025),
#  ('BsmtQual', 17.428177255986085),
#  ('BsmtExposure', 8.936856570230853),
#  ('BsmtFinType1', 6.348221730953133),
#  ('BsmtFinSF1', 19.237487981061374),
#  ('BsmtFinSF2', 2.205128190127716),
#  ('BsmtUnfSF', 23.45104819087529),
#  ('1stFlrSF', 109.48576745918204),
#  ('2ndFlrSF', 27.27196307395492),
#  ('LowQualFinSF', 1.9143963405214945),
#  ('BsmtFullBath', 4.173064162661082),
#  ('BsmtHalfBath', 1.325964161478443),
#  ('FullBath', 36.67172185726597),
#  ('HalfBath', 4.665789132700249),
#  ('BedroomAbvGr', 48.53129943707035),
#  ('KitchenAbvGr', 195.25178341438703),
#  ('KitchenQual', 22.871496329616196),
#  ('TotRmsAbvGrd', 55.10463679523275),
#  ('Fireplaces', 3.5701133181550526),
#  ('FireplaceQu', 11.2710015322758),
#  ('GarageYrBlt', 33754.835225893636),
#  ('GarageFinish', 7.489284298288219),
#  ('GarageCars', 50.43010719776774),
#  ('GarageArea', 43.639092871719704),
#  ('WoodDeckSF', 2.1827546528689843),
#  ('OpenPorchSF', 2.1952805371600457),
#  ('EnclosedPorch', 1.6596304347095214),
#  ('3SsnPorch', 1.1247550335317549),
#  ('ScreenPorch', 1.2964056111938123),
#  ('PoolArea', 11.645393738623744),
#  ('PoolQC', 26522.936492297435),
#  ('Fence', 15.433687714720453),
#  ('MiscVal', 1.0619708009188855),
#  ('MoSold', 5.656304341626484),
#  ('YrSold', 3.429062717869039),
#  ('MSSubClassDummy_30', 2.5098727159879557),
#  ('MSSubClassDummy_40', 1.1336683741583222),
#  ('MSSubClassDummy_45', 15.208645457994173),
#  ('MSSubClassDummy_50', 21.636203454383786),
#  ('MSSubClassDummy_60', 43.24316414497159),
#  ('MSSubClassDummy_70', 9.055986757423502),
#  ('MSSubClassDummy_75', inf),
#  ('MSSubClassDummy_80', 14.185867336179959),
#  ('MSSubClassDummy_85', 5.038560844743054),
#  ('MSSubClassDummy_90', 5.655687954561191),
#  ('MSSubClassDummy_120', 2.9183543953440014),
#  ('MSSubClassDummy_160', 12.373708125656165),
#  ('MSSubClassDummy_180', 2.4284327667941055),
#  ('MSSubClassDummy_190', 1.8818874029210957),
#  ('MSZoningDummy_FV', 28.005904287767233),
#  ('MSZoningDummy_RH', 5.054886686413007),
#  ('MSZoningDummy_RL', 393.8772556307645),
#  ('MSZoningDummy_RM', 62.26557654326005),
#  ('AlleyDummy_No_Alley_Access', 51.73317506352838),
#  ('AlleyDummy_Pave', 2.902770309490004),
#  ('LotShapeDummy_IR2', 1.2997131504357227),
#  ('LotShapeDummy_IR3', 1.1154479620442062),
#  ('LotShapeDummy_Reg', 4.313159711707557),
#  ('LotConfigDummy_CulDSac', 1.9368359450512902),
#  ('LotConfigDummy_FR2', 1.4185405119748202),
#  ('LotConfigDummy_FR3', 1.1043175409379051),
#  ('LotConfigDummy_Inside', 6.347684645732581),
#  ('NeighborhoodDummy_Blueste', 1.4156766532829164),
#  ('NeighborhoodDummy_BrDale', 3.682960488840505),
#  ('NeighborhoodDummy_BrkSide', 8.987904170020624),
#  ('NeighborhoodDummy_ClearCr', 3.10493371871697),
#  ('NeighborhoodDummy_CollgCr', 15.13857988842796),
#  ('NeighborhoodDummy_Crawfor', 5.50729131684982),
#  ('NeighborhoodDummy_Edwards', 10.171173961012098),
#  ('NeighborhoodDummy_Gilbert', 8.766361457504999),
#  ('NeighborhoodDummy_IDOTRR', 6.249207538207582),
#  ('NeighborhoodDummy_MeadowV', 3.8442528881389006),
#  ('NeighborhoodDummy_Mitchel', 5.945101436542777),
#  ('NeighborhoodDummy_NAmes', 25.3526293078407),
#  ('NeighborhoodDummy_NPkVill', 2.1378640551153243),
#  ('NeighborhoodDummy_NWAmes', 8.234345746667843),
#  ('NeighborhoodDummy_NoRidge', 5.2439140502384385),
#  ('NeighborhoodDummy_NridgHt', 7.101848262467996),
#  ('NeighborhoodDummy_OldTown', 15.084378081229358),
#  ('NeighborhoodDummy_SWISU', 3.975998199616133),
#  ('NeighborhoodDummy_Sawyer', 8.883102102162487),
#  ('NeighborhoodDummy_SawyerW', 6.392466064310294),
#  ('NeighborhoodDummy_Somerst', 12.606959963273379),
#  ('NeighborhoodDummy_StoneBr', 2.8315143178112363),
#  ('NeighborhoodDummy_Timber', 4.357376416240787),
#  ('NeighborhoodDummy_Veenker', 2.1259805321715883),
#  ('HouseStyleDummy_1.5Unf', 15.70417268501709),
#  ('HouseStyleDummy_1Story', 121.2548103101593),
#  ('HouseStyleDummy_2.5Fin', inf),
#  ('HouseStyleDummy_2.5Unf', inf),
#  ('HouseStyleDummy_2Story', 69.88440626890626),
#  ('HouseStyleDummy_SFoyer', 9.573415507232061),
#  ('HouseStyleDummy_SLvl', 21.0937835785537),
#  ('RoofStyleDummy_Gable', 307.6153566883198),
#  ('RoofStyleDummy_Gambrel', 3.8494348985985667),
#  ('RoofStyleDummy_Hip', 72.74036764242936),
#  ('RoofStyleDummy_Mansard', 2.2553337536801417),
#  ('RoofStyleDummy_Shed', nan),
#  ('Exterior1stDummy_AsphShn', 1.233612708004555),
#  ('Exterior1stDummy_BrkComm', 1.125312564371131),
#  ('Exterior1stDummy_BrkFace', 4.3951496033817286),
#  ('Exterior1stDummy_CBlock', 1.1993756967863891),
#  ('Exterior1stDummy_CemntBd', 5.387577206807603),
#  ('Exterior1stDummy_HdBoard', 17.895059657385204),
#  ('Exterior1stDummy_ImStucc', 1.1792194820072397),
#  ('Exterior1stDummy_MetalSd', 16.17875661985093),
#  ('Exterior1stDummy_Plywood', 8.445145819460457),
#  ('Exterior1stDummy_Stone', 1.380950498641979),
#  ('Exterior1stDummy_Stucco', 2.403904586061721),
#  ('Exterior1stDummy_VinylSd', 40.51769014467547),
#  ('Exterior1stDummy_Wd Sdng', 13.914113895227484),
#  ('Exterior1stDummy_WdShing', 2.5697553237080064),
#  ('MasVnrTypeDummy_BrkFace', 41.29795837408214),
#  ('MasVnrTypeDummy_No_MasVnr', 1.6819122983168089),
#  ('MasVnrTypeDummy_None', 77.49672946093834),
#  ('MasVnrTypeDummy_Stone', 12.465939541734393),
#  ('FoundationDummy_CBlock', 12.667372192921894),
#  ('FoundationDummy_PConc', 15.154135843089897),
#  ('FoundationDummy_Slab', 1.9517110761487007),
#  ('FoundationDummy_Stone', 1.1577812955074736),
#  ('FoundationDummy_Wood', 1.250581971987303),
#  ('GarageTypeDummy_Attchd', 255.15361455214335),
#  ('GarageTypeDummy_Basment', 6.459461805818003),
#  ('GarageTypeDummy_BuiltIn', 24.471122260723114),
#  ('GarageTypeDummy_CarPort', 2.5247911242736514),
#  ('GarageTypeDummy_Detchd', 106.24623780770263),
#  ('GarageTypeDummy_No_Garage', 1271.3173011342517),
#  ('SaleConditionDummy_AdjLand', 1.0744731969004768),
#  ('SaleConditionDummy_Alloca', 1.3657859232532108),
#  ('SaleConditionDummy_Family', 1.326535231775731),
#  ('SaleConditionDummy_Normal', 16.61694076884534),
#  ('SaleConditionDummy_Partial', 3.0503111650460606),
#  ('MSSubClassDummy_150', nan)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# PoolArea                  PoolQC                       0.998077
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996564
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996520
# GarageCars                GarageArea                   0.988906
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988360
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.984627
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.971467
# ExterQual                 KitchenQual                  0.962362
#                           BsmtQual                     0.953813
# KitchenAbvGr              MSSubClassDummy_90           0.951584
# BsmtQual                  FoundationDummy_PConc        0.951099
# 2ndFlrSF                  HouseStyleDummy_2Story       0.943809
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.942624
# MasVnrArea                MasVnrTypeDummy_None         0.940729
# YearRemodAdd              BsmtQual                     0.939558
#                           FoundationDummy_PConc        0.933947
# FoundationDummy_CBlock    FoundationDummy_PConc        0.925967
# HalfBath                  HouseStyleDummy_2Story       0.925065
# YearRemodAdd              ExterQual                    0.923273
# ExterQual                 FoundationDummy_PConc        0.921696
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.920894
# YearBuilt                 BsmtQual                     0.920252
# BsmtQual                  KitchenQual                  0.916797
# YearBuilt                 YearRemodAdd                 0.915631
# BsmtFinSF1                BsmtFullBath                 0.913291
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.903659
# HalfBath                  MSSubClassDummy_60           0.900985
# YearRemodAdd              Exterior1stDummy_VinylSd     0.895429
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.894982
# YearRemodAdd              KitchenQual                  0.893467
# YearBuilt                 ExterQual                    0.889799
# 2ndFlrSF                  HalfBath                     0.888118
# YearBuilt                 FoundationDummy_PConc        0.887454
# BsmtQual                  GarageCars                   0.886404
#                           FullBath                     0.885494
#                           Exterior1stDummy_VinylSd     0.885345
# MSSubClassDummy_60        HouseStyleDummy_2Story       0.885007
# MSZoningDummy_RL          MSZoningDummy_RM             0.883717
# ExterQual                 GarageCars                   0.883655
# FullBath                  GarageCars                   0.880892
# 2ndFlrSF                  HouseStyleDummy_1Story       0.880855
# YearBuilt                 GarageCars                   0.880316
# KitchenQual               FoundationDummy_PConc        0.879995
# FullBath                  FoundationDummy_PConc        0.874480
# ExterQual                 GarageArea                   0.866472
# YearRemodAdd              FullBath                     0.864689
# ExterQual                 FullBath                     0.863032
# BsmtQual                  GarageFinish                 0.861995
# YearBuilt                 FullBath                     0.861303
#                           GarageFinish                 0.860283
# dtype: float64
