# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2397.097983796997), ('GrLivArea', 1643.478536889009), ('ExterQual', 1026.763802685214), ('GarageCars', 1014.9815585311064), ('TotalBsmtSF', 979.9240583103749), ('GarageArea', 920.0218283705088), ('1stFlrSF', 863.0676695307175), ('KitchenQual', 800.7094739862464), ('BsmtQual', 798.6340244998792), ('YearBuilt', 673.8443940858195), ('TotRmsAbvGrd', 623.7410000185412), ('FullBath', 615.3785590754334), ('YearRemodAdd', 503.17396718167896), ('Fireplaces', 338.13637180829176), ('GarageFinish', 329.7233232663636), ('MasVnrArea', 321.4221905480203), ('BsmtFinSF1', 262.18913353089533), ('HeatingQC', 260.10119224223143), ('LotFrontage', 213.58093575236012), ('MSSubClassDummy_60', 198.32916230194212), ('OpenPorchSF', 168.44899782362148), ('WoodDeckSF', 145.24224141949335), ('BsmtExposure', 136.08399305736918), ('LotArea', 112.1172536773903), ('2ndFlrSF', 106.09137542092716), ('HalfBath', 101.46694027345013), ('BsmtFullBath', 93.85631629422875), ('GarageYrBlt', 89.84312876806264), ('MSSubClassDummy_30', 88.93690151523595), ('GarageCond', 70.36624371236688), ('GarageQual', 61.08280644309664), ('BsmtUnfSF', 57.68400051517836), ('Fence', 44.396868500005), ('BedroomAbvGr', 35.80469332215043), ('OverallCond', 33.405983744387335), ('ExterCond', 26.584180121323566), ('EnclosedPorch', 21.775104818349256), ('KitchenAbvGr', 16.343244313724814), ('BsmtFinType1', 10.416424489160537), ('MSSubClassDummy_45', 10.219915961130942), ('LowQualFinSF', 8.250000181797393), ('BsmtCond', 7.278973179488479), ('BsmtFinType2', 7.241472916977734), ('MoSold', 6.184914757878956), ('FireplaceQu', 5.613021117211553), ('BsmtHalfBath', 4.98704429132699), ('LandSlope', 4.956603795398918), ('ScreenPorch', 3.904677195232178), ('3SsnPorch', 2.7348062668142603), ('MiscVal', 0.8525654227985174), ('BsmtFinSF2', 0.09721008468380163), ('MSSubClassDummy_40', 0.0043612701699381135), ('YrSold', 0.0030992133236679075), ('PoolArea', 0.00289762293310172), ('PoolQC', 0.0006260561887126427), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 258.13390511666023), ('MSZoningDummy_RM', 150.93384505245155), ('NeighborhoodDummy_NoRidge', 140.1727325149334), ('LotShapeDummy_Reg', 95.16796224698298), ('MSZoningDummy_RL', 85.78954946069808), ('NeighborhoodDummy_OldTown', 63.50079382235943), ('NeighborhoodDummy_NAmes', 62.391495660453984), ('NeighborhoodDummy_Edwards', 48.62462005020427), ('NeighborhoodDummy_StoneBr', 44.74050815507961), ('MSSubClassDummy_50', 39.59937729184234), ('NeighborhoodDummy_Somerst', 36.65933192465904), ('NeighborhoodDummy_Timber', 33.808684124893546), ('NeighborhoodDummy_IDOTRR', 31.70286989594596), ('NeighborhoodDummy_BrkSide', 28.150321144103767), ('NeighborhoodDummy_Sawyer', 27.677427531697493), ('NeighborhoodDummy_MeadowV', 22.777907332414443), ('MSSubClassDummy_160', 20.866942439074013), ('Condition1Dummy_Norm', 18.264892432671203), ('LotConfigDummy_CulDSac', 17.161147664510978), ('MSZoningDummy_FV', 16.858417270833982), ('AlleyDummy_No_Alley_Access', 16.79620063691963), ('NeighborhoodDummy_BrDale', 16.1358133578512), ('Condition1Dummy_Feedr', 15.290173197222288), ('MSSubClassDummy_90', 14.19499655376734), ('LandContourDummy_HLS', 12.46972451288237), ('NeighborhoodDummy_CollgCr', 12.388040012626547), ('MSSubClassDummy_180', 12.023431168536796), ('MSSubClassDummy_190', 8.88860665900238), ('NeighborhoodDummy_ClearCr', 7.706663671276907), ('NeighborhoodDummy_SWISU', 7.204376642843725), ('LotShapeDummy_IR2', 7.178422450184959), ('LandContourDummy_Low', 6.811351559530256), ('LotConfigDummy_Inside', 6.65130964428063), ('NeighborhoodDummy_Veenker', 6.539477541702825), ('MSZoningDummy_RH', 5.782906641693853), ('NeighborhoodDummy_Mitchel', 4.531700287314235), ('MSSubClassDummy_85', 3.9799744322733606), ('Condition1Dummy_PosA', 3.5688768295918023), ('MSSubClassDummy_120', 3.144122547283118), ('NeighborhoodDummy_Gilbert', 2.8372892630075945), ('NeighborhoodDummy_Crawfor', 2.721203844323268), ('MSSubClassDummy_75', 2.4222036662092523), ('NeighborhoodD ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.43166471, 0.26844721]),
#  'std_fit_time': array([0.07450277, 0.02871352]),
#  'mean_score_time': array([0.011166  , 0.01263075]),
#  'std_score_time': array([0.00138599, 0.00171553]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.8702625 , 0.88893095]),
#  'split1_test_score': array([0.89532644, 0.87120605]),
#  'split2_test_score': array([0.86303932, 0.86444783]),
#  'split3_test_score': array([0.89536587, 0.89050074]),
#  'split4_test_score': array([0.89091905, 0.88605174]),
#  'mean_test_score': array([0.88298264, 0.88022746]),
#  'std_test_score': array([0.01362526, 0.01044601]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8829826370644905

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:130: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
est2.summary()
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     74.81
# Date:                Sun, 11 Jul 2021   Prob (F-statistic):               0.00
# Time:                        16:45:46   Log-Likelihood:                -14743.
# No. Observations:                1314   AIC:                         2.991e+04
# Df Residuals:                    1103   BIC:                         3.100e+04
# Df Model:                         210
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                            -7.668e+05   2.11e+05     -3.629      0.000   -1.18e+06   -3.52e+05
# LotFrontage                         42.2197     45.691      0.924      0.356     -47.432     131.871
# LotArea                              0.6898      0.106      6.494      0.000       0.481       0.898
# LandSlope                          846.1355   3478.479      0.243      0.808   -5979.047    7671.318
# OverallQual                       7072.7788    944.965      7.485      0.000    5218.646    8926.911
# OverallCond                       5508.4382    806.242      6.832      0.000    3926.498    7090.379
# YearBuilt                          307.9210     83.983      3.666      0.000     143.137     472.705
# YearRemodAdd                        44.8847     50.700      0.885      0.376     -54.594     144.363
# MasVnrArea                          16.8805      5.568      3.031      0.002       5.955      27.806
# ExterQual                        -6706.5132   1589.108     -4.220      0.000   -9824.530   -3588.496
# ExterCond                          851.1262    965.598      0.881      0.378   -1043.489    2745.742
# BsmtQual                         -2472.5484    801.739     -3.084      0.002   -4045.654    -899.443
# BsmtCond                           822.3848    727.413      1.131      0.258    -604.885    2249.655
# BsmtExposure                     -1548.6097    652.824     -2.372      0.018   -2829.526    -267.693
# BsmtFinType1                       594.1241    374.592      1.586      0.113    -140.869    1329.117
# BsmtFinSF1                          19.8006      2.264      8.745      0.000      15.358      24.243
# BsmtFinType2                      -559.1035    753.202     -0.742      0.458   -2036.974     918.767
# BsmtFinSF2                           4.9944      4.297      1.162      0.245      -3.437      13.426
# BsmtUnfSF                           -5.2189      2.235     -2.335      0.020      -9.604      -0.834
# TotalBsmtSF                         19.5761      3.141      6.232      0.000      13.412      25.740
# HeatingQC                         -241.4241    463.540     -0.521      0.603   -1150.944     668.096
# GarageTypeDummy_Basment           2.046e+04   1.37e+04      1.494      0.135   -6402.289    4.73e+04
# GarageTypeDummy_BuiltIn           1.881e+04   1.21e+04      1.551      0.121   -4987.660    4.26e+04
# GarageTypeDummy_CarPort           2.547e+04   1.69e+04      1.511      0.131   -7614.355    5.86e+04
# GarageTypeDummy_Detchd            2.187e+04   1.18e+04      1.851      0.064   -1312.561    4.51e+04
# GarageTypeDummy_No_Garage          -6.7e+04   1.16e+05     -0.580      0.562   -2.94e+05     1.6e+05
# PavedDriveDummy_P                 -621.2345   5597.536     -0.111      0.912   -1.16e+04    1.04e+04
# PavedDriveDummy_Y                 2146.0134   3689.618      0.582      0.561   -5093.450    9385.476
# MiscFeatureDummy_No_Misc_Feature  1.541e+05   1.28e+05      1.201      0.230   -9.76e+04    4.06e+05
# MiscFeatureDummy_Othr             1.603e+05   1.32e+05      1.217      0.224   -9.81e+04    4.19e+05
# MiscFeatureDummy_Shed             1.504e+05   1.23e+05      1.223      0.222    -9.1e+04    3.92e+05
# MiscFeatureDummy_TenC            -6.509e-12   3.09e-12     -2.109      0.035   -1.26e-11   -4.53e-13
# SaleTypeDummy_CWD                 5.776e+04   1.51e+04      3.832      0.000    2.82e+04    8.73e+04
# SaleTypeDummy_Con                 3.541e+04   1.53e+04      2.307      0.021    5291.447    6.55e+04
# SaleTypeDummy_ConLD               6196.7941   1.07e+04      0.577      0.564   -1.49e+04    2.73e+04
# SaleTypeDummy_ConLI              -1833.5702   1.26e+04     -0.146      0.884   -2.65e+04    2.28e+04
# SaleTypeDummy_ConLw              -6386.0839   1.14e+04     -0.558      0.577   -2.88e+04    1.61e+04
# SaleTypeDummy_New                -5435.8759    1.6e+04     -0.339      0.735   -3.69e+04     2.6e+04
# SaleTypeDummy_Oth                 1.598e+04   1.52e+04      1.050      0.294   -1.39e+04    4.58e+04
# SaleTypeDummy_WD                  1263.8332   3846.577      0.329      0.743   -6283.601    8811.267
# SaleConditionDummy_AdjLand        2.694e+04   2.21e+04      1.217      0.224   -1.65e+04    7.04e+04
# SaleConditionDummy_Alloca         1.036e+04    1.1e+04      0.944      0.346   -1.12e+04    3.19e+04
# SaleConditionDummy_Family         8020.7451   5758.012      1.393      0.164   -3277.148    1.93e+04
# SaleConditionDummy_Normal         7006.6084   2734.173      2.563      0.011    1641.842    1.24e+04
# SaleConditionDummy_Partial        2.646e+04   1.57e+04      1.691      0.091   -4246.642    5.72e+04
# MSSubClassDummy_150                       0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      281.982   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4880.172
# Skew:                           0.501   Prob(JB):                         0.00
# Kurtosis:                      12.388   Cond. No.                     6.97e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.84e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.cv_results_

# %%
gridRidge.best_params_

# %%
gridRidge.best_score_

# %%
gridRidge.best_estimator_.coef_

# %%
getFeatureImportance(50, train.columns, gridRidge.best_estimator_.coef_,'descending')

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.cv_results_

# %%
gridLasso.best_params_

# %%
gridLasso.best_score_

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.best_score_

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.best_score_

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)

# %%
mostCorrelatedFeat.head(50)

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF', 'OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
