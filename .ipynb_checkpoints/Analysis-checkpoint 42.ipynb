# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2251.8784611207543), ('GrLivArea', 1621.8437939168568), ('GarageCars', 942.8239702921827), ('TotalBsmtSF', 863.2138043610047), ('GarageArea', 842.0719541559446), ('ExterQual', 806.4871697900704), ('1stFlrSF', 788.7742226237553), ('BsmtQual', 703.1963975032354), ('FullBath', 698.3753520971205), ('KitchenQual', 692.6520906338488), ('YearBuilt', 587.1286863556314), ('TotRmsAbvGrd', 520.0438598101194), ('YearRemodAdd', 473.97308830137996), ('Fireplaces', 331.8773605649365), ('GarageFinish', 317.4888640677375), ('MasVnrArea', 312.1147666004736), ('HeatingQC', 273.6083401069908), ('MSSubClassDummy_60', 240.35101269845242), ('BsmtFinSF1', 239.86146658013612), ('LotFrontage', 218.46609740580277), ('NeighborhoodDummy_NoRidge', 216.93328241284607), ('NeighborhoodDummy_NridgHt', 177.277211302802), ('LotArea', 173.18040814117074), ('WoodDeckSF', 156.0780224541927), ('MSZoningDummy_RM', 150.63036699355445), ('2ndFlrSF', 144.85015743350974), ('OpenPorchSF', 136.14423120880892), ('BsmtExposure', 130.6373819655409), ('HalfBath', 108.22497765491298), ('MSZoningDummy_RL', 100.44437397462303), ('LotShapeDummy_Reg', 94.25406239534628), ('MSSubClassDummy_30', 86.33218063166743), ('BsmtFullBath', 84.37341855448828), ('GarageYrBlt', 75.0070565433959), ('NeighborhoodDummy_OldTown', 65.16131033744274), ('GarageCond', 65.10830906728215), ('NeighborhoodDummy_NAmes', 56.946705810657576), ('BsmtUnfSF', 53.81774709196919), ('GarageQual', 52.87950432002482), ('BedroomAbvGr', 50.96087855812155), ('NeighborhoodDummy_StoneBr', 47.78323759052707), ('PoolQC', 44.59803790662302), ('NeighborhoodDummy_Edwards', 43.35582102686596), ('NeighborhoodDummy_IDOTRR', 40.213922523671144), ('MSSubClassDummy_50', 38.76890655368006), ('Fence', 37.16925974081613), ('NeighborhoodDummy_Somerst', 32.87762270870562), ('NeighborhoodDummy_Sawyer', 25.396910887340134), ('NeighborhoodDummy_Timber', 25.206108370852448), ('NeighborhoodDummy_BrkSide', 24.874894690064107), ('OverallCond', 24.433800691558158), ('ExterCond', 23.459201596234237), ('EnclosedPorch', 22.537763752280078), ('AlleyDummy_No_Alley_Access', 21.293261762423395), ('LotConfigDummy_CulDSac', 20.87467960375782), ('MSSubClassDummy_160', 20.771112163170905), ('Condition1Dummy_Norm', 20.479580064126512), ('PoolArea', 19.61285610382344), ('NeighborhoodDummy_BrDale', 16.55111012545141), ('KitchenAbvGr', 15.912716002955403), ('Condition1Dummy_Feedr', 15.57528892508277), ('NeighborhoodDummy_MeadowV', 15.140243647366981), ('NeighborhoodDummy_CollgCr', 14.18526451930505), ('MSZoningDummy_FV', 12.804132029394129), ('BsmtFinType1', 12.688575682080595), ('LandContourDummy_HLS', 11.999424791843014), ('MSSubClassDummy_190', 11.002714970643005), ('BsmtCond', 10.76298453966304), ('MSSubClassDummy_90', 10.120743607103778), ('BsmtFinType2', 9.630464596220076), ('LotConfigDummy_Inside', 8.997046808754147), ('MSSubClassDummy_45', 8.458397673512058), ('LowQualFinSF', 6.286358994206317), ('NeighborhoodDummy_SWISU', 6.241328209327322), ('LotShapeDummy_IR2', 5.911264483543547), ('NeighborhoodDummy_Crawfor', 5.250617152486328), ('MoSold', 5.148128677706212), ('MSSubClassDummy_180', 4.889436808268398), ('NeighborhoodDummy_Mitchel', 4.515026733075383), ('MSSubClassDummy_85', 4.1755081134439065), ('BsmtHalfBath', 4.064879361701746), ('MSZoningDummy_RH', 4.049144476662509), ('NeighborhoodDummy_ClearCr', 3.9989394734638593), ('Condition1Dummy_PosA', 3.940944519424972), ('NeighborhoodDummy_Gilbert', 3.588467066095767), ('Condition1Dummy_RRAe', 3.510489751119164), ('NeighborhoodDummy_Veenker', 3.2750002001100067), ('ScreenPorch', 3.23856931111483), ('MSSubClassDummy_120', 3.0442790887162503), ('Condition1Dummy_PosN', 2.426856407739879), ('NeighborhoodDummy_NPkVill', 2.2686984209097525), ('NeighborhoodDummy_SawyerW', 1.8989837891877643), ('MSSubClassDummy_70', 1.7844257737198834), ('LandSlope', 1.584001983136575), ('LandContourDummy_Low', 1.531925594046794), ('StreetDummy_Pave', 1.4796346048598723), ('FireplaceQu', 1.4181077842080836), (' ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.47197289, 0.22329693]),
#  'std_fit_time': array([0.05166106, 0.01806022]),
#  'mean_score_time': array([0.01072516, 0.01110277]),
#  'std_score_time': array([0.0017159 , 0.00152484]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86744176, 0.87848495]),
#  'split1_test_score': array([0.90065634, 0.86967692]),
#  'split2_test_score': array([0.85796595, 0.86036123]),
#  'split3_test_score': array([0.88537998, 0.89230011]),
#  'split4_test_score': array([0.79656743, 0.76139976]),
#  'mean_test_score': array([0.86160229, 0.85244459]),
#  'std_test_score': array([0.035686  , 0.04672334]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8616022908145036

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.517315078068983),
#  ('GrLivArea', 0.1433513542682493),
#  ('BsmtFinSF1', 0.04637887565243068),
#  ('TotalBsmtSF', 0.04613244963271769),
#  ('GarageArea', 0.04057862796674173),
#  ('1stFlrSF', 0.026650079172518402),
#  ('GarageCars', 0.018826660376921992),
#  ('2ndFlrSF', 0.015237222993720805),
#  ('FullBath', 0.012354821158185298),
#  ('YearBuilt', 0.009256148552073701),
#  ('MasVnrArea', 0.009103411911906214),
#  ('LotArea', 0.009083668622334284),
#  ('YearRemodAdd', 0.008287200778189667),
#  ('BsmtUnfSF', 0.00555132106556555),
#  ('GarageYrBlt', 0.005099506185177278),
#  ('LotFrontage', 0.00489406475183554),
#  ('OverallCond', 0.004448372678614512),
#  ('WoodDeckSF', 0.004424762320192995),
#  ('OpenPorchSF', 0.004027570396500493),
#  ('BsmtQual', 0.0037130942779647186),
#  ('KitchenQual', 0.0030059790414485752),
#  ('Fireplaces', 0.0026625985503454658),
#  ('MoSold', 0.0025979663006653786),
#  ('GarageFinish', 0.002273480873817567),
#  ('BsmtFinType1', 0.002124950939544461),
#  ('HeatingDummy_Wall', 0.0020122389159218813),
#  ('PoolArea', 0.001986768306287958),
#  ('TotRmsAbvGrd', 0.0018256951546851185),
#  ('BsmtExposure', 0.0017783755644012822),
#  ('MSZoningDummy_RL', 0.0017571725122435264),
#  ('GarageTypeDummy_CarPort', 0.0017320019786009068),
#  ('FunctionalDummy_Typ', 0.0016987606799451045),
#  ('ExterQual', 0.0016260928929802273),
#  ('BsmtFullBath', 0.0015187916064030654),
#  ('FireplaceQu', 0.0015068451166806243),
#  ('BedroomAbvGr', 0.0014797307936376019),
#  ('LotShapeDummy_IR3', 0.0014377529728479802),
#  ('HalfBath', 0.0014072613930400052),
#  ('YrSold', 0.0014064493647871245),
#  ('PoolQC', 0.0011720488560289467),
#  ('MSSubClassDummy_50', 0.001021905504179966),
#  ('NeighborhoodDummy_CollgCr', 0.0009713729892395961),
#  ('Exterior2ndDummy_Stucco', 0.0009570499956678547),
#  ('KitchenAbvGr', 0.0009010187001186392),
#  ('EnclosedPorch', 0.0009008589337306072),
#  ('SaleTypeDummy_New', 9.866704904653719e-07),
#  ('MSSubClassDummy_30', 9.237670442981806e-07),
#  ('FoundationDummy_Stone', 8.611398214717422e-07),
#  ('Exterior1stDummy_HdBoard', 7.415196394516315e-07),
#  ('HouseStyleDummy_2.5Fin', 4.2176687230644454e-07),
#  ('MSSubClassDummy_160', 4.0094128218748337e-07),
#  ('Condition2Dummy_RRAn', 3.464187789149086e-07),
#  ('Condition1Dummy_RRNe', 2.364311592983751e-07),
#  ('RoofStyleDummy_Hip', 2.2055627119770091e-07),
#  ('FoundationDummy_Slab', 1.981221687550612e-07),
#  ('Exterior1stDummy_WdShing', 1.4007086185762839e-07),
#  ('LandContourDummy_Lvl', 1.2143468946748536e-07),
#  ('RoofMatlDummy_Metal', 1.1290356109012834e-07),
#  ('SaleTypeDummy_WD', 7.872967850674163e-08),
#  ('LotConfigDummy_Inside', 6.788155425257057e-08),
#  ('Exterior1stDummy_BrkFace', 2.3513355667536188e-08),
#  ('Condition2Dummy_RRAe', 1.2607645282424009e-08),
#  ('MiscFeatureDummy_No_Misc_Feature', 7.504101409152192e-09),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02813001, 0.00465884, 0.0048646 , 0.00489836, 0.00468745,
#         0.00465064, 0.00453181, 0.00475359]),
#  'std_fit_time': array([4.61190296e-02, 3.89181057e-04, 2.01807299e-04, 7.93430954e-05,
#         2.36509048e-04, 1.45380088e-04, 2.08989485e-04, 1.89718759e-04]),
#  'mean_score_time': array([0.00257978, 0.00247765, 0.00262299, 0.00265226, 0.00255852,
#         0.00240874, 0.00228562, 0.0026279 ]),
#  'std_score_time': array([2.35061983e-04, 2.35790792e-04, 1.86755853e-04, 1.26037415e-04,
#         6.29301131e-05, 2.23720846e-04, 3.04406157e-04, 1.39957140e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.8995465 , 0.90146232, 0.90414703, 0.90748983, 0.90855682,
#         0.90924735, 0.89432085, 0.86928958]),
#  'split1_test_score': array([0.90822609, 0.90849556, 0.90876029, 0.90947198, 0.90952052,
#         0.90939362, 0.88555181, 0.85501653]),
#  'split2_test_score': array([0.85876108, 0.86606173, 0.87519885, 0.88153102, 0.8821373 ,
#         0.88230922, 0.8701738 , 0.84840806]),
#  'split3_test_score': array([0.90789435, 0.90858145, 0.91129377, 0.91491425, 0.91576568,
#         0.91624812, 0.9084685 , 0.8898816 ]),
#  'split4_test_score': array([0.86698829, 0.86759937, 0.86741284, 0.86279945, 0.86033849,
#  ('Exterior2ndDummy_HdBoard', 1031.739181410233),
#  ('OpenPorchSF', 1025.3087908842376),
#  ('GarageTypeDummy_Basment', 1022.7567780923134),
#  ('MasVnrTypeDummy_Stone', 1004.9619654906454),
#  ('FoundationDummy_Stone', -1003.2740119389864),
#  ('NeighborhoodDummy_StoneBr', -981.8882011770354),
#  ('HeatingQC', -981.4021311387684),
#  ('Exterior2ndDummy_Other', -971.9715032223537),
#  ('LotFrontage', 956.1663042580335),
#  ('MiscFeatureDummy_TenC', 937.9597311853373),
#  ('MSSubClassDummy_180', -937.0210864807336),
#  ('NeighborhoodDummy_OldTown', -932.995046587588),
#  ('LandContourDummy_Lvl', -920.9208602886783),
#  ('FunctionalDummy_Min2', -908.8736603273729),
#  ('SaleConditionDummy_AdjLand', 890.7372866856656),
#  ('BsmtUnfSF', -889.2562595148253),
#  ('Exterior1stDummy_HdBoard', -878.3915070036044),
#  ('Condition1Dummy_RRNn', -864.7175650110083),
#  ('Exterior2ndDummy_CmentBd', -857.0235952060862),
#  ('Exterior1stDummy_Wd Sdng', 852.9058609835122),
#  ('Exterior2ndDummy_VinylSd', 844.0108390269036),
#  ('NeighborhoodDummy_NAmes', 841.7956437417716),
#  ('MSZoningDummy_FV', 823.8480233931923),
#  ('GarageFinish', -807.0121836722336),
#  ('ExterCond', 803.1912579047407),
#  ('Exterior1stDummy_CemntBd', -790.2055319014295),
#  ('HouseStyleDummy_SLvl', -790.2015536915837),
#  ('SalePrice', -786.1214647916228),
#  ('Condition2Dummy_RRNn', -756.422531688107),
#  ('GarageYrBlt', -756.0617174507651),
#  ('Exterior1stDummy_ImStucc', 728.0791742310863),
#  ('BsmtCond', 715.7424481121365),
#  ('MSSubClassDummy_80', -687.1225570677791),
#  ('MSSubClassDummy_45', -675.8345019712559),
#  ('HeatingDummy_GasW', -667.5589726560665),
#  ('Exterior2ndDummy_Brk Cmn', -664.1991123744477),
#  ('LotConfigDummy_FR2', -647.7614625123374),
#  ('ElectricalDummy_SBrkr', -647.4553522337931),
#  ('NeighborhoodDummy_Timber', 642.2846471396107),
#  ('SaleTypeDummy_Con', 637.9755626460027),
#  ('HalfBath', 635.3320507757802),
#  ('Exterior2ndDummy_CBlock', 617.0539574073856),
#  ('HouseStyleDummy_2.5Fin', -605.9844871026061),
#  ('FireplaceQu', -599.30282942918),
#  ('SaleTypeDummy_WD', 580.9500746582472),
#  ('MasVnrTypeDummy_BrkFace', -576.6807588771554),
#  ('GarageTypeDummy_Detchd', 576.4100626751093),
#  ('BldgTypeDummy_TwnhsE', 575.8788642687281),
#  ('MSZoningDummy_RL', 563.631803151009),
#  ('Exterior1stDummy_MetalSd', -557.6267025392364),
#  ('Exterior2ndDummy_Plywood', 548.3127345037719),
#  ('SaleConditionDummy_Alloca', 544.92434968939),
#  ('Condition1Dummy_RRAe', 539.2012060592225),
#  ('BsmtFinSF2', 535.7999228909538),
#  ('NeighborhoodDummy_Sawyer', -521.7396825136435),
#  ('FunctionalDummy_Min1', 505.652270399797),
#  ('ElectricalDummy_Mix', -482.3558623543216),
#  ('LotShapeDummy_IR2', -474.2092518322563),
#  ('RoofStyleDummy_Gambrel', 463.78600001481215),
#  ('Exterior2ndDummy_Stone', 436.1224415598787),
#  ('MSSubClassDummy_50', 435.7353561165947),
#  ('Exterior2ndDummy_AsphShn', 427.28200225080053),
#  ('FoundationDummy_Slab', -426.1177738773438),
#  ('Exterior1stDummy_Plywood', -423.6000982260704),
#  ('LotShapeDummy_IR3', 405.6250164053805),
#  ('EnclosedPorch', 384.9700883168826),
#  ('NeighborhoodDummy_Gilbert', -384.5057683115227),
#  ('GarageTypeDummy_BuiltIn', 380.5047131115171),
#  ('BldgTypeDummy_2fmCon', -366.8668834741469),
#  ('MSSubClassDummy_85', -366.8668834741443),
#  ('Fence', 358.8424492715334),
#  ('MSSubClassDummy_70', 358.8027038545827),
#  ('MiscFeatureDummy_Othr', 354.39102388877103),
#  ('RoofMatlDummy_Metal', -351.8096849917759),
#  ('Exterior1stDummy_AsphShn', -340.53383771716904),
#  ('YrSold', -334.5924236743043),
#  ('BsmtFinType2', -328.44432187030674),
#  ('LandSlope', 326.42856241503534),
#  ('FunctionalDummy_Maj2', -323.28734736895876),
#  ('HeatingDummy_GasA', -320.62308872918595),
#  ('StreetDummy_Pave', 320.59058510189374),
#  ('NeighborhoodDummy_IDOTRR', -315.82678116494884),
#  ('SaleTypeDummy_New', 312.00819248016387),
#  ('SaleTypeDummy_Oth', 310.32276915250065),
#  ('LotConfigDummy_Inside', 308.56316094028153),
#  ('Condition1Dummy_RRNe', 302.90872437615656),
#  ('PavedDriveDummy_Y', -294.8625070567705),
#  ('RoofMatlDummy_Tar&Grv', -290.9181675073219),
#  ('ElectricalDummy_FuseP', 288.8051364148375),
#  ('Condition1Dummy_RRAn', -276.48344617514744),
#  ('MiscFeatureDummy_No_Misc_Feature', 268.8583406697033),
#  ('SaleTypeDummy_ConLD', -268.13699299139955),
#  ('HeatingDummy_Wall', -246.82191774702605),
#  ('MSSubClassDummy_40', -241.36386981687392),
#  ('HouseStyleDummy_1.5Unf', 231.5537546519584),
#  ('Exterior1stDummy_Stucco', -230.18038852617505),
#  ('NeighborhoodDummy_Veenker', 222.21911187559013),
#  ('Condition2Dummy_Feedr', -216.82420845809085),
#  ('NeighborhoodDummy_SawyerW', 209.560055591214),
#  ('MSSubClassDummy_30', -205.39008785833514),
#  ('Exterior1stDummy_WdShing', 194.8081617955352),
#  ('HouseStyleDummy_2Story', -191.05993759974086),
#  ('GarageCond', 188.76790869017898),
#  ('Exterior2ndDummy_MetalSd', -181.27266875746793),
#  ('Exterior2ndDummy_BrkFace', -176.18034706509792),
#  ('Exterior1stDummy_BrkFace', -176.18034706509047),
#  ('LandContourDummy_Low', 174.66106568503542),
#  ('3SsnPorch', 167.5401737272519),
#  ('RoofMatlDummy_WdShake', 166.83153751618914),
#  ('Condition2Dummy_RRAn', -158.26840837511352),
#  ('SaleTypeDummy_ConLI', -155.4115165886212),
#  ('GarageQual', 150.8842538059188),
#  ('FoundationDummy_Wood', -143.92178730461438),
#  ('LowQualFinSF', 131.81654343924325),
#  ('RoofMatlDummy_Roll', 130.0176459839313),
#  ('Exterior1stDummy_Stone', -126.09757086882958),
#  ('Exterior2ndDummy_Wd Shng', 124.60627426924053),
#  ('LotConfigDummy_FR3', -121.72918804030824),
#  ('Exterior2ndDummy_ImStucc', 117.24491007858288),
#  ('CentralAirDummy_Y', -113.79373694410806),
#  ('RoofStyleDummy_Shed', 108.37799348086709),
#  ('Exterior2ndDummy_Stucco', 107.19517050146794),
#  ('Condition2Dummy_RRAe', -100.4932220865317),
#  ('Condition1Dummy_Norm', 94.2573887968062),
#  ('RoofStyleDummy_Hip', 79.76068249993065),
#  ('RoofStyleDummy_Gable', -74.23185451711791),
#  ('FunctionalDummy_Typ', -72.49685332891785),
#  ('NeighborhoodDummy_BrkSide', -72.00310874677712),
#  ('GarageTypeDummy_Attchd', 67.40528024374981),
#  ('MSSubClassDummy_160', -61.40648342936526),
#  ('MoSold', -60.739670592770636),
#  ('Exterior1stDummy_CBlock', -54.22391049085815),
#  ('BsmtHalfBath', 51.66833409714594),
#  ('AlleyDummy_No_Alley_Access', 43.682404934351105),
#  ('NeighborhoodDummy_SWISU', -37.221379568334214),
#  ('BsmtFinType1', 31.440575917811053),
#  ('AlleyDummy_Pave', 24.438715073107392),
#  ('MSSubClassDummy_60', 12.491994350177075),
#  ('GarageTypeDummy_No_Garage', -8.601185392131196),
#  ('MiscVal', 5.9709403021633065),
#  ('ElectricalDummy_FuseF', -3.240373289020388),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145586400177.7588, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145152228628.81766, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148737404580.76797, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160290023740.80756, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137538348094.85025, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80826899629.03986, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102222466078.4245, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122108150598.97112, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106550189834.67392, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109088152455.12248, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4748647903.648529, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11081595, 0.12664466, 0.11759119, 0.08372893, 0.06029286,
#         0.04870968, 0.01038313, 0.00799761]),
#  'std_fit_time': array([0.00571737, 0.01582861, 0.00286295, 0.00873252, 0.00461481,
#         0.00336866, 0.00300628, 0.00126235]),
#  'mean_score_time': array([0.00246964, 0.00289536, 0.00251465, 0.00289807, 0.00259504,
#         0.00280166, 0.00267897, 0.00252528]),
#  'std_score_time': array([2.69529250e-04, 1.01608052e-03, 3.43244908e-04, 1.05734336e-04,
#         3.49135876e-04, 1.38073220e-04, 9.97979960e-05, 1.66816108e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.9001872 , 0.90077629, 0.90331857, 0.90574243, 0.90714474,
#         0.90819802, 0.90446114, 0.88808825]),
#  'split1_test_score': array([0.9081637 , 0.90837974, 0.90934871, 0.91031851, 0.91142633,
#         0.91240511, 0.91283781, 0.90300114]),
#  'split2_test_score': array([0.86102455, 0.86293137, 0.86884752, 0.88045731, 0.88595462,
#         0.88966199, 0.88569806, 0.87287884]),
#  'split3_test_score': array([0.90763083, 0.90788392, 0.9096025 , 0.91220966, 0.91371336,
#         0.91508202, 0.91582864, 0.89843499]),
#  'split4_test_score': array([0.86630764, 0.86650362, 0.86737548, 0.86875123, 0.86898043,
#         0.86885163, 0.86846287, 0.860721  ]),
#  'mean_test_score': array([0.88866278, 0.88929499, 0.89169855, 0.89549583, 0.8974439 ,
#         0.89883975, 0.89745771, 0.88462485]),
#  'std_test_score': array([0.02067128, 0.02027848, 0.01939529, 0.01758117, 0.01730019,
#         0.01742943, 0.01790015, 0.01580991]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8988397519955029

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 26077.74245249362),
#  ('OverallQual', 10227.71048019341),
#  ('PoolQC', -9866.193427212374),
#  ('YearBuilt', 9171.877861342946),
#  ('BsmtFinSF1', 8324.316914831392),
#  ('OverallCond', 6030.951168497664),
#  ('TotalBsmtSF', 5734.757892519703),
#  ('LotArea', 5712.5090487747675),
#  ('SaleConditionDummy_Normal', 4987.390176241779),
#  ('PoolArea', -4796.550847529543),
#  ('MasVnrArea', 4192.611858687783),
#  ('NeighborhoodDummy_Somerst', 4141.05921802026),
#  ('BsmtQual', -4048.0960229241546),
#  ('FunctionalDummy_Sev', 3879.3240250468148),
#  ('NeighborhoodDummy_NoRidge', 3840.3049454940588),
#  ('KitchenQual', -3802.8318413394913),
#  ('2ndFlrSF', 3508.306127797024),
#  ('NeighborhoodDummy_NWAmes', 3402.5820918335276),
#  ('Exterior1stDummy_BrkComm', 2961.84033000755),
#  ('GarageCars', 2719.3060471561184),
#  ('MSSubClassDummy_120', -2713.124035829752),
#  ('Condition1Dummy_Feedr', 2654.916932202765),
#  ('NeighborhoodDummy_CollgCr', 2652.1850188580634),
#  ('KitchenAbvGr', -2648.074440135398),
#  ('BedroomAbvGr', -2598.2755676222),
#  ('HouseStyleDummy_1.5Unf', 2551.6740801416354),
#  ('MSSubClassDummy_90', -2533.0511064086268),
#  ('NeighborhoodDummy_NPkVill', -2452.6509767539956),
#  ('SaleConditionDummy_AdjLand', 773.4951408406778),
#  ('BldgTypeDummy_TwnhsE', 743.2772579310948),
#  ('MSZoningDummy_FV', 722.088250830394),
#  ('FunctionalDummy_Min2', -721.5536519007825),
#  ('MasVnrTypeDummy_Stone', 692.2233697027555),
#  ('GarageFinish', -673.6708629353404),
#  ('Exterior1stDummy_VinylSd', -670.048585125957),
#  ('SaleConditionDummy_Alloca', 669.5663826991577),
#  ('HeatingQC', -651.061767449809),
#  ('NeighborhoodDummy_OldTown', -650.3127472093774),
#  ('FullBath', 621.0427169354076),
#  ('Condition1Dummy_RRNn', -612.4267451759932),
#  ('Exterior1stDummy_HdBoard', -610.7778995898304),
#  ('BsmtCond', 604.8662085621672),
#  ('LandContourDummy_Lvl', -581.3246414158995),
#  ('SaleTypeDummy_WD', 568.7390266672414),
#  ('NeighborhoodDummy_Sawyer', -555.4737313635318),
#  ('MasVnrTypeDummy_BrkFace', -542.0630811777909),
#  ('NeighborhoodDummy_Timber', 530.8393381452696),
#  ('LotConfigDummy_FR2', -526.8015170817639),
#  ('LotShapeDummy_IR3', 487.9052085929844),
#  ('FireplaceQu', -484.2625615222553),
#  ('MiscFeatureDummy_Othr', 477.77760635940143),
#  ('Condition1Dummy_RRAe', 461.9881486926448),
#  ('Exterior2ndDummy_HdBoard', 456.8394846262068),
#  ('Exterior2ndDummy_CBlock', 449.87923341907856),
#  ('SaleTypeDummy_Con', 434.2093971379439),
#  ('Exterior1stDummy_Plywood', -428.28202137668876),
#  ('Exterior2ndDummy_Stone', 412.9429766925198),
#  ('EnclosedPorch', 394.8395358797942),
#  ('LotShapeDummy_IR2', -388.2063157421766),
#  ('Exterior2ndDummy_Plywood', 375.19022822722155),
#  ('RoofMatlDummy_Tar&Grv', -359.60684078427875),
#  ('HeatingDummy_GasW', -356.8784085693493),
#  ('GarageTypeDummy_Basment', 356.6426077624141),
#  ('ElectricalDummy_SBrkr', -333.1464437443833),
#  ('Condition1Dummy_RRNe', 327.38138422458917),
#  ('LotFrontage', 325.3062412678702),
#  ('GarageTypeDummy_BuiltIn', 309.91757651922234),
#  ('RoofMatlDummy_Metal', -304.0679910180689),
#  ('BsmtFinType2', -291.8488847332355),
#  ('NeighborhoodDummy_SWISU', 282.64069475152735),
#  ('SaleTypeDummy_Oth', 271.3384210639271),
#  ('HeatingDummy_GasA', -264.5511233532842),
#  ('HeatingDummy_Wall', -263.28669782390045),
#  ('TotRmsAbvGrd', 261.4544469473582),
#  ('ElectricalDummy_Mix', -256.27708383296505),
#  ('ElectricalDummy_FuseP', 213.7661981485564),
#  ('SaleTypeDummy_ConLD', -203.87361212026354),
#  ('Exterior2ndDummy_VinylSd', 203.7182552413586),
#  ('SaleTypeDummy_New', 200.52251129889657),
#  ('FunctionalDummy_Typ', -199.769332931419),
#  ('YrSold', -187.30780056495854),
#  ('LandContourDummy_Low', 180.5729859035041),
#  ('Fence', 178.316582898252),
#  ('LotConfigDummy_Inside', 175.60832292067607),
#  ('Exterior1stDummy_BrkFace', -175.60499677706795),
#  ('FoundationDummy_Slab', -171.74879601625176),
#  ('BldgTypeDummy_2fmCon', -171.56080105682253),
#  ('SaleTypeDummy_ConLI', -165.4954029805915),
#  ('MSSubClassDummy_45', -165.0414797556343),
#  ('Exterior2ndDummy_AsphShn', 160.01571619257922),
#  ('Exterior1stDummy_CemntBd', -156.2037504537781),
#  ('Exterior1stDummy_AsphShn', -153.72613939200858),
#  ('Condition1Dummy_RRAn', -144.79046597307664),
#  ('StreetDummy_Pave', 139.2669839245094),
#  ('Exterior2ndDummy_MetalSd', -139.03931493083311),
#  ('MSSubClassDummy_80', -138.55402117704617),
#  ('LowQualFinSF', -135.69427728042982),
#  ('AlleyDummy_No_Alley_Access', -132.61461057731663),
#  ('RoofStyleDummy_Hip', 129.34164388780212),
#  ('PavedDriveDummy_Y', -117.7576121146358),
#  ('MSSubClassDummy_85', -100.14519260779336),
#  ('SalePrice', -86.46590319969495),
#  ('HouseStyleDummy_2.5Fin', -55.13065418413599),
#  ('NeighborhoodDummy_Veenker', 51.5388997934992),
#  ('MSSubClassDummy_60', 49.66851526065224),
#  ('MSSubClassDummy_30', -49.63130652059851),
#  ('RoofStyleDummy_Gable', -48.01815434807339),
#  ('ElectricalDummy_FuseF', -30.856655124831132),
#  ('GarageCond', 27.830052925585015),
#  ('LandSlope', 20.64890709752607),
#  ('Exterior2ndDummy_BrkFace', -0.40215351130858823),
#  ('BsmtFinType1', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('BsmtHalfBath', 0.0),
#  ('HalfBath', -0.0),
#  ('GarageQual', 0.0),
#  ('3SsnPorch', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_50', -0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_160', -0.0),
#  ('MSZoningDummy_RL', 0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('NeighborhoodDummy_BrkSide', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', 0.0),
#  ('NeighborhoodDummy_SawyerW', 0.0),
#  ('Condition1Dummy_Norm', 0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Roll', 0.0),
#  ('RoofMatlDummy_WdShake', -0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', -0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_Stucco', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('FunctionalDummy_Maj2', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('GarageTypeDummy_Attchd', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8578431326060624

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8938511103920479

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159517602958.3592, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162205424652.16125, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164172802262.2277, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176944749912.36118, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146927138970.10168, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86410817857.00858, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118038603883.11288, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114096351448.48853, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77928418934.37401, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31797255809.835785, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6073719650.200073, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8961644584975194

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.999671
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999142
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998543
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996468
# GarageYrBlt               GarageTypeDummy_No_Garage    0.995664
# PoolArea                  PoolQC                       0.988821
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988671
# GarageCars                GarageArea                   0.988444
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.983787
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.982899
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.982898
# GrLivArea                 TotRmsAbvGrd                 0.964623
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.963437
# TotalBsmtSF               1stFlrSF                     0.961141
# ExterQual                 KitchenQual                  0.958153
# OverallQual               ExterQual                    0.953832
# BsmtQual                  FoundationDummy_PConc        0.952627
# ExterQual                 BsmtQual                     0.951580
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.949906
# 2ndFlrSF                  HouseStyleDummy_2Story       0.946217
# OverallQual               BsmtQual                     0.942731
# YearRemodAdd              BsmtQual                     0.942302
#                           FoundationDummy_PConc        0.940474
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.940198
# MasVnrArea                MasVnrTypeDummy_None         0.939581
# OverallQual               KitchenQual                  0.936223
#                           GarageCars                   0.932507
# ExterQual                 FoundationDummy_PConc        0.931151
# OverallQual               FullBath                     0.927291
# YearRemodAdd              ExterQual                    0.926185
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.920767
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.919503
# FoundationDummy_CBlock    FoundationDummy_PConc        0.919269
# HalfBath                  HouseStyleDummy_2Story       0.917890
# YearBuilt                 YearRemodAdd                 0.916431
# BsmtQual                  KitchenQual                  0.915903
# OverallQual               YearRemodAdd                 0.914494
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.914169
# YearBuilt                 BsmtQual                     0.913865
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.912804
# BsmtFinSF1                BsmtFullBath                 0.912638
# MSZoningDummy_RL          MSZoningDummy_RM             0.910244
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.909658
# OverallQual               GarageArea                   0.906575
# HalfBath                  MSSubClassDummy_60           0.905287
# OverallQual               FoundationDummy_PConc        0.904744
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.898948
# BsmtQual                  FullBath                     0.897727
# FullBath                  GarageCars                   0.895220
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 3.045608841657654),
#  ('LotArea', 2.260189429680229),
#  ('OverallQual', 4.563312206913775),
#  ('OverallCond', 2.0353090865404093),
#  ('YearBuilt', 15.820958344196942),
#  ('YearRemodAdd', 3.106005687402844),
#  ('MasVnrArea', 2.6827240561742878),
#  ('ExterQual', 2.9257722858408046),
#  ('BsmtQual', 2.913238945877203),
#  ('BsmtExposure', 1.8229493637348047),
#  ('BsmtFinType1', 2.2488414233676965),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.47192713147006),
#  ('BsmtHalfBath', 1.2501792870916697),
#  ('FullBath', 3.8333011075907826),
#  ('HalfBath', 2.9456109609589625),
#  ('BedroomAbvGr', 3.1121738206291987),
#  ('KitchenAbvGr', 4.357855612976384),
#  ('KitchenQual', 2.2296856371142484),
#  ('TotRmsAbvGrd', 5.524855290178525),
#  ('Fireplaces', 1.881405204460055),
#  ('FireplaceQu', 1.4087165541594198),
#  ('GarageYrBlt', 1164.7322465679003),
#  ('GarageFinish', 2.1415013208458333),
#  ('GarageCars', 6.493257215842996),
#  ('GarageArea', 6.464751046866993),
#  ('WoodDeckSF', 1.3853739125980835),
#  ('OpenPorchSF', 1.4031816888142692),
#  ('EnclosedPorch', 1.510506491188776),
#  ('3SsnPorch', 1.12058273278049),
#  ('ScreenPorch', 1.1874850674944053),
#  ('PoolArea', 7.0817666083611766),
#  ('PoolQC', 7.376475572793969),
#  ('Fence', 1.3494136284370448),
#  ('MiscVal', 1.0589213659142636),
#  ('MoSold', 1.1463202177101197),
#  ('YrSold', 1.1884200261982465),
#  ('MSSubClassDummy_30', 2.5013763272302034),
#  ('MSSubClassDummy_40', 1.131348128103126),
#  ('MSSubClassDummy_45', 13.492527646414654),
#  ('MSSubClassDummy_50', 20.012185255604763),
#  ('MSSubClassDummy_60', 29.318007790423366),
#  ('MSSubClassDummy_70', 8.07688145117132),
#  ('MSSubClassDummy_75', 18.09180214722003),
#  ('MSSubClassDummy_80', 13.49668355503349),
#  ('MSSubClassDummy_85', 4.753039468087338),
#  ('MSSubClassDummy_90', 4.440338615927216),
#  ('MSSubClassDummy_120', 2.7512424566282885),
#  ('MSSubClassDummy_160', 10.285689994767758),
#  ('MSSubClassDummy_180', 2.3242438480306515),
#  ('MSSubClassDummy_190', 2.23548260911607),
#  ('MSZoningDummy_FV', 17.21417581840556),
#  ('MSZoningDummy_RH', 2.999296230208324),
#  ('Exterior1stDummy_HdBoard', 15.007335957865624),
#  ('Exterior1stDummy_ImStucc', 1.1815666633570692),
#  ('Exterior1stDummy_MetalSd', 13.406203985554363),
#  ('Exterior1stDummy_Plywood', 8.040730831615644),
#  ('Exterior1stDummy_Stone', 1.3750856546706915),
#  ('Exterior1stDummy_Stucco', 2.180031813589583),
#  ('Exterior1stDummy_VinylSd', 24.97245033846925),
#  ('Exterior1stDummy_Wd Sdng', 12.490053373602331),
#  ('Exterior1stDummy_WdShing', 2.6673882130757867),
#  ('MasVnrTypeDummy_BrkFace', 27.922088947291165),
#  ('MasVnrTypeDummy_No_MasVnr', 1.571142068852745),
#  ('MasVnrTypeDummy_None', 31.79915189603038),
#  ('MasVnrTypeDummy_Stone', 10.690842122090569),
#  ('FoundationDummy_CBlock', 6.909390234488691),
#  ('FoundationDummy_PConc', 8.192474101629436),
#  ('FoundationDummy_Slab', 2.033727490566529),
#  ('FoundationDummy_Stone', 1.2334722748550002),
#  ('FoundationDummy_Wood', 1.2627902888127227),
#  ('GarageTypeDummy_Attchd', 95.74129203208086),
#  ('GarageTypeDummy_Basment', 6.7260241137541),
#  ('GarageTypeDummy_BuiltIn', 21.754581013386563),
#  ('GarageTypeDummy_CarPort', 2.1245469314412464),
#  ('GarageTypeDummy_Detchd', 81.53603121186289),
#  ('GarageTypeDummy_No_Garage', 1130.5154753073234),
#  ('SaleConditionDummy_AdjLand', 1.0718509981532343),
#  ('SaleConditionDummy_Alloca', 1.4688028937674449),
#  ('SaleConditionDummy_Family', 1.3181732393156875),
#  ('SaleConditionDummy_Normal', 2.63415736821728),
#  ('SaleConditionDummy_Partial', 2.658795935351835),
#  ('constant', 98297.2083256756)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 33.58293911672341),
#  ('LotArea', 11.22140371306806),
#  ('OverallCond', 38.82931754533884),
#  ('YearBuilt', 42538.5832805884),
#  ('YearRemodAdd', 26995.868238068175),
#  ('MasVnrArea', 3.5516567193221524),
#  ('ExterQual', 55.13399652731351),
#  ('BsmtQual', 17.13289383642911),
#  ('BsmtExposure', 9.425021103260589),
#  ('BsmtFinType1', 6.376112582935107),
#  ('BsmtFinSF1', 18.967095070558806),
#  ('BsmtFinSF2', 2.1811682147300715),
#  ('BsmtUnfSF', 21.98626318704971),
#  ('1stFlrSF', 103.32447059826559),
#  ('2ndFlrSF', 28.17323650022436),
#  ('LowQualFinSF', 2.0577311176053343),
#  ('BsmtFullBath', 4.182482688319554),
#  ('BsmtHalfBath', 1.316923163162517),
#  ('FullBath', 35.293300292910686),
#  ('HalfBath', 4.518756313019917),
#  ('BedroomAbvGr', 48.3754146925769),
#  ('KitchenAbvGr', 156.16737101224925),
#  ('KitchenQual', 23.576546088997144),
#  ('TotRmsAbvGrd', 54.73309262603001),
#  ('Fireplaces', 3.5165922005126404),
#  ('FireplaceQu', 11.380824351286254),
#  ('GarageYrBlt', 30585.67163748997),
#  ('GarageFinish', 7.6364950178568884),
#  ('GarageCars', 49.2562843614728),
#  ('GarageArea', 43.30881617570532),
#  ('WoodDeckSF', 2.1924698214144502),
#  ('OpenPorchSF', 2.1501238417426367),
#  ('EnclosedPorch', 1.6762567311973735),
#  ('3SsnPorch', 1.1350248608823559),
#  ('ScreenPorch', 1.2640034583150013),
#  ('PoolArea', 6.73267518172268),
#  ('PoolQC', 5830.125592989228),
#  ('Fence', 15.155007875472766),
#  ('MiscVal', 1.059998971588356),
#  ('MoSold', 5.580628224584688),
#  ('YrSold', 3.4100886652323252),
#  ('MSSubClassDummy_30', 2.367848961654975),
#  ('MSSubClassDummy_40', 1.1286289487144425),
#  ('MSSubClassDummy_45', 13.4685020274942),
#  ('MSSubClassDummy_50', 21.134190089920875),
#  ('MSSubClassDummy_60', 36.925657688939104),
#  ('MSSubClassDummy_70', 8.142538323044674),
#  ('MSSubClassDummy_75', 18.156835947154544),
#  ('MSSubClassDummy_80', 14.0602749701169),
#  ('MSSubClassDummy_85', 4.782463895863145),
#  ('MSSubClassDummy_90', 4.5114426666235445),
#  ('MSSubClassDummy_120', 2.922459931645645),
#  ('MSSubClassDummy_160', 10.682200295891807),
#  ('MSSubClassDummy_180', 2.321801287963383),
#  ('MSSubClassDummy_190', 2.224233982961409),
#  ('MSZoningDummy_FV', 17.792135773226438),
#  ('MSZoningDummy_RH', 2.992041977834977),
#  ('MSZoningDummy_RL', 268.18047779942725),
#  ('MSZoningDummy_RM', 42.89085684995707),
#  ('AlleyDummy_No_Alley_Access', 47.10410048249226),
#  ('AlleyDummy_Pave', 2.626636182727034),
#  ('LotShapeDummy_IR2', 1.292213719052018),
#  ('LotShapeDummy_IR3', 1.11590189494855),
#  ('LotShapeDummy_Reg', 4.416095645753992),
#  ('LotConfigDummy_CulDSac', 1.9136414990081447),
#  ('LotConfigDummy_FR2', 1.4157451269504377),
#  ('LotConfigDummy_FR3', 1.105077332791417),
#  ('MasVnrTypeDummy_No_MasVnr', 1.5771095606677912),
#  ('MasVnrTypeDummy_None', 77.930080938207),
#  ('MasVnrTypeDummy_Stone', 11.580016259125594),
#  ('FoundationDummy_CBlock', 12.071939656776367),
#  ('FoundationDummy_PConc', 13.92538176415434),
#  ('FoundationDummy_Slab', 2.05161801521734),
#  ('FoundationDummy_Stone', 1.2358832322542288),
#  ('FoundationDummy_Wood', 1.2397296241759492),
#  ('GarageTypeDummy_Attchd', 254.5083139044501),
#  ('GarageTypeDummy_Basment', 6.7873608549707996),
#  ('GarageTypeDummy_BuiltIn', 22.941567783451926),
#  ('GarageTypeDummy_CarPort', 2.119017939145835),
#  ('GarageTypeDummy_Detchd', 111.5406038111715),
#  ('GarageTypeDummy_No_Garage', 1030.272695935675),
#  ('SaleConditionDummy_AdjLand', 1.0719002265889357),
#  ('SaleConditionDummy_Alloca', 1.4724997485411322),
#  ('SaleConditionDummy_Family', 1.3333757290547297),
#  ('SaleConditionDummy_Normal', 17.17967745809549),
#  ('SaleConditionDummy_Partial', 2.820446189154482)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996466
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996001
# PoolArea                  PoolQC                       0.991427
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988731
# GarageCars                GarageArea                   0.987650
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.984176
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.965349
# ExterQual                 KitchenQual                  0.953465
# BsmtQual                  FoundationDummy_PConc        0.949355
# ExterQual                 BsmtQual                     0.947326
# 2ndFlrSF                  HouseStyleDummy_2Story       0.945279
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.941076
# MasVnrArea                MasVnrTypeDummy_None         0.936606
# YearRemodAdd              BsmtQual                     0.935815
#                           FoundationDummy_PConc        0.934144
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.927374
# ExterQual                 FoundationDummy_PConc        0.925717
# YearRemodAdd              ExterQual                    0.921435
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.915207
# FoundationDummy_CBlock    FoundationDummy_PConc        0.914955
# HalfBath                  HouseStyleDummy_2Story       0.914566
# BsmtFinSF1                BsmtFullBath                 0.912541
# YearBuilt                 YearRemodAdd                 0.910308
#                           BsmtQual                     0.908863
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.908554
# MSZoningDummy_RL          MSZoningDummy_RM             0.907807
# BsmtQual                  KitchenQual                  0.907282
# HalfBath                  MSSubClassDummy_60           0.902919
# YearRemodAdd              Exterior1stDummy_VinylSd     0.898719
# BsmtQual                  FullBath                     0.889892
# KitchenAbvGr              MSSubClassDummy_90           0.888548
# YearRemodAdd              KitchenQual                  0.887542
# BsmtQual                  Exterior1stDummy_VinylSd     0.886102
# FullBath                  GarageCars                   0.882773
# YearBuilt                 ExterQual                    0.882451
#                           FoundationDummy_PConc        0.881604
# LotFrontage               LotArea                      0.880544
# MSSubClassDummy_60        HouseStyleDummy_2Story       0.879538
# BsmtQual                  GarageCars                   0.879391
# ExterQual                 GarageCars                   0.877437
# KitchenQual               FoundationDummy_PConc        0.877198
# 2ndFlrSF                  HouseStyleDummy_1Story       0.874619
#                           HalfBath                     0.874346
# FullBath                  FoundationDummy_PConc        0.870832
# MasVnrArea                MasVnrTypeDummy_BrkFace      0.869614
# YearBuilt                 GarageCars                   0.867279
# ExterQual                 Exterior1stDummy_VinylSd     0.865658
# YearBuilt                 GarageFinish                 0.862849
# BsmtQual                  GarageFinish                 0.862484
# ExterQual                 FullBath                     0.860868
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173496639158.59833, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174434047290.85004, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178495994381.6061, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193572830782.32248, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152595353363.03116, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82869295152.63322, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132373855959.44525, tolerance: 486508062.7854126
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110407478851.1266, tolerance: 526390851.6509174
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126857735139.63606, tolerance: 528563051.60621333
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50903830399.413055, tolerance: 476803144.95419395
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2909326959.3671875, tolerance: 508790117.61184317
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 673.6343012649536),
#  ('LotArea', 4383.4481840626295),
#  ('OverallCond', 7416.1550916473425),
#  ('YearBuilt', 13276.132658685434),
#  ('YearRemodAdd', 922.595607525677),
#  ('MasVnrArea', 4162.067247619376),
#  ('ExterQual', -3104.6074791650535),
#  ('BsmtQual', -4191.99590740494),
#  ('BsmtExposure', -2404.3214169786115),
#  ('BsmtFinType1', 0.0),
#  ('BsmtFinSF1', 16951.492528077186),
#  ('BsmtFinSF2', 4094.824113046531),
#  ('BsmtUnfSF', 9624.2543239331),
#  ('1stFlrSF', 18546.207026185224),
#  ('2ndFlrSF', 28268.119995963993),
#  ('LowQualFinSF', 1829.7040609145095),
#  ('BsmtFullBath', 1229.7066111823096),
#  ('BsmtHalfBath', -72.9617933887274),
#  ('FullBath', 707.8825150049669),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -3197.6434590213184),
#  ('KitchenAbvGr', -3165.3252732643446),
#  ('KitchenQual', -5158.396283806386),
#  ('TotRmsAbvGrd', 1103.2986765720987),
#  ('Fireplaces', 2434.3992091080736),
#  ('FireplaceQu', -1301.6779319169505),
#  ('GarageYrBlt', -579.9211293275505),
#  ('GarageFinish', -1234.41329828635),
#  ('GarageCars', 3519.9140054909917),
#  ('GarageArea', 2020.9620448966843),
#  ('WoodDeckSF', 1311.8564421171627),
#  ('OpenPorchSF', 682.5024612618196),
#  ('EnclosedPorch', 777.7911612961118),
#  ('3SsnPorch', 64.09613322209496),
#  ('ScreenPorch', 836.8882429016845),
#  ('PoolArea', -4979.192672609698),
#  ('PoolQC', -10275.624452194777),
#  ('Fence', 357.92760077120096),
#  ('MiscVal', 217.01177481696615),
#  ('MoSold', 219.95435220501952),
#  ('YrSold', -223.62130983310405),
#  ('MSSubClassDummy_30', -210.7568100778191),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', 6.406059728951311),
#  ('MSSubClassDummy_50', -1149.1785190007104),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_70', 978.1469973866256),
#  ('MSSubClassDummy_75', 233.58879322751952),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -978.6117186149784),
#  ('MSSubClassDummy_90', -796.1268378801983),
#  ('MSSubClassDummy_120', -4111.710804452644),
#  ('MSSubClassDummy_160', -5253.3313887852355),
#  ('MSSubClassDummy_180', -723.3530636315011),
#  ('MSSubClassDummy_190', -1117.5231512373882),
#  ('MSZoningDummy_FV', 2917.194508401595),
#  ('MSZoningDummy_RH', 900.7946192507295),
#  ('MSZoningDummy_RL', 2132.968334298038),
#  ('MSZoningDummy_RM', 62.56481963738151),
#  ('AlleyDummy_No_Alley_Access', 0.0),
#  ('AlleyDummy_Pave', -0.0),
#  ('LotShapeDummy_IR2', 261.27293018389616),
#  ('LotShapeDummy_IR3', -424.2198428539741),
#  ('LotShapeDummy_Reg', 618.5421783770448),
#  ('LotConfigDummy_CulDSac', 1579.040823678287),
#  ('LotConfigDummy_FR2', -969.8150289485258),
#  ('LotConfigDummy_FR3', -544.2642214384616),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 543.1666344655674),
#  ('NeighborhoodDummy_BrDale', 2695.230834280566),
#  ('NeighborhoodDummy_BrkSide', 1923.6490537099833),
#  ('NeighborhoodDummy_ClearCr', 0.0),
#  ('NeighborhoodDummy_CollgCr', -214.52001817322568),
#  ('NeighborhoodDummy_Crawfor', 3633.681292688652),
#  ('NeighborhoodDummy_Edwards', -1430.589768270948),
#  ('NeighborhoodDummy_Gilbert', -905.9625923538827),
#  ('NeighborhoodDummy_IDOTRR', 0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -1344.010396578289),
#  ('NeighborhoodDummy_NAmes', -643.9153174678696),
#  ('NeighborhoodDummy_NPkVill', 1815.109791191607),
#  ('NeighborhoodDummy_NWAmes', -1621.2942746330893),
#  ('NeighborhoodDummy_NoRidge', 4759.933959761648),
#  ('NeighborhoodDummy_NridgHt', 5130.64016643866),
#  ('NeighborhoodDummy_OldTown', -311.2797433044545),
#  ('NeighborhoodDummy_SWISU', -549.7085226268265),
#  ('NeighborhoodDummy_Sawyer', -125.42541027207072),
#  ('NeighborhoodDummy_SawyerW', -245.1568190356509),
#  ('NeighborhoodDummy_Somerst', 1287.5083633772442),
#  ('NeighborhoodDummy_StoneBr', 5580.921667313056),
#  ('NeighborhoodDummy_Timber', -0.0),
#  ('NeighborhoodDummy_Veenker', 690.6952658971327),
#  ('HouseStyleDummy_1.5Unf', 790.9344233830902),
#  ('HouseStyleDummy_1Story', 0.0),
#  ('HouseStyleDummy_2.5Fin', -1818.5718523841877),
#  ('HouseStyleDummy_2.5Unf', -0.0),
#  ('HouseStyleDummy_2Story', -3651.786488655716),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('HouseStyleDummy_SLvl', 142.0662096260743),
#  ('RoofStyleDummy_Gable', -1721.3803481560137),
#  ('RoofStyleDummy_Gambrel', -437.1041331359585),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', -98.69633381321947),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('Exterior1stDummy_AsphShn', 0.0),
#  ('Exterior1stDummy_BrkComm', -791.0245436161414),
#  ('Exterior1stDummy_BrkFace', 2590.5761810999197),
#  ('Exterior1stDummy_CBlock', -757.3368178992923),
#  ('Exterior1stDummy_CemntBd', 453.5468027488107),
#  ('Exterior1stDummy_HdBoard', -1429.827293680721),
#  ('Exterior1stDummy_ImStucc', -296.7969089988496),
#  ('Exterior1stDummy_MetalSd', 405.0886770078201),
#  ('Exterior1stDummy_Plywood', -716.8124065217378),
#  ('Exterior1stDummy_Stone', -339.2703019856989),
#  ('Exterior1stDummy_Stucco', 505.78084724723885),
#  ('Exterior1stDummy_VinylSd', -367.59279615374294),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 108.62905591172031),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', -584.4187855266733),
#  ('MasVnrTypeDummy_None', 1200.9530167836454),
#  ('MasVnrTypeDummy_Stone', 1845.8261680178107),
#  ('FoundationDummy_CBlock', -395.6701517501896),
#  ('FoundationDummy_PConc', 2039.1607622845545),
#  ('FoundationDummy_Slab', 934.5440325548896),
#  ('FoundationDummy_Stone', -106.96656369740913),
#  ('FoundationDummy_Wood', -940.788931542884),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', 0.0),
#  ('GarageTypeDummy_CarPort', 0.0),
#  ('GarageTypeDummy_Detchd', 105.11859839363258),
#  ('GarageTypeDummy_No_Garage', 0.0),
#  ('SaleConditionDummy_AdjLand', 701.4360337625417),
#  ('SaleConditionDummy_Alloca', 1294.0219605972645),
#  ('SaleConditionDummy_Family', 1073.0916862352278),
#  ('SaleConditionDummy_Normal', 2326.4741871848255),
#  ('SaleConditionDummy_Partial', 4712.681730364539)]

# %%
train['PoolQC']
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0
#        ...
# 1454    3.0
# 1455    3.0
# 1456    3.0
# 1458    3.0
# 1459    3.0
# Name: PoolQC, Length: 1314, dtype: float64

# %%
def addHasPool(data):
    data['hasPool'] = data['PoolQC'].apply(lambda x: 0 if x=='No_Pool' else 1)

# %%
addHasPool(train)

# %%
train

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
X_Scaled.corr()
