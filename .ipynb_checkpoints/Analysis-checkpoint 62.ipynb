# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %% [markdown]
# ## Train w/ dummies

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
# X = train.loc[:, train.columns != 'SalePrice']
# y = train['SalePrice']

# %% [markdown]
# ## Drop columns with all zeros

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k, X, y):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50, X=train.loc[:, train.columns != 'SalePrice'], y=train['SalePrice'])
# Out:
# [('OverallQual', 2372.7126447848145), ('GrLivArea', 1444.1565779447747), ('ExterQual', 1099.9188535587928), ('GarageCars', 990.3554899277999), ('GarageArea', 869.7693818510173), ('TotalBsmtSF', 859.4908225494655), ('KitchenQual', 837.7769324067231), ('BsmtQual', 757.3185340447397), ('1stFlrSF', 737.9692763242194), ('FullBath', 665.5145913172385), ('YearBuilt', 621.2432210094934), ('TotRmsAbvGrd', 552.0206209114684), ('FoundationDummy_PConc', 540.8858098053105), ('YearRemodAdd', 485.9051025823888), ('GarageFinish', 326.3082207325232), ('Fireplaces', 313.41018676860955), ('MasVnrArea', 309.22682401156476), ('HeatingQC', 299.1087440489812), ('NeighborhoodDummy_NridgHt', 291.1918914880675), ('GarageTypeDummy_Detchd', 250.6083680684574), ('FoundationDummy_CBlock', 249.97593637522107), ('MasVnrTypeDummy_None', 238.48120131374088), ('Exterior1stDummy_VinylSd', 221.9191691611338), ('Exterior2ndDummy_VinylSd', 221.67340512855273), ('MSSubClassDummy_60', 221.4501101733423), ('OpenPorchSF', 214.88230739125208), ('BsmtFinSF1', 203.55092120084421), ('LotFrontage', 202.73754666111262), ('GarageTypeDummy_Attchd', 192.50276858620904), ('MasVnrTypeDummy_Stone', 179.77215952935742), ('SaleTypeDummy_New', 174.27572746434868), ('SaleConditionDummy_Partial', 170.4956948372326), ('WoodDeckSF', 151.2365622578128), ('BsmtExposure', 149.63407922322642), ('NeighborhoodDummy_NoRidge', 147.45680052206816), ('LotArea', 146.67272503312253), ('MSZoningDummy_RM', 140.7645042117667), ('2ndFlrSF', 113.69866911655487), ('HalfBath', 103.53091684429191), ('HouseStyleDummy_2Story', 87.87966252878584), ('LotShapeDummy_Reg', 84.31376445935362), ('MSSubClassDummy_30', 79.85778801988306), ('BsmtFullBath', 76.32002833931223), ('MSZoningDummy_RL', 72.476843030211), ('BsmtUnfSF', 72.38616190100242), ('SaleTypeDummy_WD', 71.86717111025547), ('ElectricalDummy_SBrkr', 70.96028919355767), ('GarageYrBlt', 70.2426642521834), ('NeighborhoodDummy_NAmes', 62.93127122074386), ('NeighborhoodDummy_OldTown', 62.576813339594224), ('MasVnrTypeDummy_BrkFace', 60.796516940975785), ('GarageTypeDummy_BuiltIn', 57.65544499151697), ('CentralAirDummy_Y', 55.391394816744096), ('GarageQual', 54.05981102699132), ('GarageCond', 51.67609271317756), ('PavedDriveDummy_Y', 51.15730598845283), ('GarageTypeDummy_No_Garage', 50.057065284456826), ('RoofStyleDummy_Hip', 48.99180206362308), ('NeighborhoodDummy_Edwards', 48.67248898349805), ('RoofStyleDummy_Gable', 46.38231343558393), ('MSSubClassDummy_50', 45.4281445631003), ('Exterior1stDummy_Wd Sdng', 43.176937647433235), ('Exterior2ndDummy_Wd Sdng', 41.29333415105425), ('Fence', 41.24404087564986), ('Exterior1stDummy_MetalSd', 41.031391652409965), ('NeighborhoodDummy_StoneBr', 40.7370972935847), ('NeighborhoodDummy_Somerst', 39.73016236789747), ('Exterior2ndDummy_MetalSd', 39.08277557887713), ('BedroomAbvGr', 38.9772660911294), ('NumFloors', 32.02569835589672), ('OverallCond', 31.76167732437567), ('NeighborhoodDummy_Sawyer', 29.342662134303854), ('FunctionalDummy_Typ', 27.334925350644912), ('NeighborhoodDummy_BrkSide', 26.692804552187376), ('Exterior1stDummy_HdBoard', 24.936209686514992), ('NeighborhoodDummy_Timber', 23.378088752232816), ('SaleConditionDummy_Normal', 22.359903355396995), ('Condition1Dummy_Norm', 22.32608140189002), ('MSSubClassDummy_160', 21.760269791425355), ('EnclosedPorch', 21.28744767272678), ('ExterCond', 21.273549144857043), ('NeighborhoodDummy_IDOTRR', 19.63755964466079), ('MSZoningDummy_FV', 18.8956877231154), ('Exterior2ndDummy_CmentBd', 17.902060963193932), ('NeighborhoodDummy_BrDale', 17.42060679714194), ('Exterior1stDummy_CemntBd', 17.299093380448372), ('Exterior2ndDummy_HdBoard', 16.976312529494226), ('KitchenAbvGr', 16.45975908323592), ('NeighborhoodDummy_MeadowV', 16.285866556875472), ('Condition1Dummy_Feedr', 15.163126728825482), ('AlleyDummy_No_Alley_Access', 14.241923622112331), ('FoundationDummy_Slab', 13.913506826314071), ('MSSubClassDummy_90', 13.466966895212298), ('BldgTypeDummy_Duplex', 13.466966895212298), ('Elec ...
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.03315015, 0.00475311, 0.00464501, 0.00490785, 0.00501518,
#         0.00440588, 0.00475059, 0.00469222]),
#  'std_fit_time': array([3.88602725e-02, 3.35484678e-05, 1.41922520e-04, 2.05844200e-04,
#         2.81527235e-04, 3.88449724e-04, 2.41744570e-04, 9.68927474e-05]),
#  'mean_score_time': array([0.00274792, 0.00260758, 0.0025012 , 0.00269914, 0.00267487,
#         0.00245814, 0.00249448, 0.00260067]),
#  'std_score_time': array([1.12267924e-04, 6.80309775e-05, 1.95366265e-04, 1.43294207e-04,
#         4.43726694e-04, 2.66902758e-05, 3.22804127e-04, 6.29378086e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89443202, 0.89574064, 0.89940329, 0.90367349, 0.90513684,
#         0.90624853, 0.90198643, 0.8827871 ]),
#  'split1_test_score': array([0.90186316, 0.90341707, 0.90671624, 0.90740194, 0.90687352,
#         0.9062405 , 0.87405084, 0.83928995]),
#  'split2_test_score': array([0.88574235, 0.89591181, 0.90044482, 0.90453468, 0.90510438,
#         0.90526079, 0.88553846, 0.85864946]),
#  'split3_test_score': array([0.88420396, 0.88481363, 0.88688657, 0.89072234, 0.89163657,
#         0.89208352, 0.87410065, 0.84865989]),
#  'split4_test_score': array([0.87898384, 0.88002308, 0.88223023, 0.88451296, 0.88503505,
#         0.88532968, 0.87195484, 0.84966851]),
#  'mean_test_score': array([0.88904506, 0.89198125, 0.89513623, 0.89816908, 0.89875727,
#         0.8990326 , 0.88152624, 0.85581098]),
#  'std_test_score': array([0.00811043, 0.00842298, 0.00911161, 0.00892198, 0.00878478,
#         0.00870487, 0.01129026, 0.01481607]),
#  'rank_test_score': array([6, 5, 4, 3, 2, 1, 7, 8], dtype=int32)}

# %%
gridRidge.best_params_
# Out:
# {'alpha': 100}

# %%
gridRidge.best_score_
# Out:
# 0.8990326025382569

# %%
gridRidge.best_estimator_.coef_
# Out:
# array([ 1.25779672e+03,  4.64285359e+03, -3.89319473e+02,  9.10512367e+03,
#         4.96959843e+03,  4.88126582e+03,  1.22023196e+03,  2.86425288e+03,
#        -4.13376713e+03,  8.32766260e+02, -3.70218334e+03,  6.81883544e+02,
#        -1.63461155e+03,  1.80161643e+02,  7.66637340e+03, -8.23561475e+02,
#         7.51787545e+02, -1.19109217e+03,  7.01120369e+03, -1.05022516e+03,
#         6.86715882e+03,  5.96103430e+03, -2.86793255e+02,  1.08372302e+04,
#         1.27277313e+03, -3.03864988e+02,  1.97270330e+03,  1.43379606e+03,
#        -2.71284539e+03, -1.15085369e+03, -4.61665628e+03,  3.93755425e+03,
#         1.98900417e+03, -8.85161602e+02, -8.18280628e+02, -8.77228763e+02,
#         3.46975016e+03,  2.23152576e+03,  3.30205996e+00,  1.85051570e+02,
#         1.88410001e+03,  1.96701233e+03,  4.18386571e+02,  1.61604394e+02,
#         1.67964784e+03,  1.01571699e+03,  4.19272440e+02, -2.45428638e+01,
#         2.65351815e+02, -5.27868643e+02, -1.55669586e+02,  6.35754126e+02,
#        -9.34326788e+02, -8.29178324e+02,  7.70624654e+01, -4.53287703e+01,
#        -2.38033060e+02,  9.36358368e+02,  2.25548644e+02,  3.84644455e+02,
#        -1.33873905e+03, -1.22253245e+03, -7.82690509e+02, -2.41123292e+03,
#        -1.36024708e+03, -2.23167890e+01, -7.69271687e+02,  1.64158448e+03,
#         1.29874765e+02,  6.78160942e+02, -7.12442312e+02,  8.16007807e+02,
#         4.97758357e+02, -4.66217970e+01, -1.00409683e+02, -2.16002089e+02,
#         4.92244431e+02,  1.52544357e+03, -7.46857049e+02,  1.24302729e+02,
#         1.01962273e+03, -1.28001662e+03, -8.39673517e+02, -1.66918628e+02,
#         2.56383311e+02,  1.52696232e+03,  1.30504977e+03,  5.30793849e+02,
#        -1.49780563e+03,  1.85742506e+03, -2.21611973e+03, -1.60093842e+03,
#        -1.47327004e+02, -2.56592655e+02, -1.49124416e+03, -2.25799732e+03,
#         9.19567648e+02, -1.98685917e+03,  3.75083139e+03,  5.38814560e+03,
#        -1.39690576e+03, -9.33033914e+02, -2.58370380e+02, -3.70080386e+02,
#         2.85415713e+02,  3.77611864e+03, -7.43121582e+02,  4.90520912e+02,
#         4.10713218e+01,  2.18841723e+03,  3.42485516e+01,  5.46189203e+02,
#        -1.53263924e+03,  1.49979476e+02, -3.68766937e+02,  2.49007693e+02,
#        -3.12979955e+02,  4.07668905e+01,  8.61793838e+02, -1.49783784e+02,
#        -1.30429605e+02, -7.69271687e+02, -7.82690509e+02, -2.40303079e+03,
#        -1.99626031e+03, -7.65021313e+01, -8.54020154e+02, -1.02919702e+03,
#         1.56130362e+02, -7.31678812e+02,  3.73784782e+02,  1.13353538e+03,
#        -7.98808525e+02,  2.25972194e+02,  3.55031276e+02,  2.92749914e+02,
#         5.19360457e+01, -3.14585018e+02,  5.72520494e+01, -2.56270220e+02,
#         1.74001189e+02, -1.32866547e+02,  2.35495048e+03, -2.97936344e+02,
#         2.02361169e+02, -2.56451354e+02, -7.08770267e+02,  4.99471591e+02,
#        -6.36394241e+02,  4.12149335e+02,  6.86080744e+02, -5.07978377e+02,
#        -1.74545801e+03,  8.47567350e+02, -3.55535404e+02,  2.47656669e+02,
#        -5.96074403e+02, -2.97936344e+02,  5.07183564e+02, -1.23531081e+03,
#         3.34265921e+02,  7.87043224e+01, -1.15780979e+02, -1.14482419e+03,
#        -5.37277952e+02, -2.66123664e+02,  9.84907520e+02,  7.42472305e+02,
#        -1.34495891e+03, -9.32713278e+01, -1.87233100e+02,  9.77162269e+02,
#         1.63743231e+03,  6.50003684e+02,  1.76452898e+03,  1.46074358e+03,
#         5.29529806e+00, -7.66679981e+02,  1.25797341e+02,  7.62146720e+01,
#        -5.98985620e+02,  5.61472532e+02, -2.34782109e+02, -1.60338954e+02,
#         9.10882314e+01,  2.14151925e+02, -3.21091745e+02, -4.77096679e+02,
#        -1.95262411e+02,  6.28044345e+02, -1.04682505e+03, -1.49145781e+03,
#         3.50930590e+03,  1.50574710e+02, -1.86346712e+02,  1.15509403e+03,
#        -2.08945529e+02,  1.14998534e+03,  8.56566134e+02, -3.46901594e+02,
#         6.62637421e+02,  3.59884646e+00,  7.75071909e+01,  1.09384833e+02,
#         2.17649137e+03,  4.96706661e+02,  5.94018342e+02,  3.05381891e+02,
#        -3.50973185e+02,  2.22829069e+03,  4.43668506e+02, -2.92757264e+02,
#         5.76563073e+02, -5.90178540e+02,  1.72244692e+02,  2.59056145e+03,
#         2.98055274e+03])

# %%
getFeatureImportance(50, train.columns, gridRidge.best_estimator_.coef_,'descending')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 10837.230176310117),
#  ('OverallQual', 9105.123672494552),
#  ('BsmtFinSF1', 7666.373395583343),
#  ('TotalBsmtSF', 7011.203692525357),
#  ('1stFlrSF', 6867.1588160945985),
#  ('2ndFlrSF', 5961.034301838414),
#  ('NeighborhoodDummy_NoRidge', 5388.145601367555),
#  ('OverallCond', 4969.598429876873),
#  ('YearBuilt', 4881.265820832081),
#  ('LotArea', 4642.853587494561),
#  ('KitchenQual', -4616.656284699067),
#  ('ExterQual', -4133.767125948265),
#  ('TotRmsAbvGrd', 3937.554254248929),
#  ('NeighborhoodDummy_Somerst', 3776.118642458502),
#  ('NeighborhoodDummy_NWAmes', 3750.8313877197625),
#  ('BsmtQual', -3702.183344045258),
#  ('FunctionalDummy_Sev', 3509.3058992862384),
#  ('GarageCars', 3469.750160041858),
#  ('SaleConditionDummy_Normal', 2980.5527405417683),
#  ('MasVnrArea', 2864.2528775827764),
#  ('BedroomAbvGr', -2712.8453914574347),
#  ('SaleConditionDummy_Family', 2590.5614493039884),
#  ('MSSubClassDummy_90', -2411.232920849464),
#  ('BldgTypeDummy_Duplex', -2403.0307850958925),
#  ('Exterior1stDummy_BrkComm', 2354.9504807162502),
#  ('NeighborhoodDummy_Mitchel', -2257.997322247792),
#  ('GarageArea', 2231.5257585022164),
#  ('SaleTypeDummy_ConLw', 2228.2906903990884),
#  ('NeighborhoodDummy_Crawfor', -2216.1197304010875),
#  ('Condition1Dummy_Feedr', 2188.4172319302006),
#  ('MiscFeatureDummy_Shed', 2176.491371546642),
#  ('BldgTypeDummy_Twnhs', -1996.260309916994),
#  ('Fireplaces', 1989.0041662212693),
#  ('NeighborhoodDummy_NPkVill', -1986.8591749804975),
#  ('FullBath', 1972.7033024110533),
#  ('OpenPorchSF', 1967.0123273158629),
#  ('WoodDeckSF', 1884.1000116366931),
#  ('NeighborhoodDummy_CollgCr', 1857.4250565564926),
#  ('FoundationDummy_CBlock', 1764.52898144622),
#  ('Exterior1stDummy_VinylSd', -1745.458009708464),
#  ('ScreenPorch', 1679.647840731508),
#  ('MSSubClassDummy_190', 1641.5844764160945),
#  ('MasVnrTypeDummy_None', 1637.432305014922),
#  ('BsmtExposure', -1634.6115459341218),
#  ('NeighborhoodDummy_Edwards', -1600.9384243975053),
#  ('Condition1Dummy_PosN', -1532.6392385111783),
#  ('NeighborhoodDummy_Blueste', 1526.9623179587163),
#  ('LotShapeDummy_Reg', 1525.4435716924897),
#  ('NeighborhoodDummy_ClearCr', -1497.8056268580572),
#  ('FunctionalDummy_Mod', -1491.4578093255636),
#  ('NeighborhoodDummy_MeadowV', -1491.2441581310643),
#  ('FoundationDummy_PConc', 1460.7435800410958),
#  ('HalfBath', 1433.796055063445),
#  ('NeighborhoodDummy_NridgHt', -1396.905758988244),
#  ('MSSubClassDummy_120', -1360.2470763477847),
#  ('Exterior2ndDummy_Wd Sdng', -1344.958912690691),
#  ('MSSubClassDummy_75', -1338.739052726875),
#  ('NeighborhoodDummy_BrDale', 1305.0497745234547),
#  ('LotConfigDummy_CulDSac', -1280.0166154463186),
#  ('BsmtFullBath', 1272.7731345719137),
#  ('LotFrontage', 1257.7967203898986),
#  ('Exterior2ndDummy_CmentBd', -1235.3108055138252),
#  ('MSSubClassDummy_80', -1222.5324450100418),
#  ('YearRemodAdd', 1220.2319567902575),
#  ('BsmtUnfSF', -1191.0921695126624),
#  ('GarageTypeDummy_Basment', 1155.0940345266597),
#  ('KitchenAbvGr', -1150.8536866433426),
#  ('GarageTypeDummy_CarPort', 1149.9853360345537),
#  ('Exterior2ndDummy_Other', -1144.8241923602127),
#  ('HouseStyleDummy_SFoyer', 1133.535384676123),
#  ('HeatingQC', -1050.2251625745441),
#  ('FunctionalDummy_Min2', -1046.825047306889),
#  ('HouseStyleDummy_1Story', -1029.1970189304357),
#  ('LandContourDummy_Lvl', 1019.6227275223424),
#  ('PoolArea', 1015.7169945138261),
#  ('Exterior2ndDummy_Stucco', 984.9075203355309),
#  ('MasVnrTypeDummy_No_MasVnr', 977.1622687710835),
#  ('MSSubClassDummy_50', 936.3583683509726),
#  ('hasBeenRemodeled', -934.3267884480588),
#  ('NeighborhoodDummy_OldTown', -933.0339138757483),
#  ('NeighborhoodDummy_NAmes', 919.5676475064649),
#  ('FireplaceQu', -885.1616017538363),
#  ('GarageFinish', -877.2287627675519),
#  ('Condition2Dummy_Norm', 861.7938380218023),
#  ('GarageTypeDummy_Detchd', 856.5661335627968),
#  ('HouseStyleDummy_1.5Unf', -854.0201536941414),
#  ('Exterior1stDummy_Wd Sdng', 847.5673499231491),
#  ('LotConfigDummy_FR2', -839.6735168578672),
#  ('ExterCond', 832.7662604740084),
#  ('NumFloors', -829.1783238366288),
#  ('BsmtFinType2', -823.5614749429012),
#  ('GarageYrBlt', -818.2806283048589),
#  ('MSZoningDummy_RM', 816.0078073371511),
#  ('HouseStyleDummy_SLvl', -798.8085252171876),
#  ('MSSubClassDummy_85', -782.6905086272227),
#  ('BldgTypeDummy_2fmCon', -782.6905086272226),
#  ('MSSubClassDummy_180', -769.271687373126),
#  ('Condition2Dummy_RRNn', -769.2716873731223),
#  ('FoundationDummy_Stone', -766.6799813323179),
#  ('BsmtFinSF2', 751.7875453243462),
#  ('LandContourDummy_HLS', -746.8570491557552),
#  ('NeighborhoodDummy_StoneBr', -743.1215816967045),
#  ('Exterior2ndDummy_VinylSd', 742.4723047989679),
#  ('HouseStyleDummy_2.5Unf', -731.6788116323677),
#  ('MSZoningDummy_RL', -712.4423118158828),
#  ('Exterior1stDummy_HdBoard', -708.7702670631222),
#  ('Exterior1stDummy_Stone', 686.0807437181102),
#  ('BsmtCond', 681.8835436987362),
#  ('MSZoningDummy_RH', 678.1609421356741),
#  ('PavedDriveDummy_P', 662.6374211260243),
#  ('MasVnrTypeDummy_Stone', 650.0036838100062),
#  ('Exterior1stDummy_MetalSd', -636.394240786741),
#  ('SalePrice', 635.7541260411388),
#  ('FunctionalDummy_Min1', 628.044345320184),
#  ('HeatingDummy_GasW', -598.9856195287231),
#  ('Exterior2ndDummy_Brk Cmn', -596.0744031973795),
#  ('SaleTypeDummy_Con', 594.0183424499292),
#  ('SaleConditionDummy_AdjLand', -590.1785397853744),
#  ('SaleTypeDummy_WD', 576.5630728913515),
#  ('HeatingDummy_Grav', 561.4725317072222),
#  ('Condition1Dummy_PosA', 546.1892029383289),
#  ('Exterior2ndDummy_Plywood', -537.2779523993113),
#  ('NeighborhoodDummy_BrkSide', 530.7938488134749),
#  ('MoSold', -527.8686433366213),
#  ('Exterior1stDummy_Stucco', -507.97837653448676),
#  ('Exterior2ndDummy_CBlock', 507.18356362958815),
#  ('Exterior1stDummy_ImStucc', 499.4715909343612),
#  ('StreetDummy_Pave', 497.7583569664995),
#  ('SaleTypeDummy_CWD', 496.7066607847512),
#  ('LotShapeDummy_IR3', 492.24443125500505),
#  ('NeighborhoodDummy_Timber', 490.52091227799053),
#  ('ElectricalDummy_SBrkr', -477.0966788490848),
#  ('SaleTypeDummy_New', 443.6685058387739),
#  ('PoolQC', 419.2724404751796),
#  ('EnclosedPorch', 418.3865708028896),
#  ('Exterior1stDummy_Plywood', 412.1493353858174),
#  ('LandSlope', -389.3194729115),
#  ('MSSubClassDummy_70', 384.6444548811106),
#  ('HouseStyleDummy_2Story', 373.78478197950125),
#  ('NeighborhoodDummy_Sawyer', -370.08038638328406),
#  ('Condition1Dummy_RRAn', -368.7669370726961),
#  ('Exterior1stDummy_WdShing', -355.5354035502969),
#  ('RoofStyleDummy_Gambrel', 355.0312761076943),
#  ('SaleTypeDummy_ConLI', -350.9731847420478),
#  ('GarageTypeDummy_No_Garage', -346.9015939232744),
#  ('Exterior2ndDummy_HdBoard', 334.2659205676462),
#  ('ElectricalDummy_Mix', -321.0917447548542),
#  ('RoofMatlDummy_CompShg', -314.5850183548458),
#  ('Condition1Dummy_RRNn', -312.97995503513124),
#  ('SaleTypeDummy_ConLD', 305.38189057189834),
#  ('BsmtHalfBath', -303.8649879107964),
#  ('Exterior2ndDummy_BrkFace', -297.93634422457757),
#  ('Exterior1stDummy_BrkFace', -297.93634422457626),
#  ('SaleTypeDummy_Oth', -292.75726392429283),
#  ('RoofStyleDummy_Hip', 292.7499139677856),
#  ('LowQualFinSF', -286.7932547879714),
#  ('NeighborhoodDummy_SawyerW', 285.4157129390859),
#  ('Exterior2ndDummy_Stone', -266.1236640092911),
#  ('MiscVal', 265.35181529916866),
#  ('NeighborhoodDummy_SWISU', -258.37038000427486),
#  ('NeighborhoodDummy_IDOTRR', -256.5926552877756),
#  ('Exterior1stDummy_CemntBd', -256.4513540697149),
#  ('LotConfigDummy_Inside', 256.3833107075333),
#  ('RoofMatlDummy_Tar&Grv', -256.27021975148176),
#  ('Condition1Dummy_RRNe', 249.00769296303687),
#  ('Exterior2ndDummy_AsphShn', 247.6566687143218),
#  ('MSSubClassDummy_45', -238.03305994858908),
#  ('HeatingDummy_Wall', -234.78210907270375),
#  ('RoofStyleDummy_Gable', 225.9721938188397),
#  ('MSSubClassDummy_60', 225.54864427108376),
#  ('LotShapeDummy_IR2', -216.00208917753326),
#  ('ElectricalDummy_FuseP', 214.15192544958913),
#  ('GarageTypeDummy_BuiltIn', -208.94552898705646),
#  ('Exterior1stDummy_CBlock', 202.36116859982968),
#  ('FunctionalDummy_Maj2', -195.26241132008616),
#  ('MasVnrTypeDummy_BrkFace', -187.23310037210618),
#  ('GarageTypeDummy_Attchd', -186.34671214595696),
#  ('GarageCond', 185.05156980299665),
#  ('BsmtFinType1', 180.16164257181615),
#  ('RoofMatlDummy_WdShake', 174.0011886162702),
#  ('SaleConditionDummy_Alloca', 172.244692342409),
#  ('LotConfigDummy_FR3', -166.91862824047269),
#  ('3SsnPorch', 161.60439372847054),
#  ('CentralAirDummy_Y', -160.3389538496033),
#  ('HouseStyleDummy_2.5Fin', 156.1303615139374),
#  ('YrSold', -155.66958565304367),
#  ('FunctionalDummy_Typ', 150.57470987438825),
#  ('Condition1Dummy_RRAe', 149.97947630495162),
#  ('Condition2Dummy_PosA', -149.78378390137775),
#  ('NeighborhoodDummy_Gilbert', -147.3270035831656),
#  ('RoofMatlDummy_WdShngl', -132.86654697138277),
#  ('Condition2Dummy_RRAn', -130.42960486396572),
#  ('MSZoningDummy_FV', 129.87476531553568),
#  ('FoundationDummy_Wood', 125.7973405596778),
#  ('LandContourDummy_Low', 124.30272881311792),
#  ('Exterior2ndDummy_MetalSd', -115.78097865694595),
#  ('MiscFeatureDummy_Othr', 109.38483294786678),
#  ('AlleyDummy_Pave', -100.40968251761363),
#  ('Exterior2ndDummy_Wd Shng', -93.27132782820019),
#  ('ElectricalDummy_FuseF', 91.08823142677679),
#  ('Exterior2ndDummy_ImStucc', 78.70432241100454),
#  ('MiscFeatureDummy_No_Misc_Feature', 77.50719090382363),
#  ('MSSubClassDummy_30', 77.06246539819209),
#  ('BldgTypeDummy_TwnhsE', -76.5021312631687),
#  ('HeatingDummy_GasA', 76.21467195003339),
#  ('RoofMatlDummy_Roll', 57.25204942780196),
#  ('RoofStyleDummy_Mansard', 51.9360456989306),
#  ('AlleyDummy_No_Alley_Access', -46.62179696728189),
#  ('MSSubClassDummy_40', -45.328770263030655),
#  ('NeighborhoodDummy_Veenker', 41.071321809542354),
#  ('Condition2Dummy_Feedr', 40.76689050627094),
#  ('Condition1Dummy_Norm', 34.24855159002712),
#  ('Fence', -24.542863824282946),
#  ('MSSubClassDummy_160', -22.316789020432832),
#  ('FoundationDummy_Slab', 5.295298055698638),
#  ('PavedDriveDummy_Y', 3.5988464581830186),
#  ('GarageQual', 3.302059963246025)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157463250019.58755, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151380581656.90482, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160109480053.09866, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154933447288.35843, tolerance: 502141457.07893145
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158839031016.3743, tolerance: 517805433.56124574
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97279321664.16835, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107856113761.09192, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127458011001.3671, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124798708776.34256, tolerance: 502141457.07893145
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136558792185.27907, tolerance: 517805433.56124574
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6284084929.795868, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 501790354.4180298, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 611043751.5977173, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3175175607.019165, tolerance: 517805433.56124574
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11239109, 0.11809645, 0.11753426, 0.07952285, 0.06260562,
#         0.04742651, 0.01486592, 0.01037912]),
#  'std_fit_time': array([0.00589027, 0.0039924 , 0.00260666, 0.00776331, 0.009129  ,
#         0.00117798, 0.0046326 , 0.00278773]),
#  'mean_score_time': array([0.00234509, 0.00244265, 0.00240378, 0.00278425, 0.00262694,
#         0.00272961, 0.00296535, 0.00248079]),
#  'std_score_time': array([2.12906483e-04, 1.90437049e-04, 1.81785272e-04, 4.80707672e-05,
#         1.31668754e-04, 2.72316746e-04, 1.33018988e-04, 1.97196778e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89408758, 0.89433452, 0.89592689, 0.90067151, 0.9020442 ,
#         0.90320923, 0.9076347 , 0.89268521]),
#  'split1_test_score': array([0.90262537, 0.90313867, 0.90668829, 0.91092266, 0.91183311,
#         0.91262215, 0.9080496 , 0.8971237 ]),
#  'split2_test_score': array([0.89054342, 0.89213446, 0.89671643, 0.90163597, 0.90304755,
#         0.90410185, 0.89498871, 0.87904485]),
#  'split3_test_score': array([0.88439557, 0.88451632, 0.8853588 , 0.88803107, 0.88987831,
#         0.89131029, 0.88795252, 0.87454628]),
#  'split4_test_score': array([0.8798322 , 0.87965296, 0.88089131, 0.88414522, 0.88501718,
#         0.88572376, 0.89446846, 0.88741731]),
#  'mean_test_score': array([0.89029683, 0.89075539, 0.89311634, 0.89708129, 0.89836407,
#         0.89939346, 0.8986188 , 0.88616347]),
#  'std_test_score': array([0.00788361, 0.00812709, 0.00910701, 0.00974132, 0.00966479,
#         0.0096325 , 0.00792968, 0.00836499]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.899393457033802

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 23747.643974919458),
#  ('OverallQual', 10145.067890297953),
#  ('BsmtFinSF1', 9780.003782535156),
#  ('YearBuilt', 9125.343543867188),
#  ('OverallCond', 6083.614180342211),
#  ('TotalBsmtSF', 5845.192972634379),
#  ('SaleConditionDummy_Normal', 5806.62760216666),
#  ('NeighborhoodDummy_NoRidge', 5725.095214209675),
#  ('LotArea', 5180.837285042489),
#  ('FunctionalDummy_Sev', 4823.31026615531),
#  ('KitchenQual', -4514.773649499569),
#  ('GarageCars', 4089.9434567771445),
#  ('ExterQual', -3898.8405316249828),
#  ('BedroomAbvGr', -3741.200718670512),
#  ('NeighborhoodDummy_Somerst', 3709.1449361240425),
#  ('BsmtQual', -3546.5737528905797),
#  ('NeighborhoodDummy_NWAmes', 3235.3632766449587),
#  ('TotRmsAbvGrd', 3172.580782249915),
#  ('hasBeenRemodeled', -3026.1689608139313),
#  ('SaleConditionDummy_Family', 2919.291930414109),
#  ('BldgTypeDummy_Duplex', -2871.690364068482),
#  ('MSSubClassDummy_90', -2643.1701693069654),
#  ('MasVnrArea', 2508.0646039640824),
#  ('Exterior1stDummy_BrkComm', 2489.8199213971034),
#  ('BldgTypeDummy_Twnhs', -2423.3413108409327),
#  ('MiscFeatureDummy_Shed', 2231.84746590914),
#  ('Condition1Dummy_Feedr', 2080.602066911893),
#  ('NeighborhoodDummy_NPkVill', -1994.5226895767303),
#  ('NeighborhoodDummy_Crawfor', -1922.9552516028755),
#  ('OpenPorchSF', 1868.431403234209),
#  ('NeighborhoodDummy_Mitchel', -1814.3715574594046),
#  ('NeighborhoodDummy_CollgCr', 1800.1187557662943),
#  ('NeighborhoodDummy_Blueste', 1782.2830586308885),
#  ('WoodDeckSF', 1755.3103586947102),
#  ('Exterior2ndDummy_CmentBd', -1675.1921512895397),
#  ('ScreenPorch', 1673.63975988019),
#  ('2ndFlrSF', 1633.7494713337398),
#  ('LotShapeDummy_Reg', 1627.5917247918019),
#  ('MasVnrTypeDummy_None', 1605.5020794118236),
#  ('Condition1Dummy_PosN', -1599.799387814193),
#  ('NeighborhoodDummy_BrDale', 1577.1031144694305),
#  ('FunctionalDummy_Mod', -1557.584772535014),
#  ('Exterior2ndDummy_Other', -1547.9046427846502),
#  ('NeighborhoodDummy_ClearCr', -1504.2700547435365),
#  ('NeighborhoodDummy_MeadowV', -1496.513663204508),
#  ('MSSubClassDummy_190', 1452.483712168771),
#  ('FunctionalDummy_Min1', 1448.3347183514454),
#  ('KitchenAbvGr', -1448.141679101009),
#  ('Exterior2ndDummy_Wd Sdng', -1376.9796861052566),
#  ('NeighborhoodDummy_NridgHt', -1363.9083468706938),
#  ('Fireplaces', 1355.452233365069),
#  ('MasVnrTypeDummy_No_MasVnr', 1331.4629702017646),
#  ('BsmtFinSF2', 1330.4380982097728),
#  ('NeighborhoodDummy_Edwards', -1320.6677805244153),
#  ('BsmtExposure', -1314.98790662925),
#  ('MSSubClassDummy_120', -1302.701599218227),
#  ('Exterior1stDummy_VinylSd', -1276.941660631743),
#  ('GarageTypeDummy_CarPort', 1201.8497999466933),
#  ('MSSubClassDummy_85', -1186.9152421375334),
#  ('NeighborhoodDummy_NAmes', 1171.3148830520859),
#  ('LotConfigDummy_CulDSac', -1132.4484815768492),
#  ('FoundationDummy_Stone', -1085.1121093275447),
#  ('MSZoningDummy_RL', -1061.4294906597097),
#  ('HouseStyleDummy_1Story', -1006.4127275319231),
#  ('HouseStyleDummy_SFoyer', 1002.2942722030327),
#  ('Exterior1stDummy_Wd Sdng', 972.4675971123311),
#  ('MSSubClassDummy_180', -965.5799127786261),
#  ('LowQualFinSF', -862.8539355634132),
#  ('FoundationDummy_PConc', 844.0802607101464),
#  ('FoundationDummy_CBlock', 832.6216453571461),
#  ('NeighborhoodDummy_StoneBr', -815.6682321956973),
#  ('GarageTypeDummy_Detchd', 799.7605662643359),
#  ('LotConfigDummy_FR2', -797.5606153538386),
#  ('Condition2Dummy_Norm', 781.3224944593225),
#  ('HouseStyleDummy_SLvl', -772.7952486529009),
#  ('HouseStyleDummy_2.5Unf', -766.7972005234977),
#  ('Exterior2ndDummy_Brk Cmn', -765.1844984074323),
#  ('GarageArea', 761.8053881641625),
#  ('BsmtFinType2', -757.033365289131),
#  ('BsmtCond', 749.6169220714179),
#  ('MSZoningDummy_RM', 747.0557451607268),
#  ('MSSubClassDummy_75', -736.489862347245),
#  ('LandContourDummy_Lvl', 729.8632825289959),
#  ('NeighborhoodDummy_OldTown', -729.7694794357072),
#  ('LandContourDummy_HLS', -726.604151756813),
#  ('BsmtFullBath', 722.1082357888789),
#  ('FireplaceQu', -704.3663249196768),
#  ('GarageYrBlt', -677.4206012139956),
#  ('MSSubClassDummy_80', -662.8398329118716),
#  ('Exterior1stDummy_HdBoard', -643.5876233656261),
#  ('GarageFinish', -633.9299365021344),
#  ('PoolArea', 621.5134280617873),
#  ('HeatingQC', -609.2309285379037),
#  ('SaleTypeDummy_WD', 598.5464792535475),
#  ('FunctionalDummy_Min2', -592.1007608790464),
#  ('EnclosedPorch', 587.0790199167659),
#  ('ExterCond', 571.2172378388894),
#  ('NeighborhoodDummy_Sawyer', -538.1883340710365),
#  ('LotShapeDummy_IR3', 536.431114357462),
#  ('SalePrice', 528.9957753468805),
#  ('HeatingDummy_Grav', 521.9101094985575),
#  ('LotFrontage', 520.1471869499666),
#  ('SaleTypeDummy_CWD', 495.5758506022192),
#  ('HeatingDummy_GasW', -491.18556711288034),
#  ('BsmtFinType1', 476.4943183177794),
#  ('SaleTypeDummy_New', 474.24154497148174),
#  ('MoSold', -469.2110357745168),
#  ('Condition1Dummy_PosA', 441.5416524462222),
#  ('GarageTypeDummy_Basment', 434.30821658065526),
#  ('Exterior1stDummy_MetalSd', -426.4223073680525),
#  ('HeatingDummy_Wall', -409.5854380336972),
#  ('Exterior1stDummy_BrkFace', -396.2609357505132),
#  ('Exterior2ndDummy_Plywood', -393.71437186964954),
#  ('HalfBath', 390.91973690690605),
#  ('YearRemodAdd', 382.89237376847785),
#  ('HouseStyleDummy_2.5Fin', 375.8644512517254),
#  ('GarageTypeDummy_No_Garage', -368.5939376647226),
#  ('LandContourDummy_Low', 325.6895234344667),
#  ('SaleConditionDummy_Alloca', 311.01337908365696),
#  ('NeighborhoodDummy_Timber', 310.86492732762935),
#  ('PavedDriveDummy_P', 309.3953844912312),
#  ('Exterior1stDummy_Stone', 306.89463820488436),
#  ('Exterior2ndDummy_CBlock', 306.33920584502096),
#  ('RoofMatlDummy_CompShg', -302.758186616402),
#  ('FunctionalDummy_Maj2', 298.68102726732434),
#  ('SaleTypeDummy_Con', 292.73952094708943),
#  ('SaleTypeDummy_ConLD', 288.23669054902734),
#  ('LandSlope', -285.8075133552918),
#  ('SaleConditionDummy_AdjLand', -285.3739949035054),
#  ('MasVnrTypeDummy_Stone', 283.10827142261275),
#  ('BsmtHalfBath', -274.1507766656746),
#  ('Exterior1stDummy_ImStucc', 272.93356077572383),
#  ('FullBath', 260.06879314882065),
#  ('SaleTypeDummy_ConLI', -255.59803019313625),
#  ('AlleyDummy_No_Alley_Access', -253.23846938173872),
#  ('Condition1Dummy_RRAn', -241.92599877125193),
#  ('NeighborhoodDummy_BrkSide', 212.56531075079005),
#  ('RoofMatlDummy_Tar&Grv', -209.57083359438127),
#  ('Exterior1stDummy_WdShing', -202.4103940953473),
#  ('RoofStyleDummy_Hip', 196.64478650621254),
#  ('NumFloors', -191.3328614013669),
#  ('Condition1Dummy_RRNe', 189.99871800776418),
#  ('MasVnrTypeDummy_BrkFace', -186.65599891391705),
#  ('Exterior1stDummy_Plywood', 171.24133871115774),
#  ('Exterior2ndDummy_MetalSd', -169.04913546961407),
#  ('BldgTypeDummy_2fmCon', -165.31606276308054),
#  ('Condition2Dummy_Feedr', 164.52161240768783),
#  ('Condition2Dummy_RRNn', -158.5052479719997),
#  ('MSSubClassDummy_60', 155.25894054086118),
#  ('MiscVal', 143.84343012706628),
#  ('Condition1Dummy_RRAe', 122.3441003453264),
#  ('NeighborhoodDummy_IDOTRR', 120.98535334598694),
#  ('ElectricalDummy_FuseP', 119.82331041316576),
#  ('Exterior2ndDummy_VinylSd', 118.57025842297325),
#  ('ElectricalDummy_Mix', -115.78338067968086),
#  ('LotShapeDummy_IR2', -111.3875096971253),
#  ('LotConfigDummy_Inside', 104.81307553502637),
#  ('MiscFeatureDummy_Othr', 102.14979384000607),
#  ('Exterior2ndDummy_HdBoard', 96.76412594921852),
#  ('StreetDummy_Pave', 84.76692212708613),
#  ('Fence', -66.02543904291376),
#  ('LotConfigDummy_FR3', -63.991509117662375),
#  ('3SsnPorch', 57.05291185629201),
#  ('NeighborhoodDummy_SawyerW', 52.18280368719468),
#  ('CentralAirDummy_Y', -36.75529124566561),
#  ('Condition1Dummy_RRNn', -23.604871872297682),
#  ('FoundationDummy_Wood', 20.50908846509519),
#  ('YrSold', -18.299801372847213),
#  ('ElectricalDummy_SBrkr', -17.50899055567971),
#  ('GarageCond', 8.982306713630017),
#  ('Exterior2ndDummy_BrkFace', -0.9351313127482483),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('GarageQual', -0.0),
#  ('PoolQC', 0.0),
#  ('MSSubClassDummy_30', -0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', 0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_70', 0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSZoningDummy_FV', 0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('AlleyDummy_Pave', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Veenker', 0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition2Dummy_PosA', -0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', -0.0),
#  ('HouseStyleDummy_2Story', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_Stucco', -0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_Stone', -0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', -0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-26-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType','MSSubClass']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8938961785232828

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161070412595.78223, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174798977285.7723, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138074351152.83154, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183330975339.46378, tolerance: 502141457.07893145
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167561824174.06454, tolerance: 517805433.56124574
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44070633057.81116, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100618414102.10515, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14467233678.991028, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133036135029.44437, tolerance: 502141457.07893145
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70828414812.3674, tolerance: 517805433.56124574
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2777033269.567688, tolerance: 509571142.51905257
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9484617280.632446, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 620201265.2797241, tolerance: 505013856.2097758
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 703903325.6427612, tolerance: 464563808.6073157
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8941030625153376

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X_Scaled.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.999683
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.999356
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999281
# PoolArea                  PoolQC                       0.998124
# GarageYrBlt               GarageTypeDummy_No_Garage    0.995672
# GarageCars                GarageArea                   0.989669
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.985034
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.984940
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.984883
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.972333
# GrLivArea                 TotRmsAbvGrd                 0.969183
# 2ndFlrSF                  NumFloors                    0.968804
# ExterQual                 KitchenQual                  0.964556
# OverallQual               ExterQual                    0.963505
# TotalBsmtSF               1stFlrSF                     0.963143
# 2ndFlrSF                  HouseStyleDummy_2Story       0.961495
# BsmtQual                  FoundationDummy_PConc        0.957229
# NumFloors                 HouseStyleDummy_1Story       0.954638
# ExterQual                 BsmtQual                     0.953862
# OverallQual               BsmtQual                     0.946523
#                           KitchenQual                  0.943805
# MasVnrArea                MasVnrTypeDummy_None         0.942371
# YearRemodAdd              BsmtQual                     0.942337
#                           FoundationDummy_PConc        0.942286
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.938206
# HalfBath                  HouseStyleDummy_2Story       0.934417
# OverallQual               GarageCars                   0.934013
# ExterQual                 FoundationDummy_PConc        0.928732
# FoundationDummy_CBlock    FoundationDummy_PConc        0.928013
# OverallQual               FullBath                     0.924418
# YearRemodAdd              ExterQual                    0.924275
# YearBuilt                 BsmtQual                     0.921833
# BsmtQual                  KitchenQual                  0.921095
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.918727
# NumFloors                 HouseStyleDummy_2Story       0.917997
# OverallQual               FoundationDummy_PConc        0.912551
# 2ndFlrSF                  HouseStyleDummy_1Story       0.912399
# OverallQual               YearRemodAdd                 0.911836
# BsmtFinSF1                BsmtFullBath                 0.911422
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.911263
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.911230
# OverallQual               GarageArea                   0.910548
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.910048
# YearRemodAdd              KitchenQual                  0.902002
# YearBuilt                 YearRemodAdd                 0.901387
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.897610
# YearBuilt                 FoundationDummy_PConc        0.896977
# GrLivArea                 FullBath                     0.896126
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.893490
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.640781186913494),
#  ('LotArea', 2.176015154335641),
#  ('OverallQual', 4.554579992474097),
#  ('OverallCond', 2.0313573398520406),
#  ('YearBuilt', 12.329500702043035),
#  ('YearRemodAdd', 3.5327785827478566),
#  ('MasVnrArea', 2.691785317895596),
#  ('ExterQual', 3.127899666946507),
#  ('BsmtQual', 2.951145009542295),
#  ('BsmtExposure', 1.8101301285796043),
#  ('BsmtFinType1', 2.2016564036908393),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.430027617531757),
#  ('BsmtHalfBath', 1.2490151360735235),
#  ('FullBath', 3.8956958897593554),
#  ('HalfBath', 2.946653904998036),
#  ('BedroomAbvGr', 2.950145497678553),
#  ('KitchenAbvGr', 1.6903865371851656),
#  ('KitchenQual', 2.3238465183564867),
#  ('TotRmsAbvGrd', 5.1489852341680615),
#  ('Fireplaces', 1.8123406151524806),
#  ('FireplaceQu', 1.4183104197748255),
#  ('GarageYrBlt', 1208.1512646904412),
#  ('GarageFinish', 2.0939398573487282),
#  ('GarageCars', 6.57765592866367),
#  ('GarageArea', 6.335493176752193),
#  ('WoodDeckSF', 1.3551578877461097),
#  ('OpenPorchSF', 1.431971780678545),
#  ('EnclosedPorch', 1.4807120866441148),
#  ('3SsnPorch', 1.1126585209720241),
#  ('ScreenPorch', 1.1835865000565495),
#  ('PoolArea', 16.130021246502558),
#  ('PoolQC', 16.074482721632016),
#  ('Fence', 1.330152581509536),
#  ('MiscVal', 1.0661351365677914),
#  ('MoSold', 1.1290642599084009),
#  ('YrSold', 1.1867808143467222),
#  ('hasBeenRemodeled', 1.8716133776982744),
#  ('NumFloors', 22.8327767018468),
#  ('MSZoningDummy_FV', 33.98148943415939),
#  ('MSZoningDummy_RH', 5.777151025092759),
#  ('MSZoningDummy_RL', 98.35816872536248),
#  ('MSZoningDummy_RM', 69.9900361951246),
#  ('AlleyDummy_No_Alley_Access', 2.6545739467488123),
#  ('AlleyDummy_Pave', 2.6748416825882573),
#  ('LotShapeDummy_IR2', 1.2138221655214338),
#  ('LotShapeDummy_IR3', 1.13882154435626),
#  ('LotShapeDummy_Reg', 1.5339045033074727),
#  ('LotConfigDummy_CulDSac', 1.6890065644231256),
#  ('LotConfigDummy_FR2', 1.353065464674784),
#  ('LotConfigDummy_FR3', 1.0851869442950195),
#  ('LotConfigDummy_Inside', 1.6716737583667431),
#  ('NeighborhoodDummy_Blueste', 1.3190627933105765),
#  ('NeighborhoodDummy_BrDale', 3.0873393073345228),
#  ('NeighborhoodDummy_BrkSide', 6.951708049753423),
#  ('NeighborhoodDummy_ClearCr', 2.692476352708399),
#  ('NeighborhoodDummy_CollgCr', 11.189617094156091),
#  ('NeighborhoodDummy_Crawfor', 5.198177963033727),
#  ('NeighborhoodDummy_Edwards', 8.530944715937988),
#  ('NeighborhoodDummy_Gilbert', 7.137151853184697),
#  ('NeighborhoodDummy_IDOTRR', 3.9786981625574778),
#  ('NeighborhoodDummy_MeadowV', 3.160979156042604),
#  ('NeighborhoodDummy_Mitchel', 5.213437437771632),
#  ('NeighborhoodDummy_NAmes', 18.43410142377051),
#  ('NeighborhoodDummy_NPkVill', 2.0465344478429186),
#  ('NeighborhoodDummy_NWAmes', 7.059816851456939),
#  ('NeighborhoodDummy_NoRidge', 4.563550404592037),
#  ('NeighborhoodDummy_NridgHt', 6.600203898729947),
#  ('NeighborhoodDummy_OldTown', 12.495447331050586),
#  ('NeighborhoodDummy_SWISU', 3.492245592920461),
#  ('NeighborhoodDummy_Sawyer', 7.355647849201653),
#  ('NeighborhoodDummy_SawyerW', 5.372722833657318),
#  ('NeighborhoodDummy_Somerst', 10.923865999933934),
#  ('NeighborhoodDummy_StoneBr', 2.7127099294863934),
#  ('NeighborhoodDummy_Timber', 3.4765969826580907),
#  ('NeighborhoodDummy_Veenker', 1.8522866989284046),
#  ('HouseStyleDummy_1.5Unf', 1.671076438585242),
#  ('HouseStyleDummy_1Story', 22.32371473715465),
#  ('HouseStyleDummy_2.5Fin', 1.918248722174302),
#  ('HouseStyleDummy_2.5Unf', 1.1868314411466416),
#  ('HouseStyleDummy_2Story', 6.05613924272351),
#  ('HouseStyleDummy_SFoyer', 2.912355340320055),
#  ('HouseStyleDummy_SLvl', 3.328782649977739),
#  ('RoofStyleDummy_Gable', 51.651357382920075),
#  ('RoofStyleDummy_Gambrel', 3.15011814068621),
#  ('RoofStyleDummy_Hip', 49.51525799488707),
#  ('RoofStyleDummy_Mansard', 2.132251590825742),
#  ('Exterior1stDummy_BrkComm', 1.1375688461496027),
#  ('Exterior1stDummy_BrkFace', 4.631704400202897),
#  ('Exterior1stDummy_CBlock', 1.2087474832822553),
#  ('Exterior1stDummy_CemntBd', 5.640487415955059),
#  ('Exterior1stDummy_HdBoard', 17.505616668204564),
#  ('Exterior1stDummy_ImStucc', 1.194772225546307),
#  ('Exterior1stDummy_MetalSd', 16.03250008933485),
#  ('Exterior1stDummy_Plywood', 9.097854663040547),
#  ('Exterior1stDummy_Stone', 1.2235136525643688),
#  ('Exterior1stDummy_Stucco', 2.2649151846215028),
#  ('Exterior1stDummy_VinylSd', 29.664159071079418),
#  ('Exterior1stDummy_Wd Sdng', 14.612921331308929),
#  ('Exterior1stDummy_WdShing', 3.0520823188344623),
#  ('MasVnrTypeDummy_BrkFace', 25.499259864767364),
#  ('MasVnrTypeDummy_No_MasVnr', 1.8007727062075558),
#  ('MasVnrTypeDummy_None', 29.172620338466153),
#  ('MasVnrTypeDummy_Stone', 10.406887335077275),
#  ('FoundationDummy_CBlock', 6.709678134237464),
#  ('FoundationDummy_PConc', 8.114754813336242),
#  ('FoundationDummy_Slab', 2.534531700102996),
#  ('FoundationDummy_Stone', 1.1498845780886027),
#  ('FoundationDummy_Wood', 1.2597315639286915),
#  ('GarageTypeDummy_Attchd', 76.97558927506044),
#  ('GarageTypeDummy_Basment', 4.747865467244481),
#  ('GarageTypeDummy_BuiltIn', 18.843996096326222),
#  ('GarageTypeDummy_CarPort', 2.688799547757071),
#  ('GarageTypeDummy_Detchd', 63.876641952604686),
#  ('GarageTypeDummy_No_Garage', 1171.4764174107283),
#  ('SaleConditionDummy_AdjLand', 1.0708439920725263),
#  ('SaleConditionDummy_Alloca', 1.354164410433818),
#  ('SaleConditionDummy_Family', 1.3062653687824703),
#  ('SaleConditionDummy_Normal', 2.6369262711463306),
#  ('SaleConditionDummy_Partial', 2.7813121565176666),
#  ('constant', 114103.40182472208)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual','GarageArea','PoolArea','PoolQC'], axis=1)

# %%
X_Scaled = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)
# Out:
# [('LotFrontage', 28.34940454563091),
#  ('LotArea', 11.145659498409461),
#  ('OverallCond', 39.1775666226664),
#  ('YearBuilt', 39483.06570537924),
#  ('YearRemodAdd', 29995.455709766647),
#  ('MasVnrArea', 3.611618503300045),
#  ('ExterQual', 51.775361259498595),
#  ('BsmtQual', 16.702675658426557),
#  ('BsmtExposure', 9.290572831463829),
#  ('BsmtFinType1', 6.2786545220765175),
#  ('BsmtFinSF1', 20.214501694634322),
#  ('BsmtFinSF2', 2.2824557556632574),
#  ('BsmtUnfSF', 25.09742241625738),
#  ('1stFlrSF', 110.38950932271968),
#  ('2ndFlrSF', 29.15813260807392),
#  ('LowQualFinSF', 2.181524222162239),
#  ('BsmtFullBath', 4.112376947071872),
#  ('BsmtHalfBath', 1.3116420310533892),
#  ('FullBath', 35.69811216751344),
#  ('HalfBath', 4.506972117850295),
#  ('BedroomAbvGr', 45.708691521438844),
#  ('KitchenAbvGr', 60.37963389930535),
#  ('KitchenQual', 23.35237747863688),
#  ('TotRmsAbvGrd', 51.58632338736465),
#  ('Fireplaces', 3.413192220998193),
#  ('FireplaceQu', 11.247257398104255),
#  ('GarageYrBlt', 27903.594769214353),
#  ('GarageFinish', 7.347615423421716),
#  ('GarageCars', 26.594897886488262),
#  ('WoodDeckSF', 2.1698482656945237),
#  ('OpenPorchSF', 2.193172057694512),
#  ('EnclosedPorch', 1.6387687304472478),
#  ('3SsnPorch', 1.1249965062351193),
#  ('ScreenPorch', 1.2678388273649137),
#  ('Fence', 15.33623681517466),
#  ('MiscVal', 1.067070317493366),
#  ('MoSold', 5.555877011733336),
#  ('YrSold', 3.3742093053881765),
#  ('hasBeenRemodeled', 3.416250989340654),
#  ('NumFloors', 504.65325562061),
#  ('MSZoningDummy_FV', 35.01582351538771),
#  ('MSZoningDummy_RH', 5.684752321809814),
#  ('MSZoningDummy_RL', 500.0940154691243),
#  ('MSZoningDummy_RM', 79.3275111410881),
#  ('AlleyDummy_No_Alley_Access', 51.892851609748504),
#  ('AlleyDummy_Pave', 2.7142546651978523),
#  ('LotShapeDummy_IR2', 1.2390512865872831),
#  ('LotShapeDummy_IR3', 1.1424133584515381),
#  ('LotShapeDummy_Reg', 4.282703461648585),
#  ('LotConfigDummy_CulDSac', 1.7890204955378395),
#  ('LotConfigDummy_FR2', 1.3963052977826649),
#  ('LotConfigDummy_FR3', 1.0865972073329098),
#  ('LotConfigDummy_Inside', 6.242129597561939),
#  ('NeighborhoodDummy_Blueste', 1.307508062400467),
#  ('NeighborhoodDummy_BrDale', 3.041935396873079),
#  ('NeighborhoodDummy_BrkSide', 6.676093617358668),
#  ('NeighborhoodDummy_ClearCr', 2.7008093225518315),
#  ('NeighborhoodDummy_CollgCr', 12.446164940405705),
#  ('NeighborhoodDummy_Crawfor', 5.079214683559621),
#  ('NeighborhoodDummy_Edwards', 8.7783418991297),
#  ('NeighborhoodDummy_Gilbert', 7.584497897443722),
#  ('NeighborhoodDummy_IDOTRR', 3.662247596936609),
#  ('NeighborhoodDummy_MeadowV', 3.0388340513957655),
#  ('NeighborhoodDummy_Mitchel', 5.326064466879947),
#  ('NeighborhoodDummy_NAmes', 21.219691469392874),
#  ('NeighborhoodDummy_NPkVill', 2.0246855478379597),
#  ('NeighborhoodDummy_NWAmes', 7.296437134660431),
#  ('NeighborhoodDummy_NoRidge', 4.675265615731267),
#  ('NeighborhoodDummy_NridgHt', 6.823980877201108),
#  ('NeighborhoodDummy_OldTown', 12.190870594292031),
#  ('NeighborhoodDummy_SWISU', 3.287735533972756),
#  ('NeighborhoodDummy_Sawyer', 7.600002214928967),
#  ('NeighborhoodDummy_SawyerW', 5.582489244226549),
#  ('NeighborhoodDummy_Somerst', 11.457471537498707),
#  ('NeighborhoodDummy_StoneBr', 2.7158434362780963),
#  ('NeighborhoodDummy_Timber', 3.542142416962188),
#  ('NeighborhoodDummy_Veenker', 1.8503914098628012),
#  ('HouseStyleDummy_1.5Unf', 1.673704754449146),
#  ('HouseStyleDummy_1Story', 45.97407268470706),
#  ('HouseStyleDummy_2.5Fin', 1.9253174531738193),
#  ('HouseStyleDummy_2.5Unf', 1.180538463529409),
#  ('HouseStyleDummy_2Story', 8.669157253395195),
#  ('HouseStyleDummy_SFoyer', 2.9609669951245636),
#  ('HouseStyleDummy_SLvl', 3.4552545310612532),
#  ('RoofStyleDummy_Gable', 255.88997642445744),
#  ('RoofStyleDummy_Gambrel', 3.0924624376370495),
#  ('RoofStyleDummy_Hip', 59.657399439171925),
#  ('RoofStyleDummy_Mansard', 2.104297704761773),
#  ('Exterior1stDummy_BrkComm', 1.1362735153787236),
#  ('Exterior1stDummy_BrkFace', 4.736934083436537),
#  ('Exterior1stDummy_CBlock', 1.2020836482965482),
#  ('Exterior1stDummy_CemntBd', 5.8195166299482635),
#  ('Exterior1stDummy_HdBoard', 20.747736795375285),
#  ('Exterior1stDummy_ImStucc', 1.1933912043051325),
#  ('Exterior1stDummy_MetalSd', 18.897126949552543),
#  ('Exterior1stDummy_Plywood', 9.69553412487381),
#  ('Exterior1stDummy_Stone', 1.222476679722897),
#  ('Exterior1stDummy_Stucco', 2.258100805108115),
#  ('Exterior1stDummy_VinylSd', 47.33413174200074),
#  ('Exterior1stDummy_Wd Sdng', 16.769102519029186),
#  ('Exterior1stDummy_WdShing', 3.080776604003366),
#  ('MasVnrTypeDummy_BrkFace', 37.19864083331674),
#  ('MasVnrTypeDummy_No_MasVnr', 1.8071901713106555),
#  ('MasVnrTypeDummy_None', 68.98159620359863),
#  ('MasVnrTypeDummy_Stone', 11.318905373818279),
#  ('FoundationDummy_CBlock', 11.311286397908907),
#  ('FoundationDummy_PConc', 13.946649959133193),
#  ('FoundationDummy_Slab', 2.561207100696159),
#  ('FoundationDummy_Stone', 1.1471808620414146),
#  ('FoundationDummy_Wood', 1.246225822911326),
#  ('GarageTypeDummy_Attchd', 201.23058699460753),
#  ('GarageTypeDummy_Basment', 4.731485860769997),
#  ('GarageTypeDummy_BuiltIn', 19.3728240177922),
#  ('GarageTypeDummy_CarPort', 2.651033711159176),
#  ('GarageTypeDummy_Detchd', 84.50820294498182),
#  ('GarageTypeDummy_No_Garage', 950.8916974364178),
#  ('SaleConditionDummy_AdjLand', 1.0703584066525864),
#  ('SaleConditionDummy_Alloca', 1.3564802690562776),
#  ('SaleConditionDummy_Family', 1.322885022714564),
#  ('SaleConditionDummy_Normal', 16.12632377027562),
#  ('SaleConditionDummy_Partial', 2.9745041552699445)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X_Scaled.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
stats.summary(gridLasso.best_estimator_, X_Scaled, y)
