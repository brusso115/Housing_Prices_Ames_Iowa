# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2357.2599295573427), ('GrLivArea', 1519.0444845001227), ('GarageCars', 1017.1507895603902), ('ExterQual', 1015.3073515980078), ('TotalBsmtSF', 913.720935556808), ('GarageArea', 899.4275280160379), ('KitchenQual', 797.8269447517779), ('BsmtQual', 789.1419761943806), ('1stFlrSF', 759.845899444944), ('FullBath', 647.5351240117253), ('TotRmsAbvGrd', 603.2330027520226), ('YearBuilt', 587.4683322414133), ('YearRemodAdd', 459.57370374050487), ('MasVnrArea', 355.81718208005674), ('GarageFinish', 341.49632667035627), ('Fireplaces', 324.63797307325336), ('HeatingQC', 274.6176570901941), ('BsmtFinSF1', 224.137696145814), ('MSSubClassDummy_60', 215.50933882537865), ('LotFrontage', 204.06789328584026), ('OpenPorchSF', 190.65974124747092), ('WoodDeckSF', 150.38726431970255), ('BsmtExposure', 146.36115186200846), ('LotArea', 137.8615266566324), ('2ndFlrSF', 120.82172760730981), ('HalfBath', 97.10569012973919), ('BsmtFullBath', 79.33460583203406), ('MSSubClassDummy_30', 71.79787226140209), ('BsmtUnfSF', 71.3885774387832), ('GarageYrBlt', 62.35711631802463), ('GarageCond', 49.1923773873856), ('GarageQual', 47.766381004899934), ('MSSubClassDummy_50', 41.196502225834045), ('BedroomAbvGr', 40.1132797518304), ('Fence', 38.917000869105806), ('OverallCond', 31.466775744366622), ('EnclosedPorch', 20.25901299577393), ('ExterCond', 19.052243100870328), ('KitchenAbvGr', 17.73133902958181), ('MSSubClassDummy_45', 7.2285082908647835), ('BsmtFinType2', 7.024204242476648), ('BsmtFinType1', 6.122970116924336), ('ScreenPorch', 4.633185095237071), ('BsmtHalfBath', 4.51638665643799), ('BsmtCond', 4.338611682063214), ('MoSold', 4.188439856910767), ('FireplaceQu', 4.067643448841854), ('LowQualFinSF', 3.944150308901957), ('3SsnPorch', 2.3899215374711393), ('LandSlope', 1.7233069181147846), ('MiscVal', 0.9396029787401404), ('BsmtFinSF2', 0.5363414900644955), ('YrSold', 0.024233110722966824), ('PoolArea', 0.007674113087988735), ('PoolQC', 0.0032527251013259074), ('MSSubClassDummy_40', 0.0006249002274557575), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 279.6589420651194), ('NeighborhoodDummy_NoRidge', 162.58837368198593), ('MSZoningDummy_RM', 134.37160095356538), ('LotShapeDummy_Reg', 88.72361291294862), ('MSZoningDummy_RL', 77.55192647533528), ('NeighborhoodDummy_NAmes', 66.34707907554237), ('NeighborhoodDummy_OldTown', 58.47032911781518), ('NeighborhoodDummy_Edwards', 49.92968891186174), ('NeighborhoodDummy_StoneBr', 37.65603680975148), ('NeighborhoodDummy_BrkSide', 30.837813861470618), ('NeighborhoodDummy_Sawyer', 29.68456046052015), ('NeighborhoodDummy_Timber', 27.802686290570758), ('NeighborhoodDummy_Somerst', 27.659087430877943), ('MSSubClassDummy_160', 22.78571632569181), ('LotConfigDummy_CulDSac', 17.82605995261617), ('NeighborhoodDummy_BrDale', 17.637637430678335), ('NeighborhoodDummy_IDOTRR', 17.616877245422955), ('Condition1Dummy_Norm', 17.27798042259933), ('NeighborhoodDummy_MeadowV', 16.09352418445402), ('AlleyDummy_No_Alley_Access', 14.772839261248127), ('MSSubClassDummy_90', 14.037418693823007), ('Condition1Dummy_Feedr', 14.034257632220585), ('LandContourDummy_HLS', 11.501699205271875), ('MSZoningDummy_FV', 10.850846635150589), ('NeighborhoodDummy_CollgCr', 10.349589627637092), ('MSSubClassDummy_190', 10.155318512089403), ('LotConfigDummy_Inside', 7.726943780753719), ('NeighborhoodDummy_Mitchel', 6.2703893599362495), ('MSZoningDummy_RH', 6.171856478437915), ('LotShapeDummy_IR2', 6.163850970879646), ('NeighborhoodDummy_ClearCr', 5.851551202134586), ('MSSubClassDummy_180', 5.2777169125425045), ('MSSubClassDummy_85', 4.9373073825750975), ('NeighborhoodDummy_SWISU', 4.6595515150301265), ('Condition1Dummy_PosA', 3.3388318032242603), ('MSSubClassDummy_120', 3.2764897838334996), ('LandContourDummy_Low', 2.7165861370337994), ('NeighborhoodDummy_Veenker', 2.7095179606388435), ('NeighborhoodDummy_NPkVill', 2.6471484126531513), ('NeighborhoodDummy_Crawfor', 2.558473959715394), ('Condition1Dummy_RRAe', 2.2567354543733216), ('Cond ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.40479259, 0.24415321]),
#  'std_fit_time': array([0.02767631, 0.01833574]),
#  'mean_score_time': array([0.01057148, 0.01227746]),
#  'std_score_time': array([0.00107946, 0.00184558]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.85788502, 0.88167776]),
#  'split1_test_score': array([0.90042198, 0.87890481]),
#  'split2_test_score': array([0.86293286, 0.86012408]),
#  'split3_test_score': array([0.8533578 , 0.84139313]),
#  'split4_test_score': array([0.89298676, 0.88526626]),
#  'mean_test_score': array([0.87351688, 0.86947321]),
#  'std_test_score': array([0.01931696, 0.01651196]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8735168837935665

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5537534812287033),
#  ('GrLivArea', 0.11926693350371145),
#  ('BsmtFinSF1', 0.056487269229584906),
#  ('TotalBsmtSF', 0.047210914795208586),
#  ('GarageArea', 0.042278146862581446),
#  ('GarageCars', 0.02119632440746821),
#  ('1stFlrSF', 0.020747222156926856),
#  ('MasVnrArea', 0.009303575818439654),
#  ('LotArea', 0.008519381002736692),
#  ('YearRemodAdd', 0.007297117273880217),
#  ('TotRmsAbvGrd', 0.00704283532324734),
#  ('BsmtUnfSF', 0.006996645666365192),
#  ('YearBuilt', 0.0067751808853370645),
#  ('BsmtQual', 0.006532269130795142),
#  ('LotFrontage', 0.005773894880230241),
#  ('GarageFinish', 0.005081277732436772),
#  ('GarageYrBlt', 0.00487511777185152),
#  ('OpenPorchSF', 0.004850375323671791),
#  ('2ndFlrSF', 0.004782605005084698),
#  ('OverallCond', 0.004188069319901325),
#  ('WoodDeckSF', 0.003531082118173131),
#  ('KitchenQual', 0.0031952433066893132),
#  ('FunctionalDummy_Typ', 0.0027990992276294775),
#  ('MoSold', 0.002639506221738068),
#  ('ExterQual', 0.002437674781621099),
#  ('GarageTypeDummy_CarPort', 0.0017505450125007774),
#  ('Fireplaces', 0.0016979965840602756),
#  ('BsmtFinType1', 0.001691416369272603),
#  ('BsmtExposure', 0.0015574679874680484),
#  ('BedroomAbvGr', 0.0014782743508302372),
#  ('MSZoningDummy_RL', 0.0014628869861792915),
#  ('YrSold', 0.001432462939394242),
#  ('FullBath', 0.0013604785639915154),
#  ('LotShapeDummy_IR3', 0.0013227961581934622),
#  ('BsmtFullBath', 0.001196487553861526),
#  ('HalfBath', 0.0011339392800628963),
#  ('FireplaceQu', 0.0011168526179366962),
#  ('NeighborhoodDummy_CollgCr', 0.0008663941515524312),
#  ('EnclosedPorch', 0.0008422359108243862),
#  ('ScreenPorch', 0.0008407787427911497),
#  ('HeatingQC', 0.0008070350448790595),
#  ('RoofStyleDummy_Gambrel', 0.0007323180760283339),
#  ('Exterior2ndDummy_Stucco', 0.0005893129132032137),
#  ('FoundationDummy_Stone', 1.1871724940125272e-06),
#  ('LotConfigDummy_Inside', 1.143839550459611e-06),
#  ('SaleConditionDummy_AdjLand', 1.1123213581017463e-06),
#  ('Condition1Dummy_RRNe', 1.0112035489526204e-06),
#  ('Condition2Dummy_RRAe', 9.690512772274677e-07),
#  ('BldgTypeDummy_TwnhsE', 7.422410642455384e-07),
#  ('HeatingDummy_GasW', 5.815895384071875e-07),
#  ('NeighborhoodDummy_Blueste', 5.305373942597367e-07),
#  ('Exterior1stDummy_WdShing', 4.5611400912866225e-07),
#  ('SaleTypeDummy_ConLD', 4.251765254862486e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 3.6068337231276604e-07),
#  ('HouseStyleDummy_1Story', 3.570020377335971e-07),
#  ('SaleTypeDummy_Con', 3.501202880798893e-07),
#  ('MSSubClassDummy_30', 3.0765393636579035e-07),
#  ('RoofStyleDummy_Hip', 2.532429869180121e-07),
#  ('HeatingDummy_OthW', 1.925362874284957e-07),
#  ('MSSubClassDummy_160', 1.8127274716085584e-07),
#  ('FoundationDummy_Slab', 1.4815732737009423e-07),
#  ('Condition2Dummy_RRAn', 1.0981729535511985e-07),
#  ('Condition1Dummy_RRNn', 5.3947143793648314e-08),
#  ('SaleTypeDummy_WD', 2.5183704220829604e-10),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('Exterior1stDummy_BrkFace', 0.0),
#  ('Exterior1stDummy_HdBoard', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.0242703 , 0.00502839, 0.00488791, 0.00507941, 0.00499802,
#         0.00508504, 0.00488706, 0.00532036]),
#  'std_fit_time': array([3.82965396e-02, 6.97542195e-05, 9.48185144e-05, 1.54651354e-04,
#         1.15219527e-04, 1.91456467e-04, 8.81029914e-05, 2.25985973e-04]),
#  'mean_score_time': array([0.00269637, 0.00266848, 0.00266747, 0.00274663, 0.00267982,
#         0.00269575, 0.00269742, 0.00285606]),
#  'std_score_time': array([5.18082201e-05, 4.93865196e-05, 7.62245339e-05, 1.35312103e-04,
#         7.84029628e-05, 8.73393871e-05, 7.94546361e-05, 1.48892920e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.87546976, 0.87838514, 0.88486031, 0.89133664, 0.89334832,
#         0.89486214, 0.89624857, 0.87939279]),
#  'split1_test_score': array([0.89659285, 0.89941893, 0.90457211, 0.90646795, 0.90632443,
#         0.90600071, 0.87857056, 0.84576169]),
#  'split2_test_score': array([0.86732484, 0.87765862, 0.88461955, 0.89127504, 0.89297157,
#  ('MasVnrArea', 4352.815583249475),
#  ('YearBuilt', 4240.982709878778),
#  ('KitchenQual', -4213.276070726817),
#  ('ExterQual', -3998.034599030749),
#  ('NeighborhoodDummy_NWAmes', 3857.3932325504184),
#  ('TotRmsAbvGrd', 3723.8135822427516),
#  ('FunctionalDummy_Sev', 3704.974641553427),
#  ('NeighborhoodDummy_Somerst', 3698.826155321292),
#  ('GarageCars', 3466.0176444993513),
#  ('SaleTypeDummy_ConLw', 3035.4315631243803),
#  ('Condition1Dummy_Feedr', 2479.501111033911),
#  ('Exterior1stDummy_BrkComm', 2472.275091654074),
#  ('NeighborhoodDummy_NPkVill', -2342.88676518302),
#  ('GarageArea', 2242.7001703445153),
#  ('SaleConditionDummy_Family', 2237.2470550809776),
#  ('BldgTypeDummy_Duplex', -2187.9655023564756),
#  ('BldgTypeDummy_Twnhs', -2177.2096009795277),
#  ('BedroomAbvGr', -2173.293900045583),
#  ('NeighborhoodDummy_Mitchel', -2145.6337117970193),
#  ('NeighborhoodDummy_CollgCr', 2125.004759192511),
#  ('Exterior1stDummy_VinylSd', -2123.212513496028),
#  ('BsmtExposure', -2093.919641839486),
#  ('YearRemodAdd', 2031.9609339305512),
#  ('MSSubClassDummy_90', -2007.2742811437145),
#  ('NeighborhoodDummy_Crawfor', -1996.3020066142312),
#  ('UtilitiesDummy_NoSeWa', 1964.4889737240296),
#  ('KitchenAbvGr', -1904.6633106677834),
#  ('OpenPorchSF', 1862.9522755467165),
#  ('Fireplaces', 1823.5909305208866),
#  ('MSSubClassDummy_120', -1806.3024588584044),
#  ('NeighborhoodDummy_Edwards', -1793.420741912512),
#  ('LotFrontage', 1779.0139744009655),
#  ('WoodDeckSF', 1775.5214706643217),
#  ('NeighborhoodDummy_MeadowV', -1688.1701235625837),
#  ('FoundationDummy_CBlock', 1657.924530299371),
#  ('NeighborhoodDummy_ClearCr', -1652.8596765473474),
#  ('MiscFeatureDummy_TenC', 1638.1388645358502),
#  ('SaleConditionDummy_Normal', 1629.6004563448205),
#  ('Exterior2ndDummy_Wd Sdng', -1591.2425691189837),
#  ('LotShapeDummy_Reg', 1584.7382502465478),
#  ('LandContourDummy_HLS', -1496.7733702965227),
#  ('FunctionalDummy_Mod', -1485.342425214262),
#  ('FoundationDummy_PConc', 1484.7197837140016),
#  ('ScreenPorch', 1461.5368761282273),
#  ('NeighborhoodDummy_Blueste', 1406.7914163228752),
#  ('RoofMatlDummy_CompShg', 1395.1678355885656),
#  ('FullBath', 1365.0405399472738),
#  ('MSSubClassDummy_190', 1354.1820692230751),
#  ('Exterior2ndDummy_CBlock', 1323.3612102809916),
#  ('BsmtUnfSF', -1309.3063349064612),
#  ('NeighborhoodDummy_NridgHt', -1295.2831050728792),
#  ('Condition1Dummy_PosN', -1261.860738574878),
#  ('MasVnrTypeDummy_None', 1259.1860820715144),
#  ('MasVnrTypeDummy_No_MasVnr', 1254.242047232809),
#  ('HouseStyleDummy_2.5Unf', -1229.552051965035),
#  ('LotConfigDummy_CulDSac', -1228.1098564240842),
#  ('Exterior1stDummy_Stone', 1200.988454780575),
#  ('SaleTypeDummy_CWD', 1176.300426427883),
#  ('Exterior1stDummy_CBlock', -1103.8271976660383),
#  ('Exterior2ndDummy_Other', -1079.144747353312),
#  ('MSSubClassDummy_75', -1078.6815775242576),
#  ('GarageTypeDummy_CarPort', 1070.910216554789),
#  ('Exterior1stDummy_Wd Sdng', 1055.0199838313977),
#  ('HouseStyleDummy_1Story', -1048.633220864494),
#  ('BsmtFullBath', 1023.3420300501222),
#  ('RoofStyleDummy_Mansard', 1019.9031439783022),
#  ('Exterior2ndDummy_CmentBd', -1017.4298117457349),
#  ('NeighborhoodDummy_OldTown', -1001.6069185332883),
#  ('SaleTypeDummy_ConLD', 998.6334947837349),
#  ('FoundationDummy_Stone', -991.07555341049),
#  ('FunctionalDummy_Min2', -988.8702505031275),
#  ('Exterior2ndDummy_VinylSd', 985.2955948937059),
#  ('PoolArea', 970.470736654642),
#  ('GarageFinish', -916.0366181481211),
#  ('LotConfigDummy_FR2', -902.199379260873),
#  ('BsmtFinSF2', 894.785728811857),
#  ('HouseStyleDummy_SFoyer', 883.8978269518972),
#  ('SalePrice', -864.6143657306427),
#  ('HouseStyleDummy_2.5Fin', -857.8054194894278),
#  ('PavedDriveDummy_P', 836.5887624489802),
#  ('NeighborhoodDummy_BrDale', 812.3094080098749),
#  ('HalfBath', 784.8842471157501),
#  ('HeatingQC', -775.1119045118522),
#  ('MSSubClassDummy_180', -771.7651061223988),
#  ('Condition2Dummy_RRNn', -771.7651061223968),
#  ('MSZoningDummy_RM', 766.2080798310508),
#  ('HouseStyleDummy_SLvl', -742.2629455485995),
#  ('NeighborhoodDummy_NAmes', 725.291153040906),
#  ('SaleTypeDummy_WD', 724.3377982509977),
#  ('Exterior2ndDummy_Wd Shng', -713.7091640638472),
#  ('Exterior1stDummy_ImStucc', 712.7070670809231),
#  ('MSSubClassDummy_80', -709.5668593864377),
#  ('RoofMatlDummy_Tar&Grv', -699.5609584596148),
#  ('MSSubClassDummy_50', 670.5152982821543),
#  ('MSZoningDummy_FV', 661.9007295550044),
#  ('SaleTypeDummy_Con', 657.8372093156837),
#  ('GarageTypeDummy_Basment', 644.6551926153422),
#  ('NeighborhoodDummy_StoneBr', -638.9998846193691),
#  ('Exterior1stDummy_HdBoard', -607.5219240487545),
#  ('RoofStyleDummy_Gambrel', 607.0666362002868),
#  ('BsmtFinType2', -586.8270065518335),
#  ('FunctionalDummy_Min1', 576.0448781736177),
#  ('3SsnPorch', 572.1595672820789),
#  ('SaleConditionDummy_Alloca', 561.4014271947603),
#  ('NeighborhoodDummy_Sawyer', -554.554992603482),
#  ('GarageTypeDummy_Detchd', 547.0113854606726),
#  ('ExterCond', 543.5504864475125),
#  ('NeighborhoodDummy_Timber', 527.0479574532221),
#  ('GarageYrBlt', -525.2475827718546),
#  ('Exterior1stDummy_CemntBd', -513.7475150740172),
#  ('RoofMatlDummy_Membran', 510.8881693988751),
#  ('CentralAirDummy_Y', -479.0354331327606),
#  ('LotShapeDummy_IR3', 478.39169951043317),
#  ('BsmtCond', 464.53626165488333),
#  ('FireplaceQu', -461.702714221872),
#  ('LandSlope', -458.1622130359624),
#  ('MSSubClassDummy_70', 452.6520384524917),
#  ('StreetDummy_Pave', 447.7568343826228),
#  ('MSZoningDummy_RH', 444.9425736860212),
#  ('BldgTypeDummy_2fmCon', -436.63849737419906),
#  ('MSSubClassDummy_85', -436.63849737419747),
#  ('FoundationDummy_Slab', -434.1633907080694),
#  ('RoofMatlDummy_Roll', -430.9298600557293),
#  ('MoSold', -420.26893215076285),
#  ('Condition1Dummy_PosA', 410.013029535311),
#  ('Condition1Dummy_RRAn', -393.62287235860913),
#  ('MSZoningDummy_RL', -388.768132236571),
#  ('Exterior2ndDummy_AsphShn', 387.4278221707751),
#  ('LotShapeDummy_IR2', -379.3845870049581),
#  ('NeighborhoodDummy_IDOTRR', -375.9765780802647),
#  ('SaleConditionDummy_AdjLand', -370.0630654314732),
#  ('HeatingDummy_GasA', -367.4731079060302),
#  ('Condition1Dummy_RRAe', 352.47021071378333),
#  ('HouseStyleDummy_2Story', -349.5808519162741),
#  ('NeighborhoodDummy_SawyerW', 343.21559972114136),
#  ('Exterior1stDummy_MetalSd', -340.9462929174858),
#  ('HeatingDummy_GasW', -337.36514881469026),
#  ('Exterior1stDummy_WdShing', 335.4507587675842),
#  ('BldgTypeDummy_TwnhsE', 335.33460309522894),
#  ('RoofMatlDummy_WdShake', 332.1733800798637),
#  ('Condition1Dummy_RRNn', -332.04776112463713),
#  ('ElectricalDummy_SBrkr', -328.31573589567023),
#  ('MasVnrTypeDummy_Stone', 321.5777187600558),
#  ('SaleTypeDummy_New', 315.20885017444533),
#  ('GarageTypeDummy_No_Garage', -310.2266644804837),
#  ('LandContourDummy_Low', -299.24219411839476),
#  ('RoofMatlDummy_WdShngl', -294.13460497641233),
#  ('YrSold', -290.9528186863373),
#  ('Exterior1stDummy_AsphShn', -289.82868128680514),
#  ('MiscFeatureDummy_Othr', 283.7381549636742),
#  ('MSSubClassDummy_45', -280.6777115660694),
#  ('Exterior2ndDummy_BrkFace', -278.3069715851291),
#  ('Exterior1stDummy_BrkFace', -278.3069715851267),
#  ('Exterior2ndDummy_Plywood', -265.76502591367773),
#  ('Condition2Dummy_Feedr', -261.33326301130336),
#  ('LowQualFinSF', -260.29105965941216),
#  ('SaleTypeDummy_Oth', -258.9754254653368),
#  ('MSSubClassDummy_160', 251.4724458061423),
#  ('PoolQC', 247.71465365959543),
#  ('Exterior2ndDummy_HdBoard', 242.34765153494465),
#  ('Condition2Dummy_RRAn', -240.35981713143673),
#  ('RoofStyleDummy_Gable', 236.1320682112338),
#  ('BsmtHalfBath', -230.4367151913987),
#  ('BsmtFinType1', 216.19396891400768),
#  ('GarageTypeDummy_Attchd', -213.63420581702835),
#  ('Condition1Dummy_RRNe', 211.86279532637576),
#  ('LotConfigDummy_Inside', 205.57349410450917),
#  ('NeighborhoodDummy_Veenker', 203.91589988110462),
#  ('MSSubClassDummy_40', -200.79277902716788),
#  ('HeatingDummy_OthW', -200.78866899847657),
#  ('Condition1Dummy_Norm', 199.80988631214524),
#  ('Exterior2ndDummy_Brk Cmn', -195.0460500806123),
#  ('GarageTypeDummy_BuiltIn', -194.7100260105034),
#  ('FunctionalDummy_Maj2', -190.56558449769605),
#  ('RoofStyleDummy_Hip', -183.39416587938672),
#  ('SaleTypeDummy_ConLI', -163.87248405849843),
#  ('AlleyDummy_Pave', -163.455195713685),
#  ('FoundationDummy_Wood', -161.3864703957857),
#  ('PavedDriveDummy_Y', -156.49933215081552),
#  ('Fence', 155.15030438152624),
#  ('FunctionalDummy_Typ', -148.75759362686017),
#  ('ElectricalDummy_Mix', -148.05273449446827),
#  ('MSSubClassDummy_30', 141.14256495255086),
#  ('GarageCond', 140.07024133185237),
#  ('NeighborhoodDummy_SWISU', -132.77171516537786),
#  ('Exterior1stDummy_Stucco', -123.72818272972307),
#  ('Exterior2ndDummy_MetalSd', -121.33338557589144),
#  ('Condition2Dummy_RRAe', -121.23481673324167),
#  ('GarageQual', 112.08170911449078),
#  ('Exterior2ndDummy_ImStucc', -105.8669315563468),
#  ('NeighborhoodDummy_BrkSide', -93.58477323165044),
#  ('MSSubClassDummy_60', 93.55817101572539),
#  ('MiscVal', 88.38603561736898),
#  ('HouseStyleDummy_1.5Unf', -84.6533682100286),
#  ('AlleyDummy_No_Alley_Access', -83.6221537652442),
#  ('MiscFeatureDummy_No_Misc_Feature', 82.14729031457287),
#  ('Exterior1stDummy_Plywood', -77.44298514993086),
#  ('RoofStyleDummy_Shed', 53.30714501328741),
#  ('NeighborhoodDummy_Gilbert', -50.24834140804799),
#  ('LotConfigDummy_FR3', -36.43917687654366),
#  ('HeatingDummy_Wall', -31.029906457023277),
#  ('MasVnrTypeDummy_BrkFace', -22.82294661652506),
#  ('Exterior2ndDummy_Stucco', 15.876838250634457),
#  ('Exterior2ndDummy_Stone', 8.445511089553522),
#  ('EnclosedPorch', 6.273136954969623),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166477386405.17148, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166207873731.52832, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171345919457.85297, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159177671862.39478, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173456705060.7294, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81411550676.16306, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130039103890.02216, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130325904552.51645, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119228201472.48372, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145997597256.34814, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1514898650.3119507, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6239529954.818359, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11615639, 0.12145176, 0.12930522, 0.09156628, 0.06100693,
#         0.05188713, 0.00980964, 0.00826683]),
#  'std_fit_time': array([0.00554941, 0.0032504 , 0.00515255, 0.00349401, 0.00413209,
#         0.00139545, 0.00045001, 0.00050816]),
#  'mean_score_time': array([0.00265388, 0.00257468, 0.00280838, 0.00317335, 0.002981  ,
#         0.00333071, 0.00287561, 0.00294919]),
#  'std_score_time': array([2.44278068e-04, 1.43473320e-04, 3.29768919e-04, 3.03532602e-04,
#         1.11652864e-04, 1.84798362e-04, 9.33798134e-05, 2.15022017e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.8752241 , 0.87625377, 0.88148226, 0.88694954, 0.889283  ,
#         0.89082891, 0.90099831, 0.89196873]),
#  'split1_test_score': array([0.89713807, 0.89765946, 0.90220372, 0.90954602, 0.91120454,
#         0.91257779, 0.90987473, 0.89928258]),
#  'split2_test_score': array([0.87246771, 0.8738684 , 0.88065761, 0.88658976, 0.88852792,
#         0.88959804, 0.88731951, 0.87572206]),
#  'split3_test_score': array([0.88142132, 0.88164153, 0.88301826, 0.88502615, 0.88568382,
#         0.88621105, 0.8803773 , 0.864223  ]),
#  'split4_test_score': array([0.88777617, 0.88759032, 0.88845733, 0.89094718, 0.89254674,
#         0.89359319, 0.89972845, 0.88923602]),
#  'mean_test_score': array([0.88280548, 0.8834027 , 0.88716384, 0.89181173, 0.8934492 ,
#         0.8945618 , 0.89565966, 0.88408648]),
#  'std_test_score': array([0.00890386, 0.00855457, 0.00799585, 0.00907972, 0.00914269,
#         0.00931475, 0.01049031, 0.0125227 ]),
#  'rank_test_score': array([8, 7, 5, 4, 3, 2, 1, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8956596616975384

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 22389.379252846004),
#  ('OverallQual', 12780.746732461263),
#  ('BsmtFinSF1', 9202.494009705766),
#  ('TotalBsmtSF', 6860.229504692657),
#  ('NeighborhoodDummy_NoRidge', 5346.797189058236),
#  ('ExterQual', -4938.554157305911),
#  ('KitchenQual', -4926.940720172609),
#  ('LotArea', 4568.377765169565),
#  ('BsmtQual', -4441.273748358473),
#  ('OverallCond', 3964.5431745698365),
#  ('YearBuilt', 3939.503688467439),
#  ('SaleTypeDummy_ConLw', 3752.472667285292),
#  ('NeighborhoodDummy_NWAmes', 3512.671678283955),
#  ('MasVnrArea', 3339.314506187857),
#  ('FunctionalDummy_Sev', 3116.181410215325),
#  ('GarageCars', 2998.1620105573484),
#  ('NeighborhoodDummy_Somerst', 2601.411462688731),
#  ('KitchenAbvGr', -2313.6346429689447),
#  ('Exterior1stDummy_BrkComm', 2021.3906567644733),
#  ('GarageArea', 2015.501115416964),
#  ('YearRemodAdd', 1833.5944245594087),
#  ('NeighborhoodDummy_CollgCr', 1733.0629438292801),
#  ('Fireplaces', 1539.1451182198555),
#  ('MSSubClassDummy_120', -1392.6678986397546),
#  ('Condition1Dummy_Feedr', 1342.2411870242654),
#  ('MSSubClassDummy_90', -1289.4588051062597),
#  ('FunctionalDummy_Mod', -1203.4809965674938),
#  ('LotShapeDummy_Reg', 1182.7032961555985),
#  ('BldgTypeDummy_Duplex', -1026.8756088666041),
#  ('BsmtExposure', -1025.768098393213),
#  ('BldgTypeDummy_Twnhs', -949.9594920793264),
#  ('UtilitiesDummy_NoSeWa', 947.9806067368042),
#  ('WoodDeckSF', 944.7730519832018),
#  ('NeighborhoodDummy_SawyerW', 829.3803405920496),
#  ('OpenPorchSF', 827.1719298099966),
#  ('NeighborhoodDummy_NPkVill', -818.7551057475018),
#  ('Exterior2ndDummy_Wd Shng', -778.2677092895005),
#  ('LotFrontage', 750.0528074187279),
#  ('SaleTypeDummy_CWD', 685.6290878747939),
#  ('BsmtFinSF2', 680.829928530505),
#  ('HouseStyleDummy_SLvl', -637.8352233888207),
#  ('MiscFeatureDummy_TenC', 606.3184813447158),
#  ('TotRmsAbvGrd', 582.9231580299225),
#  ('Exterior1stDummy_VinylSd', -534.6263055578243),
#  ('NeighborhoodDummy_NridgHt', -496.1350871233379),
#  ('HeatingQC', -491.5458136059702),
#  ('GarageFinish', -486.8498041293979),
#  ('Exterior2ndDummy_Wd Sdng', -330.0257475778167),
#  ('MSZoningDummy_RL', -294.1100632099132),
#  ('NeighborhoodDummy_BrDale', 290.28699228918066),
#  ('ScreenPorch', 273.46870890924106),
#  ('NeighborhoodDummy_OldTown', -261.4537956662725),
#  ('FoundationDummy_CBlock', 256.79958616500994),
#  ('FoundationDummy_PConc', 253.71282239206027),
#  ('NeighborhoodDummy_MeadowV', -245.10292249196004),
#  ('BsmtFullBath', 187.87660226448764),
#  ('BsmtFinType2', -181.93852036449488),
#  ('Condition1Dummy_PosN', -176.14670522430546),
#  ('MasVnrTypeDummy_None', 160.44761759763594),
#  ('BedroomAbvGr', -156.96440426320015),
#  ('SaleTypeDummy_ConLD', 141.01365235463564),
#  ('FoundationDummy_Stone', -138.13635151766866),
#  ('LowQualFinSF', -119.47370340306983),
#  ('Exterior1stDummy_CemntBd', -117.76313431181057),
#  ('Exterior1stDummy_Stone', 113.63895030586717),
#  ('HouseStyleDummy_1Story', -101.02189327767044),
#  ('Exterior1stDummy_AsphShn', -88.91837953034184),
#  ('MSSubClassDummy_70', -64.66383479886825),
#  ('RoofMatlDummy_CompShg', 44.24224973284187),
#  ('Condition2Dummy_RRNn', -2.673612689757095),
#  ('MSSubClassDummy_180', -1.3385994768231222),
#  ('LandSlope', 0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('FireplaceQu', -0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', 0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', 0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', 0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Timber', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('BldgTypeDummy_2fmCon', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_CmentBd', -0.0),
#  ('Exterior2ndDummy_HdBoard', -0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Other', -0.0),
#  ('Exterior2ndDummy_Plywood', -0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Min2', -0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_Con', 0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', -0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', 0.0),
#  ('SaleConditionDummy_Normal', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8763949998445615

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.893002454303409

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172265197773.37433, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187019791838.43686, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167499907620.31097, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173747418978.08804, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181518459016.6938, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23598145108.278046, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141782541427.05048, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25958116127.69464, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94622212059.82718, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67438040516.53833, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7241468345.923462, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8931305251309428

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999142
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998918
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998670
# PoolArea                  PoolQC                       0.997981
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.995055
# GarageYrBlt               GarageTypeDummy_No_Garage    0.993900
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.990471
# GarageCars                GarageArea                   0.988694
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.986555
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984216
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.982015
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.972266
# GrLivArea                 TotRmsAbvGrd                 0.970172
# ExterQual                 KitchenQual                  0.965709
# OverallQual               ExterQual                    0.960682
# TotalBsmtSF               1stFlrSF                     0.955966
# ExterQual                 BsmtQual                     0.954621
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.952943
# BsmtQual                  FoundationDummy_PConc        0.952045
# 2ndFlrSF                  HouseStyleDummy_2Story       0.950590
# OverallQual               BsmtQual                     0.949250
# YearRemodAdd              BsmtQual                     0.942899
#                           FoundationDummy_PConc        0.941761
# OverallQual               GarageCars                   0.941026
#                           KitchenQual                  0.940862
# MasVnrArea                MasVnrTypeDummy_None         0.940144
# HalfBath                  HouseStyleDummy_2Story       0.930329
# FoundationDummy_CBlock    FoundationDummy_PConc        0.929532
# YearBuilt                 BsmtQual                     0.925861
# OverallQual               FullBath                     0.925166
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.924677
# ExterQual                 FoundationDummy_PConc        0.924370
# YearRemodAdd              ExterQual                    0.923592
# BsmtQual                  KitchenQual                  0.923311
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.920631
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.919704
# YearBuilt                 YearRemodAdd                 0.918002
# OverallQual               GarageArea                   0.916719
#                           YearRemodAdd                 0.912091
# BsmtFinSF1                BsmtFullBath                 0.910744
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.909614
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.908264
# KitchenAbvGr              MSSubClassDummy_90           0.908131
# FullBath                  GarageCars                   0.906507
# OverallQual               FoundationDummy_PConc        0.904039
# BsmtQual                  GarageCars                   0.903453
# HalfBath                  MSSubClassDummy_60           0.902285
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.901610
# 2ndFlrSF                  HalfBath                     0.900461
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.8671957807110506),
#  ('LotArea', 2.212852546525957),
#  ('OverallQual', 4.6967671701521),
#  ('OverallCond', 2.0739932523822775),
#  ('YearBuilt', 15.712741599795349),
#  ('YearRemodAdd', 3.0869847589316257),
#  ('MasVnrArea', 2.679899979691976),
#  ('ExterQual', 3.1280898798121375),
#  ('BsmtQual', 3.0792975591006533),
#  ('BsmtExposure', 1.8346280095934133),
#  ('BsmtFinType1', 2.216370998378582),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.4758998658437177),
#  ('BsmtHalfBath', 1.2652661195972243),
#  ('FullBath', 4.05277158563999),
#  ('HalfBath', 3.037907147877025),
#  ('BedroomAbvGr', 3.165861276494482),
#  ('KitchenAbvGr', 6.135181159508307),
#  ('KitchenQual', 2.3702790338777406),
#  ('TotRmsAbvGrd', 5.557469954410432),
#  ('Fireplaces', 1.9025142715851246),
#  ('FireplaceQu', 1.427050228975592),
#  ('GarageYrBlt', 981.6968819566018),
#  ('GarageFinish', 2.1074423148233516),
#  ('GarageCars', 6.365780932714711),
#  ('GarageArea', 6.24632988427474),
#  ('WoodDeckSF', 1.3773309576675765),
#  ('OpenPorchSF', 1.4588796081885222),
#  ('EnclosedPorch', 1.4869543755403267),
#  ('3SsnPorch', 1.1168294089605377),
#  ('ScreenPorch', 1.1796989113479075),
#  ('PoolArea', 16.05045068289922),
#  ('PoolQC', 15.99587878531481),
#  ('Fence', 1.3558356557282338),
#  ('MiscVal', 1.0654148364916183),
#  ('MoSold', 1.1583920059780906),
#  ('YrSold', 1.1955597799375284),
#  ('MSSubClassDummy_30', 2.4376696855112674),
#  ('MSSubClassDummy_40', 1.7113246046981154),
#  ('MSSubClassDummy_45', 11.494386674621925),
#  ('MSSubClassDummy_50', 21.12756721397569),
#  ('MSSubClassDummy_60', 42.3232917451557),
#  ('MSSubClassDummy_70', 9.37034093529506),
#  ('MSSubClassDummy_75', 13.116266956592447),
#  ('MSSubClassDummy_80', 18.976648525936838),
#  ('MSSubClassDummy_85', 6.761105646236862),
#  ('MSSubClassDummy_90', 5.470408267860448),
#  ('MSSubClassDummy_120', 2.7163272376093786),
#  ('MSSubClassDummy_160', 14.332131259259311),
#  ('MSSubClassDummy_180', 2.8687111533818235),
#  ('MSSubClassDummy_190', 2.234917785895375),
#  ('MSZoningDummy_FV', 34.34022940871056),
#  ('MSZoningDummy_RH', 5.381431328855603),
#  ('MSZoningDummy_RL', 96.98694979814279),
#  ('Exterior1stDummy_HdBoard', 19.332492365563812),
#  ('Exterior1stDummy_ImStucc', 1.2059071088574296),
#  ('Exterior1stDummy_MetalSd', 17.551218548434793),
#  ('Exterior1stDummy_Plywood', 10.378814170181315),
#  ('Exterior1stDummy_Stone', 1.412486228403026),
#  ('Exterior1stDummy_Stucco', 2.574579156622498),
#  ('Exterior1stDummy_VinylSd', 32.62218049995258),
#  ('Exterior1stDummy_Wd Sdng', 15.528212721402303),
#  ('Exterior1stDummy_WdShing', 2.953604191721188),
#  ('MasVnrTypeDummy_BrkFace', 27.208076011699216),
#  ('MasVnrTypeDummy_No_MasVnr', 1.8927601624843335),
#  ('MasVnrTypeDummy_None', 30.875981828100876),
#  ('MasVnrTypeDummy_Stone', 11.196460374780207),
#  ('FoundationDummy_CBlock', 7.64399965828876),
#  ('FoundationDummy_PConc', 9.117128784689315),
#  ('FoundationDummy_Slab', 2.193962124978302),
#  ('FoundationDummy_Stone', 1.2325387383890263),
#  ('FoundationDummy_Wood', 1.2648790814994169),
#  ('GarageTypeDummy_Attchd', 94.03177848782498),
#  ('GarageTypeDummy_Basment', 6.335745790642717),
#  ('GarageTypeDummy_BuiltIn', 22.86137725424363),
#  ('GarageTypeDummy_CarPort', 3.1455672522419724),
#  ('GarageTypeDummy_Detchd', 79.26104012872226),
#  ('GarageTypeDummy_No_Garage', 956.1769831522364),
#  ('SaleConditionDummy_AdjLand', 1.0755919427283154),
#  ('SaleConditionDummy_Alloca', 1.4478647803640345),
#  ('SaleConditionDummy_Family', 1.342753306319164),
#  ('SaleConditionDummy_Normal', 2.782786811572351),
#  ('SaleConditionDummy_Partial', 2.9173636929070215),
#  ('constant', 133832.5017571898)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)
# Out:
# [('LotFrontage', 32.05334234471209),
#  ('LotArea', 8.431718364382053),
#  ('OverallCond', 40.487908805514884),
#  ('YearBuilt', 52028.82413718317),
#  ('YearRemodAdd', 28020.33762333005),
#  ('MasVnrArea', 3.5970651176307524),
#  ('ExterQual', 50.81312846548417),
#  ('BsmtQual', 17.25584834579328),
#  ('BsmtExposure', 9.110645806221804),
#  ('BsmtFinType1', 6.220648984457283),
#  ('BsmtFinSF1', 19.576402584583626),
#  ('BsmtFinSF2', 2.2650083846851845),
#  ('BsmtUnfSF', 22.727995266436597),
#  ('1stFlrSF', 111.27572707135371),
#  ('2ndFlrSF', 27.734505899312833),
#  ('LowQualFinSF', 1.9582638635430663),
#  ('BsmtFullBath', 4.289009445671694),
#  ('BsmtHalfBath', 1.3343133172180321),
#  ('FullBath', 37.97248492998454),
#  ('HalfBath', 4.805729190786887),
#  ('BedroomAbvGr', 50.2413010394537),
#  ('KitchenAbvGr', 273.68246691433654),
#  ('KitchenQual', 23.640143411209568),
#  ('TotRmsAbvGrd', 55.13438620522492),
#  ('Fireplaces', 3.6453813912409485),
#  ('FireplaceQu', 11.391661561509025),
#  ('GarageYrBlt', 34635.62647183381),
#  ('GarageFinish', 7.342302377558895),
#  ('GarageCars', 51.24268873768334),
#  ('GarageArea', 44.90541390556304),
#  ('WoodDeckSF', 2.2088659485814435),
#  ('OpenPorchSF', 2.275685492470874),
#  ('EnclosedPorch', 1.6450805106686373),
#  ('3SsnPorch', 1.1329175210822178),
#  ('ScreenPorch', 1.26212963609347),
#  ('PoolArea', 11.78457929257713),
#  ('PoolQC', 26846.6338091614),
#  ('Fence', 16.516426115820924),
#  ('MiscVal', 1.067583515261239),
#  ('MoSold', 5.688445086574713),
#  ('YrSold', 3.3987206828932193),
#  ('MSSubClassDummy_30', 2.357833850230999),
#  ('MSSubClassDummy_40', 1.7082024723546418),
#  ('MSSubClassDummy_45', 11.486409171052433),
#  ('MSSubClassDummy_50', 22.59722204488344),
#  ('MSSubClassDummy_60', 53.491871000823664),
#  ('MSSubClassDummy_70', 9.540127120011613),
#  ('MSSubClassDummy_75', 13.158649784152361),
#  ('MSSubClassDummy_80', 19.804757267276244),
#  ('MSSubClassDummy_85', 6.821704534346207),
#  ('MSSubClassDummy_90', 5.5595105784426275),
#  ('MSSubClassDummy_120', 2.8934013319552614),
#  ('MSSubClassDummy_160', 14.918412524204218),
#  ('MSSubClassDummy_180', 2.870908835743253),
#  ('MSSubClassDummy_190', 2.2375226803884383),
#  ('MSZoningDummy_FV', 35.85178712604525),
#  ('MSZoningDummy_RH', 5.39591731792538),
#  ('MSZoningDummy_RL', 527.6290764683613),
#  ('MSZoningDummy_RM', 77.12628628577619),
#  ('AlleyDummy_No_Alley_Access', 58.56635840959261),
#  ('AlleyDummy_Pave', 3.177209051657754),
#  ('LotShapeDummy_IR2', 1.2900287340087027),
#  ('LotShapeDummy_IR3', 1.1157334283387021),
#  ('LotShapeDummy_Reg', 4.266803130362476),
#  ('LotConfigDummy_CulDSac', 1.9816360333374383),
#  ('LotConfigDummy_FR2', 1.4085505618819596),
#  ('LotConfigDummy_FR3', 1.1063082484238789),
#  ('MasVnrTypeDummy_BrkFace', 39.98231341705308),
#  ('MasVnrTypeDummy_No_MasVnr', 1.9035859447991283),
#  ('MasVnrTypeDummy_None', 72.88750101807142),
#  ('MasVnrTypeDummy_Stone', 12.245822277568239),
#  ('FoundationDummy_CBlock', 13.305912147654945),
#  ('FoundationDummy_PConc', 16.09115810426177),
#  ('FoundationDummy_Slab', 2.215042179362807),
#  ('FoundationDummy_Stone', 1.2311869441245138),
#  ('FoundationDummy_Wood', 1.250239675866567),
#  ('GarageTypeDummy_Attchd', 259.4640952797865),
#  ('GarageTypeDummy_Basment', 6.39439227123978),
#  ('GarageTypeDummy_BuiltIn', 24.181191716606754),
#  ('GarageTypeDummy_CarPort', 3.154610078656764),
#  ('GarageTypeDummy_Detchd', 106.91650812448016),
#  ('GarageTypeDummy_No_Garage', 900.5591191073104),
#  ('SaleConditionDummy_AdjLand', 1.0757141386488722),
#  ('SaleConditionDummy_Alloca', 1.4482800659993298),
#  ('SaleConditionDummy_Family', 1.359336276677465),
#  ('SaleConditionDummy_Normal', 17.748824818968277),
#  ('SaleConditionDummy_Partial', 3.146395852506583)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# PoolArea                    PoolQC                        0.998113
# MSSubClassDummy_45          HouseStyleDummy_1.5Unf        0.995047
# GarageYrBlt                 GarageTypeDummy_No_Garage     0.994368
# MSSubClassDummy_80          HouseStyleDummy_SLvl          0.990512
# GarageCars                  GarageArea                    0.987795
# RoofStyleDummy_Gable        RoofStyleDummy_Hip            0.982895
# MSZoningDummy_FV            NeighborhoodDummy_Somerst     0.973922
# ExterQual                   KitchenQual                   0.961596
# MSSubClassDummy_85          HouseStyleDummy_SFoyer        0.954414
# ExterQual                   BsmtQual                      0.950898
# 2ndFlrSF                    HouseStyleDummy_2Story        0.949911
# BsmtQual                    FoundationDummy_PConc         0.949219
# MasVnrArea                  MasVnrTypeDummy_None          0.936904
# YearRemodAdd                BsmtQual                      0.936760
#                             FoundationDummy_PConc         0.935746
# HalfBath                    HouseStyleDummy_2Story        0.927773
# FoundationDummy_CBlock      FoundationDummy_PConc         0.926247
# Exterior1stDummy_VinylSd    FoundationDummy_PConc         0.924513
# YearBuilt                   BsmtQual                      0.921419
# YearRemodAdd                ExterQual                     0.919498
# ExterQual                   FoundationDummy_PConc         0.918981
# BsmtQual                    KitchenQual                   0.915926
# GarageTypeDummy_Attchd      GarageTypeDummy_Detchd        0.914513
# YearBuilt                   YearRemodAdd                  0.911292
# BsmtFinSF1                  BsmtFullBath                  0.910834
# KitchenAbvGr                MSSubClassDummy_90            0.910198
# HalfBath                    MSSubClassDummy_60            0.899584
# 2ndFlrSF                    HalfBath                      0.898549
# YearRemodAdd                Exterior1stDummy_VinylSd      0.896448
# FullBath                    GarageCars                    0.895112
# YearBuilt                   FoundationDummy_PConc         0.894752
# BsmtQual                    GarageCars                    0.892837
# YearRemodAdd                KitchenQual                   0.892741
# BsmtQual                    FullBath                      0.890826
# MasVnrTypeDummy_BrkFace     MasVnrTypeDummy_None          0.889187
# MSSubClassDummy_60          HouseStyleDummy_2Story        0.888829
# YearBuilt                   ExterQual                     0.887665
# ExterQual                   GarageCars                    0.886971
# SaleConditionDummy_Normal   SaleConditionDummy_Partial    0.882836
# 2ndFlrSF                    HouseStyleDummy_1Story        0.882115
# BsmtQual                    Exterior1stDummy_VinylSd      0.881250
# KitchenQual                 FoundationDummy_PConc         0.876756
# MSZoningDummy_RL            MSZoningDummy_RM              0.874181
# YearBuilt                   GarageCars                    0.873989
#                             GarageFinish                  0.873778
# BsmtQual                    GarageFinish                  0.873346
# FullBath                    FoundationDummy_PConc         0.868733
# ExterQual                   GarageArea                    0.866095
# AlleyDummy_No_Alley_Access  AlleyDummy_Pave               0.865881
# ExterQual                   FullBath                      0.862268
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199725750420.4284, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203148865086.18546, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199087485004.71994, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195381141097.34656, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202151516689.21075, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60896830580.64511, tolerance: 538585237.4526064
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163938721791.6317, tolerance: 485591402.73587835
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92175341956.13321, tolerance: 530785291.77063674
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113524607980.14162, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95637907756.09592, tolerance: 528768796.88804495
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8562507415.356934, tolerance: 509747439.2416074
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 1801.168367944776),
#  ('LotArea', 4441.216828440978),
#  ('OverallCond', 7133.092558130633),
#  ('YearBuilt', 12012.249633701644),
#  ('YearRemodAdd', 550.0449444719892),
#  ('MasVnrArea', 4545.771566115541),
#  ('ExterQual', -5541.66165724405),
#  ('BsmtQual', -4651.67358329836),
#  ('BsmtExposure', -2601.6000136689627),
#  ('BsmtFinType1', 640.7127581186639),
#  ('BsmtFinSF1', 19149.631250999697),
#  ('BsmtFinSF2', 5439.681904196479),
#  ('BsmtUnfSF', 10081.595753512614),
#  ('1stFlrSF', 16428.823834202387),
#  ('2ndFlrSF', 24375.61986351341),
#  ('LowQualFinSF', 839.0515127069506),
#  ('BsmtFullBath', 98.40884935363012),
#  ('BsmtHalfBath', -245.2774123101274),
#  ('FullBath', 0.0),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -3499.9090570115804),
#  ('KitchenAbvGr', -2714.9742582318454),
#  ('KitchenQual', -5330.711525135777),
#  ('TotRmsAbvGrd', 3701.959591797019),
#  ('Fireplaces', 2377.043134171662),
#  ('FireplaceQu', -810.9475730409583),
#  ('GarageYrBlt', -0.0),
#  ('GarageFinish', -1265.6826717250278),
#  ('GarageCars', 4887.857138948997),
#  ('GarageArea', 935.7343529890909),
#  ('WoodDeckSF', 1442.0494079741698),
#  ('OpenPorchSF', 1310.2664926891314),
#  ('EnclosedPorch', 276.4807801209869),
#  ('3SsnPorch', 462.0371395964299),
#  ('ScreenPorch', 1379.5689761182625),
#  ('PoolArea', 871.9936201104922),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 266.22850326454756),
#  ('MoSold', -0.0),
#  ('YrSold', -155.03417789916273),
#  ('MSSubClassDummy_30', -257.3670759965097),
#  ('MSSubClassDummy_40', 148.42289952480286),
#  ('MSSubClassDummy_45', 92.90505530855827),
#  ('MSSubClassDummy_50', -409.7922453529961),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', 1288.031533904151),
#  ('MSSubClassDummy_75', 809.3468989280993),
#  ('MSSubClassDummy_80', -413.2199005617659),
#  ('MSSubClassDummy_85', -651.8765102482519),
#  ('MSSubClassDummy_90', -272.0848134676525),
#  ('MSSubClassDummy_120', -4153.036402853592),
#  ('MSSubClassDummy_160', -5254.432422125367),
#  ('MSSubClassDummy_180', -408.9719763736528),
#  ('MSSubClassDummy_190', -883.0451605601527),
#  ('MSZoningDummy_FV', 2079.1596149013208),
#  ('MSZoningDummy_RH', 645.0999870308553),
#  ('MSZoningDummy_RL', 0.0),
#  ('MSZoningDummy_RM', -796.1758389612004),
#  ('AlleyDummy_No_Alley_Access', 18.519577065161617),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -509.78207362396944),
#  ('LotShapeDummy_Reg', 785.7902028348292),
#  ('LotConfigDummy_CulDSac', 2096.9550502132342),
#  ('LotConfigDummy_FR2', -1019.253919327559),
#  ('LotConfigDummy_FR3', -802.7972008396227),
#  ('LotConfigDummy_Inside', -91.25901541747581),
#  ('NeighborhoodDummy_Blueste', 437.8158793940289),
#  ('NeighborhoodDummy_BrDale', 2495.369627723157),
#  ('NeighborhoodDummy_BrkSide', 1072.9774045261809),
#  ('NeighborhoodDummy_ClearCr', -30.92868067193097),
#  ('NeighborhoodDummy_CollgCr', -287.51959017657197),
#  ('NeighborhoodDummy_Crawfor', 2922.3032951612013),
#  ('NeighborhoodDummy_Edwards', -1791.7849126374626),
#  ('NeighborhoodDummy_Gilbert', -728.4805839880979),
#  ('NeighborhoodDummy_IDOTRR', 494.4411725788815),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -1570.4872178674896),
#  ('NeighborhoodDummy_NAmes', -1017.0613583624448),
#  ('NeighborhoodDummy_NPkVill', 1870.4156666936371),
#  ('NeighborhoodDummy_NWAmes', -1459.864357496873),
#  ('NeighborhoodDummy_NoRidge', 4621.113808356771),
#  ('NeighborhoodDummy_NridgHt', 7010.9393199484),
#  ('NeighborhoodDummy_OldTown', -546.9748215464858),
#  ('NeighborhoodDummy_SWISU', -487.72407863418584),
#  ('NeighborhoodDummy_Sawyer', -152.62412575247936),
#  ('NeighborhoodDummy_SawyerW', -290.88796466254274),
#  ('NeighborhoodDummy_Somerst', 1504.723631133246),
#  ('NeighborhoodDummy_StoneBr', 5051.2000903450635),
#  ('NeighborhoodDummy_Timber', 346.96159887656404),
#  ('NeighborhoodDummy_Veenker', 588.0226153750546),
#  ('HouseStyleDummy_1.5Unf', 625.2777288728081),
#  ('HouseStyleDummy_1Story', 0.0),
#  ('HouseStyleDummy_2.5Fin', -1351.5645879853596),
#  ('HouseStyleDummy_2.5Unf', -710.6857343054378),
#  ('HouseStyleDummy_2Story', -2895.1800680399397),
#  ('HouseStyleDummy_SFoyer', -626.8715540961568),
#  ('HouseStyleDummy_SLvl', 607.9988158197738),
#  ('RoofStyleDummy_Gable', -0.0),
#  ('RoofStyleDummy_Gambrel', 206.42947480704387),
#  ('RoofStyleDummy_Hip', 1580.0487255539392),
#  ('RoofStyleDummy_Mansard', -57.68104965402958),
#  ('RoofStyleDummy_Shed', 257.8325178423889),
#  ('Exterior1stDummy_AsphShn', 292.03415287941584),
#  ('Exterior1stDummy_BrkComm', -648.8410805756121),
#  ('Exterior1stDummy_BrkFace', 2821.5373162949904),
#  ('Exterior1stDummy_CBlock', -931.5808056176509),
#  ('Exterior1stDummy_CemntBd', 275.1062346623401),
#  ('Exterior1stDummy_HdBoard', -698.3994471036723),
#  ('Exterior1stDummy_ImStucc', -314.2649624887008),
#  ('Exterior1stDummy_MetalSd', 840.5161856012136),
#  ('Exterior1stDummy_Plywood', -582.9389913537613),
#  ('Exterior1stDummy_Stone', -213.57555769492447),
#  ('Exterior1stDummy_Stucco', 1474.229450134019),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', -293.9812716838087),
#  ('Exterior1stDummy_WdShing', 379.4123163451591),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', -0.0),
#  ('MasVnrTypeDummy_None', 1809.5430252216197),
#  ('MasVnrTypeDummy_Stone', 1602.5142290886208),
#  ('FoundationDummy_CBlock', -1332.7138049591997),
#  ('FoundationDummy_PConc', 1162.5631136672168),
#  ('FoundationDummy_Slab', 1518.7827131073805),
#  ('FoundationDummy_Stone', -444.3543104159134),
#  ('FoundationDummy_Wood', -1088.9026444573574),
#  ('GarageTypeDummy_Attchd', 0.0),
#  ('GarageTypeDummy_Basment', -51.00407643062585),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -1304.2566618737765),
#  ('GarageTypeDummy_Detchd', 230.39001824197706),
#  ('GarageTypeDummy_No_Garage', 814.8203996297991),
#  ('SaleConditionDummy_AdjLand', 649.3506277303441),
#  ('SaleConditionDummy_Alloca', -234.59773338052983),
#  ('SaleConditionDummy_Family', 937.9025015029492),
#  ('SaleConditionDummy_Normal', 2394.7505314124187),
#  ('SaleConditionDummy_Partial', 4547.8369163141215)]

# %%
def addHasPool(data):
    data['hasPool'] = data['PoolQC'].apply(lambda x: 0 if x=='No_Pool' else 1)

# %%
addHasPool(train)

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
X_Scaled.corr()
