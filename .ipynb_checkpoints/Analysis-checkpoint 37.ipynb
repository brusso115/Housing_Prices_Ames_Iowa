# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2346.946503763387), ('GrLivArea', 1549.4574329996224), ('GarageCars', 1008.2162788946997), ('GarageArea', 923.3574847927888), ('ExterQual', 913.614635789516), ('TotalBsmtSF', 815.7563727796831), ('KitchenQual', 743.3692820487597), ('BsmtQual', 719.1838435444583), ('1stFlrSF', 715.3025925042268), ('FullBath', 712.676496207046), ('YearBuilt', 674.6398078580731), ('TotRmsAbvGrd', 546.8153559311294), ('YearRemodAdd', 516.2288296690135), ('Fireplaces', 329.34881580988), ('GarageFinish', 309.246556692152), ('MasVnrArea', 289.3849261060345), ('HeatingQC', 288.52713099553125), ('MSSubClassDummy_60', 239.93775771825938), ('NeighborhoodDummy_NridgHt', 210.28855073239353), ('LotFrontage', 194.82962288357712), ('BsmtFinSF1', 181.32011417087264), ('OpenPorchSF', 180.00493962745253), ('WoodDeckSF', 163.53441508717657), ('NeighborhoodDummy_NoRidge', 153.87815491654703), ('MSZoningDummy_RM', 150.74413641062654), ('LotArea', 140.102933903959), ('2ndFlrSF', 139.02706957093113), ('BsmtExposure', 138.74333014385547), ('HalfBath', 109.66150384256568), ('LotShapeDummy_Reg', 99.66584262809852), ('GarageYrBlt', 93.02210215836367), ('MSSubClassDummy_30', 92.19984405614512), ('MSZoningDummy_RL', 81.6483654052907), ('BsmtUnfSF', 76.78259101113822), ('GarageCond', 76.6310170641635), ('BsmtFullBath', 71.87947296683832), ('NeighborhoodDummy_OldTown', 69.27188087639662), ('GarageQual', 68.94110788310553), ('NeighborhoodDummy_NAmes', 61.20760836759919), ('NeighborhoodDummy_Edwards', 53.75248319097041), ('BedroomAbvGr', 51.74979341307795), ('NeighborhoodDummy_Somerst', 44.47332643834554), ('MSSubClassDummy_50', 42.06077552203943), ('NeighborhoodDummy_StoneBr', 38.16471469607651), ('Fence', 37.60842739873752), ('NeighborhoodDummy_IDOTRR', 36.39585182683742), ('NeighborhoodDummy_Timber', 33.135117581278244), ('NeighborhoodDummy_Sawyer', 28.32032272099562), ('NeighborhoodDummy_BrkSide', 27.1858387666994), ('EnclosedPorch', 25.34857266567341), ('ExterCond', 24.334882181858806), ('MSZoningDummy_FV', 21.442652913556635), ('KitchenAbvGr', 20.798305585214692), ('OverallCond', 20.679283863986427), ('Condition1Dummy_Norm', 19.636052956073463), ('AlleyDummy_No_Alley_Access', 19.473891201479525), ('MSSubClassDummy_160', 18.534416266290236), ('NeighborhoodDummy_CollgCr', 17.083996740788322), ('NeighborhoodDummy_MeadowV', 16.683554627027963), ('MSSubClassDummy_90', 15.341593417440508), ('Condition1Dummy_Feedr', 14.773175416722818), ('NeighborhoodDummy_BrDale', 14.710337668548894), ('BsmtFinType2', 12.28298846982917), ('LotConfigDummy_CulDSac', 11.41294319391445), ('MSSubClassDummy_45', 11.11452195621417), ('LandContourDummy_HLS', 11.025038198592936), ('MSSubClassDummy_190', 10.670679359129403), ('BsmtFinType1', 9.24060801075036), ('MSZoningDummy_RH', 8.503429290530564), ('BsmtCond', 7.72202344089455), ('MSSubClassDummy_120', 6.040523260535675), ('NeighborhoodDummy_SWISU', 5.923343008097596), ('LowQualFinSF', 5.876905147975587), ('MoSold', 5.874849667000949), ('NeighborhoodDummy_Crawfor', 5.823871537867482), ('MSSubClassDummy_180', 5.232737024727937), ('NeighborhoodDummy_Mitchel', 4.668088446467564), ('MSSubClassDummy_85', 4.54283478722091), ('Condition1Dummy_PosA', 4.399085058326265), ('NeighborhoodDummy_Gilbert', 4.340094497810457), ('LotShapeDummy_IR2', 4.096717957099135), ('ScreenPorch', 3.862193666801418), ('BsmtHalfBath', 3.850264705214219), ('NeighborhoodDummy_ClearCr', 3.7027055638926205), ('NeighborhoodDummy_Veenker', 3.669563065510903), ('Condition1Dummy_RRAe', 3.3803037548307033), ('LotConfigDummy_Inside', 2.920157724177391), ('FireplaceQu', 2.4790735485362316), ('NeighborhoodDummy_NPkVill', 2.3917213632065257), ('LotConfigDummy_FR3', 2.3317503413716043), ('Condition1Dummy_PosN', 2.2998808972011235), ('NeighborhoodDummy_NWAmes', 1.7819545198975288), ('YrSold', 1.613097810445675), ('MSSubClassDummy_75', 1.5778130705454008), ('LandContourDummy_Low', 1.261586126933392), ('BsmtFinSF2', 1.1924408630927419), ('MSSubClassDummy_80', 1.0795835718095734),  ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.35089068, 0.20936642]),
#  'std_fit_time': array([0.03587218, 0.00366759]),
#  'mean_score_time': array([0.01081023, 0.01058335]),
#  'std_score_time': array([0.00086892, 0.00060394]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.85963957, 0.88171542]),
#  'split1_test_score': array([0.88748973, 0.88257926]),
#  'split2_test_score': array([0.85908944, 0.85598047]),
#  'split3_test_score': array([0.88325255, 0.88733246]),
#  'split4_test_score': array([0.88089508, 0.8529712 ]),
#  'mean_test_score': array([0.87407327, 0.87211576]),
#  'std_test_score': array([0.01219545, 0.01456055]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8740732734356904

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5795930288697482),
#  ('GrLivArea', 0.1259333014718793),
#  ('TotalBsmtSF', 0.047690819552985264),
#  ('BsmtFinSF1', 0.034526506979006465),
#  ('GarageCars', 0.03182378821488254),
#  ('GarageArea', 0.022090411643939344),
#  ('1stFlrSF', 0.020367112128400828),
#  ('LotArea', 0.009162981799483983),
#  ('YearBuilt', 0.008957962471456521),
#  ('YearRemodAdd', 0.008497120764001472),
#  ('BsmtUnfSF', 0.0062140384576116255),
#  ('GarageYrBlt', 0.005883596150304287),
#  ('BsmtQual', 0.005735498429081206),
#  ('LotFrontage', 0.005419494142167597),
#  ('OverallCond', 0.005153355378843216),
#  ('2ndFlrSF', 0.005116531857195602),
#  ('OpenPorchSF', 0.004904020257894299),
#  ('WoodDeckSF', 0.004805907584325761),
#  ('FullBath', 0.004232420452485418),
#  ('MasVnrArea', 0.004136170992912393),
#  ('KitchenQual', 0.003472947816908047),
#  ('MoSold', 0.0032374891411362273),
#  ('BsmtFinType1', 0.0023670262193921706),
#  ('GarageTypeDummy_CarPort', 0.0022805642805787726),
#  ('Fireplaces', 0.002014440930310258),
#  ('ExterQual', 0.0018499331137384414),
#  ('BsmtExposure', 0.0018086318856140066),
#  ('TotRmsAbvGrd', 0.0018017480704706939),
#  ('BsmtFullBath', 0.0017131926907784777),
#  ('GarageFinish', 0.0016985295428446805),
#  ('FunctionalDummy_Typ', 0.0016630875781742213),
#  ('YrSold', 0.001504276591707195),
#  ('HeatingDummy_Wall', 0.0014756484502656416),
#  ('BedroomAbvGr', 0.0014509472070573224),
#  ('MSZoningDummy_RL', 0.0014190061513341306),
#  ('FireplaceQu', 0.0012327245462407854),
#  ('LotShapeDummy_IR3', 0.0011313938024308965),
#  ('HalfBath', 0.0010103310555467778),
#  ('NeighborhoodDummy_CollgCr', 0.0009704284147909727),
#  ('KitchenAbvGr', 0.0008531934661520842),
#  ('EnclosedPorch', 0.0008246785772082734),
#  ('HeatingQC', 0.0007774453988206539),
#  ('SaleConditionDummy_Family', 0.0007399150444364494),
#  ('ExterCond', 0.0006757490993225374),
#  ('Exterior1stDummy_Stucco', 0.0006588652660253037),
#  ('MSSubClassDummy_160', 9.71322281271622e-07),
#  ('RoofMatlDummy_Metal', 9.294209028472364e-07),
#  ('MSSubClassDummy_30', 8.37538841299085e-07),
#  ('Condition2Dummy_RRAn', 6.946339280234923e-07),
#  ('RoofStyleDummy_Hip', 6.601576063307857e-07),
#  ('HeatingDummy_OthW', 5.948225436856817e-07),
#  ('NeighborhoodDummy_Blueste', 5.507333943903978e-07),
#  ('RoofMatlDummy_Tar&Grv', 4.627957914353285e-07),
#  ('MSZoningDummy_RM', 2.0496217174322548e-07),
#  ('Condition2Dummy_Feedr', 1.8801420282769984e-07),
#  ('Exterior1stDummy_BrkFace', 1.6737026068130252e-07),
#  ('SaleTypeDummy_Con', 9.27838939263491e-08),
#  ('FoundationDummy_Slab', 8.582125918200506e-08),
#  ('MiscFeatureDummy_No_Misc_Feature', 4.133760827182293e-08),
#  ('Condition1Dummy_RRAn', 2.660432428226377e-08),
#  ('Exterior2ndDummy_BrkFace', 2.101438927186417e-08),
#  ('LandContourDummy_Lvl', 6.9534754800789966e-09),
#  ('Exterior1stDummy_HdBoard', 5.9097152428439e-09),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('Exterior1stDummy_Plywood', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.0279213 , 0.00517359, 0.00483761, 0.00474124, 0.00482068,
#         0.0046298 , 0.00484624, 0.00485005]),
#  'std_fit_time': array([4.54638189e-02, 6.51282698e-04, 9.41978017e-05, 1.07120531e-04,
#         1.61732142e-04, 2.31059139e-04, 1.47630247e-04, 1.48992621e-04]),
#  'mean_score_time': array([0.00266509, 0.00260348, 0.00254149, 0.00256901, 0.00256066,
#         0.00258026, 0.0024529 , 0.00253558]),
#  'std_score_time': array([2.93920289e-04, 2.61769720e-04, 7.45483315e-05, 6.87504933e-05,
#         8.24011861e-05, 6.05383412e-05, 2.79967310e-04, 7.23802053e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89919346, 0.90127896, 0.90382013, 0.90540538, 0.90591101,
#         0.906299  , 0.8959275 , 0.87379095]),
#  'split1_test_score': array([0.90881472, 0.91033409, 0.91368983, 0.91618002, 0.91612452,
#         0.91582735, 0.88972323, 0.85829214]),
#  'split2_test_score': array([0.86326802, 0.87976475, 0.88785775, 0.89250692, 0.89315065,
#         0.89336287, 0.87227035, 0.84423311]),
#  'split3_test_score': array([0.89556133, 0.89690557, 0.9001405 , 0.90528994, 0.90672525,
#         0.90763594, 0.8999329 , 0.87896548]),
#  'split4_test_score': array([0.88893407, 0.88951262, 0.89127091, 0.89291253, 0.89318806,
#         0.89326032, 0.87312395, 0.84450183]),
#  ('FunctionalDummy_Sev', 2653.5411993300877),
#  ('SaleConditionDummy_Normal', 2633.854723670814),
#  ('MasVnrArea', 2585.9593503568617),
#  ('TotRmsAbvGrd', 2540.1964420943727),
#  ('WoodDeckSF', 2391.7025585115452),
#  ('SaleConditionDummy_Family', 2386.3361830545973),
#  ('Condition1Dummy_Feedr', 2305.45786056543),
#  ('Fireplaces', 2239.8216996356077),
#  ('BldgTypeDummy_Duplex', -2152.6096857333814),
#  ('FullBath', 2098.435018004458),
#  ('BsmtFullBath', 2096.76443802912),
#  ('NeighborhoodDummy_Crawfor', -2085.241663967085),
#  ('NeighborhoodDummy_Mitchel', -2078.9886584561623),
#  ('MSSubClassDummy_90', -2045.2934168784768),
#  ('Exterior1stDummy_Stone', 1989.5810971704816),
#  ('YearRemodAdd', 1898.7284016116116),
#  ('KitchenAbvGr', -1893.124330706228),
#  ('NeighborhoodDummy_NPkVill', -1891.2249458267192),
#  ('BsmtExposure', -1857.073175838476),
#  ('OpenPorchSF', 1804.719592613457),
#  ('MSSubClassDummy_190', 1803.9729208662839),
#  ('BldgTypeDummy_Twnhs', -1802.013198241819),
#  ('FunctionalDummy_Mod', -1767.6602559337766),
#  ('FoundationDummy_CBlock', 1735.2570163531545),
#  ('SaleTypeDummy_ConLw', 1696.7767773663516),
#  ('MiscFeatureDummy_TenC', 1695.7377226918516),
#  ('BedroomAbvGr', -1660.093931795127),
#  ('Exterior2ndDummy_Wd Sdng', -1655.7436686605104),
#  ('MSSubClassDummy_120', -1638.58866434014),
#  ('Exterior1stDummy_VinylSd', -1594.7943530310438),
#  ('NeighborhoodDummy_ClearCr', -1547.9001288848822),
#  ('NeighborhoodDummy_Edwards', -1512.657811636725),
#  ('Exterior2ndDummy_CBlock', 1474.0901307444426),
#  ('Exterior2ndDummy_Other', -1458.060941439941),
#  ('NeighborhoodDummy_MeadowV', -1420.5842551465241),
#  ('HouseStyleDummy_1Story', -1400.9990146100556),
#  ('NeighborhoodDummy_Blueste', 1299.0562482096088),
#  ('ScreenPorch', 1292.523061405953),
#  ('UtilitiesDummy_NoSeWa', 1251.1067926846172),
#  ('Exterior2ndDummy_CmentBd', -1238.4984100493043),
#  ('MSSubClassDummy_75', -1204.3928412633686),
#  ('NeighborhoodDummy_NridgHt', -1201.460119522653),
#  ('FunctionalDummy_Min2', -1179.0303813589665),
#  ('SaleConditionDummy_AdjLand', 1166.5142735156396),
#  ('MasVnrTypeDummy_None', 1166.361316209267),
#  ('SaleTypeDummy_CWD', 1155.1400282216266),
#  ('LotConfigDummy_CulDSac', -1147.9217240551754),
#  ('MSSubClassDummy_50', 1145.0063189812358),
#  ('LotShapeDummy_Reg', 1136.8872377656542),
#  ('Condition1Dummy_PosN', -1136.467841327163),
#  ('NeighborhoodDummy_BrDale', 1126.456046317188),
#  ('MSZoningDummy_RH', 1123.485654389975),
#  ('FoundationDummy_PConc', 1119.0991478120507),
#  ('Exterior1stDummy_CBlock', -1084.8985717236596),
#  ('LotFrontage', 1069.5073372319425),
#  ('ExterCond', 1037.4431655181722),
#  ('MSSubClassDummy_80', -1035.9239007001797),
#  ('NeighborhoodDummy_OldTown', -996.7510838778127),
#  ('HouseStyleDummy_2.5Unf', -970.4742626611827),
#  ('PoolArea', 945.9591809391891),
#  ('HeatingQC', -945.6046965689158),
#  ('MSSubClassDummy_85', -929.2953931182461),
#  ('BldgTypeDummy_2fmCon', -929.2953931182433),
#  ('PavedDriveDummy_P', 919.4352235428066),
#  ('LandContourDummy_Lvl', -905.4473347946438),
#  ('FoundationDummy_Stone', -872.7674257070232),
#  ('MSZoningDummy_RM', 851.6512809399004),
#  ('SalePrice', -843.0261546445346),
#  ('Exterior2ndDummy_VinylSd', 841.4885330184352),
#  ('GarageTypeDummy_Basment', 838.0141325986477),
#  ('MasVnrTypeDummy_Stone', 829.6484469282548),
#  ('ElectricalDummy_SBrkr', -824.8795809380865),
#  ('FireplaceQu', -821.6516242266015),
#  ('GarageFinish', -819.2825950404057),
#  ('GarageTypeDummy_CarPort', 811.5485936742582),
#  ('MSSubClassDummy_180', -805.3608851094413),
#  ('Exterior1stDummy_Wd Sdng', 800.3402509539254),
#  ('HouseStyleDummy_SFoyer', 796.3130019923389),
#  ('GarageYrBlt', -767.2537036561052),
#  ('BsmtFinSF2', 752.4705112319898),
#  ('FunctionalDummy_Maj2', -745.6506191280196),
#  ('LotConfigDummy_FR2', -738.8464179320871),
#  ('NeighborhoodDummy_NAmes', 736.5640844119741),
#  ('NeighborhoodDummy_Timber', 721.4998365041856),
#  ('NeighborhoodDummy_SawyerW', 680.0353158136118),
#  ('GarageTypeDummy_Detchd', 674.9469270605842),
#  ('SaleTypeDummy_WD', 657.5516297933374),
#  ('MasVnrTypeDummy_No_MasVnr', 653.4942196699134),
#  ('Exterior1stDummy_CemntBd', -648.3545015347843),
#  ('HalfBath', 633.1798823520909),
#  ('BsmtUnfSF', -632.458330269334),
#  ('HouseStyleDummy_SLvl', -617.7061935408815),
#  ('LandContourDummy_HLS', -614.9593902270717),
#  ('Exterior1stDummy_HdBoard', -590.2898921112829),
#  ('BldgTypeDummy_TwnhsE', 551.1923165151464),
#  ('Exterior2ndDummy_Stone', -543.1474639885766),
#  ('Condition2Dummy_RRNn', -536.3887691813409),
#  ('YrSold', -527.904682784404),
#  ('NeighborhoodDummy_BrkSide', 512.3314126221437),
#  ('StreetDummy_Pave', 504.62304752551455),
#  ('MoSold', -495.4933102964637),
#  ('NeighborhoodDummy_Sawyer', -485.12581231504316),
#  ('HeatingDummy_GasW', -467.196072494631),
#  ('SaleTypeDummy_Con', 462.48202810541295),
#  ('LotShapeDummy_IR3', 459.4502684326355),
#  ('Exterior1stDummy_Stucco', -456.36738769374233),
#  ('RoofStyleDummy_Gable', 453.2335507732152),
#  ('RoofMatlDummy_Tar&Grv', -452.91934640274644),
#  ('Exterior1stDummy_MetalSd', -440.4363442406316),
#  ('SaleTypeDummy_New', 433.3571123341903),
#  ('MSZoningDummy_FV', -427.1630516205356),
#  ('Condition1Dummy_PosA', 412.35454472295146),
#  ('ElectricalDummy_FuseP', 406.8824144791964),
#  ('EnclosedPorch', 402.8977309023473),
#  ('MSSubClassDummy_60', 399.50449318439814),
#  ('BsmtCond', 398.70405955688796),
#  ('Exterior1stDummy_ImStucc', 392.85994888633786),
#  ('Condition1Dummy_RRNe', 385.620026568898),
#  ('HouseStyleDummy_2.5Fin', -351.8762033455351),
#  ('AlleyDummy_No_Alley_Access', -351.6279048806361),
#  ('PoolQC', 349.28256507174547),
#  ('FunctionalDummy_Typ', -348.777852748899),
#  ('RoofStyleDummy_Gambrel', 348.378549295842),
#  ('Exterior2ndDummy_Stucco', 345.5541556847138),
#  ('MSSubClassDummy_40', -328.46308896926223),
#  ('MasVnrTypeDummy_BrkFace', 324.4214458872719),
#  ('3SsnPorch', 313.6165797867587),
#  ('Exterior1stDummy_WdShing', -313.18914135605695),
#  ('Exterior2ndDummy_Brk Cmn', -312.3770444110266),
#  ('Condition1Dummy_RRAn', -311.7717671722492),
#  ('BsmtFinType1', -310.77152332898515),
#  ('BsmtHalfBath', -308.2907714068997),
#  ('MiscVal', 291.68507232666144),
#  ('MSSubClassDummy_70', 285.9743465524241),
#  ('Exterior2ndDummy_AsphShn', 285.36549028252256),
#  ('LotShapeDummy_IR2', -285.07110814803065),
#  ('Exterior2ndDummy_HdBoard', 267.6666065078494),
#  ('Exterior1stDummy_AsphShn', -257.6478186711741),
#  ('NeighborhoodDummy_Gilbert', -256.53389156949095),
#  ('HouseStyleDummy_2Story', 250.27954881736304),
#  ('SaleTypeDummy_Oth', -244.57864368683946),
#  ('NeighborhoodDummy_Veenker', 241.91989896824435),
#  ('NeighborhoodDummy_StoneBr', -239.7234904171115),
#  ('Exterior2ndDummy_BrkFace', -238.89091469122383),
#  ('Exterior1stDummy_BrkFace', -238.89091469121672),
#  ('RoofMatlDummy_Roll', 230.84806926764045),
#  ('LotConfigDummy_Inside', 229.3014246559424),
#  ('GarageTypeDummy_No_Garage', -228.22269433505795),
#  ('MiscFeatureDummy_Othr', 226.98018126435915),
#  ('MSZoningDummy_RL', -226.69475735560587),
#  ('NeighborhoodDummy_IDOTRR', -221.94565598992307),
#  ('MSSubClassDummy_30', 209.24933959253693),
#  ('HeatingDummy_OthW', -208.56345400207724),
#  ('GarageQual', 206.51887936024093),
#  ('ElectricalDummy_Mix', 205.68247582197148),
#  ('Exterior2ndDummy_Plywood', 192.2359013477343),
#  ('BsmtFinType2', 186.3026002204117),
#  ('AlleyDummy_Pave', -181.22542281251395),
#  ('MSSubClassDummy_160', -176.22846434544735),
#  ('Exterior2ndDummy_ImStucc', 175.33598353908027),
#  ('HeatingDummy_Wall', 172.97014254529043),
#  ('RoofMatlDummy_WdShngl', 169.62021179529253),
#  ('LotConfigDummy_FR3', -168.1232248644528),
#  ('SaleTypeDummy_ConLD', -166.34836904062615),
#  ('Exterior1stDummy_Plywood', -165.7466628362676),
#  ('MSSubClassDummy_45', -153.9397265922044),
#  ('Condition2Dummy_RRAe', -144.81939319054896),
#  ('LowQualFinSF', 141.80645211715205),
#  ('Condition1Dummy_RRNn', -136.5322550221515),
#  ('LandSlope', -136.1326567219374),
#  ('RoofStyleDummy_Hip', 135.84174442406214),
#  ('ElectricalDummy_FuseF', 135.0372337285089),
#  ('SaleConditionDummy_Alloca', 132.94948336720444),
#  ('FoundationDummy_Slab', -120.78280679607798),
#  ('SaleTypeDummy_ConLI', -119.81073538451788),
#  ('HeatingDummy_GasA', -119.49447329922025),
#  ('CentralAirDummy_Y', -115.17255658352387),
#  ('Condition1Dummy_Norm', 107.28315273414742),
#  ('NeighborhoodDummy_SWISU', -103.69720736402755),
#  ('RoofMatlDummy_Metal', -96.81752150004533),
#  ('Exterior2ndDummy_Wd Shng', 96.29583868173283),
#  ('FunctionalDummy_Min1', 95.68936474480414),
#  ('HouseStyleDummy_1.5Unf', -91.46943510656666),
#  ('RoofMatlDummy_WdShake', 82.30849939831131),
#  ('RoofStyleDummy_Shed', 64.5995828020685),
#  ('LandContourDummy_Low', -53.32006782115987),
#  ('Condition1Dummy_RRAe', 52.797386055147086),
#  ('Fence', 48.08615938067219),
#  ('Condition2Dummy_Feedr', -47.586903393111854),
#  ('PavedDriveDummy_Y', -36.113724305499844),
#  ('Condition2Dummy_RRAn', -31.302082067005028),
#  ('GarageTypeDummy_Attchd', -26.299896519119386),
#  ('GarageTypeDummy_BuiltIn', -10.915347193458828),
#  ('FoundationDummy_Wood', -7.730345484270003),
#  ('Exterior2ndDummy_MetalSd', -2.945151294657759),
#  ('MiscFeatureDummy_No_Misc_Feature', 2.727735174178106),
#  ('GarageCond', 0.8309771282043829),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140144028095.9849, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141253584319.29214, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138353579531.3273, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150454399313.34085, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134719332990.64769, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99370156386.27655, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116589735329.29222, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117118043061.64026, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126567892582.79428, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108616379845.42169, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13174787604.189117, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3276583588.2384033, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1026181994.609314, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.1157331 , 0.11766295, 0.11765413, 0.08090553, 0.05952296,
#         0.04734917, 0.00922613, 0.00785637]),
#  'std_fit_time': array([0.00730382, 0.00363918, 0.00271677, 0.00373856, 0.00407002,
#         0.00340169, 0.00060429, 0.00059737]),
#  'mean_score_time': array([0.00251918, 0.00248013, 0.00248652, 0.00277224, 0.00279479,
#         0.00281134, 0.00266852, 0.00269232]),
#  'std_score_time': array([2.42719500e-04, 1.16871766e-04, 1.60804832e-04, 3.93462914e-04,
#         4.64064096e-04, 1.16441408e-04, 7.95217427e-05, 7.26576229e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89919273, 0.89959993, 0.90226919, 0.90526681, 0.905902  ,
#         0.90659642, 0.90873336, 0.89447939]),
#  'split1_test_score': array([0.90963115, 0.90956013, 0.91234668, 0.91797936, 0.91914561,
#         0.91961897, 0.91246537, 0.89906665]),
#  'split2_test_score': array([0.8715117 , 0.87341227, 0.8832678 , 0.89132823, 0.8929483 ,
#         0.89376388, 0.8834415 , 0.86787845]),
#  'split3_test_score': array([0.89598537, 0.89623265, 0.89763813, 0.90240198, 0.90431613,
#         0.90587325, 0.91010753, 0.89478756]),
#  'split4_test_score': array([0.88882869, 0.88943298, 0.89027841, 0.8922063 , 0.8937704 ,
#         0.89498335, 0.90159331, 0.89220533]),
#  'mean_test_score': array([0.89302993, 0.89364759, 0.89716004, 0.90183654, 0.90321649,
#         0.90416718, 0.90326821, 0.88968348]),
#  'std_test_score': array([0.0126728 , 0.01202126, 0.00997313, 0.00975544, 0.00955847,
#         0.00938233, 0.0105559 , 0.01112578]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9041671758802707

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 25402.51751746902),
#  ('YearBuilt', 9787.078974140797),
#  ('OverallQual', 9379.458999200067),
#  ('BsmtFinSF1', 7299.786573977753),
#  ('OverallCond', 5978.107155664601),
#  ('NeighborhoodDummy_NoRidge', 5016.213423866327),
#  ('TotalBsmtSF', 4928.545996731323),
#  ('SaleConditionDummy_Normal', 4782.634386905085),
#  ('LotArea', 4749.536679420301),
#  ('KitchenQual', -4046.408835284716),
#  ('FunctionalDummy_Sev', 3834.5810883901618),
#  ('NeighborhoodDummy_Somerst', 3739.072764685154),
#  ('BsmtQual', -3569.8322114278994),
#  ('NeighborhoodDummy_NWAmes', 3436.6111411575657),
#  ('Exterior1stDummy_BrkComm', 3217.2894645267343),
#  ('GarageCars', 3116.750454376508),
#  ('ExterQual', -2870.850503181075),
#  ('NeighborhoodDummy_CollgCr', 2786.085430436871),
#  ('SaleConditionDummy_Family', 2647.918850478367),
#  ('GarageArea', 2632.503284261593),
#  ('BldgTypeDummy_Duplex', -2439.9684231990846),
#  ('MSSubClassDummy_90', -2336.95403604861),
#  ('KitchenAbvGr', -2299.0413362098107),
#  ('BedroomAbvGr', -2287.9767211475482),
#  ('WoodDeckSF', 2244.6234264044697),
#  ('Condition1Dummy_Feedr', 2235.4151394190267),
#  ('Exterior1stDummy_Stone', 2172.9042453650827),
#  ('MasVnrArea', 2061.9542803193144),
#  ('BldgTypeDummy_Twnhs', -2031.9825401512585),
#  ('MSSubClassDummy_190', 1980.6533598768353),
#  ('NeighborhoodDummy_Timber', 611.5538981285304),
#  ('PoolArea', 597.7342157016068),
#  ('LandContourDummy_Lvl', -596.5736272073276),
#  ('HeatingQC', -592.8424695378164),
#  ('Exterior1stDummy_ImStucc', 581.6571933999326),
#  ('Exterior2ndDummy_Stone', -578.2345234716121),
#  ('GarageFinish', -576.757085139779),
#  ('PavedDriveDummy_P', 569.5498724732313),
#  ('LotShapeDummy_IR3', 557.1257356978289),
#  ('Exterior2ndDummy_Brk Cmn', -546.5351992384363),
#  ('Exterior1stDummy_VinylSd', -538.5547727181281),
#  ('FullBath', 527.364656954429),
#  ('BldgTypeDummy_TwnhsE', 523.1181134347596),
#  ('ElectricalDummy_SBrkr', -510.4046551472263),
#  ('NeighborhoodDummy_Sawyer', -506.73712838038773),
#  ('EnclosedPorch', 502.37516626042844),
#  ('SaleTypeDummy_Con', 498.85424966941827),
#  ('RoofMatlDummy_Tar&Grv', -492.56017773498274),
#  ('MasVnrTypeDummy_No_MasVnr', 484.6816734196545),
#  ('LandContourDummy_HLS', -469.92902451167464),
#  ('Exterior1stDummy_HdBoard', -466.35900002129597),
#  ('SaleTypeDummy_New', 463.06662139417597),
#  ('LotFrontage', 448.34432374943896),
#  ('AlleyDummy_No_Alley_Access', -423.98985057084894),
#  ('Condition1Dummy_RRNe', 416.35342035006),
#  ('MoSold', -411.4789472235129),
#  ('MSSubClassDummy_80', -400.97749398977857),
#  ('ElectricalDummy_FuseP', 385.9775304988982),
#  ('BsmtCond', 385.1167515104292),
#  ('MasVnrTypeDummy_Stone', 367.96314457479286),
#  ('MSSubClassDummy_60', 349.5432688754468),
#  ('YrSold', -324.94913793720974),
#  ('LowQualFinSF', -287.55404567197576),
#  ('HeatingDummy_GasW', -281.1991643987168),
#  ('NeighborhoodDummy_BrkSide', 276.2492937800267),
#  ('NeighborhoodDummy_SWISU', 266.4681290704232),
#  ('SaleConditionDummy_Alloca', 265.3264425730098),
#  ('StreetDummy_Pave', 258.6845587342896),
#  ('RoofStyleDummy_Gable', 253.6960634602975),
#  ('Exterior1stDummy_BrkFace', -253.52784346925472),
#  ('BsmtHalfBath', -241.26097255524832),
#  ('Condition1Dummy_PosA', 239.92567791544695),
#  ('MSZoningDummy_FV', -222.0167725473355),
#  ('GarageTypeDummy_No_Garage', -218.18271628981154),
#  ('Exterior1stDummy_Plywood', -214.71321490034083),
#  ('MiscFeatureDummy_Othr', 209.2368274381141),
#  ('NeighborhoodDummy_Veenker', 206.38023696330163),
#  ('MiscVal', 205.7799715127982),
#  ('ElectricalDummy_Mix', 189.86372226225663),
#  ('BldgTypeDummy_2fmCon', -181.6961624484005),
#  ('LandSlope', -181.41597113538828),
#  ('NeighborhoodDummy_StoneBr', -167.1748177673474),
#  ('3SsnPorch', 163.72778437719808),
#  ('Condition1Dummy_RRAn', -161.20421827878266),
#  ('LotShapeDummy_IR2', -150.536814316184),
#  ('FunctionalDummy_Maj2', -147.1126373980795),
#  ('LotConfigDummy_Inside', 131.1514554740211),
#  ('Exterior1stDummy_WdShing', -123.50760549805251),
#  ('SaleTypeDummy_ConLD', -99.71377670644455),
#  ('SaleTypeDummy_ConLI', -96.24505969416552),
#  ('FoundationDummy_Wood', 95.35453333801453),
#  ('MasVnrTypeDummy_BrkFace', 67.37552042835618),
#  ('LandContourDummy_Low', 50.84968528897563),
#  ('HeatingDummy_GasA', -43.59586941040704),
#  ('Condition1Dummy_RRAe', 43.008718853562776),
#  ('LotConfigDummy_FR3', -31.82481528739443),
#  ('Exterior2ndDummy_HdBoard', 27.17715956443999),
#  ('CentralAirDummy_Y', -26.29814030453615),
#  ('MSSubClassDummy_45', -20.74560709578631),
#  ('Condition1Dummy_RRNn', 16.9084612562277),
#  ('Condition2Dummy_RRAe', -15.894561538507729),
#  ('Exterior2ndDummy_Wd Shng', -9.290606446066706),
#  ('GarageTypeDummy_Basment', 6.469826371173108),
#  ('Exterior2ndDummy_BrkFace', -1.1756954127201928),
#  ('SalePrice', -0.8416190893696534),
#  ('Exterior1stDummy_AsphShn', -0.586743490192436),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinType2', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('HalfBath', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('PoolQC', 0.0),
#  ('Fence', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_160', -0.0),
#  ('MSZoningDummy_RL', -0.0),
#  ('AlleyDummy_Pave', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', 0.0),
#  ('Condition1Dummy_Norm', 0.0),
#  ('Condition2Dummy_Feedr', -0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2Story', 0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Roll', 0.0),
#  ('RoofMatlDummy_WdShake', -0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Stucco', -0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', -0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', 0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', -0.0),
#  ('HeatingDummy_Wall', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('GarageTypeDummy_Attchd', 0.0),
#  ('GarageTypeDummy_BuiltIn', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8759089649598021

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.9017988214248222

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155276156127.16162, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158437022301.09268, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152756521661.12543, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165336285658.03918, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74053079224.14877, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92289098305.41866, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127198415485.90344, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113031967217.83725, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116453437560.99301, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6231345876.416992, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8290147487.795532, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.9018375442866006

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.999471
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999199
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998569
# PoolArea                  PoolQC                       0.997955
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996769
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.993119
# GarageCars                GarageArea                   0.989964
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988415
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.987153
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.986384
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.983223
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.974607
# GrLivArea                 TotRmsAbvGrd                 0.966505
# ExterQual                 KitchenQual                  0.961341
# BsmtQual                  FoundationDummy_PConc        0.956869
# OverallQual               ExterQual                    0.954197
# TotalBsmtSF               1stFlrSF                     0.952896
# 2ndFlrSF                  HouseStyleDummy_2Story       0.952179
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.951942
# ExterQual                 BsmtQual                     0.950875
# YearRemodAdd              BsmtQual                     0.941595
# MasVnrArea                MasVnrTypeDummy_None         0.941216
# YearRemodAdd              FoundationDummy_PConc        0.940878
# OverallQual               BsmtQual                     0.940238
# KitchenAbvGr              MSSubClassDummy_90           0.938651
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.937685
# OverallQual               KitchenQual                  0.936320
#                           GarageCars                   0.933452
# ExterQual                 FoundationDummy_PConc        0.932123
# YearRemodAdd              ExterQual                    0.927085
# YearBuilt                 BsmtQual                     0.927036
# HalfBath                  HouseStyleDummy_2Story       0.926426
# FoundationDummy_CBlock    FoundationDummy_PConc        0.926299
# OverallQual               FullBath                     0.922743
# YearBuilt                 YearRemodAdd                 0.921751
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.917173
# BsmtQual                  KitchenQual                  0.914794
# OverallQual               YearRemodAdd                 0.913660
#                           GarageArea                   0.910973
# BsmtFinSF1                BsmtFullBath                 0.909805
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.909270
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.909112
# HalfBath                  MSSubClassDummy_60           0.908615
# OverallQual               FoundationDummy_PConc        0.908225
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.907394
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.905637
# YearRemodAdd              KitchenQual                  0.898330
# LotFrontage               LotArea                      0.898067
# YearBuilt                 FoundationDummy_PConc        0.897515
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.986521913296021),
#  ('LotArea', 2.2472410548481787),
#  ('OverallQual', 4.55442380587524),
#  ('OverallCond', 2.089486061727057),
#  ('YearBuilt', 15.191943878623729),
#  ('YearRemodAdd', 3.2085199110509586),
#  ('MasVnrArea', 2.6648725996440272),
#  ('ExterQual', 2.9340905515035676),
#  ('BsmtQual', 2.958326758694852),
#  ('BsmtExposure', 1.8022751781271467),
#  ('BsmtFinType1', 2.209808231487011),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.4972591103816475),
#  ('BsmtHalfBath', 1.2640886982312751),
#  ('FullBath', 3.8992530538563424),
#  ('HalfBath', 2.8885262690131257),
#  ('BedroomAbvGr', 3.1795923704261084),
#  ('KitchenAbvGr', 5.820816234216583),
#  ('KitchenQual', 2.268993928245179),
#  ('TotRmsAbvGrd', 5.557568435805219),
#  ('Fireplaces', 1.8624741003864937),
#  ('FireplaceQu', 1.402586457984389),
#  ('GarageYrBlt', 1538.2133627370763),
#  ('GarageFinish', 2.1683833353677247),
#  ('GarageCars', 6.830989387582868),
#  ('GarageArea', 6.652934688391345),
#  ('WoodDeckSF', 1.3638500426680573),
#  ('OpenPorchSF', 1.4485583010169156),
#  ('EnclosedPorch', 1.4874742356151451),
#  ('3SsnPorch', 1.119358750992722),
#  ('ScreenPorch', 1.2008569118032424),
#  ('PoolArea', 16.076556288156887),
#  ('PoolQC', 16.02388200898603),
#  ('Fence', 1.3391677336101189),
#  ('MiscVal', 1.0725932776334313),
#  ('MoSold', 1.1467517880057252),
#  ('YrSold', 1.2061568385503325),
#  ('MSSubClassDummy_30', 2.5005556004057756),
#  ('MSSubClassDummy_40', 1.1332027855830704),
#  ('MSSubClassDummy_45', 7.664280278207764),
#  ('MSSubClassDummy_50', 18.912977010986378),
#  ('MSSubClassDummy_60', 30.60435925789767),
#  ('MSSubClassDummy_70', 7.5408404664633135),
#  ('MSSubClassDummy_75', 11.671122749811213),
#  ('MSSubClassDummy_80', 13.867206326397174),
#  ('MSSubClassDummy_85', 4.566394345939195),
#  ('MSSubClassDummy_90', 6.19466844369526),
#  ('MSSubClassDummy_120', 2.7609361462965167),
#  ('MSSubClassDummy_160', 10.466650767449556),
#  ('MSSubClassDummy_180', 2.3549308155603628),
#  ('MSSubClassDummy_190', 2.3263437124617328),
#  ('MSZoningDummy_FV', 23.95133428906824),
#  ('MSZoningDummy_RH', 4.960902453234962),
#  ('MSZoningDummy_RL', 65.45994623467664),
#  ('MSZoningDummy_RM', 44.299216272239214),
#  ('AlleyDummy_No_Alley_Access', 2.611905948431481),
#  ('AlleyDummy_Pave', 2.8517607953612187),
#  ('LotShapeDummy_IR2', 1.2012170976619123),
#  ('Exterior1stDummy_Stucco', 2.395078542518337),
#  ('Exterior1stDummy_VinylSd', 27.42471732636888),
#  ('Exterior1stDummy_Wd Sdng', 13.769310655933852),
#  ('Exterior1stDummy_WdShing', 2.665763863263674),
#  ('MasVnrTypeDummy_BrkFace', 26.980049225185674),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7559765032899726),
#  ('MasVnrTypeDummy_None', 30.605829666298906),
#  ('MasVnrTypeDummy_Stone', 10.363194755434368),
#  ('FoundationDummy_CBlock', 7.007481972200586),
#  ('FoundationDummy_PConc', 8.463455888757025),
#  ('FoundationDummy_Slab', 2.1681968708018706),
#  ('FoundationDummy_Stone', 1.28794674759233),
#  ('FoundationDummy_Wood', 1.2708812886820833),
#  ('GarageTypeDummy_Attchd', 92.77770598457921),
#  ('GarageTypeDummy_Basment', 5.933790046674193),
#  ('GarageTypeDummy_BuiltIn', 21.495056565799462),
#  ('GarageTypeDummy_CarPort', 2.9885314135089645),
#  ('GarageTypeDummy_Detchd', 76.09615439220623),
#  ('GarageTypeDummy_No_Garage', 1496.1175461248765),
#  ('SaleConditionDummy_AdjLand', 1.0690497929406442),
#  ('SaleConditionDummy_Alloca', 1.3494709257008035),
#  ('SaleConditionDummy_Family', 1.3385807338954818),
#  ('SaleConditionDummy_Normal', 2.677918410167393),
#  ('SaleConditionDummy_Partial', 2.759607834701578),
#  ('constant', 130547.5496322093)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1457         275           0        877         1152
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1457       2340      1188      1152             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF', 'OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 33.80088108577209),
#  ('LotArea', 12.377374606011966),
#  ('OverallCond', 39.26817110356011),
#  ('YearBuilt', 50150.51769482988),
#  ('YearRemodAdd', 27935.51308823986),
#  ('MasVnrArea', 3.5572502408977362),
#  ('ExterQual', 52.81648756694937),
#  ('BsmtQual', 17.289342672253962),
#  ('BsmtExposure', 9.341008096477475),
#  ('BsmtFinType1', 6.345523161721274),
#  ('BsmtFinSF1', 18.56888532990657),
#  ('BsmtFinSF2', 2.217870820190854),
#  ('BsmtUnfSF', 22.35307852061574),
#  ('1stFlrSF', 107.91486525156611),
#  ('2ndFlrSF', 29.379592759364513),
#  ('LowQualFinSF', 1.9674096664187397),
#  ('BsmtFullBath', 4.175702850694596),
#  ('BsmtHalfBath', 1.3312572749765283),
#  ('FullBath', 36.688596351500195),
#  ('HalfBath', 4.511480585109143),
#  ('BedroomAbvGr', 50.158388082382714),
#  ('KitchenAbvGr', 196.40725183093116),
#  ('KitchenQual', 23.72461807082022),
#  ('TotRmsAbvGrd', 55.76076991987386),
#  ('Fireplaces', 3.5047722336026284),
#  ('FireplaceQu', 11.524378233371387),
#  ('GarageYrBlt', 33924.88088958548),
#  ('GarageFinish', 7.674128027042847),
#  ('GarageCars', 49.61279846685512),
#  ('GarageArea', 43.77341134296059),
#  ('WoodDeckSF', 2.1722154775320535),
#  ('OpenPorchSF', 2.2101869642089356),
#  ('EnclosedPorch', 1.6529082715616499),
#  ('3SsnPorch', 1.133838738057028),
#  ('ScreenPorch', 1.2842935914602616),
#  ('PoolArea', 11.646397277694101),
#  ('PoolQC', 26521.202198078077),
#  ('Fence', 15.266173521768472),
#  ('MiscVal', 1.0753321661549098),
#  ('MoSold', 5.585963778644395),
#  ('YrSold', 3.465128988629105),
#  ('MSSubClassDummy_30', 2.4394649810527786),
#  ('MSSubClassDummy_40', 1.131115224909734),
#  ('MSSubClassDummy_45', 7.706674397700361),
#  ('MSSubClassDummy_50', 20.618574752422273),
#  ('MSSubClassDummy_60', 38.22352120994243),
#  ('MSSubClassDummy_70', 7.729685920283322),
#  ('MSSubClassDummy_75', 11.702196371632304),
#  ('MSSubClassDummy_80', 14.441561539217357),
#  ('MSSubClassDummy_85', 4.582028541621138),
#  ('MSSubClassDummy_90', 6.377639171206491),
#  ('MSSubClassDummy_120', 2.9421571360118484),
#  ('MSSubClassDummy_160', 10.780569997744541),
#  ('MSSubClassDummy_180', 2.357152630402651),
#  ('MSSubClassDummy_190', 2.3368388332749666),
#  ('MSZoningDummy_FV', 25.00876268381708),
#  ('MSZoningDummy_RH', 4.968911281274186),
#  ('MSZoningDummy_RL', 340.52639040737034),
#  ('MSZoningDummy_RM', 50.788180172908056),
#  ('AlleyDummy_No_Alley_Access', 49.62228209077876),
#  ('AlleyDummy_Pave', 2.915703792944746),
#  ('LotShapeDummy_IR2', 1.2263676880651293),
#  ('LotShapeDummy_IR3', 1.1179025318585454),
#  ('LotShapeDummy_Reg', 4.38851208405318),
#  ('LotConfigDummy_CulDSac', 1.8400796882145631),
#  ('LotConfigDummy_FR2', 1.4036274284791466),
#  ('LotConfigDummy_FR3', 1.0936236786346671),
#  ('LotConfigDummy_Inside', 6.3618857048296436),
#  ('NeighborhoodDummy_Blueste', 1.4189922383538816),
#  ('NeighborhoodDummy_BrDale', 3.1686906815496108),
#  ('NeighborhoodDummy_BrkSide', 8.367153433930177),
#  ('NeighborhoodDummy_ClearCr', 2.798061672695072),
#  ('FoundationDummy_Slab', 2.186797870842849),
#  ('FoundationDummy_Stone', 1.2830270987670873),
#  ('FoundationDummy_Wood', 1.2581849833458045),
#  ('GarageTypeDummy_Attchd', 247.54662721036806),
#  ('GarageTypeDummy_Basment', 5.9886355064336545),
#  ('GarageTypeDummy_BuiltIn', 22.696096897770893),
#  ('GarageTypeDummy_CarPort', 2.990146729946163),
#  ('GarageTypeDummy_Detchd', 102.83733863616816),
#  ('GarageTypeDummy_No_Garage', 1415.7603654524964),
#  ('SaleConditionDummy_AdjLand', 1.069260723919714),
#  ('SaleConditionDummy_Alloca', 1.3526016231448343),
#  ('SaleConditionDummy_Family', 1.3571054425913793),
#  ('SaleConditionDummy_Normal', 17.15198642085509),
#  ('SaleConditionDummy_Partial', 2.954995215745239)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# PoolArea                   PoolQC                        0.998089
# GarageYrBlt                GarageTypeDummy_No_Garage     0.996995
# MSSubClassDummy_45         HouseStyleDummy_1.5Unf        0.993011
# GarageCars                 GarageArea                    0.989285
# MSSubClassDummy_80         HouseStyleDummy_SLvl          0.988480
# RoofStyleDummy_Gable       RoofStyleDummy_Hip            0.987375
# MSZoningDummy_FV           NeighborhoodDummy_Somerst     0.975994
# ExterQual                  KitchenQual                   0.957041
# BsmtQual                   FoundationDummy_PConc         0.953913
# 2ndFlrSF                   HouseStyleDummy_2Story        0.951391
# ExterQual                  BsmtQual                      0.947002
# KitchenAbvGr               MSSubClassDummy_90            0.939295
# MSSubClassDummy_85         HouseStyleDummy_SFoyer        0.938563
# MasVnrArea                 MasVnrTypeDummy_None          0.938479
# YearRemodAdd               BsmtQual                      0.935116
#                            FoundationDummy_PConc         0.934970
# ExterQual                  FoundationDummy_PConc         0.927043
# HalfBath                   HouseStyleDummy_2Story        0.923592
# YearRemodAdd               ExterQual                     0.923351
# Exterior1stDummy_VinylSd   FoundationDummy_PConc         0.923339
# FoundationDummy_CBlock     FoundationDummy_PConc         0.922897
# YearBuilt                  BsmtQual                      0.922601
#                            YearRemodAdd                  0.915719
# BsmtFinSF1                 BsmtFullBath                  0.909746
# MasVnrTypeDummy_BrkFace    MasVnrTypeDummy_None          0.907854
# BsmtQual                   KitchenQual                   0.906618
# HalfBath                   MSSubClassDummy_60            0.906281
# GarageTypeDummy_Attchd     GarageTypeDummy_Detchd        0.898856
# YearRemodAdd               Exterior1stDummy_VinylSd      0.895292
# YearBuilt                  FoundationDummy_PConc         0.893059
# LotFrontage                LotArea                       0.892495
# YearRemodAdd               KitchenQual                   0.892412
# 2ndFlrSF                   HalfBath                      0.892351
# MSSubClassDummy_60         HouseStyleDummy_2Story        0.890893
# BsmtQual                   Exterior1stDummy_VinylSd      0.889065
#                            FullBath                      0.888900
# YearBuilt                  ExterQual                     0.885250
# KitchenQual                FoundationDummy_PConc         0.883168
# YearBuilt                  GarageCars                    0.877762
# MSZoningDummy_RL           MSZoningDummy_RM              0.877555
# BsmtQual                   GarageCars                    0.877309
# MasVnrArea                 MasVnrTypeDummy_BrkFace       0.874572
# FullBath                   GarageCars                    0.872932
# 2ndFlrSF                   HouseStyleDummy_1Story        0.871560
# ExterQual                  GarageCars                    0.868925
# FullBath                   FoundationDummy_PConc         0.866843
# YearBuilt                  Exterior1stDummy_VinylSd      0.862463
# ExterQual                  FullBath                      0.859762
#                            Exterior1stDummy_VinylSd      0.859695
# SaleConditionDummy_Normal  SaleConditionDummy_Partial    0.857892
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171897843208.35782, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171960441065.54315, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168063943616.58133, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184357678784.23846, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121633239868.35693, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104912536041.01547, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146470438547.19482, tolerance: 442416816.35907304
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125753286763.95001, tolerance: 469850546.077073
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127725145688.27997, tolerance: 480432741.5900617
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2793164841.7318115, tolerance: 458414831.5310057
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8620556589.827148, tolerance: 467611401.1420592
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
get_top_abs_correlations(X_Scacorr, 1000)
# Out:
#       LotFrontage   LotArea  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0       -0.246726 -0.285522    -0.553209   1.049076      0.875177    0.588986
# 1        0.440166 -0.032990     2.239045   0.111000     -0.445293   -0.580585
# 2       -0.109347  0.329339    -0.553209   0.979588      0.826270    0.386102
# 3       -0.475690 -0.043969    -0.553209  -2.008357     -0.738730   -0.580585
# 4        0.623337  0.990314    -0.553209   0.944845      0.728458    1.507936
# ...           ...       ...          ...        ...           ...         ...
# 1309    -0.384104 -0.402565    -0.553209   0.910101      0.728458   -0.580585
# 1310     0.669130  0.752055     0.377542   0.180487      0.141583    0.129512
# 1311    -0.200933 -0.155523     3.169797  -1.105025      1.021896   -0.580585
# 1312    -0.109347 -0.007297     0.377542  -0.792333      0.532833   -0.580585
# 1313     0.211202  0.041013     0.377542  -0.271180     -0.983262   -0.580585
#
#       ExterQual  BsmtQual  BsmtExposure  BsmtFinType1  ...  \
# 0     -0.946560 -0.607523      0.574349     -0.496737  ...
# 1      0.681424 -0.607523     -1.174653     -1.379974  ...
# 2     -0.946560 -0.607523     -0.300152     -0.496737  ...
# 3      0.681424  1.001924      0.574349     -1.379974  ...
# 4     -0.946560 -0.607523     -2.049154     -0.496737  ...
# ...         ...       ...           ...           ...  ...
# 1309   0.681424 -0.607523      0.574349      1.269737  ...
# 1310   0.681424 -0.607523      0.574349     -1.379974  ...
# 1311  -4.202528  1.001924      0.574349     -0.496737  ...
# 1312   0.681424  1.001924     -0.300152     -0.496737  ...
# 1313  -0.946560  1.001924      0.574349     -0.938355  ...
#
#       GarageTypeDummy_Basment  GarageTypeDummy_BuiltIn  \
# 0                   -0.107459                -0.237213
# 1                   -0.107459                -0.237213
# 2                   -0.107459                -0.237213
# 3                   -0.107459                -0.237213
# 4                   -0.107459                -0.237213
# ...                       ...                      ...
# 1309                -0.107459                -0.237213
# 1310                -0.107459                -0.237213
# 1311                -0.107459                -0.237213
# 1312                -0.107459                -0.237213
# 1313                -0.107459                -0.237213
#
#       GarageTypeDummy_CarPort  GarageTypeDummy_Detchd  \
# 0                   -0.067729               -0.594343
# 1                   -0.067729               -0.594343
# 2                   -0.067729               -0.594343
# 3                   -0.067729                1.682529
# 4                   -0.067729               -0.594343
# ...                       ...                     ...
# 1309                -0.067729               -0.594343
# 1310                -0.067729               -0.594343
# 1311                -0.067729               -0.594343
# 1312                -0.067729               -0.594343
# 1313                -0.067729               -0.594343
#
#       GarageTypeDummy_No_Garage  SaleConditionDummy_AdjLand  \
# 0                      -0.20702                   -0.027597
# 1                      -0.20702                   -0.027597
# 2                      -0.20702                   -0.027597
# 3                      -0.20702                   -0.027597
# 4                      -0.20702                   -0.027597
# ...                         ...                         ...
# 1309                   -0.20702                   -0.027597
# 1310                   -0.20702                   -0.027597
# 1311                   -0.20702                   -0.027597
# 1312                   -0.20702                   -0.027597
# 1313                   -0.20702                   -0.027597
#
#       SaleConditionDummy_Alloca  SaleConditionDummy_Family  \
# 0                     -0.055258                  -0.117851
# 1                     -0.055258                  -0.117851
# 2                     -0.055258                  -0.117851
# 3                     -0.055258                  -0.117851
# 4                     -0.055258                  -0.117851
# ...                         ...                        ...
# 1309                  -0.055258                  -0.117851
# 1310                  -0.055258                  -0.117851
# 1311                  -0.055258                  -0.117851
# 1312                  -0.055258                  -0.117851
# 1313                  -0.055258                  -0.117851
#
#       SaleConditionDummy_Normal  SaleConditionDummy_Partial
# 0                      0.429943                   -0.283887
# 1                      0.429943                   -0.283887
# 2                      0.429943                   -0.283887
# 3                     -2.325888                   -0.283887
# 4                      0.429943                   -0.283887
# ...                         ...                         ...
# 1309                   0.429943                   -0.283887
# 1310                   0.429943                   -0.283887
# 1311                   0.429943                   -0.283887
# 1312                   0.429943                   -0.283887
# 1313                   0.429943                   -0.283887
#
# [1314 rows x 138 columns]

# %%
stats.summary(gridRidge.best_estimator_,X_Scaled, y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-65-a03456951746> in <module>
# ----> 1 stats.summary(gridRidge.best_estimator_,X, y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in summary(clf, X, y, xlabels)
#     252     coef_df['Estimate'] = np.concatenate(
#     253         (np.round(np.array([clf.intercept_]), 6), np.round((clf.coef_), 6)))
# --> 254     coef_df['Std. Error'] = np.round(coef_se(clf, X, y), 6)
#     255     coef_df['t value'] = np.round(coef_tval(clf, X, y), 4)
#     256     coef_df['p value'] = np.round(coef_pval(clf, X, y), 6)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in coef_se(clf, X, y)
#     145     se_matrix = scipy.linalg.sqrtm(
#     146         metrics.mean_squared_error(y, clf.predict(X)) *
# --> 147         np.linalg.inv(X1.T * X1)
#     148     )
#     149     return np.diagonal(se_matrix)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
