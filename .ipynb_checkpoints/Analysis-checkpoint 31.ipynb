# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2355.119017677356), ('GrLivArea', 1755.8637514723453), ('GarageCars', 956.5879378302325), ('ExterQual', 919.7973659505656), ('TotalBsmtSF', 871.3987641588595), ('GarageArea', 841.731838761731), ('BsmtQual', 789.547657544028), ('KitchenQual', 779.2963223405732), ('1stFlrSF', 770.8321258121724), ('FullBath', 623.5250667599107), ('TotRmsAbvGrd', 606.4239393672984), ('YearBuilt', 582.8593975210986), ('YearRemodAdd', 462.2250981066734), ('GarageFinish', 330.1138494816384), ('Fireplaces', 323.5541275844534), ('MasVnrArea', 313.4700970511803), ('HeatingQC', 269.02648406229497), ('NeighborhoodDummy_NridgHt', 239.26832431761656), ('BsmtFinSF1', 234.61108990475984), ('MSSubClassDummy_60', 221.74184418715402), ('LotFrontage', 221.3594613484418), ('OpenPorchSF', 200.18538610665058), ('NeighborhoodDummy_NoRidge', 190.5754343332041), ('WoodDeckSF', 167.91965163797857), ('BsmtExposure', 147.39253495240297), ('2ndFlrSF', 145.80939120704156), ('LotArea', 142.3020389996758), ('MSZoningDummy_RM', 125.92342630124824), ('HalfBath', 108.05084849265643), ('LotShapeDummy_Reg', 95.40265776410129), ('BsmtFullBath', 80.66562554183317), ('MSSubClassDummy_30', 74.2537504220517), ('MSZoningDummy_RL', 70.10339032184547), ('GarageYrBlt', 68.59262782951983), ('NeighborhoodDummy_NAmes', 66.04638469574027), ('GarageCond', 57.09791649447835), ('BsmtUnfSF', 56.047695522200804), ('GarageQual', 55.56899725482934), ('NeighborhoodDummy_OldTown', 52.21947436213913), ('NeighborhoodDummy_Edwards', 44.45120827781504), ('BedroomAbvGr', 43.54092826028525), ('PoolQC', 40.606529276926906), ('MSSubClassDummy_50', 40.446631538017996), ('Fence', 40.06291805260037), ('NeighborhoodDummy_Somerst', 32.84452086918843), ('NeighborhoodDummy_StoneBr', 30.990274503159306), ('OverallCond', 30.706502217894194), ('NeighborhoodDummy_Sawyer', 30.43481572452184), ('NeighborhoodDummy_BrkSide', 27.37307506592169), ('NeighborhoodDummy_IDOTRR', 24.99660143487988), ('NeighborhoodDummy_Timber', 24.888142074631524), ('MSSubClassDummy_160', 23.535940442409395), ('EnclosedPorch', 18.83532813308156), ('NeighborhoodDummy_BrDale', 18.456922954304876), ('Condition1Dummy_Norm', 18.38797680728405), ('ExterCond', 18.27465098389338), ('NeighborhoodDummy_MeadowV', 17.665676319411055), ('PoolArea', 17.634343040416084), ('MSSubClassDummy_90', 17.15298370080297), ('LandContourDummy_HLS', 16.71980984355473), ('KitchenAbvGr', 16.308444282370267), ('LotConfigDummy_CulDSac', 16.179363678171093), ('MSZoningDummy_FV', 14.792442106065282), ('Condition1Dummy_Feedr', 14.365774234039181), ('AlleyDummy_No_Alley_Access', 13.00545069144012), ('BsmtFinType2', 10.093330609639935), ('NeighborhoodDummy_CollgCr', 9.975697751764), ('LotConfigDummy_Inside', 8.133203307584385), ('MSSubClassDummy_190', 8.052145952877538), ('BsmtFinType1', 7.839761690173387), ('MSSubClassDummy_45', 7.147771741516416), ('MSSubClassDummy_180', 6.812906061222525), ('BsmtCond', 6.384201991236843), ('NeighborhoodDummy_Veenker', 5.949559147563579), ('MSZoningDummy_RH', 5.906158995256299), ('MoSold', 5.651565892879089), ('NeighborhoodDummy_Mitchel', 5.578384569614968), ('LotShapeDummy_IR2', 5.434829756817482), ('NeighborhoodDummy_SWISU', 5.316178113236065), ('NeighborhoodDummy_ClearCr', 5.028820090536731), ('LowQualFinSF', 4.868496016767766), ('MSSubClassDummy_85', 4.250678238786661), ('ScreenPorch', 3.8603941528498202), ('NeighborhoodDummy_Crawfor', 3.7987375885830708), ('BsmtHalfBath', 3.749273693010969), ('FireplaceQu', 3.4962401625033537), ('Condition1Dummy_PosA', 3.2076835799348125), ('MSSubClassDummy_120', 2.995554622639887), ('LandContourDummy_Low', 2.9101744793640694), ('NeighborhoodDummy_NPkVill', 2.5312408163387503), ('LandContourDummy_Lvl', 2.1887753590309003), ('NeighborhoodDummy_Gilbert', 2.1003999657812367), ('MSSubClassDummy_80', 1.9943027931489965), ('LandSlope', 1.9641895578792532), ('BsmtFinSF2', 1.6202656268993212), ('StreetDummy_Pave', 1.5712513436555067), ('LotShapeDummy_IR3', 1.2236601231760411), ('MiscVal', 1.1485071559 ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.cv_results_

# %%
gridRf.best_params_

# %%
gridRf.best_score_

# %%
stats.summary(gridRf.best_estimator_, X, y)

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.cv_results_

# %%
gridRidge.best_params_

# %%
gridRidge.best_score_

# %%
gridRidge.best_estimator_.coef_

# %%
getFeatureImportance(50, train.columns, gridRidge.best_estimator_.coef_,'descending')

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.cv_results_

# %%
gridLasso.best_params_

# %%
gridLasso.best_score_

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.best_score_

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.best_score_

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)

# %%
mostCorrelatedFeat.head(50)

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF', 'OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
