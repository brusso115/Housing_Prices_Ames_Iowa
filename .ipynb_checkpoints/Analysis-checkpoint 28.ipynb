# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2465.186416527182), ('GrLivArea', 1519.818460042114), ('ExterQual', 1037.8671690140177), ('GarageCars', 1031.446427218952), ('TotalBsmtSF', 960.7720788790772), ('GarageArea', 889.8847448893351), ('KitchenQual', 842.8280727319717), ('1stFlrSF', 837.4243206375195), ('BsmtQual', 801.1800767351259), ('FullBath', 671.5917099112436), ('YearBuilt', 607.739056874612), ('TotRmsAbvGrd', 591.7154756049024), ('YearRemodAdd', 489.7351290745481), ('Fireplaces', 339.85145206743607), ('GarageFinish', 332.7211071355053), ('MasVnrArea', 319.30563910729927), ('HeatingQC', 280.5128102305451), ('BsmtFinSF1', 213.43895839383526), ('LotFrontage', 208.4543501133857), ('MSSubClassDummy_60', 206.59868607116113), ('OpenPorchSF', 161.3462331392223), ('BsmtExposure', 158.1535606436843), ('WoodDeckSF', 149.15546372890188), ('LotArea', 123.78534684339371), ('2ndFlrSF', 113.27529682674749), ('HalfBath', 106.35854502447943), ('MSSubClassDummy_30', 82.1914551574775), ('GarageYrBlt', 80.67332175074301), ('BsmtFullBath', 77.65785216117044), ('BsmtUnfSF', 77.38563903779881), ('GarageCond', 64.0229979818958), ('GarageQual', 50.64312529752407), ('Fence', 44.446889148082384), ('BedroomAbvGr', 38.059726231275654), ('OverallCond', 27.47070673885469), ('EnclosedPorch', 19.599643653158193), ('KitchenAbvGr', 18.433177640239716), ('ExterCond', 17.694359444192752), ('FireplaceQu', 8.132125467778899), ('BsmtFinType1', 8.053335755293878), ('ScreenPorch', 7.79044753311019), ('MSSubClassDummy_45', 6.963678216617488), ('LowQualFinSF', 6.503244027021276), ('BsmtFinType2', 6.317355643453078), ('BsmtCond', 5.171157906424986), ('MoSold', 4.1799182720393695), ('BsmtHalfBath', 3.330234113360903), ('LandSlope', 2.474228696132985), ('3SsnPorch', 1.6907644678384823), ('MiscVal', 1.0838647593639061), ('MSSubClassDummy_40', 0.46154115609031476), ('BsmtFinSF2', 0.24107737749506647), ('YrSold', 0.2057625702112658), ('PoolArea', 0.006231670954843798), ('PoolQC', 0.0024143878291044366), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 270.36082948218007), ('NeighborhoodDummy_NoRidge', 134.12221887051908), ('MSZoningDummy_RM', 128.41147022311836), ('LotShapeDummy_Reg', 83.6984277083726), ('MSZoningDummy_RL', 73.02802390609534), ('NeighborhoodDummy_NAmes', 66.37746264221549), ('NeighborhoodDummy_OldTown', 60.99122808961649), ('NeighborhoodDummy_Edwards', 50.96769842293172), ('NeighborhoodDummy_StoneBr', 50.87688719678883), ('MSSubClassDummy_50', 42.65600277202142), ('NeighborhoodDummy_Somerst', 35.77461615762325), ('NeighborhoodDummy_Sawyer', 28.848980666970764), ('NeighborhoodDummy_Timber', 27.429087204916012), ('NeighborhoodDummy_BrkSide', 27.411827709791464), ('NeighborhoodDummy_IDOTRR', 23.61260413930856), ('MSSubClassDummy_160', 22.629201150650843), ('AlleyDummy_No_Alley_Access', 20.270814329872504), ('Condition1Dummy_Norm', 18.18836288488355), ('NeighborhoodDummy_BrDale', 17.009838483450558), ('MSZoningDummy_FV', 16.810173951003723), ('LandContourDummy_HLS', 15.63310835875124), ('NeighborhoodDummy_MeadowV', 15.525590382573716), ('MSSubClassDummy_90', 13.778750324170314), ('Condition1Dummy_Feedr', 13.238415986648473), ('LotConfigDummy_CulDSac', 11.032722302041718), ('NeighborhoodDummy_CollgCr', 10.345295399464815), ('MSSubClassDummy_190', 9.28283859628535), ('NeighborhoodDummy_SWISU', 6.879767380343749), ('MSZoningDummy_RH', 6.100645897980054), ('NeighborhoodDummy_Mitchel', 5.911745342602015), ('MSSubClassDummy_180', 5.083928361628576), ('LotShapeDummy_IR2', 4.875803614227601), ('NeighborhoodDummy_ClearCr', 4.6405676745290965), ('NeighborhoodDummy_Crawfor', 4.598869204316351), ('MSSubClassDummy_120', 4.546091104285846), ('NeighborhoodDummy_Veenker', 4.354389094330106), ('MSSubClassDummy_85', 4.234284704977702), ('LotConfigDummy_Inside', 3.21856279434207), ('Condition1Dummy_PosA', 2.847757064827863), ('LandContourDummy_Low', 2.5873563173492893), ('NeighborhoodDummy_NPkVill', 2.5284617773292783), ('NeighborhoodDummy_Gilbert', 2.260548522303578), ('MSSubClassDumm ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.31504421, 0.21151013]),
#  'std_fit_time': array([0.06267521, 0.00519654]),
#  'mean_score_time': array([0.01070166, 0.00960088]),
#  'std_score_time': array([0.00156739, 0.00015926]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86590821, 0.8935128 ]),
#  'split1_test_score': array([0.89452145, 0.88039637]),
#  'split2_test_score': array([0.86332103, 0.85953405]),
#  'split3_test_score': array([0.85773603, 0.85919657]),
#  'split4_test_score': array([0.8883884 , 0.88266994]),
#  'mean_test_score': array([0.87397502, 0.87506195]),
#  'std_test_score': array([0.01464368, 0.01356169]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8750619467374566

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.09500941156372716),
#  ('GrLivArea', 0.07187938017419494),
#  ('TotalBsmtSF', 0.06300265086686682),
#  ('GarageArea', 0.054782149090217454),
#  ('YearBuilt', 0.05025748859553124),
#  ('FullBath', 0.04121647015194761),
#  ('GarageCars', 0.03894592881885468),
#  ('KitchenQual', 0.03889670419084581),
#  ('1stFlrSF', 0.03731140135144874),
#  ('BsmtQual', 0.03190745422908706),
#  ('BsmtFinSF1', 0.027515359697604373),
#  ('ExterQual', 0.026254084167862225),
#  ('TotRmsAbvGrd', 0.026023492100445612),
#  ('LotArea', 0.021483340125082444),
#  ('OpenPorchSF', 0.0204869389275759),
#  ('2ndFlrSF', 0.02032750390623022),
#  ('YearRemodAdd', 0.019962683732811595),
#  ('GarageYrBlt', 0.01848117719283854),
#  ('MasVnrArea', 0.017026329391707163),
#  ('LotFrontage', 0.016460812662516314),
#  ('FoundationDummy_CBlock', 0.016413679850835475),
#  ('Fireplaces', 0.015295030493093718),
#  ('HeatingQC', 0.011976187963206424),
#  ('BsmtUnfSF', 0.010725036592755744),
#  ('WoodDeckSF', 0.008733105715650768),
#  ('MSSubClassDummy_50', 0.008589500070232785),
#  ('NeighborhoodDummy_NoRidge', 0.008520303532688274),
#  ('GarageFinish', 0.007835237628493525),
#  ('FireplaceQu', 0.007725405016086496),
#  ('FunctionalDummy_Typ', 0.0075699041757799745),
#  ('GarageTypeDummy_CarPort', 0.0064667118125194545),
#  ('BedroomAbvGr', 0.005561602501850442),
#  ('HalfBath', 0.005291043302299931),
#  ('BsmtFullBath', 0.004855828167139736),
#  ('MasVnrTypeDummy_None', 0.004839355106625495),
#  ('SaleConditionDummy_Normal', 0.004724572670003319),
#  ('MasVnrTypeDummy_No_MasVnr', 0.004539995134700627),
#  ('MoSold', 0.004425870855903317),
#  ('BsmtExposure', 0.0043654851469011186),
#  ('RoofStyleDummy_Gambrel', 0.004287545391687939),
#  ('BsmtFinType1', 0.004265470303425393),
#  ('SaleTypeDummy_ConLw', 0.0041759341837422),
#  ('MasVnrTypeDummy_Stone', 0.004002111284240992),
#  ('OverallCond', 0.003884596647674846),
#  ('HouseStyleDummy_SLvl', 0.0035040952890541756),
#  ('MSSubClassDummy_160', 7.911036702092533e-06),
#  ('Condition2Dummy_Norm', 6.616507599889628e-06),
#  ('SaleTypeDummy_ConLD', 4.995625975226197e-06),
#  ('Condition1Dummy_RRAn', 4.7519635849080824e-06),
#  ('SaleTypeDummy_ConLI', 4.609640272332153e-06),
#  ('LotConfigDummy_Inside', 4.471780697669067e-06),
#  ('RoofStyleDummy_Hip', 4.4017005091023595e-06),
#  ('FoundationDummy_Slab', 3.3275090264947255e-06),
#  ('Exterior2ndDummy_BrkFace', 3.1947581265567546e-06),
#  ('SaleTypeDummy_WD', 1.8454862688041476e-06),
#  ('HeatingDummy_OthW', 1.3231338203546349e-06),
#  ('RoofMatlDummy_WdShngl', 1.0482622664791912e-06),
#  ('MiscFeatureDummy_No_Misc_Feature', 2.2122781250536837e-07),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', 0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02554226, 0.00485411, 0.00475116, 0.00424261, 0.00509119,
#         0.00484114, 0.00482879, 0.00445356]),
#  'std_fit_time': array([0.04119712, 0.00014656, 0.0001713 , 0.00049788, 0.00020062,
#         0.00013422, 0.00021656, 0.00039762]),
#  'mean_score_time': array([0.00272865, 0.00259662, 0.00255399, 0.00217242, 0.00270343,
#         0.00262866, 0.00261106, 0.0022244 ]),
#  'std_score_time': array([1.09373223e-04, 7.72024246e-05, 1.21735919e-04, 3.20058855e-04,
#         5.20762067e-05, 7.36636402e-05, 1.72800589e-04, 2.99928768e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.88551786, 0.88699721, 0.89134783, 0.89631207, 0.89797985,
#         0.89925945, 0.89825197, 0.88092925]),
#  'split1_test_score': array([0.89716808, 0.89840538, 0.90078129, 0.90060097, 0.8999507 ,
#         0.89932464, 0.87216077, 0.83973707]),
#  'split2_test_score': array([0.87755086, 0.88803797, 0.89431294, 0.89791734, 0.89832387,
#         0.89841121, 0.88150849, 0.85664946]),
#  'split3_test_score': array([0.87274056, 0.87327209, 0.87575386, 0.87960706, 0.88051772,
#         0.88098696, 0.86329456, 0.83681925]),
#  'split4_test_score': array([0.88655721, 0.88687279, 0.88750246, 0.89002523, 0.89096656,
#         0.89163937, 0.8810889 , 0.85851537]),
#  'mean_test_score': array([0.88390691, 0.88671709, 0.88993967, 0.89289253, 0.89354774,
#         0.89392433, 0.87926094, 0.85453008]),
#  'std_test_score': array([0.00837335, 0.00799039, 0.00831657, 0.00749783, 0.00720967,
#  ('MasVnrArea', 2583.977254172222),
#  ('BldgTypeDummy_Duplex', -2479.1280436892343),
#  ('BedroomAbvGr', -2444.663123630944),
#  ('MSSubClassDummy_90', -2432.121801698455),
#  ('BldgTypeDummy_Twnhs', -2399.0565765784395),
#  ('Condition1Dummy_Feedr', 2327.966350436657),
#  ('SaleConditionDummy_Family', 2324.3874704239556),
#  ('NeighborhoodDummy_CollgCr', 2292.996827619707),
#  ('BsmtExposure', -2217.38738371418),
#  ('NeighborhoodDummy_Crawfor', -2203.419786345513),
#  ('SaleConditionDummy_Normal', 2164.8380687960066),
#  ('NeighborhoodDummy_Mitchel', -2107.022722168967),
#  ('GarageArea', 2072.270072208643),
#  ('NeighborhoodDummy_NPkVill', -2052.100924670595),
#  ('Fireplaces', 1990.5160699276128),
#  ('FoundationDummy_CBlock', 1950.3956155451576),
#  ('Exterior2ndDummy_CBlock', 1878.4332036151056),
#  ('YearRemodAdd', 1876.7079700097972),
#  ('MasVnrTypeDummy_None', 1875.9619091705883),
#  ('MSSubClassDummy_120', -1846.5338983528877),
#  ('FullBath', 1843.4540561956546),
#  ('MSSubClassDummy_190', 1810.2267964123012),
#  ('Exterior1stDummy_VinylSd', -1810.0200006969117),
#  ('NeighborhoodDummy_Edwards', -1771.6455876688742),
#  ('NeighborhoodDummy_NridgHt', -1763.1899938152012),
#  ('NeighborhoodDummy_ClearCr', -1666.0924819588602),
#  ('WoodDeckSF', 1661.1925522607924),
#  ('MiscFeatureDummy_TenC', 1640.536243637926),
#  ('NeighborhoodDummy_Blueste', 1629.9018015015154),
#  ('LotShapeDummy_Reg', 1616.217626770984),
#  ('Exterior2ndDummy_Wd Sdng', -1613.0877963277856),
#  ('ScreenPorch', 1565.1663807910347),
#  ('LotFrontage', 1520.7864328727817),
#  ('HalfBath', 1498.9679002818316),
#  ('FoundationDummy_PConc', 1427.4669946790962),
#  ('OpenPorchSF', 1362.0121102978087),
#  ('UtilitiesDummy_NoSeWa', 1344.1221289375214),
#  ('Exterior2ndDummy_CmentBd', -1324.8170606940184),
#  ('Condition1Dummy_PosN', -1311.0204226667868),
#  ('Condition2Dummy_Norm', 1289.6368764384138),
#  ('GarageTypeDummy_Basment', 1266.8629617783329),
#  ('MSSubClassDummy_75', -1262.4990376303665),
#  ('Exterior2ndDummy_Other', -1261.672172524975),
#  ('NeighborhoodDummy_MeadowV', -1255.780396083615),
#  ('MSZoningDummy_RM', 1204.6201221672852),
#  ('SaleTypeDummy_CWD', 1193.544544694637),
#  ('Exterior1stDummy_Wd Sdng', 1147.5659535600241),
#  ('FunctionalDummy_Min2', -1134.7854192221162),
#  ('RoofMatlDummy_Roll', -1062.5014915316056),
#  ('Exterior2ndDummy_VinylSd', 1052.783467855557),
#  ('NeighborhoodDummy_NAmes', 1021.5606077830405),
#  ('BsmtFullBath', 1016.7703916461635),
#  ('MasVnrTypeDummy_Stone', 1014.4122866549875),
#  ('PoolArea', 1014.2128661432054),
#  ('HouseStyleDummy_1Story', -1013.2302734645377),
#  ('FunctionalDummy_Mod', -985.5143483783143),
#  ('RoofStyleDummy_Mansard', 984.837459338905),
#  ('MSZoningDummy_RH', 978.7897833128164),
#  ('Exterior1stDummy_Stone', 967.2244159819904),
#  ('HouseStyleDummy_SLvl', -923.9190752145479),
#  ('LotConfigDummy_CulDSac', -923.8899642804652),
#  ('GarageFinish', -909.414173187225),
#  ('FoundationDummy_Stone', -905.369399260436),
#  ('NeighborhoodDummy_BrDale', 893.0880487958602),
#  ('MSSubClassDummy_50', 885.512399741596),
#  ('BsmtFinSF2', 885.1707347521415),
#  ('MasVnrTypeDummy_No_MasVnr', 881.835402626882),
#  ('LandContourDummy_HLS', -877.4952422365591),
#  ('LotConfigDummy_FR2', -864.1608350701102),
#  ('HouseStyleDummy_SFoyer', 855.4664284969763),
#  ('PavedDriveDummy_P', 846.5370874937348),
#  ('BsmtUnfSF', -840.128872522123),
#  ('GarageTypeDummy_CarPort', 785.9404931574796),
#  ('NeighborhoodDummy_OldTown', -778.0928431657828),
#  ('MSSubClassDummy_80', -768.6305089467859),
#  ('HeatingQC', -736.1724573101446),
#  ('MoSold', -731.8648524084396),
#  ('Exterior1stDummy_ImStucc', 728.9155081258086),
#  ('NeighborhoodDummy_Timber', 719.3746598184832),
#  ('Exterior1stDummy_CBlock', -714.1530129248908),
#  ('SalePrice', -713.463445093818),
#  ('GarageYrBlt', -712.935766371297),
#  ('NeighborhoodDummy_IDOTRR', -694.8620260542046),
#  ('HouseStyleDummy_2.5Unf', -693.2539465425905),
#  ('Exterior1stDummy_MetalSd', -683.745276075642),
#  ('ExterCond', 675.8510721023533),
#  ('BsmtFinType2', -667.9515952876291),
#  ('FunctionalDummy_Min1', 666.1547301497227),
#  ('ElectricalDummy_SBrkr', -648.442466769018),
#  ('GarageTypeDummy_Detchd', 634.9112296357107),
#  ('SaleTypeDummy_WD', 623.2061491345588),
#  ('FunctionalDummy_Typ', -622.2797258957058),
#  ('Exterior1stDummy_CemntBd', -620.7165198099625),
#  ('Condition1Dummy_RRNn', -599.497506540791),
#  ('RoofStyleDummy_Shed', 595.2355576752512),
#  ('HeatingDummy_GasW', -591.4203336071736),
#  ('FireplaceQu', -589.2772443671238),
#  ('BsmtHalfBath', -584.7782333031302),
#  ('HouseStyleDummy_1.5Unf', -583.4969146624392),
#  ('MSSubClassDummy_60', 572.4129205467077),
#  ('Exterior1stDummy_HdBoard', -549.4678886651951),
#  ('LandContourDummy_Low', 534.4318915161498),
#  ('FunctionalDummy_Maj2', -517.5762158059149),
#  ('NeighborhoodDummy_StoneBr', -516.3200126667781),
#  ('HouseStyleDummy_2.5Fin', -516.2684012573689),
#  ('Condition2Dummy_RRNn', -512.1364855736429),
#  ('MSSubClassDummy_180', -512.1364855736251),
#  ('Exterior2ndDummy_Plywood', 505.0860992720148),
#  ('MSZoningDummy_FV', 484.7096566462919),
#  ('RoofStyleDummy_Gambrel', 470.48180751386326),
#  ('MSSubClassDummy_85', -459.017323380574),
#  ('BldgTypeDummy_2fmCon', -459.01732338056956),
#  ('3SsnPorch', 450.0743070626211),
#  ('RoofMatlDummy_WdShake', 442.9542662382763),
#  ('Exterior1stDummy_Plywood', -430.0902738919819),
#  ('RoofStyleDummy_Gable', 389.7981060358852),
#  ('Condition1Dummy_RRAn', -367.232264048534),
#  ('NeighborhoodDummy_Gilbert', -361.91246436048107),
#  ('PoolQC', 358.4645791216024),
#  ('Condition1Dummy_PosA', 357.41590518549486),
#  ('HeatingDummy_OthW', -353.6009993627371),
#  ('LotShapeDummy_IR2', -349.97821320152303),
#  ('LotShapeDummy_IR3', 347.94662144994203),
#  ('YrSold', -344.38999485954525),
#  ('Condition1Dummy_RRAe', 339.9023565187687),
#  ('Exterior2ndDummy_Brk Cmn', -336.5783292390848),
#  ('Exterior2ndDummy_HdBoard', 331.4747444887807),
#  ('Fence', 321.7145154481633),
#  ('Exterior2ndDummy_MetalSd', -315.29731685823623),
#  ('LandSlope', -308.0081212096377),
#  ('SaleTypeDummy_New', 302.55582368089165),
#  ('GarageTypeDummy_No_Garage', -298.7758568979971),
#  ('SaleTypeDummy_Con', 297.3949108238176),
#  ('HeatingDummy_Wall', 279.8001027599648),
#  ('LotConfigDummy_Inside', 269.1557510439466),
#  ('SaleTypeDummy_Oth', -268.42468485323),
#  ('HeatingDummy_GasA', -263.9077713655718),
#  ('Exterior1stDummy_BrkFace', -262.5069849206426),
#  ('Exterior2ndDummy_BrkFace', -262.5069849206404),
#  ('Exterior2ndDummy_Stucco', 250.10193565975166),
#  ('HouseStyleDummy_2Story', -247.48685243512318),
#  ('Condition1Dummy_Norm', 243.29534080398403),
#  ('BsmtFinType1', -240.28430817986512),
#  ('AlleyDummy_No_Alley_Access', -236.30156110414893),
#  ('Exterior2ndDummy_AsphShn', 233.56137804348822),
#  ('SaleConditionDummy_AdjLand', 233.539017277802),
#  ('Condition1Dummy_RRNe', 223.3848250404488),
#  ('MSSubClassDummy_30', 222.50072698703923),
#  ('BsmtCond', 222.093992382346),
#  ('NeighborhoodDummy_Sawyer', -221.55732192626738),
#  ('FoundationDummy_Slab', -220.194672186426),
#  ('ElectricalDummy_FuseF', 218.45405255830414),
#  ('SaleTypeDummy_ConLD', -209.46557784374767),
#  ('LowQualFinSF', -199.0127232687256),
#  ('MiscFeatureDummy_Othr', 190.18441412167186),
#  ('RoofMatlDummy_Tar&Grv', -189.94575309613901),
#  ('MSSubClassDummy_70', 187.88275015146473),
#  ('Exterior1stDummy_WdShing', 187.6969376686845),
#  ('Exterior1stDummy_AsphShn', -181.43068413028877),
#  ('MasVnrTypeDummy_BrkFace', 162.72696096269738),
#  ('MiscVal', 157.50747091253118),
#  ('Exterior2ndDummy_Stone', -153.90966435615422),
#  ('CentralAirDummy_Y', -136.22603646877582),
#  ('NeighborhoodDummy_SawyerW', 128.48770585627145),
#  ('GarageQual', 126.69034651855605),
#  ('FoundationDummy_Wood', -121.82926373835423),
#  ('Exterior2ndDummy_ImStucc', 118.96893354595841),
#  ('MiscFeatureDummy_No_Misc_Feature', 118.57652619464545),
#  ('EnclosedPorch', 115.5095203730914),
#  ('MSSubClassDummy_160', 102.47846448371413),
#  ('MSSubClassDummy_45', 87.17840949084815),
#  ('ElectricalDummy_Mix', -83.9277595981762),
#  ('Exterior1stDummy_Stucco', -76.13845177325776),
#  ('PavedDriveDummy_Y', -74.42531072771057),
#  ('RoofMatlDummy_WdShngl', -67.80813009909944),
#  ('SaleConditionDummy_Alloca', -66.39292030843086),
#  ('GarageTypeDummy_BuiltIn', -52.672338265393115),
#  ('Exterior2ndDummy_Wd Shng', 50.998603115010404),
#  ('NeighborhoodDummy_Veenker', 43.28205311862179),
#  ('MSZoningDummy_RL', -30.253769575725595),
#  ('AlleyDummy_Pave', 29.7388197385908),
#  ('LotConfigDummy_FR3', 28.885485676188306),
#  ('GarageTypeDummy_Attchd', -28.853195716884525),
#  ('NeighborhoodDummy_BrkSide', -26.492467123759464),
#  ('MSSubClassDummy_40', 20.58273858828143),
#  ('BldgTypeDummy_TwnhsE', 20.58273858826583),
#  ('SaleTypeDummy_ConLI', -19.639952120282146),
#  ('Condition2Dummy_Feedr', 13.73527965575615),
#  ('Condition2Dummy_RRAe', 12.579820484549137),
#  ('NeighborhoodDummy_SWISU', 9.393808118942921),
#  ('RoofStyleDummy_Hip', -8.9847300958157),
#  ('StreetDummy_Pave', 2.6434105823346012),
#  ('GarageCond', -0.49360820738528466),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175827239012.18906, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169091355670.7292, tolerance: 493723687.1391147
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180480455026.83655, tolerance: 546321123.5990222
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161723051769.74506, tolerance: 526444134.25497514
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178314581129.95538, tolerance: 544571233.8349129
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116571671693.4845, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122497990267.53603, tolerance: 493723687.1391147
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142358313035.35886, tolerance: 546321123.5990222
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118771273755.4285, tolerance: 526444134.25497514
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149478148678.9777, tolerance: 544571233.8349129
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10705612584.089783, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.1122448 , 0.11581988, 0.11428123, 0.08316226, 0.0625927 ,
#         0.0482481 , 0.00934234, 0.00884051]),
#  'std_fit_time': array([0.00612621, 0.00219229, 0.00241347, 0.00446762, 0.00248224,
#         0.00289349, 0.00065167, 0.00260688]),
#  'mean_score_time': array([0.00247917, 0.00241694, 0.00234809, 0.00242481, 0.00281124,
#         0.00287743, 0.00259905, 0.00265589]),
#  'std_score_time': array([2.35956671e-04, 1.49950586e-04, 2.89178310e-04, 4.03306450e-04,
#         3.80344382e-04, 2.41100741e-04, 2.26637646e-05, 1.06781355e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.88513581, 0.8853882 , 0.8877726 , 0.89376544, 0.89549928,
#         0.89676515, 0.90277709, 0.89244731]),
#  'split1_test_score': array([0.89781108, 0.89831878, 0.90051334, 0.90353215, 0.90411244,
#         0.90460573, 0.90527911, 0.90001295]),
#  'split2_test_score': array([0.88298106, 0.88434391, 0.89082158, 0.89757601, 0.90048701,
#         0.90125236, 0.89852119, 0.88149893]),
#  'split3_test_score': array([0.87261787, 0.87282746, 0.87370716, 0.87700746, 0.87844965,
#         0.87985994, 0.87764695, 0.86167652]),
#  'split4_test_score': array([0.88686007, 0.88649927, 0.88681793, 0.88803504, 0.8895534 ,
#         0.89068989, 0.89996874, 0.89340082]),
#  'mean_test_score': array([0.88508118, 0.88547553, 0.88792652, 0.89198322, 0.89362036,
#         0.89463461, 0.89683861, 0.88580731]),
#  'std_test_score': array([0.00806179, 0.00809023, 0.00860526, 0.00902989, 0.00902724,
#         0.00873623, 0.00987377, 0.01344923]),
#  'rank_test_score': array([8, 7, 5, 4, 3, 2, 1, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8968386139577724

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 23656.847534895234),
#  ('OverallQual', 12524.809274025565),
#  ('BsmtFinSF1', 8579.080711745568),
#  ('TotalBsmtSF', 7457.9940387818215),
#  ('NeighborhoodDummy_NoRidge', 5284.36494792801),
#  ('ExterQual', -5178.7708516164),
#  ('KitchenQual', -5169.099695660506),
#  ('YearBuilt', 5077.888711905948),
#  ('SaleTypeDummy_ConLw', 4343.515073998697),
#  ('OverallCond', 4031.9409786863353),
#  ('LotArea', 3910.3219892239536),
#  ('NeighborhoodDummy_Somerst', 3712.1001902535104),
#  ('BsmtQual', -3707.3082589094643),
#  ('GarageCars', 3260.002749600661),
#  ('NeighborhoodDummy_NWAmes', 3125.1409546660057),
#  ('FunctionalDummy_Sev', 2719.4886928906235),
#  ('KitchenAbvGr', -2354.1987941078637),
#  ('Exterior1stDummy_BrkComm', 2194.1243217078154),
#  ('NeighborhoodDummy_CollgCr', 2128.0442425657016),
#  ('GarageArea', 1817.8359989427559),
#  ('YearRemodAdd', 1726.7045362871236),
#  ('Fireplaces', 1669.5161547276964),
#  ('MSSubClassDummy_90', -1654.2000077133657),
#  ('MasVnrArea', 1380.3313024323568),
#  ('MSSubClassDummy_120', -1348.1080598524075),
#  ('BldgTypeDummy_Twnhs', -1289.8518890696657),
#  ('Condition1Dummy_Feedr', 1285.6611714474984),
#  ('BldgTypeDummy_Duplex', -1180.471675360307),
#  ('BsmtExposure', -1145.710657133823),
#  ('RoofMatlDummy_Roll', -1016.6951836115823),
#  ('MasVnrTypeDummy_None', 889.0364068337961),
#  ('NeighborhoodDummy_SawyerW', 845.7764093818097),
#  ('WoodDeckSF', 817.9782844654567),
#  ('HouseStyleDummy_SLvl', -802.7641314599207),
#  ('GarageFinish', -697.499927084773),
#  ('SaleTypeDummy_CWD', 667.1171141882985),
#  ('NeighborhoodDummy_NPkVill', -666.580602134794),
#  ('NeighborhoodDummy_NridgHt', -649.354354785931),
#  ('HouseStyleDummy_1Story', -636.966537395482),
#  ('FunctionalDummy_Mod', -606.5736546417676),
#  ('MiscFeatureDummy_TenC', 601.6449173701664),
#  ('LotShapeDummy_Reg', 592.4504944325665),
#  ('BedroomAbvGr', -487.3083254546611),
#  ('ScreenPorch', 483.5773348849622),
#  ('FunctionalDummy_Min2', -472.6830714827005),
#  ('Exterior2ndDummy_CmentBd', -405.48026441565884),
#  ('TotRmsAbvGrd', 383.6238075647182),
#  ('BsmtFullBath', 341.86039333611546),
#  ('BsmtFinSF2', 341.3555891778412),
#  ('LotFrontage', 324.1503151766008),
#  ('HeatingQC', -323.6873291107323),
#  ('MSZoningDummy_RL', -321.4318861453467),
#  ('OpenPorchSF', 290.45797788068654),
#  ('BsmtFinType2', -289.92222469540786),
#  ('LowQualFinSF', -276.14581337927376),
#  ('NeighborhoodDummy_BrDale', 273.2517683159661),
#  ('Exterior1stDummy_MetalSd', -260.1776247961837),
#  ('1stFlrSF', 243.47334859949157),
#  ('GarageTypeDummy_Basment', 227.66145676358383),
#  ('NeighborhoodDummy_Timber', 213.71357962970092),
#  ('UtilitiesDummy_NoSeWa', 195.7548044267164),
#  ('Exterior2ndDummy_CBlock', 192.0757362690047),
#  ('FoundationDummy_PConc', 191.27219982039253),
#  ('Exterior2ndDummy_Wd Sdng', -174.7909462364531),
#  ('Exterior1stDummy_VinylSd', -174.28995185818798),
#  ('FoundationDummy_Stone', -147.76615773794038),
#  ('MSSubClassDummy_190', 125.24006441271924),
#  ('Condition1Dummy_PosN', -113.56765410958566),
#  ('NeighborhoodDummy_OldTown', -92.57352461535919),
#  ('FireplaceQu', -52.39882893611757),
#  ('MSZoningDummy_RM', 38.67788085096539),
#  ('Exterior2ndDummy_Other', -22.539143311508322),
#  ('SaleConditionDummy_Alloca', -2.0043485652605035),
#  ('LandSlope', -0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', -0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', 0.0),
#  ('LandContourDummy_Lvl', 0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', 0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', 0.0),
#  ('Condition1Dummy_PosA', -0.0),
#  ('Condition1Dummy_RRAe', -0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_2fmCon', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', -0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_CBlock', 0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', 0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_Con', -0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Family', 0.0),
#  ('SaleConditionDummy_Normal', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-30-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8790541306143315

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8920025978924186

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 194815835846.4794, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188810397322.13498, tolerance: 493723687.1391147
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196662168190.617, tolerance: 546321123.5990222
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176034677243.5515, tolerance: 526444134.25497514
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144943124341.16473, tolerance: 544571233.8349129
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127342327945.25308, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152574624765.58655, tolerance: 493723687.1391147
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142113420665.99973, tolerance: 546321123.5990222
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104865183714.5901, tolerance: 526444134.25497514
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18148096117.96283, tolerance: 544571233.8349129
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14015462784.95227, tolerance: 549750650.1124107
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8933249589108241

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       1.000000
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999131
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998966
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998875
# PoolArea                  PoolQC                       0.997895
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996030
# GarageCars                GarageArea                   0.989427
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.989099
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.987362
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984758
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.983095
# GrLivArea                 TotRmsAbvGrd                 0.971202
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.970397
# TotalBsmtSF               1stFlrSF                     0.967618
# ExterQual                 KitchenQual                  0.966624
# OverallQual               ExterQual                    0.958958
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.954541
# BsmtQual                  FoundationDummy_PConc        0.952913
# ExterQual                 BsmtQual                     0.952616
# MasVnrArea                MasVnrTypeDummy_None         0.948301
# OverallQual               BsmtQual                     0.948113
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.948033
# 2ndFlrSF                  HouseStyleDummy_2Story       0.946566
# YearRemodAdd              BsmtQual                     0.944306
# OverallQual               GarageCars                   0.942991
#                           KitchenQual                  0.942884
# YearRemodAdd              FoundationDummy_PConc        0.942833
# HalfBath                  HouseStyleDummy_2Story       0.929768
# OverallQual               FullBath                     0.928296
# YearBuilt                 BsmtQual                     0.924828
# FoundationDummy_CBlock    FoundationDummy_PConc        0.924360
# BsmtQual                  KitchenQual                  0.924137
# ExterQual                 FoundationDummy_PConc        0.922817
# YearRemodAdd              ExterQual                    0.922037
# OverallQual               GarageArea                   0.919479
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.916856
# YearBuilt                 YearRemodAdd                 0.915969
# OverallQual               YearRemodAdd                 0.915657
# BsmtFinSF1                BsmtFullBath                 0.912356
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.909509
# HalfBath                  MSSubClassDummy_60           0.908966
# OverallQual               FoundationDummy_PConc        0.907178
# BsmtQual                  GarageCars                   0.907037
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.903814
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.902386
# BsmtQual                  FullBath                     0.900526
# KitchenAbvGr              MSSubClassDummy_90           0.899795
# ExterQual                 GarageCars                   0.898689
# YearRemodAdd              KitchenQual                  0.897307
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 3.0206882761553726),
#  ('LotArea', 2.0901029609095576),
#  ('OverallQual', 4.8299266494449125),
#  ('OverallCond', 2.1136736444677706),
#  ('YearBuilt', 15.904263455757901),
#  ('YearRemodAdd', 3.1554296072574353),
#  ('MasVnrArea', 2.7322815802507714),
#  ('ExterQual', 3.041130659202499),
#  ('BsmtQual', 3.1167611019180246),
#  ('BsmtExposure', 1.8282188980190996),
#  ('BsmtFinType1', 2.1535969634111307),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.4609735108834587),
#  ('BsmtHalfBath', 1.2604478123056646),
#  ('FullBath', 3.9513658511897707),
#  ('HalfBath', 2.974661677370262),
#  ('BedroomAbvGr', 3.0335840936100014),
#  ('KitchenAbvGr', 4.11031165823016),
#  ('KitchenQual', 2.3441540680357353),
#  ('TotRmsAbvGrd', 5.463451656364143),
#  ('Fireplaces', 1.9124689361275389),
#  ('FireplaceQu', 1.4159112521103094),
#  ('GarageYrBlt', 1259.8133932418154),
#  ('GarageFinish', 2.1719855854403685),
#  ('GarageCars', 6.5316486632060125),
#  ('GarageArea', 6.402843307401114),
#  ('WoodDeckSF', 1.379773799481042),
#  ('OpenPorchSF', 1.517437589312898),
#  ('EnclosedPorch', 1.4269766684415661),
#  ('3SsnPorch', 1.1224083094893098),
#  ('ScreenPorch', 1.202311353891179),
#  ('PoolArea', 16.12262376745357),
#  ('PoolQC', 16.05498097523203),
#  ('Fence', 1.3446582244975278),
#  ('MiscVal', 1.0668746954710355),
#  ('MoSold', 1.1581411700087265),
#  ('YrSold', 1.19490209392985),
#  ('MSSubClassDummy_30', 2.5319816526334),
#  ('MSSubClassDummy_40', 1.5670751449162388),
#  ('MSSubClassDummy_45', inf),
#  ('MSSubClassDummy_50', 22.719555347059767),
#  ('MSSubClassDummy_60', 40.83672406093116),
#  ('MSSubClassDummy_70', 9.856007212460351),
#  ('MSSubClassDummy_75', 18.71568091135874),
#  ('MSSubClassDummy_80', 17.043768210353306),
#  ('MSSubClassDummy_85', 6.704567736990362),
#  ('MSSubClassDummy_90', 4.210643375281387),
#  ('MSSubClassDummy_120', 2.828230562988972),
#  ('MSSubClassDummy_160', 13.134767551229675),
#  ('MSSubClassDummy_180', 2.841347675835618),
#  ('MSSubClassDummy_190', 1.8461974232166822),
#  ('MSZoningDummy_FV', 23.2900307752406),
#  ('MSZoningDummy_RH', 4.330161279376066),
#  ('MSZoningDummy_RL', 66.12519631623475),
#  ('MSZoningDummy_RM', 45.83498826072729),
#  ('AlleyDummy_No_Alley_Access', 2.4897893639237014),
#  ('AlleyDummy_Pave', 2.5399324693241345),
#  ('LotShapeDummy_IR2', 1.284200471784195),
#  ('LotShapeDummy_IR3', 1.10734196336972),
#  ('LotShapeDummy_Reg', 1.5488198795555337),
#  ('LotConfigDummy_CulDSac', 1.7974053657015967),
#  ('LotConfigDummy_FR2', 1.3582123150804843),
#  ('LotConfigDummy_FR3', 1.1047250003348836),
#  ('LotConfigDummy_Inside', 1.7879777380396802),
#  ('NeighborhoodDummy_Blueste', 1.435926490924098),
#  ('NeighborhoodDummy_BrDale', 3.7926530012370856),
#  ('NeighborhoodDummy_BrkSide', 8.381658346532983),
#  ('NeighborhoodDummy_ClearCr', 3.491035374209441),
#  ('NeighborhoodDummy_CollgCr', 13.516740115467986),
#  ('NeighborhoodDummy_Crawfor', 6.323618526834),
#  ('FoundationDummy_Stone', 1.2025890924061018),
#  ('FoundationDummy_Wood', 1.2719289769494504),
#  ('GarageTypeDummy_Attchd', 127.44664785286014),
#  ('GarageTypeDummy_Basment', 8.033130095130225),
#  ('GarageTypeDummy_BuiltIn', 31.225762236677163),
#  ('GarageTypeDummy_CarPort', 3.6618177449688663),
#  ('GarageTypeDummy_Detchd', 103.7909138152536),
#  ('GarageTypeDummy_No_Garage', 1227.4294864222477),
#  ('SaleConditionDummy_AdjLand', 1.072290435671553),
#  ('SaleConditionDummy_Alloca', 1.2239497944044841),
#  ('SaleConditionDummy_Family', 1.3126211498627756),
#  ('SaleConditionDummy_Normal', 2.740390870045555),
#  ('SaleConditionDummy_Partial', 2.9389131619359192),
#  ('MSSubClassDummy_150', nan),
#  ('constant', 131701.18752813898)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 36.805766083242),
#  ('LotArea', 8.544101139384404),
#  ('OverallQual', 76.83901829685396),
#  ('OverallCond', 41.66595508004255),
#  ('YearBuilt', 51988.12254680405),
#  ('YearRemodAdd', 28148.46931980944),
#  ('MasVnrArea', 3.699509428042847),
#  ('ExterQual', 49.79371883245337),
#  ('BsmtQual', 17.52567870570721),
#  ('BsmtExposure', 9.207801390956938),
#  ('BsmtFinType1', 6.144742487775633),
#  ('BsmtFinSF1', 20.124002852158146),
#  ('BsmtFinSF2', 2.3120061187013077),
#  ('BsmtUnfSF', 24.23394316574673),
#  ('1stFlrSF', 109.76449962106526),
#  ('2ndFlrSF', 28.282013350839023),
#  ('LowQualFinSF', 2.0492810159665558),
#  ('BsmtFullBath', 4.218904261972258),
#  ('BsmtHalfBath', 1.3314018588009793),
#  ('FullBath', 36.90991590039587),
#  ('HalfBath', 4.700990718509662),
#  ('BedroomAbvGr', 48.57869359836954),
#  ('KitchenAbvGr', 198.29553763039598),
#  ('KitchenQual', 22.871513241037977),
#  ('TotRmsAbvGrd', 54.63291103869046),
#  ('Fireplaces', 3.680695227980292),
#  ('FireplaceQu', 11.270791162581274),
#  ('GarageYrBlt', 32610.785045265522),
#  ('GarageFinish', 7.437501940656295),
#  ('GarageCars', 49.49531104576806),
#  ('GarageArea', 43.40758080458801),
#  ('WoodDeckSF', 2.2024955608369234),
#  ('OpenPorchSF', 2.3209815458399947),
#  ('EnclosedPorch', 1.5858064481870604),
#  ('3SsnPorch', 1.1370527051320678),
#  ('ScreenPorch', 1.2909465690713668),
#  ('PoolArea', 11.779505041963136),
#  ('PoolQC', 26830.89295852486),
#  ('Fence', 15.623545212931786),
#  ('MiscVal', 1.0723108380214765),
#  ('MoSold', 5.716016000682574),
#  ('YrSold', 3.4295478939534547),
#  ('MSSubClassDummy_30', 2.472289368069573),
#  ('MSSubClassDummy_40', 1.5640685469317708),
#  ('MSSubClassDummy_45', inf),
#  ('MSSubClassDummy_50', 24.62467607669776),
#  ('MSSubClassDummy_60', 51.49005595068493),
#  ('MSSubClassDummy_70', 10.189081932710321),
#  ('MSSubClassDummy_75', 18.85880879197663),
#  ('MSSubClassDummy_80', 17.717944109542238),
#  ('MSSubClassDummy_85', 6.808039526845996),
#  ('MSSubClassDummy_90', 4.262052627206783),
#  ('MSSubClassDummy_120', 3.0163523453446257),
#  ('MSSubClassDummy_160', 13.598364802630968),
#  ('MSSubClassDummy_180', 2.8480415591045634),
#  ('MSSubClassDummy_190', 1.850100733787016),
#  ('MSZoningDummy_FV', 24.30846097175003),
#  ('MSZoningDummy_RH', 4.348124059826165),
#  ('MSZoningDummy_RL', 350.27217867704184),
#  ('MSZoningDummy_RM', 52.72072032925812),
#  ('AlleyDummy_No_Alley_Access', 51.83164705315676),
#  ('AlleyDummy_Pave', 2.587669690149238),
#  ('LotShapeDummy_IR2', 1.3129904170859936),
#  ('LotShapeDummy_IR3', 1.1119412695107014),
#  ('LotShapeDummy_Reg', 4.25193856721528),
#  ('LotConfigDummy_CulDSac', 1.9088496076999166),
#  ('LotConfigDummy_FR2', 1.4036473459696535),
#  ('LotConfigDummy_FR3', 1.1070516072825767),
#  ('LotConfigDummy_Inside', 6.702750442114438),
#  ('NeighborhoodDummy_Blueste', 1.4273852689151836),
#  ('NeighborhoodDummy_BrDale', 3.7680741684501653),
#  ('NeighborhoodDummy_BrkSide', 8.479339709047725),
#  ('NeighborhoodDummy_ClearCr', 3.537422259145998),
#  ('NeighborhoodDummy_CollgCr', 15.243627549991164),
#  ('NeighborhoodDummy_Crawfor', 6.432372678330704),
#  ('NeighborhoodDummy_Edwards', 10.765734407107123),
#  ('NeighborhoodDummy_Gilbert', 8.78573194260282),
#  ('NeighborhoodDummy_IDOTRR', 5.416268462437645),
#  ('NeighborhoodDummy_MeadowV', 3.8577228354948225),
#  ('NeighborhoodDummy_Mitchel', 5.55437351543611),
#  ('NeighborhoodDummy_NAmes', 24.98931764527061),
#  ('NeighborhoodDummy_NPkVill', 2.1429697741133187),
#  ('NeighborhoodDummy_NWAmes', 8.680774177463125),
#  ('NeighborhoodDummy_NoRidge', 5.305951014777447),
#  ('NeighborhoodDummy_NridgHt', 7.460613521517865),
#  ('NeighborhoodDummy_OldTown', 15.473821706834043),
#  ('NeighborhoodDummy_SWISU', 3.9535799100055824),
#  ('NeighborhoodDummy_Sawyer', 9.036710923381715),
#  ('NeighborhoodDummy_SawyerW', 6.292376393804418),
#  ('NeighborhoodDummy_Somerst', 12.30442346298241),
#  ('NeighborhoodDummy_StoneBr', 2.926737688509466),
#  ('NeighborhoodDummy_Timber', 4.361518859289001),
#  ('NeighborhoodDummy_Veenker', 1.8713237301723182),
#  ('HouseStyleDummy_1.5Unf', inf),
#  ('HouseStyleDummy_1Story', 133.24406322517882),
#  ('HouseStyleDummy_2.5Fin', 8.549534417970337),
#  ('HouseStyleDummy_2.5Unf', 11.999919177938365),
#  ('HouseStyleDummy_2Story', 70.99607292348782),
#  ('HouseStyleDummy_SFoyer', 11.771788748714807),
#  ('HouseStyleDummy_SLvl', 23.687435287391423),
#  ('RoofStyleDummy_Gable', 250.2175693610418),
#  ('RoofStyleDummy_Gambrel', 3.3989103736492825),
#  ('RoofStyleDummy_Hip', 62.664721147565444),
#  ('RoofStyleDummy_Mansard', 2.142627685640894),
#  ('RoofStyleDummy_Shed', 1.6967221511130108),
#  ('Exterior1stDummy_AsphShn', 1.283076612735607),
#  ('Exterior1stDummy_BrkComm', 1.1399554598252264),
#  ('Exterior1stDummy_BrkFace', 5.10762302268566),
#  ('Exterior1stDummy_CBlock', 1.222378912266001),
#  ('Exterior1stDummy_CemntBd', 6.493176342561275),
#  ('Exterior1stDummy_HdBoard', 21.772795458634846),
#  ('Exterior1stDummy_ImStucc', 1.1983757378943543),
#  ('Exterior1stDummy_MetalSd', 19.06561761680806),
#  ('Exterior1stDummy_Plywood', 9.836358386230563),
#  ('Exterior1stDummy_Stone', 1.4053045607161077),
#  ('Exterior1stDummy_Stucco', 2.78331534170869),
#  ('Exterior1stDummy_VinylSd', 49.47950717228968),
#  ('Exterior1stDummy_Wd Sdng', 17.544750484457214),
#  ('Exterior1stDummy_WdShing', 3.126267945388122),
#  ('MasVnrTypeDummy_BrkFace', 38.099161768081856),
#  ('MasVnrTypeDummy_No_MasVnr', 1.6341702157812321),
#  ('MasVnrTypeDummy_None', 71.11150999718379),
#  ('MasVnrTypeDummy_Stone', 11.936103071762075),
#  ('FoundationDummy_CBlock', 12.434957485432587),
#  ('FoundationDummy_PConc', 15.15985292665842),
#  ('FoundationDummy_Slab', 1.9049739964484225),
#  ('FoundationDummy_Stone', 1.2036569681640343),
#  ('FoundationDummy_Wood', 1.2573511039752494),
#  ('GarageTypeDummy_Attchd', 343.7170992340345),
#  ('GarageTypeDummy_Basment', 8.124474488538377),
#  ('GarageTypeDummy_BuiltIn', 33.13827718995025),
#  ('GarageTypeDummy_CarPort', 3.670795967751181),
#  ('GarageTypeDummy_Detchd', 139.8972411149222),
#  ('GarageTypeDummy_No_Garage', 1155.7797505004366),
#  ('SaleConditionDummy_AdjLand', 1.0726605687782627),
#  ('SaleConditionDummy_Alloca', 1.2219221365462258),
#  ('SaleConditionDummy_Family', 1.3297571532572166),
#  ('SaleConditionDummy_Normal', 17.14498582324693),
#  ('SaleConditionDummy_Partial', 3.1840571751747233),
#  ('MSSubClassDummy_150', nan)]

# %%
corr = X.corr()

# %%
# Out:
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       1.000000
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999131
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998966
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998875
# PoolArea                  PoolQC                       0.997895
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996030
# GarageCars                GarageArea                   0.989427
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.989099
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.987362
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984758
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.983095
# GrLivArea                 TotRmsAbvGrd                 0.971202
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.970397
# TotalBsmtSF               1stFlrSF                     0.967618
# ExterQual                 KitchenQual                  0.966624
# OverallQual               ExterQual                    0.958958
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.954541
# BsmtQual                  FoundationDummy_PConc        0.952913
# ExterQual                 BsmtQual                     0.952616
# MasVnrArea                MasVnrTypeDummy_None         0.948301
# OverallQual               BsmtQual                     0.948113
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.948033
# 2ndFlrSF                  HouseStyleDummy_2Story       0.946566
# YearRemodAdd              BsmtQual                     0.944306
# OverallQual               GarageCars                   0.942991
#                           KitchenQual                  0.942884
# YearRemodAdd              FoundationDummy_PConc        0.942833
# HalfBath                  HouseStyleDummy_2Story       0.929768
# OverallQual               FullBath                     0.928296
# YearBuilt                 BsmtQual                     0.924828
# FoundationDummy_CBlock    FoundationDummy_PConc        0.924360
# BsmtQual                  KitchenQual                  0.924137
# ExterQual                 FoundationDummy_PConc        0.922817
# YearRemodAdd              ExterQual                    0.922037
# OverallQual               GarageArea                   0.919479
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.916856
# YearBuilt                 YearRemodAdd                 0.915969
# OverallQual               YearRemodAdd                 0.915657
# BsmtFinSF1                BsmtFullBath                 0.912356
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.909509
# HalfBath                  MSSubClassDummy_60           0.908966
# OverallQual               FoundationDummy_PConc        0.907178
# BsmtQual                  GarageCars                   0.907037
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.903814
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.902386
# BsmtQual                  FullBath                     0.900526
# KitchenAbvGr              MSSubClassDummy_90           0.899795
# ExterQual                 GarageCars                   0.898689
# YearRemodAdd              KitchenQual                  0.897307
# dtype: float64
