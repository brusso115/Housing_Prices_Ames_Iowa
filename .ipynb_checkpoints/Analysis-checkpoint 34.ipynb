# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2355.119017677356), ('GrLivArea', 1755.8637514723453), ('GarageCars', 956.5879378302325), ('ExterQual', 919.7973659505656), ('TotalBsmtSF', 871.3987641588595), ('GarageArea', 841.731838761731), ('BsmtQual', 789.547657544028), ('KitchenQual', 779.2963223405732), ('1stFlrSF', 770.8321258121724), ('FullBath', 623.5250667599107), ('TotRmsAbvGrd', 606.4239393672984), ('YearBuilt', 582.8593975210986), ('YearRemodAdd', 462.2250981066734), ('GarageFinish', 330.1138494816384), ('Fireplaces', 323.5541275844534), ('MasVnrArea', 313.4700970511803), ('HeatingQC', 269.02648406229497), ('NeighborhoodDummy_NridgHt', 239.26832431761656), ('BsmtFinSF1', 234.61108990475984), ('MSSubClassDummy_60', 221.74184418715402), ('LotFrontage', 221.3594613484418), ('OpenPorchSF', 200.18538610665058), ('NeighborhoodDummy_NoRidge', 190.5754343332041), ('WoodDeckSF', 167.91965163797857), ('BsmtExposure', 147.39253495240297), ('2ndFlrSF', 145.80939120704156), ('LotArea', 142.3020389996758), ('MSZoningDummy_RM', 125.92342630124824), ('HalfBath', 108.05084849265643), ('LotShapeDummy_Reg', 95.40265776410129), ('BsmtFullBath', 80.66562554183317), ('MSSubClassDummy_30', 74.2537504220517), ('MSZoningDummy_RL', 70.10339032184547), ('GarageYrBlt', 68.59262782951983), ('NeighborhoodDummy_NAmes', 66.04638469574027), ('GarageCond', 57.09791649447835), ('BsmtUnfSF', 56.047695522200804), ('GarageQual', 55.56899725482934), ('NeighborhoodDummy_OldTown', 52.21947436213913), ('NeighborhoodDummy_Edwards', 44.45120827781504), ('BedroomAbvGr', 43.54092826028525), ('PoolQC', 40.606529276926906), ('MSSubClassDummy_50', 40.446631538017996), ('Fence', 40.06291805260037), ('NeighborhoodDummy_Somerst', 32.84452086918843), ('NeighborhoodDummy_StoneBr', 30.990274503159306), ('OverallCond', 30.706502217894194), ('NeighborhoodDummy_Sawyer', 30.43481572452184), ('NeighborhoodDummy_BrkSide', 27.37307506592169), ('NeighborhoodDummy_IDOTRR', 24.99660143487988), ('NeighborhoodDummy_Timber', 24.888142074631524), ('MSSubClassDummy_160', 23.535940442409395), ('EnclosedPorch', 18.83532813308156), ('NeighborhoodDummy_BrDale', 18.456922954304876), ('Condition1Dummy_Norm', 18.38797680728405), ('ExterCond', 18.27465098389338), ('NeighborhoodDummy_MeadowV', 17.665676319411055), ('PoolArea', 17.634343040416084), ('MSSubClassDummy_90', 17.15298370080297), ('LandContourDummy_HLS', 16.71980984355473), ('KitchenAbvGr', 16.308444282370267), ('LotConfigDummy_CulDSac', 16.179363678171093), ('MSZoningDummy_FV', 14.792442106065282), ('Condition1Dummy_Feedr', 14.365774234039181), ('AlleyDummy_No_Alley_Access', 13.00545069144012), ('BsmtFinType2', 10.093330609639935), ('NeighborhoodDummy_CollgCr', 9.975697751764), ('LotConfigDummy_Inside', 8.133203307584385), ('MSSubClassDummy_190', 8.052145952877538), ('BsmtFinType1', 7.839761690173387), ('MSSubClassDummy_45', 7.147771741516416), ('MSSubClassDummy_180', 6.812906061222525), ('BsmtCond', 6.384201991236843), ('NeighborhoodDummy_Veenker', 5.949559147563579), ('MSZoningDummy_RH', 5.906158995256299), ('MoSold', 5.651565892879089), ('NeighborhoodDummy_Mitchel', 5.578384569614968), ('LotShapeDummy_IR2', 5.434829756817482), ('NeighborhoodDummy_SWISU', 5.316178113236065), ('NeighborhoodDummy_ClearCr', 5.028820090536731), ('LowQualFinSF', 4.868496016767766), ('MSSubClassDummy_85', 4.250678238786661), ('ScreenPorch', 3.8603941528498202), ('NeighborhoodDummy_Crawfor', 3.7987375885830708), ('BsmtHalfBath', 3.749273693010969), ('FireplaceQu', 3.4962401625033537), ('Condition1Dummy_PosA', 3.2076835799348125), ('MSSubClassDummy_120', 2.995554622639887), ('LandContourDummy_Low', 2.9101744793640694), ('NeighborhoodDummy_NPkVill', 2.5312408163387503), ('LandContourDummy_Lvl', 2.1887753590309003), ('NeighborhoodDummy_Gilbert', 2.1003999657812367), ('MSSubClassDummy_80', 1.9943027931489965), ('LandSlope', 1.9641895578792532), ('BsmtFinSF2', 1.6202656268993212), ('StreetDummy_Pave', 1.5712513436555067), ('LotShapeDummy_IR3', 1.2236601231760411), ('MiscVal', 1.1485071559 ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.37812576, 0.2297163 ]),
#  'std_fit_time': array([0.11901685, 0.00832988]),
#  'mean_score_time': array([0.01102929, 0.01116629]),
#  'std_score_time': array([0.00180408, 0.0012311 ]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86278544, 0.89371153]),
#  'split1_test_score': array([0.91311175, 0.88974948]),
#  'split2_test_score': array([0.86402092, 0.85685915]),
#  'split3_test_score': array([0.87222254, 0.86480147]),
#  'split4_test_score': array([0.86214318, 0.8428738 ]),
#  'mean_test_score': array([0.87485677, 0.86959909]),
#  'std_test_score': array([0.0194687 , 0.01942685]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8748567672488405

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5609532876467518),
#  ('GrLivArea', 0.12718780238557853),
#  ('BsmtFinSF1', 0.054464645505104346),
#  ('TotalBsmtSF', 0.03903698250443387),
#  ('GarageArea', 0.03689255126707425),
#  ('1stFlrSF', 0.027238523242131222),
#  ('GarageCars', 0.015304655783856976),
#  ('2ndFlrSF', 0.012707918749114772),
#  ('LotArea', 0.009704147195030693),
#  ('YearBuilt', 0.007971530980908598),
#  ('LotFrontage', 0.006900739409353486),
#  ('MasVnrArea', 0.006447506168642746),
#  ('YearRemodAdd', 0.0063367774029012515),
#  ('OpenPorchSF', 0.0050871853114693),
#  ('FullBath', 0.0050254648518434876),
#  ('BsmtUnfSF', 0.004986999554641802),
#  ('GarageYrBlt', 0.004764640349884868),
#  ('OverallCond', 0.004725094789168177),
#  ('WoodDeckSF', 0.004089605904910104),
#  ('BsmtQual', 0.003991372231888121),
#  ('TotRmsAbvGrd', 0.003873450994053889),
#  ('KitchenQual', 0.0030951258611484726),
#  ('MoSold', 0.0024315955189414796),
#  ('BsmtFinType1', 0.002410040844581024),
#  ('GarageFinish', 0.0023609944757223373),
#  ('FunctionalDummy_Typ', 0.002201890103874616),
#  ('BsmtExposure', 0.0021799177871815634),
#  ('FireplaceQu', 0.0017487694088072895),
#  ('Fireplaces', 0.0016572308083039847),
#  ('YrSold', 0.0013690169397804724),
#  ('ExterQual', 0.0012967766523770525),
#  ('LotShapeDummy_IR3', 0.0012110492153285287),
#  ('HalfBath', 0.0011661124223847266),
#  ('BedroomAbvGr', 0.0011341580039351934),
#  ('MSSubClassDummy_50', 0.001124935439158318),
#  ('NeighborhoodDummy_CollgCr', 0.0009478622372888533),
#  ('GarageTypeDummy_CarPort', 0.0008949578464091903),
#  ('BsmtFullBath', 0.0008229695345891161),
#  ('SaleTypeDummy_Oth', 0.0008068512213876487),
#  ('PoolQC', 0.0007563139989552659),
#  ('HeatingQC', 0.0007475766896965325),
#  ('MSZoningDummy_RL', 0.0007354595948949839),
#  ('SalePrice', 0.0005604736492428865),
#  ('EnclosedPorch', 0.0005374033405710497),
#  ('Condition1Dummy_RRAn', 1.20790487160543e-06),
#  ('BldgTypeDummy_TwnhsE', 1.1505401351875454e-06),
#  ('SaleTypeDummy_CWD', 1.086718405821866e-06),
#  ('MSSubClassDummy_30', 1.0719477369952879e-06),
#  ('NeighborhoodDummy_Blueste', 1.0208608621370916e-06),
#  ('Exterior1stDummy_BrkFace', 9.708737769112673e-07),
#  ('RoofStyleDummy_Hip', 6.807619104871912e-07),
#  ('FoundationDummy_Slab', 5.334833268110987e-07),
#  ('Condition1Dummy_RRNn', 5.290616064547091e-07),
#  ('Exterior1stDummy_Plywood', 4.004191934079736e-07),
#  ('MSZoningDummy_RM', 2.947137288767662e-07),
#  ('SaleTypeDummy_New', 2.7605278744454924e-07),
#  ('SaleTypeDummy_WD', 2.245002180514422e-07),
#  ('Exterior1stDummy_HdBoard', 1.946743541873236e-07),
#  ('HouseStyleDummy_2.5Fin', 1.51299051466009e-07),
#  ('RoofMatlDummy_Metal', 9.263685247423649e-08),
#  ('MiscFeatureDummy_No_Misc_Feature', 8.81202386629163e-08),
#  ('LotConfigDummy_Inside', 5.7437351692049565e-08),
#  ('Exterior2ndDummy_BrkFace', 4.560885196363592e-08),
#  ('LandContourDummy_Lvl', 6.8092811273718956e-09),
#  ('RoofMatlDummy_WdShngl', 3.240214038372319e-09),
#  ('Condition2Dummy_RRAn', 1.0557515370429324e-11),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02927456, 0.00547857, 0.00498757, 0.00475535, 0.00488391,
#         0.00547462, 0.00502224, 0.00494342]),
#  'std_fit_time': array([0.0481013 , 0.00011347, 0.0001015 , 0.00018518, 0.0001277 ,
#         0.00011531, 0.0001522 , 0.0002485 ]),
#  'mean_score_time': array([0.00286021, 0.0028224 , 0.00260921, 0.00245881, 0.0026895 ,
#         0.00287638, 0.00272098, 0.00257816]),
#  'std_score_time': array([2.98384737e-04, 7.42190565e-05, 7.30634348e-05, 2.68199687e-04,
#         5.30567002e-05, 1.47567164e-04, 1.14591281e-04, 8.68163993e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.88653309, 0.88850835, 0.89285532, 0.89780811, 0.89943548,
#         0.90065339, 0.89750225, 0.87901735]),
#  'split1_test_score': array([0.8990255 , 0.90196223, 0.90686678, 0.90867145, 0.9086567 ,
#         0.90852826, 0.89131131, 0.86587705]),
#  'split2_test_score': array([0.86191038, 0.87406049, 0.87917862, 0.88028416, 0.87976044,
#  ('OverallCond', 4576.785956384778),
#  ('BsmtQual', -4423.605728127138),
#  ('YearBuilt', 4251.034156094675),
#  ('KitchenQual', -4033.193195166278),
#  ('MasVnrArea', 4019.9896738944394),
#  ('FunctionalDummy_Sev', 3748.1516154883775),
#  ('GarageCars', 3722.0673448062594),
#  ('NeighborhoodDummy_NWAmes', 3706.581361987812),
#  ('NeighborhoodDummy_Somerst', 3404.9592270359926),
#  ('ExterQual', -3382.4613663939563),
#  ('SaleTypeDummy_ConLw', 3311.2719667694487),
#  ('Condition1Dummy_Feedr', 2832.7288601108066),
#  ('Exterior1stDummy_BrkComm', 2816.350095508997),
#  ('TotRmsAbvGrd', 2773.635552537142),
#  ('NeighborhoodDummy_NPkVill', -2737.2159016452138),
#  ('PoolArea', -2568.0903637956976),
#  ('BldgTypeDummy_Duplex', -2417.705329996317),
#  ('BsmtExposure', -2289.315580652053),
#  ('BldgTypeDummy_Twnhs', -2214.9206967025375),
#  ('BedroomAbvGr', -2190.324626466867),
#  ('WoodDeckSF', 2170.1549234693307),
#  ('SaleConditionDummy_Family', 2139.7471492726213),
#  ('Exterior2ndDummy_CBlock', 2124.174819078842),
#  ('LotShapeDummy_Reg', 2114.7266769581865),
#  ('NeighborhoodDummy_Crawfor', -2101.28397788186),
#  ('MSSubClassDummy_90', -2086.2638080733946),
#  ('NeighborhoodDummy_Mitchel', -2030.127653175208),
#  ('OpenPorchSF', 1972.9200705181554),
#  ('FoundationDummy_CBlock', 1951.8199911090821),
#  ('LotFrontage', 1937.5998335711897),
#  ('SaleConditionDummy_Normal', 1912.8834294218982),
#  ('NeighborhoodDummy_CollgCr', 1910.904716257208),
#  ('NeighborhoodDummy_Edwards', -1910.3492730938344),
#  ('MasVnrTypeDummy_No_MasVnr', 1889.1270137623844),
#  ('UtilitiesDummy_NoSeWa', 1858.8047287691427),
#  ('KitchenAbvGr', -1850.4360957038393),
#  ('NeighborhoodDummy_MeadowV', -1840.8787806221355),
#  ('MSSubClassDummy_120', -1796.3321722188325),
#  ('NeighborhoodDummy_ClearCr', -1768.1887201645113),
#  ('GarageArea', 1726.727228529864),
#  ('MiscFeatureDummy_TenC', 1687.9800416535306),
#  ('HouseStyleDummy_1Story', -1673.854427276612),
#  ('Exterior1stDummy_VinylSd', -1617.8766556388184),
#  ('HouseStyleDummy_2.5Unf', -1613.1061029041516),
#  ('BsmtUnfSF', -1604.0723310821868),
#  ('Exterior2ndDummy_Wd Sdng', -1602.5184497249124),
#  ('Fireplaces', 1553.906389897942),
#  ('Condition1Dummy_PosN', -1533.0042969396218),
#  ('MSSubClassDummy_190', 1462.115582038853),
#  ('YearRemodAdd', 1399.3045342579624),
#  ('FunctionalDummy_Mod', -1384.7056312013726),
#  ('Exterior1stDummy_Wd Sdng', 1381.0886883345995),
#  ('NeighborhoodDummy_Blueste', 1358.8886601456004),
#  ('BsmtFullBath', 1329.8850401043776),
#  ('MSSubClassDummy_75', -1319.1611374110923),
#  ('ScreenPorch', 1219.1869752378861),
#  ('MSSubClassDummy_45', -1213.2475436502987),
#  ('FullBath', 1210.7777075549207),
#  ('MasVnrTypeDummy_None', 1206.4940455233427),
#  ('LotConfigDummy_CulDSac', -1204.9326870001678),
#  ('HouseStyleDummy_SFoyer', 1197.2868556890235),
#  ('SaleTypeDummy_CWD', 1191.6371599216563),
#  ('MSZoningDummy_RM', 1188.3644355127942),
#  ('RoofStyleDummy_Mansard', 1186.8677980533837),
#  ('NeighborhoodDummy_OldTown', -1183.7484231778974),
#  ('GarageTypeDummy_CarPort', 1176.2134553941648),
#  ('FoundationDummy_PConc', 1162.8619697415002),
#  ('Exterior2ndDummy_HdBoard', 1117.5589423753804),
#  ('Exterior1stDummy_CBlock', -1112.5934639152074),
#  ('Exterior2ndDummy_CmentBd', -1106.8036061052414),
#  ('SalePrice', -1105.6649836045412),
#  ('NeighborhoodDummy_NridgHt', -1100.3842533027703),
#  ('HeatingQC', -1075.4748575455753),
#  ('LandContourDummy_HLS', -1070.2995854573046),
#  ('FoundationDummy_Stone', -1059.515705841489),
#  ('LandContourDummy_Lvl', -1048.2992629996372),
#  ('Exterior2ndDummy_Other', -1039.048591810588),
#  ('GarageFinish', -990.494400398041),
#  ('FunctionalDummy_Min2', -968.0971995017876),
#  ('NeighborhoodDummy_BrDale', 930.416978617034),
#  ('HalfBath', 914.9115598997025),
#  ('Exterior2ndDummy_VinylSd', 910.2131567367771),
#  ('FunctionalDummy_Min1', 909.4795937976328),
#  ('LotConfigDummy_FR2', -898.8588311740485),
#  ('Exterior1stDummy_HdBoard', -892.8089965717513),
#  ('RoofMatlDummy_WdShake', 884.474369751359),
#  ('Exterior1stDummy_Stone', 854.3367619232381),
#  ('MSZoningDummy_FV', 827.9992321199014),
#  ('NeighborhoodDummy_NAmes', 823.8151037456404),
#  ('HeatingDummy_GasW', -805.4619992244808),
#  ('MSSubClassDummy_180', -799.8624106579603),
#  ('Condition2Dummy_RRNn', -799.86241065794),
#  ('NeighborhoodDummy_Timber', 794.3126426025298),
#  ('MasVnrTypeDummy_Stone', 791.8946703733834),
#  ('NeighborhoodDummy_StoneBr', -787.6905436423415),
#  ('Exterior2ndDummy_Brk Cmn', -782.9875536317038),
#  ('GarageYrBlt', -780.1686148437445),
#  ('MSZoningDummy_RH', 777.9807520157316),
#  ('NeighborhoodDummy_Sawyer', -732.1572667834814),
#  ('RoofMatlDummy_Membran', 709.9039262725172),
#  ('LandSlope', -699.8361175451605),
#  ('PavedDriveDummy_P', 685.6026370304934),
#  ('Exterior1stDummy_ImStucc', 684.6919780215545),
#  ('GarageTypeDummy_Detchd', 684.2823491675372),
#  ('HouseStyleDummy_1.5Unf', 680.1363078456146),
#  ('BsmtCond', 679.825091113949),
#  ('Condition1Dummy_RRAe', 669.3892690521766),
#  ('HouseStyleDummy_2.5Fin', -634.2137494783765),
#  ('RoofMatlDummy_Roll', -632.3745240841029),
#  ('RoofMatlDummy_Tar&Grv', -630.358062322488),
#  ('HouseStyleDummy_2Story', -620.1418199094047),
#  ('SaleTypeDummy_Con', 536.1844742318821),
#  ('ElectricalDummy_SBrkr', -509.72266862550026),
#  ('CentralAirDummy_Y', -503.1850042857186),
#  ('BldgTypeDummy_TwnhsE', 502.5516750894901),
#  ('BsmtFinSF2', 484.954642676869),
#  ('FireplaceQu', -484.73005346691826),
#  ('RoofMatlDummy_Metal', -475.17853585271166),
#  ('HouseStyleDummy_SLvl', -471.1975186075952),
#  ('NeighborhoodDummy_BrkSide', -455.2871325546319),
#  ('Exterior1stDummy_Stucco', -452.0858367151871),
#  ('LotShapeDummy_IR2', -447.8957556796127),
#  ('GarageTypeDummy_BuiltIn', -445.97144644971155),
#  ('Exterior2ndDummy_Plywood', -442.6661517431967),
#  ('BldgTypeDummy_2fmCon', -427.73172297871616),
#  ('MSSubClassDummy_85', -427.7317229787146),
#  ('RoofMatlDummy_WdShngl', -422.78992169303234),
#  ('SaleTypeDummy_WD', 420.82119286519617),
#  ('ElectricalDummy_Mix', -420.23389043062156),
#  ('MSSubClassDummy_80', -416.20437357141253),
#  ('Exterior1stDummy_MetalSd', -413.8125538565612),
#  ('GarageTypeDummy_Basment', 390.5039282931983),
#  ('MoSold', -389.00275935698033),
#  ('Condition1Dummy_RRNn', -388.3593636509936),
#  ('LotShapeDummy_IR3', 385.58331721619874),
#  ('NeighborhoodDummy_Veenker', 379.50705571984855),
#  ('Exterior1stDummy_CemntBd', -369.1617451390226),
#  ('Condition1Dummy_PosA', 359.3296561875191),
#  ('SaleTypeDummy_New', 352.3471943820622),
#  ('AlleyDummy_No_Alley_Access', -352.2192449502694),
#  ('MSSubClassDummy_50', -345.7016646444621),
#  ('Exterior2ndDummy_Stucco', 344.2013634763176),
#  ('Condition2Dummy_Feedr', -338.70833523179454),
#  ('Exterior2ndDummy_AsphShn', 332.0758631795189),
#  ('NeighborhoodDummy_IDOTRR', -330.79350749846355),
#  ('NeighborhoodDummy_SawyerW', 327.30725135209724),
#  ('SaleTypeDummy_ConLD', 312.1953851181124),
#  ('Exterior1stDummy_AsphShn', -310.7048305226601),
#  ('Condition1Dummy_RRAn', -308.4676287933109),
#  ('Exterior2ndDummy_Stone', -306.5366538224875),
#  ('HeatingDummy_Wall', -298.4748482677995),
#  ('MSSubClassDummy_70', 280.38243892002487),
#  ('GarageQual', 277.5211016387559),
#  ('MiscFeatureDummy_Othr', 276.6747176427797),
#  ('Exterior1stDummy_WdShing', 275.08094208287656),
#  ('SaleConditionDummy_Alloca', 267.4517447211217),
#  ('FoundationDummy_Wood', -261.76703773740223),
#  ('Condition2Dummy_RRAn', -259.11993587172145),
#  ('RoofStyleDummy_Shed', 247.08252597412252),
#  ('RoofStyleDummy_Gable', 243.52198081949572),
#  ('RoofStyleDummy_Gambrel', 234.97965463326346),
#  ('Exterior2ndDummy_BrkFace', -230.75279442216794),
#  ('Exterior1stDummy_BrkFace', -230.75279442216285),
#  ('Condition1Dummy_RRNe', 226.72311675505273),
#  ('FunctionalDummy_Typ', -224.74678235922028),
#  ('BsmtHalfBath', -218.19967687929352),
#  ('3SsnPorch', 216.63817189996195),
#  ('Exterior2ndDummy_Wd Shng', -214.9086626480407),
#  ('LandContourDummy_Low', 214.42488565783384),
#  ('Fence', 208.04463004281138),
#  ('HeatingDummy_OthW', -207.53803909606873),
#  ('GarageTypeDummy_Attchd', 207.42988024268087),
#  ('ExterCond', 201.68353011490134),
#  ('LotConfigDummy_Inside', 189.40748205978002),
#  ('BsmtFinType1', 188.87128193488437),
#  ('LowQualFinSF', 185.37612023189317),
#  ('YrSold', -182.26287868661586),
#  ('MSZoningDummy_RL', -167.75024904141614),
#  ('SaleTypeDummy_Oth', 166.23221216836762),
#  ('NeighborhoodDummy_SWISU', -166.0032002106179),
#  ('MasVnrTypeDummy_BrkFace', -165.2231425571231),
#  ('Condition2Dummy_RRAe', -159.29953242930793),
#  ('MiscVal', 139.33299734077843),
#  ('Exterior2ndDummy_MetalSd', -125.46297909488266),
#  ('MiscFeatureDummy_No_Misc_Feature', 124.61082492298863),
#  ('SaleConditionDummy_AdjLand', 119.1741090651921),
#  ('EnclosedPorch', -107.17415618722455),
#  ('MSSubClassDummy_40', -106.64345595358417),
#  ('AlleyDummy_Pave', -104.36028096149653),
#  ('Condition1Dummy_Norm', 98.26777104699435),
#  ('RoofStyleDummy_Hip', 96.45984444288577),
#  ('PavedDriveDummy_Y', -92.71401825840076),
#  ('MSSubClassDummy_30', -88.80681909022299),
#  ('FunctionalDummy_Maj2', 84.04640530170342),
#  ('StreetDummy_Pave', 75.8140974389352),
#  ('SaleTypeDummy_ConLI', -63.0911453540758),
#  ('BsmtFinType2', -59.029801118895065),
#  ('MSSubClassDummy_160', 42.30661523113993),
#  ('GarageTypeDummy_No_Garage', 37.03834230903796),
#  ('Exterior2ndDummy_ImStucc', 27.929847228907402),
#  ('NeighborhoodDummy_Gilbert', 27.294991595414388),
#  ('FoundationDummy_Slab', -24.952724267326875),
#  ('HeatingDummy_GasA', 24.807759666384836),
#  ('LotConfigDummy_FR3', -10.51376486557954),
#  ('MSSubClassDummy_60', -7.838901217208124),
#  ('GarageCond', -6.967507289753866),
#  ('Exterior1stDummy_Plywood', 6.639291873084766),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169980266373.71228, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170269185536.48724, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166951745785.49994, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154537501875.3248, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169937970451.77438, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111343731458.14899, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118491116785.9951, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132771621169.48898, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120105757378.8211, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145161265900.31805, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3404371133.0062866, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 624634589.6889038, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1216479077.0739746, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.2121428 , 0.13196626, 0.11610999, 0.0889658 , 0.05786743,
#         0.05702782, 0.02646809, 0.00762982]),
#  'std_fit_time': array([0.04437125, 0.01174528, 0.00367206, 0.00804527, 0.00400639,
#         0.00797876, 0.03466364, 0.00035267]),
#  'mean_score_time': array([0.0047771 , 0.00283518, 0.00248804, 0.00288858, 0.00268483,
#         0.00312634, 0.0026278 , 0.00251417]),
#  'std_score_time': array([0.00121233, 0.0004434 , 0.00010398, 0.00027811, 0.00012468,
#         0.00032866, 0.0001446 , 0.00017382]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.88570939, 0.88744764, 0.89119605, 0.89634053, 0.89837336,
#         0.8994246 , 0.90140438, 0.89011778]),
#  'split1_test_score': array([0.89914398, 0.90023416, 0.90415164, 0.91170707, 0.91317997,
#         0.91439003, 0.9156924 , 0.90504378]),
#  'split2_test_score': array([0.86801901, 0.86939102, 0.87617278, 0.88092148, 0.88261597,
#         0.88334539, 0.87979295, 0.8692807 ]),
#  'split3_test_score': array([0.85803531, 0.85839049, 0.86116369, 0.86810913, 0.87110905,
#         0.87353363, 0.88488558, 0.87517385]),
#  'split4_test_score': array([0.86152926, 0.86207604, 0.86629968, 0.88044132, 0.88133627,
#         0.88200164, 0.87945657, 0.87091496]),
#  'mean_test_score': array([0.87448739, 0.87550787, 0.87979677, 0.88750391, 0.88932292,
#         0.89053906, 0.89224638, 0.88210622]),
#  'std_test_score': array([0.015584  , 0.0159046 , 0.01590974, 0.01505487, 0.01477555,
#         0.0145715 , 0.01418755, 0.01362434]),
#  'rank_test_score': array([8, 7, 6, 4, 3, 2, 1, 5], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8922463751911899

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 25061.88277821929),
#  ('OverallQual', 13632.057856834084),
#  ('BsmtFinSF1', 9377.904241374903),
#  ('TotalBsmtSF', 6552.145381168525),
#  ('KitchenQual', -4990.819839232581),
#  ('NeighborhoodDummy_NoRidge', 4941.899255181174),
#  ('PoolQC', -4488.466715580993),
#  ('BsmtQual', -4431.344560420424),
#  ('LotArea', 4278.129292412346),
#  ('SaleTypeDummy_ConLw', 4199.893051295092),
#  ('ExterQual', -4117.757090324805),
#  ('OverallCond', 3758.781377309119),
#  ('NeighborhoodDummy_NWAmes', 3670.3531903330695),
#  ('YearBuilt', 3170.7343125446087),
#  ('FunctionalDummy_Sev', 2893.0908206835365),
#  ('GarageCars', 2706.31215349904),
#  ('MasVnrArea', 2368.561842014981),
#  ('NeighborhoodDummy_Somerst', 2206.5071842476905),
#  ('GarageArea', 2064.486814639389),
#  ('KitchenAbvGr', -2059.3576151628386),
#  ('Exterior1stDummy_BrkComm', 1924.4764503016522),
#  ('WoodDeckSF', 1598.3289581240913),
#  ('MSSubClassDummy_120', -1501.2441054871535),
#  ('LotShapeDummy_Reg', 1483.541501265944),
#  ('MSSubClassDummy_90', -1475.2661378361288),
#  ('YearRemodAdd', 1469.260821066883),
#  ('NeighborhoodDummy_CollgCr', 1385.6178032221756),
#  ('Condition1Dummy_Feedr', 1298.231162135806),
#  ('BsmtExposure', -1258.513905034911),
#  ('NeighborhoodDummy_NPkVill', -1252.6374856161706),
#  ('FunctionalDummy_Mod', -1224.0694960758472),
#  ('LotFrontage', 1092.7555544510801),
#  ('OpenPorchSF', 1070.9428885637133),
#  ('NeighborhoodDummy_SawyerW', 1044.7199407345759),
#  ('Fireplaces', 971.4297661114731),
#  ('NeighborhoodDummy_OldTown', -769.9518935653435),
#  ('BldgTypeDummy_Duplex', -700.8325807536986),
#  ('GarageFinish', -595.1345210374463),
#  ('Exterior2ndDummy_Wd Shng', -583.6994447369677),
#  ('HouseStyleDummy_1Story', -554.1413558634218),
#  ('SaleTypeDummy_CWD', 539.0097964551662),
#  ('UtilitiesDummy_NoSeWa', 536.9082367498223),
#  ('MiscFeatureDummy_TenC', 535.5184337202867),
#  ('HeatingQC', -471.6862606756885),
#  ('MSZoningDummy_RL', -466.5749023180924),
#  ('FunctionalDummy_Min2', -452.54425331095024),
#  ('Condition1Dummy_PosN', -429.7893249849037),
#  ('NeighborhoodDummy_Timber', 387.23031049952885),
#  ('BsmtFullBath', 372.42398153601994),
#  ('FoundationDummy_Stone', -349.7587440070796),
#  ('BedroomAbvGr', -238.7638971770049),
#  ('Exterior2ndDummy_CBlock', 224.47723474453312),
#  ('HouseStyleDummy_SLvl', -222.49503060992635),
#  ('BldgTypeDummy_Twnhs', -221.29504212545243),
#  ('NeighborhoodDummy_MeadowV', -220.06440654966542),
#  ('NeighborhoodDummy_BrDale', 182.4176786692199),
#  ('NeighborhoodDummy_NridgHt', -165.93133334516372),
#  ('NeighborhoodDummy_Crawfor', -164.6053629026456),
#  ('LowQualFinSF', -112.70965882493088),
#  ('BldgTypeDummy_2fmCon', -110.09227500717213),
#  ('RoofMatlDummy_Roll', -107.00378512947064),
#  ('Exterior2ndDummy_CmentBd', -101.9869569023216),
#  ('Exterior2ndDummy_Wd Sdng', -41.29900217617777),
#  ('LandSlope', -0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinType2', -0.0),
#  ('BsmtFinSF2', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', -0.0),
#  ('HalfBath', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('FireplaceQu', -0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('ScreenPorch', 0.0),
#  ('PoolArea', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.0),
#  ('YrSold', 0.0),
#  ('SalePrice', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', 0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', 0.0),
#  ('LandContourDummy_Lvl', -0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', -0.0),
#  ('NeighborhoodDummy_Veenker', 0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', -0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', -0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Other', -0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_None', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_CBlock', 0.0),
#  ('FoundationDummy_PConc', 0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('FoundationDummy_Wood', -0.0),
#  ('HeatingDummy_GasA', 0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_Con', -0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', -0.0),
#  ('SaleConditionDummy_AdjLand', -0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', 0.0),
#  ('SaleConditionDummy_Normal', 0.0),
#  ('SaleConditionDummy_Partial', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-38-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8743335924207066

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8879403293109224

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174512654750.20526, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188144039020.7478, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165876280503.50177, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165152462436.34906, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127677047602.1309, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25260166015.94754, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119707265486.8849, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49147181015.425934, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78238532299.30032, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14633841486.414734, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11022926578.686157, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1196517671.8411255, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5655519361.788452, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 727350207.1463623, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8886371693504737

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999174
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.999003
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998790
# GarageYrBlt               GarageTypeDummy_No_Garage    0.995637
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.995600
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.989913
# PoolArea                  PoolQC                       0.988874
# GarageCars                GarageArea                   0.988859
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984813
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.982762
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.981402
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.969695
# GrLivArea                 TotRmsAbvGrd                 0.968262
# ExterQual                 KitchenQual                  0.965069
# TotalBsmtSF               1stFlrSF                     0.964898
# OverallQual               ExterQual                    0.959052
# ExterQual                 BsmtQual                     0.952999
# 2ndFlrSF                  HouseStyleDummy_2Story       0.951020
# OverallQual               BsmtQual                     0.949107
# BsmtQual                  FoundationDummy_PConc        0.948824
# YearRemodAdd              BsmtQual                     0.945901
# MasVnrArea                MasVnrTypeDummy_None         0.942706
# OverallQual               KitchenQual                  0.941655
# YearRemodAdd              FoundationDummy_PConc        0.941235
# FoundationDummy_CBlock    FoundationDummy_PConc        0.938327
# OverallQual               GarageCars                   0.938149
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.933958
# HalfBath                  HouseStyleDummy_2Story       0.933517
# YearBuilt                 BsmtQual                     0.930345
#                           YearRemodAdd                 0.927993
# OverallQual               FullBath                     0.924980
# YearRemodAdd              ExterQual                    0.924955
# ExterQual                 FoundationDummy_PConc        0.924221
# BsmtQual                  KitchenQual                  0.923232
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.920612
# KitchenAbvGr              MSSubClassDummy_90           0.918067
# OverallQual               YearRemodAdd                 0.916555
#                           GarageArea                   0.912982
# HalfBath                  MSSubClassDummy_60           0.911241
# BsmtFinSF1                BsmtFullBath                 0.909249
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.908873
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.908628
# OverallQual               FoundationDummy_PConc        0.906678
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.905836
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.904707
# MSSubClassDummy_60        HouseStyleDummy_2Story       0.904031
# OverallQual               YearBuilt                    0.901116
# BsmtQual                  GarageCars                   0.900867
# 2ndFlrSF                  HalfBath                     0.900029
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.8718538347294227),
#  ('LotArea', 2.1665013479290582),
#  ('OverallQual', 4.791585464278905),
#  ('OverallCond', 2.065806193320574),
#  ('YearBuilt', 15.882889224856672),
#  ('YearRemodAdd', 3.156946102537716),
#  ('MasVnrArea', 2.6930700002870163),
#  ('ExterQual', 3.087582697418259),
#  ('BsmtQual', 3.083760565317482),
#  ('BsmtExposure', 1.834543242492375),
#  ('BsmtFinType1', 2.1886629781784834),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.5284493306960028),
#  ('BsmtHalfBath', 1.304058615071659),
#  ('FullBath', 3.8735828802043266),
#  ('HalfBath', 3.032092559507778),
#  ('BedroomAbvGr', 3.1093403526437116),
#  ('KitchenAbvGr', 4.893422110405443),
#  ('KitchenQual', 2.338368181840174),
#  ('TotRmsAbvGrd', 5.344321011706379),
#  ('Fireplaces', 1.8921208330608235),
#  ('FireplaceQu', 1.4295305652552517),
#  ('GarageYrBlt', 1274.2889524757995),
#  ('GarageFinish', 2.139160309663831),
#  ('GarageCars', 6.620206127747679),
#  ('GarageArea', 6.405146141427465),
#  ('WoodDeckSF', 1.387521232276566),
#  ('OpenPorchSF', 1.4419859879591026),
#  ('EnclosedPorch', 1.5406489081731534),
#  ('3SsnPorch', 1.1211287227062336),
#  ('ScreenPorch', 1.1899531334142337),
#  ('PoolArea', 7.058680549460934),
#  ('PoolQC', 7.347250437095251),
#  ('Fence', 1.3619549187800133),
#  ('MiscVal', 1.0622640610700753),
#  ('MoSold', 1.1438288938448893),
#  ('YrSold', 1.1993542698826165),
#  ('MSSubClassDummy_30', 2.4736081912229664),
#  ('MSSubClassDummy_40', 1.703593354912956),
#  ('MSSubClassDummy_45', 12.534732540242718),
#  ('MSSubClassDummy_50', 20.276009064365816),
#  ('MSSubClassDummy_60', 43.60021130237701),
#  ('MSSubClassDummy_70', 9.15233413242708),
#  ('MSSubClassDummy_75', 13.160170064955441),
#  ('MSSubClassDummy_80', 13.754006435527492),
#  ('MSSubClassDummy_85', 4.783645351919191),
#  ('MSSubClassDummy_90', 5.346210678341917),
#  ('MSSubClassDummy_120', 2.752388268907508),
#  ('Exterior1stDummy_AsphShn', 1.254179511865876),
#  ('Exterior1stDummy_BrkComm', 1.1370138794141877),
#  ('Exterior1stDummy_BrkFace', 4.63168628384111),
#  ('Exterior1stDummy_CBlock', 1.2168657507298333),
#  ('Exterior1stDummy_CemntBd', 5.994722795810772),
#  ('Exterior1stDummy_HdBoard', 17.820365332646485),
#  ('Exterior1stDummy_ImStucc', 1.1968379246895235),
#  ('Exterior1stDummy_MetalSd', 15.485146945403185),
#  ('Exterior1stDummy_Plywood', 9.532808636178615),
#  ('Exterior1stDummy_Stone', 1.3962006886431795),
#  ('Exterior1stDummy_Stucco', 2.2688248099118895),
#  ('Exterior1stDummy_VinylSd', 29.434121965369673),
#  ('Exterior1stDummy_Wd Sdng', 14.062140687249014),
#  ('Exterior1stDummy_WdShing', 3.2299264219330506),
#  ('MasVnrTypeDummy_BrkFace', 25.34702048949752),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7106135339378756),
#  ('MasVnrTypeDummy_None', 28.6864852516218),
#  ('MasVnrTypeDummy_Stone', 10.500465553295928),
#  ('FoundationDummy_CBlock', 7.6179731861663775),
#  ('FoundationDummy_PConc', 8.848151463362493),
#  ('FoundationDummy_Slab', 1.964066211248111),
#  ('FoundationDummy_Stone', 1.1554343786468884),
#  ('FoundationDummy_Wood', 1.2701392161105025),
#  ('GarageTypeDummy_Attchd', 93.8033894820089),
#  ('GarageTypeDummy_Basment', 6.979716714825421),
#  ('GarageTypeDummy_BuiltIn', 22.74180040576112),
#  ('GarageTypeDummy_CarPort', 3.4316435979721565),
#  ('GarageTypeDummy_Detchd', 77.26456776012566),
#  ('GarageTypeDummy_No_Garage', 1240.0346891295144),
#  ('SaleConditionDummy_AdjLand', 1.3693558187237356),
#  ('SaleConditionDummy_Alloca', 1.4563492922102206),
#  ('SaleConditionDummy_Family', 1.3332708870633962),
#  ('SaleConditionDummy_Normal', 2.696350865738206),
#  ('SaleConditionDummy_Partial', 2.7962816716505645),
#  ('MSSubClassDummy_150', nan),
#  ('constant', 100471.81848776716)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF', 'OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 31.516097663938694),
#  ('LotArea', 8.149952870225349),
#  ('OverallCond', 40.61068432186003),
#  ('YearBuilt', 47248.57296973177),
#  ('YearRemodAdd', 28490.70041166801),
#  ('MasVnrArea', 3.6421400749067456),
#  ('ExterQual', 51.04798613527147),
#  ('BsmtQual', 17.20668402705478),
#  ('BsmtExposure', 9.023714843774604),
#  ('BsmtFinType1', 6.097227070078171),
#  ('BsmtFinSF1', 20.599341134982367),
#  ('BsmtFinSF2', 2.301757583743514),
#  ('BsmtUnfSF', 23.355308701947653),
#  ('1stFlrSF', 112.89305133798425),
#  ('2ndFlrSF', 26.8211799886497),
#  ('LowQualFinSF', 1.9212791106678337),
#  ('BsmtFullBath', 4.3568620949281875),
#  ('BsmtHalfBath', 1.3771437605426007),
#  ('FullBath', 34.755980214190146),
#  ('HalfBath', 4.721220833077263),
#  ('BedroomAbvGr', 48.884817504737384),
#  ('KitchenAbvGr', 194.9292334311116),
#  ('KitchenQual', 23.555986439127317),
#  ('TotRmsAbvGrd', 55.0187385957281),
#  ('Fireplaces', 3.6169861843797695),
#  ('FireplaceQu', 11.31924199583359),
#  ('GarageYrBlt', 33888.26606316056),
#  ('GarageFinish', 7.392047362516247),
#  ('GarageCars', 50.597414387002985),
#  ('GarageArea', 43.37784064374568),
#  ('WoodDeckSF', 2.2229063290162374),
#  ('OpenPorchSF', 2.247540554948159),
#  ('EnclosedPorch', 1.6931244876069322),
#  ('3SsnPorch', 1.1353116852050975),
#  ('ScreenPorch', 1.2745525236841035),
#  ('PoolArea', 6.736313254367368),
#  ('PoolQC', 5837.622301835733),
#  ('Fence', 15.67817115102965),
#  ('MiscVal', 1.0646364553723704),
#  ('MoSold', 5.569526480746303),
#  ('YrSold', 3.4433229131911594),
#  ('MSSubClassDummy_30', 2.337732883542865),
#  ('MSSubClassDummy_40', 1.6985726455590178),
#  ('MSSubClassDummy_45', 12.512388072646214),
#  ('MSSubClassDummy_50', 21.552467125308418),
#  ('MSSubClassDummy_60', 54.76231836793237),
#  ('MSSubClassDummy_70', 9.356014348587697),
#  ('MSSubClassDummy_75', 13.211602099142716),
#  ('MSSubClassDummy_80', 14.344984218545605),
#  ('MSSubClassDummy_85', 4.817800615773417),
#  ('MSSubClassDummy_90', 5.476353263558658),
#  ('MSSubClassDummy_120', 2.928656034432346),
#  ('MSSubClassDummy_160', 14.005629325964177),
#  ('MSSubClassDummy_180', 2.5477888784716014),
#  ('MSSubClassDummy_190', 1.89931414351864),
#  ('MSZoningDummy_FV', 26.59098675289898),
#  ('MSZoningDummy_RH', 4.40225952094368),
#  ('MSZoningDummy_RL', 402.5627180391372),
#  ('MSZoningDummy_RM', 57.901340573917224),
#  ('Exterior1stDummy_ImStucc', 1.1960342128479673),
#  ('Exterior1stDummy_MetalSd', 18.141669980954532),
#  ('Exterior1stDummy_Plywood', 10.255461009511455),
#  ('Exterior1stDummy_Stone', 1.3975282576375316),
#  ('Exterior1stDummy_Stucco', 2.2830577543865216),
#  ('Exterior1stDummy_VinylSd', 46.8311430896906),
#  ('Exterior1stDummy_Wd Sdng', 16.08235727018744),
#  ('Exterior1stDummy_WdShing', 3.263097744824269),
#  ('MasVnrTypeDummy_BrkFace', 37.29529642001624),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7186205939122368),
#  ('MasVnrTypeDummy_None', 67.0344403579604),
#  ('MasVnrTypeDummy_Stone', 11.477238318223776),
#  ('FoundationDummy_CBlock', 13.39921421766774),
#  ('FoundationDummy_PConc', 15.420186161120672),
#  ('FoundationDummy_Slab', 1.9651120992814126),
#  ('FoundationDummy_Stone', 1.1539972504431444),
#  ('FoundationDummy_Wood', 1.245571487706318),
#  ('GarageTypeDummy_Attchd', 257.59646423662093),
#  ('GarageTypeDummy_Basment', 7.045796762502163),
#  ('GarageTypeDummy_BuiltIn', 24.04865780847526),
#  ('GarageTypeDummy_CarPort', 3.4323075332204342),
#  ('GarageTypeDummy_Detchd', 102.93685343282843),
#  ('GarageTypeDummy_No_Garage', 1145.3269226908699),
#  ('SaleConditionDummy_AdjLand', 1.3654359724876066),
#  ('SaleConditionDummy_Alloca', 1.4623504866391193),
#  ('SaleConditionDummy_Family', 1.348614154589194),
#  ('SaleConditionDummy_Normal', 16.519557222001268),
#  ('SaleConditionDummy_Partial', 2.989739299924752),
#  ('MSSubClassDummy_150', nan)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# GarageYrBlt                 GarageTypeDummy_No_Garage    0.995991
# MSSubClassDummy_45          HouseStyleDummy_1.5Unf       0.995603
# PoolArea                    PoolQC                       0.991487
# MSSubClassDummy_80          HouseStyleDummy_SLvl         0.989971
# GarageCars                  GarageArea                   0.987995
# RoofStyleDummy_Gable        RoofStyleDummy_Hip           0.982306
# MSZoningDummy_FV            NeighborhoodDummy_Somerst    0.971260
# ExterQual                   KitchenQual                  0.960791
# 2ndFlrSF                    HouseStyleDummy_2Story       0.950216
# ExterQual                   BsmtQual                     0.948992
# BsmtQual                    FoundationDummy_PConc        0.945717
# YearRemodAdd                BsmtQual                     0.940242
# MasVnrArea                  MasVnrTypeDummy_None         0.939399
# YearRemodAdd                FoundationDummy_PConc        0.935278
# FoundationDummy_CBlock      FoundationDummy_PConc        0.934843
# HalfBath                    HouseStyleDummy_2Story       0.931417
# YearBuilt                   BsmtQual                     0.926458
#                             YearRemodAdd                 0.922581
# YearRemodAdd                ExterQual                    0.921259
# Exterior1stDummy_VinylSd    FoundationDummy_PConc        0.920758
# ExterQual                   FoundationDummy_PConc        0.919047
# KitchenAbvGr                MSSubClassDummy_90           0.918477
# BsmtQual                    KitchenQual                  0.915454
# BsmtFinSF1                  BsmtFullBath                 0.909567
# MSSubClassDummy_85          HouseStyleDummy_SFoyer       0.909322
# HalfBath                    MSSubClassDummy_60           0.908706
# GarageTypeDummy_Attchd      GarageTypeDummy_Detchd       0.902738
# MSSubClassDummy_60          HouseStyleDummy_2Story       0.901607
# 2ndFlrSF                    HalfBath                     0.897814
# YearRemodAdd                KitchenQual                  0.894378
#                             Exterior1stDummy_VinylSd     0.892563
# YearBuilt                   FoundationDummy_PConc        0.892007
#                             ExterQual                    0.890433
# MasVnrTypeDummy_BrkFace     MasVnrTypeDummy_None         0.889851
# BsmtQual                    GarageCars                   0.889634
#                             FullBath                     0.888249
# ExterQual                   GarageCars                   0.886406
# MSZoningDummy_RL            MSZoningDummy_RM             0.883317
# KitchenQual                 FoundationDummy_PConc        0.877552
# YearBuilt                   GarageCars                   0.874952
# AlleyDummy_No_Alley_Access  AlleyDummy_Pave              0.874409
# BsmtQual                    Exterior1stDummy_VinylSd     0.873919
# FullBath                    GarageCars                   0.872464
# BsmtQual                    GarageFinish                 0.872189
# YearBuilt                   GarageFinish                 0.870485
# 2ndFlrSF                    HouseStyleDummy_1Story       0.870154
# FullBath                    FoundationDummy_PConc        0.870028
# 2ndFlrSF                    MSSubClassDummy_60           0.866744
# ExterQual                   GarageArea                   0.865623
# YearRemodAdd                FullBath                     0.862193
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188764075930.94214, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209981258682.92303, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186787948758.82248, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195998308860.06723, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174952590616.52545, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31422180565.954407, tolerance: 557912425.0736336
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146301140225.1416, tolerance: 530132343.91688657
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55416123575.52005, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141334653196.63113, tolerance: 533856685.9896065
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1101926411.526184, tolerance: 528044428.8676814
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1549845476.0944214, tolerance: 555286082.3307194
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'ExterQual', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1',
#        ...
#        'FoundationDummy_Wood', 'GarageTypeDummy_Basment',
#        'GarageTypeDummy_BuiltIn', 'GarageTypeDummy_CarPort',
#        'GarageTypeDummy_No_Garage', 'SaleConditionDummy_AdjLand',
#        'SaleConditionDummy_Alloca', 'SaleConditionDummy_Family',
#        'SaleConditionDummy_Normal', 'SaleConditionDummy_Partial'],
#       dtype='object', length=122)

# %%
stats.summary(gridRidge.best_estimator_,X_Scaled.columns[gridRidge.best_estimator_.coef_ != 0], y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-133acf5600c1> in <module>
# ----> 1 stats.summary(gridRidge.best_estimator_,X_Scaled.columns[gridRidge.best_estimator_.coef_ != 0].to_list(), y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in summary(clf, X, y, xlabels)
#     234     """
#     235     # Check and/or make xlabels
# --> 236     ncols = X.shape[1]
#     237     if xlabels is None:
#     238         xlabels = np.array(
#
# AttributeError: 'list' object has no attribute 'shape'
