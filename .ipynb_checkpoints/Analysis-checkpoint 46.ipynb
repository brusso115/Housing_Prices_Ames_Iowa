# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2244.4337074142577), ('GrLivArea', 1507.624801516842), ('GarageCars', 956.7126061011297), ('TotalBsmtSF', 847.8695748258089), ('GarageArea', 838.090144916752), ('ExterQual', 828.8052027277371), ('1stFlrSF', 784.6199263553945), ('KitchenQual', 694.0334107405796), ('FullBath', 671.9820843276249), ('BsmtQual', 653.8123913276563), ('YearBuilt', 585.2501658507829), ('TotRmsAbvGrd', 549.9942042120895), ('YearRemodAdd', 472.22117231400796), ('Fireplaces', 340.1914248930598), ('GarageFinish', 323.5167494430004), ('HeatingQC', 262.4483151753918), ('MasVnrArea', 254.08135610486715), ('MSSubClassDummy_60', 211.39890420624735), ('LotFrontage', 203.62756238153696), ('NeighborhoodDummy_NridgHt', 203.38295842470518), ('BsmtFinSF1', 182.67526834267952), ('OpenPorchSF', 178.26059124297447), ('NeighborhoodDummy_NoRidge', 163.2942784608338), ('MSZoningDummy_RM', 157.1859093276904), ('WoodDeckSF', 152.45498465924265), ('BsmtExposure', 128.4224478506232), ('2ndFlrSF', 119.83771419957948), ('LotArea', 107.66682586369967), ('HalfBath', 95.55443530237864), ('MSZoningDummy_RL', 91.02458767950628), ('LotShapeDummy_Reg', 82.95534919993499), ('MSSubClassDummy_30', 81.3210669184868), ('BsmtFullBath', 75.02069466970006), ('BsmtUnfSF', 74.0534913600136), ('GarageYrBlt', 70.18866674628907), ('NeighborhoodDummy_OldTown', 67.78929699968535), ('NeighborhoodDummy_NAmes', 65.60464905155796), ('GarageCond', 58.51818911930397), ('GarageQual', 57.273929895332145), ('BedroomAbvGr', 50.503759967560946), ('NeighborhoodDummy_Edwards', 45.06299161318806), ('MSSubClassDummy_50', 40.359492221176964), ('NeighborhoodDummy_Somerst', 38.76143005679503), ('NeighborhoodDummy_StoneBr', 38.703717307295186), ('Fence', 35.3311044952157), ('NeighborhoodDummy_Timber', 34.69218421103084), ('NumFloors', 32.76363998721028), ('NeighborhoodDummy_IDOTRR', 32.01660427483551), ('NeighborhoodDummy_BrkSide', 27.428756305410918), ('NeighborhoodDummy_Sawyer', 26.166623432931978), ('OverallCond', 22.768861763607774), ('MSSubClassDummy_160', 22.625052082654367), ('EnclosedPorch', 22.45116061102793), ('ExterCond', 18.69581395622948), ('NeighborhoodDummy_BrDale', 18.366146192498565), ('Condition1Dummy_Norm', 17.742128148385223), ('NeighborhoodDummy_MeadowV', 16.791696388590378), ('MSZoningDummy_FV', 16.71350645229702), ('KitchenAbvGr', 15.818966306807841), ('LandContourDummy_HLS', 15.139886480217234), ('LotConfigDummy_CulDSac', 15.033638047182034), ('AlleyDummy_No_Alley_Access', 14.322073609697153), ('Condition1Dummy_Feedr', 12.5671422834899), ('NeighborhoodDummy_CollgCr', 12.354625626175862), ('MSSubClassDummy_190', 12.148546700196928), ('MSSubClassDummy_45', 11.513769908294137), ('MSSubClassDummy_90', 9.715023474716157), ('MSZoningDummy_RH', 8.333320957040902), ('NeighborhoodDummy_Crawfor', 8.184192277747101), ('BsmtFinType1', 7.167847043973038), ('ScreenPorch', 6.4625185566794014), ('LotShapeDummy_IR2', 6.230996249201943), ('LowQualFinSF', 5.986703226788105), ('BsmtFinType2', 5.7444051837951156), ('MSSubClassDummy_180', 5.432651662697813), ('NeighborhoodDummy_ClearCr', 5.392840883185785), ('NeighborhoodDummy_SWISU', 5.336357856935898), ('LotConfigDummy_Inside', 5.1537304244723225), ('NeighborhoodDummy_Mitchel', 5.13857831897549), ('MSSubClassDummy_120', 4.9328384235029255), ('NeighborhoodDummy_Veenker', 4.902561616050053), ('BsmtHalfBath', 4.849528279636327), ('MSSubClassDummy_85', 4.712443216065339), ('BsmtCond', 4.484951173986357), ('LandContourDummy_Low', 4.2452783202922575), ('Condition1Dummy_PosA', 4.211498682796372), ('MoSold', 3.973353282746449), ('FireplaceQu', 3.8357098682288644), ('NeighborhoodDummy_Gilbert', 3.6373043931541083), ('LandSlope', 3.199254707958413), ('LotShapeDummy_IR3', 2.61155962634406), ('NeighborhoodDummy_NPkVill', 2.554130862379822), ('LandContourDummy_Lvl', 2.019604521822374), ('hasBeenRemodeled', 1.8738064442679359), ('NeighborhoodDummy_NWAmes', 1.4239271865505085), ('MSSubClassDummy_80', 1.3588040598914344), ('NeighborhoodDummy_SawyerW', 1.201143921 ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.45462003, 0.23332958]),
#  'std_fit_time': array([0.06108216, 0.02234936]),
#  'mean_score_time': array([0.01162219, 0.01089482]),
#  'std_score_time': array([0.00181897, 0.00136866]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.84711718, 0.88336998]),
#  'split1_test_score': array([0.87211802, 0.84472957]),
#  'split2_test_score': array([0.85164691, 0.84048145]),
#  'split3_test_score': array([0.87997389, 0.88803309]),
#  'split4_test_score': array([0.87624378, 0.8601244 ]),
#  'mean_test_score': array([0.86541996, 0.8633477 ]),
#  'std_test_score': array([0.01340541, 0.019443  ]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8654199562547893

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.55685883699539),
#  ('GrLivArea', 0.12534058384390503),
#  ('GarageArea', 0.043166867818404536),
#  ('1stFlrSF', 0.04289226469659149),
#  ('TotalBsmtSF', 0.04073328928565331),
#  ('BsmtFinSF1', 0.033752014845155644),
#  ('GarageCars', 0.014864342868632904),
#  ('LotArea', 0.01142422463237961),
#  ('YearRemodAdd', 0.008602915455849883),
#  ('YearBuilt', 0.007546848725621041),
#  ('BsmtUnfSF', 0.007367091387772429),
#  ('LotFrontage', 0.0064332322837236),
#  ('OverallCond', 0.005430660762419666),
#  ('OpenPorchSF', 0.005297681225870707),
#  ('MasVnrArea', 0.00521273056425221),
#  ('WoodDeckSF', 0.00500472759916578),
#  ('GarageYrBlt', 0.0048822683859836066),
#  ('2ndFlrSF', 0.0046939843322874476),
#  ('KitchenQual', 0.003981331685910732),
#  ('MoSold', 0.0031939935155495323),
#  ('GarageFinish', 0.0028569010880718972),
#  ('FullBath', 0.00285007530832441),
#  ('GarageTypeDummy_CarPort', 0.0027279547451804238),
#  ('BsmtExposure', 0.0026611359171258976),
#  ('BsmtQual', 0.002355264376693956),
#  ('BsmtFullBath', 0.0021861158733508775),
#  ('FunctionalDummy_Typ', 0.0021067178818160396),
#  ('TotRmsAbvGrd', 0.0020829678202787584),
#  ('BedroomAbvGr', 0.0019673868894144408),
#  ('Fireplaces', 0.0018905247194622172),
#  ('BsmtFinType1', 0.0018389114770011874),
#  ('FireplaceQu', 0.0018079644831921462),
#  ('YrSold', 0.0017314930154879527),
#  ('ExterQual', 0.0014436010812222807),
#  ('LotShapeDummy_IR3', 0.0012745752074208563),
#  ('EnclosedPorch', 0.0010955414617710025),
#  ('HeatingDummy_Wall', 0.0010523884632834594),
#  ('NeighborhoodDummy_CollgCr', 0.0009374485909340062),
#  ('HalfBath', 0.0009164081934613664),
#  ('LotShapeDummy_Reg', 0.0008692518288724587),
#  ('HeatingQC', 0.0008403821828084347),
#  ('LandSlope', 0.0007787640834152305),
#  ('ScreenPorch', 0.0007778972340002358),
#  ('Condition2Dummy_RRAn', 2.208179225518501e-06),
#  ('MSSubClassDummy_160', 1.9937846055006878e-06),
#  ('BldgTypeDummy_TwnhsE', 1.4094271970967956e-06),
#  ('SaleTypeDummy_WD', 1.1504933235457807e-06),
#  ('SaleTypeDummy_New', 9.40800517406311e-07),
#  ('SaleTypeDummy_Con', 6.388643770787546e-07),
#  ('Exterior1stDummy_BrkFace', 6.306744871576678e-07),
#  ('MSZoningDummy_RM', 6.005293768458582e-07),
#  ('NeighborhoodDummy_Blueste', 5.872257105961668e-07),
#  ('Condition1Dummy_RRAn', 5.584397063145917e-07),
#  ('Exterior2ndDummy_HdBoard', 5.563900644956777e-07),
#  ('ElectricalDummy_FuseP', 5.543260129565173e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 5.121597497234968e-07),
#  ('Exterior2ndDummy_Plywood', 4.427374171951319e-07),
#  ('RoofStyleDummy_Hip', 3.8350123219057006e-07),
#  ('HeatingDummy_OthW', 2.9491237191987255e-07),
#  ('Exterior1stDummy_HdBoard', 1.625416969494751e-07),
#  ('RoofMatlDummy_Metal', 1.5160304119005765e-07),
#  ('ElectricalDummy_FuseF', 1.2115657022049105e-07),
#  ('LotConfigDummy_Inside', 1.0354970177384248e-07),
#  ('Condition1Dummy_RRNn', 5.7573160118656935e-08),
#  ('LandContourDummy_Lvl', 3.2365406321299114e-08),
#  ('Condition2Dummy_RRAe', 2.0264187211307346e-08),
#  ('HeatingDummy_Grav', 1.289168285321564e-08),
#  ('Exterior2ndDummy_BrkFace', 2.1825895115232753e-10),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02326403, 0.00483928, 0.00454111, 0.004916  , 0.00470753,
#         0.00451341, 0.00487919, 0.00497379]),
#  'std_fit_time': array([3.64706961e-02, 2.00811215e-04, 2.83321472e-04, 7.89536939e-05,
#         4.07460725e-04, 3.29106036e-04, 1.16338143e-04, 6.78801771e-05]),
#  'mean_score_time': array([0.00254698, 0.00257487, 0.00245566, 0.00257783, 0.00256205,
#         0.00248194, 0.00261254, 0.00265784]),
#  'std_score_time': array([3.06761852e-04, 1.40467065e-04, 2.37708819e-04, 2.68237554e-04,
#         3.38557740e-04, 3.06973527e-05, 7.74515369e-05, 1.81751911e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.88958792, 0.89166941, 0.89638386, 0.8993336 , 0.90014255,
#         0.90077824, 0.89332718, 0.87207067]),
#  'split1_test_score': array([0.8838528 , 0.88601049, 0.89272655, 0.89715251, 0.89697097,
#         0.89637209, 0.86242558, 0.82639586]),
#  'split2_test_score': array([0.84992876, 0.87210262, 0.8813583 , 0.88653513, 0.8874322 ,
#  ('YearBuilt', 4506.637989046839),
#  ('NeighborhoodDummy_Somerst', 3977.3212159123027),
#  ('NeighborhoodDummy_NWAmes', 3971.9059913279784),
#  ('KitchenQual', -3854.726670613325),
#  ('GarageCars', 3635.0569205190473),
#  ('BsmtQual', -3367.8837966213405),
#  ('ExterQual', -3229.7762743167036),
#  ('FunctionalDummy_Sev', 3052.7744859077366),
#  ('Exterior1stDummy_BrkComm', 2866.9408292621283),
#  ('NeighborhoodDummy_CollgCr', 2700.277940663676),
#  ('SaleTypeDummy_ConLw', 2592.43499146471),
#  ('GarageArea', 2543.5773094718447),
#  ('TotRmsAbvGrd', 2434.4682958700755),
#  ('NeighborhoodDummy_Mitchel', -2431.7742592723284),
#  ('SaleConditionDummy_Family', 2367.810225986502),
#  ('Condition1Dummy_Feedr', 2339.6529687846837),
#  ('MasVnrArea', 2320.8159066626436),
#  ('BldgTypeDummy_Duplex', -2255.9666458622833),
#  ('BldgTypeDummy_Twnhs', -2249.8477603782258),
#  ('MSSubClassDummy_90', -2212.3192841921027),
#  ('NeighborhoodDummy_Crawfor', -2189.403506865583),
#  ('Fireplaces', 2087.611764536473),
#  ('BsmtExposure', -2047.8790333620868),
#  ('YearRemodAdd', 1990.5580798942958),
#  ('NeighborhoodDummy_NPkVill', -1979.4593343500185),
#  ('MSSubClassDummy_120', -1969.5139487867914),
#  ('WoodDeckSF', 1939.3374033070368),
#  ('OpenPorchSF', 1938.8570896519195),
#  ('FoundationDummy_CBlock', 1878.4749161339894),
#  ('Exterior1stDummy_VinylSd', -1849.925509970445),
#  ('ScreenPorch', 1769.1738202413712),
#  ('NeighborhoodDummy_Blueste', 1734.2484484005063),
#  ('NeighborhoodDummy_ClearCr', -1641.2700806902476),
#  ('FullBath', 1618.7890093858346),
#  ('Exterior2ndDummy_CBlock', 1612.3193835667453),
#  ('UtilitiesDummy_NoSeWa', 1598.9794252903162),
#  ('MiscFeatureDummy_TenC', 1598.475414795804),
#  ('LotShapeDummy_Reg', 1581.2687476376218),
#  ('NeighborhoodDummy_NridgHt', -1541.8936441467172),
#  ('LotFrontage', 1537.5019377976932),
#  ('MSSubClassDummy_190', 1533.3102151127262),
#  ('BedroomAbvGr', -1531.8561553641791),
#  ('FunctionalDummy_Mod', -1437.1511810006207),
#  ('NeighborhoodDummy_Edwards', -1425.7047024673695),
#  ('NeighborhoodDummy_MeadowV', -1363.8903033156005),
#  ('MasVnrTypeDummy_None', 1360.053753663114),
#  ('BsmtFullBath', 1319.0431940254164),
#  ('Exterior2ndDummy_Wd Sdng', -1300.5432092358146),
#  ('MSSubClassDummy_75', -1296.066051789368),
#  ('LotConfigDummy_CulDSac', -1212.8724992988898),
#  ('Exterior2ndDummy_Other', -1205.8681465335837),
#  ('Condition1Dummy_PosN', -1202.3763763313068),
#  ('SaleTypeDummy_CWD', 1197.7336041582905),
#  ('FunctionalDummy_Min2', -1173.9536540540976),
#  ('MSZoningDummy_RM', 1123.5021494992222),
#  ('Exterior2ndDummy_CmentBd', -1116.6285646404701),
#  ('LandContourDummy_HLS', -1116.3298716547692),
#  ('NumFloors', -1097.5304804476725),
#  ('BldgTypeDummy_2fmCon', -1073.3593136927698),
#  ('MSSubClassDummy_85', -1073.3593136927611),
#  ('HouseStyleDummy_1Story', -1065.647424096082),
#  ('NeighborhoodDummy_OldTown', -1064.9779330668214),
#  ('SaleConditionDummy_Normal', 1062.8924494508497),
#  ('Exterior1stDummy_CBlock', -1042.194082373469),
#  ('NeighborhoodDummy_BrDale', 1035.1702558421312),
#  ('Exterior1stDummy_Stone', 1029.7003661169208),
#  ('LandContourDummy_Lvl', -1028.6344378835888),
#  ('FoundationDummy_Stone', -1002.5455039540012),
#  ('KitchenAbvGr', -999.1185535845062),
#  ('ExterCond', 989.0504484076087),
#  ('GarageTypeDummy_CarPort', 988.7686600397811),
#  ('FireplaceQu', -976.1770917447633),
#  ('PoolArea', 948.940873500515),
#  ('Exterior2ndDummy_VinylSd', 938.6849925308333),
#  ('HeatingQC', -935.8593100055413),
#  ('GarageFinish', -925.9557357521778),
#  ('MSSubClassDummy_80', -899.4468952958139),
#  ('HalfBath', 896.491859522771),
#  ('NeighborhoodDummy_Timber', 871.2434927359724),
#  ('BsmtUnfSF', -866.9995715597641),
#  ('MasVnrTypeDummy_No_MasVnr', 866.3228503823511),
#  ('MSSubClassDummy_50', 861.688828614501),
#  ('HouseStyleDummy_2.5Unf', -856.2668855465303),
#  ('HouseStyleDummy_SFoyer', 852.2703038186927),
#  ('Exterior1stDummy_ImStucc', 843.7989654877898),
#  ('MSSubClassDummy_180', -826.2180171345516),
#  ('LotConfigDummy_FR2', -821.3864759945621),
#  ('RoofStyleDummy_Mansard', 818.9354915335471),
#  ('hasBeenRemodeled', -814.0507590024245),
#  ('PavedDriveDummy_P', 803.7941132044957),
#  ('GarageTypeDummy_Basment', 799.1555537204239),
#  ('FoundationDummy_PConc', 792.4447581212988),
#  ('HeatingDummy_Grav', -772.0145540860843),
#  ('MSZoningDummy_RH', 771.0840975911252),
#  ('Exterior1stDummy_Wd Sdng', 744.2234133418531),
#  ('Exterior1stDummy_CemntBd', -727.6385162464959),
#  ('SaleTypeDummy_Con', 720.7353453311288),
#  ('NeighborhoodDummy_NAmes', 713.7655665328595),
#  ('Condition2Dummy_RRNn', -704.8539186031626),
#  ('NeighborhoodDummy_SawyerW', 700.692528690756),
#  ('SaleTypeDummy_WD', 687.8831124653004),
#  ('MSSubClassDummy_70', 686.6488435301463),
#  ('Exterior1stDummy_HdBoard', -677.8842379803564),
#  ('BsmtFinSF2', 673.8049147133476),
#  ('Condition1Dummy_PosA', 664.1852857049225),
#  ('BsmtFinType2', -663.9405801023084),
#  ('MasVnrTypeDummy_Stone', 659.3708311366115),
#  ('MSZoningDummy_RL', -648.7217367960724),
#  ('GarageYrBlt', -641.1017606328934),
#  ('SaleConditionDummy_AdjLand', 560.896479199372),
#  ('GarageTypeDummy_Detchd', 551.4971663191122),
#  ('ElectricalDummy_SBrkr', -542.9831962849015),
#  ('FoundationDummy_Slab', -518.0323201527882),
#  ('MSSubClassDummy_60', 508.4169962516637),
#  ('HeatingDummy_GasW', -487.939836399118),
#  ('NeighborhoodDummy_Sawyer', -473.9657341687094),
#  ('Exterior1stDummy_WdShing', 470.5615627283015),
#  ('CentralAirDummy_Y', -468.15949074497735),
#  ('AlleyDummy_Pave', 466.4944164061997),
#  ('BsmtCond', 463.6950077286281),
#  ('LotShapeDummy_IR3', 454.2617205939765),
#  ('NeighborhoodDummy_IDOTRR', -451.0349711575648),
#  ('Exterior2ndDummy_AsphShn', 449.7914076474095),
#  ('HouseStyleDummy_2.5Fin', -446.6060076077422),
#  ('Condition1Dummy_RRNe', 432.63248948863264),
#  ('BsmtHalfBath', -430.7933411955858),
#  ('RoofStyleDummy_Hip', -417.8851482632732),
#  ('SalePrice', 409.9073239657706),
#  ('Exterior2ndDummy_Brk Cmn', -408.2832474016767),
#  ('Exterior2ndDummy_Wd Shng', 407.03295247306164),
#  ('HouseStyleDummy_SLvl', -403.3691817518717),
#  ('HouseStyleDummy_1.5Unf', -399.3689102185713),
#  ('YrSold', -398.58195456401506),
#  ('RoofMatlDummy_WdShake', 397.91822716469676),
#  ('RoofStyleDummy_Gambrel', 391.5127042501969),
#  ('MoSold', -383.2768089412443),
#  ('NeighborhoodDummy_BrkSide', 377.30738263626176),
#  ('Exterior2ndDummy_HdBoard', 374.698441908974),
#  ('PoolQC', 369.8863704037441),
#  ('LandSlope', -350.69586759818884),
#  ('Exterior2ndDummy_Stucco', 346.3309580444862),
#  ('MasVnrTypeDummy_BrkFace', 344.9453409464154),
#  ('RoofStyleDummy_Gable', 337.04011270426656),
#  ('MiscFeatureDummy_Othr', 329.8983592146069),
#  ('EnclosedPorch', 329.1115918951835),
#  ('Exterior1stDummy_MetalSd', -324.2780281334859),
#  ('RoofMatlDummy_Roll', -319.5503441142854),
#  ('LotShapeDummy_IR2', -312.69259935447695),
#  ('HeatingDummy_GasA', -301.39431688573154),
#  ('LotConfigDummy_Inside', 300.6217853567619),
#  ('LowQualFinSF', -293.5830446805063),
#  ('3SsnPorch', 292.4409185124103),
#  ('GarageQual', 291.34269611206105),
#  ('Condition1Dummy_RRAn', -289.2858836528756),
#  ('SaleTypeDummy_ConLI', -286.0645098584402),
#  ('Exterior1stDummy_AsphShn', -284.74013723561706),
#  ('FunctionalDummy_Maj2', -284.6973652176937),
#  ('Condition1Dummy_RRNn', -282.084252835014),
#  ('GarageTypeDummy_No_Garage', -278.70179360353274),
#  ('SaleTypeDummy_New', 276.9143476053715),
#  ('MiscVal', 260.08238713953597),
#  ('Exterior1stDummy_BrkFace', -258.04880151589555),
#  ('Exterior2ndDummy_BrkFace', -258.048801515883),
#  ('FunctionalDummy_Min1', 250.72381341641855),
#  ('ElectricalDummy_FuseP', 198.935178580099),
#  ('StreetDummy_Pave', 193.62577115458583),
#  ('FoundationDummy_Wood', 184.6910277201104),
#  ('Condition1Dummy_RRAe', 182.48037309664497),
#  ('Fence', 179.2039128695202),
#  ('MSZoningDummy_FV', 178.1848589489946),
#  ('ElectricalDummy_Mix', -174.84940496295687),
#  ('HeatingDummy_Wall', -160.32615107017307),
#  ('NeighborhoodDummy_SWISU', -156.67496684278484),
#  ('HeatingDummy_OthW', 149.02375372316135),
#  ('MSSubClassDummy_30', 141.82037043971167),
#  ('LandContourDummy_Low', 140.96975444744862),
#  ('MSSubClassDummy_40', -140.05021317133924),
#  ('GarageCond', 135.85973963392337),
#  ('FunctionalDummy_Typ', 134.12063556928513),
#  ('PavedDriveDummy_Y', -129.2538233860841),
#  ('BldgTypeDummy_TwnhsE', 129.0139905446853),
#  ('MiscFeatureDummy_No_Misc_Feature', 115.73842922742097),
#  ('NeighborhoodDummy_StoneBr', -112.29356475545296),
#  ('SaleTypeDummy_Oth', -110.5091471769357),
#  ('Condition1Dummy_Norm', 106.2657943756611),
#  ('GarageTypeDummy_Attchd', 98.78484510638422),
#  ('SaleTypeDummy_ConLD', -97.55556668178116),
#  ('Condition2Dummy_Feedr', 96.32946336291924),
#  ('Exterior2ndDummy_ImStucc', 89.36809870814761),
#  ('Exterior2ndDummy_MetalSd', -80.62005109865346),
#  ('Exterior2ndDummy_Plywood', 80.36413041054121),
#  ('SaleConditionDummy_Alloca', 72.84597470839064),
#  ('RoofMatlDummy_Tar&Grv', 71.08989489653368),
#  ('BsmtFinType1', -63.747873641297026),
#  ('ElectricalDummy_FuseF', -60.48556872501501),
#  ('RoofMatlDummy_Metal', -56.30103872340184),
#  ('LotConfigDummy_FR3', -52.10424137344165),
#  ('GarageTypeDummy_BuiltIn', -50.792457515997505),
#  ('Condition2Dummy_RRAe', -46.75041362052052),
#  ('NeighborhoodDummy_Veenker', 44.067660145832605),
#  ('Exterior1stDummy_Stucco', 37.852360981111616),
#  ('MSSubClassDummy_160', 34.04042964519026),
#  ('Exterior2ndDummy_Stone', 31.204331187174155),
#  ('Exterior1stDummy_Plywood', 30.21393155616984),
#  ('MSSubClassDummy_45', -29.866364666029952),
#  ('RoofStyleDummy_Shed', 23.66070141570056),
#  ('AlleyDummy_No_Alley_Access', 15.06302241643866),
#  ('HouseStyleDummy_2Story', -13.810450187936638),
#  ('Condition2Dummy_RRAn', 12.23388721972408),
#  ('NeighborhoodDummy_Gilbert', 9.263141222144505),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146265467093.3353, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136018451235.4135, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144933243312.9217, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160899258987.01517, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146589180409.71906, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104813029308.54869, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108469801979.81631, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119885250112.89745, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132522370827.86331, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117290550050.40817, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9596433084.7529, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6146967993.261841, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11650357, 0.1215148 , 0.11614699, 0.09099612, 0.06641669,
#         0.05292535, 0.00865302, 0.00690484]),
#  'std_fit_time': array([0.00632845, 0.00433518, 0.00344729, 0.00726541, 0.00523921,
#         0.00344447, 0.00029298, 0.00059958]),
#  'mean_score_time': array([0.00247383, 0.00254169, 0.00241442, 0.00271492, 0.0028667 ,
#         0.00274639, 0.0024724 , 0.00232158]),
#  'std_score_time': array([9.54614414e-05, 3.44139479e-04, 2.09378507e-04, 4.28665212e-04,
#         1.59965428e-04, 2.91091116e-04, 3.18084448e-04, 3.53708040e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.88945692, 0.88975657, 0.89262522, 0.89875967, 0.90095152,
#         0.90270119, 0.90517677, 0.89030122]),
#  'split1_test_score': array([0.88386254, 0.88443496, 0.88854709, 0.89666044, 0.89826844,
#         0.89855622, 0.89564781, 0.88111326]),
#  'split2_test_score': array([0.85954193, 0.8618507 , 0.87649519, 0.88569019, 0.88889751,
#         0.89014636, 0.88073261, 0.86048672]),
#  'split3_test_score': array([0.88955724, 0.88969657, 0.89077164, 0.8943184 , 0.89632049,
#         0.89777199, 0.90563588, 0.89094055]),
#  'split4_test_score': array([0.89147344, 0.89122334, 0.89021427, 0.89195941, 0.8936601 ,
#         0.89545852, 0.89816092, 0.88612033]),
#  'mean_test_score': array([0.88277842, 0.88339243, 0.88773068, 0.89347762, 0.89561961,
#         0.89692686, 0.8970708 , 0.88179242]),
#  'std_test_score': array([0.01189343, 0.01101545, 0.00576672, 0.00450969, 0.00412221,
#         0.0041193 , 0.00904673, 0.01121796]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 2, 1, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8970707988065886

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 22364.170945676295),
#  ('OverallQual', 12466.643356136286),
#  ('BsmtFinSF1', 7470.319296587145),
#  ('TotalBsmtSF', 6059.45501012284),
#  ('YearBuilt', 5738.818938312547),
#  ('NeighborhoodDummy_NoRidge', 4654.074510355422),
#  ('LotArea', 4495.9751268214595),
#  ('KitchenQual', -4393.682182415534),
#  ('OverallCond', 4021.473701185557),
#  ('ExterQual', -3792.7491746744627),
#  ('NeighborhoodDummy_NWAmes', 3473.05430943844),
#  ('BsmtQual', -3019.961931504901),
#  ('FunctionalDummy_Sev', 2907.566234606971),
#  ('GarageCars', 2870.5462994553204),
#  ('NeighborhoodDummy_Somerst', 2730.4268996868213),
#  ('NeighborhoodDummy_CollgCr', 2655.7567084995226),
#  ('SaleTypeDummy_ConLw', 2567.710429250078),
#  ('GarageArea', 2496.992806046308),
#  ('Exterior1stDummy_BrkComm', 2399.723256931662),
#  ('KitchenAbvGr', -2286.5771774591244),
#  ('YearRemodAdd', 2065.1980386815676),
#  ('Fireplaces', 1738.6604843459563),
#  ('1stFlrSF', 1540.1622741918814),
#  ('NeighborhoodDummy_SawyerW', 1331.3292461747728),
#  ('MSSubClassDummy_120', -1321.298602793754),
#  ('Condition1Dummy_Feedr', 1300.1353197982398),
#  ('MasVnrArea', 1246.2245992699127),
#  ('WoodDeckSF', 1234.8779617625003),
#  ('MSSubClassDummy_90', -1141.6470817939764),
#  ('BldgTypeDummy_Twnhs', -1120.1827113158718),
#  ('LotShapeDummy_Reg', 1114.7131849432776),
#  ('FunctionalDummy_Mod', -1056.925027541742),
#  ('BldgTypeDummy_Duplex', -1036.4766101395057),
#  ('BsmtExposure', -1018.8224393666613),
#  ('OpenPorchSF', 831.3939213884646),
#  ('BsmtFullBath', 744.4663741787449),
#  ('GarageFinish', -734.4718398966243),
#  ('NeighborhoodDummy_BrDale', 678.4594927049947),
#  ('MSZoningDummy_RL', -616.7953084550608),
#  ('LotFrontage', 612.538674341739),
#  ('NeighborhoodDummy_NPkVill', -566.4211128927417),
#  ('MiscFeatureDummy_TenC', 562.77750203024),
#  ('ScreenPorch', 562.4643464460303),
#  ('SaleTypeDummy_CWD', 554.1416570220022),
#  ('UtilitiesDummy_NoSeWa', 551.1440699507316),
#  ('FunctionalDummy_Min2', -522.5934798682936),
#  ('HeatingQC', -489.528006481148),
#  ('BsmtFinType2', -489.16510840264414),
#  ('FoundationDummy_CBlock', 456.0028937140349),
#  ('FireplaceQu', -444.49939792029136),
#  ('NeighborhoodDummy_NridgHt', -427.8483283729124),
#  ('Exterior1stDummy_CemntBd', -401.49513538296134),
#  ('HouseStyleDummy_SLvl', -320.62786116072317),
#  ('NeighborhoodDummy_OldTown', -289.99800201701026),
#  ('Exterior2ndDummy_Wd Sdng', -235.2716972680212),
#  ('MSSubClassDummy_85', -227.21683189412968),
#  ('NeighborhoodDummy_Timber', 211.6776891344767),
#  ('LowQualFinSF', -208.03953984340507),
#  ('Exterior1stDummy_VinylSd', -202.17254470306295),
#  ('HouseStyleDummy_1Story', -175.8729540670165),
#  ('Exterior1stDummy_Stone', 133.4615818345154),
#  ('MasVnrTypeDummy_None', 125.7658984531631),
#  ('FoundationDummy_Stone', -121.13306803211019),
#  ('Condition1Dummy_PosN', -118.87785224009242),
#  ('Exterior2ndDummy_Other', -96.48459347239643),
#  ('SaleConditionDummy_Family', 68.58835217618926),
#  ('HeatingDummy_Grav', -67.65866618861762),
#  ('Exterior2ndDummy_Stucco', 42.01398235696132),
#  ('BldgTypeDummy_2fmCon', -42.00984022044807),
#  ('NeighborhoodDummy_MeadowV', -24.50311941966128),
#  ('LandSlope', -0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtFinSF2', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('BedroomAbvGr', -0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', -0.0),
#  ('SalePrice', 0.0),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', -0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', 0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Crawfor', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_RRAe', -0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', 0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_Tar&Grv', 0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('Exterior1stDummy_AsphShn', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', 0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_CmentBd', -0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Plywood', 0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_PConc', 0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', -0.0),
#  ('ElectricalDummy_FuseP', -0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Typ', 0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_Con', 0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Normal', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8683118057044638

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8941724127740629

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158647935440.7806, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152828336552.93167, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157375205132.80423, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177376400672.35114, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97011988571.35474, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72199379436.37193, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105699201945.61208, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90693568292.74286, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98536075771.66664, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2337788095.4890137, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3474129280.3931885, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6508574929.979858, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8944642550629325

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999145
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998785
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998592
# PoolArea                  PoolQC                       0.997938
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996768
# GarageYrBlt               GarageTypeDummy_No_Garage    0.993901
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.988783
# GarageCars                GarageArea                   0.987570
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.986385
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984921
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.983175
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.969195
# 2ndFlrSF                  NumFloors                    0.968481
# GrLivArea                 TotRmsAbvGrd                 0.967904
# TotalBsmtSF               1stFlrSF                     0.962973
# ExterQual                 KitchenQual                  0.955125
# BsmtQual                  FoundationDummy_PConc        0.952945
# OverallQual               ExterQual                    0.952864
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.950565
# 2ndFlrSF                  HouseStyleDummy_2Story       0.949576
# ExterQual                 BsmtQual                     0.947855
# NumFloors                 HouseStyleDummy_1Story       0.940330
# OverallQual               BsmtQual                     0.938779
# MasVnrArea                MasVnrTypeDummy_None         0.936119
# YearRemodAdd              BsmtQual                     0.935434
#                           FoundationDummy_PConc        0.935112
# OverallQual               KitchenQual                  0.931451
# ExterQual                 FoundationDummy_PConc        0.931346
# OverallQual               GarageCars                   0.930408
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.929850
# HalfBath                  HouseStyleDummy_2Story       0.929349
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.927265
# YearRemodAdd              ExterQual                    0.924196
# OverallQual               FullBath                     0.922868
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.920586
# FoundationDummy_CBlock    FoundationDummy_PConc        0.914874
# BsmtFinSF1                BsmtFullBath                 0.913784
# YearBuilt                 BsmtQual                     0.911067
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.910827
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.909514
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.908960
# BsmtQual                  KitchenQual                  0.908411
# OverallQual               FoundationDummy_PConc        0.906049
#                           YearRemodAdd                 0.905977
# HalfBath                  MSSubClassDummy_60           0.905772
# OverallQual               GarageArea                   0.902723
# YearBuilt                 YearRemodAdd                 0.901488
# KitchenAbvGr              MSSubClassDummy_90           0.899072
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.898986
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.8250497350915307),
#  ('LotArea', 1.7672228993473218),
#  ('OverallQual', 4.493801793005443),
#  ('OverallCond', 2.06767440263414),
#  ('YearBuilt', 17.08869172245497),
#  ('YearRemodAdd', 3.5071770449755464),
#  ('MasVnrArea', 2.6507466111119875),
#  ('ExterQual', 2.8881327096237843),
#  ('BsmtQual', 2.920306369516387),
#  ('BsmtExposure', 1.7993098341493237),
#  ('BsmtFinType1', 2.211450195857495),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.5110585302228317),
#  ('BsmtHalfBath', 1.2772112231338368),
#  ('FullBath', 4.0103851666690264),
#  ('HalfBath', 3.1205571821142293),
#  ('BedroomAbvGr', 3.1475140237637733),
#  ('KitchenAbvGr', 5.286911670300968),
#  ('KitchenQual', 2.227387528953962),
#  ('TotRmsAbvGrd', 5.413297949351153),
#  ('Fireplaces', 1.9206651019264473),
#  ('FireplaceQu', 1.4185509153051095),
#  ('GarageYrBlt', 932.0377627404326),
#  ('GarageFinish', 2.11787630746906),
#  ('GarageCars', 6.231145140687112),
#  ('GarageArea', 6.193445881604161),
#  ('WoodDeckSF', 1.3706552577777196),
#  ('OpenPorchSF', 1.4400957731861217),
#  ('EnclosedPorch', 1.5092879707301319),
#  ('3SsnPorch', 1.116694505363356),
#  ('ScreenPorch', 1.2022326907988423),
#  ('PoolArea', 16.106795679677067),
#  ('PoolQC', 16.052449060740823),
#  ('Fence', 1.3597100026298787),
#  ('MiscVal', 1.073370952913697),
#  ('MoSold', 1.143925588437961),
#  ('YrSold', 1.1980115638687632),
#  ('hasBeenRemodeled', 1.9196383486490798),
#  ('NumFloors', 23.189851588717),
#  ('MSSubClassDummy_30', 2.5277918832265818),
#  ('MSSubClassDummy_40', 1.7704155327429891),
#  ('MSSubClassDummy_45', 15.145139538465477),
#  ('MSSubClassDummy_50', 20.633346338215922),
#  ('MSSubClassDummy_60', 35.15030041695146),
#  ('MSSubClassDummy_70', 8.69067245401829),
#  ('MSSubClassDummy_75', 16.07142116427608),
#  ('MSSubClassDummy_80', 13.962157897714071),
#  ('MSSubClassDummy_85', 5.877697905938744),
#  ('MSSubClassDummy_90', 4.7667431984571245),
#  ('MSSubClassDummy_120', 2.712507816711286),
#  ('MSSubClassDummy_160', 12.31854411920904),
#  ('MSSubClassDummy_180', 2.472648323003294),
#  ('MSSubClassDummy_190', 2.2982528796132886),
#  ('Exterior1stDummy_CBlock', 1.2124646946225834),
#  ('Exterior1stDummy_CemntBd', 5.025472828385286),
#  ('Exterior1stDummy_HdBoard', 15.120041537232474),
#  ('Exterior1stDummy_ImStucc', 1.1795978663781332),
#  ('Exterior1stDummy_MetalSd', 13.59876785770921),
#  ('Exterior1stDummy_Plywood', 8.200484758913552),
#  ('Exterior1stDummy_Stone', 1.219908567704333),
#  ('Exterior1stDummy_Stucco', 2.291701802460061),
#  ('Exterior1stDummy_VinylSd', 25.466742621134056),
#  ('Exterior1stDummy_Wd Sdng', 12.485307641172321),
#  ('Exterior1stDummy_WdShing', 2.509588754685561),
#  ('MasVnrTypeDummy_BrkFace', 25.796038689881208),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7403953476407787),
#  ('MasVnrTypeDummy_None', 29.41035719117601),
#  ('MasVnrTypeDummy_Stone', 9.92905863270154),
#  ('FoundationDummy_CBlock', 7.324650337110031),
#  ('FoundationDummy_PConc', 8.58194960975563),
#  ('FoundationDummy_Slab', 2.1839118887965823),
#  ('FoundationDummy_Stone', 1.3423342696340042),
#  ('FoundationDummy_Wood', 1.2719891139341692),
#  ('GarageTypeDummy_Attchd', 78.13782666790156),
#  ('GarageTypeDummy_Basment', 6.0075642256362105),
#  ('GarageTypeDummy_BuiltIn', 17.725473898693064),
#  ('GarageTypeDummy_CarPort', 2.4703899287758553),
#  ('GarageTypeDummy_Detchd', 65.70746094436763),
#  ('GarageTypeDummy_No_Garage', 901.7635970130084),
#  ('SaleConditionDummy_AdjLand', 1.073285169638667),
#  ('SaleConditionDummy_Alloca', 1.2955263544926239),
#  ('SaleConditionDummy_Family', 1.3418024462749822),
#  ('SaleConditionDummy_Normal', 2.587026408109578),
#  ('SaleConditionDummy_Partial', 2.654348987657091),
#  ('constant', 133685.74239979606)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1457         275           0        877         1152
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1457       2340      1188      1152             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 30.734243465402923),
#  ('LotArea', 4.825022164110603),
#  ('OverallCond', 39.181375546070726),
#  ('YearBuilt', 54617.60154302997),
#  ('YearRemodAdd', 31684.259876550965),
#  ('MasVnrArea', 3.5394597158082886),
#  ('ExterQual', 54.650217933504074),
#  ('BsmtQual', 17.148390830964438),
#  ('BsmtExposure', 9.141464695578485),
#  ('BsmtFinType1', 6.225638159739149),
#  ('BsmtFinSF1', 20.239456156566046),
#  ('BsmtFinSF2', 2.3530216453077566),
#  ('BsmtUnfSF', 24.304934371251765),
#  ('1stFlrSF', 113.86129504425115),
#  ('2ndFlrSF', 31.95836674779235),
#  ('LowQualFinSF', 2.2914310290006608),
#  ('BsmtFullBath', 4.272207756417539),
#  ('BsmtHalfBath', 1.3471022521687324),
#  ('FullBath', 37.504242428433464),
#  ('HalfBath', 4.895124897216271),
#  ('BedroomAbvGr', 49.89825244361354),
#  ('KitchenAbvGr', 229.5423220027035),
#  ('KitchenQual', 23.493911632582552),
#  ('TotRmsAbvGrd', 55.23024082366791),
#  ('Fireplaces', 3.6417093100933893),
#  ('FireplaceQu', 11.45746477131626),
#  ('GarageYrBlt', 33216.846119170375),
#  ('GarageFinish', 7.569481174579583),
#  ('GarageCars', 50.274971290993435),
#  ('GarageArea', 44.7604879666093),
#  ('WoodDeckSF', 2.1830080042443663),
#  ('OpenPorchSF', 2.2200337593455877),
#  ('EnclosedPorch', 1.683566677686867),
#  ('3SsnPorch', 1.1310935713199888),
#  ('ScreenPorch', 1.2863392809700687),
#  ('PoolArea', 11.787572071514541),
#  ('PoolQC', 26853.98337213775),
#  ('Fence', 15.682774053048385),
#  ('MiscVal', 1.0760587612470114),
#  ('MoSold', 5.5728475728811),
#  ('YrSold', 3.4236208190182773),
#  ('hasBeenRemodeled', 3.5684835568121063),
#  ('NumFloors', 523.2388014124375),
#  ('MSSubClassDummy_30', 2.4757473406452797),
#  ('MSSubClassDummy_40', 1.770432124264169),
#  ('MSSubClassDummy_45', 15.139399638184814),
#  ('MSSubClassDummy_50', 22.17709173293891),
#  ('MSSubClassDummy_60', 44.00130244356779),
#  ('MSSubClassDummy_70', 8.900651914130105),
#  ('MSSubClassDummy_75', 16.151593186585167),
#  ('MSSubClassDummy_80', 14.541104650990034),
#  ('MSSubClassDummy_85', 5.9319129354485645),
#  ('MSSubClassDummy_90', 4.8392722632743705),
#  ('MSSubClassDummy_120', 2.888184183548198),
#  ('MSSubClassDummy_160', 12.728515439394487),
#  ('MSSubClassDummy_180', 2.467906094191683),
#  ('MSSubClassDummy_190', 2.3017135614629605),
#  ('MSZoningDummy_FV', 28.56519460442934),
#  ('MSZoningDummy_RH', 5.371184536476983),
#  ('MSZoningDummy_RL', 417.4179406961715),
#  ('MSZoningDummy_RM', 66.32870096820487),
#  ('AlleyDummy_No_Alley_Access', 54.72572782337623),
#  ('AlleyDummy_Pave', 3.067078038916411),
#  ('LotShapeDummy_IR2', 1.2327777118909256),
#  ('Exterior1stDummy_Stucco', 2.3035403088597737),
#  ('Exterior1stDummy_VinylSd', 40.32851870520743),
#  ('Exterior1stDummy_Wd Sdng', 14.376430640942392),
#  ('Exterior1stDummy_WdShing', 2.532744862928312),
#  ('MasVnrTypeDummy_BrkFace', 37.71659482364554),
#  ('MasVnrTypeDummy_No_MasVnr', 1.747157834392666),
#  ('MasVnrTypeDummy_None', 71.10839605081846),
#  ('MasVnrTypeDummy_Stone', 10.746483281815792),
#  ('FoundationDummy_CBlock', 12.678338192777666),
#  ('FoundationDummy_PConc', 14.940146759434086),
#  ('FoundationDummy_Slab', 2.2034219967471493),
#  ('FoundationDummy_Stone', 1.3436388865708173),
#  ('FoundationDummy_Wood', 1.2564754553403412),
#  ('GarageTypeDummy_Attchd', 212.78927830501664),
#  ('GarageTypeDummy_Basment', 6.079842418495245),
#  ('GarageTypeDummy_BuiltIn', 18.67578975084847),
#  ('GarageTypeDummy_CarPort', 2.468364035759586),
#  ('GarageTypeDummy_Detchd', 89.7676210844422),
#  ('GarageTypeDummy_No_Garage', 857.9642641422535),
#  ('SaleConditionDummy_AdjLand', 1.0734037255386686),
#  ('SaleConditionDummy_Alloca', 1.297366506207072),
#  ('SaleConditionDummy_Family', 1.3601653975581516),
#  ('SaleConditionDummy_Normal', 17.07914096790536),
#  ('SaleConditionDummy_Partial', 2.8323768774569755)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# PoolArea                    PoolQC                       0.998071
# MSSubClassDummy_45          HouseStyleDummy_1.5Unf       0.996767
# GarageYrBlt                 GarageTypeDummy_No_Garage    0.994372
# MSSubClassDummy_80          HouseStyleDummy_SLvl         0.988822
# GarageCars                  GarageArea                   0.986691
# RoofStyleDummy_Gable        RoofStyleDummy_Hip           0.984662
# MSZoningDummy_FV            NeighborhoodDummy_Somerst    0.970810
# 2ndFlrSF                    NumFloors                    0.968678
# MSSubClassDummy_85          HouseStyleDummy_SFoyer       0.952053
# ExterQual                   KitchenQual                  0.950059
# BsmtQual                    FoundationDummy_PConc        0.949459
# 2ndFlrSF                    HouseStyleDummy_2Story       0.948764
# ExterQual                   BsmtQual                     0.943666
# NumFloors                   HouseStyleDummy_1Story       0.940418
# MasVnrArea                  MasVnrTypeDummy_None         0.933097
# YearRemodAdd                BsmtQual                     0.928176
#                             FoundationDummy_PConc        0.928028
# HalfBath                    HouseStyleDummy_2Story       0.927135
# ExterQual                   FoundationDummy_PConc        0.926221
# Exterior1stDummy_VinylSd    FoundationDummy_PConc        0.924082
# GarageTypeDummy_Attchd      GarageTypeDummy_Detchd       0.922154
# YearRemodAdd                ExterQual                    0.919900
# BsmtFinSF1                  BsmtFullBath                 0.914048
# FoundationDummy_CBlock      FoundationDummy_PConc        0.909994
# MasVnrTypeDummy_BrkFace     MasVnrTypeDummy_None         0.907847
# YearBuilt                   BsmtQual                     0.905050
# HalfBath                    MSSubClassDummy_60           0.904180
# BsmtQual                    KitchenQual                  0.899404
# KitchenAbvGr                MSSubClassDummy_90           0.899381
# 2ndFlrSF                    HouseStyleDummy_1Story       0.894927
# NumFloors                   HouseStyleDummy_2Story       0.893986
# YearBuilt                   YearRemodAdd                 0.893707
# 2ndFlrSF                    HalfBath                     0.892037
# YearRemodAdd                Exterior1stDummy_VinylSd     0.891101
# MSSubClassDummy_60          HouseStyleDummy_2Story       0.889867
# YearRemodAdd                KitchenQual                  0.889821
# MSZoningDummy_RL            MSZoningDummy_RM             0.887106
# BsmtQual                    Exterior1stDummy_VinylSd     0.885710
# FullBath                    GarageCars                   0.884285
# YearBuilt                   FoundationDummy_PConc        0.880899
# BsmtQual                    GarageCars                   0.880132
#                             FullBath                     0.880038
# YearBuilt                   ExterQual                    0.876027
# MasVnrArea                  MasVnrTypeDummy_BrkFace      0.875535
# KitchenQual                 FoundationDummy_PConc        0.874726
# AlleyDummy_No_Alley_Access  AlleyDummy_Pave              0.871328
# YearBuilt                   GarageFinish                 0.869681
# ExterQual                   GarageCars                   0.867059
# BsmtQual                    GarageFinish                 0.863051
# ExterQual                   Exterior1stDummy_VinylSd     0.861950
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180443809196.03326, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169115384948.48373, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176471896589.17114, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199320013688.64505, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65774621058.309845, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93492537693.0469, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138384530019.47397, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112421011870.90561, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130138634590.34335, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 666742673.0848999, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5402778500.235413, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10251897131.880127, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 1466.8597078432522),
#  ('LotArea', 4325.133401642856),
#  ('OverallCond', 7042.612052748208),
#  ('YearBuilt', 12411.924633691773),
#  ('YearRemodAdd', 820.644321984297),
#  ('MasVnrArea', 2031.1880312488474),
#  ('ExterQual', -4494.244384494926),
#  ('BsmtQual', -3461.9195392305633),
#  ('BsmtExposure', -2461.853297142938),
#  ('BsmtFinType1', 205.22200448356026),
#  ('BsmtFinSF1', 15894.832084029988),
#  ('BsmtFinSF2', 4461.097845386426),
#  ('BsmtUnfSF', 8918.34143343663),
#  ('1stFlrSF', 18222.972638033967),
#  ('2ndFlrSF', 24835.849708945454),
#  ('LowQualFinSF', 1080.10856778085),
#  ('BsmtFullBath', 719.6492482098956),
#  ('BsmtHalfBath', -445.38816990052584),
#  ('FullBath', 146.54428784834062),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -2539.195571591982),
#  ('KitchenAbvGr', -1575.6140830651098),
#  ('KitchenQual', -4887.946883094696),
#  ('TotRmsAbvGrd', 1841.9510097069601),
#  ('Fireplaces', 2442.2574824099465),
#  ('FireplaceQu', -1484.8031002332416),
#  ('GarageYrBlt', -557.9081363582192),
#  ('GarageFinish', -1580.4207285820544),
#  ('GarageCars', 4876.612558057135),
#  ('GarageArea', 1136.9833937131455),
#  ('WoodDeckSF', 1726.440098699867),
#  ('OpenPorchSF', 1349.7156275640775),
#  ('EnclosedPorch', 546.4625646519795),
#  ('3SsnPorch', 214.11288206665844),
#  ('ScreenPorch', 1605.8774277122764),
#  ('PoolArea', 670.4923214035875),
#  ('PoolQC', 0.0),
#  ('Fence', 36.53645583545591),
#  ('MiscVal', 420.84824662318124),
#  ('MoSold', 0.0),
#  ('YrSold', -333.0104982933706),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -1160.322519621357),
#  ('MSSubClassDummy_30', -350.3550328092528),
#  ('MSSubClassDummy_40', 254.9380144632179),
#  ('MSSubClassDummy_45', 548.9401732129929),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_70', 1618.9325322194618),
#  ('MSSubClassDummy_75', 741.6121043139387),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -914.6362610929436),
#  ('MSSubClassDummy_90', -1906.7859586097702),
#  ('MSSubClassDummy_120', -4396.746357214053),
#  ('MSSubClassDummy_160', -5302.721552805475),
#  ('MSSubClassDummy_180', -511.51486704152137),
#  ('MSSubClassDummy_190', -797.6448975406937),
#  ('MSZoningDummy_FV', 2037.1407942564133),
#  ('MSZoningDummy_RH', 180.3097351878899),
#  ('MSZoningDummy_RL', 0.0),
#  ('MSZoningDummy_RM', -1463.2689579634164),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', 536.0683532003359),
#  ('LotShapeDummy_IR3', -318.7362894933231),
#  ('LotShapeDummy_Reg', 747.0940420186994),
#  ('LotConfigDummy_CulDSac', 1443.618609494295),
#  ('LotConfigDummy_FR2', -1127.4432052476263),
#  ('LotConfigDummy_FR3', -754.0850276673123),
#  ('LotConfigDummy_Inside', -201.34132578366425),
#  ('NeighborhoodDummy_Blueste', 490.9255263063659),
#  ('NeighborhoodDummy_BrDale', 2943.665162903252),
#  ('NeighborhoodDummy_BrkSide', 1550.5009160005202),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_CollgCr', -114.03166994620823),
#  ('NeighborhoodDummy_Crawfor', 3668.981484958842),
#  ('NeighborhoodDummy_Edwards', -1804.7919233252512),
#  ('NeighborhoodDummy_Gilbert', -352.15715896654876),
#  ('NeighborhoodDummy_IDOTRR', 605.8130815257737),
#  ('NeighborhoodDummy_MeadowV', 0.0),
#  ('NeighborhoodDummy_Mitchel', -1049.8403111368625),
#  ('NeighborhoodDummy_NAmes', -1204.4092793636587),
#  ('NeighborhoodDummy_NPkVill', 1989.3669245026788),
#  ('NeighborhoodDummy_NWAmes', -963.8502595574593),
#  ('NeighborhoodDummy_NoRidge', 4817.67475175397),
#  ('NeighborhoodDummy_NridgHt', 6429.521650219731),
#  ('NeighborhoodDummy_OldTown', -821.2766179954293),
#  ('NeighborhoodDummy_SWISU', -525.0970344416165),
#  ('NeighborhoodDummy_Sawyer', -154.95216186321053),
#  ('NeighborhoodDummy_SawyerW', -19.36278671522483),
#  ('NeighborhoodDummy_Somerst', 2193.4360826652523),
#  ('NeighborhoodDummy_StoneBr', 5501.334679316519),
#  ('NeighborhoodDummy_Timber', 778.4340747163544),
#  ('NeighborhoodDummy_Veenker', 986.7634971207494),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_1Story', -0.0),
#  ('HouseStyleDummy_2.5Fin', -1254.784534131363),
#  ('HouseStyleDummy_2.5Unf', -368.1169382683322),
#  ('HouseStyleDummy_2Story', -2086.6692621297148),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('HouseStyleDummy_SLvl', 135.66372048266703),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 319.78984031395373),
#  ('RoofStyleDummy_Hip', 1057.783543313589),
#  ('RoofStyleDummy_Mansard', -0.0),
#  ('RoofStyleDummy_Shed', 466.0587445239529),
#  ('Exterior1stDummy_AsphShn', 0.0),
#  ('Exterior1stDummy_BrkComm', -747.9563182575204),
#  ('Exterior1stDummy_BrkFace', 3130.0954128035264),
#  ('Exterior1stDummy_CBlock', -837.895447707231),
#  ('Exterior1stDummy_CemntBd', 42.17161678330981),
#  ('Exterior1stDummy_HdBoard', -1511.0575598630655),
#  ('Exterior1stDummy_ImStucc', -347.36382417272137),
#  ('Exterior1stDummy_MetalSd', 889.2973450025377),
#  ('Exterior1stDummy_Plywood', -975.4760410829489),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 1576.0268466447237),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 198.2792935317785),
#  ('MasVnrTypeDummy_BrkFace', 163.98804687374994),
#  ('MasVnrTypeDummy_No_MasVnr', 157.79318335581945),
#  ('MasVnrTypeDummy_None', 0.0),
#  ('MasVnrTypeDummy_Stone', 1156.5225568735275),
#  ('FoundationDummy_CBlock', -495.1052148262315),
#  ('FoundationDummy_PConc', 1969.629621422785),
#  ('FoundationDummy_Slab', 500.68365485928746),
#  ('FoundationDummy_Stone', -575.0578996744308),
#  ('FoundationDummy_Wood', -1033.7976205962193),
#  ('GarageTypeDummy_Attchd', 318.394653696915),
#  ('GarageTypeDummy_Basment', -0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -1467.487807724229),
#  ('GarageTypeDummy_Detchd', 274.67783968496497),
#  ('GarageTypeDummy_No_Garage', 0.0),
#  ('SaleConditionDummy_AdjLand', 721.0305127761175),
#  ('SaleConditionDummy_Alloca', 774.8303137807426),
#  ('SaleConditionDummy_Family', 386.65360281248246),
#  ('SaleConditionDummy_Normal', 2519.753058102826),
#  ('SaleConditionDummy_Partial', 3527.463630845695)]

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147036879467.89636, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165191594917.812, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136897846047.90979, tolerance: 469343258.8767608
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 198351100253.72025, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153997725782.16953, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1206290556.746521, tolerance: 468976472.4010471
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65445057660.981125, tolerance: 427668229.72581315
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123654301281.8817, tolerance: 489329027.4394335
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10956847653.194946, tolerance: 458591459.99849004
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8873278723257464

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 1505.33637352526),
#  ('LotArea', 4313.829875811851),
#  ('OverallCond', 7053.089078777541),
#  ('YearBuilt', 12421.458136655356),
#  ('YearRemodAdd', 819.9455759520617),
#  ('MasVnrArea', 2021.4434014261658),
#  ('ExterQual', -4504.897991593474),
#  ('BsmtQual', -3384.81016017435),
#  ('BsmtExposure', -2462.682606272188),
#  ('BsmtFinType1', 204.09001707064564),
#  ('BsmtFinSF1', 15874.299580781144),
#  ('BsmtFinSF2', 4467.516607537335),
#  ('BsmtUnfSF', 8904.674220094743),
#  ('1stFlrSF', 18439.76161376813),
#  ('2ndFlrSF', 25031.54209664241),
#  ('LowQualFinSF', 1095.002071919534),
#  ('BsmtFullBath', 786.9327311853812),
#  ('BsmtHalfBath', -462.83430314420195),
#  ('FullBath', 57.831755037452446),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -2535.2574454378373),
#  ('KitchenAbvGr', -1517.8435936349422),
#  ('KitchenQual', -4903.911825009684),
#  ('TotRmsAbvGrd', 1688.0375695540959),
#  ('Fireplaces', 2427.576684512513),
#  ('FireplaceQu', -1514.709422366199),
#  ('GarageYrBlt', -0.0),
#  ('GarageFinish', -1613.843465735221),
#  ('GarageCars', 5709.611006793797),
#  ('WoodDeckSF', 1758.0125264089113),
#  ('OpenPorchSF', 1332.5382454919788),
#  ('EnclosedPorch', 558.6952827767719),
#  ('3SsnPorch', 229.0649856065734),
#  ('ScreenPorch', 1595.2711739415122),
#  ('Fence', 0.0),
#  ('MiscVal', 421.4895010550773),
#  ('MoSold', -0.0),
#  ('YrSold', -357.34078431832046),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -1235.8520011438195),
#  ('MSSubClassDummy_30', -356.006279425289),
#  ('MSSubClassDummy_40', 238.19978166044302),
#  ('MSSubClassDummy_45', 522.7733631612869),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', -0.0),
#  ('MSSubClassDummy_70', 1588.9556849684795),
#  ('MSSubClassDummy_75', 656.9242351977364),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -915.6282295110341),
#  ('MSSubClassDummy_90', -1944.8234164710645),
#  ('MSSubClassDummy_120', -4524.412999640225),
#  ('MSSubClassDummy_160', -5409.880034717744),
#  ('MSSubClassDummy_180', -525.160797099467),
#  ('MSSubClassDummy_190', -798.5812577765311),
#  ('MSZoningDummy_FV', 2045.88212455769),
#  ('MSZoningDummy_RH', 207.48903700801412),
#  ('MSZoningDummy_RL', 0.0),
#  ('MSZoningDummy_RM', -1513.841974221282),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', 534.0695699509198),
#  ('LotShapeDummy_IR3', -315.54749133820155),
#  ('LotShapeDummy_Reg', 768.0103415849692),
#  ('LotConfigDummy_CulDSac', 1435.2373273450278),
#  ('LotConfigDummy_FR2', -1143.5189573902949),
#  ('LotConfigDummy_FR3', -756.8035382943294),
#  ('LotConfigDummy_Inside', -177.7561733365623),
#  ('NeighborhoodDummy_Blueste', 490.41903729079735),
#  ('NeighborhoodDummy_BrDale', 2970.057678214245),
#  ('NeighborhoodDummy_BrkSide', 1501.228128183148),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_CollgCr', -107.28090761282355),
#  ('NeighborhoodDummy_Crawfor', 3594.472799644807),
#  ('NeighborhoodDummy_Edwards', -1870.7408950235738),
#  ('NeighborhoodDummy_Gilbert', -490.11397241056954),
#  ('NeighborhoodDummy_IDOTRR', 624.7556749259286),
#  ('NeighborhoodDummy_MeadowV', 0.0),
#  ('NeighborhoodDummy_Mitchel', -1015.0540794141119),
#  ('NeighborhoodDummy_NAmes', -1293.167638993966),
#  ('NeighborhoodDummy_NPkVill', 1988.6905555858825),
#  ('NeighborhoodDummy_NWAmes', -950.3986932582221),
#  ('NeighborhoodDummy_NoRidge', 4815.3659664345205),
#  ('NeighborhoodDummy_NridgHt', 6513.392620889869),
#  ('NeighborhoodDummy_OldTown', -842.1242711254366),
#  ('NeighborhoodDummy_SWISU', -560.9686429147458),
#  ('NeighborhoodDummy_Sawyer', -238.59624437645965),
#  ('NeighborhoodDummy_SawyerW', -70.70486315512386),
#  ('NeighborhoodDummy_Somerst', 2259.714675474236),
#  ('NeighborhoodDummy_StoneBr', 5500.739026184622),
#  ('NeighborhoodDummy_Timber', 758.2894770609817),
#  ('NeighborhoodDummy_Veenker', 963.064469947233),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_1Story', -0.0),
#  ('HouseStyleDummy_2.5Fin', -1170.7899387530206),
#  ('HouseStyleDummy_2.5Unf', -332.07537941726457),
#  ('HouseStyleDummy_2Story', -2037.3506047631447),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('HouseStyleDummy_SLvl', 211.02823412865683),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 299.9780552239732),
#  ('RoofStyleDummy_Hip', 1064.7174904620463),
#  ('RoofStyleDummy_Mansard', -0.0),
#  ('RoofStyleDummy_Shed', 457.06773812283797),
#  ('Exterior1stDummy_AsphShn', 0.0),
#  ('Exterior1stDummy_BrkComm', -738.4258579331002),
#  ('Exterior1stDummy_BrkFace', 3100.56511226213),
#  ('Exterior1stDummy_CBlock', -840.1713155723024),
#  ('Exterior1stDummy_CemntBd', 72.37395261654892),
#  ('Exterior1stDummy_HdBoard', -1478.6915482144964),
#  ('Exterior1stDummy_ImStucc', -360.2672550353763),
#  ('Exterior1stDummy_MetalSd', 910.6078600102059),
#  ('Exterior1stDummy_Plywood', -913.0473316999422),
#  ('Exterior1stDummy_Stone', -0.0),
#  ('Exterior1stDummy_Stucco', 1589.9204877301056),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 185.03803553547286),
#  ('MasVnrTypeDummy_BrkFace', 142.0550557143101),
#  ('MasVnrTypeDummy_No_MasVnr', 139.5268590280753),
#  ('MasVnrTypeDummy_None', 0.0),
#  ('MasVnrTypeDummy_Stone', 1148.8850921728001),
#  ('FoundationDummy_CBlock', -504.70548405121104),
#  ('FoundationDummy_PConc', 1972.1174272338978),
#  ('FoundationDummy_Slab', 481.84361422626677),
#  ('FoundationDummy_Stone', -562.7655891904469),
#  ('FoundationDummy_Wood', -1031.5286825222531),
#  ('GarageTypeDummy_Attchd', 316.3935747314795),
#  ('GarageTypeDummy_Basment', -0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -1463.6490570143258),
#  ('GarageTypeDummy_Detchd', 316.9098504112674),
#  ('GarageTypeDummy_No_Garage', 455.14965486051125),
#  ('SaleConditionDummy_AdjLand', 716.8348723766807),
#  ('SaleConditionDummy_Alloca', 761.1357354596475),
#  ('SaleConditionDummy_Family', 388.5203559445023),
#  ('SaleConditionDummy_Normal', 2558.7477066379683),
#  ('SaleConditionDummy_Partial', 3580.383834673121)]

# %%
stats.coef_pval(gridLasso.best_estimator_, X_Scaled, y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-68-1efe47c205a1> in <module>
# ----> 1 stats.coef_pval(gridLasso.best_estimator_, X_Scaled, y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in coef_pval(clf, X, y)
#     190     """
#     191     n = X.shape[0]
# --> 192     t = coef_tval(clf, X, y)
#     193     p = 2 * (1 - scipy.stats.t.cdf(abs(t), n - 1))
#     194     return p
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in coef_tval(clf, X, y)
#     167         An array of t-statistic values.
#     168     """
# --> 169     a = np.array(clf.intercept_ / coef_se(clf, X, y)[0])
#     170     b = np.array(clf.coef_ / coef_se(clf, X, y)[1:])
#     171     return np.append(a, b)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in coef_se(clf, X, y)
#     145     se_matrix = scipy.linalg.sqrtm(
#     146         metrics.mean_squared_error(y, clf.predict(X)) *
# --> 147         np.linalg.inv(X1.T * X1)
#     148     )
#     149     return np.diagonal(se_matrix)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
