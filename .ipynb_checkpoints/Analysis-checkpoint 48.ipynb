# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')
train_ord = pd.read_csv('train_filled_na_ord.csv')

# %%
train.drop('Id', axis = 1, inplace=True)
train_ord

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2396.4386124222024), ('GrLivArea', 1540.3828402943886), ('GarageCars', 1025.6193008332032), ('ExterQual', 1009.2177388041181), ('GarageArea', 926.128519392264), ('TotalBsmtSF', 902.9018467118926), ('BsmtQual', 794.2952914448382), ('1stFlrSF', 792.6570940904136), ('KitchenQual', 787.9953583598437), ('FullBath', 676.319483398524), ('YearBuilt', 642.586092039924), ('TotRmsAbvGrd', 553.2445269297281), ('YearRemodAdd', 499.1113301654399), ('Fireplaces', 324.517173340769), ('GarageFinish', 309.25876580306016), ('MasVnrArea', 302.0641955355343), ('HeatingQC', 272.524869948425), ('LotFrontage', 216.3690705147019), ('MSSubClassDummy_60', 201.56173076085017), ('BsmtFinSF1', 199.26360807906522), ('OpenPorchSF', 172.58181868431313), ('BsmtExposure', 144.7886364164947), ('WoodDeckSF', 132.12340478239892), ('LotArea', 123.69339580324491), ('2ndFlrSF', 110.67120140559962), ('HalfBath', 90.2300642709462), ('GarageYrBlt', 88.16127275782955), ('MSSubClassDummy_30', 84.77174010744662), ('BsmtUnfSF', 78.82819691960658), ('BsmtFullBath', 72.67070671279832), ('GarageCond', 66.79664710424541), ('GarageQual', 60.759346139368176), ('Fence', 45.00316736259876), ('BedroomAbvGr', 38.243158653681036), ('OverallCond', 30.15439369304664), ('NumFloors', 29.02321243102151), ('EnclosedPorch', 22.233157303981493), ('ExterCond', 21.31946433762363), ('KitchenAbvGr', 15.810716484886521), ('BsmtCond', 9.669013670582986), ('BsmtFinType1', 8.687629382542776), ('ScreenPorch', 7.641489060791777), ('BsmtFinType2', 7.638547863498392), ('MoSold', 6.77950086324598), ('FireplaceQu', 5.6965583291465824), ('LowQualFinSF', 4.843061802201764), ('BsmtHalfBath', 4.450710325261562), ('3SsnPorch', 2.956894959374826), ('LandSlope', 1.5465406691149195), ('hasBeenRemodeled', 1.0156127863315145), ('MiscVal', 0.9633011040524923), ('BsmtFinSF2', 0.5808883051470958), ('YrSold', 0.06481436925437876), ('MSSubClassDummy_40', 0.00629207683628299), ('PoolArea', 0.0021178890122671807), ('PoolQC', 0.0002845642238462928), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 290.4942399395786), ('NeighborhoodDummy_NoRidge', 139.18995834816315), ('MSZoningDummy_RM', 138.53591576748568), ('LotShapeDummy_Reg', 82.0774453717044), ('MSZoningDummy_RL', 78.74665790157361), ('NeighborhoodDummy_NAmes', 61.20104105627306), ('NeighborhoodDummy_OldTown', 61.19183232475112), ('NeighborhoodDummy_Edwards', 48.81832310199174), ('MSSubClassDummy_50', 42.93375580706964), ('NeighborhoodDummy_Somerst', 35.525822346895275), ('NeighborhoodDummy_BrkSide', 31.4187141952875), ('NeighborhoodDummy_Sawyer', 30.55468679237185), ('NeighborhoodDummy_Timber', 29.11492718982318), ('NeighborhoodDummy_StoneBr', 28.91308908734182), ('NeighborhoodDummy_IDOTRR', 25.078211773171358), ('MSSubClassDummy_160', 23.117575043867333), ('Condition1Dummy_Norm', 19.616604629421857), ('NeighborhoodDummy_BrDale', 19.14077109423813), ('Condition1Dummy_Feedr', 17.807440924239984), ('MSZoningDummy_FV', 15.233426015923772), ('LandContourDummy_HLS', 14.61456841857296), ('AlleyDummy_No_Alley_Access', 14.600087543372505), ('NeighborhoodDummy_MeadowV', 14.16585753996982), ('NeighborhoodDummy_CollgCr', 13.73659175579681), ('MSSubClassDummy_90', 13.689628432258292), ('MSSubClassDummy_190', 9.205246227022178), ('LotConfigDummy_CulDSac', 8.912182306235971), ('MSSubClassDummy_45', 7.11354628645279), ('NeighborhoodDummy_SWISU', 6.781842015895447), ('MSZoningDummy_RH', 6.003847966760143), ('NeighborhoodDummy_ClearCr', 5.3168516734302695), ('NeighborhoodDummy_Mitchel', 5.139021825247137), ('LotShapeDummy_IR2', 5.018207660324756), ('MSSubClassDummy_85', 4.719675849048925), ('Condition1Dummy_PosA', 3.8454139161552447), ('LandContourDummy_Low', 3.7943098049599686), ('MSSubClassDummy_180', 3.5640368258858866), ('NeighborhoodDummy_Gilbert', 3.209591062486696), ('NeighborhoodDummy_Crawfor', 3.13672983201185), ('MSSubClassDummy_120', 2.569909467624943), ('LotConfigDummy_Inside', 2.5659435923257345), ('NeighborhoodDummy_NPkVill', 2.4774068582297 ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.42619781, 0.23434057]),
#  'std_fit_time': array([0.15352964, 0.03202025]),
#  'mean_score_time': array([0.0126843 , 0.01041889]),
#  'std_score_time': array([0.00221224, 0.00114366]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86812914, 0.89770614]),
#  'split1_test_score': array([0.89287869, 0.87797548]),
#  'split2_test_score': array([0.85598589, 0.84221146]),
#  'split3_test_score': array([0.86862361, 0.87481468]),
#  'split4_test_score': array([0.88617661, 0.88422853]),
#  'mean_test_score': array([0.87435879, 0.87538726]),
#  'std_test_score': array([0.01335598, 0.0183519 ]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.8753872591851257

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 0.08627343665390147),
#  ('OverallQual', 0.0795803486477929),
#  ('TotalBsmtSF', 0.051656105163562706),
#  ('ExterQual', 0.05148711676851545),
#  ('FullBath', 0.05043224299877),
#  ('YearBuilt', 0.047035868037222844),
#  ('GarageArea', 0.046666437928018424),
#  ('GarageCars', 0.046497555923039766),
#  ('1stFlrSF', 0.04112827004933885),
#  ('KitchenQual', 0.04014270874868529),
#  ('BsmtFinSF1', 0.028309236886895447),
#  ('GarageYrBlt', 0.02721038826438059),
#  ('BsmtQual', 0.026308809046215704),
#  ('Fireplaces', 0.01967239670625634),
#  ('TotRmsAbvGrd', 0.01955139221914699),
#  ('LotArea', 0.019490796290361753),
#  ('2ndFlrSF', 0.019294352584272745),
#  ('LotFrontage', 0.01916074364210406),
#  ('MasVnrArea', 0.01843600639217731),
#  ('YearRemodAdd', 0.018084681656651832),
#  ('OpenPorchSF', 0.015108557114683657),
#  ('GarageFinish', 0.013192867090648364),
#  ('BsmtUnfSF', 0.012147011285878416),
#  ('FoundationDummy_CBlock', 0.009132887212372976),
#  ('WoodDeckSF', 0.008890154207992926),
#  ('HeatingQC', 0.008696285422161562),
#  ('FireplaceQu', 0.007117232680083225),
#  ('NeighborhoodDummy_NWAmes', 0.006064257687770997),
#  ('BsmtExposure', 0.005634182252767616),
#  ('MSSubClassDummy_50', 0.005571548175897643),
#  ('MoSold', 0.0051350339950702465),
#  ('FunctionalDummy_Typ', 0.00488000300165726),
#  ('HalfBath', 0.004841337652861927),
#  ('BsmtFullBath', 0.0048243607831336245),
#  ('BedroomAbvGr', 0.004760853792143298),
#  ('SaleTypeDummy_ConLw', 0.004714410035096114),
#  ('GarageTypeDummy_CarPort', 0.004621940414633918),
#  ('MasVnrTypeDummy_Stone', 0.0042654792060854456),
#  ('HouseStyleDummy_SLvl', 0.0040802918619877795),
#  ('HouseStyleDummy_2.5Unf', 0.004052922618959589),
#  ('OverallCond', 0.00401621143986655),
#  ('NeighborhoodDummy_NoRidge', 0.004008082210492607),
#  ('BsmtFinType1', 0.0037615761943325236),
#  ('MiscFeatureDummy_No_Misc_Feature', 1.161932213230717e-05),
#  ('Exterior1stDummy_WdShing', 9.26745021777281e-06),
#  ('MSZoningDummy_RM', 8.913070932170552e-06),
#  ('RoofMatlDummy_Roll', 7.753258049833075e-06),
#  ('RoofMatlDummy_WdShngl', 7.644090097807578e-06),
#  ('BldgTypeDummy_TwnhsE', 7.424112696660076e-06),
#  ('RoofStyleDummy_Hip', 6.22171158238053e-06),
#  ('SaleTypeDummy_CWD', 6.075114955608516e-06),
#  ('LotConfigDummy_Inside', 5.976411703940236e-06),
#  ('PoolArea', 5.582621414276014e-06),
#  ('Condition2Dummy_RRAe', 3.6554992746087953e-06),
#  ('SaleTypeDummy_WD', 3.2547466244551177e-06),
#  ('Condition1Dummy_RRAn', 2.079531103779442e-06),
#  ('Condition2Dummy_RRAn', 1.2354078505600044e-06),
#  ('RoofMatlDummy_Metal', 1.1556977536812995e-06),
#  ('FoundationDummy_Slab', 9.289060601269506e-07),
#  ('Exterior2ndDummy_BrkFace', 6.18545494499576e-07),
#  ('Exterior1stDummy_BrkFace', 6.729563898606335e-08),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02337499, 0.00481658, 0.00471869, 0.00469923, 0.00504022,
#         0.00467892, 0.00488005, 0.00462856]),
#  'std_fit_time': array([3.59445410e-02, 3.35902161e-04, 3.73736758e-04, 4.72602446e-04,
#         5.57468117e-05, 4.03899690e-04, 1.43967523e-04, 4.18032305e-04]),
#  'mean_score_time': array([0.00294404, 0.00271449, 0.00252862, 0.00257807, 0.0027266 ,
#         0.00258389, 0.00255375, 0.00254159]),
#  'std_score_time': array([6.58467745e-05, 6.17147033e-05, 2.73201493e-04, 1.85201821e-04,
#         2.01456786e-05, 3.27112397e-04, 2.20947394e-04, 2.87869614e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89206318, 0.89620243, 0.90234321, 0.90708599, 0.90861554,
#         0.90974554, 0.9037823 , 0.88355854]),
#  'split1_test_score': array([0.89569262, 0.89998009, 0.90589744, 0.90528283, 0.90421225,
#         0.90322024, 0.87255605, 0.83987618]),
#  'split2_test_score': array([0.86086714, 0.87120983, 0.87790054, 0.88387748, 0.88494882,
#         0.88542915, 0.86727091, 0.84179086]),
#  'split3_test_score': array([0.87511447, 0.87521164, 0.87786997, 0.88390669, 0.885733  ,
#         0.8869591 , 0.87710704, 0.85261926]),
#  'split4_test_score': array([0.88840324, 0.88930308, 0.89037523, 0.8923702 , 0.89289634,
#         0.89317074, 0.87752126, 0.85298351]),
#  ('GarageCars', 3390.1198693791966),
#  ('SaleTypeDummy_ConLw', 2964.6391143852434),
#  ('MasVnrArea', 2850.8586126439714),
#  ('Exterior1stDummy_BrkComm', 2715.314775887228),
#  ('SaleConditionDummy_Family', 2565.4413949713667),
#  ('BedroomAbvGr', -2439.8287536112093),
#  ('Condition1Dummy_Feedr', 2430.23705731369),
#  ('BldgTypeDummy_Duplex', -2380.3523271978056),
#  ('GarageArea', 2362.7387249287663),
#  ('NeighborhoodDummy_Crawfor', -2340.1621783294395),
#  ('MSSubClassDummy_90', -2310.890083146927),
#  ('BldgTypeDummy_Twnhs', -2263.471861097292),
#  ('NeighborhoodDummy_CollgCr', 2147.699082818646),
#  ('NeighborhoodDummy_Mitchel', -2126.3453148046224),
#  ('LotFrontage', 1978.42118311067),
#  ('NeighborhoodDummy_NPkVill', -1939.9112845285351),
#  ('BsmtExposure', -1937.4361196472394),
#  ('Fireplaces', 1873.9748492285685),
#  ('SaleConditionDummy_Normal', 1829.456436037044),
#  ('KitchenAbvGr', -1686.2671980932082),
#  ('Exterior2ndDummy_Plywood', -1618.4541139074795),
#  ('Exterior1stDummy_VinylSd', -1612.6599083873862),
#  ('FullBath', 1603.663577835087),
#  ('OpenPorchSF', 1593.6756048483685),
#  ('Exterior2ndDummy_Wd Sdng', -1586.7016429041466),
#  ('Exterior2ndDummy_CBlock', 1577.0597157367486),
#  ('NeighborhoodDummy_Edwards', -1559.5994681182954),
#  ('WoodDeckSF', 1550.7312664321016),
#  ('MSSubClassDummy_120', -1549.343991292978),
#  ('YearRemodAdd', 1541.1647871814234),
#  ('ScreenPorch', 1537.5468100770167),
#  ('NeighborhoodDummy_ClearCr', -1510.7719145462445),
#  ('MSSubClassDummy_190', 1490.0565643726059),
#  ('FunctionalDummy_Min1', 1435.605121773434),
#  ('NeighborhoodDummy_Blueste', 1420.7537472683903),
#  ('LotShapeDummy_Reg', 1380.9114917560878),
#  ('MasVnrTypeDummy_None', 1319.3112809345628),
#  ('FoundationDummy_CBlock', 1316.0097100268517),
#  ('NeighborhoodDummy_NridgHt', -1295.3021262555735),
#  ('NeighborhoodDummy_MeadowV', -1264.7809383130982),
#  ('Condition1Dummy_PosN', -1224.297556206885),
#  ('BsmtFullBath', 1219.582055785597),
#  ('Exterior2ndDummy_VinylSd', 1166.2987337549093),
#  ('Exterior2ndDummy_Other', -1156.3235128164654),
#  ('UtilitiesDummy_NoSeWa', 1141.7096772751222),
#  ('SaleConditionDummy_AdjLand', 1129.6727992732197),
#  ('FoundationDummy_Stone', -1116.7485905646085),
#  ('Exterior1stDummy_Wd Sdng', 1106.7365840854704),
#  ('Exterior2ndDummy_CmentBd', -1101.9114283233384),
#  ('FoundationDummy_PConc', 1092.903152264261),
#  ('MSSubClassDummy_75', -1074.1013818838903),
#  ('BldgTypeDummy_2fmCon', -1050.6344739615727),
#  ('MSSubClassDummy_85', -1050.6344739615722),
#  ('Exterior1stDummy_Plywood', 1049.0368519860083),
#  ('HouseStyleDummy_1Story', -1014.7780728962023),
#  ('BsmtUnfSF', -998.6745562710641),
#  ('HouseStyleDummy_SFoyer', 991.5173315614137),
#  ('BsmtFinSF2', 990.6620922439815),
#  ('GarageFinish', -984.5054573511218),
#  ('NumFloors', -979.1297317214039),
#  ('Exterior1stDummy_Stone', 978.2613235713587),
#  ('HalfBath', 945.8945522300817),
#  ('Exterior1stDummy_CBlock', -935.9187653131826),
#  ('PoolArea', 930.8226389039096),
#  ('hasBeenRemodeled', -920.9273101792986),
#  ('NeighborhoodDummy_NAmes', 890.0631522350112),
#  ('RoofStyleDummy_Mansard', 857.3332603308821),
#  ('GarageTypeDummy_CarPort', 835.5797271290927),
#  ('LotConfigDummy_CulDSac', -826.9370301947195),
#  ('SalePrice', 809.6649532987841),
#  ('LotConfigDummy_FR2', -808.8442893041964),
#  ('Exterior2ndDummy_Stucco', 806.2711599394786),
#  ('SaleTypeDummy_WD', 794.7120438816729),
#  ('NeighborhoodDummy_OldTown', -794.0482455946342),
#  ('NeighborhoodDummy_BrDale', 793.950170255766),
#  ('GarageTypeDummy_Basment', 786.3638811602203),
#  ('Exterior2ndDummy_Brk Cmn', -779.9629577278741),
#  ('GarageTypeDummy_Detchd', 777.5465058152809),
#  ('FunctionalDummy_Min2', -765.5410198414675),
#  ('RoofMatlDummy_Roll', -743.1815114774886),
#  ('MSZoningDummy_RH', 735.9242620615321),
#  ('GarageYrBlt', -729.2464399579216),
#  ('MSSubClassDummy_80', -725.466946202348),
#  ('FireplaceQu', -699.2238181312684),
#  ('HeatingQC', -692.3751724696641),
#  ('PavedDriveDummy_P', 681.5650783817059),
#  ('MasVnrTypeDummy_No_MasVnr', 681.2691566873037),
#  ('MSSubClassDummy_50', 680.6978772486264),
#  ('LandContourDummy_HLS', -679.8314582103516),
#  ('LandSlope', -678.8393611162055),
#  ('Exterior1stDummy_ImStucc', 642.7016104170149),
#  ('RoofMatlDummy_Membran', 639.86762197952),
#  ('HeatingDummy_Wall', 625.6191378874893),
#  ('HeatingDummy_GasW', -620.6849324359137),
#  ('MSZoningDummy_FV', 615.3327439257919),
#  ('ExterCond', 603.7734261619185),
#  ('Exterior1stDummy_HdBoard', -594.9369679895539),
#  ('RoofStyleDummy_Gambrel', 590.6148711522723),
#  ('MSZoningDummy_RM', 584.7082725682784),
#  ('MiscFeatureDummy_TenC', 584.6520359456384),
#  ('BsmtCond', 562.1334628115012),
#  ('Exterior1stDummy_CemntBd', -546.363097380822),
#  ('MoSold', -534.2242487023701),
#  ('BsmtFinType2', -533.95664678599),
#  ('HouseStyleDummy_SLvl', -531.0995504015909),
#  ('NeighborhoodDummy_SawyerW', 526.4069344022945),
#  ('MSSubClassDummy_60', 521.9725995529302),
#  ('NeighborhoodDummy_Timber', 519.4591037147145),
#  ('3SsnPorch', 515.6270538998886),
#  ('RoofMatlDummy_WdShake', 506.9414356602069),
#  ('SaleTypeDummy_CWD', 504.9807127797601),
#  ('GarageTypeDummy_BuiltIn', -489.22241144010763),
#  ('Condition1Dummy_PosA', 489.0308739161927),
#  ('NeighborhoodDummy_IDOTRR', -486.73470764588103),
#  ('Condition2Dummy_RRNn', -479.3878720114214),
#  ('Exterior1stDummy_MetalSd', -468.0413498171803),
#  ('MasVnrTypeDummy_Stone', 466.88857790373663),
#  ('LotShapeDummy_IR3', 466.67867142556224),
#  ('ElectricalDummy_SBrkr', -453.5016565280473),
#  ('Exterior2ndDummy_Wd Shng', -451.4117843228299),
#  ('HouseStyleDummy_2.5Unf', -437.00492128207577),
#  ('Condition1Dummy_RRNn', -436.3234808064126),
#  ('CentralAirDummy_Y', -426.64489806034277),
#  ('Exterior1stDummy_Stucco', -425.58326336592853),
#  ('HouseStyleDummy_2.5Fin', -400.2053312519013),
#  ('NeighborhoodDummy_StoneBr', -396.4863860985849),
#  ('Condition1Dummy_RRAe', 393.2716515252194),
#  ('Exterior2ndDummy_HdBoard', 383.45525860951705),
#  ('MSSubClassDummy_70', 379.7413557950558),
#  ('NeighborhoodDummy_Sawyer', -377.92464948907696),
#  ('SaleTypeDummy_ConLD', -363.13617245028473),
#  ('LowQualFinSF', -351.8266211696423),
#  ('SaleTypeDummy_Oth', -341.8678522778699),
#  ('BsmtHalfBath', -339.22181866316964),
#  ('Fence', 336.84261218778795),
#  ('GarageTypeDummy_Attchd', 334.246097056374),
#  ('NeighborhoodDummy_Gilbert', -333.3947993119007),
#  ('AlleyDummy_No_Alley_Access', -326.40170603000934),
#  ('Condition1Dummy_RRAn', -319.00086697612346),
#  ('MiscFeatureDummy_Othr', 315.79848274103676),
#  ('Exterior1stDummy_BrkFace', -306.97024718962683),
#  ('Exterior2ndDummy_BrkFace', -306.9702471896265),
#  ('LotShapeDummy_IR2', -306.06268128896716),
#  ('LandContourDummy_Low', -303.8848813401826),
#  ('PoolQC', 301.5861760133295),
#  ('FoundationDummy_Wood', -297.22798524895575),
#  ('RoofStyleDummy_Gable', 295.31838549394774),
#  ('Exterior1stDummy_WdShing', 281.69566899484573),
#  ('YrSold', -256.1612230770767),
#  ('HouseStyleDummy_1.5Unf', -254.4168834705668),
#  ('Condition1Dummy_RRNe', 253.47800235288042),
#  ('Exterior2ndDummy_AsphShn', 247.08634203039068),
#  ('MSSubClassDummy_180', -246.51861440512033),
#  ('SaleTypeDummy_New', 244.53081725095439),
#  ('Exterior1stDummy_AsphShn', -223.08005179065688),
#  ('MSSubClassDummy_30', 222.71011742893316),
#  ('MiscVal', 217.25533058355782),
#  ('LotConfigDummy_Inside', 216.3813472106629),
#  ('NeighborhoodDummy_BrkSide', -212.59789013446172),
#  ('NeighborhoodDummy_Veenker', -203.73601373151098),
#  ('SaleTypeDummy_ConLI', -200.5219350714292),
#  ('NeighborhoodDummy_SWISU', -196.0562403797148),
#  ('FunctionalDummy_Typ', -186.10338395233273),
#  ('HeatingDummy_GasA', 183.15594061894137),
#  ('RoofMatlDummy_WdShngl', -178.15052143717938),
#  ('PavedDriveDummy_Y', -169.3998662587408),
#  ('RoofMatlDummy_Metal', -154.6694938099861),
#  ('ElectricalDummy_Mix', 138.40822239746842),
#  ('SaleConditionDummy_Alloca', 135.58258361918854),
#  ('RoofStyleDummy_Shed', 129.5249281274771),
#  ('HouseStyleDummy_2Story', -106.94665530755479),
#  ('Condition2Dummy_Feedr', 100.94889039091676),
#  ('MSSubClassDummy_160', 97.653132330374),
#  ('RoofMatlDummy_Tar&Grv', -97.17055685589801),
#  ('AlleyDummy_Pave', 95.39789361777501),
#  ('RoofStyleDummy_Hip', -94.87424617273362),
#  ('Exterior2ndDummy_Stone', -79.67298553053539),
#  ('MasVnrTypeDummy_BrkFace', -77.37540318389229),
#  ('EnclosedPorch', 75.30172194112288),
#  ('SaleTypeDummy_Con', 72.61065565907242),
#  ('BsmtFinType1', 70.55575474190621),
#  ('Condition2Dummy_RRAn', 69.6699961966051),
#  ('MSSubClassDummy_45', -69.30995640997611),
#  ('Exterior2ndDummy_MetalSd', -63.67622672910806),
#  ('GarageCond', -59.61472573689434),
#  ('FunctionalDummy_Maj2', 57.87254448664087),
#  ('BldgTypeDummy_TwnhsE', 52.182993441621306),
#  ('GarageQual', 46.11079818777372),
#  ('Exterior2ndDummy_ImStucc', -42.09148687898652),
#  ('GarageTypeDummy_No_Garage', -33.235132137071965),
#  ('MSSubClassDummy_40', -32.6808563359542),
#  ('Condition2Dummy_RRAe', 23.266806950974342),
#  ('MSZoningDummy_RL', -22.94274120217069),
#  ('FoundationDummy_Slab', 22.17496777989363),
#  ('StreetDummy_Pave', 19.304472024910314),
#  ('Condition1Dummy_Norm', -12.288888205045113),
#  ('LotConfigDummy_FR3', 11.940126703551982),
#  ('MiscFeatureDummy_No_Misc_Feature', 7.277587140709165),
#  ('LandContourDummy_Lvl', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163576031249.8043, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156367195415.09674, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161617229582.4944, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155417898673.8915, tolerance: 497016804.70499045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162256051953.73032, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108786364409.88766, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112068076632.79251, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125677786342.9871, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116349607016.69974, tolerance: 497016804.70499045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139228016670.2415, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4410446355.503296, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468772365.71759033, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1262122027.5306396, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11686492, 0.11705098, 0.11907296, 0.08427792, 0.06269164,
#         0.05321107, 0.00875535, 0.00750203]),
#  'std_fit_time': array([0.00430065, 0.00588699, 0.00379906, 0.00707968, 0.00269678,
#         0.01060477, 0.00037515, 0.00056729]),
#  'mean_score_time': array([0.00290861, 0.00261359, 0.00238452, 0.00294271, 0.00276804,
#         0.00269294, 0.00251284, 0.00261583]),
#  'std_score_time': array([4.59471799e-04, 2.96044472e-04, 9.98159933e-05, 1.47798337e-04,
#         2.94354362e-04, 4.10270730e-04, 3.31981742e-04, 1.74277399e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89213855, 0.89282209, 0.89789421, 0.90481534, 0.90677676,
#         0.90772944, 0.90599292, 0.89341099]),
#  'split1_test_score': array([0.89487169, 0.89742054, 0.90296881, 0.9102464 , 0.91083868,
#         0.91097742, 0.90719842, 0.89662764]),
#  'split2_test_score': array([0.86629805, 0.86761094, 0.87386222, 0.88104885, 0.88272422,
#         0.88453416, 0.88202481, 0.86795971]),
#  'split3_test_score': array([0.87505309, 0.87512168, 0.87563593, 0.88058225, 0.88286507,
#         0.88475453, 0.89224697, 0.8804637 ]),
#  'split4_test_score': array([0.88892235, 0.888902  , 0.88940637, 0.89081989, 0.89178703,
#         0.89309944, 0.89998555, 0.89036216]),
#  'mean_test_score': array([0.88345675, 0.88437545, 0.88795351, 0.89350255, 0.89499835,
#         0.896219  , 0.89748973, 0.88576484]),
#  'std_test_score': array([0.01095983, 0.01121331, 0.01163336, 0.01214546, 0.01181381,
#         0.01120716, 0.00937488, 0.01041848]),
#  'rank_test_score': array([8, 7, 5, 4, 3, 2, 1, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 1000, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8974897326427195

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 23111.663184514),
#  ('OverallQual', 12255.388480195303),
#  ('BsmtFinSF1', 8550.079732595632),
#  ('TotalBsmtSF', 6346.268387929814),
#  ('NeighborhoodDummy_NoRidge', 5609.711659596995),
#  ('ExterQual', -5263.583228750132),
#  ('YearBuilt', 4734.458474341855),
#  ('KitchenQual', -4436.887101876141),
#  ('OverallCond', 3914.9770848357234),
#  ('BsmtQual', -3852.021647175651),
#  ('SaleTypeDummy_ConLw', 3766.3254731058846),
#  ('LotArea', 3359.833028385031),
#  ('NeighborhoodDummy_NWAmes', 2984.7230819935103),
#  ('FunctionalDummy_Sev', 2941.9474373915614),
#  ('GarageArea', 2700.0966650842925),
#  ('GarageCars', 2475.7460432862003),
#  ('NeighborhoodDummy_Somerst', 2291.6240618699817),
#  ('YearRemodAdd', 2092.3939152659937),
#  ('NeighborhoodDummy_CollgCr', 1934.1563948248995),
#  ('KitchenAbvGr', -1890.5774059139817),
#  ('Fireplaces', 1649.8034681323384),
#  ('Exterior1stDummy_BrkComm', 1556.3656940004348),
#  ('Condition1Dummy_Feedr', 1438.258081257262),
#  ('MSSubClassDummy_90', -1405.8174039145883),
#  ('BldgTypeDummy_Twnhs', -1396.5591484098852),
#  ('MasVnrArea', 1389.439617396954),
#  ('BldgTypeDummy_Duplex', -1347.593521184538),
#  ('BsmtExposure', -1184.5229333644877),
#  ('MSSubClassDummy_120', -1054.6754527110243),
#  ('NeighborhoodDummy_SawyerW', 1019.1044039624367),
#  ('LotShapeDummy_Reg', 999.0007993819513),
#  ('LotFrontage', 989.0463859175052),
#  ('MSSubClassDummy_85', -976.3151989422112),
#  ('1stFlrSF', 959.9281308452805),
#  ('GarageFinish', -932.4065320860599),
#  ('BsmtFinSF2', 754.3995703953761),
#  ('OpenPorchSF', 670.4666059029142),
#  ('NeighborhoodDummy_NPkVill', -602.7891963909527),
#  ('MasVnrTypeDummy_None', 556.2915965526213),
#  ('WoodDeckSF', 548.3681860761894),
#  ('HouseStyleDummy_SLvl', -471.158533599833),
#  ('FunctionalDummy_Min2', -438.88153499561463),
#  ('ScreenPorch', 423.44332930417113),
#  ('BsmtFullBath', 372.9215120620221),
#  ('LowQualFinSF', -335.4209443760464),
#  ('BedroomAbvGr', -305.33707768968947),
#  ('HouseStyleDummy_1Story', -299.02551637914183),
#  ('NeighborhoodDummy_BrDale', 297.34872470402536),
#  ('Condition1Dummy_PosN', -253.60508392450544),
#  ('FoundationDummy_Stone', -244.3306948651414),
#  ('Exterior1stDummy_CemntBd', -232.26748810709955),
#  ('Exterior2ndDummy_Stucco', 185.8617898343744),
#  ('FireplaceQu', -170.71992615583815),
#  ('Exterior2ndDummy_Wd Sdng', -145.53892360116612),
#  ('MSZoningDummy_RL', -121.12302624266857),
#  ('NeighborhoodDummy_Crawfor', -103.29387173206915),
#  ('BldgTypeDummy_2fmCon', -93.5125340811126),
#  ('RoofMatlDummy_Roll', -73.62699462623051),
#  ('HeatingQC', -56.23302849412604),
#  ('Exterior1stDummy_Stone', 44.62204582210563),
#  ('BsmtFinType2', -39.86386947733931),
#  ('SaleConditionDummy_Family', 37.357038455788334),
#  ('Exterior1stDummy_AsphShn', -1.4127051989095007),
#  ('LandSlope', -0.0),
#  ('ExterCond', 0.0),
#  ('BsmtCond', 0.0),
#  ('BsmtFinType1', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('2ndFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', -0.0),
#  ('GarageQual', 0.0),
#  ('GarageCond', 0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('PoolQC', -0.0),
#  ('Fence', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', -0.0),
#  ('YrSold', 0.0),
#  ('SalePrice', 0.0),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', -0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', 0.0),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', 0.0),
#  ('MSZoningDummy_FV', 0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', 0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -0.0),
#  ('LandContourDummy_HLS', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', 0.0),
#  ('UtilitiesDummy_NoSeWa', 0.0),
#  ('LotConfigDummy_CulDSac', -0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', 0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrkSide', 0.0),
#  ('NeighborhoodDummy_ClearCr', -0.0),
#  ('NeighborhoodDummy_Edwards', -0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -0.0),
#  ('NeighborhoodDummy_NAmes', 0.0),
#  ('NeighborhoodDummy_NridgHt', -0.0),
#  ('NeighborhoodDummy_OldTown', -0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_StoneBr', 0.0),
#  ('NeighborhoodDummy_Timber', 0.0),
#  ('NeighborhoodDummy_Veenker', -0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition1Dummy_PosA', 0.0),
#  ('Condition1Dummy_RRAe', 0.0),
#  ('Condition1Dummy_RRAn', -0.0),
#  ('Condition1Dummy_RRNe', 0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', 0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_TwnhsE', 0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gable', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Membran', 0.0),
#  ('RoofMatlDummy_Metal', -0.0),
#  ('RoofMatlDummy_Tar&Grv', 0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_BrkFace', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', 0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', 0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', -0.0),
#  ('Exterior2ndDummy_Brk Cmn', -0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', 0.0),
#  ('Exterior2ndDummy_CmentBd', -0.0),
#  ('Exterior2ndDummy_HdBoard', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Other', -0.0),
#  ('Exterior2ndDummy_Plywood', -0.0),
#  ('Exterior2ndDummy_Stone', 0.0),
#  ('Exterior2ndDummy_VinylSd', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_No_MasVnr', 0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('FoundationDummy_CBlock', 0.0),
#  ('FoundationDummy_PConc', 0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', 0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('CentralAirDummy_Y', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('FunctionalDummy_Maj2', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Mod', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 0.0),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('PavedDriveDummy_P', 0.0),
#  ('PavedDriveDummy_Y', -0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', -0.0),
#  ('MiscFeatureDummy_Othr', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('MiscFeatureDummy_TenC', 0.0),
#  ('SaleTypeDummy_CWD', 0.0),
#  ('SaleTypeDummy_Con', -0.0),
#  ('SaleTypeDummy_ConLD', -0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_New', 0.0),
#  ('SaleTypeDummy_Oth', -0.0),
#  ('SaleTypeDummy_WD', 0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Normal', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType','MSSubClass']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8764090940055771

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.891006007255988

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158337918504.891, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178599307502.74774, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132762992621.17195, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148334480976.38577, tolerance: 497016804.70499045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160062852673.09888, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13163899496.444763, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101810385665.0232, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16933590917.237152, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8713835822.028503, tolerance: 497016804.70499045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7720494448.135071, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8538346971.4747925, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8907364082687741

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999200
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998929
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.998538
# PoolArea                  PoolQC                       0.998154
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996824
# GarageCars                GarageArea                   0.990188
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.985626
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.985473
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.982331
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.969442
# GrLivArea                 TotRmsAbvGrd                 0.967883
# 2ndFlrSF                  NumFloors                    0.967172
# TotalBsmtSF               1stFlrSF                     0.966004
# 2ndFlrSF                  HouseStyleDummy_2Story       0.964215
# ExterQual                 KitchenQual                  0.963816
# OverallQual               ExterQual                    0.958095
# ExterQual                 BsmtQual                     0.954039
# BsmtQual                  FoundationDummy_PConc        0.952299
# OverallQual               BsmtQual                     0.950994
# NumFloors                 HouseStyleDummy_1Story       0.949913
# MasVnrArea                MasVnrTypeDummy_None         0.943396
# YearRemodAdd              BsmtQual                     0.940284
#                           FoundationDummy_PConc        0.939106
# OverallQual               KitchenQual                  0.938793
#                           GarageCars                   0.938602
# FoundationDummy_CBlock    FoundationDummy_PConc        0.938448
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.937249
# YearBuilt                 BsmtQual                     0.933842
# HalfBath                  HouseStyleDummy_2Story       0.933130
# OverallQual               FullBath                     0.928192
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.926005
# ExterQual                 FoundationDummy_PConc        0.923641
# BsmtQual                  KitchenQual                  0.919795
# YearRemodAdd              ExterQual                    0.919648
# NumFloors                 HouseStyleDummy_2Story       0.917314
# OverallQual               GarageArea                   0.916432
#                           YearRemodAdd                 0.912589
#                           FoundationDummy_PConc        0.910158
# BsmtFinSF1                BsmtFullBath                 0.909529
# OverallQual               YearBuilt                    0.908679
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.907411
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.906542
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.904348
# 2ndFlrSF                  HouseStyleDummy_1Story       0.904243
# YearBuilt                 YearRemodAdd                 0.904047
# BsmtQual                  FullBath                     0.900951
# Exterior1stDummy_BrkFace  Exterior2ndDummy_BrkFace     0.900698
# YearRemodAdd              KitchenQual                  0.900322
# YearBuilt                 FoundationDummy_PConc        0.900184
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.5959969776657497),
#  ('LotArea', 2.0829783055429303),
#  ('OverallQual', 4.599608061030932),
#  ('OverallCond', 2.0937373614984987),
#  ('YearBuilt', 12.169681250432186),
#  ('YearRemodAdd', 3.533076283988766),
#  ('MasVnrArea', 2.6707534983001353),
#  ('ExterQual', 3.093487903065224),
#  ('BsmtQual', 3.0189081718196924),
#  ('BsmtExposure', 1.8283693696269263),
#  ('BsmtFinType1', 2.190274783760511),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.4683377231741437),
#  ('BsmtHalfBath', 1.2631920061528716),
#  ('FullBath', 3.809823429119268),
#  ('HalfBath', 2.845051125798826),
#  ('BedroomAbvGr', 3.0045822069568615),
#  ('KitchenAbvGr', 1.787946797073733),
#  ('KitchenQual', 2.319560056276182),
#  ('TotRmsAbvGrd', 5.275844759521316),
#  ('Fireplaces', 1.8442292381328407),
#  ('FireplaceQu', 1.4138963413066792),
#  ('GarageYrBlt', 1506.079545257476),
#  ('GarageFinish', 2.1223502633955356),
#  ('GarageCars', 6.846372284044965),
#  ('GarageArea', 6.4896650766168404),
#  ('WoodDeckSF', 1.3547548083811465),
#  ('OpenPorchSF', 1.3814435006359345),
#  ('EnclosedPorch', 1.492992393413211),
#  ('3SsnPorch', 1.1160339890753823),
#  ('ScreenPorch', 1.1831025222102698),
#  ('PoolArea', 16.09217118176252),
#  ('PoolQC', 16.03731114544625),
#  ('Fence', 1.3361471248905117),
#  ('MiscVal', 1.0649460442784047),
#  ('MoSold', 1.1400496386733159),
#  ('YrSold', 1.177666623118406),
#  ('hasBeenRemodeled', 1.8901942767031585),
#  ('NumFloors', 22.166753712393376),
#  ('MSZoningDummy_FV', 25.981183407967947),
#  ('MSZoningDummy_RH', 5.129421646349059),
#  ('MSZoningDummy_RL', 74.22301051629996),
#  ('MSZoningDummy_RM', 51.84239511869086),
#  ('AlleyDummy_No_Alley_Access', 2.734044808695438),
#  ('AlleyDummy_Pave', 2.703135613237077),
#  ('LotShapeDummy_IR2', 1.251321081967036),
#  ('LotShapeDummy_IR3', 1.1049443795560672),
#  ('LotShapeDummy_Reg', 1.5453272803721954),
#  ('LotConfigDummy_CulDSac', 1.7327398740260107),
#  ('LotConfigDummy_FR2', 1.3720799329744149),
#  ('LotConfigDummy_FR3', 1.0847267283202573),
#  ('LotConfigDummy_Inside', 1.7034399864845333),
#  ('NeighborhoodDummy_Blueste', 1.3151844293999833),
#  ('NeighborhoodDummy_BrDale', 3.2361696391644377),
#  ('NeighborhoodDummy_BrkSide', 7.048548622370677),
#  ('NeighborhoodDummy_ClearCr', 3.4109453786117365),
#  ('NeighborhoodDummy_CollgCr', 11.305261888897373),
#  ('NeighborhoodDummy_Crawfor', 5.0620493897615475),
#  ('NeighborhoodDummy_Edwards', 8.458029507887415),
#  ('NeighborhoodDummy_Gilbert', 6.957993649886356),
#  ('NeighborhoodDummy_IDOTRR', 4.430101128500429),
#  ('NeighborhoodDummy_MeadowV', 3.1588455869586456),
#  ('NeighborhoodDummy_Mitchel', 4.989137029146279),
#  ('NeighborhoodDummy_NAmes', 18.399946361393418),
#  ('NeighborhoodDummy_NPkVill', 2.0353143604139294),
#  ('NeighborhoodDummy_NWAmes', 7.180838622354785),
#  ('NeighborhoodDummy_NoRidge', 4.448634649189015),
#  ('NeighborhoodDummy_NridgHt', 6.565056502837498),
#  ('NeighborhoodDummy_OldTown', 10.965033039772077),
#  ('NeighborhoodDummy_SWISU', 3.6471701386693574),
#  ('NeighborhoodDummy_Sawyer', 7.485167689535371),
#  ('NeighborhoodDummy_SawyerW', 5.614383333288409),
#  ('NeighborhoodDummy_Somerst', 10.38545069916311),
#  ('NeighborhoodDummy_StoneBr', 2.574838095838897),
#  ('NeighborhoodDummy_Timber', 3.5806264432965245),
#  ('NeighborhoodDummy_Veenker', 1.8401639380372021),
#  ('HouseStyleDummy_1.5Unf', 1.660663185166587),
#  ('HouseStyleDummy_1Story', 22.58198112220847),
#  ('HouseStyleDummy_2.5Fin', 1.8119153042559704),
#  ('HouseStyleDummy_2.5Unf', 1.1289777733773594),
#  ('HouseStyleDummy_2Story', 6.252438059332734),
#  ('HouseStyleDummy_SFoyer', 3.0881664158156),
#  ('HouseStyleDummy_SLvl', 3.712388438065146),
#  ('RoofStyleDummy_Gable', 43.66188976549832),
#  ('RoofStyleDummy_Gambrel', 2.97114584691247),
#  ('RoofStyleDummy_Hip', 41.70382163164968),
#  ('RoofStyleDummy_Mansard', 1.9825103202856422),
#  ('RoofStyleDummy_Shed', 1.319664977043746),
#  ('Exterior1stDummy_AsphShn', 1.2544218554297695),
#  ('Exterior1stDummy_BrkComm', 1.1318534124019528),
#  ('Exterior1stDummy_BrkFace', 4.317607570831132),
#  ('Exterior1stDummy_CBlock', 1.204043212181955),
#  ('Exterior1stDummy_CemntBd', 5.45622214496618),
#  ('Exterior1stDummy_HdBoard', 16.567719240365832),
#  ('Exterior1stDummy_ImStucc', 1.1880474027421752),
#  ('Exterior1stDummy_MetalSd', 14.93840490591357),
#  ('Exterior1stDummy_Plywood', 9.186384096608366),
#  ('Exterior1stDummy_Stone', 1.221430845870575),
#  ('Exterior1stDummy_Stucco', 1.8872591740596893),
#  ('Exterior1stDummy_VinylSd', 27.645851027004472),
#  ('Exterior1stDummy_Wd Sdng', 13.240803709859835),
#  ('Exterior1stDummy_WdShing', 2.8532224404472606),
#  ('MasVnrTypeDummy_BrkFace', 27.58045933714213),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7660639138589336),
#  ('MasVnrTypeDummy_None', 31.55004729154271),
#  ('MasVnrTypeDummy_Stone', 11.122166841118375),
#  ('FoundationDummy_CBlock', 6.7077307990362955),
#  ('FoundationDummy_PConc', 8.210590939502511),
#  ('FoundationDummy_Slab', 2.3836590991776827),
#  ('FoundationDummy_Stone', 1.150584938320377),
#  ('FoundationDummy_Wood', 1.2483401482833605),
#  ('GarageTypeDummy_Attchd', 92.07713704668038),
#  ('GarageTypeDummy_Basment', 5.81930977080691),
#  ('GarageTypeDummy_BuiltIn', 21.40326200727117),
#  ('GarageTypeDummy_CarPort', 2.943858582359688),
#  ('GarageTypeDummy_Detchd', 75.12893759488308),
#  ('GarageTypeDummy_No_Garage', 1464.2019849564279),
#  ('SaleConditionDummy_AdjLand', 1.068763396326296),
#  ('SaleConditionDummy_Alloca', 1.5481127359636941),
#  ('SaleConditionDummy_Family', 1.327893480880722),
#  ('SaleConditionDummy_Normal', 2.7479699555002552),
#  ('SaleConditionDummy_Partial', 2.7994745900087605),
#  ('constant', 115761.65102911381)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual','GarageArea','PoolArea','PoolQC'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)
# Out:
# [('LotFrontage', 28.512232393270722),
#  ('LotArea', 8.42677090695083),
#  ('OverallCond', 41.2394160726846),
#  ('YearBuilt', 39779.13868804204),
#  ('YearRemodAdd', 30678.19397668106),
#  ('MasVnrArea', 3.573818439164621),
#  ('ExterQual', 51.91179069581312),
#  ('BsmtQual', 17.29895440847367),
#  ('BsmtExposure', 9.3173366053196),
#  ('BsmtFinType1', 6.207830997571362),
#  ('BsmtFinSF1', 20.677439446864835),
#  ('BsmtFinSF2', 2.2420423420920605),
#  ('BsmtUnfSF', 25.544160847149644),
#  ('1stFlrSF', 115.03711766726501),
#  ('2ndFlrSF', 29.350010357639142),
#  ('LowQualFinSF', 2.0567523323712376),
#  ('BsmtFullBath', 4.164906517782721),
#  ('BsmtHalfBath', 1.3298295068114723),
#  ('FullBath', 34.279039354482606),
#  ('HalfBath', 4.382090097743207),
#  ('BedroomAbvGr', 45.56213494537319),
#  ('KitchenAbvGr', 59.32072104358191),
#  ('KitchenQual', 23.471221034925055),
#  ('TotRmsAbvGrd', 52.22311285918361),
#  ('Fireplaces', 3.458107696978718),
#  ('FireplaceQu', 11.360263309261075),
#  ('GarageYrBlt', 29695.716794717773),
#  ('GarageFinish', 7.355654636568919),
#  ('GarageCars', 26.68127976936111),
#  ('WoodDeckSF', 2.168728720214833),
#  ('OpenPorchSF', 2.126135955457439),
#  ('EnclosedPorch', 1.6283535083403837),
#  ('3SsnPorch', 1.1319746240774127),
#  ('ScreenPorch', 1.2666916368862557),
#  ('RoofStyleDummy_Shed', 1.3200777822694816),
#  ('Exterior1stDummy_AsphShn', 1.2491621768576389),
#  ('Exterior1stDummy_BrkComm', 1.1304579338270284),
#  ('Exterior1stDummy_BrkFace', 4.416525842700773),
#  ('Exterior1stDummy_CBlock', 1.198766974199867),
#  ('Exterior1stDummy_CemntBd', 5.625929488469798),
#  ('Exterior1stDummy_HdBoard', 19.686903716948166),
#  ('Exterior1stDummy_ImStucc', 1.1866194535038663),
#  ('Exterior1stDummy_MetalSd', 17.592243449494454),
#  ('Exterior1stDummy_Plywood', 9.851708403976446),
#  ('Exterior1stDummy_Stone', 1.220673126166022),
#  ('Exterior1stDummy_Stucco', 1.8741683065380355),
#  ('Exterior1stDummy_VinylSd', 43.910297360062124),
#  ('Exterior1stDummy_Wd Sdng', 15.133455968653426),
#  ('Exterior1stDummy_WdShing', 2.8787258496017034),
#  ('MasVnrTypeDummy_BrkFace', 40.391625866625596),
#  ('MasVnrTypeDummy_No_MasVnr', 1.7746084611982698),
#  ('MasVnrTypeDummy_None', 74.99175323027329),
#  ('MasVnrTypeDummy_Stone', 12.137070011090028),
#  ('FoundationDummy_CBlock', 11.695779281600348),
#  ('FoundationDummy_PConc', 14.048688373744467),
#  ('FoundationDummy_Slab', 2.400693175525652),
#  ('FoundationDummy_Stone', 1.1485504780782982),
#  ('FoundationDummy_Wood', 1.2356884651162179),
#  ('GarageTypeDummy_Attchd', 245.81888995642652),
#  ('GarageTypeDummy_Basment', 5.836438414854051),
#  ('GarageTypeDummy_BuiltIn', 22.295987521130705),
#  ('GarageTypeDummy_CarPort', 2.9189037134989184),
#  ('GarageTypeDummy_Detchd', 99.75940616996698),
#  ('GarageTypeDummy_No_Garage', 1224.952577470733),
#  ('SaleConditionDummy_AdjLand', 1.0682682393276401),
#  ('SaleConditionDummy_Alloca', 1.5542888454778514),
#  ('SaleConditionDummy_Family', 1.3454635945928106),
#  ('SaleConditionDummy_Normal', 17.002542792386254),
#  ('SaleConditionDummy_Partial', 2.995726473382873)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# GarageYrBlt                 GarageTypeDummy_No_Garage     0.996864
# RoofStyleDummy_Gable        RoofStyleDummy_Hip            0.983049
# MSZoningDummy_FV            NeighborhoodDummy_Somerst     0.971615
# 2ndFlrSF                    NumFloors                     0.968266
#                             HouseStyleDummy_2Story        0.964449
# ExterQual                   KitchenQual                   0.958222
# NumFloors                   HouseStyleDummy_1Story        0.950755
# ExterQual                   BsmtQual                      0.949179
# BsmtQual                    FoundationDummy_PConc         0.948123
# MasVnrArea                  MasVnrTypeDummy_None          0.939016
# FoundationDummy_CBlock      FoundationDummy_PConc         0.934248
# YearRemodAdd                BsmtQual                      0.932048
# HalfBath                    HouseStyleDummy_2Story        0.931176
# YearRemodAdd                FoundationDummy_PConc         0.930927
# YearBuilt                   BsmtQual                      0.927297
# Exterior1stDummy_VinylSd    FoundationDummy_PConc         0.921199
# NumFloors                   HouseStyleDummy_2Story        0.917223
# ExterQual                   FoundationDummy_PConc         0.916367
# YearRemodAdd                ExterQual                     0.913503
# BsmtQual                    KitchenQual                   0.909514
# BsmtFinSF1                  BsmtFullBath                  0.909056
# 2ndFlrSF                    HouseStyleDummy_1Story        0.908133
# GarageTypeDummy_Attchd      GarageTypeDummy_Detchd        0.898733
# BsmtQual                    GarageCars                    0.893595
# MasVnrTypeDummy_BrkFace     MasVnrTypeDummy_None          0.893402
# YearBuilt                   FoundationDummy_PConc         0.892655
#                             GarageCars                    0.892485
#                             YearRemodAdd                  0.892427
# YearRemodAdd                KitchenQual                   0.892281
# 2ndFlrSF                    HalfBath                      0.891356
# BsmtQual                    FullBath                      0.889666
# YearRemodAdd                Exterior1stDummy_VinylSd      0.889297
# YearBuilt                   ExterQual                     0.887114
# ExterQual                   GarageCars                    0.882375
# MSZoningDummy_RL            MSZoningDummy_RM              0.878231
# BsmtQual                    Exterior1stDummy_VinylSd      0.877876
# FullBath                    FoundationDummy_PConc         0.876538
# AlleyDummy_No_Alley_Access  AlleyDummy_Pave               0.876489
# KitchenQual                 FoundationDummy_PConc         0.872911
# FullBath                    GarageCars                    0.871681
# BsmtQual                    GarageFinish                  0.859439
# MasVnrArea                  MasVnrTypeDummy_BrkFace       0.856586
# YearRemodAdd                FullBath                      0.856008
# YearBuilt                   FullBath                      0.854892
# ExterQual                   FullBath                      0.853665
# YearBuilt                   Exterior1stDummy_VinylSd      0.852719
# SaleConditionDummy_Normal   SaleConditionDummy_Partial    0.851998
# KitchenQual                 GarageCars                    0.848621
# YearBuilt                   GarageFinish                  0.847947
# Exterior1stDummy_VinylSd    FoundationDummy_CBlock        0.843646
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209788243540.12234, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193438913938.767, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201724929718.38934, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153412323948.85046, tolerance: 497016804.70499045
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199678522983.33386, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114518522459.77682, tolerance: 502026956.9861996
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72002604465.17352, tolerance: 462374858.1220429
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117467049761.07698, tolerance: 510274910.65851074
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100948255684.26735, tolerance: 497551680.5459313
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 3556.9360913296287),
#  ('LotArea', 4240.1606114782635),
#  ('OverallCond', 7451.981397821022),
#  ('YearBuilt', 10286.48343608039),
#  ('YearRemodAdd', 540.7562399604716),
#  ('MasVnrArea', 2789.5460213970496),
#  ('ExterQual', -5307.013180844038),
#  ('BsmtQual', -3944.6278938262008),
#  ('BsmtExposure', -1964.928169387696),
#  ('BsmtFinType1', 163.59486128724956),
#  ('BsmtFinSF1', 19112.190899321715),
#  ('BsmtFinSF2', 5428.682534433748),
#  ('BsmtUnfSF', 10839.325542744535),
#  ('1stFlrSF', 17049.980074161907),
#  ('2ndFlrSF', 25350.37845294272),
#  ('LowQualFinSF', 896.6395271823311),
#  ('BsmtFullBath', 101.32725682948991),
#  ('BsmtHalfBath', -545.6152912292062),
#  ('FullBath', -0.0),
#  ('HalfBath', 0.0),
#  ('BedroomAbvGr', -2783.6087549207123),
#  ('KitchenAbvGr', -4287.44555734101),
#  ('KitchenQual', -4791.356054934235),
#  ('TotRmsAbvGrd', 4041.630359105492),
#  ('Fireplaces', 2285.967022887128),
#  ('FireplaceQu', -1430.372608757118),
#  ('GarageYrBlt', -0.0),
#  ('GarageFinish', -1597.7952226799105),
#  ('GarageCars', 5896.2857119609425),
#  ('WoodDeckSF', 1087.5871490198922),
#  ('OpenPorchSF', 1593.763981550481),
#  ('EnclosedPorch', 576.8702988254978),
#  ('3SsnPorch', 552.9103718227251),
#  ('ScreenPorch', 1502.0084898090372),
#  ('Fence', 45.03267889751899),
#  ('MiscVal', 382.9664956017569),
#  ('MoSold', 146.69424519751993),
#  ('YrSold', -0.0),
#  ('hasBeenRemodeled', 124.00991454500442),
#  ('NumFloors', -2130.032718139131),
#  ('MSZoningDummy_FV', 2276.775865987664),
#  ('MSZoningDummy_RH', 957.2183342294597),
#  ('MSZoningDummy_RL', 2371.7069234086066),
#  ('MSZoningDummy_RM', -0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', -463.24032875686595),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -489.85086007614296),
#  ('LotShapeDummy_Reg', 748.1156026523137),
#  ('LotConfigDummy_CulDSac', 1360.3679375819672),
#  ('LotConfigDummy_FR2', -831.3457466385088),
#  ('LotConfigDummy_FR3', -847.4195524934901),
#  ('LotConfigDummy_Inside', 250.9156501509823),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrDale', 1312.9648156893238),
#  ('NeighborhoodDummy_BrkSide', 1720.6901298980713),
#  ('NeighborhoodDummy_ClearCr', -230.31636615227032),
#  ('NeighborhoodDummy_CollgCr', 806.0376399770666),
#  ('NeighborhoodDummy_Crawfor', 3022.9371507974456),
#  ('NeighborhoodDummy_Edwards', -1860.616773174919),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', 864.7167002963623),
#  ('NeighborhoodDummy_MeadowV', -895.6509416653633),
#  ('NeighborhoodDummy_Mitchel', -690.0346874841705),
#  ('NeighborhoodDummy_NAmes', -1003.528251121091),
#  ('NeighborhoodDummy_NPkVill', 573.5025717118563),
#  ('NeighborhoodDummy_NWAmes', -1034.6722242762266),
#  ('NeighborhoodDummy_NoRidge', 4466.66795877154),
#  ('NeighborhoodDummy_NridgHt', 6800.567442475425),
#  ('NeighborhoodDummy_OldTown', 655.3512728887985),
#  ('NeighborhoodDummy_SWISU', -0.0),
#  ('NeighborhoodDummy_Sawyer', -91.64331118522279),
#  ('NeighborhoodDummy_SawyerW', -0.0),
#  ('NeighborhoodDummy_Somerst', 2343.9719187588216),
#  ('NeighborhoodDummy_StoneBr', 3991.7484114444483),
#  ('NeighborhoodDummy_Timber', 1015.3164665607685),
#  ('NeighborhoodDummy_Veenker', 174.91293743740667),
#  ('HouseStyleDummy_1.5Unf', 844.9210472118143),
#  ('HouseStyleDummy_1Story', 0.0),
#  ('HouseStyleDummy_2.5Fin', -1230.8403688484407),
#  ('HouseStyleDummy_2.5Unf', 14.083322729271691),
#  ('HouseStyleDummy_2Story', -1482.7528151454421),
#  ('HouseStyleDummy_SFoyer', -133.77613818511918),
#  ('HouseStyleDummy_SLvl', 971.3082696193007),
#  ('RoofStyleDummy_Gable', -0.0),
#  ('RoofStyleDummy_Gambrel', 574.8750741716855),
#  ('RoofStyleDummy_Hip', 1522.634923505378),
#  ('RoofStyleDummy_Mansard', -0.0),
#  ('RoofStyleDummy_Shed', 758.1396333083694),
#  ('Exterior1stDummy_AsphShn', 198.5403480951032),
#  ('Exterior1stDummy_BrkComm', -656.5039630561175),
#  ('Exterior1stDummy_BrkFace', 1957.4636675885902),
#  ('Exterior1stDummy_CBlock', -1125.0572626904761),
#  ('Exterior1stDummy_CemntBd', 289.05228696425206),
#  ('Exterior1stDummy_HdBoard', -1533.7705886774454),
#  ('Exterior1stDummy_ImStucc', -274.04784366861253),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Plywood', -1323.3196918612875),
#  ('Exterior1stDummy_Stone', 0.0),
#  ('Exterior1stDummy_Stucco', 1190.568662966845),
#  ('Exterior1stDummy_VinylSd', 0.0),
#  ('Exterior1stDummy_Wd Sdng', -539.594461226341),
#  ('Exterior1stDummy_WdShing', 78.86400356104663),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_No_MasVnr', -57.96041123550897),
#  ('MasVnrTypeDummy_None', 1484.5635618078081),
#  ('MasVnrTypeDummy_Stone', 1392.0520929625877),
#  ('FoundationDummy_CBlock', -1159.363383886193),
#  ('FoundationDummy_PConc', 233.85551649793084),
#  ('FoundationDummy_Slab', 1119.2635657537096),
#  ('FoundationDummy_Stone', 0.0),
#  ('FoundationDummy_Wood', -1403.4859199118564),
#  ('GarageTypeDummy_Attchd', 0.0),
#  ('GarageTypeDummy_Basment', 638.9053690847668),
#  ('GarageTypeDummy_BuiltIn', -0.0),
#  ('GarageTypeDummy_CarPort', -658.7948200693879),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', 855.9837189309508),
#  ('SaleConditionDummy_AdjLand', 739.5434864869997),
#  ('SaleConditionDummy_Alloca', 1079.9688213013817),
#  ('SaleConditionDummy_Family', 440.03593009755855),
#  ('SaleConditionDummy_Normal', 2755.549402113324),
#  ('SaleConditionDummy_Partial', 5668.509050825461)]

# %%
stats.summary(gridLasso.best_estimator_, X_Scaled, y)
# Out:
# Residuals:
#        Min         1Q     Median          3Q         Max
# 42657.2241 130454.784 166288.023 216352.8567 443552.7088
#
#
# Coefficients:
#                  Estimate    Std. Error   t value   p value
# _intercept  178528.608828    569.493955  313.4864  0.000000
# x1            3556.936091    824.053462    4.3164  0.000017
# x2            4240.160611    764.471005    5.5465  0.000000
# x3            7451.981398    747.994671    9.9626  0.000000
# x4           10286.483436   1756.960790    5.8547  0.000000
