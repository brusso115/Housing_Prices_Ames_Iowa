# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2386.904541135078), ('GrLivArea', 1523.9095945417237), ('ExterQual', 1071.111729210286), ('GarageCars', 1067.518759478655), ('GarageArea', 962.2978293611327), ('TotalBsmtSF', 895.2316046556983), ('KitchenQual', 840.260126495177), ('BsmtQual', 814.9288563965226), ('1stFlrSF', 786.4474392119956), ('YearBuilt', 666.3406334655103), ('FullBath', 656.3755104405316), ('TotRmsAbvGrd', 548.5649261473343), ('YearRemodAdd', 507.4311656554456), ('GarageFinish', 346.36707008410787), ('Fireplaces', 317.16642082824), ('HeatingQC', 305.3427996908775), ('MasVnrArea', 303.4224616944494), ('NeighborhoodDummy_NridgHt', 255.07596068881594), ('MSSubClassDummy_60', 219.1479897415808), ('BsmtFinSF1', 199.382319452767), ('LotFrontage', 186.21796900502935), ('OpenPorchSF', 174.83723022149957), ('NeighborhoodDummy_NoRidge', 147.4179581952685), ('WoodDeckSF', 145.5625379061476), ('MSZoningDummy_RM', 143.8752422822495), ('BsmtExposure', 134.7766753782809), ('LotArea', 129.3996938356395), ('2ndFlrSF', 109.5717445779698), ('HalfBath', 93.28258978815563), ('LotShapeDummy_Reg', 89.35305736074083), ('MSSubClassDummy_30', 85.13313685078316), ('BsmtFullBath', 80.67702951906759), ('MSZoningDummy_RL', 79.09136409121506), ('GarageYrBlt', 76.49489622371019), ('BsmtUnfSF', 71.05873281717845), ('NeighborhoodDummy_NAmes', 68.02076994913782), ('NeighborhoodDummy_OldTown', 62.83109498591884), ('GarageQual', 59.2161004328165), ('GarageCond', 57.31054279331668), ('NeighborhoodDummy_StoneBr', 52.99336392783103), ('NeighborhoodDummy_Edwards', 45.87321784745723), ('Fence', 45.81420398937584), ('MSSubClassDummy_50', 45.50049291164994), ('NeighborhoodDummy_Somerst', 37.271009765909014), ('BedroomAbvGr', 34.047122679430075), ('NeighborhoodDummy_IDOTRR', 33.24509699777731), ('OverallCond', 32.848386878199875), ('NeighborhoodDummy_Sawyer', 29.153534357043412), ('EnclosedPorch', 26.411519076751347), ('NumFloors', 26.346713007753003), ('NeighborhoodDummy_Timber', 26.074958883388792), ('NeighborhoodDummy_BrkSide', 24.761038598693137), ('MSSubClassDummy_160', 24.338452210637946), ('ExterCond', 22.812112540725344), ('NeighborhoodDummy_BrDale', 19.88075557382004), ('Condition1Dummy_Norm', 19.621815463636956), ('LotConfigDummy_CulDSac', 18.377231590953112), ('MSZoningDummy_FV', 17.285895606213884), ('NeighborhoodDummy_MeadowV', 16.59310815684944), ('Condition1Dummy_Feedr', 15.214021911289104), ('KitchenAbvGr', 14.637051122656983), ('AlleyDummy_No_Alley_Access', 13.219696040140107), ('NeighborhoodDummy_CollgCr', 12.016095852944407), ('MSSubClassDummy_90', 11.899302634566629), ('LandContourDummy_HLS', 11.499520962667308), ('BsmtFinType2', 9.539437493920367), ('MSSubClassDummy_45', 9.158843223164759), ('LotConfigDummy_Inside', 7.6984892238694105), ('NeighborhoodDummy_SWISU', 7.430229102008702), ('LotShapeDummy_IR2', 7.387783462098833), ('NeighborhoodDummy_ClearCr', 7.340634950616994), ('FireplaceQu', 7.069044267443624), ('MoSold', 7.068072314909948), ('MSSubClassDummy_190', 6.87405782160697), ('BsmtFinType1', 6.744383550515323), ('MSZoningDummy_RH', 6.674480710591939), ('MSSubClassDummy_120', 6.240714687008825), ('NeighborhoodDummy_Mitchel', 6.17263853868405), ('LowQualFinSF', 5.789753306398067), ('ScreenPorch', 5.586513349213087), ('MSSubClassDummy_180', 5.418573247077756), ('MSSubClassDummy_85', 4.956483220665854), ('BsmtHalfBath', 4.256458631328245), ('Condition1Dummy_PosA', 3.652228275344007), ('BsmtCond', 3.6432796175178193), ('MSSubClassDummy_70', 3.641378934378932), ('NeighborhoodDummy_Gilbert', 3.1677957228996294), ('NeighborhoodDummy_Veenker', 2.983188762647648), ('LandContourDummy_Low', 2.7297602260469573), ('3SsnPorch', 2.6930643498713907), ('NeighborhoodDummy_NPkVill', 2.6658315270558983), ('LotShapeDummy_IR3', 2.647083401501284), ('MSSubClassDummy_80', 2.4566003045519613), ('NeighborhoodDummy_Crawfor', 2.365979545089814), ('LotConfigDummy_FR3', 1.9771717595368898), ('BsmtFinSF2', 1.4361847026992534), ('LandSlope', 1.2112668391325745), ('NeighborhoodDummy_Sawyer ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.49876428, 0.25402355]),
#  'std_fit_time': array([0.05638619, 0.03088132]),
#  'mean_score_time': array([0.0132453 , 0.01195054]),
#  'std_score_time': array([0.00262657, 0.00209572]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86610875, 0.884809  ]),
#  'split1_test_score': array([0.89542409, 0.87854577]),
#  'split2_test_score': array([0.86181292, 0.8532341 ]),
#  'split3_test_score': array([0.88546893, 0.89187794]),
#  'split4_test_score': array([0.8884314 , 0.87904303]),
#  'mean_test_score': array([0.87944922, 0.87750197]),
#  'std_test_score': array([0.01312341, 0.01305722]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.879449217755251

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.5397226527374442),
#  ('GrLivArea', 0.11348151332553008),
#  ('GarageArea', 0.052256585871764225),
#  ('TotalBsmtSF', 0.04386524191756767),
#  ('BsmtFinSF1', 0.043244253694246525),
#  ('GarageCars', 0.03486408377031085),
#  ('1stFlrSF', 0.02385281162179077),
#  ('BsmtQual', 0.01036849145757127),
#  ('FullBath', 0.009563518972210241),
#  ('LotArea', 0.00881093178289784),
#  ('YearBuilt', 0.008183161334305637),
#  ('YearRemodAdd', 0.007938662082466819),
#  ('BsmtUnfSF', 0.006793605347501308),
#  ('MasVnrArea', 0.005843336422613111),
#  ('LotFrontage', 0.0049183418452951495),
#  ('OpenPorchSF', 0.0049044005473932095),
#  ('OverallCond', 0.0048935366954761285),
#  ('KitchenQual', 0.00465707401265512),
#  ('GarageYrBlt', 0.004603630409096919),
#  ('WoodDeckSF', 0.00415388642705952),
#  ('2ndFlrSF', 0.003786371984125217),
#  ('ExterQual', 0.0031137503128934553),
#  ('GarageFinish', 0.003095136209359691),
#  ('MoSold', 0.002793507936320655),
#  ('FunctionalDummy_Typ', 0.0024529287770636453),
#  ('BsmtExposure', 0.0024410800049242637),
#  ('GarageTypeDummy_CarPort', 0.0020848235760468014),
#  ('BsmtFinType1', 0.002020033088294759),
#  ('BedroomAbvGr', 0.0020074673707919256),
#  ('TotRmsAbvGrd', 0.0019770428381377138),
#  ('Fireplaces', 0.0018283875711812903),
#  ('YrSold', 0.0015443137481305524),
#  ('FireplaceQu', 0.0014940423630637346),
#  ('HalfBath', 0.0014762048601817408),
#  ('BsmtFullBath', 0.0012018503125467664),
#  ('NeighborhoodDummy_CollgCr', 0.0009338989077105085),
#  ('MSZoningDummy_RL', 0.0008981272428495873),
#  ('EnclosedPorch', 0.0008417603680998171),
#  ('HeatingQC', 0.0007510930971221569),
#  ('SaleTypeDummy_ConLD', 2.518904867379416e-06),
#  ('Exterior1stDummy_Plywood', 2.4429963130876e-06),
#  ('MSSubClassDummy_40', 2.3520493224088637e-06),
#  ('FoundationDummy_Slab', 2.343363096245397e-06),
#  ('SaleTypeDummy_WD', 2.3263389318002835e-06),
#  ('MSSubClassDummy_180', 2.0711104287296394e-06),
#  ('Condition2Dummy_RRNn', 2.0592112632188483e-06),
#  ('BldgTypeDummy_TwnhsE', 1.8960690268601997e-06),
#  ('FoundationDummy_Wood', 1.887702478462951e-06),
#  ('Exterior1stDummy_WdShing', 1.7586734036584559e-06),
#  ('SaleTypeDummy_New', 1.7492216900200177e-06),
#  ('Condition2Dummy_RRAn', 1.5217830889507363e-06),
#  ('HeatingDummy_GasW', 1.35966631262522e-06),
#  ('SaleTypeDummy_CWD', 1.2454620446950476e-06),
#  ('MSZoningDummy_RM', 1.2088454250240287e-06),
#  ('HouseStyleDummy_2.5Fin', 8.233636979412169e-07),
#  ('RoofMatlDummy_CompShg', 7.341018424363717e-07),
#  ('LotShapeDummy_IR2', 4.925571810704141e-07),
#  ('Exterior2ndDummy_HdBoard', 4.167325061403233e-07),
#  ('Condition1Dummy_RRNn', 3.2051318583036224e-07),
#  ('RoofMatlDummy_Tar&Grv', 2.997615554751201e-07),
#  ('Exterior2ndDummy_BrkFace', 2.9531635353600343e-07),
#  ('MSSubClassDummy_30', 2.3430276825059105e-07),
#  ('RoofStyleDummy_Hip', 1.7849502146201008e-07),
#  ('Condition1Dummy_RRAn', 1.4989381321965662e-07),
#  ('Exterior1stDummy_HdBoard', 1.4531540871512482e-07),
#  ('MiscFeatureDummy_No_Misc_Feature', 1.0050396335076024e-07),
#  ('RoofMatlDummy_Metal', 9.868682623644774e-09),
#  ('LandContourDummy_Lvl', 7.896003401753796e-09),
#  ('Condition2Dummy_RRAe', 4.431423573988209e-09),
#  ('Exterior1stDummy_BrkFace', 1.2788460185000606e-11),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.03081017, 0.00793428, 0.00809541, 0.00587411, 0.00648704,
#         0.00786867, 0.00752335, 0.00768337]),
#  'std_fit_time': array([0.04642217, 0.00069297, 0.00106363, 0.00037643, 0.0005171 ,
#         0.00065438, 0.00031971, 0.00071088]),
#  'mean_score_time': array([0.00405178, 0.00449796, 0.0041326 , 0.00318856, 0.00368695,
#         0.00396175, 0.00427227, 0.00404186]),
#  'std_score_time': array([0.00034168, 0.00031065, 0.00059442, 0.00016831, 0.00057165,
#         0.00031403, 0.00050361, 0.00015988]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.90541948, 0.90692986, 0.90860753, 0.90952969, 0.90970113,
#         0.90972606, 0.89225477, 0.86777306]),
#  'split1_test_score': array([0.9083159 , 0.90956694, 0.91092037, 0.9111896 , 0.91103914,
#         0.91082537, 0.88830633, 0.85819172]),
#  'split2_test_score': array([0.86810564, 0.87761823, 0.88575558, 0.89142332, 0.89246509,
#         0.89304057, 0.87904987, 0.853965  ]),
#  'split3_test_score': array([0.8924442 , 0.89276143, 0.89425317, 0.89849344, 0.90005195,
#         0.90116682, 0.89557017, 0.87549865]),
#  'split4_test_score': array([0.89173461, 0.89237197, 0.89323261, 0.89499523, 0.89532407,
#         0.89538089, 0.87577379, 0.84961814]),
#  'mean_test_score': array([0.89320396, 0.89584968, 0.89855385, 0.90112626, 0.90171627,
#         0.90202794, 0.88619099, 0.86100931]),
#  'std_test_score': array([0.01421444, 0.01153214, 0.00963965, 0.00788108, 0.00748182,
#         0.00724367, 0.00759904, 0.00941285]),
#  'rank_test_score': array([6, 5, 4, 3, 2, 1, 7, 8], dtype=int32)}

# %%
gridRidge.best_params_
# Out:
# {'alpha': 100}

# %%
gridRidge.best_score_
# Out:
# 0.9020279405841283

# %%
gridRidge.best_estimator_.coef_
# Out:
# array([ 1.42411363e+03,  4.39891543e+03, -5.27084455e+02,  8.92542372e+03,
#         4.62915511e+03,  4.61015695e+03,  1.48949402e+03,  2.86068755e+03,
#        -3.89146914e+03,  8.75740224e+02, -3.77600257e+03,  3.41956232e+02,
#        -1.85295045e+03,  6.74996422e+01,  6.71653606e+03, -3.56345399e+02,
#         5.48010216e+02, -8.92176038e+02,  6.44476892e+03, -1.05675111e+03,
#         6.90589862e+03,  6.28636773e+03, -1.90126645e+02,  1.12268379e+04,
#         2.01385849e+03, -5.14695075e+02,  1.89115843e+03,  1.02503663e+03,
#        -2.10673625e+03, -2.18771697e+03, -4.60304232e+03,  2.69029450e+03,
#         1.61404325e+03, -1.12904167e+03, -6.65577988e+02, -9.30016056e+02,
#         2.93169821e+03,  3.07389520e+03,  3.83000996e+02, -6.80261946e+01,
#         2.05193771e+03,  1.69239207e+03,  2.58665739e+02,  5.52083023e+02,
#         1.21679029e+03,  1.03844590e+03,  4.53844789e+02,  3.03968514e+02,
#         1.44757999e+02, -3.55668819e+02, -2.35072738e+02,  9.00938031e+02,
#        -5.73044450e+02, -1.15712745e+03,  1.72153275e+02, -1.83536330e+02,
#        -1.23398418e+02,  1.34469198e+03,  3.68078314e+02, -2.63801086e+02,
#        -1.16518383e+03, -6.55354386e+02, -2.94792472e+02, -2.28380647e+03,
#        -1.82718769e+03,  3.83336959e+01, -5.02654740e+02,  1.49943536e+03,
#         1.19339288e+01,  9.70108537e+02, -1.58865015e+01,  7.13707709e+02,
#         1.16514078e+02, -3.55591709e+02,  1.75934666e+02, -1.81006586e+01,

# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 11226.837860900096),
#  ('OverallQual', 8925.423718691412),
#  ('1stFlrSF', 6905.89861637634),
#  ('BsmtFinSF1', 6716.5360611000915),
#  ('TotalBsmtSF', 6444.768919396862),
#  ('2ndFlrSF', 6286.367729833191),
#  ('NeighborhoodDummy_NoRidge', 4904.678957513426),
#  ('OverallCond', 4629.155105828485),
#  ('YearBuilt', 4610.156950254393),
#  ('KitchenQual', -4603.042315832949),
#  ('NeighborhoodDummy_Somerst', 4476.1547113779225),
#  ('LotArea', 4398.915426354886),
#  ('NeighborhoodDummy_NWAmes', 3917.60488040088),
#  ('ExterQual', -3891.4691351935903),
#  ('BsmtQual', -3776.002568673742),
#  ('FunctionalDummy_Sev', 3741.9273033605778),
#  ('SaleConditionDummy_Normal', 3146.4680366575026),
#  ('GarageArea', 3073.895198961391),
#  ('GarageCars', 2931.6982136058823),
#  ('MasVnrArea', 2860.687545787114),
#  ('TotRmsAbvGrd', 2690.294496034294),
#  ('Exterior1stDummy_BrkComm', 2674.38993359941),
#  ('Condition1Dummy_Feedr', 2491.7056375784086),
#  ('NeighborhoodDummy_Mitchel', -2353.300372548131),
#  ('SaleConditionDummy_Family', 2346.7134754740723),
#  ('BldgTypeDummy_Twnhs', -2315.762804922124),
#  ('MSSubClassDummy_90', -2283.8064746210534),
#  ('SaleTypeDummy_ConLw', 2265.1273273189295),
#  ('BldgTypeDummy_Duplex', -2260.102409491454),
#  ('KitchenAbvGr', -2187.71697121393),
#  ('MiscFeatureDummy_TenC', 2162.0637318649315),
#  ('BedroomAbvGr', -2106.736245133944),
#  ('WoodDeckSF', 2051.9377089493364),
#  ('BsmtFullBath', 2013.85848600024),
#  ('NeighborhoodDummy_Crawfor', -1933.4489542770236),
#  ('NeighborhoodDummy_CollgCr', 1911.9613418903346),
#  ('FunctionalDummy_Mod', -1892.3336970027708),
#  ('FullBath', 1891.1584267115602),
#  ('BsmtExposure', -1852.9504523608337),
#  ('MSSubClassDummy_120', -1827.187693674795),
#  ('NeighborhoodDummy_NridgHt', -1724.284472959126),
#  ('NeighborhoodDummy_ClearCr', -1713.7495379261545),
#  ('OpenPorchSF', 1692.3920663521321),
#  ('Exterior2ndDummy_CBlock', 1679.517046523084),
#  ('Fireplaces', 1614.0432488056665),
#  ('Exterior2ndDummy_Wd Sdng', -1566.6984375876586),
#  ('Exterior1stDummy_VinylSd', -1556.655215381876),
#  ('NeighborhoodDummy_NPkVill', -1542.3572408204473),
#  ('UtilitiesDummy_NoSeWa', 1502.267435453755),
#  ('MSSubClassDummy_190', 1499.43535820701),
#  ('NeighborhoodDummy_MeadowV', -1499.3705696338704),
#  ('YearRemodAdd', 1489.4940247486422),
#  ('NeighborhoodDummy_Edwards', -1487.1088434116605),
#  ('LotFrontage', 1424.1136330271067),
#  ('LandContourDummy_HLS', -1352.7750359621307),
#  ('MSSubClassDummy_50', 1344.6919823777314),
#  ('RoofMatlDummy_CompShg', 1339.7132383472301),
#  ('NeighborhoodDummy_Blueste', 1326.4391339560502),
#  ('MasVnrTypeDummy_None', 1283.4141153768248),
#  ('Exterior2ndDummy_Other', -1240.1188957339216),
#  ('LotShapeDummy_Reg', 1233.392783589744),
#  ('SaleTypeDummy_CWD', 1228.641354091096),
#  ('ScreenPorch', 1216.790293236618),
#  ('GarageTypeDummy_CarPort', 1214.6227337679709),
#  ('Condition1Dummy_PosN', -1184.8951528103894),
#  ('MSSubClassDummy_75', -1165.183826116805),
#  ('FoundationDummy_CBlock', 1162.8267363673272),
#  ('NumFloors', -1157.1274473664478),
#  ('FireplaceQu', -1129.041667815425),
#  ('HeatingQC', -1056.7511132457519),
#  ('PoolArea', 1038.445901342764),
#  ('HalfBath', 1025.036628625792),
#  ('Exterior1stDummy_Stone', 1018.1860674083031),
#  ('LotConfigDummy_CulDSac', -1007.1015215753363),
#  ('PavedDriveDummy_P', 988.8202084850765),
#  ('FoundationDummy_Stone', -980.1362659445115),
#  ('GarageTypeDummy_Basment', 971.1850513556883),
#  ('MSZoningDummy_RH', 970.1085371603881),
#  ('Exterior2ndDummy_CmentBd', -969.3631296773788),
#  ('Exterior1stDummy_CBlock', -963.4696055244093),
#  ('GarageFinish', -930.01605635054),
#  ('NeighborhoodDummy_OldTown', -922.6296597576367),
#  ('NeighborhoodDummy_NAmes', 905.5936666713567),
#  ('SalePrice', 900.9380312007476),
#  ('FunctionalDummy_Min2', -894.0094299641547),
#  ('BsmtUnfSF', -892.1760382794179),
#  ('Condition1Dummy_PosA', 879.6538491398486),
#  ('ExterCond', 875.7402241805939),
#  ('SaleConditionDummy_AdjLand', -870.7572724958194),
#  ('Exterior1stDummy_Wd Sdng', 854.2411360005516),
#  ('HouseStyleDummy_SFoyer', 853.064852063642),
#  ('FunctionalDummy_Min1', 802.6218171965768),
#  ('LandContourDummy_Lvl', -800.9207840114893),
#  ('HouseStyleDummy_2.5Unf', -790.6882633191976),
#  ('NeighborhoodDummy_Timber', 787.5257779301259),
#  ('FoundationDummy_PConc', 784.9460638456862),
#  ('HouseStyleDummy_SLvl', -781.6356470263137),
#  ('MasVnrTypeDummy_No_MasVnr', 775.9332429959179),
#  ('Exterior1stDummy_CemntBd', -757.8194966472936),
#  ('RoofStyleDummy_Mansard', 740.6884360271713),
#  ('RoofMatlDummy_WdShake', 739.8815694462398),
#  ('NeighborhoodDummy_BrkSide', 738.6559013156158),
#  ('LotConfigDummy_FR2', -729.6502641745726),
#  ('Exterior1stDummy_ImStucc', 714.4430307743878),
#  ('MSZoningDummy_RM', 713.707709161632),
#  ('RoofStyleDummy_Shed', -670.835180447032),
#  ('GarageYrBlt', -665.577987747625),
#  ('MSSubClassDummy_80', -655.3543856180842),
#  ('Exterior1stDummy_HdBoard', -650.930074505096),
#  ('Exterior2ndDummy_VinylSd', 639.4158713731484),
#  ('SaleTypeDummy_WD', 607.6660717125052),
#  ('NeighborhoodDummy_IDOTRR', -602.4758598781385),
#  ('NeighborhoodDummy_BrDale', 594.9792720116),
#  ('GarageTypeDummy_Detchd', 587.1563343065881),
#  ('hasBeenRemodeled', -573.0444496648626),
#  ('NeighborhoodDummy_Sawyer', -553.3882242739513),
#  ('3SsnPorch', 552.0830228776981),
#  ('BsmtFinSF2', 548.0102160343129),
#  ('LandSlope', -527.0844548677006),
#  ('BsmtHalfBath', -514.6950746128712),
#  ('LotShapeDummy_IR3', 510.1653007349363),
#  ('Condition2Dummy_RRNn', -502.6547395365675),
#  ('MSSubClassDummy_180', -502.65473953656516),
#  ('NeighborhoodDummy_SawyerW', 494.7191235393073),
#  ('CentralAirDummy_Y', -456.19679865451127),
#  ('PoolQC', 453.84478916978173),
#  ('FunctionalDummy_Maj2', 445.19417250306094),
#  ('Exterior1stDummy_MetalSd', -428.0057828144824),
#  ('ElectricalDummy_SBrkr', -405.85879613921145),
#  ('RoofStyleDummy_Gable', 403.212570210501),
#  ('MiscFeatureDummy_Othr', 389.8132558327549),
#  ('GarageQual', 383.0009964388603),
#  ('Exterior2ndDummy_Brk Cmn', -380.3789444577503),
#  ('NeighborhoodDummy_Gilbert', -380.01996273714343),
#  ('RoofMatlDummy_Metal', -376.51448769583254),
#  ('Exterior2ndDummy_Stucco', 373.3098822015883),
#  ('MSSubClassDummy_60', 368.07831445903975),
#  ('HouseStyleDummy_2Story', -363.1077109173769),
#  ('Condition1Dummy_RRAn', -359.0484308163866),
#  ('BsmtFinType2', -356.34539863803985),
#  ('FoundationDummy_Slab', -355.68725702719905),
#  ('MoSold', -355.668819053235),
#  ('AlleyDummy_No_Alley_Access', -355.5917092301451),
#  ('RoofStyleDummy_Gambrel', 354.0606968730189),
#  ('LotConfigDummy_FR3', -342.5757039310819),
#  ('BsmtCond', 341.95623169759045),
#  ('SaleTypeDummy_ConLD', 341.8455055785023),
#  ('Exterior2ndDummy_HdBoard', 340.24870202267573),
#  ('RoofMatlDummy_Tar&Grv', -334.17572124998765),
#  ('RoofMatlDummy_Membran', 328.26120585752005),
#  ('Condition1Dummy_RRAe', 322.90868423120304),
#  ('MasVnrTypeDummy_Stone', 315.1826084469213),
#  ('Condition1Dummy_RRNe', 314.56245822170274),
#  ('Exterior1stDummy_Plywood', 313.8041787499078),
#  ('Exterior2ndDummy_AsphShn', 309.98806615203677),
#  ('LotConfigDummy_Inside', 309.05539366164146),
#  ('Fence', 303.96851442770645),
#  ('RoofMatlDummy_Roll', 302.08134819718674),
#  ('MSSubClassDummy_85', -294.7924719574044),
#  ('BldgTypeDummy_2fmCon', -294.79247195738157),
#  ('SaleTypeDummy_Con', 286.7260261245021),
#  ('PavedDriveDummy_Y', -284.7762221488969),
#  ('Exterior1stDummy_BrkFace', -277.9364884440847),
#  ('Exterior2ndDummy_BrkFace', -277.9364884440763),
#  ('NeighborhoodDummy_StoneBr', -275.1012100037556),
#  ('GarageTypeDummy_Attchd', -274.5482920258415),
#  ('SaleTypeDummy_New', 270.57588185192344),
#  ('HouseStyleDummy_1.5Unf', -268.6824222327531),
#  ('Condition2Dummy_RRAe', -267.42880714302214),
#  ('Exterior1stDummy_AsphShn', -266.3650191111986),
#  ('MSSubClassDummy_70', -263.801086003705),
#  ('HeatingDummy_Wall', 259.2241562457003),
#  ('EnclosedPorch', 258.6657394156229),
#  ('GarageTypeDummy_BuiltIn', 257.8824571680776),
#  ('YrSold', -235.07273828487308),
#  ('Exterior1stDummy_WdShing', 234.13503929579574),
#  ('Condition2Dummy_Feedr', -233.73285554307188),
#  ('HouseStyleDummy_1Story', -233.10116315233302),
#  ('ElectricalDummy_FuseP', 201.8897746310402),
#  ('BldgTypeDummy_TwnhsE', 200.61767750426313),
#  ('SaleTypeDummy_ConLI', -194.7981399394875),
#  ('Condition1Dummy_RRNn', -194.77258094632379),
#  ('Exterior2ndDummy_MetalSd', -191.41633911387157),
#  ('LowQualFinSF', -190.1266451106173),
#  ('MSSubClassDummy_40', -183.53632987659282),
#  ('RoofStyleDummy_Hip', -180.7511589994336),
#  ('AlleyDummy_Pave', 175.93466591003417),
#  ('MSSubClassDummy_30', 172.15327519819402),
#  ('Exterior1stDummy_Stucco', -170.61864264291833),
#  ('Exterior2ndDummy_Plywood', -154.41809069442186),
#  ('MiscVal', 144.75799885287162),
#  ('Condition2Dummy_RRAn', -139.43273692365148),
#  ('HouseStyleDummy_2.5Fin', -139.39990083035778),
#  ('NeighborhoodDummy_Veenker', -129.49242009396696),
#  ('MSSubClassDummy_45', -123.39841765888694),
#  ('StreetDummy_Pave', 116.514078368446),
#  ('FoundationDummy_Wood', 110.51201722986437),
#  ('HeatingDummy_GasA', -92.85302804841665),
#  ('ElectricalDummy_Mix', 76.867593662889),
#  ('NeighborhoodDummy_SWISU', -73.66414197352717),
#  ('Exterior2ndDummy_Stone', 73.10951364949881),
#  ('HeatingDummy_GasW', -68.59748481263621),
#  ('GarageCond', -68.02619462751339),
#  ('BsmtFinType1', 67.49964218208883),
#  ('GarageTypeDummy_No_Garage', 58.70251245578161),
#  ('LandContourDummy_Low', 47.62439033120442),
#  ('SaleTypeDummy_Oth', -46.730550023264854),
#  ('Exterior2ndDummy_Wd Shng', 41.72565947542434),
#  ('MasVnrTypeDummy_BrkFace', 40.23572419265222),
#  ('MSSubClassDummy_160', 38.333695860833416),
#  ('SaleConditionDummy_Alloca', -27.76222366935374),
#  ('Condition1Dummy_Norm', -23.359838963915823),
#  ('Exterior2ndDummy_ImStucc', -19.79669398775526),
#  ('LotShapeDummy_IR2', -18.100658620815086),
#  ('MSZoningDummy_RL', -15.886501500793209),
#  ('MSZoningDummy_FV', 11.933928767079836),
#  ('MiscFeatureDummy_No_Misc_Feature', 11.915815959442904),
#  ('FunctionalDummy_Typ', 5.638673492554392),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144864406803.67862, tolerance: 492581568.1731299
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143021674505.29184, tolerance: 460897073.1229422
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143009070484.0156, tolerance: 501735851.5003171
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152209785126.97504, tolerance: 513928188.8441815
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141453193167.6188, tolerance: 492146431.50232774
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106742330973.63226, tolerance: 492581568.1731299
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112737766258.56976, tolerance: 460897073.1229422
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115516786773.60257, tolerance: 501735851.5003171
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105563978576.17018, tolerance: 513928188.8441815
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117260611550.3229, tolerance: 492146431.50232774
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7164106233.9973755, tolerance: 492581568.1731299
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.13662162, 0.12378221, 0.15210443, 0.11478624, 0.06367002,
#         0.05337009, 0.01824512, 0.017379  ]),
#  'std_fit_time': array([0.0173    , 0.00566936, 0.02133854, 0.01221933, 0.00320807,
#         0.00211379, 0.00502077, 0.00343136]),
#  'mean_score_time': array([0.00341177, 0.00284085, 0.00358648, 0.00349669, 0.00288377,
#         0.00306444, 0.0036746 , 0.00403185]),
#  'std_score_time': array([8.87653688e-04, 3.70451428e-04, 4.16822188e-04, 6.62173469e-04,
#         4.13199689e-05, 2.08318001e-04, 3.97937467e-04, 2.69991052e-04]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.90647926, 0.90590539, 0.9079104 , 0.90902785, 0.90957962,
#         0.9099292 , 0.904975  , 0.89229844]),
#  'split1_test_score': array([0.90863221, 0.90894647, 0.91100357, 0.9141559 , 0.91514504,
#         0.91617334, 0.9160329 , 0.904629  ]),
#  'split2_test_score': array([0.87222794, 0.87388736, 0.88053657, 0.89126108, 0.89465735,
#         0.89562157, 0.89222878, 0.87846438]),
#  'split3_test_score': array([0.89239213, 0.89254158, 0.89401925, 0.89730477, 0.89909041,
#         0.90037882, 0.90418357, 0.89213261]),
#  'split4_test_score': array([0.89176661, 0.89195761, 0.89248825, 0.89369965, 0.89472322,
#         0.89528537, 0.89967054, 0.89071687]),
#  'mean_test_score': array([0.89429963, 0.89464768, 0.89719161, 0.90108985, 0.90263913,
#         0.90347766, 0.90341816, 0.89164826]),
#  'std_test_score': array([0.01304592, 0.0124407 , 0.01109269, 0.00893622, 0.00828893,
#         0.0082612 , 0.00776387, 0.00829264]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9034776610762771

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 25355.059302348942),
#  ('OverallQual', 9990.87113289387),
#  ('YearBuilt', 8566.461398450532),
#  ('BsmtFinSF1', 8143.622084560888),
#  ('SaleConditionDummy_Normal', 5891.362152221055),
#  ('OverallCond', 5589.81677213882),
#  ('NeighborhoodDummy_NoRidge', 5533.767300089351),
#  ('FunctionalDummy_Sev', 5208.370563462911),
#  ('TotalBsmtSF', 5137.83805933733),
#  ('LotArea', 4992.712622334427),
#  ('NeighborhoodDummy_Somerst', 4615.827422281891),
#  ('KitchenQual', -4489.005170710303),
#  ('ExterQual', -3727.4751691057786),
#  ('NeighborhoodDummy_NWAmes', 3664.586168799064),
#  ('BsmtQual', -3534.2253887270504),
#  ('GarageCars', 3142.5861574528567),
#  ('Exterior1stDummy_BrkComm', 2882.888993120648),
#  ('BedroomAbvGr', -2819.2629864948126),
#  ('SaleConditionDummy_Family', 2743.172255709287),
#  ('KitchenAbvGr', -2737.2886930944815),
#  ('MSSubClassDummy_90', -2633.3391943674196),
#  ('Condition1Dummy_Feedr', 2583.707041681459),
#  ('BldgTypeDummy_Twnhs', -2543.509079002807),
#  ('BldgTypeDummy_Duplex', -2531.070989819598),
#  ('hasBeenRemodeled', -2493.261990736988),
#  ('MasVnrArea', 2333.187393041368),
#  ('MSSubClassDummy_120', -2268.4584872853916),
#  ('MiscFeatureDummy_TenC', 2154.6597292661027),
#  ('GarageArea', 2095.752150060405),
#  ('NeighborhoodDummy_CollgCr', 2035.3631136282088),
#  ('FunctionalDummy_Mod', -1839.0951211161635),
#  ('WoodDeckSF', 1801.978313345966),
#  ('NeighborhoodDummy_Blueste', 1755.8677338209673),
#  ('FunctionalDummy_Min1', 1681.6364267146225),
#  ('Exterior2ndDummy_Other', -1665.2918924249836),
#  ('Exterior2ndDummy_Wd Sdng', -1630.3015098562007),
#  ('BsmtFullBath', 1583.572657750611),
#  ('BsmtExposure', -1564.118024386999),
#  ('Exterior2ndDummy_CmentBd', -1545.8913874769805),
#  ('GarageTypeDummy_CarPort', 1523.3923789883104),
#  ('RoofMatlDummy_CompShg', 1520.647728780692),
#  ('MSSubClassDummy_190', 1515.662824195035),
#  ('OpenPorchSF', 1496.435749539075),
#  ('NeighborhoodDummy_Mitchel', -1480.1188172552563),
#  ('NeighborhoodDummy_NridgHt', -1449.3988173047665),
#  ('NeighborhoodDummy_Crawfor', -1388.7991067159858),
#  ('NeighborhoodDummy_NAmes', 1351.024883205969),
#  ('NeighborhoodDummy_ClearCr', -1319.2759732043528),
#  ('NeighborhoodDummy_MeadowV', -1312.6812646614494),
#  ('FoundationDummy_Stone', -1305.418702138086),
#  ('NeighborhoodDummy_NPkVill', -1287.8631505143921),
#  ('LandContourDummy_HLS', -1284.7135112662722),
#  ('UtilitiesDummy_NoSeWa', 1274.77705988533),
#  ('Exterior2ndDummy_CBlock', 1254.4669972210427),
#  ('Condition1Dummy_PosN', -1247.1192272426056),
#  ('SaleTypeDummy_CWD', 1235.5815471848186),
#  ('GarageYrBlt', -1203.3465118956708),
#  ('ScreenPorch', 1190.0776477505037),
#  ('MasVnrTypeDummy_None', 1146.3741285434228),
#  ('LotShapeDummy_Reg', 1138.4725108440682),
#  ('TotRmsAbvGrd', 1137.055456303117),
#  ('BsmtFinSF2', 1042.5596393318026),
#  ('Exterior1stDummy_Stone', 1013.0367621653297),
#  ('FireplaceQu', -988.9336897466213),
#  ('Fireplaces', 985.0050783779302),
#  ('FunctionalDummy_Maj2', 978.421614838881),
#  ('Exterior1stDummy_Wd Sdng', 947.9106066246302),
#  ('NeighborhoodDummy_BrDale', 932.3377345870614),
#  ('Exterior1stDummy_VinylSd', -885.9159229124327),
#  ('Condition1Dummy_PosA', 866.5826045761527),
#  ('2ndFlrSF', 839.5372837161109),
#  ('HouseStyleDummy_SLvl', -835.7582498047317),
#  ('MasVnrTypeDummy_No_MasVnr', 826.3598642697749),
#  ('RoofMatlDummy_WdShake', 814.9479693463112),
#  ('Exterior1stDummy_CBlock', -811.7968748359752),
#  ('LowQualFinSF', -794.0889133022562),
#  ('YearRemodAdd', 788.5976950568294),
#  ('NeighborhoodDummy_Edwards', -768.3879647352376),
#  ('LotFrontage', 760.9101375494922),
#  ('HeatingQC', -756.3478973323341),
#  ('SalePrice', 748.5201862920865),
#  ('GarageFinish', -748.3711068545744),
#  ('NeighborhoodDummy_Timber', 741.5154677626956),
#  ('LotConfigDummy_CulDSac', -735.6434892711861),
#  ('MSZoningDummy_RH', 691.877771084662),
#  ('MSZoningDummy_RM', 688.6312579601931),
#  ('NeighborhoodDummy_OldTown', -688.2401263651533),
#  ('HouseStyleDummy_2Story', -688.1416274773168),
#  ('LotConfigDummy_FR2', -672.488998042976),
#  ('MSSubClassDummy_70', -657.3120865283605),
#  ('ExterCond', 649.8798650777758),
#  ('SaleConditionDummy_AdjLand', -640.0264665087942),
#  ('Exterior1stDummy_ImStucc', 638.7238654158325),
#  ('SaleTypeDummy_WD', 625.7545242330422),
#  ('LandContourDummy_Lvl', -617.4158234792671),
#  ('Exterior2ndDummy_Brk Cmn', -615.2974224545609),
#  ('NeighborhoodDummy_SawyerW', 609.6043299825959),
#  ('HouseStyleDummy_2.5Unf', -600.0277867464297),
#  ('RoofStyleDummy_Mansard', 591.4796873181901),
#  ('PavedDriveDummy_P', 586.051670354692),
#  ('Exterior1stDummy_HdBoard', -581.4568291170946),
#  ('NeighborhoodDummy_BrkSide', 574.9762824451503),
#  ('PoolArea', 560.973789879678),
#  ('RoofMatlDummy_Roll', 545.1765177313662),
#  ('LotShapeDummy_IR3', 543.7247381415233),
#  ('LandSlope', -518.1412418540176),
#  ('NumFloors', -513.1181208662426),
#  ('BsmtCond', 478.7337236663424),
#  ('RoofMatlDummy_Membran', 470.83452225652013),
#  ('FunctionalDummy_Min2', -457.72973621278743),
#  ('CentralAirDummy_Y', -450.4802895547213),
#  ('NeighborhoodDummy_Sawyer', -431.46020834654735),
#  ('Condition1Dummy_RRAe', 423.64542067795475),
#  ('MSSubClassDummy_180', -416.5162976196104),
#  ('BsmtHalfBath', -415.40811426700384),
#  ('AlleyDummy_No_Alley_Access', -383.54606702562455),
#  ('3SsnPorch', 381.1593972369986),
#  ('GarageTypeDummy_Basment', 374.8338704312697),
#  ('EnclosedPorch', 374.4823781033353),
#  ('FoundationDummy_CBlock', 373.3410940734044),
#  ('NeighborhoodDummy_SWISU', 359.17243920097013),
#  ('FoundationDummy_PConc', 351.66259334461824),
#  ('Exterior1stDummy_BrkFace', -338.19506483347175),
#  ('PavedDriveDummy_Y', -323.1057010657808),
#  ('MoSold', -314.1061200009101),
#  ('MiscFeatureDummy_Othr', 310.61906825584794),
#  ('Condition1Dummy_RRNe', 305.35312822583523),
#  ('GarageTypeDummy_BuiltIn', 268.635159144804),
#  ('RoofStyleDummy_Gable', 226.22128954772188),
#  ('MSSubClassDummy_60', 225.73120726370115),
#  ('SaleTypeDummy_New', 219.67326018852063),
#  ('Exterior2ndDummy_MetalSd', -209.8643834067523),
#  ('BsmtFinType2', -204.13923593586563),
#  ('BldgTypeDummy_2fmCon', -200.32898226217404),
#  ('Condition1Dummy_RRAn', -198.40255195168783),
#  ('HeatingDummy_GasA', -193.24449439064108),
#  ('LotConfigDummy_Inside', 190.11492482678224),
#  ('MSSubClassDummy_80', -176.64205732043257),
#  ('BsmtFinType1', 174.97021834858762),
#  ('LotConfigDummy_FR3', -167.9920620044909),
#  ('SaleConditionDummy_Alloca', 163.5180607558387),
#  ('GarageQual', 155.2805475021254),
#  ('HouseStyleDummy_1Story', -139.91046205642039),
#  ('ElectricalDummy_FuseP', 125.86888767073305),
#  ('FullBath', 122.29918280895629),
#  ('SaleTypeDummy_ConLD', 121.99182042450212),
#  ('Condition2Dummy_RRNn', -116.50670244908359),
#  ('MSSubClassDummy_75', -112.15998826738821),
#  ('GarageTypeDummy_Attchd', -109.28383659406755),
#  ('RoofMatlDummy_Metal', -104.65071138483553),
#  ('Exterior1stDummy_CemntBd', -92.9541219411876),
#  ('Exterior2ndDummy_HdBoard', 91.59902143119368),
#  ('FoundationDummy_Slab', -89.66597443353237),
#  ('SaleTypeDummy_ConLI', -85.7735692617448),
#  ('YrSold', -85.22229605098832),
#  ('FoundationDummy_Wood', 70.96572763668425),
#  ('BldgTypeDummy_TwnhsE', 56.82068081587229),
#  ('SaleTypeDummy_Con', 56.013816630618194),
#  ('Exterior1stDummy_Plywood', 54.31121727465855),
#  ('Exterior1stDummy_AsphShn', -52.254642147456146),
#  ('AlleyDummy_Pave', 52.11752490464386),
#  ('Exterior1stDummy_WdShing', 51.758121939889755),
#  ('Exterior2ndDummy_Stone', 41.03966899011093),
#  ('Condition2Dummy_RRAe', -39.597627121521995),
#  ('NeighborhoodDummy_StoneBr', -31.411688172455154),
#  ('Condition1Dummy_RRNn', 28.989999262519873),
#  ('MiscVal', 22.55570402539216),
#  ('Exterior2ndDummy_BrkFace', -3.0125305443832766),
#  ('Fence', 2.585634294032553),
#  ('MSSubClassDummy_85', -1.3693246772500873),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('HalfBath', 0.0),
#  ('GarageCond', 0.0),
#  ('PoolQC', 0.0),
#  ('MSSubClassDummy_30', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_160', 0.0),
#  ('MSZoningDummy_FV', -0.0),
#  ('MSZoningDummy_RL', -0.0),
#  ('StreetDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LandContourDummy_Low', 0.0),
#  ('NeighborhoodDummy_Gilbert', -0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('NeighborhoodDummy_Veenker', 0.0),
#  ('Condition1Dummy_Norm', -0.0),
#  ('Condition2Dummy_Feedr', -0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_SFoyer', 0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Shed', -0.0),
#  ('RoofMatlDummy_Tar&Grv', -0.0),
#  ('RoofMatlDummy_WdShngl', 0.0),
#  ('Exterior1stDummy_MetalSd', -0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_Plywood', -0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', 0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_Stone', -0.0),
#  ('HeatingDummy_GasW', -0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_OthW', 0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', 0.0),
#  ('FunctionalDummy_Typ', -0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', 0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType','MSSubClass']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.best_score_

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.best_score_

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)

# %%
mostCorrelatedFeat.head(50)

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
stats.coef_pval(gridLasso.best_estimator_, X_Scaled, y)
