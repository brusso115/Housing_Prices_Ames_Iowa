# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.metrics import mean_squared_error, make_scorer, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso, LinearRegression, LassoLarsIC
from sklearn.feature_selection import SelectKBest, f_regression, RFECV
from sklearn.svm import SVR
from statsmodels.stats.outliers_influence import variance_inflation_factor, OLSInfluence
from scipy.stats import kurtosis, skew, boxcox
from regressors import stats
from numpy import mean
from numpy import std
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('./data/train_filled_na.csv')
test = pd.read_csv('./data/test_filled_na.csv')
train.drop('Id', axis = 1, inplace=True)
test.drop('Id', axis = 1, inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
X_sm = sm.add_constant(X_Scaled)
model = sm.OLS(list(y),X_sm)
results = model.fit()

# %%
C, P = OLSInfluence(results).cooks_distance
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:693: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:713: RuntimeWarning: divide by zero encountered in true_divide
#   cooks_d2 *= hii / (1 - hii)

# %%
def plot_cooks_distance(c):
    _, ax = plt.subplots(figsize=(9,6))
    ax.stem(c, markerfmt=",")
    ax.set_xlabel("instance")
    ax.set_ylabel("distance")
    ax.set_title("Cook's Distance Outlier Detection")
    return ax


plot_cooks_distance(C)
# Out:
# <AxesSubplot:title={'center':"Cook's Distance Outlier Detection"}, xlabel='instance', ylabel='distance'>

# %%
#influential_points = C[C > 1]
#train.merge(pd.DataFrame(influential_points), left_index=True, right_index=True)
outliers = pd.DataFrame(C[C > 1])
outliers.columns = ["Cook's Distance"]
outliers
# Out:
#       Cook's Distance
# 120          2.218727
# 185          7.334633
# 250         10.342979
# 375         21.145168
# 583        148.526322
# 666          6.932813
# 821          4.842004
# 944               inf
# 1170         5.547019
# 1275              inf
# 1298        31.471564
# 1423         5.547019

# %%
#data_mean, data_std = mean(train), std(train)

# %%
# cut_off = data_std * 3
# lower, upper = data_mean - cut_off, data_mean + cut_off

# outliers = {}
# for col in ['LotFrontage','LotArea','MasVnrArea','YearBuilt','YearRemodAdd','BsmtFinSF1','BsmtFinSF2',
#             'BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF',
#            'OpenPorchSF','EnclosedPorch']:
#     #train[train['LotArea'].between(lower['LotArea'], upper['LotArea'], inclusive=False)]
#     m = train[col].between(lower[col], upper[col], inclusive=True)
#     outliers[col] = train[~m]

# %%
# outlier_indices = set()
# for col in outliers:
#     print(col, len(outliers[col]))
#     for idx in list(outliers[col].index):
#         #print(idx)
#         outlier_indices.add(idx)

# %%
train = train.drop(outliers.index, axis=0)

# %% [markdown]
# # Log Transformations

# %%
def logTransform(data, colsToTransform):
    for col in colsToTransform:
        data[col] = np.log1p(data[col])

# %%
colsToTransform = ['SalePrice']
logTransform(train, colsToTransform)

# %% [markdown]
# # Modeling

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ## Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Ridge()
params = {'alpha':[0.0001,0.001,0.01,0.1,1,10,50,75,100,200,300,400,500,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 75, 100,
#                                    200, 300, 400, 500, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.09867682, 0.00703831, 0.00712123, 0.00704131, 0.00701241,
#         0.00739784, 0.00725589, 0.00753994, 0.00760875, 0.0078187 ,
#         0.00751505, 0.00775251, 0.00758243, 0.00797219, 0.0075222 ]),
#  'std_fit_time': array([1.82286993e-01, 2.83786116e-04, 1.75678458e-04, 1.72363250e-04,
#         1.54259982e-04, 3.56002273e-04, 2.67292327e-04, 2.20102547e-04,
#         2.09431342e-04, 5.15671951e-04, 3.83475443e-04, 3.30378393e-04,
#         5.05480923e-04, 4.57239482e-04, 1.87725563e-04]),
#  'mean_score_time': array([0.00338416, 0.00359545, 0.00343199, 0.00344791, 0.00332832,
#         0.00369177, 0.00347004, 0.0036921 , 0.0034874 , 0.0037231 ,
#         0.0038085 , 0.00371327, 0.00396662, 0.00377922, 0.00375128]),
#  'std_score_time': array([6.45166843e-05, 2.21594575e-04, 1.43406459e-04, 1.04679452e-04,
#         9.50924963e-05, 2.00257335e-04, 1.36355635e-04, 8.83588904e-05,
#         6.09664605e-05, 2.96428089e-04, 3.22978109e-04, 1.43870914e-04,
#         2.82274082e-04, 2.14615998e-04, 1.58839675e-04]),
#  'param_alpha': masked_array(data=[0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 75, 100, 200, 300,
#                     400, 500, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.0001},
#   {'alpha': 0.001},
#   {'alpha': 0.01},
#   {'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 200},
#   {'alpha': 300},
#   {'alpha': 400},
#   {'alpha': 500},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89352322, 0.89352723, 0.89356695, 0.89393308, 0.89621134,
#         0.90119316, 0.90366232, 0.90427639, 0.90474607, 0.90591427,
#         0.90639108, 0.90645328, 0.9062522 , 0.9034306 , 0.89471492]),
#  'split1_test_score': array([0.83335931, 0.83336182, 0.83338735, 0.83367139, 0.8366421 ,
#         0.84592463, 0.85112631, 0.85261043, 0.85377511, 0.85677136,
#         0.85835709, 0.85920262, 0.85959325, 0.85830211, 0.85001777]),
#  'split2_test_score': array([0.74727178, 0.74758635, 0.75061914, 0.7725652 , 0.81386271,
#         0.83242782, 0.85324366, 0.85954656, 0.86415295, 0.87503038,
#         0.88050839, 0.88353917, 0.88519282, 0.8848502 , 0.87273784]),
#  'split3_test_score': array([0.91159665, 0.91159924, 0.91162418, 0.91180483, 0.91215122,
#         0.91158314, 0.91175213, 0.91225513, 0.91263302, 0.91297584,
#         0.91221441, 0.91092853, 0.90937704, 0.9004818 , 0.88274221]),
#  'split4_test_score': array([0.89486942, 0.89487602, 0.89494105, 0.89551118, 0.89781206,
#         0.8989998 , 0.90026717, 0.90140322, 0.90236452, 0.9046167 ,
#         0.90528359, 0.90511268, 0.90445903, 0.8983143 , 0.88286584]),
#  'mean_test_score': array([0.85612408, 0.85619013, 0.85682773, 0.86149713, 0.87133589,
#         0.87802571, 0.88401032, 0.88601835, 0.88753433, 0.89106171,
#         0.89255091, 0.89304725, 0.89297487, 0.8890758 , 0.87661571]),
#  'std_test_score': array([0.06057089, 0.06045947, 0.05938815, 0.05181326, 0.03871044,
#         0.03228743, 0.02626039, 0.02480026, 0.02380124, 0.02152857,
#         0.02027099, 0.01939535, 0.0187195 , 0.01665163, 0.01501112]),
#  'rank_test_score': array([15, 14, 13, 12, 11,  9,  8,  7,  6,  4,  3,  1,  2,  5, 10],
#        dtype=int32)}

# %%
gridRidge.best_params_
# Out:
# {'alpha': 400}

# %%
gridRidge.best_score_
# Out:
# 0.8930472543086225

# %%
getFeatureImportance(30, X_Scaled.columns, gridRidge.best_estimator_.coef_,'descending')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallCond', 0.030003110375766476),
#  ('TotalIndoorSF', 0.02652958189580847),
#  ('GrLivArea', 0.025958701800727905),
#  ('TotalSF', 0.025781436324412082),
#  ('OverallQual', 0.025719178667690554),
#  ('GrLivAreaHighQualitySF', 0.02479249542530956),
#  ('1stFlrSF', 0.02250401972027363),
#  ('YearRemodAdd', 0.021689953092303173),
#  ('BsmtFinSF1', 0.019741877629902857),
#  ('TotalBsmtSF', 0.01971744770138295),
#  ('YearBuilt', 0.018864168143495556),
#  ('NeighborhoodDummy_NridgHt', 0.018297895720341344),
#  ('BsmtQualDummy_Ex', 0.018089078380037652),
#  ('CentralAirDummy_Y', 0.016941668506693017),
#  ('SaleConditionDummy_Normal', 0.01637686760485346),
#  ('NeighborhoodDummy_Crawfor', 0.016270207185985985),
#  ('Condition2Dummy_PosN', -0.016138367330564344),
#  ('NeighborhoodDummy_MeadowV', -0.016093677645048928),
#  ('GarageCars', 0.01576476121467462),
#  ('NeighborhoodDummy_StoneBr', 0.0151168869658498),
#  ('GarageArea', 0.015010111854899299),
#  ('KitchenQualDummy_TA', -0.014532762518475142),
#  ('MSSubClassDummy_30', -0.01392775202554798),
#  ('Baths', 0.013389480310735741),
#  ('MSZoningDummy_RL', 0.013013304694538019),
#  ('LotArea', 0.012912888663295954),
#  ('NeighborhoodDummy_Edwards', -0.012911054337126113),
#  ('Condition1Dummy_Norm', 0.012300398828547615),
#  ('Fireplaces', 0.012187687663827084),
#  ('HeatingQCDummy_TA', -0.01209078089266471),
#  ('LotFrontage', 0.011861383295641653),
#  ('NeighborhoodDummy_IDOTRR', -0.011510465397384928),
#  ('Exterior1stDummy_BrkFace', 0.011174613337292763),
#  ('HalfBath', 0.010863185009020613),
#  ('FoundationDummy_PConc', 0.010772958050466488),
#  ('ExterQualDummy_TA', -0.010713976765326745),
#  ('FunctionalDummy_Maj2', -0.010572807021813728),
#  ('FullBath', 0.010481499042588497),
#  ('WoodDeckSF', 0.010423336368155211),
#  ('SaleTypeDummy_New', 0.01041274338505399),
#  ('2ndFlrSF', 0.010263911269828454),
#  ('BsmtQualDummy_TA', -0.010218300083726305),
#  ('MSSubClassDummy_160', -0.009993319673639062),
#  ('MSZoningDummy_FV', 0.009933023231755753),
#  ('KitchenAbvGr', -0.009849571279058875),
#  ('NeighborhoodDummy_NoRidge', 0.009376763913731163),
#  ('NeighborhoodDummy_OldTown', -0.009354278409622585),
#  ('FunctionalDummy_Typ', 0.009314274755581086),
#  ('NeighborhoodDummy_Somerst', 0.009195794177840522),
#  ('SaleConditionDummy_Partial', 0.009080880695211572),
#  ('MasVnrArea', 0.008951458822115213),
#  ('HeatingDummy_Grav', -0.008737911712386838),
#  ('BsmtExposure', -0.008293793788175975),
#  ('BsmtFullBath', 0.008085040867129604),
#  ('Condition2Dummy_Norm', 0.007954020573198438),
#  ('BsmtBaths', 0.007740995844498747),
#  ('MSSubClassDummy_70', 0.007696309085516622),
#  ('LotConfigDummy_CulDSac', 0.007671832111759677),
#  ('KitchenQualDummy_Gd', -0.007513664581894307),
#  ('ScreenPorch', 0.007471614589256291),
#  ('hasFireplace', 0.0074428118771044886),
#  ('StreetDummy_Pave', 0.007265983438830973),
#  ('BldgTypeDummy_Twnhs', -0.007251683529542845),
#  ('GarageFinish', -0.007012896059074943),
#  ('LowQualFinSF', 0.006933803591006943),
#  ('NeighborhoodDummy_NAmes', -0.00668823248450872),
#  ('Exterior1stDummy_BrkComm', -0.006678622250968979),
#  ('FireplaceQuDummy_Gd', 0.006484454383568881),
#  ('BsmtFinType1', -0.006181837838115189),
#  ('NeighborhoodDummy_Mitchel', -0.006119712899515917),
#  ('MasVnrTypeDummy_Stone', 0.00610054597965937),
#  ('RoofMatlDummy_WdShngl', 0.005948990115047706),
#  ('PavedDriveDummy_Y', 0.005805863820697101),
#  ('BldgTypeDummy_TwnhsE', -0.005794582847634143),
#  ('NeighborhoodDummy_Veenker', 0.005421477137508602),
#  ('HeatingQCDummy_Gd', -0.00541096200350093),
#  ('Exterior1stDummy_Wd Sdng', -0.005406279389300864),
#  ('FireplaceQuDummy_Ex', 0.005325029844401155),
#  ('RoofMatlDummy_Membran', 0.005232886428623907),
#  ('BsmtCondDummy_Fa', -0.005219262845297561),
#  ('LandContourDummy_HLS', 0.005095348288431011),
#  ('ExterCondDummy_Fa', -0.004724038979301148),
#  ('HeatingDummy_GasW', 0.0046520998505313535),
#  ('TotalOutdoorSF', 0.004567107443824882),
#  ('LotConfigDummy_FR2', -0.004546470673195293),
#  ('GarageTypeDummy_Attchd', 0.004524488674212505),
#  ('NeighborhoodDummy_ClearCr', 0.004521698881701854),
#  ('FunctionalDummy_Mod', -0.004503205775888388),
#  ('MoSold', 0.004480261828417531),
#  ('RoofStyleDummy_Shed', 0.004451425979163168),
#  ('Condition1Dummy_RRAe', -0.004433460589559679),
#  ('NeighborhoodDummy_BrkSide', 0.004429245250090885),
#  ('SaleTypeDummy_ConLD', 0.004329629723516077),
#  ('ExterQualDummy_Fa', -0.004234256304857412),
#  ('Exterior2ndDummy_CmentBd', 0.0041413297335227165),
#  ('LotShapeDummy_IR2', 0.004056752634481616),
#  ('HouseStyleDummy_1Story', -0.003997132015173149),
#  ('GarageCondDummy_Fa', -0.0039703609359649115),
#  ('SaleTypeDummy_Con', 0.003953054978973978),
#  ('FoundationDummy_CBlock', -0.003921834751738982),
#  ('Exterior2ndDummy_BrkFace', -0.0038095964998067226),
#  ('BedroomAbvGr', 0.0038093217480877203),
#  ('NeighborhoodDummy_NWAmes', -0.003758016225434218),
#  ('HeatingQCDummy_Fa', -0.0037272472116168295),
#  ('KitchenQualDummy_Fa', -0.003661384406406322),
#  ('GarageCondDummy_Po', 0.0036259577636511284),
#  ('SaleConditionDummy_AdjLand', 0.0035130004121336454),
#  ('NeighborhoodDummy_Sawyer', -0.0034974572963606555),
#  ('MiscFeatureDummy_TenC', -0.003414271377813337),
#  ('LotConfigDummy_Inside', -0.003409104587798938),
#  ('NeighborhoodDummy_Gilbert', -0.0034063510847548283),
#  ('Exterior2ndDummy_Wd Sdng', 0.0033821617976956017),
#  ('hasBeenRemodeled', -0.00338013886507864),
#  ('BsmtFinSF2', 0.003374467005683675),
#  ('SaleTypeDummy_CWD', 0.003336030216315328),
#  ('Exterior1stDummy_Stucco', 0.003333731966213567),
#  ('HouseStyleDummy_2.5Unf', 0.003276558281969764),
#  ('RoofStyleDummy_Gambrel', -0.003256010019244639),
#  ('MSSubClassDummy_60', 0.0032271538421459103),
#  ('GarageCondDummy_TA', 0.003196563511989182),
#  ('GarageQualDummy_Fa', -0.0031865890629058607),
#  ('HouseStyleDummy_1.5Unf', 0.0030819269745315844),
#  ('BsmtCondDummy_Gd', 0.0030656101391647573),
#  ('RoofStyleDummy_Gable', -0.0030654550914558003),
#  ('Condition2Dummy_RRAe', -0.0030615986024755855),
#  ('GarageYrBlt', 0.003025495809312721),
#  ('ExterQualDummy_Gd', -0.0029891385661971644),
#  ('GarageTypeDummy_BuiltIn', 0.00295567461844124),
#  ('Condition2Dummy_Feedr', 0.0028957413772741536),
#  ('AlleyDummy_Pave', 0.002833196948786799),
#  ('LandContourDummy_Low', -0.002743083354688529),
#  ('Condition1Dummy_RRNn', 0.002738274751960287),
#  ('SaleTypeDummy_WD', -0.0027319611525651708),
#  ('Exterior1stDummy_MetalSd', 0.002714657482527459),
#  ('GarageQualDummy_Gd', 0.002701236247011125),
#  ('RoofMatlDummy_CompShg', -0.002693096674390541),
#  ('MSZoningDummy_RH', 0.0026718609832238048),
#  ('hasGarage', 0.0026514339614649466),
#  ('GarageTypeDummy_No_Garage', -0.002651433961464945),
#  ('GarageTypeDummy_CarPort', -0.0026187742751752306),
#  ('Exterior2ndDummy_VinylSd', 0.0026149086896096758),
#  ('Exterior1stDummy_CemntBd', 0.00260649792246237),
#  ('hasFence', -0.0025881555429873616),
#  ('FoundationDummy_Wood', -0.002585978789768636),
#  ('LotConfigDummy_FR3', -0.002577238581630405),
#  ('ExterCondDummy_TA', 0.0025563366166465856),
#  ('NeighborhoodDummy_BrDale', -0.002532850417920541),
#  ('Exterior2ndDummy_Plywood', -0.002532707257808216),
#  ('GarageQualDummy_TA', 0.0025324355623058277),
#  ('RoofStyleDummy_Hip', 0.0024703497487338064),
#  ('YrSold', -0.0024023904781908553),
#  ('HouseStyleDummy_SLvl', 0.002398195255870911),
#  ('RoofStyleDummy_Mansard', 0.0023381995480405925),
#  ('NumFloors', 0.002335088831041365),
#  ('FunctionalDummy_Min2', -0.0023201232838882414),
#  ('GarageTypeDummy_Detchd', -0.0021773519284652375),
#  ('GarageCondDummy_Ex', 0.0021610208289845156),
#  ('GarageQualDummy_Ex', 0.0021610208289845135),
#  ('HouseStyleDummy_2.5Fin', -0.002158042039775981),
#  ('HeatingDummy_GasA', 0.002141759129638575),
#  ('NeighborhoodDummy_Timber', 0.0021097598881961864),
#  ('SaleConditionDummy_Family', -0.0020648705688917496),
#  ('3SsnPorch', 0.0020296216982500334),
#  ('MSSubClassDummy_120', -0.002027425047382741),
#  ('ExterCondDummy_Gd', -0.002012411299849757),
#  ('BsmtUnfSF', -0.001978839686047737),
#  ('GarageQualDummy_Po', 0.001971829610371677),
#  ('MSSubClassDummy_45', -0.0019320717932892967),
#  ('MSSubClassDummy_180', -0.0019031280314243135),
#  ('ElectricalDummy_FuseP', -0.0018931165955052471),
#  ('Condition1Dummy_RRAn', 0.001868271722755244),
#  ('PoolArea', 0.0018606411194448246),
#  ('MiscVal', 0.0018439159877115048),
#  ('MSSubClassDummy_80', -0.0017595290481203245),
#  ('BsmtHalfBath', -0.0017445214004665358),
#  ('Exterior1stDummy_HdBoard', -0.0017048792771970404),
#  ('Exterior1stDummy_VinylSd', 0.0016495509160290255),
#  ('BsmtCondDummy_TA', 0.001643874320182962),
#  ('BsmtQualDummy_Fa', -0.0016302885735281708),
#  ('Condition1Dummy_Feedr', -0.0016266515214993465),
#  ('SaleTypeDummy_ConLw', 0.0016127295746125871),
#  ('FireplaceQuDummy_Fa', -0.0015864013019359295),
#  ('PoolQCDummy_Ex', 0.0015667280140890087),
#  ('Condition2Dummy_RRNn', 0.001548076297197078),
#  ('Exterior2ndDummy_ImStucc', 0.0015235407883647128),
#  ('FireplaceQuDummy_Po', -0.001495002707553457),
#  ('MasVnrTypeDummy_BrkFace', 0.0014912461366688033),
#  ('FireplaceQuDummy_TA', 0.0014505298198079903),
#  ('SaleTypeDummy_Oth', 0.0014382612522748355),
#  ('Exterior2ndDummy_CBlock', -0.0014268393040258853),
#  ('Exterior1stDummy_CBlock', -0.0014268393040258742),
#  ('NeighborhoodDummy_SawyerW', 0.0014170151304712048),
#  ('MiscFeatureDummy_Othr', -0.001413203446396449),
#  ('hasBsmt', 0.0014115277960420557),
#  ('BsmtFinType2', 0.001392252559979904),
#  ('MSZoningDummy_RM', -0.0013857887042266954),
#  ('RoofMatlDummy_WdShake', -0.0013783772270301304),
#  ('LandSlope', -0.0013577160788780468),
#  ('Exterior2ndDummy_HdBoard', -0.0013095756995144326),
#  ('MSSubClassDummy_50', 0.0013028015640673192),
#  ('Exterior2ndDummy_AsphShn', 0.00124035979396536),
#  ('MasVnrTypeDummy_None', -0.001209881823521778),
#  ('Fence', -0.0011990061719959835),
#  ('HouseStyleDummy_2Story', 0.0011955516129887474),
#  ('RoofMatlDummy_Tar&Grv', -0.001161344935455746),
#  ('Condition1Dummy_RRNe', -0.0011426574897468785),
#  ('BsmtQualDummy_Gd', 0.0011232132228442423),
#  ('Exterior2ndDummy_Wd Shng', -0.0011220693467824205),
#  ('HeatingDummy_Wall', 0.0010336365945137873),
#  ('Exterior2ndDummy_Stone', -0.0010152745192197157),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0009457332706293956),
#  ('hasMisc_Feature', -0.0009457332706293869),
#  ('Exterior1stDummy_Stone', 0.0009078844971745664),
#  ('hasPool', 0.0009067283017467852),
#  ('OpenPorchSF', 0.0008572215209965403),
#  ('EnclosedPorch', -0.0008490171702627714),
#  ('NeighborhoodDummy_NPkVill', 0.0008418356150197671),
#  ('Exterior2ndDummy_Stucco', -0.0008376950877498636),
#  ('BldgTypeDummy_Duplex', -0.0007859637183938311),
#  ('MSSubClassDummy_90', -0.0007859637183937942),
#  ('Exterior1stDummy_Plywood', -0.0006631840248431253),
#  ('Exterior1stDummy_ImStucc', 0.0006558640455241921),
#  ('ElectricalDummy_SBrkr', -0.0006541184214254304),
#  ('FoundationDummy_Stone', 0.0006343538911243962),
#  ('HeatingQCDummy_Po', -0.0006322072023177356),
#  ('Exterior1stDummy_WdShing', -0.0006069031338330307),
#  ('GarageCondDummy_Gd', -0.0005686575645118093),
#  ('MSSubClassDummy_190', -0.0005586683247823504),
#  ('BldgTypeDummy_2fmCon', -0.0005586683247823442),
#  ('MSSubClassDummy_75', -0.0005519247877985193),
#  ('Condition2Dummy_RRAn', -0.0005197356682657694),
#  ('MSSubClassDummy_85', -0.000503546405394507),
#  ('Condition1Dummy_PosA', -0.000501148372762688),
#  ('PavedDriveDummy_P', 0.0004802007698533965),
#  ('LandContourDummy_Lvl', 0.00047993845599736813),
#  ('Exterior2ndDummy_MetalSd', 0.00047976389809798825),
#  ('Exterior2ndDummy_Brk Cmn', 0.00047814558800381103),
#  ('SaleConditionDummy_Alloca', -0.0004714099209500657),
#  ('SaleTypeDummy_ConLI', 0.00040156846081662514),
#  ('HouseStyleDummy_SFoyer', 0.0003786000450345909),
#  ('Condition1Dummy_PosN', 0.00037500305950137914),
#  ('LotShapeDummy_IR3', 0.0003621675047603536),
#  ('GarageTypeDummy_Basment', -0.00034232577955264345),
#  ('FoundationDummy_Slab', -0.0003331122251914627),
#  ('HeatingDummy_OthW', 0.00031941996599924017),
#  ('MiscFeatureDummy_Shed', -0.0002898151663082334),
#  ('PoolQCDummy_Fa', -0.00028530765552955804),
#  ('MSSubClassDummy_40', 0.00027414907434188015),
#  ('Exterior1stDummy_AsphShn', 0.0002262530331711765),
#  ('Exterior2ndDummy_Other', -0.00021705650956135516),
#  ('hasMasVnr', 0.00020341313951618493),
#  ('MasVnrTypeDummy_No_MasVnr', -0.00020341313951617728),
#  ('FunctionalDummy_Min1', 0.00017821520374105868),
#  ('TotRmsAbvGrd', 0.0001719681426198894),
#  ('BsmtCondDummy_Po', -0.00016458343363256735),
#  ('ElectricalDummy_Mix', -0.0001645834336325655),
#  ('LotShapeDummy_Reg', -0.00014792158728101738),
#  ('ElectricalDummy_FuseF', -8.236950064655524e-05),
#  ('NeighborhoodDummy_Blueste', -6.615906964675978e-05),
#  ('AlleyDummy_No_Alley_Access', -4.541473739069725e-05),
#  ('hasAlley_Access', 4.541473739069323e-05),
#  ('NeighborhoodDummy_SWISU', -2.2197251482579977e-05),
#  ('NeighborhoodDummy_CollgCr', -6.9078580041702325e-06),
#  ('UtilitiesDummy_NoSeWa', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('RoofMatlDummy_Roll', 0.0),
#  ('ExterCondDummy_Po', 0.0),
#  ('FunctionalDummy_Sev', 0.0),
#  ('PoolQCDummy_Gd', 0.0),
#  ('MSSubClassDummy_150', 0.0)]

# %%
gridRidge.score(X_Scaled, y)
# Out:
# 0.9279959639786199

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.09867682, 0.00703831, 0.00712123, 0.00704131, 0.00701241,
#         0.00739784, 0.00725589, 0.00753994, 0.00760875, 0.0078187 ,
#         0.00751505, 0.00775251, 0.00758243, 0.00797219, 0.0075222 ]),
#  'std_fit_time': array([1.82286993e-01, 2.83786116e-04, 1.75678458e-04, 1.72363250e-04,
#         1.54259982e-04, 3.56002273e-04, 2.67292327e-04, 2.20102547e-04,
#         2.09431342e-04, 5.15671951e-04, 3.83475443e-04, 3.30378393e-04,
#         5.05480923e-04, 4.57239482e-04, 1.87725563e-04]),
#  'mean_score_time': array([0.00338416, 0.00359545, 0.00343199, 0.00344791, 0.00332832,
#         0.00369177, 0.00347004, 0.0036921 , 0.0034874 , 0.0037231 ,
#         0.0038085 , 0.00371327, 0.00396662, 0.00377922, 0.00375128]),
#  'std_score_time': array([6.45166843e-05, 2.21594575e-04, 1.43406459e-04, 1.04679452e-04,
#         9.50924963e-05, 2.00257335e-04, 1.36355635e-04, 8.83588904e-05,
#         6.09664605e-05, 2.96428089e-04, 3.22978109e-04, 1.43870914e-04,
#         2.82274082e-04, 2.14615998e-04, 1.58839675e-04]),
#  'param_alpha': masked_array(data=[0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 75, 100, 200, 300,
#                     400, 500, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.0001},
#   {'alpha': 0.001},
#   {'alpha': 0.01},
#   {'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 200},
#   {'alpha': 300},
#   {'alpha': 400},
#   {'alpha': 500},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89352322, 0.89352723, 0.89356695, 0.89393308, 0.89621134,
#         0.90119316, 0.90366232, 0.90427639, 0.90474607, 0.90591427,
#         0.90639108, 0.90645328, 0.9062522 , 0.9034306 , 0.89471492]),
#  'split1_test_score': array([0.83335931, 0.83336182, 0.83338735, 0.83367139, 0.8366421 ,
#         0.84592463, 0.85112631, 0.85261043, 0.85377511, 0.85677136,
#         0.85835709, 0.85920262, 0.85959325, 0.85830211, 0.85001777]),
#  'split2_test_score': array([0.74727178, 0.74758635, 0.75061914, 0.7725652 , 0.81386271,
#         0.83242782, 0.85324366, 0.85954656, 0.86415295, 0.87503038,
#         0.88050839, 0.88353917, 0.88519282, 0.8848502 , 0.87273784]),
#  'split3_test_score': array([0.91159665, 0.91159924, 0.91162418, 0.91180483, 0.91215122,
#         0.91158314, 0.91175213, 0.91225513, 0.91263302, 0.91297584,
#         0.91221441, 0.91092853, 0.90937704, 0.9004818 , 0.88274221]),
#  'split4_test_score': array([0.89486942, 0.89487602, 0.89494105, 0.89551118, 0.89781206,
#         0.8989998 , 0.90026717, 0.90140322, 0.90236452, 0.9046167 ,
#         0.90528359, 0.90511268, 0.90445903, 0.8983143 , 0.88286584]),
#  'mean_test_score': array([0.85612408, 0.85619013, 0.85682773, 0.86149713, 0.87133589,
#         0.87802571, 0.88401032, 0.88601835, 0.88753433, 0.89106171,
#         0.89255091, 0.89304725, 0.89297487, 0.8890758 , 0.87661571]),
#  'std_test_score': array([0.06057089, 0.06045947, 0.05938815, 0.05181326, 0.03871044,
#         0.03228743, 0.02626039, 0.02480026, 0.02380124, 0.02152857,
#         0.02027099, 0.01939535, 0.0187195 , 0.01665163, 0.01501112]),
#  'rank_test_score': array([15, 14, 13, 12, 11,  9,  8,  7,  6,  4,  3,  1,  2,  5, 10],
#        dtype=int32)}

# %% [markdown]
# ## Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.0075,0.005,0.001,0.01,0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0075, 0.005, 0.001, 0.01, 0.1, 1, 10, 50,
#                                    75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.03006854, 0.04011469, 0.11632061, 0.02468476, 0.00909939,
#         0.00690451, 0.0061656 , 0.00661287, 0.00665956, 0.00671597,
#         0.00703931, 0.00685463]),
#  'std_fit_time': array([0.00608956, 0.00850493, 0.01114328, 0.00527064, 0.00052398,
#         0.00072966, 0.00018266, 0.00027351, 0.00019736, 0.00025826,
#         0.0003293 , 0.00033425]),
#  'mean_score_time': array([0.0035347 , 0.00384278, 0.00362277, 0.00361676, 0.00342269,
#         0.00393763, 0.00353804, 0.00381107, 0.00373158, 0.00372071,
#         0.00395761, 0.00390062]),
#  'std_score_time': array([1.54045607e-04, 1.30871900e-04, 4.88466618e-04, 4.73486092e-05,
#         5.86334063e-05, 2.31531551e-04, 1.99319107e-04, 1.68298755e-04,
#         2.52131903e-05, 1.56261829e-04, 1.96698801e-04, 1.51665747e-04]),
#  'param_alpha': masked_array(data=[0.0075, 0.005, 0.001, 0.01, 0.1, 1, 10, 50, 75, 100,
#                     1000, 2000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000,
#                     1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.0075, 'max_iter': 1000},
#   {'alpha': 0.005, 'max_iter': 1000},
#   {'alpha': 0.001, 'max_iter': 1000},
#   {'alpha': 0.01, 'max_iter': 1000},
#   {'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([ 9.09152257e-01,  9.11929727e-01,  9.10261172e-01,  9.03925360e-01,
#          7.42535603e-01, -7.15006620e-04, -7.15006620e-04, -7.15006620e-04,
#         -7.15006620e-04, -7.15006620e-04, -7.15006620e-04, -7.15006620e-04]),
#  'split1_test_score': array([ 8.61295539e-01,  8.65935756e-01,  8.59048297e-01,  8.53955792e-01,
#          6.94879683e-01, -1.28099745e-04, -1.28099745e-04, -1.28099745e-04,
#         -1.28099745e-04, -1.28099745e-04, -1.28099745e-04, -1.28099745e-04]),
#  'split2_test_score': array([ 0.87116829,  0.86878536,  0.8546409 ,  0.87188548,  0.72191323,
#         -0.00231383, -0.00231383, -0.00231383, -0.00231383, -0.00231383,
#         -0.00231383, -0.00231383]),
#  'split3_test_score': array([ 0.91136275,  0.91512756,  0.91670886,  0.90531462,  0.71028007,
#         -0.01319939, -0.01319939, -0.01319939, -0.01319939, -0.01319939,
#         -0.01319939, -0.01319939]),
#  'split4_test_score': array([ 9.06221736e-01,  9.10575962e-01,  9.09167847e-01,  8.99667715e-01,
#          7.20063072e-01, -5.49258762e-04, -5.49258762e-04, -5.49258762e-04,
#         -5.49258762e-04, -5.49258762e-04, -5.49258762e-04, -5.49258762e-04]),
#  'mean_test_score': array([ 0.89184011,  0.89447087,  0.88996542,  0.88694979,  0.71793433,
#         -0.00338112, -0.00338112, -0.00338112, -0.00338112, -0.00338112,
#         -0.00338112, -0.00338112]),
#  'std_test_score': array([0.02120363, 0.02220307, 0.0272013 , 0.02050717, 0.01559288,
#         0.00496482, 0.00496482, 0.00496482, 0.00496482, 0.00496482,
#         0.00496482, 0.00496482]),
#  'rank_test_score': array([2, 1, 3, 4, 5, 6, 6, 6, 6, 6, 6, 6], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 0.005, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.8944708727756684

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.03006854, 0.04011469, 0.11632061, 0.02468476, 0.00909939,
#         0.00690451, 0.0061656 , 0.00661287, 0.00665956, 0.00671597,
#         0.00703931, 0.00685463]),
#  'std_fit_time': array([0.00608956, 0.00850493, 0.01114328, 0.00527064, 0.00052398,
#         0.00072966, 0.00018266, 0.00027351, 0.00019736, 0.00025826,
#         0.0003293 , 0.00033425]),
#  'mean_score_time': array([0.0035347 , 0.00384278, 0.00362277, 0.00361676, 0.00342269,
#         0.00393763, 0.00353804, 0.00381107, 0.00373158, 0.00372071,
#         0.00395761, 0.00390062]),
#  'std_score_time': array([1.54045607e-04, 1.30871900e-04, 4.88466618e-04, 4.73486092e-05,
#         5.86334063e-05, 2.31531551e-04, 1.99319107e-04, 1.68298755e-04,
#         2.52131903e-05, 1.56261829e-04, 1.96698801e-04, 1.51665747e-04]),
#  'param_alpha': masked_array(data=[0.0075, 0.005, 0.001, 0.01, 0.1, 1, 10, 50, 75, 100,
#                     1000, 2000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000,
#                     1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.0075, 'max_iter': 1000},
#   {'alpha': 0.005, 'max_iter': 1000},
#   {'alpha': 0.001, 'max_iter': 1000},
#   {'alpha': 0.01, 'max_iter': 1000},
#   {'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([ 9.09152257e-01,  9.11929727e-01,  9.10261172e-01,  9.03925360e-01,
#          7.42535603e-01, -7.15006620e-04, -7.15006620e-04, -7.15006620e-04,
#         -7.15006620e-04, -7.15006620e-04, -7.15006620e-04, -7.15006620e-04]),
#  'split1_test_score': array([ 8.61295539e-01,  8.65935756e-01,  8.59048297e-01,  8.53955792e-01,
#          6.94879683e-01, -1.28099745e-04, -1.28099745e-04, -1.28099745e-04,
#         -1.28099745e-04, -1.28099745e-04, -1.28099745e-04, -1.28099745e-04]),
#  'split2_test_score': array([ 0.87116829,  0.86878536,  0.8546409 ,  0.87188548,  0.72191323,
#         -0.00231383, -0.00231383, -0.00231383, -0.00231383, -0.00231383,
#         -0.00231383, -0.00231383]),
#  'split3_test_score': array([ 0.91136275,  0.91512756,  0.91670886,  0.90531462,  0.71028007,
#         -0.01319939, -0.01319939, -0.01319939, -0.01319939, -0.01319939,
#         -0.01319939, -0.01319939]),
#  'split4_test_score': array([ 9.06221736e-01,  9.10575962e-01,  9.09167847e-01,  8.99667715e-01,
#          7.20063072e-01, -5.49258762e-04, -5.49258762e-04, -5.49258762e-04,
#         -5.49258762e-04, -5.49258762e-04, -5.49258762e-04, -5.49258762e-04]),
#  'mean_test_score': array([ 0.89184011,  0.89447087,  0.88996542,  0.88694979,  0.71793433,
#         -0.00338112, -0.00338112, -0.00338112, -0.00338112, -0.00338112,
#         -0.00338112, -0.00338112]),
#  'std_test_score': array([0.02120363, 0.02220307, 0.0272013 , 0.02050717, 0.01559288,
#         0.00496482, 0.00496482, 0.00496482, 0.00496482, 0.00496482,
#         0.00496482, 0.00496482]),
#  'rank_test_score': array([2, 1, 3, 4, 5, 6, 6, 6, 6, 6, 6, 6], dtype=int32)}

# %%
getFeatureImportance(30, X_Scaled.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('TotalSF', 0.11452043819744845),
#  ('GrLivArea', 0.07459368995833543),
#  ('YearBuilt', 0.05307543206056887),
#  ('OverallCond', 0.04051850940484263),
#  ('OverallQual', 0.036442999743745055),
#  ('BsmtFinSF1', 0.029127715430322637),
#  ('BsmtQualDummy_Ex', 0.022492551731828275),
#  ('YearRemodAdd', 0.020919402172921518),
#  ('Condition2Dummy_PosN', -0.019111284488801606),
#  ('GarageCars', 0.018373527635769344),
#  ('SaleTypeDummy_New', 0.018284259599400523),
#  ('Fireplaces', 0.0182423785405204),
#  ('NeighborhoodDummy_Crawfor', 0.01782028445776836),
#  ('NeighborhoodDummy_NridgHt', 0.016861552459620663),
#  ('FoundationDummy_PConc', 0.01620552616596478),
#  ('MSZoningDummy_RL', 0.01483711277582018),
#  ('CentralAirDummy_Y', 0.014533205358618333),
#  ('KitchenAbvGr', -0.014167340304845405),
#  ('LotArea', 0.013580216847787187),
#  ('SaleConditionDummy_Normal', 0.013079753365706355),
#  ('Condition1Dummy_Norm', 0.01288088961046268),
#  ('NeighborhoodDummy_StoneBr', 0.012703526800651586),
#  ('NeighborhoodDummy_MeadowV', -0.012096698077865474),
#  ('FunctionalDummy_Typ', 0.011416076856066657),
#  ('Baths', 0.011247286560676263),
#  ('NeighborhoodDummy_Somerst', 0.010913749194301643),
#  ('MSSubClassDummy_30', -0.01059836161640354),
#  ('BsmtFullBath', 0.01000174099185919),
#  ('MSSubClassDummy_160', -0.009773409635650867),
#  ('LotFrontage', 0.009139844701087411),
#  ('NeighborhoodDummy_IDOTRR', -0.008704876080724613),
#  ('NeighborhoodDummy_Edwards', -0.00787170124763059),
#  ('WoodDeckSF', 0.0078011803149842),
#  ('HeatingQCDummy_TA', -0.0072827554954321356),
#  ('Exterior1stDummy_BrkFace', 0.007251795897825354),
#  ('MSZoningDummy_FV', 0.007075462256890013),
#  ('LotConfigDummy_CulDSac', 0.006448200246127359),
#  ('HeatingDummy_Grav', -0.006390313656025257),
#  ('BsmtExposure', -0.006010052526571934),
#  ('ExterQualDummy_TA', -0.005886786943035392),
#  ('FunctionalDummy_Maj2', -0.005414383004232687),
#  ('KitchenQualDummy_TA', -0.005346122814495698),
#  ('FireplaceQuDummy_Gd', 0.005088660987813169),
#  ('BsmtQualDummy_TA', -0.004457822022038562),
#  ('MasVnrArea', 0.004280549111036816),
#  ('NeighborhoodDummy_Mitchel', -0.004264739140510259),
#  ('NeighborhoodDummy_OldTown', -0.0040439317502271475),
#  ('BldgTypeDummy_Twnhs', -0.0039931432702059845),
#  ('StreetDummy_Pave', 0.0037771383578506152),
#  ('Exterior1stDummy_BrkComm', -0.0037735200430710544),
#  ('NeighborhoodDummy_NoRidge', 0.0034706195765253083),
#  ('GarageCondDummy_TA', 0.0034441593110283524),
#  ('NeighborhoodDummy_BrkSide', 0.002825901652703119),
#  ('ExterQualDummy_Fa', -0.0025000207008173954),
#  ('BsmtCondDummy_Fa', -0.002409495029677353),
#  ('RoofMatlDummy_WdShngl', 0.002235810053806495),
#  ('GarageFinish', -0.00217225573839619),
#  ('HalfBath', 0.002121777675594885),
#  ('RoofMatlDummy_Membran', 0.0020771077911251354),
#  ('NeighborhoodDummy_Veenker', 0.0018351014953809758),
#  ('Condition1Dummy_RRAe', -0.0017393798856600667),
#  ('MSSubClassDummy_70', 0.0016895709142710814),
#  ('MoSold', 0.0016241885098049592),
#  ('ExterCondDummy_TA', 0.0015223023364583513),
#  ('PavedDriveDummy_Y', 0.0012116905223619173),
#  ('LotShapeDummy_IR2', 0.0012006426453184207),
#  ('GarageTypeDummy_Attchd', 0.0011440878136020727),
#  ('NeighborhoodDummy_ClearCr', 0.0011228518766089508),
#  ('FunctionalDummy_Mod', -0.0011226457166960441),
#  ('LandContourDummy_HLS', 0.0009241831113110591),
#  ('ScreenPorch', 0.0007997057955015978),
#  ('GarageCondDummy_Fa', -0.0007796081973259537),
#  ('FireplaceQuDummy_Ex', 0.0005440372373606602),
#  ('hasFireplace', 0.0005384118215222586),
#  ('BsmtFinType1', -0.000500803978594777),
#  ('BsmtFinSF2', 0.0004598099785421643),
#  ('SaleTypeDummy_Con', 0.00019609430895984134),
#  ('LandSlope', -0.0),
#  ('BsmtFinType2', -0.0),
#  ('BsmtUnfSF', -0.0),
#  ('TotalBsmtSF', 0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('LowQualFinSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('FullBath', 0.0),
#  ('BedroomAbvGr', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageYrBlt', 0.0),
#  ('GarageArea', 0.0),
#  ('OpenPorchSF', -0.0),
#  ('EnclosedPorch', -0.0),
#  ('3SsnPorch', -0.0),
#  ('PoolArea', 0.0),
#  ('Fence', -0.0),
#  ('MiscVal', -0.0),
#  ('YrSold', -0.0),
#  ('hasGarage', 0.0),
#  ('hasBsmt', 0.0),
#  ('hasAlley_Access', 0.0),
#  ('hasPool', 0.0),
#  ('hasFence', -0.0),
#  ('hasMisc_Feature', -0.0),
#  ('hasMasVnr', 0.0),
#  ('GrLivAreaHighQualitySF', 0.0),
#  ('TotalIndoorSF', 0.0),
#  ('TotalOutdoorSF', 0.0),
#  ('BsmtBaths', 0.0),
#  ('hasBeenRemodeled', -0.0),
#  ('NumFloors', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', 0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_80', 0.0),
#  ('MSSubClassDummy_85', 0.0),
#  ('MSSubClassDummy_90', -0.0),
#  ('MSSubClassDummy_120', -0.0),
#  ('MSSubClassDummy_180', -0.0),
#  ('MSSubClassDummy_190', -0.0),
#  ('MSZoningDummy_RH', 0.0),
#  ('MSZoningDummy_RM', -0.0),
#  ('AlleyDummy_No_Alley_Access', -0.0),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR3', 0.0),
#  ('LotShapeDummy_Reg', -0.0),
#  ('LandContourDummy_Low', -0.0),
#  ('LandContourDummy_Lvl', -0.0),
#  ('UtilitiesDummy_NoSeWa', 0.0),
#  ('LotConfigDummy_FR2', -0.0),
#  ('LotConfigDummy_FR3', -0.0),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 0.0),
#  ('NeighborhoodDummy_BrDale', -0.0),
#  ('NeighborhoodDummy_CollgCr', 0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_NAmes', -0.0),
#  ('NeighborhoodDummy_NPkVill', 0.0),
#  ('NeighborhoodDummy_NWAmes', -0.0),
#  ('NeighborhoodDummy_SWISU', 0.0),
#  ('NeighborhoodDummy_Sawyer', -0.0),
#  ('NeighborhoodDummy_SawyerW', -0.0),
#  ('NeighborhoodDummy_Timber', 0.0),
#  ('Condition1Dummy_Feedr', -0.0),
#  ('Condition1Dummy_PosA', -0.0),
#  ('Condition1Dummy_PosN', 0.0),
#  ('Condition1Dummy_RRAn', 0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', 0.0),
#  ('Condition2Dummy_Feedr', 0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('Condition2Dummy_RRNn', -0.0),
#  ('BldgTypeDummy_2fmCon', -0.0),
#  ('BldgTypeDummy_Duplex', -0.0),
#  ('BldgTypeDummy_TwnhsE', -0.0),
#  ('HouseStyleDummy_1.5Unf', 0.0),
#  ('HouseStyleDummy_1Story', -0.0),
#  ('HouseStyleDummy_2.5Fin', -0.0),
#  ('HouseStyleDummy_2.5Unf', 0.0),
#  ('HouseStyleDummy_2Story', 0.0),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('HouseStyleDummy_SLvl', 0.0),
#  ('RoofStyleDummy_Gable', -0.0),
#  ('RoofStyleDummy_Gambrel', -0.0),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', -0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('RoofMatlDummy_Roll', 0.0),
#  ('RoofMatlDummy_Tar&Grv', 0.0),
#  ('RoofMatlDummy_WdShake', 0.0),
#  ('Exterior1stDummy_AsphShn', 0.0),
#  ('Exterior1stDummy_CBlock', -0.0),
#  ('Exterior1stDummy_CemntBd', 0.0),
#  ('Exterior1stDummy_HdBoard', -0.0),
#  ('Exterior1stDummy_ImStucc', 0.0),
#  ('Exterior1stDummy_MetalSd', 0.0),
#  ('Exterior1stDummy_Plywood', -0.0),
#  ('Exterior1stDummy_Stone', -0.0),
#  ('Exterior1stDummy_Stucco', 0.0),
#  ('Exterior1stDummy_VinylSd', 0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 0.0),
#  ('Exterior2ndDummy_AsphShn', 0.0),
#  ('Exterior2ndDummy_Brk Cmn', -0.0),
#  ('Exterior2ndDummy_BrkFace', -0.0),
#  ('Exterior2ndDummy_CBlock', -0.0),
#  ('Exterior2ndDummy_CmentBd', 0.0),
#  ('Exterior2ndDummy_HdBoard', -0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', 0.0),
#  ('Exterior2ndDummy_Other', -0.0),
#  ('Exterior2ndDummy_Plywood', -0.0),
#  ('Exterior2ndDummy_Stone', -0.0),
#  ('Exterior2ndDummy_Stucco', 0.0),
#  ('Exterior2ndDummy_VinylSd', 0.0),
#  ('Exterior2ndDummy_Wd Sdng', 0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', -0.0),
#  ('MasVnrTypeDummy_No_MasVnr', -0.0),
#  ('MasVnrTypeDummy_None', -0.0),
#  ('MasVnrTypeDummy_Stone', 0.0),
#  ('ExterQualDummy_Gd', 0.0),
#  ('ExterCondDummy_Fa', -0.0),
#  ('ExterCondDummy_Gd', -0.0),
#  ('ExterCondDummy_Po', 0.0),
#  ('FoundationDummy_CBlock', -0.0),
#  ('FoundationDummy_Slab', -0.0),
#  ('FoundationDummy_Stone', 0.0),
#  ('FoundationDummy_Wood', -0.0),
#  ('BsmtQualDummy_Fa', -0.0),
#  ('BsmtQualDummy_Gd', 0.0),
#  ('BsmtCondDummy_Gd', 0.0),
#  ('BsmtCondDummy_Po', -0.0),
#  ('BsmtCondDummy_TA', 0.0),
#  ('HeatingDummy_GasA', -0.0),
#  ('HeatingDummy_GasW', 0.0),
#  ('HeatingDummy_OthW', -0.0),
#  ('HeatingDummy_Wall', 0.0),
#  ('HeatingQCDummy_Fa', -0.0),
#  ('HeatingQCDummy_Gd', -0.0),
#  ('HeatingQCDummy_Po', -0.0),
#  ('ElectricalDummy_FuseF', 0.0),
#  ('ElectricalDummy_FuseP', -0.0),
#  ('ElectricalDummy_Mix', -0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('KitchenQualDummy_Fa', -0.0),
#  ('KitchenQualDummy_Gd', -0.0),
#  ('FunctionalDummy_Min1', 0.0),
#  ('FunctionalDummy_Min2', -0.0),
#  ('FunctionalDummy_Sev', 0.0),
#  ('FireplaceQuDummy_Fa', -0.0),
#  ('FireplaceQuDummy_Po', -0.0),
#  ('FireplaceQuDummy_TA', 0.0),
#  ('GarageTypeDummy_Basment', -0.0),
#  ('GarageTypeDummy_BuiltIn', 0.0),
#  ('GarageTypeDummy_CarPort', -0.0),
#  ('GarageTypeDummy_Detchd', -0.0),
#  ('GarageTypeDummy_No_Garage', -0.0),
#  ('GarageQualDummy_Ex', 0.0),
#  ('GarageQualDummy_Fa', -0.0),
#  ('GarageQualDummy_Gd', 0.0),
#  ('GarageQualDummy_Po', 0.0),
#  ('GarageQualDummy_TA', 0.0),
#  ('GarageCondDummy_Ex', 0.0),
#  ('GarageCondDummy_Gd', 0.0),
#  ('GarageCondDummy_Po', 0.0),
#  ('PavedDriveDummy_P', -0.0),
#  ('PoolQCDummy_Ex', 0.0),
#  ('PoolQCDummy_Fa', -0.0),
#  ('PoolQCDummy_Gd', 0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Othr', -0.0),
#  ('MiscFeatureDummy_Shed', -0.0),
#  ('MiscFeatureDummy_TenC', -0.0),
#  ('SaleTypeDummy_CWD', 0.0),
#  ('SaleTypeDummy_ConLD', 0.0),
#  ('SaleTypeDummy_ConLI', -0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', 0.0),
#  ('SaleTypeDummy_WD', -0.0),
#  ('SaleConditionDummy_AdjLand', 0.0),
#  ('SaleConditionDummy_Alloca', -0.0),
#  ('SaleConditionDummy_Family', -0.0),
#  ('SaleConditionDummy_Partial', 0.0),
#  ('MSSubClassDummy_150', 0.0)]

# %%
gridLasso.score(X_Scaled, y)
# Out:
# 0.9195328337890243

# %% [markdown]
# ## Linear Regression on Lasso Selected Features

# %%
lasso_coef_estimates = list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
lasso_coef_non_zero = [var[0] for var in lasso_coef_estimates if var[1] != 0]

# %%
X_sm = X_Scaled[lasso_coef_non_zero]
X_sm = sm.add_constant(X_sm)
model = sm.OLS(list(y),X_sm)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     222.0
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                        09:20:05   Log-Likelihood:                 1164.0
# No. Observations:                1448   AIC:                            -2172.
# Df Residuals:                    1370   BIC:                            -1760.
# Df Model:                          77
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        12.0246      0.003   4109.350      0.000      12.019      12.030
# LotFrontage                   0.0130      0.004      3.181      0.002       0.005       0.021
# LotArea                       0.0147      0.004      4.002      0.000       0.007       0.022
# OverallQual                   0.0308      0.004      7.091      0.000       0.022       0.039
# OverallCond                   0.0443      0.004     10.730      0.000       0.036       0.052
# YearBuilt                     0.0585      0.009      6.831      0.000       0.042       0.075
# YearRemodAdd                  0.0177      0.005      3.599      0.000       0.008       0.027
# MasVnrArea                    0.0079      0.004      2.111      0.035       0.001       0.015
# BsmtExposure                 -0.0081      0.003     -2.380      0.017      -0.015      -0.001
# BsmtFinType1                 -0.0024      0.004     -0.583      0.560      -0.010       0.006
# BsmtFinSF1                    0.0314      0.005      5.923      0.000       0.021       0.042
# BsmtFinSF2                    0.0056      0.003      1.641      0.101      -0.001       0.012
# GrLivArea                     0.0824      0.009      9.145      0.000       0.065       0.100
# BsmtFullBath                  0.0131      0.004      3.049      0.002       0.005       0.022
# HalfBath                      0.0026      0.004      0.665      0.506      -0.005       0.010
# KitchenAbvGr                 -0.0156      0.004     -4.447      0.000      -0.023      -0.009
# Fireplaces                    0.0151      0.008      2.010      0.045       0.000       0.030
# GarageFinish                 -0.0026      0.004     -0.675      0.500      -0.010       0.005
# GarageCars                    0.0201      0.005      3.720      0.000       0.009       0.031
# WoodDeckSF                    0.0095      0.003      2.864      0.004       0.003       0.016
# ScreenPorch                   0.0062      0.003      1.963      0.050    2.98e-06       0.012
# MoSold                        0.0055      0.003      1.832      0.067      -0.000       0.011
# hasFireplace                 -0.0002      0.008     -0.024      0.981      -0.016       0.015
# TotalSF                       0.0960      0.009     10.461      0.000       0.078       0.114
# Baths                         0.0148      0.006      2.470      0.014       0.003       0.027
# MSSubClassDummy_30           -0.0125      0.004     -3.541      0.000      -0.019      -0.006
# MSSubClassDummy_70            0.0088      0.004      2.434      0.015       0.002       0.016
# MSSubClassDummy_160          -0.0146      0.004     -3.345      0.001      -0.023      -0.006
# MSZoningDummy_FV              0.0104      0.007      1.582      0.114      -0.002       0.023
# MSZoningDummy_RL              0.0179      0.005      3.277      0.001       0.007       0.029
# StreetDummy_Pave              0.0089      0.003      2.662      0.008       0.002       0.016
# LotShapeDummy_IR2             0.0034      0.003      1.094      0.274      -0.003       0.010
# LandContourDummy_HLS          0.0043      0.003      1.363      0.173      -0.002       0.010
# LotConfigDummy_CulDSac        0.0098      0.003      3.002      0.003       0.003       0.016
# NeighborhoodDummy_BrkSide     0.0115      0.004      3.085      0.002       0.004       0.019
# NeighborhoodDummy_ClearCr     0.0038      0.003      1.191      0.234      -0.002       0.010
# NeighborhoodDummy_Crawfor     0.0225      0.004      6.313      0.000       0.016       0.030
# NeighborhoodDummy_Edwards    -0.0099      0.003     -2.939      0.003      -0.017      -0.003
# NeighborhoodDummy_IDOTRR     -0.0076      0.004     -1.872      0.061      -0.015       0.000
# NeighborhoodDummy_MeadowV    -0.0158      0.003     -4.683      0.000      -0.022      -0.009
# NeighborhoodDummy_Mitchel    -0.0090      0.003     -2.862      0.004      -0.015      -0.003
# NeighborhoodDummy_NoRidge     0.0083      0.004      2.373      0.018       0.001       0.015
# NeighborhoodDummy_NridgHt     0.0235      0.004      6.114      0.000       0.016       0.031
# NeighborhoodDummy_OldTown    -0.0011      0.005     -0.221      0.825      -0.011       0.009
# NeighborhoodDummy_Somerst     0.0176      0.006      2.785      0.005       0.005       0.030
# NeighborhoodDummy_StoneBr     0.0180      0.003      5.626      0.000       0.012       0.024
# NeighborhoodDummy_Veenker     0.0045      0.003      1.448      0.148      -0.002       0.011
# Condition1Dummy_Norm          0.0169      0.003      5.228      0.000       0.011       0.023
# Condition1Dummy_RRAe         -0.0049      0.003     -1.576      0.115      -0.011       0.001
# Condition2Dummy_PosN         -0.0247      0.003     -7.753      0.000      -0.031      -0.018
# BldgTypeDummy_Twnhs          -0.0054      0.004     -1.386      0.166      -0.013       0.002
# RoofMatlDummy_Membran         0.0073      0.003      2.272      0.023       0.001       0.014
# RoofMatlDummy_WdShngl         0.0064      0.003      2.085      0.037       0.000       0.012
# Exterior1stDummy_BrkComm     -0.0057      0.003     -1.840      0.066      -0.012       0.000
# Exterior1stDummy_BrkFace      0.0113      0.003      3.571      0.000       0.005       0.018
# ExterQualDummy_Fa            -0.0041      0.004     -1.139      0.255      -0.011       0.003
# ExterQualDummy_TA            -0.0054      0.005     -1.034      0.301      -0.016       0.005
# ExterCondDummy_TA             0.0063      0.003      1.985      0.047    7.58e-05       0.013
# FoundationDummy_PConc         0.0164      0.005      3.320      0.001       0.007       0.026
# BsmtQualDummy_Ex              0.0216      0.004      5.463      0.000       0.014       0.029
# BsmtQualDummy_TA             -0.0043      0.005     -0.955      0.340      -0.013       0.005
# BsmtCondDummy_Fa             -0.0025      0.003     -0.759      0.448      -0.009       0.004
# HeatingDummy_Grav            -0.0115      0.003     -3.609      0.000      -0.018      -0.005
# HeatingQCDummy_TA            -0.0092      0.004     -2.597      0.009      -0.016      -0.002
# CentralAirDummy_Y             0.0139      0.004      3.726      0.000       0.007       0.021
# KitchenQualDummy_TA          -0.0036      0.004     -0.793      0.428      -0.012       0.005
# FunctionalDummy_Maj2         -0.0095      0.003     -3.039      0.002      -0.016      -0.003
# FunctionalDummy_Mod          -0.0064      0.003     -1.874      0.061      -0.013       0.000
# FunctionalDummy_Typ           0.0124      0.004      3.511      0.000       0.005       0.019
# FireplaceQuDummy_Ex           0.0047      0.003      1.429      0.153      -0.002       0.011
# FireplaceQuDummy_Gd           0.0070      0.004      1.683      0.093      -0.001       0.015
# GarageTypeDummy_Attchd        0.0012      0.004      0.304      0.761      -0.006       0.009
# GarageCondDummy_Fa           -0.0072      0.004     -1.865      0.062      -0.015       0.000
# GarageCondDummy_TA            0.0012      0.005      0.254      0.799      -0.008       0.011
# PavedDriveDummy_Y             0.0021      0.004      0.566      0.571      -0.005       0.009
# SaleTypeDummy_Con             0.0036      0.003      1.163      0.245      -0.002       0.010
# SaleTypeDummy_New             0.0295      0.005      6.533      0.000       0.021       0.038
# SaleConditionDummy_Normal     0.0250      0.004      6.229      0.000       0.017       0.033
# ==============================================================================
# Omnibus:                      449.624   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5827.532
# Skew:                          -1.069   Prob(JB):                         0.00
# Kurtosis:                      12.593   Cond. No.                         13.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Refit until all vars significant

# %%
while True:
    if len(results.pvalues[results.pvalues > 0.05]) == 0:
        break
    significant_coefs = results.pvalues[results.pvalues < 0.05]
    significant_coefs = significant_coefs[significant_coefs.index != 'const']

    X_sm = X_Scaled[significant_coefs.index]
    X_sm = sm.add_constant(X_sm)
    model = sm.OLS(list(y),X_sm)
    results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     354.3
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                        09:20:05   Log-Likelihood:                 1132.0
# No. Observations:                1448   AIC:                            -2168.
# Df Residuals:                    1400   BIC:                            -1915.
# Df Model:                          47
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        12.0246      0.003   4063.490      0.000      12.019      12.030
# LotFrontage                   0.0144      0.004      3.587      0.000       0.007       0.022
# LotArea                       0.0169      0.003      4.871      0.000       0.010       0.024
# OverallQual                   0.0325      0.004      7.692      0.000       0.024       0.041
# OverallCond                   0.0479      0.004     11.919      0.000       0.040       0.056
# YearBuilt                     0.0698      0.007      9.920      0.000       0.056       0.084
# YearRemodAdd                  0.0184      0.005      3.917      0.000       0.009       0.028
# BsmtExposure                 -0.0091      0.003     -2.694      0.007      -0.016      -0.002
# BsmtFinSF1                    0.0313      0.004      7.009      0.000       0.023       0.040
# GrLivArea                     0.0882      0.008     10.458      0.000       0.072       0.105
# BsmtFullBath                  0.0161      0.004      3.916      0.000       0.008       0.024
# KitchenAbvGr                 -0.0162      0.003     -4.763      0.000      -0.023      -0.010
# Fireplaces                    0.0200      0.004      5.358      0.000       0.013       0.027
# GarageCars                    0.0207      0.005      4.507      0.000       0.012       0.030
# WoodDeckSF                    0.0120      0.003      3.608      0.000       0.005       0.019
# ScreenPorch                   0.0078      0.003      2.481      0.013       0.002       0.014
# TotalSF                       0.0946      0.008     11.212      0.000       0.078       0.111
# Baths                         0.0159      0.006      2.786      0.005       0.005       0.027
# MSSubClassDummy_30           -0.0122      0.003     -3.502      0.000      -0.019      -0.005
# MSSubClassDummy_70            0.0076      0.004      2.106      0.035       0.001       0.015
# MSSubClassDummy_160          -0.0147      0.004     -4.000      0.000      -0.022      -0.008
# MSZoningDummy_RL              0.0197      0.004      4.802      0.000       0.012       0.028
# StreetDummy_Pave              0.0110      0.003      3.560      0.000       0.005       0.017
# LotConfigDummy_CulDSac        0.0105      0.003      3.255      0.001       0.004       0.017
# NeighborhoodDummy_BrkSide     0.0131      0.003      4.105      0.000       0.007       0.019
# NeighborhoodDummy_Crawfor     0.0244      0.003      7.325      0.000       0.018       0.031
# NeighborhoodDummy_Edwards    -0.0104      0.003     -3.267      0.001      -0.017      -0.004
# NeighborhoodDummy_MeadowV    -0.0160      0.003     -4.958      0.000      -0.022      -0.010
# NeighborhoodDummy_Mitchel    -0.0106      0.003     -3.427      0.001      -0.017      -0.005
# NeighborhoodDummy_NoRidge     0.0087      0.003      2.586      0.010       0.002       0.015
# NeighborhoodDummy_NridgHt     0.0246      0.004      6.728      0.000       0.017       0.032
# NeighborhoodDummy_Somerst     0.0279      0.004      7.457      0.000       0.021       0.035
# NeighborhoodDummy_StoneBr     0.0195      0.003      6.188      0.000       0.013       0.026
# Condition1Dummy_Norm          0.0186      0.003      5.933      0.000       0.012       0.025
# Condition2Dummy_PosN         -0.0244      0.003     -7.646      0.000      -0.031      -0.018
# RoofMatlDummy_Membran         0.0067      0.003      2.233      0.026       0.001       0.013
# RoofMatlDummy_WdShngl         0.0073      0.003      2.363      0.018       0.001       0.013
# Exterior1stDummy_BrkFace      0.0131      0.003      4.251      0.000       0.007       0.019
# ExterCondDummy_TA             0.0077      0.003      2.432      0.015       0.001       0.014
# FoundationDummy_PConc         0.0182      0.005      3.854      0.000       0.009       0.027
# BsmtQualDummy_Ex              0.0238      0.004      6.219      0.000       0.016       0.031
# HeatingDummy_Grav            -0.0104      0.003     -3.297      0.001      -0.017      -0.004
# HeatingQCDummy_TA            -0.0101      0.003     -2.902      0.004      -0.017      -0.003
# CentralAirDummy_Y             0.0167      0.004      4.611      0.000       0.010       0.024
# FunctionalDummy_Maj2         -0.0085      0.003     -2.717      0.007      -0.015      -0.002
# FunctionalDummy_Typ           0.0166      0.003      5.107      0.000       0.010       0.023
# SaleTypeDummy_New             0.0305      0.004      6.778      0.000       0.022       0.039
# SaleConditionDummy_Normal     0.0259      0.004      6.453      0.000       0.018       0.034
# ==============================================================================
# Omnibus:                      491.691   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6649.259
# Skew:                          -1.192   Prob(JB):                         0.00
# Kurtosis:                      13.224   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Get CV results of model

# %%
model = LinearRegression()
params = {}
gridLr = GridSearchCV(model, param_grid=params, cv=5)
gridLr.fit(X_Scaled[significant_coefs.index], y)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(), param_grid={})

# %%
gridLr.cv_results_
# Out:
# {'mean_fit_time': array([0.00702605]),
#  'std_fit_time': array([0.00556372]),
#  'mean_score_time': array([0.00221214]),
#  'std_score_time': array([0.00024541]),
#  'params': [{}],
#  'split0_test_score': array([0.91657676]),
#  'split1_test_score': array([0.86790681]),
#  'split2_test_score': array([0.86845708]),
#  'split3_test_score': array([0.92578637]),
#  'split4_test_score': array([0.91591313]),
#  'mean_test_score': array([0.89892803]),
#  'std_test_score': array([0.02534615]),
#  'rank_test_score': array([1], dtype=int32)}

# %%
gridLr.score(X_Scaled[significant_coefs.index], y)
# Out:
# 0.9224473062153176

# %% [markdown]
# ## LassoLarsIC

# %%
model = LassoLarsIC()
params = {'criterion':['aic','bic']}
gridLL = GridSearchCV(model, param_grid=params, cv=5)
gridLL.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=5.086e-05, with an active set of 134 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 156 iterations, i.e. alpha=4.589e-05, with an active set of 142 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 177 iterations, i.e. alpha=3.507e-05, with an active set of 163 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 180 iterations, i.e. alpha=3.424e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 180 iterations, i.e. alpha=3.424e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 186 iterations, i.e. alpha=3.090e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 194 iterations, i.e. alpha=2.887e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 194 iterations, i.e. alpha=2.887e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 196 iterations, i.e. alpha=2.838e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 198 iterations, i.e. alpha=2.688e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 198 iterations, i.e. alpha=2.673e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 202 iterations, alpha=2.402e-05, previous alpha=2.359e-05, with an active set of 179 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 150 iterations, i.e. alpha=4.803e-05, with an active set of 140 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 193 iterations, i.e. alpha=2.077e-05, with an active set of 175 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 212 iterations, i.e. alpha=1.574e-05, with an active set of 188 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.572e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.572e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.544e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 216 iterations, alpha=1.415e-05, previous alpha=1.385e-05, with an active set of 191 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=2.530e-04, with an active set of 58 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=1.837e-04, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=1.835e-04, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.424e-04, with an active set of 73 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.150e-04, with an active set of 89 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 103 iterations, i.e. alpha=1.029e-04, with an active set of 97 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=9.240e-05, with an active set of 107 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=9.240e-05, with an active set of 107 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 116 iterations, i.e. alpha=8.894e-05, with an active set of 110 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 130 iterations, i.e. alpha=6.651e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 130 iterations, i.e. alpha=6.651e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 139 iterations, alpha=6.159e-05, previous alpha=5.997e-05, with an active set of 130 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=1.218e-04, with an active set of 92 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 107 iterations, i.e. alpha=1.097e-04, with an active set of 101 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 119 iterations, i.e. alpha=1.004e-04, with an active set of 111 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 131 iterations, i.e. alpha=8.640e-05, with an active set of 121 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 155 iterations, i.e. alpha=5.105e-05, with an active set of 139 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 157 iterations, i.e. alpha=4.986e-05, with an active set of 141 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 188 iterations, i.e. alpha=2.946e-05, with an active set of 172 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 188 iterations, i.e. alpha=2.946e-05, with an active set of 172 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 194 iterations, alpha=2.865e-05, previous alpha=2.815e-05, with an active set of 177 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=1.139e-04, with an active set of 95 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=1.066e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=1.066e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 108 iterations, i.e. alpha=1.009e-04, with an active set of 104 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 118 iterations, i.e. alpha=8.217e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.206e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.197e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.197e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 152 iterations, i.e. alpha=5.291e-05, with an active set of 144 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 155 iterations, i.e. alpha=4.974e-05, with an active set of 147 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 159 iterations, alpha=4.855e-05, previous alpha=4.839e-05, with an active set of 150 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=5.086e-05, with an active set of 134 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 156 iterations, i.e. alpha=4.589e-05, with an active set of 142 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 177 iterations, i.e. alpha=3.507e-05, with an active set of 163 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 180 iterations, i.e. alpha=3.424e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 180 iterations, i.e. alpha=3.424e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 186 iterations, i.e. alpha=3.090e-05, with an active set of 166 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 194 iterations, i.e. alpha=2.887e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 194 iterations, i.e. alpha=2.887e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 196 iterations, i.e. alpha=2.838e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 198 iterations, i.e. alpha=2.688e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 198 iterations, i.e. alpha=2.673e-05, with an active set of 176 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 202 iterations, alpha=2.402e-05, previous alpha=2.359e-05, with an active set of 179 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 150 iterations, i.e. alpha=4.803e-05, with an active set of 140 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 193 iterations, i.e. alpha=2.077e-05, with an active set of 175 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 212 iterations, i.e. alpha=1.574e-05, with an active set of 188 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.572e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.572e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 213 iterations, i.e. alpha=1.544e-05, with an active set of 189 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 216 iterations, alpha=1.415e-05, previous alpha=1.385e-05, with an active set of 191 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=2.530e-04, with an active set of 58 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=1.837e-04, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=1.835e-04, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.424e-04, with an active set of 73 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.150e-04, with an active set of 89 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 103 iterations, i.e. alpha=1.029e-04, with an active set of 97 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=9.240e-05, with an active set of 107 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=9.240e-05, with an active set of 107 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 116 iterations, i.e. alpha=8.894e-05, with an active set of 110 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 130 iterations, i.e. alpha=6.651e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 130 iterations, i.e. alpha=6.651e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 139 iterations, alpha=6.159e-05, previous alpha=5.997e-05, with an active set of 130 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=1.218e-04, with an active set of 92 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 107 iterations, i.e. alpha=1.097e-04, with an active set of 101 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 119 iterations, i.e. alpha=1.004e-04, with an active set of 111 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 131 iterations, i.e. alpha=8.640e-05, with an active set of 121 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 155 iterations, i.e. alpha=5.105e-05, with an active set of 139 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 157 iterations, i.e. alpha=4.986e-05, with an active set of 141 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 188 iterations, i.e. alpha=2.946e-05, with an active set of 172 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 188 iterations, i.e. alpha=2.946e-05, with an active set of 172 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 194 iterations, alpha=2.865e-05, previous alpha=2.815e-05, with an active set of 177 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=1.139e-04, with an active set of 95 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=1.066e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=1.066e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 108 iterations, i.e. alpha=1.009e-04, with an active set of 104 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 118 iterations, i.e. alpha=8.217e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.206e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.197e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 126 iterations, i.e. alpha=7.197e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 152 iterations, i.e. alpha=5.291e-05, with an active set of 144 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 155 iterations, i.e. alpha=4.974e-05, with an active set of 147 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 159 iterations, alpha=4.855e-05, previous alpha=4.839e-05, with an active set of 150 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 92 iterations, i.e. alpha=1.137e-04, with an active set of 88 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 103 iterations, i.e. alpha=9.075e-05, with an active set of 97 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 155 iterations, i.e. alpha=4.603e-05, with an active set of 147 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 190 iterations, i.e. alpha=2.302e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 190 iterations, i.e. alpha=2.302e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 190 iterations, i.e. alpha=2.302e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 190 iterations, i.e. alpha=2.286e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 190 iterations, i.e. alpha=2.286e-05, with an active set of 174 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 193 iterations, i.e. alpha=2.239e-05, with an active set of 177 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 209 iterations, i.e. alpha=1.808e-05, with an active set of 185 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 231 iterations, i.e. alpha=1.156e-05, with an active set of 195 regressors, and the smallest cholesky pivot element being 5.053e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 231 iterations, i.e. alpha=1.156e-05, with an active set of 195 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 232 iterations, i.e. alpha=1.143e-05, with an active set of 196 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 233 iterations, i.e. alpha=1.139e-05, with an active set of 197 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 233 iterations, i.e. alpha=1.139e-05, with an active set of 197 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:615: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 233 iterations, i.e. alpha=1.119e-05, with an active set of 197 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:642: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 234 iterations, alpha=1.146e-05, previous alpha=1.118e-05, with an active set of 197 regressors.
#   warnings.warn('Early stopping the lars path, as the residues '
# GridSearchCV(cv=5, estimator=LassoLarsIC(),
#              param_grid={'criterion': ['aic', 'bic']})

# %%
ll_non_zero_coefs = list(zip(X_Scaled.columns,gridLL.best_estimator_.coef_))
ll_non_zero_coefs = [col[0] for col in ll_non_zero_coefs if col[1] != 0]

# %%
X_sm = X_Scaled[ll_non_zero_coefs]
X_sm = sm.add_constant(X_sm)
model = sm.OLS(list(y),X_sm)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     434.4
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                        09:20:06   Log-Likelihood:                 984.07
# No. Observations:                1448   AIC:                            -1904.
# Df Residuals:                    1416   BIC:                            -1735.
# Df Model:                          31
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        12.0246      0.003   3689.670      0.000      12.018      12.031
# LotFrontage                   0.0125      0.004      3.090      0.002       0.005       0.020
# LotArea                       0.0208      0.004      5.661      0.000       0.014       0.028
# OverallQual                   0.0385      0.005      8.299      0.000       0.029       0.048
# OverallCond                   0.0519      0.004     12.023      0.000       0.043       0.060
# YearBuilt                     0.0608      0.007      8.410      0.000       0.047       0.075
# YearRemodAdd                  0.0187      0.005      3.604      0.000       0.009       0.029
# BsmtFinSF1                    0.0400      0.004     10.056      0.000       0.032       0.048
# GrLivArea                     0.0742      0.009      8.365      0.000       0.057       0.092
# KitchenAbvGr                 -0.0177      0.004     -4.852      0.000      -0.025      -0.011
# Fireplaces                    0.0166      0.008      2.036      0.042       0.001       0.033
# GarageCars                    0.0250      0.005      5.016      0.000       0.015       0.035
# WoodDeckSF                    0.0093      0.004      2.617      0.009       0.002       0.016
# hasFireplace                  0.0026      0.008      0.310      0.757      -0.014       0.019
# TotalSF                       0.1183      0.009     13.293      0.000       0.101       0.136
# Baths                         0.0125      0.006      2.046      0.041       0.001       0.025
# MSSubClassDummy_30           -0.0143      0.004     -3.843      0.000      -0.022      -0.007
# MSZoningDummy_RL              0.0037      0.006      0.623      0.533      -0.008       0.015
# MSZoningDummy_RM             -0.0166      0.006     -2.777      0.006      -0.028      -0.005
# NeighborhoodDummy_Crawfor     0.0208      0.004      5.876      0.000       0.014       0.028
# NeighborhoodDummy_IDOTRR     -0.0110      0.004     -3.074      0.002      -0.018      -0.004
# NeighborhoodDummy_NridgHt     0.0131      0.004      3.387      0.001       0.006       0.021
# Condition1Dummy_Norm          0.0156      0.003      4.591      0.000       0.009       0.022
# Condition2Dummy_PosN         -0.0263      0.003     -7.563      0.000      -0.033      -0.019
# ExterQualDummy_TA            -0.0116      0.005     -2.138      0.033      -0.022      -0.001
# FoundationDummy_PConc         0.0238      0.005      4.572      0.000       0.014       0.034
# BsmtQualDummy_Ex              0.0286      0.004      7.005      0.000       0.021       0.037
# HeatingQCDummy_TA            -0.0107      0.004     -2.818      0.005      -0.018      -0.003
# CentralAirDummy_Y             0.0164      0.004      4.181      0.000       0.009       0.024
# KitchenQualDummy_TA          -0.0053      0.005     -1.077      0.281      -0.015       0.004
# FunctionalDummy_Typ           0.0170      0.003      4.913      0.000       0.010       0.024
# FireplaceQuDummy_Gd           0.0111      0.004      2.587      0.010       0.003       0.019
# ==============================================================================
# Omnibus:                      404.734   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3966.084
# Skew:                          -1.010   Prob(JB):                         0.00
# Kurtosis:                      10.852   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Refit until all vars significant

# %%
while True:
    if len(results.pvalues[results.pvalues > 0.05]) == 0:
        break
    significant_coefs = results.pvalues[results.pvalues < 0.05]
    significant_coefs = significant_coefs[significant_coefs.index != 'const']

    X_sm = X_Scaled[significant_coefs.index]
    X_sm = sm.add_constant(X_sm)
    model = sm.OLS(list(y),X_sm)
    results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     481.4
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                        09:20:06   Log-Likelihood:                 983.22
# No. Observations:                1448   AIC:                            -1908.
# Df Residuals:                    1419   BIC:                            -1755.
# Df Model:                          28
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        12.0246      0.003   3691.419      0.000      12.018      12.031
# LotFrontage                   0.0130      0.004      3.254      0.001       0.005       0.021
# LotArea                       0.0206      0.004      5.680      0.000       0.013       0.028
# OverallQual                   0.0388      0.005      8.378      0.000       0.030       0.048
# OverallCond                   0.0524      0.004     12.217      0.000       0.044       0.061
# YearBuilt                     0.0610      0.007      8.457      0.000       0.047       0.075
# YearRemodAdd                  0.0197      0.005      3.869      0.000       0.010       0.030
# BsmtFinSF1                    0.0400      0.004     10.091      0.000       0.032       0.048
# GrLivArea                     0.0744      0.009      8.390      0.000       0.057       0.092
# KitchenAbvGr                 -0.0181      0.004     -4.990      0.000      -0.025      -0.011
# Fireplaces                    0.0190      0.004      4.311      0.000       0.010       0.028
# GarageCars                    0.0251      0.005      5.047      0.000       0.015       0.035
# WoodDeckSF                    0.0097      0.004      2.733      0.006       0.003       0.017
# TotalSF                       0.1186      0.009     13.348      0.000       0.101       0.136
# Baths                         0.0126      0.006      2.063      0.039       0.001       0.025
# MSSubClassDummy_30           -0.0140      0.004     -3.777      0.000      -0.021      -0.007
# MSZoningDummy_RM             -0.0196      0.004     -4.930      0.000      -0.027      -0.012
# NeighborhoodDummy_Crawfor     0.0209      0.004      5.910      0.000       0.014       0.028
# NeighborhoodDummy_IDOTRR     -0.0113      0.004     -3.186      0.001      -0.018      -0.004
# NeighborhoodDummy_NridgHt     0.0134      0.004      3.476      0.001       0.006       0.021
# Condition1Dummy_Norm          0.0156      0.003      4.587      0.000       0.009       0.022
# Condition2Dummy_PosN         -0.0263      0.003     -7.571      0.000      -0.033      -0.019
# ExterQualDummy_TA            -0.0132      0.005     -2.615      0.009      -0.023      -0.003
# FoundationDummy_PConc         0.0244      0.005      4.734      0.000       0.014       0.034
# BsmtQualDummy_Ex              0.0284      0.004      6.951      0.000       0.020       0.036
# HeatingQCDummy_TA            -0.0111      0.004     -2.935      0.003      -0.019      -0.004
# CentralAirDummy_Y             0.0161      0.004      4.132      0.000       0.008       0.024
# FunctionalDummy_Typ           0.0171      0.003      4.947      0.000       0.010       0.024
# FireplaceQuDummy_Gd           0.0116      0.004      2.849      0.004       0.004       0.020
# ==============================================================================
# Omnibus:                      409.167   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4044.840
# Skew:                          -1.022   Prob(JB):                         0.00
# Kurtosis:                      10.929   Cond. No.                         9.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
residuals = results.resid
fitted = results.fittedvalues
sns.scatterplot(x=fitted,y=residuals).set_title('Residuals vs Fitted')
plt.xlabel('Fitted')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# #### Get CV results of model

# %%
model = LinearRegression()
params = {}
gridLr = GridSearchCV(model, param_grid=params, cv=5)
gridLr.fit(X_Scaled[significant_coefs.index], y)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(), param_grid={})

# %%
gridLr.cv_results_
# Out:
# {'mean_fit_time': array([0.00332937]),
#  'std_fit_time': array([0.00054429]),
#  'mean_score_time': array([0.00210567]),
#  'std_score_time': array([0.0003604]),
#  'params': [{}],
#  'split0_test_score': array([0.89792438]),
#  'split1_test_score': array([0.84651473]),
#  'split2_test_score': array([0.84492329]),
#  'split3_test_score': array([0.9136679]),
#  'split4_test_score': array([0.9128213]),
#  'mean_test_score': array([0.88317032]),
#  'std_test_score': array([0.03109158]),
#  'rank_test_score': array([1], dtype=int32)}

# %%
getFeatureImportance(50, X_Scaled[significant_coefs.index].columns, gridLr.best_estimator_.coef_,'descending')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('TotalSF', 0.11862480996673867),
#  ('GrLivArea', 0.07435909517262138),
#  ('YearBuilt', 0.06098937427842538),
#  ('OverallCond', 0.052442233101662294),
#  ('BsmtFinSF1', 0.039971964892101496),
#  ('OverallQual', 0.03882078788435345),
#  ('BsmtQualDummy_Ex', 0.028351800000512024),
#  ('Condition2Dummy_PosN', -0.02628675078829827),
#  ('GarageCars', 0.025085011191650727),
#  ('FoundationDummy_PConc', 0.02439165673621458),
#  ('NeighborhoodDummy_Crawfor', 0.020870617000482056),
#  ('LotArea', 0.02058661002441709),
#  ('YearRemodAdd', 0.01966413936605247),
#  ('MSZoningDummy_RM', -0.019596130346449223),
#  ('Fireplaces', 0.019010536656889003),
#  ('KitchenAbvGr', -0.018087956013840296),
#  ('FunctionalDummy_Typ', 0.017054740269257854),
#  ('CentralAirDummy_Y', 0.01605804291859625),
#  ('Condition1Dummy_Norm', 0.01557899417768213),
#  ('MSSubClassDummy_30', -0.013994365498939234),
#  ('NeighborhoodDummy_NridgHt', 0.013362485257670677),
#  ('ExterQualDummy_TA', -0.013219458608785744),
#  ('LotFrontage', 0.013040947118785296),
#  ('Baths', 0.012571182261617863),
#  ('FireplaceQuDummy_Gd', 0.011636364435975185),
#  ('NeighborhoodDummy_IDOTRR', -0.011275939501091648),
#  ('HeatingQCDummy_TA', -0.011131110938387347),
#  ('WoodDeckSF', 0.00965212124429207)]

# %%
estimates = pd.concat([pd.Series(X_Scaled[significant_coefs.index].columns), pd.Series(gridLr.best_estimator_.coef_)], axis=1)

# %%
estimates.columns = ['Variable', 'Coefficient Estimate']
estimates
# Out:
#                      Variable  Coefficient Estimate
# 0                 LotFrontage              0.013041
# 1                     LotArea              0.020587
# 2                 OverallQual              0.038821
# 3                 OverallCond              0.052442
# 4                   YearBuilt              0.060989
# 5                YearRemodAdd              0.019664
# 6                  BsmtFinSF1              0.039972
# 7                   GrLivArea              0.074359
# 8                KitchenAbvGr             -0.018088
# 9                  Fireplaces              0.019011
# 10                 GarageCars              0.025085
# 11                 WoodDeckSF              0.009652
# 12                    TotalSF              0.118625
# 13                      Baths              0.012571
# 14         MSSubClassDummy_30             -0.013994
# 15           MSZoningDummy_RM             -0.019596
# 16  NeighborhoodDummy_Crawfor              0.020871
# 17   NeighborhoodDummy_IDOTRR             -0.011276
# 18  NeighborhoodDummy_NridgHt              0.013362
# 19       Condition1Dummy_Norm              0.015579
# 20       Condition2Dummy_PosN             -0.026287
# 21          ExterQualDummy_TA             -0.013219
# 22      FoundationDummy_PConc              0.024392
# 23           BsmtQualDummy_Ex              0.028352
# 24          HeatingQCDummy_TA             -0.011131
# 25          CentralAirDummy_Y              0.016058
# 26        FunctionalDummy_Typ              0.017055
# 27        FireplaceQuDummy_Gd              0.011636

# %%
gridLr.score(X_Scaled[significant_coefs.index], y)
# Out:
# 0.9047504535571849

# %% [markdown]
# ### Interpreting Coeficient Estimates

# %%
coef_estimates = list(zip(X_Scaled[significant_coefs.index].columns, gridLr.best_estimator_.coef_))
coef_estimates
# Out:
# [('LotFrontage', 0.013040947118785296),
#  ('LotArea', 0.02058661002441709),
#  ('OverallQual', 0.03882078788435345),
#  ('OverallCond', 0.052442233101662294),
#  ('YearBuilt', 0.06098937427842538),
#  ('YearRemodAdd', 0.01966413936605247),
#  ('BsmtFinSF1', 0.039971964892101496),
#  ('GrLivArea', 0.07435909517262138),
#  ('KitchenAbvGr', -0.018087956013840296),
#  ('Fireplaces', 0.019010536656889003),
#  ('GarageCars', 0.025085011191650727),
#  ('WoodDeckSF', 0.00965212124429207),
#  ('TotalSF', 0.11862480996673867),
#  ('Baths', 0.012571182261617863),
#  ('MSSubClassDummy_30', -0.013994365498939234),
#  ('MSZoningDummy_RM', -0.019596130346449223),
#  ('NeighborhoodDummy_Crawfor', 0.020870617000482056),
#  ('NeighborhoodDummy_IDOTRR', -0.011275939501091648),
#  ('NeighborhoodDummy_NridgHt', 0.013362485257670677),
#  ('Condition1Dummy_Norm', 0.01557899417768213),
#  ('Condition2Dummy_PosN', -0.02628675078829827),
#  ('ExterQualDummy_TA', -0.013219458608785744),
#  ('FoundationDummy_PConc', 0.02439165673621458),
#  ('BsmtQualDummy_Ex', 0.028351800000512024),
#  ('HeatingQCDummy_TA', -0.011131110938387347),
#  ('CentralAirDummy_Y', 0.01605804291859625),
#  ('FunctionalDummy_Typ', 0.017054740269257854),
#  ('FireplaceQuDummy_Gd', 0.011636364435975185)]

# %%
var_unit_impact = []
for est in coef_estimates:
    if est[0] in colsToTransform:
        difference = np.exp(train['SalePrice'].mean() + est[1]) - np.exp(train['SalePrice'].mean())
        var_unit_impact.append((f'log({est[0]})',difference / train[est[0]].std()))
    else:
        difference = np.exp(train['SalePrice'].mean() + est[1]) - np.exp(train['SalePrice'].mean())
        var_unit_impact.append((est[0],difference / train[est[0]].std()))

# %%
pd.DataFrame(var_unit_impact, columns =['Coefficient', '1-unit change'])[:]
# Out:
#                   Coefficient  1-unit change
# 0                 LotFrontage      96.146118
# 1                     LotArea       0.350224
# 2                 OverallQual    4693.270691
# 3                 OverallCond    8182.109142
# 4                   YearBuilt     348.292255
# 5                YearRemodAdd     160.571908
# 6                  BsmtFinSF1      15.604238
# 7                   GrLivArea      25.217721
# 8                KitchenAbvGr  -13604.006201
# 9                  Fireplaces    4994.310124
# 10                 GarageCars    2838.596714
# 11                 WoodDeckSF      12.955992
# 12                    TotalSF      22.075398
# 13                      Baths    3330.303724
# 14         MSSubClassDummy_30  -11030.755918
# 15           MSZoningDummy_RM   -9100.030577
# 16  NeighborhoodDummy_Crawfor   19077.149070
# 17   NeighborhoodDummy_IDOTRR  -11848.509658
# 18  NeighborhoodDummy_NridgHt    9996.537605
# 19       Condition1Dummy_Norm    7652.760809
# 20       Condition2Dummy_PosN -116483.327691
# 21          ExterQualDummy_TA   -4514.985145
# 22      FoundationDummy_PConc    8282.602144
# 23           BsmtQualDummy_Ex   17393.365928
# 24          HeatingQCDummy_TA   -4056.134557
# 25          CentralAirDummy_Y   11010.187511
# 26        FunctionalDummy_Typ   11527.931779
# 27        FireplaceQuDummy_Gd    4451.197362

# %%
pd.DataFrame(var_unit_impact, columns =['Coefficient', '1-unit change'])[15:]
# Out:
#                   Coefficient  1-unit change
# 15           MSZoningDummy_RM   -9100.030577
# 16  NeighborhoodDummy_Crawfor   19077.149070
# 17   NeighborhoodDummy_IDOTRR  -11848.509658
# 18  NeighborhoodDummy_NridgHt    9996.537605
# 19       Condition1Dummy_Norm    7652.760809
# 20       Condition2Dummy_PosN -116483.327691
# 21          ExterQualDummy_TA   -4514.985145
# 22      FoundationDummy_PConc    8282.602144
# 23           BsmtQualDummy_Ex   17393.365928
# 24          HeatingQCDummy_TA   -4056.134557
# 25          CentralAirDummy_Y   11010.187511
# 26        FunctionalDummy_Typ   11527.931779
# 27        FireplaceQuDummy_Gd    4451.197362

# %% [markdown]
# # SVR

# %%
# model = SVR()
# params = {'kernel':['linear','rbf'], 'C':[0.01,1,10], 'epsilon':[0.01,0.1,1,10]}

# gridSvr = GridSearchCV(model, param_grid=params, cv=5)
# gridSvr.fit(X_Scaled, y)
# print(gridSvr.cv_results_)
# print(gridSvr.best_params_)
# print(gridSvr.best_score_)

# %%
# gridSvr.score(X_Scaled, y)

# %% [markdown]
# # SVR w/ Lasso Lars IC Selected Features

# %%
# model = SVR()
# params = {'kernel':['linear','rbf'], 'C':[0.01,1,10], 'epsilon':[0.01,0.1,1,10]}

# gridSvr = GridSearchCV(model, param_grid=params, cv=5)
# gridSvr.fit(X_Scaled[significant_coefs.index], y)
# print(gridSvr.cv_results_)
# print(gridSvr.best_params_)
# print(gridSvr.best_score_)

# %%
# gridSvr.score(X_Scaled[significant_coefs.index], y)

# %%
# getFeatureImportance(30, X_Scaled[significant_coefs.index].columns, gridSvr.best_estimator_.coef_[0], '')

# %%
# coef_estimates = list(zip(X_Scaled[significant_coefs.index].columns, gridSvr.best_estimator_.coef_[0]))
# coef_estimates

# %%
# var_unit_impact = []
# for est in coef_estimates:
#     difference = np.exp(train['SalePrice'].mean() + est[1]) - np.exp(train['SalePrice'].mean())
#     var_unit_impact.append((est[0],difference / train[est[0]].std()))

# %%
# var_unit_impact

# %% [markdown]
# # Test Predictions

# %%
X_test_scaled = scaler.transform(test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=test.columns)

# %%
gridLr_predictions = gridLr.predict(X_test_scaled[significant_coefs.index])
gridLr_predictions = pd.Series(np.exp(np.array(gridLr_predictions)))
gridLr_predictions.index = gridLr_predictions.index + 1461
gridLr_predictions = pd.DataFrame(gridLr_predictions, columns=['SalePrice'])
gridLr_predictions = gridLr_predictions.rename_axis('Id')

# %%
#gridLr_predictions.to_csv('./submissions/submission11.csv')
