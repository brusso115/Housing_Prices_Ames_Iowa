# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2357.2599295573427), ('GrLivArea', 1519.0444845001227), ('GarageCars', 1017.1507895603902), ('ExterQual', 1015.3073515980078), ('TotalBsmtSF', 913.720935556808), ('GarageArea', 899.4275280160379), ('KitchenQual', 797.8269447517779), ('BsmtQual', 789.1419761943806), ('1stFlrSF', 759.845899444944), ('FullBath', 647.5351240117253), ('TotRmsAbvGrd', 603.2330027520226), ('YearBuilt', 587.4683322414133), ('YearRemodAdd', 459.57370374050487), ('MasVnrArea', 355.81718208005674), ('GarageFinish', 341.49632667035627), ('Fireplaces', 324.63797307325336), ('HeatingQC', 274.6176570901941), ('BsmtFinSF1', 224.137696145814), ('MSSubClassDummy_60', 215.50933882537865), ('LotFrontage', 204.06789328584026), ('OpenPorchSF', 190.65974124747092), ('WoodDeckSF', 150.38726431970255), ('BsmtExposure', 146.36115186200846), ('LotArea', 137.8615266566324), ('2ndFlrSF', 120.82172760730981), ('HalfBath', 97.10569012973919), ('BsmtFullBath', 79.33460583203406), ('MSSubClassDummy_30', 71.79787226140209), ('BsmtUnfSF', 71.3885774387832), ('GarageYrBlt', 62.35711631802463), ('GarageCond', 49.1923773873856), ('GarageQual', 47.766381004899934), ('MSSubClassDummy_50', 41.196502225834045), ('BedroomAbvGr', 40.1132797518304), ('Fence', 38.917000869105806), ('OverallCond', 31.466775744366622), ('EnclosedPorch', 20.25901299577393), ('ExterCond', 19.052243100870328), ('KitchenAbvGr', 17.73133902958181), ('MSSubClassDummy_45', 7.2285082908647835), ('BsmtFinType2', 7.024204242476648), ('BsmtFinType1', 6.122970116924336), ('ScreenPorch', 4.633185095237071), ('BsmtHalfBath', 4.51638665643799), ('BsmtCond', 4.338611682063214), ('MoSold', 4.188439856910767), ('FireplaceQu', 4.067643448841854), ('LowQualFinSF', 3.944150308901957), ('3SsnPorch', 2.3899215374711393), ('LandSlope', 1.7233069181147846), ('MiscVal', 0.9396029787401404), ('BsmtFinSF2', 0.5363414900644955), ('YrSold', 0.024233110722966824), ('PoolArea', 0.007674113087988735), ('PoolQC', 0.0032527251013259074), ('MSSubClassDummy_40', 0.0006249002274557575), ('UtilitiesDummy_NoSeWa', nan), ('NeighborhoodDummy_NridgHt', 279.6589420651194), ('NeighborhoodDummy_NoRidge', 162.58837368198593), ('MSZoningDummy_RM', 134.37160095356538), ('LotShapeDummy_Reg', 88.72361291294862), ('MSZoningDummy_RL', 77.55192647533528), ('NeighborhoodDummy_NAmes', 66.34707907554237), ('NeighborhoodDummy_OldTown', 58.47032911781518), ('NeighborhoodDummy_Edwards', 49.92968891186174), ('NeighborhoodDummy_StoneBr', 37.65603680975148), ('NeighborhoodDummy_BrkSide', 30.837813861470618), ('NeighborhoodDummy_Sawyer', 29.68456046052015), ('NeighborhoodDummy_Timber', 27.802686290570758), ('NeighborhoodDummy_Somerst', 27.659087430877943), ('MSSubClassDummy_160', 22.78571632569181), ('LotConfigDummy_CulDSac', 17.82605995261617), ('NeighborhoodDummy_BrDale', 17.637637430678335), ('NeighborhoodDummy_IDOTRR', 17.616877245422955), ('Condition1Dummy_Norm', 17.27798042259933), ('NeighborhoodDummy_MeadowV', 16.09352418445402), ('AlleyDummy_No_Alley_Access', 14.772839261248127), ('MSSubClassDummy_90', 14.037418693823007), ('Condition1Dummy_Feedr', 14.034257632220585), ('LandContourDummy_HLS', 11.501699205271875), ('MSZoningDummy_FV', 10.850846635150589), ('NeighborhoodDummy_CollgCr', 10.349589627637092), ('MSSubClassDummy_190', 10.155318512089403), ('LotConfigDummy_Inside', 7.726943780753719), ('NeighborhoodDummy_Mitchel', 6.2703893599362495), ('MSZoningDummy_RH', 6.171856478437915), ('LotShapeDummy_IR2', 6.163850970879646), ('NeighborhoodDummy_ClearCr', 5.851551202134586), ('MSSubClassDummy_180', 5.2777169125425045), ('MSSubClassDummy_85', 4.9373073825750975), ('NeighborhoodDummy_SWISU', 4.6595515150301265), ('Condition1Dummy_PosA', 3.3388318032242603), ('MSSubClassDummy_120', 3.2764897838334996), ('LandContourDummy_Low', 2.7165861370337994), ('NeighborhoodDummy_Veenker', 2.7095179606388435), ('NeighborhoodDummy_NPkVill', 2.6471484126531513), ('NeighborhoodDummy_Crawfor', 2.558473959715394), ('Condition1Dummy_RRAe', 2.2567354543733216), ('Cond ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.cv_results_

# %%
gridRf.best_params_

# %%
gridRf.best_score_

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.cv_results_

# %%
gridRidge.best_params_

# %%
gridRidge.best_score_

# %%
gridRidge.best_estimator_.coef_

# %%
getFeatureImportance(50, train.columns, gridRidge.best_estimator_.coef_,'descending')

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.cv_results_

# %%
gridLasso.best_params_

# %%
gridLasso.best_score_

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)

# %%
gridRf.best_score_

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)

# %%
gridRidge.best_score_

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)

# %%
mostCorrelatedFeat.head(50)

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])

# %%
list(vifs)

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
def addHasPool(data):
    data['hasPool'] = data['PoolQC'].apply(lambda x: 0 if x=='No_Pool' else 1)

# %%
addHasPool(train)

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)

# %%
gridLasso.best_score_

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))

# %%
X_Scaled.corr()
