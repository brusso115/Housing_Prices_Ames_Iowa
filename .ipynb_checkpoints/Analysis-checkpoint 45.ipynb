# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.feature_selection import SelectKBest, f_regression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from regressors import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled_na.csv')

# %%
train.drop('Id', axis = 1, inplace=True)

# %%
allZeroCols = train.columns[(train == 0).all()].to_list()
train = train.drop(allZeroCols, axis=1)

# %% [markdown]
# # Outlier Detection

# %%
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(train)

# %%
mask = yhat != -1

# %%
train = train.loc[mask, :]

# %%
X = train.loc[:, train.columns != 'SalePrice']
y = train['SalePrice']

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Select K Best

# %%
def get_k_best(k):
    k_best = SelectKBest(f_regression, k=k).fit(X, y)
    X[X.columns[k_best.get_support()]]

    k_best_scores = zip(X.columns, k_best.scores_)
    sorted_coef_importance = sorted(list(k_best_scores),key= lambda x: x[1],reverse=True)
    sorted_coef_importance
    print(sorted_coef_importance)
    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_coef_importance[:k]], [x[1] for x in sorted_coef_importance[:k]])
    plt.xticks(rotation=90)

# %%
get_k_best(50)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 2343.006770502344), ('GrLivArea', 1610.7241421795127), ('GarageCars', 994.7879668899876), ('GarageArea', 920.3280050307479), ('ExterQual', 850.510362540004), ('TotalBsmtSF', 787.2246884605031), ('FullBath', 733.485683201715), ('1stFlrSF', 708.619465035397), ('BsmtQual', 691.6540899891575), ('KitchenQual', 676.6653446467967), ('YearBuilt', 613.3393513828306), ('TotRmsAbvGrd', 551.3663192724576), ('YearRemodAdd', 489.33456513266714), ('Fireplaces', 324.05042999447033), ('MasVnrArea', 320.77262577691295), ('GarageFinish', 293.4029557072298), ('HeatingQC', 277.1321973075216), ('MSSubClassDummy_60', 252.2342056991865), ('NeighborhoodDummy_NridgHt', 213.37605862538842), ('LotFrontage', 205.741219468045), ('BsmtFinSF1', 199.27685476717375), ('NeighborhoodDummy_NoRidge', 187.956462288622), ('WoodDeckSF', 169.7036122877397), ('2ndFlrSF', 160.57229897166437), ('OpenPorchSF', 158.41815577521692), ('MSZoningDummy_RM', 157.3022834093913), ('LotArea', 154.26739276705808), ('BsmtExposure', 141.61727754753892), ('HalfBath', 113.43749810862595), ('LotShapeDummy_Reg', 101.08411720270989), ('MSZoningDummy_RL', 91.87902366585001), ('MSSubClassDummy_30', 91.25263555568216), ('GarageYrBlt', 87.16680447062741), ('BsmtFullBath', 80.9585517347387), ('GarageCond', 68.84496905084411), ('NeighborhoodDummy_OldTown', 64.25068081705946), ('BsmtUnfSF', 61.711369944986856), ('GarageQual', 59.751477054523626), ('NeighborhoodDummy_NAmes', 59.1337380224616), ('BedroomAbvGr', 57.18406620452848), ('NeighborhoodDummy_Edwards', 46.35068077839787), ('Fence', 41.119132329189966), ('MSSubClassDummy_50', 36.16710578342765), ('NeighborhoodDummy_IDOTRR', 34.3961312128455), ('NeighborhoodDummy_Somerst', 31.89723820484745), ('NeighborhoodDummy_StoneBr', 30.682203279149995), ('NeighborhoodDummy_Sawyer', 28.789084090696694), ('NeighborhoodDummy_Timber', 26.641509662706177), ('NeighborhoodDummy_BrkSide', 26.37260866301), ('LotConfigDummy_CulDSac', 23.01543528924821), ('OverallCond', 22.190508489636684), ('EnclosedPorch', 21.31687607386631), ('MSSubClassDummy_160', 20.84414252413861), ('Condition1Dummy_Norm', 19.833137646737935), ('ExterCond', 19.63421406527862), ('NeighborhoodDummy_MeadowV', 18.168657301795083), ('NeighborhoodDummy_BrDale', 17.45085027865851), ('KitchenAbvGr', 17.150988368982162), ('AlleyDummy_No_Alley_Access', 15.956572299417996), ('MSZoningDummy_FV', 15.72699131356249), ('NeighborhoodDummy_CollgCr', 15.419534705358174), ('LandContourDummy_HLS', 14.856392299266926), ('Condition1Dummy_Feedr', 13.696938858167009), ('MSSubClassDummy_90', 13.216391289611186), ('MSSubClassDummy_45', 12.660364674087608), ('MSSubClassDummy_190', 11.149289332404035), ('BsmtFinType2', 10.514306510594496), ('BsmtFinType1', 10.238647620427214), ('BsmtCond', 8.386922119542758), ('LotShapeDummy_IR2', 8.235219626678134), ('MSZoningDummy_RH', 7.888193327423318), ('MSSubClassDummy_180', 7.164227226847389), ('LowQualFinSF', 6.621629581661165), ('LotConfigDummy_Inside', 6.573785517400889), ('NeighborhoodDummy_SWISU', 6.572269733841321), ('NeighborhoodDummy_Crawfor', 5.235131956191665), ('MSSubClassDummy_85', 4.9963489615888035), ('NeighborhoodDummy_Mitchel', 4.709160050738628), ('MoSold', 4.702029693469323), ('NeighborhoodDummy_ClearCr', 4.694082967873737), ('MSSubClassDummy_120', 4.474826678024267), ('NeighborhoodDummy_Gilbert', 4.436578288716789), ('LandSlope', 4.39892203157614), ('BsmtHalfBath', 4.23839226920993), ('Condition1Dummy_PosA', 4.16248948525328), ('LandContourDummy_Low', 4.159702519888312), ('Condition1Dummy_RRAe', 3.9441336431084024), ('ScreenPorch', 3.5070536460395094), ('NeighborhoodDummy_Veenker', 3.4597783451142154), ('NeighborhoodDummy_NPkVill', 2.388279935168356), ('LotConfigDummy_FR3', 2.2144823003076226), ('NeighborhoodDummy_SawyerW', 1.9992802626224253), ('FireplaceQu', 1.7388577208641087), ('YrSold', 1.5593730372193624), ('Condition1Dummy_PosN', 1.498675079252218), ('BsmtFinSF2', 1.1769929978185272), ('LotShapeDummy_IR3', 1.175679582701553), ('MSSubCla ...

# %% [markdown]
# ## Model Feature Selection

# %%
def getFeatureImportance(num, cols, features_importances_, sort):
    
    feature_importances = zip(cols, features_importances_)
    sorted_importance = sorted(list(feature_importances),key= lambda x: abs(x[1]),reverse=False if sort == 'ascending' else True)

    f, ax = plt.subplots(figsize=(13, 9))
    sns.barplot([x[0] for x in sorted_importance[:num]], [x[1] for x in sorted_importance[:num]])
    plt.xticks(rotation=90)
    
    return sorted_importance

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.cv_results_
# Out:
# {'mean_fit_time': array([1.36904726, 0.23698974]),
#  'std_fit_time': array([0.08979922, 0.03272865]),
#  'mean_score_time': array([0.01066527, 0.01164417]),
#  'std_score_time': array([0.00099887, 0.00218513]),
#  'param_max_features': masked_array(data=['auto', 'sqrt'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 100],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto', 'n_estimators': 100},
#   {'max_features': 'sqrt', 'n_estimators': 100}],
#  'split0_test_score': array([0.86569601, 0.89250297]),
#  'split1_test_score': array([0.90474312, 0.8763373 ]),
#  'split2_test_score': array([0.85171981, 0.84199243]),
#  'split3_test_score': array([0.88582928, 0.88503667]),
#  'split4_test_score': array([0.85312022, 0.82624457]),
#  'mean_test_score': array([0.87222169, 0.86442279]),
#  'std_test_score': array([0.02034988, 0.02575299]),
#  'rank_test_score': array([1, 2], dtype=int32)}

# %%
gridRf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 100}

# %%
gridRf.best_score_
# Out:
# 0.872221686851032

# %%
getFeatureImportance(50, train.columns, gridRf.best_estimator_.feature_importances_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('OverallQual', 0.546778135289492),
#  ('GrLivArea', 0.13091372012543404),
#  ('GarageArea', 0.046884962398679564),
#  ('BsmtFinSF1', 0.045814682102132395),
#  ('TotalBsmtSF', 0.042143456497928326),
#  ('1stFlrSF', 0.018319828330951325),
#  ('GarageCars', 0.017231920085849527),
#  ('YearBuilt', 0.009594839070602611),
#  ('LotArea', 0.00916679679031824),
#  ('FullBath', 0.009142544531624365),
#  ('YearRemodAdd', 0.008387595041783484),
#  ('2ndFlrSF', 0.007705163539282395),
#  ('MasVnrArea', 0.007272960967012605),
#  ('BsmtUnfSF', 0.006403079825348138),
#  ('BsmtQual', 0.005842933891293374),
#  ('LotFrontage', 0.005738280292008079),
#  ('WoodDeckSF', 0.005099686956776523),
#  ('OpenPorchSF', 0.005073756017244152),
#  ('GarageYrBlt', 0.0049764039464837324),
#  ('OverallCond', 0.004832475187744475),
#  ('KitchenQual', 0.0035568151148359234),
#  ('MoSold', 0.003315786591821307),
#  ('TotRmsAbvGrd', 0.002447889015728785),
#  ('FunctionalDummy_Typ', 0.002276511663317091),
#  ('BsmtFinType1', 0.00218867454888984),
#  ('GarageFinish', 0.00198258275019321),
#  ('BsmtExposure', 0.0019057717307978134),
#  ('YrSold', 0.001821258516585367),
#  ('Fireplaces', 0.001794864546655295),
#  ('BedroomAbvGr', 0.0016321020048028667),
#  ('FireplaceQu', 0.001596232097344238),
#  ('ExterQual', 0.0015800401688163801),
#  ('MSZoningDummy_RL', 0.0015068879732507328),
#  ('BsmtFullBath', 0.0014608284058405642),
#  ('LotShapeDummy_IR3', 0.0013294390504611398),
#  ('GarageTypeDummy_CarPort', 0.0013206758829178396),
#  ('HeatingDummy_Wall', 0.0012639663789722167),
#  ('Exterior2ndDummy_Stucco', 0.0012582953707081102),
#  ('HalfBath', 0.0012041728240292288),
#  ('FunctionalDummy_Sev', 0.0008588093909623488),
#  ('HeatingQC', 0.0007975441919509731),
#  ('NeighborhoodDummy_CollgCr', 0.000755672555425841),
#  ('LotShapeDummy_Reg', 0.00072316763995779),
#  ('NeighborhoodDummy_Blueste', 2.073538913240069e-06),
#  ('ElectricalDummy_FuseF', 1.94518082282828e-06),
#  ('RoofStyleDummy_Hip', 1.8598016978863457e-06),
#  ('SaleTypeDummy_Con', 1.2299328823995305e-06),
#  ('Condition1Dummy_RRAn', 1.2023874010280883e-06),
#  ('HeatingDummy_GasW', 1.0761221393468457e-06),
#  ('MiscFeatureDummy_No_Misc_Feature', 9.820955149820247e-07),
#  ('HouseStyleDummy_1Story', 9.587104618325986e-07),
#  ('MSSubClassDummy_160', 8.618689136688157e-07),
#  ('Condition1Dummy_RRNn', 7.177940596951845e-07),
#  ('SaleTypeDummy_WD', 6.967706609368962e-07),
#  ('Exterior1stDummy_HdBoard', 6.383211864768309e-07),
#  ('HouseStyleDummy_2.5Fin', 4.811907565857497e-07),
#  ('MSZoningDummy_RM', 4.232693669616976e-07),
#  ('Condition1Dummy_RRNe', 1.6080969218511144e-07),
#  ('HeatingDummy_OthW', 1.5537244626848512e-07),
#  ('Condition2Dummy_RRAe', 1.172877312450574e-07),
#  ('MSSubClassDummy_30', 9.177666930632138e-08),
#  ('RoofMatlDummy_WdShake', 6.79854448750919e-08),
#  ('Exterior1stDummy_BrkFace', 4.580740498775505e-08),
#  ('LandContourDummy_Lvl', 2.574068114293207e-09),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('Exterior2ndDummy_BrkFace', 0.0),
#  ('FoundationDummy_Slab', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Ridge Regression

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000]})

# %%
gridRidge.cv_results_
# Out:
# {'mean_fit_time': array([0.02457056, 0.00486727, 0.00479641, 0.00484514, 0.00488591,
#         0.00516181, 0.00514297, 0.00495181]),
#  'std_fit_time': array([3.94050851e-02, 2.55242312e-04, 2.40741269e-04, 2.13697646e-04,
#         2.22681779e-04, 8.98529248e-05, 1.79911829e-04, 1.18685774e-04]),
#  'mean_score_time': array([0.0024231 , 0.00267062, 0.00265646, 0.00265484, 0.00261035,
#         0.00276952, 0.0026372 , 0.00268435]),
#  'std_score_time': array([3.60983851e-04, 9.59447552e-05, 7.61906103e-05, 7.18349125e-05,
#         2.75605014e-04, 1.50192079e-04, 8.99681156e-05, 5.13726483e-05]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1},
#   {'alpha': 1},
#   {'alpha': 10},
#   {'alpha': 50},
#   {'alpha': 75},
#   {'alpha': 100},
#   {'alpha': 1000},
#   {'alpha': 2000}],
#  'split0_test_score': array([0.89291621, 0.89584051, 0.9000949 , 0.9043293 , 0.90580005,
#         0.90691997, 0.90164031, 0.88072414]),
#  'split1_test_score': array([0.9066249 , 0.9083509 , 0.91062881, 0.91032175, 0.90964793,
#         0.90896681, 0.88283527, 0.85230807]),
#  'split2_test_score': array([0.86216505, 0.87278974, 0.8795574 , 0.88479227, 0.88566065,
#         0.88605498, 0.86929049, 0.84284377]),
#  'split3_test_score': array([0.89821532, 0.89945376, 0.90304054, 0.90826839, 0.90965367,
#  ('Exterior1stDummy_Wd Sdng', 1101.1518252921906),
#  ('HeatingQC', -1087.2826213804346),
#  ('FunctionalDummy_Min1', 1082.7047431982205),
#  ('PoolArea', 1065.8488880877035),
#  ('Exterior2ndDummy_CmentBd', -1048.6657460669066),
#  ('LotConfigDummy_CulDSac', -1040.4394717974362),
#  ('MSZoningDummy_RH', 1032.9597037758654),
#  ('FoundationDummy_Stone', -1023.8114334644649),
#  ('LandContourDummy_Lvl', -991.8675506853212),
#  ('SalePrice', -942.2427285689483),
#  ('NeighborhoodDummy_BrDale', 904.1009307229077),
#  ('NeighborhoodDummy_OldTown', -893.1845209755932),
#  ('MSSubClassDummy_50', 891.7881469205064),
#  ('BsmtUnfSF', -872.0073001551126),
#  ('RoofMatlDummy_WdShake', 867.1654703615847),
#  ('Condition1Dummy_PosA', 838.2464438707549),
#  ('FunctionalDummy_Min2', -835.6737825978951),
#  ('MSZoningDummy_RM', 821.4468045498817),
#  ('NeighborhoodDummy_NAmes', 773.8940317047521),
#  ('NeighborhoodDummy_Timber', 760.7439048969594),
#  ('LandContourDummy_HLS', -757.8906460198474),
#  ('PavedDriveDummy_P', 740.4678200043463),
#  ('BsmtFinSF2', 730.3511725998862),
#  ('NeighborhoodDummy_IDOTRR', -723.1757630094241),
#  ('GarageFinish', -718.0764274524377),
#  ('FireplaceQu', -696.8977557727501),
#  ('HalfBath', 693.7971321175205),
#  ('RoofMatlDummy_Tar&Grv', -693.0551452139982),
#  ('GarageYrBlt', -675.5192965534643),
#  ('YrSold', -653.689422504045),
#  ('HouseStyleDummy_SLvl', -643.4907370999855),
#  ('LotConfigDummy_FR2', -637.8313827592956),
#  ('GarageTypeDummy_CarPort', 635.2212860067067),
#  ('SaleTypeDummy_WD', 621.1388820007479),
#  ('Exterior2ndDummy_CBlock', 615.1579467804147),
#  ('Condition2Dummy_RRNn', -607.1664242707426),
#  ('MSSubClassDummy_180', -607.1664242707363),
#  ('Exterior1stDummy_MetalSd', -600.9833370957182),
#  ('HouseStyleDummy_SFoyer', 571.8037425238203),
#  ('SaleConditionDummy_Alloca', 560.8399409489074),
#  ('MasVnrTypeDummy_Stone', 560.1851753537577),
#  ('MSSubClassDummy_80', -553.822599634688),
#  ('GarageTypeDummy_Detchd', 546.4839029544445),
#  ('NeighborhoodDummy_StoneBr', -545.1809481468377),
#  ('Exterior2ndDummy_Brk Cmn', -542.824821791026),
#  ('NeighborhoodDummy_SawyerW', 538.2357895577829),
#  ('Condition1Dummy_RRAe', 520.5327080331347),
#  ('Exterior1stDummy_CemntBd', -517.7080180181557),
#  ('RoofStyleDummy_Gable', 512.3703304080407),
#  ('BsmtCond', 497.37874931452944),
#  ('StreetDummy_Pave', 491.5417435908437),
#  ('SaleTypeDummy_Con', 488.5891254398272),
#  ('ExterCond', 481.84320855256726),
#  ('HeatingDummy_GasW', -472.2469861681866),
#  ('Exterior1stDummy_HdBoard', -470.34662009306743),
#  ('RoofMatlDummy_Membran', 440.0624760147919),
#  ('ElectricalDummy_SBrkr', -434.36740302126145),
#  ('Exterior1stDummy_ImStucc', 420.7911411223091),
#  ('GarageTypeDummy_Attchd', 419.23916148975593),
#  ('Exterior2ndDummy_AsphShn', 399.4051056421379),
#  ('PoolQC', 392.6994211679853),
#  ('LotShapeDummy_IR2', -390.4825050662064),
#  ('Condition1Dummy_RRNn', -381.66112478834555),
#  ('FoundationDummy_Slab', -378.6335013434798),
#  ('GarageTypeDummy_No_Garage', -375.39665289390666),
#  ('HouseStyleDummy_2.5Fin', -369.8377113744821),
#  ('BldgTypeDummy_TwnhsE', 365.71674555101544),
#  ('Condition1Dummy_RRAn', -348.16256182659384),
#  ('Exterior2ndDummy_Stone', 339.2425693248408),
#  ('Exterior1stDummy_Stone', 337.1518389039547),
#  ('Fence', 336.94768528213126),
#  ('HeatingDummy_GasA', 336.9443764384972),
#  ('MSSubClassDummy_60', 329.6439246944803),
#  ('SaleTypeDummy_ConLD', -327.78195571993786),
#  ('Exterior2ndDummy_Plywood', -325.5755933175717),
#  ('RoofStyleDummy_Gambrel', 323.4191579248969),
#  ('3SsnPorch', 313.4468002466059),
#  ('MSSubClassDummy_85', -310.8399251799757),
#  ('BldgTypeDummy_2fmCon', -310.83992517997075),
#  ('HeatingDummy_Wall', 308.6778283560989),
#  ('SaleConditionDummy_AdjLand', 304.10138621744113),
#  ('Condition2Dummy_Feedr', -303.92203919584045),
#  ('Exterior1stDummy_AsphShn', -301.376854539301),
#  ('ElectricalDummy_FuseP', 288.5432828640855),
#  ('LotShapeDummy_IR3', 283.4836690426778),
#  ('NeighborhoodDummy_Sawyer', -281.5735597538105),
#  ('MoSold', -279.0790575707806),
#  ('SaleTypeDummy_New', 268.71955286440993),
#  ('Exterior1stDummy_Stucco', -262.35134551738065),
#  ('LotConfigDummy_Inside', 246.18645845702883),
#  ('NeighborhoodDummy_Gilbert', -241.24853356142538),
#  ('EnclosedPorch', 240.32303149805924),
#  ('ElectricalDummy_FuseF', 237.71730954996045),
#  ('FunctionalDummy_Typ', -237.30695541434147),
#  ('Condition2Dummy_RRAn', -234.6923365028261),
#  ('MiscFeatureDummy_Othr', 233.45334857041556),
#  ('NeighborhoodDummy_Veenker', 226.85603196929299),
#  ('MSSubClassDummy_45', -225.9896028151666),
#  ('Condition2Dummy_RRAe', -210.04242416997928),
#  ('LandContourDummy_Low', 209.59060409568386),
#  ('Exterior1stDummy_BrkFace', -203.98303981106653),
#  ('Exterior2ndDummy_BrkFace', -203.98303981106238),
#  ('MSSubClassDummy_70', 203.14969843456822),
#  ('MSZoningDummy_RL', -197.1143035262124),
#  ('GarageCond', 194.81413483079265),
#  ('MSSubClassDummy_160', -179.0138454009883),
#  ('LandSlope', 169.75370570234264),
#  ('MiscFeatureDummy_No_Misc_Feature', 169.19259207782147),
#  ('NeighborhoodDummy_BrkSide', -169.1173035306466),
#  ('HouseStyleDummy_1.5Unf', 162.03007534111265),
#  ('MSZoningDummy_FV', 152.5341580571432),
#  ('GarageQual', -152.09350441280716),
#  ('PavedDriveDummy_Y', -148.93199746968023),
#  ('BsmtHalfBath', -148.80309470754338),
#  ('MiscVal', 141.57692140362647),
#  ('SaleTypeDummy_ConLI', -139.03463401237303),
#  ('Exterior1stDummy_WdShing', 133.89547962583077),
#  ('Exterior2ndDummy_Stucco', 133.38594018468342),
#  ('SaleTypeDummy_Oth', -131.49910348159966),
#  ('LotConfigDummy_FR3', 129.6303975598318),
#  ('BsmtFinType1', -127.36119461621966),
#  ('AlleyDummy_Pave', -122.91766553172566),
#  ('RoofStyleDummy_Hip', -120.36892011261601),
#  ('HouseStyleDummy_2Story', -115.5427422094479),
#  ('Exterior2ndDummy_ImStucc', 114.94262568547009),
#  ('BsmtFinType2', -92.38458429498559),
#  ('HeatingDummy_OthW', -91.83678396932446),
#  ('NeighborhoodDummy_SWISU', -87.72011102232395),
#  ('FunctionalDummy_Maj2', 86.46768231676103),
#  ('Condition1Dummy_Norm', 83.9421207015911),
#  ('MSSubClassDummy_40', -83.91376129294382),
#  ('FoundationDummy_Wood', 83.67995781572861),
#  ('GarageTypeDummy_BuiltIn', -81.50708721267951),
#  ('RoofMatlDummy_WdShngl', -81.20914772393827),
#  ('CentralAirDummy_Y', 79.43676850386865),
#  ('Exterior1stDummy_Plywood', 73.592271347586),
#  ('Condition1Dummy_RRNe', -70.38226555064368),
#  ('Exterior1stDummy_CBlock', 63.986102307780385),
#  ('AlleyDummy_No_Alley_Access', -62.48467373739825),
#  ('RoofMatlDummy_Roll', -59.87955495417861),
#  ('ElectricalDummy_Mix', 54.01045054632952),
#  ('Exterior2ndDummy_HdBoard', -46.966511431961514),
#  ('RoofStyleDummy_Shed', -42.82749807187919),
#  ('MasVnrTypeDummy_BrkFace', 39.28981395576986),
#  ('LowQualFinSF', -31.413055186844964),
#  ('Exterior2ndDummy_MetalSd', 22.342506044920086),
#  ('MSSubClassDummy_30', 21.523694324072505),
#  ('Exterior2ndDummy_Wd Shng', 7.661213039108026),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0)]

# %% [markdown]
# ### Lasso Regression

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151204465843.47946, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148907440137.6556, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144642794907.9221, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159502231959.2519, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137019515313.1741, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106636248737.58588, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102994361635.97272, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117822600783.5971, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121095096174.20718, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113292846768.63548, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14548365124.593231, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.cv_results_
# Out:
# {'mean_fit_time': array([0.11618824, 0.11693721, 0.11613917, 0.08471479, 0.05660939,
#         0.05083442, 0.01149149, 0.00874548]),
#  'std_fit_time': array([0.00759114, 0.00130171, 0.0021898 , 0.00745186, 0.0045289 ,
#         0.00301187, 0.00433694, 0.00247425]),
#  'mean_score_time': array([0.00253344, 0.00263028, 0.00257096, 0.00290689, 0.00281343,
#         0.00266633, 0.00272536, 0.00240812]),
#  'std_score_time': array([0.00038924, 0.00025787, 0.00030315, 0.00012772, 0.00012938,
#         0.00042119, 0.00012078, 0.00034454]),
#  'param_alpha': masked_array(data=[0.1, 1, 10, 50, 75, 100, 1000, 2000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1, 'max_iter': 1000},
#   {'alpha': 1, 'max_iter': 1000},
#   {'alpha': 10, 'max_iter': 1000},
#   {'alpha': 50, 'max_iter': 1000},
#   {'alpha': 75, 'max_iter': 1000},
#   {'alpha': 100, 'max_iter': 1000},
#   {'alpha': 1000, 'max_iter': 1000},
#   {'alpha': 2000, 'max_iter': 1000}],
#  'split0_test_score': array([0.89301335, 0.89336762, 0.89782665, 0.90208279, 0.90376625,
#         0.90490534, 0.90563557, 0.89307271]),
#  'split1_test_score': array([0.90680465, 0.90742688, 0.9101657 , 0.9142004 , 0.91505596,
#         0.91573945, 0.91431505, 0.90419597]),
#  'split2_test_score': array([0.86681547, 0.86892411, 0.87558308, 0.88310553, 0.88665782,
#         0.88888086, 0.88398071, 0.87247437]),
#  'split3_test_score': array([0.89814536, 0.8985142 , 0.90075774, 0.90557494, 0.90797687,
#         0.90995029, 0.91408839, 0.90016529]),
#  'split4_test_score': array([0.88743845, 0.88782356, 0.88817313, 0.88946269, 0.88974867,
#         0.89019893, 0.891453  , 0.88154951]),
#  'mean_test_score': array([0.89044346, 0.89121128, 0.89450126, 0.89888527, 0.90064112,
#         0.90193498, 0.90189454, 0.89029157]),
#  'std_test_score': array([0.01342329, 0.01287729, 0.01177726, 0.01120102, 0.01082169,
#         0.0106937 , 0.01222199, 0.01176804]),
#  'rank_test_score': array([7, 6, 5, 4, 3, 1, 2, 8], dtype=int32)}

# %%
gridLasso.best_params_
# Out:
# {'alpha': 100, 'max_iter': 1000}

# %%
gridLasso.best_score_
# Out:
# 0.9019349751780549

# %%
getFeatureImportance(50, train.columns, gridLasso.best_estimator_.coef_, '')
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [('GrLivArea', 26558.250198362148),
#  ('OverallQual', 10103.115839411805),
#  ('YearBuilt', 8440.87880046876),
#  ('BsmtFinSF1', 7925.260691946274),
#  ('OverallCond', 5827.067341558782),
#  ('FunctionalDummy_Sev', 5777.471881177216),
#  ('TotalBsmtSF', 5174.184151224088),
#  ('SaleConditionDummy_Normal', 5000.622044940058),
#  ('NeighborhoodDummy_NoRidge', 4975.658613238509),
#  ('LotArea', 4854.797105459689),
#  ('KitchenQual', -3758.4803246653814),
#  ('NeighborhoodDummy_NWAmes', 3757.01158269679),
#  ('MasVnrArea', 3593.7334538565033),
#  ('BsmtQual', -3544.5950647173004),
#  ('NeighborhoodDummy_Somerst', 3413.5199620156172),
#  ('GarageCars', 3340.769937729165),
#  ('2ndFlrSF', 3170.7306204043534),
#  ('Exterior1stDummy_BrkComm', 3142.6739998186363),
#  ('Condition1Dummy_Feedr', 2938.9171040657156),
#  ('KitchenAbvGr', -2887.5441812338827),
#  ('HouseStyleDummy_1.5Unf', 2586.187499786271),
#  ('NeighborhoodDummy_CollgCr', 2519.197584798514),
#  ('BedroomAbvGr', -2387.353571555108),
#  ('NeighborhoodDummy_Timber', 773.661361721724),
#  ('Condition1Dummy_PosA', 755.582729492913),
#  ('LandContourDummy_HLS', -745.066504633509),
#  ('HouseStyleDummy_SLvl', -725.0409716473897),
#  ('Condition1Dummy_RRAe', 686.7592997064552),
#  ('NeighborhoodDummy_Mitchel', -680.4981963537319),
#  ('SaleConditionDummy_Alloca', 678.1197872074213),
#  ('Exterior2ndDummy_Brk Cmn', -675.6562542023206),
#  ('LandContourDummy_Lvl', -670.2116673086276),
#  ('PoolArea', 668.5197700116265),
#  ('GarageYrBlt', -658.3312803600963),
#  ('Exterior2ndDummy_VinylSd', 633.377633605882),
#  ('LotConfigDummy_FR2', -619.6762796022635),
#  ('SaleTypeDummy_WD', 607.9894680464998),
#  ('Exterior1stDummy_ImStucc', 605.2416570597132),
#  ('NeighborhoodDummy_SawyerW', 604.9914732487198),
#  ('MSSubClassDummy_180', -592.2649916513661),
#  ('NeighborhoodDummy_OldTown', -583.2428589467121),
#  ('NeighborhoodDummy_SWISU', 557.6140042000508),
#  ('YrSold', -543.293365451437),
#  ('BsmtCond', 532.6422328830213),
#  ('GarageFinish', -511.91092375118734),
#  ('FireplaceQu', -508.8696799230394),
#  ('RoofMatlDummy_Membran', 478.5764945676805),
#  ('Exterior1stDummy_HdBoard', -451.6075302597365),
#  ('MSSubClassDummy_60', 444.7803490864182),
#  ('Exterior2ndDummy_CBlock', 428.6769762363345),
#  ('LotShapeDummy_IR3', 412.7450610050977),
#  ('GarageTypeDummy_No_Garage', -412.28926156653944),
#  ('PavedDriveDummy_Y', -372.8912877286124),
#  ('FunctionalDummy_Min2', -366.8971250287557),
#  ('HeatingDummy_GasW', -363.1847834884664),
#  ('Exterior2ndDummy_Stone', 355.23926049935494),
#  ('NeighborhoodDummy_Veenker', 337.71534096467667),
#  ('SaleConditionDummy_AdjLand', 333.8799197416653),
#  ('FullBath', 330.99924115130545),
#  ('EnclosedPorch', 321.96087656200154),
#  ('ExterCond', 318.54216564358103),
#  ('SaleTypeDummy_Con', 309.1612164373584),
#  ('AlleyDummy_No_Alley_Access', -308.4532342609387),
#  ('RoofStyleDummy_Gable', 288.29646843729296),
#  ('PavedDriveDummy_P', 283.860932282775),
#  ('NeighborhoodDummy_StoneBr', -268.0329770956789),
#  ('LowQualFinSF', -262.4489741381048),
#  ('Exterior1stDummy_Stone', 261.29452254481924),
#  ('StreetDummy_Pave', 259.54496316961024),
#  ('Exterior1stDummy_MetalSd', -255.44222305357403),
#  ('MoSold', -253.4723595342481),
#  ('LotShapeDummy_IR2', -248.14734837675292),
#  ('SaleTypeDummy_ConLD', -245.69736480956738),
#  ('HouseStyleDummy_2.5Fin', -228.44261654704457),
#  ('ElectricalDummy_FuseP', 214.24342500155484),
#  ('FoundationDummy_Slab', -202.70082283947184),
#  ('SaleTypeDummy_New', 202.51871776821986),
#  ('LandContourDummy_Low', 201.35307366880096),
#  ('Exterior1stDummy_BrkFace', -186.09021837197238),
#  ('Condition1Dummy_RRAn', -176.57333435086417),
#  ('HouseStyleDummy_SFoyer', 169.33133719892476),
#  ('GarageTypeDummy_Attchd', 167.68267363353286),
#  ('Exterior2ndDummy_AsphShn', 165.66003123470446),
#  ('3SsnPorch', 154.63363337583962),
#  ('LotConfigDummy_Inside', 151.27934714642913),
#  ('SaleTypeDummy_ConLI', -134.4237484122061),
#  ('Exterior2ndDummy_Plywood', -121.01011966631025),
#  ('MiscFeatureDummy_Othr', 115.40042603667307),
#  ('Exterior1stDummy_AsphShn', -111.90204785172281),
#  ('Condition2Dummy_RRNn', -104.76642120589753),
#  ('MSZoningDummy_FV', 100.48930158305839),
#  ('SalePrice', -93.48445801902048),
#  ('NeighborhoodDummy_Sawyer', -86.51934027027696),
#  ('Fence', 79.69795688908908),
#  ('BldgTypeDummy_2fmCon', -73.78430927359055),
#  ('BsmtFinType2', -68.73681159863219),
#  ('ElectricalDummy_FuseF', 56.586341139601394),
#  ('MasVnrTypeDummy_Stone', 56.42922438354848),
#  ('GarageTypeDummy_CarPort', 55.6016019154845),
#  ('GarageTypeDummy_Basment', 48.91315292287434),
#  ('HalfBath', -34.760508313506705),
#  ('LotConfigDummy_FR3', 33.930676357103266),
#  ('HeatingDummy_OthW', -25.690113279131687),
#  ('MSSubClassDummy_85', -22.876019037214128),
#  ('MSSubClassDummy_80', -22.84325383997571),
#  ('Exterior1stDummy_Plywood', -19.260269786671646),
#  ('Exterior2ndDummy_HdBoard', -8.862867388049459),
#  ('MSSubClassDummy_30', -8.407843681981921),
#  ('Condition1Dummy_Norm', 2.892164691844723),
#  ('Exterior2ndDummy_BrkFace', -1.1498494987241195),
#  ('LandSlope', -0.0),
#  ('BsmtFinType1', 0.0),
#  ('BsmtUnfSF', -0.0),
#  ('1stFlrSF', 0.0),
#  ('BsmtHalfBath', -0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('GarageQual', -0.0),
#  ('GarageCond', 0.0),
#  ('PoolQC', 0.0),
#  ('MiscVal', 0.0),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', -0.0),
#  ('MSSubClassDummy_50', 0.0),
#  ('MSSubClassDummy_70', -0.0),
#  ('MSSubClassDummy_75', -0.0),
#  ('MSSubClassDummy_160', -0.0),
#  ('MSZoningDummy_RL', -0.0),
#  ('AlleyDummy_Pave', -0.0),
#  ('NeighborhoodDummy_BrkSide', -0.0),
#  ('NeighborhoodDummy_Gilbert', 0.0),
#  ('NeighborhoodDummy_IDOTRR', -0.0),
#  ('Condition1Dummy_RRNe', -0.0),
#  ('Condition1Dummy_RRNn', -0.0),
#  ('Condition2Dummy_Feedr', -0.0),
#  ('Condition2Dummy_Norm', 0.0),
#  ('Condition2Dummy_PosA', 0.0),
#  ('Condition2Dummy_PosN', 0.0),
#  ('Condition2Dummy_RRAe', -0.0),
#  ('Condition2Dummy_RRAn', -0.0),
#  ('HouseStyleDummy_2Story', -0.0),
#  ('RoofStyleDummy_Gambrel', 0.0),
#  ('RoofStyleDummy_Hip', -0.0),
#  ('RoofStyleDummy_Mansard', 0.0),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('RoofMatlDummy_CompShg', 0.0),
#  ('RoofMatlDummy_Metal', 0.0),
#  ('RoofMatlDummy_Roll', -0.0),
#  ('RoofMatlDummy_WdShngl', -0.0),
#  ('Exterior1stDummy_CBlock', 0.0),
#  ('Exterior1stDummy_CemntBd', -0.0),
#  ('Exterior1stDummy_Stucco', -0.0),
#  ('Exterior1stDummy_WdShing', -0.0),
#  ('Exterior2ndDummy_ImStucc', 0.0),
#  ('Exterior2ndDummy_MetalSd', -0.0),
#  ('Exterior2ndDummy_Stucco', -0.0),
#  ('Exterior2ndDummy_Wd Shng', -0.0),
#  ('MasVnrTypeDummy_BrkFace', 0.0),
#  ('FoundationDummy_Wood', 0.0),
#  ('HeatingDummy_GasA', 0.0),
#  ('HeatingDummy_Grav', 0.0),
#  ('HeatingDummy_Wall', -0.0),
#  ('CentralAirDummy_Y', 0.0),
#  ('ElectricalDummy_Mix', 0.0),
#  ('ElectricalDummy_SBrkr', -0.0),
#  ('GarageTypeDummy_BuiltIn', 0.0),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('MiscFeatureDummy_No_Misc_Feature', 0.0),
#  ('MiscFeatureDummy_Shed', 0.0),
#  ('SaleTypeDummy_ConLw', 0.0),
#  ('SaleTypeDummy_Oth', 0.0)]

# %% [markdown]
# ## Value Counts

# %%
train_org = pd.read_csv('train.csv')

# %%
def getValueCounts(cols, data):
    f, axes = plt.subplots(round(len(cols)/2)+1, 2, figsize=(10,80))
    rowIdx = 0
    colIdx = 0
    for col in cols:
        if colIdx > 1:
            rowIdx = rowIdx + 1
            colIdx = 0
        value_counts = data[col].value_counts()
        ax = sns.barplot(x=value_counts.index, y=value_counts, data=data, ax=axes[rowIdx,colIdx]).set_title(col)
        colIdx += 1
    f.tight_layout()

# %%
cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']
getValueCounts(cat_cols, train_org)
# Out:
# <ipython-input-31-805f6aa5abec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   cat_cols = train_org.columns[train_org.dtypes == 'object'] | train_org.columns[train_org.columns == 'MSSubClass']

# %%
colsToDrop = ['BldgType','BsmtCond','BsmtFinType2','CentralAir','Condition1','Condition2','Electrical',
              'ExterCond','Functional','GarageCond','GarageQual','Heating','LandContour','LandSlope',
              'MiscFeature','PavedDrive','RoofMatl','Street','Utilities','SaleType']

# %%
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %% [markdown]
# ## Random Forest on Subset

# %%
model = RandomForestRegressor()
params = {'n_estimators':[100], 'max_features':['auto', 'sqrt']}
gridRf = GridSearchCV(model, param_grid=params, cv=5)
gridRf.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100]})

# %%
gridRf.best_score_
# Out:
# 0.8716853343623623

# %% [markdown]
# ## Ridge on Subset

# %%
model = Ridge()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridRidge = GridSearchCV(model, param_grid=params, cv=5)
gridRidge.fit(X_Scaled, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridRidge.best_score_
# Out:
# 0.8964122614422919

# %% [markdown]
# ## Lasso on Subset

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 169802071721.02615, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168120386396.64944, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162390483102.64355, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180296210785.04132, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152023487454.6613, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107013581526.42798, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123227359689.98698, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112308196665.61462, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134513206916.4154, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93782380916.00983, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11641018624.778198, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8978476282010259

# %% [markdown]
# ## Correlation between variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = X.corr()

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
# Out:
# Top Absolute Correlations

# %%
mostCorrelatedFeat.head(50)
# Out:
# Exterior1stDummy_CBlock   Exterior2ndDummy_CBlock      1.000000
# Exterior1stDummy_CemntBd  Exterior2ndDummy_CmentBd     0.999652
# Exterior1stDummy_VinylSd  Exterior2ndDummy_VinylSd     0.999213
# Exterior1stDummy_MetalSd  Exterior2ndDummy_MetalSd     0.998852
# PoolArea                  PoolQC                       0.997972
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996980
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996286
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.990017
# GarageCars                GarageArea                   0.989631
# Exterior1stDummy_Wd Sdng  Exterior2ndDummy_Wd Sdng     0.986715
# Exterior1stDummy_HdBoard  Exterior2ndDummy_HdBoard     0.984287
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.982538
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.978051
# GrLivArea                 TotRmsAbvGrd                 0.967165
# Exterior1stDummy_Stucco   Exterior2ndDummy_Stucco      0.959567
# ExterQual                 KitchenQual                  0.958804
# TotalBsmtSF               1stFlrSF                     0.958147
# OverallQual               ExterQual                    0.956260
# BsmtQual                  FoundationDummy_PConc        0.955467
# ExterQual                 BsmtQual                     0.954119
# 2ndFlrSF                  HouseStyleDummy_2Story       0.948082
# YearRemodAdd              BsmtQual                     0.944259
#                           FoundationDummy_PConc        0.940796
# OverallQual               BsmtQual                     0.939683
# ExterQual                 FoundationDummy_PConc        0.939628
# OverallQual               GarageCars                   0.937009
# MasVnrArea                MasVnrTypeDummy_None         0.936945
# OverallQual               KitchenQual                  0.936144
# YearRemodAdd              ExterQual                    0.931251
# HalfBath                  HouseStyleDummy_2Story       0.930991
# FoundationDummy_CBlock    FoundationDummy_PConc        0.930212
# OverallQual               FullBath                     0.928534
# YearBuilt                 BsmtQual                     0.925457
# KitchenAbvGr              MSSubClassDummy_90           0.921891
# YearBuilt                 YearRemodAdd                 0.921460
# Exterior1stDummy_Plywood  Exterior2ndDummy_Plywood     0.920538
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.918311
# BsmtQual                  KitchenQual                  0.916891
# OverallQual               GarageArea                   0.914950
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.914512
# Exterior2ndDummy_VinylSd  FoundationDummy_PConc        0.914201
# OverallQual               YearRemodAdd                 0.913851
# BsmtFinSF1                BsmtFullBath                 0.909598
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.909232
# OverallQual               FoundationDummy_PConc        0.907281
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.906789
# HalfBath                  MSSubClassDummy_60           0.904375
# YearRemodAdd              KitchenQual                  0.902911
# FullBath                  GarageCars                   0.902890
# 2ndFlrSF                  HalfBath                     0.898550
# dtype: float64

# %%
colsToDrop = ['Exterior2nd']
for col in colsToDrop:
    train = train[train.columns.drop(list(train.filter(regex=col)))]

# %%
X = train.loc[:, train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor

# %%
constant = np.ones((X.shape[0], 1))
X['constant'] = constant

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1685: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 2.887572279697948),
#  ('LotArea', 2.085376511164549),
#  ('OverallQual', 4.562623914712346),
#  ('OverallCond', 2.086814278562759),
#  ('YearBuilt', 15.995067621484223),
#  ('YearRemodAdd', 3.1557033578235245),
#  ('MasVnrArea', 2.6636371540844266),
#  ('ExterQual', 3.029371336576255),
#  ('BsmtQual', 2.9583105621127426),
#  ('BsmtExposure', 1.8082241089403868),
#  ('BsmtFinType1', 2.1895064921369665),
#  ('BsmtFinSF1', inf),
#  ('BsmtFinSF2', inf),
#  ('BsmtUnfSF', inf),
#  ('TotalBsmtSF', inf),
#  ('1stFlrSF', inf),
#  ('2ndFlrSF', inf),
#  ('LowQualFinSF', inf),
#  ('GrLivArea', inf),
#  ('BsmtFullBath', 2.4355709728793773),
#  ('BsmtHalfBath', 1.2607130907798734),
#  ('FullBath', 3.963350705678212),
#  ('HalfBath', 3.008374120856214),
#  ('BedroomAbvGr', 3.217724924321069),
#  ('KitchenAbvGr', 5.615247270804096),
#  ('KitchenQual', 2.183336176389214),
#  ('TotRmsAbvGrd', 5.61598011311989),
#  ('Fireplaces', 1.8667221330968675),
#  ('FireplaceQu', 1.407854388166587),
#  ('GarageYrBlt', 1333.748009631755),
#  ('GarageFinish', 2.1251544682265355),
#  ('GarageCars', 6.653738241436786),
#  ('GarageArea', 6.603059673805705),
#  ('WoodDeckSF', 1.4058077028567546),
#  ('OpenPorchSF', 1.4496701655246527),
#  ('EnclosedPorch', 1.4970460763143991),
#  ('3SsnPorch', 1.111073572989825),
#  ('ScreenPorch', 1.1933844417167823),
#  ('PoolArea', 16.074815908219097),
#  ('PoolQC', 16.02030352504007),
#  ('Fence', 1.3478162925264556),
#  ('MiscVal', 1.0634027249388134),
#  ('MoSold', 1.1429252777973422),
#  ('YrSold', 1.196290100184492),
#  ('MSSubClassDummy_30', 2.5590025467223954),
#  ('MSSubClassDummy_40', 1.1348029041600738),
#  ('MSSubClassDummy_45', 16.582123419101),
#  ('MSSubClassDummy_50', 21.03332233117241),
#  ('MSSubClassDummy_60', 33.495125496701604),
#  ('MSSubClassDummy_70', 7.903622041903289),
#  ('MSSubClassDummy_75', 12.311620176969743),
#  ('MSSubClassDummy_80', 14.430259850080935),
#  ('MSSubClassDummy_85', 4.568796787060055),
#  ('MSSubClassDummy_90', 5.199084187739217),
#  ('RoofStyleDummy_Shed', nan),
#  ('Exterior1stDummy_AsphShn', 1.263191448128718),
#  ('Exterior1stDummy_BrkComm', 1.1366989875131608),
#  ('Exterior1stDummy_BrkFace', 4.651749763563609),
#  ('Exterior1stDummy_CBlock', 1.2235314876474752),
#  ('Exterior1stDummy_CemntBd', 5.4611955429036705),
#  ('Exterior1stDummy_HdBoard', 17.849844181383894),
#  ('Exterior1stDummy_ImStucc', 1.1970129169645662),
#  ('Exterior1stDummy_MetalSd', 16.21791079206699),
#  ('Exterior1stDummy_Plywood', 9.220390557185953),
#  ('Exterior1stDummy_Stone', 1.3965471007579222),
#  ('Exterior1stDummy_Stucco', 2.3601815434843227),
#  ('Exterior1stDummy_VinylSd', 30.016686227929057),
#  ('Exterior1stDummy_Wd Sdng', 14.993679628459052),
#  ('Exterior1stDummy_WdShing', 3.0646359142543727),
#  ('MasVnrTypeDummy_BrkFace', 25.575613102625425),
#  ('MasVnrTypeDummy_No_MasVnr', 1.8233563564795243),
#  ('MasVnrTypeDummy_None', 28.937342592603176),
#  ('MasVnrTypeDummy_Stone', 9.742996255731056),
#  ('FoundationDummy_CBlock', 7.055776600443058),
#  ('FoundationDummy_PConc', 8.334415862587882),
#  ('FoundationDummy_Slab', 1.8899749878725582),
#  ('FoundationDummy_Stone', 1.2042129450863104),
#  ('FoundationDummy_Wood', 1.2626503875381976),
#  ('GarageTypeDummy_Attchd', 94.21729242913966),
#  ('GarageTypeDummy_Basment', 6.306401760252171),
#  ('GarageTypeDummy_BuiltIn', 22.923616407142976),
#  ('GarageTypeDummy_CarPort', 3.024763046844204),
#  ('GarageTypeDummy_Detchd', 77.18211305682057),
#  ('GarageTypeDummy_No_Garage', 1297.0296232776316),
#  ('SaleConditionDummy_AdjLand', 1.0731600756363924),
#  ('SaleConditionDummy_Alloca', 1.3291164926842727),
#  ('SaleConditionDummy_Family', 1.2967176575424963),
#  ('SaleConditionDummy_Normal', 2.6140620015553755),
#  ('SaleConditionDummy_Partial', 2.731034064075325),
#  ('constant', 132457.67158712904)]

# %%
X[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0            706           0        150          856
# 1            978           0        284         1262
# 2            486           0        434          920
# 3            216           0        540          756
# 4            655           0        490         1145
# ...          ...         ...        ...          ...
# 1454         410           0        811         1221
# 1455           0           0        953          953
# 1456         790         163        589         1542
# 1458          49        1029          0         1078
# 1459         830         290        136         1256
#
# [1314 rows x 4 columns]

# %%
X[['GrLivArea','1stFlrSF','2ndFlrSF','LowQualFinSF']]
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0          1710       856       854             0
# 1          1262      1262         0             0
# 2          1786       920       866             0
# 3          1717       961       756             0
# 4          2198      1145      1053             0
# ...         ...       ...       ...           ...
# 1454       1221      1221         0             0
# 1455       1647       953       694             0
# 1456       2073      2073         0             0
# 1458       1078      1078         0             0
# 1459       1256      1256         0             0
#
# [1314 rows x 4 columns]

# %%
train = train.drop(['GrLivArea','TotalBsmtSF','OverallQual'], axis=1)

# %%
X = train.loc[:,train.columns != 'SalePrice']

# %% [markdown]
# ### Variance Inflation Factor on Subset

# %%
vifs = zip(X.columns, [variance_inflation_factor(X.values, i) for i in range(len(X.columns))])
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss

# %%
list(vifs)
# Out:
# [('LotFrontage', 31.26481080803063),
#  ('LotArea', 8.217648981835815),
#  ('OverallCond', 40.27055046754404),
#  ('YearBuilt', 51835.580394188335),
#  ('YearRemodAdd', 28024.474793659905),
#  ('MasVnrArea', 3.5458379813920238),
#  ('ExterQual', 59.04964572911572),
#  ('BsmtQual', 17.300071069726634),
#  ('BsmtExposure', 9.146786052551782),
#  ('BsmtFinType1', 6.256660065647357),
#  ('BsmtFinSF1', 18.633915341437802),
#  ('BsmtFinSF2', 2.228641710192634),
#  ('BsmtUnfSF', 22.4751561674805),
#  ('1stFlrSF', 103.65524658339483),
#  ('2ndFlrSF', 27.84018221453224),
#  ('LowQualFinSF', 2.057920881200661),
#  ('BsmtFullBath', 4.107976697047283),
#  ('BsmtHalfBath', 1.3302033323699896),
#  ('FullBath', 36.90666233106686),
#  ('HalfBath', 4.732536442394737),
#  ('BedroomAbvGr', 50.4365735531274),
#  ('KitchenAbvGr', 218.9897593089205),
#  ('KitchenQual', 24.60666681409289),
#  ('TotRmsAbvGrd', 55.80134548183749),
#  ('Fireplaces', 3.513309330723154),
#  ('FireplaceQu', 11.460875582254387),
#  ('GarageYrBlt', 33442.7756136124),
#  ('GarageFinish', 7.585130042566672),
#  ('GarageCars', 49.88455838896353),
#  ('GarageArea', 44.74567949680541),
#  ('WoodDeckSF', 2.2363051117206876),
#  ('OpenPorchSF', 2.226571395390711),
#  ('EnclosedPorch', 1.6516297588071762),
#  ('3SsnPorch', 1.125380120813912),
#  ('ScreenPorch', 1.2738476218407964),
#  ('PoolArea', 11.774326529640597),
#  ('PoolQC', 26831.44287503572),
#  ('Fence', 15.599122821813582),
#  ('MiscVal', 1.065697067694576),
#  ('MoSold', 5.607276922286955),
#  ('YrSold', 3.4033179542097898),
#  ('MSSubClassDummy_30', 2.4780416195430433),
#  ('MSSubClassDummy_40', 1.1315294540088248),
#  ('MSSubClassDummy_45', 16.58427169402299),
#  ('MSSubClassDummy_50', 22.518613355417155),
#  ('MSSubClassDummy_60', 42.28115922494903),
#  ('MSSubClassDummy_70', 7.9985814740904635),
#  ('MSSubClassDummy_75', 12.325981148917933),
#  ('MSSubClassDummy_80', 15.07115179586085),
#  ('MSSubClassDummy_85', 4.602574168162925),
#  ('MSSubClassDummy_90', 5.309820212434596),
#  ('MSSubClassDummy_120', 2.9274042847486266),
#  ('MSSubClassDummy_160', 12.5378000118004),
#  ('MSSubClassDummy_180', 2.6848110213372065),
#  ('MSSubClassDummy_190', 2.3336171975212125),
#  ('MSZoningDummy_FV', 28.66989443961698),
#  ('MSZoningDummy_RH', 5.0449131312773945),
#  ('MSZoningDummy_RL', 384.97703095510457),
#  ('MSZoningDummy_RM', 61.26915936969114),
#  ('AlleyDummy_No_Alley_Access', 51.192943499489274),
#  ('Exterior1stDummy_MetalSd', 19.0675913241896),
#  ('Exterior1stDummy_Plywood', 9.847562406358652),
#  ('Exterior1stDummy_Stone', 1.3977543049982293),
#  ('Exterior1stDummy_Stucco', 2.3648232344622104),
#  ('Exterior1stDummy_VinylSd', 47.72102719651395),
#  ('Exterior1stDummy_Wd Sdng', 17.246746498344738),
#  ('Exterior1stDummy_WdShing', 3.09119247177898),
#  ('MasVnrTypeDummy_BrkFace', 37.51514813490878),
#  ('MasVnrTypeDummy_No_MasVnr', 1.8323280608549712),
#  ('MasVnrTypeDummy_None', 69.47138866865566),
#  ('MasVnrTypeDummy_Stone', 10.544741051443468),
#  ('FoundationDummy_CBlock', 12.422244298286884),
#  ('FoundationDummy_PConc', 14.645506299807497),
#  ('FoundationDummy_Slab', 1.9047055872624183),
#  ('FoundationDummy_Stone', 1.2037795986664077),
#  ('FoundationDummy_Wood', 1.248281331876767),
#  ('GarageTypeDummy_Attchd', 252.54533327071806),
#  ('GarageTypeDummy_Basment', 6.374069631022496),
#  ('GarageTypeDummy_BuiltIn', 24.288301782484098),
#  ('GarageTypeDummy_CarPort', 3.028121527857856),
#  ('GarageTypeDummy_Detchd', 104.25431359760594),
#  ('GarageTypeDummy_No_Garage', 1235.9337518417929),
#  ('SaleConditionDummy_AdjLand', 1.0731787565862934),
#  ('SaleConditionDummy_Alloca', 1.3326719407052188),
#  ('SaleConditionDummy_Family', 1.312255275992025),
#  ('SaleConditionDummy_Normal', 16.506985155505927),
#  ('SaleConditionDummy_Partial', 2.9309244689272833)]

# %% [markdown]
# ### Correlation Matrix on Subset

# %%
corr = X.corr()

# %%
mostCorrelatedFeat = get_top_abs_correlations(corr, 1000)
mostCorrelatedFeat.head(50)
# Out:
# PoolArea                  PoolQC                       0.998107
# MSSubClassDummy_45        HouseStyleDummy_1.5Unf       0.996978
# GarageYrBlt               GarageTypeDummy_No_Garage    0.996550
# MSSubClassDummy_80        HouseStyleDummy_SLvl         0.990122
# GarageCars                GarageArea                   0.988878
# RoofStyleDummy_Gable      RoofStyleDummy_Hip           0.983482
# MSZoningDummy_FV          NeighborhoodDummy_Somerst    0.979261
# ExterQual                 KitchenQual                  0.953862
# BsmtQual                  FoundationDummy_PConc        0.952420
# ExterQual                 BsmtQual                     0.950191
# 2ndFlrSF                  HouseStyleDummy_2Story       0.947497
# YearRemodAdd              BsmtQual                     0.937781
# ExterQual                 FoundationDummy_PConc        0.934737
# YearRemodAdd              FoundationDummy_PConc        0.934705
# MasVnrArea                MasVnrTypeDummy_None         0.933727
# HalfBath                  HouseStyleDummy_2Story       0.928178
# Exterior1stDummy_VinylSd  FoundationDummy_PConc        0.927207
# YearRemodAdd              ExterQual                    0.926950
# FoundationDummy_CBlock    FoundationDummy_PConc        0.926511
# KitchenAbvGr              MSSubClassDummy_90           0.923173
# YearBuilt                 BsmtQual                     0.921321
# MSSubClassDummy_85        HouseStyleDummy_SFoyer       0.920578
# YearBuilt                 YearRemodAdd                 0.915840
# BsmtFinSF1                BsmtFullBath                 0.909459
# BsmtQual                  KitchenQual                  0.908208
# MasVnrTypeDummy_BrkFace   MasVnrTypeDummy_None         0.905123
# GarageTypeDummy_Attchd    GarageTypeDummy_Detchd       0.902970
# YearRemodAdd              Exterior1stDummy_VinylSd     0.902388
# HalfBath                  MSSubClassDummy_60           0.901536
# 2ndFlrSF                  HalfBath                     0.896573
# YearRemodAdd              KitchenQual                  0.896314
# BsmtQual                  Exterior1stDummy_VinylSd     0.894009
# YearBuilt                 ExterQual                    0.893816
# FullBath                  GarageCars                   0.890997
# BsmtQual                  FullBath                     0.889623
# YearBuilt                 FoundationDummy_PConc        0.889115
# KitchenQual               FoundationDummy_PConc        0.888100
# MSSubClassDummy_60        HouseStyleDummy_2Story       0.887894
# MSZoningDummy_RL          MSZoningDummy_RM             0.878766
# ExterQual                 Exterior1stDummy_VinylSd     0.877286
# BsmtQual                  GarageCars                   0.874709
# ExterQual                 GarageCars                   0.873761
# MasVnrArea                MasVnrTypeDummy_BrkFace      0.872946
# 2ndFlrSF                  HouseStyleDummy_1Story       0.872590
# YearBuilt                 GarageCars                   0.871185
# ExterQual                 FullBath                     0.870692
# FullBath                  FoundationDummy_PConc        0.868743
# YearBuilt                 Exterior1stDummy_VinylSd     0.863009
# YearRemodAdd              FullBath                     0.859648
# MSSubClassDummy_75        HouseStyleDummy_2.5Fin       0.859291
# dtype: float64

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172229653422.19785, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181848489728.26373, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180076116177.27545, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196808674267.36514, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152438186504.7465, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42099603795.73514, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132345663806.40036, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129343455338.11823, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129074249983.34756, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39978315806.21921, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1081561062.2944946, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1203127978.1505737, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 1370.0388437207055),
#  ('LotArea', 4319.819672510028),
#  ('OverallCond', 7426.797614280191),
#  ('YearBuilt', 12329.968244138368),
#  ('YearRemodAdd', 545.9522298845611),
#  ('MasVnrArea', 3918.675906567801),
#  ('ExterQual', -3309.549333957685),
#  ('BsmtQual', -3938.008451914478),
#  ('BsmtExposure', -2800.191122093439),
#  ('BsmtFinType1', 65.78244473085005),
#  ('BsmtFinSF1', 15736.048019331922),
#  ('BsmtFinSF2', 3900.0379949215358),
#  ('BsmtUnfSF', 8907.795286441044),
#  ('1stFlrSF', 18459.51707388857),
#  ('2ndFlrSF', 28396.324838083518),
#  ('LowQualFinSF', 1755.7872625038663),
#  ('BsmtFullBath', 1619.6347396575811),
#  ('BsmtHalfBath', -106.1138259601547),
#  ('FullBath', 591.8146414616982),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -2834.0766927671357),
#  ('KitchenAbvGr', -3650.3801911828014),
#  ('KitchenQual', -5042.351829351232),
#  ('TotRmsAbvGrd', 653.0818994718171),
#  ('Fireplaces', 2490.96723198846),
#  ('FireplaceQu', -1154.508108215936),
#  ('GarageYrBlt', -711.8141458323267),
#  ('GarageFinish', -1406.3695105976662),
#  ('GarageCars', 4018.5603430700776),
#  ('GarageArea', 2169.106411302171),
#  ('WoodDeckSF', 2075.912555055849),
#  ('OpenPorchSF', 1070.8044578180195),
#  ('EnclosedPorch', 465.80315584655995),
#  ('3SsnPorch', 239.8133601773675),
#  ('ScreenPorch', 1044.8303427853562),
#  ('PoolArea', 777.8646407707025),
#  ('PoolQC', 0.0),
#  ('Fence', 316.20607579153085),
#  ('MiscVal', 275.1613979191557),
#  ('MoSold', 79.34289347570288),
#  ('YrSold', -672.4725229663261),
#  ('MSSubClassDummy_30', -334.2438177360355),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', 224.6923256737489),
#  ('MSSubClassDummy_50', -55.37074075806616),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', 1584.1590344096282),
#  ('MSSubClassDummy_75', 597.7458128961171),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -296.522565343612),
#  ('MSSubClassDummy_90', -0.0),
#  ('MSSubClassDummy_120', -3790.655039251527),
#  ('MSSubClassDummy_160', -5254.210281620733),
#  ('MSSubClassDummy_180', -857.137779473366),
#  ('MSSubClassDummy_190', -281.1553196564518),
#  ('MSZoningDummy_FV', 3137.9955313694263),
#  ('MSZoningDummy_RH', 525.2611912605688),
#  ('MSZoningDummy_RL', 1870.6019029500437),
#  ('MSZoningDummy_RM', -0.0),
#  ('AlleyDummy_No_Alley_Access', 78.08352545767693),
#  ('AlleyDummy_Pave', 0.0),
#  ('LotShapeDummy_IR2', 0.0),
#  ('LotShapeDummy_IR3', -216.10636478193982),
#  ('LotShapeDummy_Reg', 677.0850055858912),
#  ('LotConfigDummy_CulDSac', 1938.9765621770987),
#  ('LotConfigDummy_FR2', -908.4578884718296),
#  ('LotConfigDummy_FR3', -451.62265044313455),
#  ('LotConfigDummy_Inside', -0.0),
#  ('NeighborhoodDummy_Blueste', 478.9166828370421),
#  ('NeighborhoodDummy_BrDale', 2690.9457495225615),
#  ('NeighborhoodDummy_BrkSide', 1463.918541636664),
#  ('NeighborhoodDummy_ClearCr', 0.0),
#  ('NeighborhoodDummy_CollgCr', -315.47726024086546),
#  ('NeighborhoodDummy_Crawfor', 3114.030386277612),
#  ('NeighborhoodDummy_Edwards', -1664.6850792072435),
#  ('NeighborhoodDummy_Gilbert', -818.4530375898253),
#  ('NeighborhoodDummy_IDOTRR', 345.0875803232576),
#  ('NeighborhoodDummy_MeadowV', -67.01727787496748),
#  ('NeighborhoodDummy_Mitchel', -1267.2919111392143),
#  ('NeighborhoodDummy_NAmes', -958.4732729774961),
#  ('NeighborhoodDummy_NPkVill', 2014.4617003115377),
#  ('NeighborhoodDummy_NWAmes', -1143.8383162174114),
#  ('NeighborhoodDummy_NoRidge', 4577.7368926703175),
#  ('NeighborhoodDummy_NridgHt', 5681.209521135147),
#  ('NeighborhoodDummy_OldTown', -499.1292335076819),
#  ('NeighborhoodDummy_SWISU', -684.231367442224),
#  ('NeighborhoodDummy_Sawyer', -68.96531730910877),
#  ('NeighborhoodDummy_SawyerW', -114.07313491021208),
#  ('NeighborhoodDummy_Somerst', 1399.5266118431696),
#  ('NeighborhoodDummy_StoneBr', 4602.076794829663),
#  ('NeighborhoodDummy_Timber', 19.51452050538591),
#  ('NeighborhoodDummy_Veenker', 701.1150564403782),
#  ('HouseStyleDummy_1.5Unf', 929.1045955633529),
#  ('HouseStyleDummy_1Story', 1958.5119170322423),
#  ('HouseStyleDummy_2.5Fin', -2042.190457124907),
#  ('HouseStyleDummy_2.5Unf', -191.9000411988113),
#  ('HouseStyleDummy_2Story', -2768.147129688312),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('HouseStyleDummy_SLvl', 302.030040277579),
#  ('RoofStyleDummy_Gable', -1137.232287053004),
#  ('RoofStyleDummy_Gambrel', 128.29566526130336),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', -552.7423246020819),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('Exterior1stDummy_AsphShn', 336.6213976919714),
#  ('Exterior1stDummy_BrkComm', -704.5722520106349),
#  ('Exterior1stDummy_BrkFace', 3114.4746777056757),
#  ('Exterior1stDummy_CBlock', -762.8097557977696),
#  ('Exterior1stDummy_CemntBd', 494.7737457992427),
#  ('Exterior1stDummy_HdBoard', -949.6573342014568),
#  ('Exterior1stDummy_ImStucc', -246.31178172890213),
#  ('Exterior1stDummy_MetalSd', 735.0293521739704),
#  ('Exterior1stDummy_Plywood', -1098.5925167738255),
#  ('Exterior1stDummy_Stone', -148.4542916103141),
#  ('Exterior1stDummy_Stucco', 973.5276108519387),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', -0.0),
#  ('Exterior1stDummy_WdShing', 288.49925552413396),
#  ('MasVnrTypeDummy_BrkFace', 855.6731619836817),
#  ('MasVnrTypeDummy_No_MasVnr', -0.0),
#  ('MasVnrTypeDummy_None', 1804.8587902304616),
#  ('MasVnrTypeDummy_Stone', 1935.1346963663525),
#  ('FoundationDummy_CBlock', -843.0395945628239),
#  ('FoundationDummy_PConc', 1833.4186615581505),
#  ('FoundationDummy_Slab', 1119.9789214910738),
#  ('FoundationDummy_Stone', -294.5949548380681),
#  ('FoundationDummy_Wood', -1092.4173056631369),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 619.3713339082095),
#  ('GarageTypeDummy_BuiltIn', 71.96187825550628),
#  ('GarageTypeDummy_CarPort', -1056.9945818274612),
#  ('GarageTypeDummy_Detchd', 0.0),
#  ('GarageTypeDummy_No_Garage', 0.0),
#  ('SaleConditionDummy_AdjLand', 687.1346774053968),
#  ('SaleConditionDummy_Alloca', 389.89230213089604),
#  ('SaleConditionDummy_Family', 1009.2597017433341),
#  ('SaleConditionDummy_Normal', 2613.818553354062),
#  ('SaleConditionDummy_Partial', 4963.036212534209)]

# %%
train = train.drop(['GarageArea','PoolArea','PoolQC'],axis=1)

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(train.loc[:, train.columns != 'SalePrice'])
X_Scaled = pd.DataFrame(X_Scaled, columns = train.columns[train.columns != 'SalePrice'])
y = train['SalePrice']

# %%
model = Lasso()
params = {'alpha':[0.1,1,10,50,75,100,1000,2000],'max_iter':[1000]}
gridLasso = GridSearchCV(model, param_grid=params, cv=5)
gridLasso.fit(X_Scaled, y)
# Out:
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175609203397.77094, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177448290316.35297, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149474097985.00494, tolerance: 486776417.35761964
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192998347671.17603, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145960797674.15442, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33881030481.68347, tolerance: 491220796.1427745
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107148865838.39294, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117516963145.42995, tolerance: 498360214.9752293
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1530290069.7886963, tolerance: 463886015.13225275
#   model = cd_fast.enet_coordinate_descent(
# /Users/baileyrusso/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7021054269.228821, tolerance: 455979649.5767756
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 75, 100, 1000, 2000],
#                          'max_iter': [1000]})

# %%
gridLasso.best_score_
# Out:
# 0.8899803863547978

# %%
list(zip(X_Scaled.columns,gridLasso.best_estimator_.coef_))
# Out:
# [('LotFrontage', 1415.2766033143243),
#  ('LotArea', 4372.348633453678),
#  ('OverallCond', 7472.1518866030965),
#  ('YearBuilt', 12421.078549128479),
#  ('YearRemodAdd', 516.9755312061511),
#  ('MasVnrArea', 3916.9007197473434),
#  ('ExterQual', -3306.361852859575),
#  ('BsmtQual', -3845.004385158637),
#  ('BsmtExposure', -2805.477963508711),
#  ('BsmtFinType1', 67.2250311984724),
#  ('BsmtFinSF1', 15730.765164606462),
#  ('BsmtFinSF2', 3924.4691878583762),
#  ('BsmtUnfSF', 8885.612632799368),
#  ('1stFlrSF', 18852.56391662216),
#  ('2ndFlrSF', 28736.540308085838),
#  ('LowQualFinSF', 1799.2733146225328),
#  ('BsmtFullBath', 1716.6825956076934),
#  ('BsmtHalfBath', -123.35934409480298),
#  ('FullBath', 482.71422329837173),
#  ('HalfBath', -0.0),
#  ('BedroomAbvGr', -2888.650611024073),
#  ('KitchenAbvGr', -3559.4497883049494),
#  ('KitchenQual', -5060.716122722208),
#  ('TotRmsAbvGrd', 421.33784096326275),
#  ('Fireplaces', 2461.0801204305603),
#  ('FireplaceQu', -1178.528457181482),
#  ('GarageYrBlt', -0.0),
#  ('GarageFinish', -1433.2575846460911),
#  ('GarageCars', 5621.112760506498),
#  ('WoodDeckSF', 2104.4846729453393),
#  ('OpenPorchSF', 1069.914093121),
#  ('EnclosedPorch', 503.14477634624666),
#  ('3SsnPorch', 240.23654931727532),
#  ('ScreenPorch', 1039.4876686457453),
#  ('Fence', 212.5279117994957),
#  ('MiscVal', 284.42990588125593),
#  ('MoSold', 25.62365752908973),
#  ('YrSold', -708.914503209831),
#  ('MSSubClassDummy_30', -316.9924441947996),
#  ('MSSubClassDummy_40', 0.0),
#  ('MSSubClassDummy_45', 379.07268524251623),
#  ('MSSubClassDummy_50', -20.645181963253894),
#  ('MSSubClassDummy_60', 0.0),
#  ('MSSubClassDummy_70', 1563.1181533659762),
#  ('MSSubClassDummy_75', 450.7865620420752),
#  ('MSSubClassDummy_80', -0.0),
#  ('MSSubClassDummy_85', -280.1000279876037),
#  ('MSSubClassDummy_90', -0.0),
#  ('MSSubClassDummy_120', -3980.56832723723),
#  ('MSSubClassDummy_160', -5420.045134237722),
#  ('MSSubClassDummy_180', -878.9022222470614),
#  ('MSSubClassDummy_190', -278.6494783168325),
#  ('MSZoningDummy_FV', 3228.9587306076196),
#  ('MSZoningDummy_RH', 616.2543555317343),
#  ('MSZoningDummy_RL', 2034.2206671648535),
#  ('MSZoningDummy_RM', -0.0),
#  ('AlleyDummy_No_Alley_Access', 138.20475514502306),
#  ('AlleyDummy_Pave', -0.0),
#  ('LotShapeDummy_IR2', -0.0),
#  ('LotShapeDummy_IR3', -208.7868138100259),
#  ('LotShapeDummy_Reg', 715.0918735231757),
#  ('LotConfigDummy_CulDSac', 1888.852324074385),
#  ('LotConfigDummy_FR2', -954.6029936260145),
#  ('LotConfigDummy_FR3', -479.48528006019035),
#  ('LotConfigDummy_Inside', 0.0),
#  ('NeighborhoodDummy_Blueste', 490.99231374556103),
#  ('NeighborhoodDummy_BrDale', 2796.4879538585465),
#  ('NeighborhoodDummy_BrkSide', 1486.5198837477742),
#  ('NeighborhoodDummy_ClearCr', 0.0),
#  ('NeighborhoodDummy_CollgCr', -178.0432365105739),
#  ('NeighborhoodDummy_Crawfor', 3025.234832006401),
#  ('NeighborhoodDummy_Edwards', -1675.716416313666),
#  ('NeighborhoodDummy_Gilbert', -985.1666831592364),
#  ('NeighborhoodDummy_IDOTRR', 462.9348432640624),
#  ('NeighborhoodDummy_MeadowV', -0.0),
#  ('NeighborhoodDummy_Mitchel', -1190.0354784522422),
#  ('NeighborhoodDummy_NAmes', -933.2265481736222),
#  ('NeighborhoodDummy_NPkVill', 2032.348382105985),
#  ('NeighborhoodDummy_NWAmes', -1077.5240118550278),
#  ('NeighborhoodDummy_NoRidge', 4618.697115260921),
#  ('NeighborhoodDummy_NridgHt', 5907.016407260252),
#  ('NeighborhoodDummy_OldTown', -385.36357442405694),
#  ('NeighborhoodDummy_SWISU', -706.272018062848),
#  ('NeighborhoodDummy_Sawyer', -111.90838687037414),
#  ('NeighborhoodDummy_SawyerW', -142.35751177697585),
#  ('NeighborhoodDummy_Somerst', 1623.069569765362),
#  ('NeighborhoodDummy_StoneBr', 4635.110493526005),
#  ('NeighborhoodDummy_Timber', 38.752511889600996),
#  ('NeighborhoodDummy_Veenker', 687.2593279919199),
#  ('HouseStyleDummy_1.5Unf', 748.327315569719),
#  ('HouseStyleDummy_1Story', 2036.3965214585717),
#  ('HouseStyleDummy_2.5Fin', -1879.3730093738236),
#  ('HouseStyleDummy_2.5Unf', -121.92016721449028),
#  ('HouseStyleDummy_2Story', -2700.0787396392266),
#  ('HouseStyleDummy_SFoyer', -0.0),
#  ('HouseStyleDummy_SLvl', 432.639889028825),
#  ('RoofStyleDummy_Gable', -1149.2515289395822),
#  ('RoofStyleDummy_Gambrel', 84.45073919319178),
#  ('RoofStyleDummy_Hip', 0.0),
#  ('RoofStyleDummy_Mansard', -567.3820890455663),
#  ('RoofStyleDummy_Shed', 0.0),
#  ('Exterior1stDummy_AsphShn', 327.11584012041146),
#  ('Exterior1stDummy_BrkComm', -685.892743910396),
#  ('Exterior1stDummy_BrkFace', 3062.9601314041925),
#  ('Exterior1stDummy_CBlock', -771.2549739391214),
#  ('Exterior1stDummy_CemntBd', 544.7163534030971),
#  ('Exterior1stDummy_HdBoard', -913.9305993718148),
#  ('Exterior1stDummy_ImStucc', -277.1716231279888),
#  ('Exterior1stDummy_MetalSd', 745.6538957031082),
#  ('Exterior1stDummy_Plywood', -1022.9154756098744),
#  ('Exterior1stDummy_Stone', -165.17639218564088),
#  ('Exterior1stDummy_Stucco', 988.1254827472707),
#  ('Exterior1stDummy_VinylSd', -0.0),
#  ('Exterior1stDummy_Wd Sdng', -31.904487110488418),
#  ('Exterior1stDummy_WdShing', 273.25049047440353),
#  ('MasVnrTypeDummy_BrkFace', 909.9723605840304),
#  ('MasVnrTypeDummy_No_MasVnr', -0.0),
#  ('MasVnrTypeDummy_None', 1919.5483728113954),
#  ('MasVnrTypeDummy_Stone', 1971.529506870104),
#  ('FoundationDummy_CBlock', -900.9848203929611),
#  ('FoundationDummy_PConc', 1820.2231293712794),
#  ('FoundationDummy_Slab', 1087.7689117700945),
#  ('FoundationDummy_Stone', -290.9454327658827),
#  ('FoundationDummy_Wood', -1094.3909217988519),
#  ('GarageTypeDummy_Attchd', -0.0),
#  ('GarageTypeDummy_Basment', 642.6397091378147),
#  ('GarageTypeDummy_BuiltIn', 28.195104357566425),
#  ('GarageTypeDummy_CarPort', -1035.540665023912),
#  ('GarageTypeDummy_Detchd', 48.79758899051796),
#  ('GarageTypeDummy_No_Garage', 506.63337912876335),
#  ('SaleConditionDummy_AdjLand', 672.8908361145336),
#  ('SaleConditionDummy_Alloca', 356.12512785969056),
#  ('SaleConditionDummy_Family', 1008.7576106940786),
#  ('SaleConditionDummy_Normal', 2653.4932035403313),
#  ('SaleConditionDummy_Partial', 5039.01655561769)]

# %%
stats.summary(gridLasso.best_estimator_, X_Scaled, y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-66-fb2b742594f3> in <module>
# ----> 1 stats.summary(gridLasso.best_estimator_, X_Scaled, y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in summary(clf, X, y, xlabels)
#     252     coef_df['Estimate'] = np.concatenate(
#     253         (np.round(np.array([clf.intercept_]), 6), np.round((clf.coef_), 6)))
# --> 254     coef_df['Std. Error'] = np.round(coef_se(clf, X, y), 6)
#     255     coef_df['t value'] = np.round(coef_tval(clf, X, y), 4)
#     256     coef_df['p value'] = np.round(coef_pval(clf, X, y), 6)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/regressors/stats.py in coef_se(clf, X, y)
#     145     se_matrix = scipy.linalg.sqrtm(
#     146         metrics.mean_squared_error(y, clf.predict(X)) *
# --> 147         np.linalg.inv(X1.T * X1)
#     148     )
#     149     return np.diagonal(se_matrix)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
